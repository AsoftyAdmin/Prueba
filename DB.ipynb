-- %% [markdown]
-- # [dbo].[Academica]

-- %%
USE [AsoftyDB]
GO

-- %%
/****** Object:  Table [dbo].[Academica]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Academica](
	[idAcademico] [int] IDENTITY(1,1) NOT NULL,
	[Rector] [nvarchar](250) NULL,
	[Secretaria] [nvarchar](250) NULL,
	[Resolucion] [nvarchar](250) NULL,
	[Departamento] [nvarchar](250) NULL,
	[Municipio] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Academica] PRIMARY KEY CLUSTERED 
(
	[idAcademico] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Actividades]

-- %%
/****** Object:  Table [dbo].[Actividades]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Actividades](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Actividad] [nvarchar](250) NULL,
	[TCree] [float] NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Actividades] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Activos]

-- %%
/****** Object:  Table [dbo].[Activos]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Activos](
	[IdActivo] [int] NOT NULL,
	[DescripciónActivo] [nvarchar](255) NULL,
	[IdEmpleado] [nvarchar](250) NULL,
	[IdCategoríaActivo] [int] NULL,
	[IdSituación] [int] NULL,
	[NúmModelo] [nvarchar](250) NULL,
	[NúmSerie] [nvarchar](250) NULL,
	[CódigoDeBarras] [nvarchar](250) NULL,
	[FechaCompra] [smalldatetime] NULL,
	[FechaDeVenta] [smalldatetime] NULL,
	[PrecioCompra] [int] NULL,
	[MétodoDepreciación] [nvarchar](250) NULL,
	[VidaDepreciable] [int] NULL,
	[ValorRescate] [int] NULL,
	[ValorActual] [int] NULL,
	[Comentarios] [nvarchar](250) NULL,
	[Descripción] [nvarchar](255) NULL,
	[PróxFechaMant] [smalldatetime] NULL,
	[Fproceso] [smalldatetime] NULL,
	[Documento] [nvarchar](250) NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Neto] [int] NULL,
	[Procesar] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Niif] [nvarchar](50) NULL,
	[Local] [nvarchar](50) NULL,
 CONSTRAINT [PK_Activos] PRIMARY KEY CLUSTERED 
(
	[IdActivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Activos fijos]

-- %%
/****** Object:  Table [dbo].[Activos fijos]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Activos fijos](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Idproyectos] [int] NOT NULL,
	[AF1] [nvarchar](250) NULL,
	[Q1] [int] NULL,
	[CU1] [int] NULL,
	[VU1] [int] NULL,
	[Q2] [int] NULL,
	[CU2] [int] NULL,
 CONSTRAINT [PK_Activos fijos] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Activosub]

-- %%
/****** Object:  Table [dbo].[Activosub]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Activosub](
	[IdActivo] [int] NOT NULL,
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Componente] [nvarchar](250) NULL,
	[Vida] [int] NULL,
	[IdComponente] [int] NULL,
 CONSTRAINT [PK_Activosub] PRIMARY KEY CLUSTERED 
(
	[IdControl] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Adicion]

-- %%
/****** Object:  Table [dbo].[Adicion]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Adicion](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[TransferNo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Remesa] [int] NULL,
	[Cliente] [nvarchar](250) NULL,
	[Placa] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Tenedor] [nvarchar](50) NULL,
	[Tipo] [nvarchar](50) NULL,
 CONSTRAINT [PK_Adicion] PRIMARY KEY CLUSTERED 
(
	[TransferNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Adicionsub]

-- %%
/****** Object:  Table [dbo].[Adicionsub]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Adicionsub](
	[idtranfersub] [int] IDENTITY(1,1) NOT NULL,
	[TransferNo] [int] NULL,
	[Referencia] [nvarchar](250) NULL,
	[Cantidad] [float] NULL,
	[Neto] [int] NULL,
	[Costo] [int] NULL,
	[Notas] [nvarchar](250) NULL,
	[Estadosub] [int] NULL,
	[Estadoliq] [int] NULL,
	[DO] [int] NULL,
	[Proveedor] [nvarchar](50) NULL,
 CONSTRAINT [PK_Adicionsub] PRIMARY KEY CLUSTERED 
(
	[idtranfersub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaDeclara]

-- %%
/****** Object:  Table [dbo].[AduanaDeclara]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaDeclara](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_AduanaDeclara] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaDps]

-- %%
/****** Object:  Table [dbo].[AduanaDps]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaDps](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Ciudad] [nvarchar](50) NULL,
	[Direccion] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_AduanaDps] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaDpto]

-- %%
/****** Object:  Table [dbo].[AduanaDpto]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaDpto](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_AduanaDpto] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaEmb]

-- %%
/****** Object:  Table [dbo].[AduanaEmb]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaEmb](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_AduanaEmb] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaExpo]

-- %%
/****** Object:  Table [dbo].[AduanaExpo]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaExpo](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[FormularioNo] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Fecha] [datetime] NULL,
	[Año] [int] NULL,
	[Exportador] [nvarchar](50) NULL,
	[CodAdmon] [nvarchar](50) NULL,
	[Declarante] [nvarchar](50) NULL,
	[Suscriptor] [nvarchar](50) NULL,
	[ClaseExpo] [nvarchar](50) NULL,
	[Importador] [nvarchar](50) NULL,
	[DirecDestino] [nvarchar](50) NULL,
	[Codpaisdestino] [nvarchar](50) NULL,
	[Citypaisdestino] [nvarchar](50) NULL,
	[AutorizaEmbarque] [nvarchar](50) NULL,
	[Fautorizaembarque] [datetime] NULL,
	[TipoDeclara] [nvarchar](50) NULL,
	[CodLugarSalida] [nvarchar](50) NULL,
	[CodDptoProcedencia] [nvarchar](50) NULL,
	[DecExpoAnterior] [nvarchar](50) NULL,
	[FDecExpoanter] [datetime] NULL,
	[AdhesivoImpoanterior] [nvarchar](50) NULL,
	[FAdhesivo] [datetime] NULL,
	[CodModaImpo] [nvarchar](50) NULL,
	[CodMincomercio] [nvarchar](50) NULL,
	[CodMoneda] [nvarchar](50) NULL,
	[TotalMoneda] [float] NULL,
	[CodModotransporte] [nvarchar](50) NULL,
	[CodBandera] [nvarchar](50) NULL,
	[PesoBruto] [float] NULL,
	[CodModalidad] [nvarchar](50) NULL,
	[CodFormapago] [nvarchar](50) NULL,
	[QPgAnticipados] [int] NULL,
	[FPgAnticipado] [datetime] NULL,
	[CodEmbarque] [nvarchar](50) NULL,
	[Consolidacion] [nvarchar](50) NULL,
	[QEmbarques] [int] NULL,
	[CodDatos] [nvarchar](50) NULL,
	[CodEmbalaje] [nvarchar](50) NULL,
	[QEmbalajes] [int] NULL,
	[CertiOrigen] [nvarchar](50) NULL,
	[Cual] [nvarchar](50) NULL,
	[SEspeciales] [nvarchar](50) NULL,
	[SEsp67] [nvarchar](50) NULL,
	[SEsp68] [nvarchar](50) NULL,
	[SEsp69] [nvarchar](50) NULL,
	[SEsp70] [nvarchar](50) NULL,
	[SEsp71] [nvarchar](50) NULL,
	[SEsp72] [nvarchar](50) NULL,
	[SEsp73] [nvarchar](50) NULL,
	[NameVbentidad] [nvarchar](50) NULL,
	[NoVbentidad] [nvarchar](50) NULL,
	[FVbentidad] [datetime] NULL,
	[NameVbentidad2] [nvarchar](50) NULL,
	[NoVbentidad2] [nvarchar](50) NULL,
	[FVbentidad2] [datetime] NULL,
	[CodExpTransito] [nvarchar](50) NULL,
	[CodAdmonEmbque] [nvarchar](50) NULL,
	[CodLocMcia] [nvarchar](50) NULL,
	[ItemNo] [nvarchar](50) NULL,
	[CodSubpartida] [nvarchar](50) NULL,
	[CodDepOrigen] [nvarchar](50) NULL,
	[FacturaNo] [nvarchar](50) NULL,
	[CodUniComercial] [nvarchar](50) NULL,
	[Cantidad] [float] NULL,
	[PesoNeto] [float] NULL,
	[VlrFOB] [float] NULL,
	[VAN] [float] NULL,
	[CIP] [float] NULL,
	[Aplicacion] [nvarchar](50) NULL,
	[DescrpMerca] [ntext] NULL,
	[QSubpartidas] [int] NULL,
	[HojasAnexas] [nvarchar](50) NULL,
	[TPesoNeto] [float] NULL,
	[TFOB] [float] NULL,
	[TVAN] [float] NULL,
	[QHojasAnexas] [int] NULL,
	[VlrFletes] [float] NULL,
	[VlrSeguros] [float] NULL,
	[VlrOtros] [float] NULL,
	[VlrTExpo] [float] NULL,
	[VlrReintegro] [float] NULL,
 CONSTRAINT [PK_AduanaExpo] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaImpo]

-- %%
/****** Object:  Table [dbo].[AduanaImpo]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaImpo](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[FormularioNo] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Fecha] [datetime] NULL,
	[Año] [int] NULL,
	[Importador] [nvarchar](50) NULL,
	[Declarante] [nvarchar](50) NULL,
	[ClaseImportador] [nvarchar](50) NULL,
	[TipoDeclaracion] [nvarchar](50) NULL,
	[DecAnterior] [nvarchar](50) NULL,
	[FDecAnterior] [datetime] NULL,
	[SecAnterior] [nvarchar](50) NULL,
	[DecExporta] [nvarchar](50) NULL,
	[FExporta] [datetime] NULL,
	[SecExporta] [nvarchar](50) NULL,
	[CodIngMcia] [nvarchar](50) NULL,
	[CodDeposito] [nvarchar](50) NULL,
	[ManCarga] [nvarchar](50) NULL,
	[Fllegada] [datetime] NULL,
	[DocTransporte] [nvarchar](50) NULL,
	[FTransporte] [datetime] NULL,
	[Exportador] [nvarchar](50) NULL,
	[CityExpo] [nvarchar](50) NULL,
	[CodpaisExpo] [nvarchar](50) NULL,
	[DirExpo] [nvarchar](50) NULL,
	[MailExpo] [nvarchar](50) NULL,
	[FacturaExpo] [nvarchar](50) NULL,
	[FfacExpo] [datetime] NULL,
	[CodpaisProc] [nvarchar](50) NULL,
	[CodModtrans] [nvarchar](50) NULL,
	[CodBandera] [nvarchar](50) NULL,
	[CodDestino] [nvarchar](50) NULL,
	[Transportadora] [nvarchar](50) NULL,
	[TRM] [float] NULL,
	[Subpartida] [nvarchar](50) NULL,
	[CodComplementa] [nvarchar](50) NULL,
	[CodSuplementa] [nvarchar](50) NULL,
	[CodModalidad] [nvarchar](50) NULL,
	[Cuotas] [int] NULL,
	[VlrCuotas] [float] NULL,
	[Periodo] [nvarchar](50) NULL,
	[CodpaisOrigen] [nvarchar](50) NULL,
	[CodAcuerdo] [nvarchar](50) NULL,
	[CodPago] [nvarchar](50) NULL,
	[TipoImporta] [nvarchar](50) NULL,
	[CodCompra] [nvarchar](50) NULL,
	[PesoBruto] [float] NULL,
	[PesoNeto] [float] NULL,
	[CodEmbala] [nvarchar](50) NULL,
	[Bultos] [int] NULL,
	[NoSubpartidas] [int] NULL,
	[CodUnidad] [nvarchar](50) NULL,
	[Cantidad] [int] NULL,
	[VlrFOB] [float] NULL,
	[VlrFletes] [float] NULL,
	[VlrSeguros] [float] NULL,
	[VlrOtros] [float] NULL,
	[VlrAjuste] [float] NULL,
	[VlrAduana] [float] NULL,
	[CodRegistro] [nvarchar](50) NULL,
	[NoRegistro] [nvarchar](50) NULL,
	[CodOficina] [nvarchar](50) NULL,
	[AñoRegistro] [int] NULL,
	[NoPrograma] [nvarchar](50) NULL,
	[CodInterno] [nvarchar](50) NULL,
	[DescrpMerca] [ntext] NULL,
	[PArancel] [float] NULL,
	[BArancel] [float] NULL,
	[SArancel] [float] NULL,
	[TArancel] [float] NULL,
	[UArancel] [float] NULL,
	[PIVA] [float] NULL,
	[BIVA] [float] NULL,
	[SIVA] [float] NULL,
	[TIVA] [float] NULL,
	[UIVA] [float] NULL,
	[PSalva] [float] NULL,
	[BSalva] [float] NULL,
	[SSalva] [float] NULL,
	[TSalva] [float] NULL,
	[USalva] [float] NULL,
	[PCompensa] [float] NULL,
	[BCompensa] [float] NULL,
	[SCompensa] [float] NULL,
	[TCompensa] [float] NULL,
	[UCompensa] [float] NULL,
	[PAntid] [float] NULL,
	[BAntid] [float] NULL,
	[SAntid] [float] NULL,
	[TAntid] [float] NULL,
	[UAntid] [float] NULL,
	[PSancion] [float] NULL,
	[BSancion] [float] NULL,
	[SSancion] [float] NULL,
	[TSancion] [float] NULL,
	[PRescate] [float] NULL,
	[BRescate] [float] NULL,
	[SRescate] [float] NULL,
	[TRescate] [float] NULL,
	[Pagoant] [float] NULL,
	[Reciboant] [nvarchar](50) NULL,
	[FPagoant] [datetime] NULL,
 CONSTRAINT [PK_AduanaImpo] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaIng]

-- %%
/****** Object:  Table [dbo].[AduanaIng]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaIng](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_AduanaIng] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaLiq]

-- %%
/****** Object:  Table [dbo].[AduanaLiq]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaLiq](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [datetime] NULL,
	[DO] [int] NULL,
	[Modalidad] [nvarchar](50) NULL,
	[TRM] [float] NULL,
	[Observaciones] [ntext] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_AduanaLiq] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaLiqsub]

-- %%
/****** Object:  Table [dbo].[AduanaLiqsub]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaLiqsub](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Posicion] [nvarchar](50) NULL,
	[PesoBruto] [float] NULL,
	[PesoNeto] [float] NULL,
	[Bultos] [float] NULL,
	[Cantidad] [float] NULL,
	[FOB] [float] NULL,
	[Fletes] [float] NULL,
	[Seguro] [float] NULL,
	[Otros] [float] NULL,
	[Ajustes] [float] NULL,
	[Aduana] [float] NULL,
	[CIF] [float] NULL,
	[PArancel] [float] NULL,
	[Arancel] [float] NULL,
	[Piva] [float] NULL,
	[Iva] [float] NULL,
	[Sanciones] [float] NULL,
	[OtrosPagos] [float] NULL,
	[PagoAnt] [float] NULL,
	[TPagar] [float] NULL,
 CONSTRAINT [PK_AduanaLiqsub] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaMdEx]

-- %%
/****** Object:  Table [dbo].[AduanaMdEx]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaMdEx](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_AduanaMdEx] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaMod]

-- %%
/****** Object:  Table [dbo].[AduanaMod]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaMod](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Vigencia] [datetime] NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_AduanaMod] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaPago]

-- %%
/****** Object:  Table [dbo].[AduanaPago]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaPago](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](100) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_AduanaPago] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaPartidas]

-- %%
/****** Object:  Table [dbo].[AduanaPartidas]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaPartidas](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](250) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[PArancelp] [float] NULL,
	[PIvap] [float] NULL,
 CONSTRAINT [PK_AduanaPartidas] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaReg]

-- %%
/****** Object:  Table [dbo].[AduanaReg]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaReg](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_AduanaReg] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaSec]

-- %%
/****** Object:  Table [dbo].[AduanaSec]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaSec](
	[idControl] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_AduanaSec] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaTimp]

-- %%
/****** Object:  Table [dbo].[AduanaTimp]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaTimp](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_AduanaTimp] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaTrans]

-- %%
/****** Object:  Table [dbo].[AduanaTrans]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaTrans](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_AduanaTrans] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AduanaUni]

-- %%
/****** Object:  Table [dbo].[AduanaUni]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AduanaUni](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_AduanaUni] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Aerolineas]

-- %%
/****** Object:  Table [dbo].[Aerolineas]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Aerolineas](
	[IdDocumentos] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](50) NULL,
	[IATA] [nvarchar](50) NULL,
	[ICAO] [nvarchar](50) NULL,
	[Pais] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Aerolineas] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Aeropuertos]

-- %%
/****** Object:  Table [dbo].[Aeropuertos]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Aeropuertos](
	[IdDocumentos] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Ciudad] [nvarchar](50) NULL,
	[Pais] [nvarchar](50) NULL,
	[codpais] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Aeropuertos] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Afactura]

-- %%
/****** Object:  Table [dbo].[Afactura]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Afactura](
	[Idaplica] [int] IDENTITY(1,1) NOT NULL,
	[IdCaja] [int] NOT NULL,
	[Factura] [int] NULL,
	[Neto] [float] NULL,
	[DO] [int] NULL,
	[Concepto] [nvarchar](50) NULL,
	[US] [float] NULL,
	[VRecibido] [int] NULL,
	[Tasa] [float] NULL,
	[Docu] [nvarchar](50) NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Tipo] [nvarchar](250) NULL,
	[Bl] [nvarchar](250) NULL,
	[Contenedor] [nvarchar](250) NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Dias] [int] NULL,
	[Prefijo] [nvarchar](50) NULL,
	[TRM] [float] NULL,
 CONSTRAINT [PK_Afactura] PRIMARY KEY CLUSTERED 
(
	[Idaplica] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Afacturaegreso]

-- %%
/****** Object:  Table [dbo].[Afacturaegreso]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Afacturaegreso](
	[Idaplica] [int] IDENTITY(1,1) NOT NULL,
	[IdEgreso] [int] NOT NULL,
	[Factura] [int] NULL,
	[Neto] [float] NULL,
	[DO] [int] NULL,
	[US] [float] NULL,
	[VRecibido] [int] NULL,
	[FFac] [smalldatetime] NULL,
	[Tasa] [float] NULL,
	[TRM] [float] NULL,
	[Docu] [nvarchar](50) NULL,
	[Manifiesto] [int] NULL,
	[Doctransporte] [nvarchar](50) NULL,
	[Bl] [nvarchar](50) NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Prefijo] [nvarchar](50) NULL,
 CONSTRAINT [PK_Afacturaegreso] PRIMARY KEY CLUSTERED 
(
	[Idaplica] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AfacturaEgresoVirtual]

-- %%
/****** Object:  Table [dbo].[AfacturaEgresoVirtual]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AfacturaEgresoVirtual](
	[Idaplica] [int] IDENTITY(1,1) NOT NULL,
	[IdEgreso] [int] NOT NULL,
	[Factura] [int] NULL,
	[Neto] [float] NULL,
	[DO] [int] NULL,
	[US] [float] NULL,
	[VRecibido] [int] NULL,
	[FFac] [smalldatetime] NULL,
	[Tasa] [float] NULL,
	[TRM] [float] NULL,
	[Manifiesto] [int] NULL,
	[Docu] [nvarchar](50) NULL,
	[Doctransporte] [nvarchar](50) NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Prefijo] [nvarchar](50) NULL,
 CONSTRAINT [PK_AfacturaEgresoVirtual] PRIMARY KEY CLUSTERED 
(
	[Idaplica] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AfacturaVirtual]

-- %%
/****** Object:  Table [dbo].[AfacturaVirtual]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AfacturaVirtual](
	[Idaplica] [int] IDENTITY(1,1) NOT NULL,
	[IdCaja] [int] NOT NULL,
	[Factura] [int] NULL,
	[Neto] [float] NULL,
	[DO] [int] NULL,
	[Concepto] [nvarchar](50) NULL,
	[US] [float] NULL,
	[VRecibido] [int] NULL,
	[Tasa] [float] NULL,
	[Docu] [nvarchar](50) NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Prefijo] [nvarchar](50) NULL,
	[TRM] [float] NULL,
 CONSTRAINT [PK_AfacturaVirtual] PRIMARY KEY CLUSTERED 
(
	[Idaplica] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agenda]

-- %%
/****** Object:  Table [dbo].[Agenda]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agenda](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[FECHA] [smalldatetime] NOT NULL,
	[FINICIAL] [smalldatetime] NULL,
	[FFINAL] [smalldatetime] NULL,
 CONSTRAINT [PK_Agenda] PRIMARY KEY CLUSTERED 
(
	[FECHA] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agenda2]

-- %%
/****** Object:  Table [dbo].[Agenda2]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agenda2](
	[Control] [int] IDENTITY(1,1) NOT NULL,
	[Fechas] [smalldatetime] NOT NULL,
	[HoraInicial] [datetime] NULL,
	[Consultor] [nvarchar](50) NULL,
	[Empresa] [nvarchar](50) NULL,
	[Lugar] [nvarchar](250) NULL,
	[Contacto] [nvarchar](50) NULL,
	[Notas] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Agenda2] PRIMARY KEY CLUSTERED 
(
	[Control] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agentes]

-- %%
/****** Object:  Table [dbo].[Agentes]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agentes](
	[IdProspectos] [int] IDENTITY(1,1) NOT NULL,
	[Identificacion] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Direccion] [nvarchar](250) NULL,
	[Telefono] [nvarchar](50) NULL,
	[Celular] [nvarchar](50) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Email] [nvarchar](250) NULL,
	[Contacto] [nvarchar](250) NULL,
	[Ciudad] [nvarchar](250) NULL,
 CONSTRAINT [PK_Agentes] PRIMARY KEY CLUSTERED 
(
	[Identificacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Aghouse]

-- %%
/****** Object:  Table [dbo].[Aghouse]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Aghouse](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[CentroCostos] [nvarchar](50) NULL,
	[Norden] [int] NOT NULL,
	[DocumentoBL] [nvarchar](50) NULL,
	[Fecha] [smalldatetime] NULL,
	[Shpper] [nvarchar](50) NULL,
	[PtoOrigen] [nvarchar](50) NULL,
	[PtoDestino] [nvarchar](50) NULL,
	[Motonave] [nvarchar](50) NULL,
	[Viaje] [nvarchar](50) NULL,
	[Patio] [nvarchar](50) NULL,
	[Cantidad] [nvarchar](50) NULL,
	[Tamaño] [nvarchar](50) NULL,
	[EstadoContene] [nvarchar](50) NULL,
	[Tipocarga] [ntext] NULL,
	[estado] [int] NULL,
	[Vendedor] [nvarchar](50) NULL,
	[Tflete] [nvarchar](50) NULL,
	[Consignatario] [nvarchar](50) NULL,
	[Emisionbl] [nvarchar](50) NULL,
	[facturacion] [nvarchar](50) NULL,
	[TImportacion] [nvarchar](50) NULL,
	[contacto] [nvarchar](50) NULL,
	[Notify] [nvarchar](50) NULL,
	[Agente] [nvarchar](50) NULL,
	[SIA] [nvarchar](50) NULL,
	[Tipotrafico] [nvarchar](50) NULL,
	[TipoServicio] [nvarchar](50) NULL,
	[Naviera] [nvarchar](50) NULL,
	[Emisionhbl] [nvarchar](50) NULL,
	[Fecharetiro] [smalldatetime] NULL,
	[EntregaCga] [nvarchar](50) NULL,
	[Fechaentregacga] [nchar](10) NULL,
	[BookingNo] [nvarchar](50) NULL,
	[FechaETA] [smalldatetime] NULL,
	[FechaETD] [smalldatetime] NULL,
	[PosiArancel] [nvarchar](50) NULL,
	[Rutahbl] [nvarchar](50) NULL,
	[Rutabl] [nvarchar](50) NULL,
	[Encargado] [nvarchar](50) NULL,
	[EstadoOrden] [nvarchar](50) NULL,
	[Cdigicoter] [nvarchar](50) NULL,
	[TipoDocumento] [nvarchar](50) NULL,
	[Terminal] [int] NULL,
	[Cotizacion] [int] NULL,
	[DONo] [int] NULL,
	[FCambioestado] [smalldatetime] NULL,
	[Letras] [nvarchar](250) NULL,
	[Piezas] [nvarchar](50) NULL,
	[Peso] [nvarchar](50) NULL,
	[Dimensiones] [nvarchar](50) NULL,
	[CIF] [int] NULL,
	[Tipomail] [nvarchar](50) NULL,
	[NotasEmbarque] [ntext] NULL,
	[NCotizacion] [int] NULL,
	[Operativo] [nvarchar](50) NULL,
	[Lugarrecibo] [nvarchar](50) NULL,
	[Lugarentrega] [nvarchar](50) NULL,
	[Copias] [nvarchar](50) NULL,
	[Destinofinal] [nvarchar](50) NULL,
	[PuertoOrigen] [nvarchar](50) NULL,
	[PuertoDestino] [nvarchar](50) NULL,
	[PreCarriage] [nvarchar](50) NULL,
	[Containerezed] [nvarchar](1) NULL,
	[TRM] [float] NULL,
	[TContenedores] [int] NULL,
	[TBL] [int] NULL,
 CONSTRAINT [PK_Aghouse] PRIMARY KEY CLUSTERED 
(
	[Norden] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Aghouseanexos]

-- %%
/****** Object:  Table [dbo].[Aghouseanexos]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Aghouseanexos](
	[Idnordena] [int] IDENTITY(1,1) NOT NULL,
	[Norden] [int] NULL,
	[Tipo] [nvarchar](50) NULL,
	[RutaFoto] [nvarchar](250) NULL,
	[Situacion] [nvarchar](50) NULL,
	[Notas] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Gestor] [nvarchar](50) NULL,
 CONSTRAINT [PK_Aghouseanexos] PRIMARY KEY CLUSTERED 
(
	[Idnordena] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Aghousecontenedor]

-- %%
/****** Object:  Table [dbo].[Aghousecontenedor]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Aghousecontenedor](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Norden] [int] NULL,
	[NoContendor] [nvarchar](50) NULL,
	[Tipo] [nvarchar](50) NULL,
	[Tamaño] [int] NULL,
	[Cantidad] [int] NULL,
	[Kilos] [float] NULL,
	[House] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
	[Pedido] [int] NULL,
	[Precinto] [nvarchar](50) NULL,
	[Tipomercancia] [nvarchar](250) NULL,
	[Volumen] [float] NULL,
 CONSTRAINT [PK_Aghousecontenedor] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Aghousefletes]

-- %%
/****** Object:  Table [dbo].[Aghousefletes]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Aghousefletes](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Norden] [int] NULL,
	[Concepto] [nvarchar](50) NOT NULL,
	[Moneda] [nvarchar](50) NULL,
	[Neto] [float] NULL,
	[Netoreal] [float] NULL,
	[TRM1] [float] NULL,
	[TRM2] [float] NULL,
	[Certifica] [nvarchar](50) NULL,
	[Pesos] [int] NULL,
	[Cantidad] [float] NULL,
	[Anticipo] [int] NULL,
	[Tercero] [nvarchar](250) NULL,
	[Costous] [float] NULL,
	[Invoice] [nvarchar](50) NULL,
	[Fecha] [smalldatetime] NULL,
	[Notas] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Peso] [float] NULL,
	[Tfletesub] [nvarchar](50) NULL,
	[Preciounit] [float] NULL,
	[Costounit] [float] NULL,
 CONSTRAINT [PK_Aghousefletes] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Aghouseservicios]

-- %%
/****** Object:  Table [dbo].[Aghouseservicios]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Aghouseservicios](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Norden] [int] NULL,
	[TipoServicio] [nvarchar](50) NULL,
	[Empresa] [nvarchar](50) NULL,
	[Neto] [int] NULL,
	[Netoreal] [int] NULL,
	[Moneda] [nvarchar](50) NULL,
 CONSTRAINT [PK_Aghouseservicios] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agicoterms]

-- %%
/****** Object:  Table [dbo].[Agicoterms]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agicoterms](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Agicoterms] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agordenactividad]

-- %%
/****** Object:  Table [dbo].[Agordenactividad]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agordenactividad](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CdigActivi] [nvarchar](50) NULL,
	[Actividad] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Agordenactividad] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agordenruta]

-- %%
/****** Object:  Table [dbo].[Agordenruta]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agordenruta](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[CentroCostos] [nvarchar](50) NULL,
	[Norden] [int] NOT NULL,
	[DocumentoBL] [nvarchar](50) NULL,
	[Fecha] [smalldatetime] NULL,
	[Shpper] [nvarchar](50) NULL,
	[PtoOrigen] [nvarchar](50) NULL,
	[PtoDestino] [nvarchar](50) NULL,
	[Motonave] [nvarchar](50) NULL,
	[Viaje] [nvarchar](50) NULL,
	[Patio] [nvarchar](50) NULL,
	[Cantidad] [nvarchar](50) NULL,
	[Tamaño] [nvarchar](50) NULL,
	[EstadoContene] [nvarchar](50) NULL,
	[Tipocarga] [ntext] NULL,
	[estado] [int] NULL,
	[Vendedor] [nvarchar](50) NULL,
	[Tflete] [nvarchar](50) NULL,
	[Consignatario] [nvarchar](50) NULL,
	[Emisionbl] [nvarchar](50) NULL,
	[facturacion] [nvarchar](50) NULL,
	[TImportacion] [nvarchar](50) NULL,
	[contacto] [nvarchar](50) NULL,
	[Notify] [nvarchar](50) NULL,
	[Agente] [nvarchar](50) NULL,
	[SIA] [nvarchar](50) NULL,
	[Tipotrafico] [nvarchar](50) NULL,
	[TipoServicio] [nvarchar](50) NULL,
	[Naviera] [nvarchar](50) NULL,
	[Emisionhbl] [nvarchar](50) NULL,
	[Fecharetiro] [smalldatetime] NULL,
	[EntregaCga] [nvarchar](50) NULL,
	[Fechaentregacga] [smalldatetime] NULL,
	[BookingNo] [nvarchar](50) NULL,
	[FechaETA] [smalldatetime] NULL,
	[FechaETD] [smalldatetime] NULL,
	[PosiArancel] [nvarchar](50) NULL,
	[Rutahbl] [nvarchar](50) NULL,
	[Rutabl] [nvarchar](50) NULL,
	[Encargado] [nvarchar](50) NULL,
	[EstadoOrden] [nvarchar](50) NULL,
	[Cdigicoter] [nvarchar](50) NULL,
	[TipoDocumento] [nvarchar](50) NULL,
	[Terminal] [int] NULL,
	[DONo] [int] NULL,
	[FCambioestado] [smalldatetime] NULL,
	[Letras] [nvarchar](250) NULL,
	[Piezas] [nvarchar](50) NULL,
	[Peso] [nvarchar](50) NULL,
	[Dimensiones] [nvarchar](50) NULL,
	[CIF] [int] NULL,
	[FDoctrans] [smalldatetime] NULL,
	[Warehouse] [nvarchar](50) NULL,
	[Noconsolidado] [nvarchar](50) NULL,
	[FWareh] [smalldatetime] NULL,
	[Porige] [nvarchar](50) NULL,
	[Pdestin] [nvarchar](50) NULL,
	[Colauder] [nvarchar](50) NULL,
	[diasdemora] [int] NULL,
	[Radicacion] [nvarchar](50) NULL,
	[diaslibres] [int] NULL,
	[Fllegctn] [smalldatetime] NULL,
	[fdevctn] [smalldatetime] NULL,
	[Tipomail] [nvarchar](50) NULL,
	[NotasEmbarque] [ntext] NULL,
	[Operativo] [nvarchar](50) NULL,
	[NCotizacion] [int] NULL,
	[ReferenciasExpo] [nvarchar](50) NULL,
	[PuertoOrigen] [nvarchar](50) NULL,
	[PuertoDestino] [nvarchar](50) NULL,
	[PagoCarga] [nvarchar](50) NULL,
	[TRM] [float] NULL,
	[TContenedores] [int] NULL,
	[TBL] [int] NULL,
 CONSTRAINT [PK_Agordenruta] PRIMARY KEY CLUSTERED 
(
	[Norden] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agordenrutaanexos]

-- %%
/****** Object:  Table [dbo].[Agordenrutaanexos]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agordenrutaanexos](
	[Idnordena] [int] IDENTITY(1,1) NOT NULL,
	[Norden] [int] NULL,
	[Tipo] [nvarchar](50) NULL,
	[RutaFoto] [nvarchar](250) NULL,
	[Situacion] [nvarchar](50) NULL,
	[Notas] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Gestor] [nvarchar](50) NULL,
 CONSTRAINT [PK_Agordenrutaanexos] PRIMARY KEY CLUSTERED 
(
	[Idnordena] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agordenrutacontenedor]

-- %%
/****** Object:  Table [dbo].[Agordenrutacontenedor]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agordenrutacontenedor](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Norden] [int] NULL,
	[NoContendor] [nvarchar](50) NULL,
	[House] [nvarchar](50) NULL,
	[Tipo] [nvarchar](50) NULL,
	[Tamaño] [int] NULL,
	[Cantidad] [int] NULL,
	[Kilos] [float] NULL,
	[Destino] [nvarchar](50) NULL,
	[Pedido] [int] NULL,
	[Precinto] [nvarchar](50) NULL,
	[Tipomercancia] [nvarchar](250) NULL,
	[Volumen] [float] NULL,
	[UPeso] [nvarchar](50) NULL,
	[UVolumen] [nvarchar](50) NULL,
 CONSTRAINT [PK_Agordenrutacontenedor] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agordenrutafletes]

-- %%
/****** Object:  Table [dbo].[Agordenrutafletes]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agordenrutafletes](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Norden] [int] NULL,
	[Concepto] [nvarchar](50) NOT NULL,
	[Moneda] [nvarchar](50) NULL,
	[Neto] [float] NULL,
	[Netoreal] [float] NULL,
	[TRM1] [float] NULL,
	[TRM2] [float] NULL,
	[Certifica] [nvarchar](50) NULL,
	[Pesos] [int] NULL,
	[Cantidad] [float] NULL,
	[Tercero] [nvarchar](250) NULL,
	[Costous] [float] NULL,
	[Invoice] [nvarchar](50) NULL,
	[Anticipo] [int] NULL,
	[Fecha] [smalldatetime] NULL,
	[Notas] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Peso] [float] NULL,
	[Tfletesub] [nvarchar](50) NULL,
	[Preciounit] [float] NULL,
	[Costounit] [float] NULL,
 CONSTRAINT [PK_Agordenrutafletes] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agordenrutaservicios]

-- %%
/****** Object:  Table [dbo].[Agordenrutaservicios]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agordenrutaservicios](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Norden] [int] NULL,
	[TipoServicio] [nvarchar](50) NULL,
	[Empresa] [nvarchar](50) NULL,
	[Neto] [int] NULL,
	[Netoreal] [int] NULL,
	[Moneda] [nvarchar](50) NULL,
 CONSTRAINT [PK_Agordenrutaservicios] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agpedidoscontenedor]

-- %%
/****** Object:  Table [dbo].[Agpedidoscontenedor]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agpedidoscontenedor](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Factura] [int] NULL,
	[NoContendor] [nvarchar](50) NULL,
	[Pedido] [nvarchar](50) NULL,
 CONSTRAINT [PK_Agpedidoscontenedor] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AgrupaMenor]

-- %%
/****** Object:  Table [dbo].[AgrupaMenor]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AgrupaMenor](
	[IdAgrupa] [int] IDENTITY(1,1) NOT NULL,
	[Grupo] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Cuenta] [nvarchar](50) NULL,
	[CuentaIva] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[CuentaRetefte] [nvarchar](50) NULL,
 CONSTRAINT [PK_AgrupaMenor] PRIMARY KEY CLUSTERED 
(
	[Grupo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agseguimiento]

-- %%
/****** Object:  Table [dbo].[Agseguimiento]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agseguimiento](
	[Idseguimiento] [int] IDENTITY(1,1) NOT NULL,
	[Norden] [int] NULL,
	[Fechaseg] [smalldatetime] NULL,
	[Hora] [smalldatetime] NULL,
	[Resultado] [nvarchar](50) NULL,
	[FProceso] [smalldatetime] NULL,
	[Tiposeguimiento] [int] NULL,
	[Gestor] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Nota] [ntext] NULL,
	[Status] [nvarchar](50) NULL,
	[FNueva] [smalldatetime] NULL,
 CONSTRAINT [PK_Agseguimiento] PRIMARY KEY CLUSTERED 
(
	[Idseguimiento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agseguimientohouse]

-- %%
/****** Object:  Table [dbo].[Agseguimientohouse]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agseguimientohouse](
	[Idseguimiento] [int] IDENTITY(1,1) NOT NULL,
	[Norden] [int] NULL,
	[Fechaseg] [smalldatetime] NULL,
	[Hora] [smalldatetime] NULL,
	[Resultado] [int] NULL,
	[FProceso] [smalldatetime] NULL,
	[Tiposeguimiento] [int] NULL,
	[Gestor] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Nota] [ntext] NULL,
	[Status] [nvarchar](50) NULL,
	[FNueva] [smalldatetime] NULL,
 CONSTRAINT [PK_Agseguimientohouse] PRIMARY KEY CLUSTERED 
(
	[Idseguimiento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agtipoanexos]

-- %%
/****** Object:  Table [dbo].[Agtipoanexos]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agtipoanexos](
	[IdtipoAgdo] [int] IDENTITY(1,1) NOT NULL,
	[CodigoAnexo] [nvarchar](50) NOT NULL,
	[NombreAnexo] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
 CONSTRAINT [PK_Agtipoanexos] PRIMARY KEY CLUSTERED 
(
	[CodigoAnexo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agtipocon]

-- %%
/****** Object:  Table [dbo].[Agtipocon]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agtipocon](
	[Tipcon] [nvarchar](50) NOT NULL,
	[Tamcon] [int] NOT NULL,
	[Descripcion] [nvarchar](50) NULL,
	[Matcon] [nvarchar](50) NULL,
	[Tarcon] [float] NULL,
	[Anccon] [float] NULL,
	[Larcon] [float] NULL,
	[Capcon] [float] NULL,
	[Altcon] [float] NULL,
	[Volcon] [float] NULL,
	[Fchfab] [smalldatetime] NULL,
	[Iso] [int] NULL,
	[Tipotam] [nvarchar](50) NULL,
 CONSTRAINT [PK_Agtipocon] PRIMARY KEY CLUSTERED 
(
	[Tipcon] ASC,
	[Tamcon] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AgTipoguia]

-- %%
/****** Object:  Table [dbo].[AgTipoguia]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AgTipoguia](
	[IdDocumentos] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_AgTipoguia] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agtiposervicio]

-- %%
/****** Object:  Table [dbo].[Agtiposervicio]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agtiposervicio](
	[IdDocumentos] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Anexos] [ntext] NULL,
 CONSTRAINT [PK_Agtiposervicio] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agtrafico]

-- %%
/****** Object:  Table [dbo].[Agtrafico]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agtrafico](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[grupda] [nvarchar](50) NULL,
	[nombre] [nvarchar](50) NULL,
 CONSTRAINT [PK_Agtrafico] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ajustes]

-- %%
/****** Object:  Table [dbo].[Ajustes]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ajustes](
	[Idajustes] [int] IDENTITY(1,1) NOT NULL,
	[Fecha] [smalldatetime] NOT NULL,
	[Cuenta] [nvarchar](250) NOT NULL,
	[Saldo] [int] NULL,
	[Paag] [float] NULL,
	[Partida] [nvarchar](250) NULL,
	[Imputacion] [nvarchar](250) NULL,
	[Contra] [nvarchar](250) NULL,
	[Imputacontra] [nvarchar](250) NULL,
	[Valor] [int] NULL,
	[ValorNegativo] [int] NULL,
 CONSTRAINT [PK_Ajustes] PRIMARY KEY CLUSTERED 
(
	[Fecha] ASC,
	[Cuenta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ajustesinf]

-- %%
/****** Object:  Table [dbo].[Ajustesinf]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ajustesinf](
	[idInforajuste] [int] IDENTITY(1,1) NOT NULL,
	[Ffinal] [smalldatetime] NULL,
 CONSTRAINT [PK_Ajustesinf] PRIMARY KEY CLUSTERED 
(
	[idInforajuste] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Alumnos]

-- %%
/****** Object:  Table [dbo].[Alumnos]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Alumnos](
	[IdAlumnos] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Tipo] [nvarchar](250) NULL,
	[Alumno] [nvarchar](250) NULL,
	[Direccion] [nvarchar](250) NULL,
	[Telefono] [nvarchar](250) NULL,
	[Curso] [nvarchar](250) NULL,
	[Jornada] [nvarchar](250) NULL,
	[Fecha matricula] [smalldatetime] NULL,
	[Valor matricula] [int] NULL,
	[Pension] [int] NULL,
	[Materiales] [int] NULL,
	[Uniformes] [int] NULL,
	[Otros] [int] NULL,
	[Anterior] [nvarchar](250) NULL,
	[Acudiente] [nvarchar](250) NULL,
	[Telefono acudiente] [nvarchar](250) NULL,
	[Grupo] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [nvarchar](50) NULL,
	[TipoDoc] [nvarchar](250) NULL,
	[NoDoc] [nvarchar](250) NULL,
	[Expedicion] [nvarchar](250) NULL,
	[LugarNacimiento] [nvarchar](250) NULL,
	[FechaNacimiento] [smalldatetime] NULL,
	[Edad] [nvarchar](250) NULL,
	[Sexo] [nvarchar](250) NULL,
	[Padre] [nvarchar](250) NULL,
	[DirPadre] [nvarchar](250) NULL,
	[TelPadre] [nvarchar](250) NULL,
	[ProfesionPadre] [nvarchar](250) NULL,
	[EmpresaPadre] [nvarchar](250) NULL,
	[TelEmpresaPadre] [nvarchar](250) NULL,
	[Madre] [nvarchar](250) NULL,
	[DirMadre] [nvarchar](250) NULL,
	[TelMadre] [nvarchar](250) NULL,
	[ProfesionMadre] [nvarchar](250) NULL,
	[EmpresaMadre] [nvarchar](250) NULL,
	[TelEmpresaMadre] [nvarchar](250) NULL,
	[DirAcudiente] [nvarchar](250) NULL,
	[ProfesionAcudiente] [nvarchar](250) NULL,
	[ParentezcoAcudiente] [nvarchar](250) NULL,
	[Apellido1] [nvarchar](50) NULL,
	[Apellido2] [nvarchar](50) NULL,
	[Nombre1] [nvarchar](50) NULL,
	[Nombre2] [nvarchar](50) NULL,
	[CodigoMpio] [nvarchar](250) NULL,
	[Celular] [nvarchar](250) NULL,
	[Email] [nvarchar](250) NULL,
	[Estado2] [int] NULL,
	[RutaFoto] [nvarchar](250) NULL,
 CONSTRAINT [PK_Alumnos] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Anticipos]

-- %%
/****** Object:  Table [dbo].[Anticipos]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Anticipos](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[IdAnticipos] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Nombre] [nvarchar](50) NULL,
	[Anticipo] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Documento] [nvarchar](250) NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Capital] [int] NULL,
	[Tasa] [float] NULL,
	[Tiempo] [int] NULL,
	[Frecuencia] [int] NULL,
	[Cuota] [int] NULL,
	[Finicio] [smalldatetime] NULL,
	[Concepto] [nvarchar](50) NULL,
 CONSTRAINT [PK_Anticipos] PRIMARY KEY CLUSTERED 
(
	[IdAnticipos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Anticipossub]

-- %%
/****** Object:  Table [dbo].[Anticipossub]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Anticipossub](
	[Idplan] [int] IDENTITY(1,1) NOT NULL,
	[idAnticipos] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Pago] [int] NULL,
	[Concepto] [nvarchar](50) NULL,
 CONSTRAINT [PK_Anticipossub] PRIMARY KEY CLUSTERED 
(
	[Idplan] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Anticipostrans]

-- %%
/****** Object:  Table [dbo].[Anticipostrans]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Anticipostrans](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Documento] [nvarchar](50) NULL,
	[DocNumero] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Placa] [nvarchar](50) NULL,
	[Tenedor] [nvarchar](50) NULL,
	[Flete] [int] NULL,
	[Porc] [float] NULL,
	[Neto] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Fproceso] [smalldatetime] NULL,
	[Terminal] [int] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Autorizado] [float] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Egreso] [int] NULL,
	[Banco] [nvarchar](250) NULL,
	[Comprobante] [int] NULL,
	[DO] [int] NULL,
	[Control] [int] NULL,
 CONSTRAINT [PK_Anticipostrans] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ARP]

-- %%
/****** Object:  Table [dbo].[ARP]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ARP](
	[idARP] [int] IDENTITY(1,1) NOT NULL,
	[ARP] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Tercero] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_ARP] PRIMARY KEY CLUSTERED 
(
	[ARP] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Auditoria]

-- %%
/****** Object:  Table [dbo].[Auditoria]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Auditoria](
	[IdAuditoria] [int] IDENTITY(1,1) NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Hora] [smalldatetime] NULL,
	[Nombre] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Comprobante] [nvarchar](50) NULL,
	[Tipo] [nvarchar](50) NULL,
	[Transac] [nvarchar](50) NULL,
 CONSTRAINT [PK_Auditoria] PRIMARY KEY CLUSTERED 
(
	[IdAuditoria] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Autentica]

-- %%
/****** Object:  Table [dbo].[Autentica]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Autentica](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Cliente] [nvarchar](50) NOT NULL,
	[Usuario] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Password] [nvarchar](50) NULL,
	[Gestor] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Autentica] PRIMARY KEY CLUSTERED 
(
	[Cliente] ASC,
	[Usuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Autorizaciones]

-- %%
/****** Object:  Table [dbo].[Autorizaciones]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Autorizaciones](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[AutorizaNo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Dias] [int] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Tercero] [nvarchar](50) NULL,
	[Neto] [int] NULL,
	[BL] [nvarchar](50) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Aprobo] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Autorizaciones] PRIMARY KEY CLUSTERED 
(
	[AutorizaNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Bancos]

-- %%
/****** Object:  Table [dbo].[Bancos]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Bancos](
	[Idbancos] [int] IDENTITY(1,1) NOT NULL,
	[Banco] [nvarchar](250) NOT NULL,
	[Observacion] [nvarchar](250) NULL,
	[Cuenta] [nvarchar](250) NULL,
	[Imputacion] [nvarchar](250) NULL,
	[NInicial] [float] NULL,
	[NFinal] [float] NULL,
	[CuentaImpuesto] [nvarchar](250) NULL,
	[Pimpuesto] [float] NULL,
	[Estado] [int] NULL,
	[Comision] [float] NULL,
	[PRetefuente] [float] NULL,
	[PReteiva] [float] NULL,
	[PReteica] [float] NULL,
	[CuentaC] [nvarchar](50) NULL,
	[CuentaRfte] [nvarchar](50) NULL,
	[CuentaRiva] [nvarchar](50) NULL,
	[CuentaRica] [nvarchar](50) NULL,
	[CuentaNeto] [nvarchar](50) NULL,
	[Tercero] [nvarchar](50) NULL,
 CONSTRAINT [PK_Bancos] PRIMARY KEY CLUSTERED 
(
	[Banco] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BaseConductor]

-- %%
/****** Object:  Table [dbo].[BaseConductor]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BaseConductor](
	[idBase] [int] IDENTITY(1,1) NOT NULL,
	[Cedula] [nvarchar](50) NOT NULL,
	[Responsable] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_BaseConductor] PRIMARY KEY CLUSTERED 
(
	[idBase] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BaseContenedor]

-- %%
/****** Object:  Table [dbo].[BaseContenedor]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BaseContenedor](
	[idBase] [int] IDENTITY(1,1) NOT NULL,
	[Remesa] [int] NOT NULL,
	[Responsable] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Fecha] [smalldatetime] NULL,
	[ContenedorNo] [nvarchar](50) NULL,
	[OCargue] [int] NULL,
	[Conductor] [nvarchar](50) NULL,
	[Placa] [nvarchar](50) NULL,
	[Sellos] [nvarchar](50) NULL,
	[Patio] [nvarchar](50) NULL,
	[Cliente] [nvarchar](50) NULL,
	[Reserva] [nvarchar](50) NULL,
 CONSTRAINT [PK_BaseContenedor] PRIMARY KEY CLUSTERED 
(
	[idBase] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BaseVehiculos]

-- %%
/****** Object:  Table [dbo].[BaseVehiculos]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BaseVehiculos](
	[idBase] [int] IDENTITY(1,1) NOT NULL,
	[Placa2] [nvarchar](250) NOT NULL,
	[Responsable] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_BaseVehiculos] PRIMARY KEY CLUSTERED 
(
	[idBase] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CajaMenor]

-- %%
/****** Object:  Table [dbo].[CajaMenor]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CajaMenor](
	[Idcajamenor] [int] IDENTITY(1,1) NOT NULL,
	[IdEgreso] [int] NULL,
	[fecha] [smalldatetime] NULL,
	[Documento] [int] NULL,
	[Concepto] [nvarchar](50) NULL,
	[Grupo] [nvarchar](250) NULL,
	[Neto] [int] NULL,
	[iva] [int] NULL,
	[total] [int] NULL,
	[Identificacion] [nvarchar](250) NULL,
	[Placa] [nvarchar](250) NULL,
	[CMedios] [nvarchar](50) NULL,
	[DO] [int] NULL,
	[Referencia] [nvarchar](250) NULL,
	[Doc] [nvarchar](50) NULL,
	[Consecutivo] [int] NULL,
	[Retefte] [int] NULL,
 CONSTRAINT [PK_CajaMenor] PRIMARY KEY CLUSTERED 
(
	[Idcajamenor] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CajaMenorEnc]

-- %%
/****** Object:  Table [dbo].[CajaMenorEnc]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CajaMenorEnc](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Documento] [nvarchar](50) NOT NULL,
	[IdEgreso] [int] NOT NULL,
	[Anticipo] [int] NULL,
	[Finicial] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
	[Concepto] [nvarchar](50) NULL,
	[Doc] [nvarchar](50) NULL,
	[Docu] [nvarchar](50) NULL,
	[Comprobante] [int] NULL,
	[Estado] [int] NULL,
	[Tercero] [nvarchar](50) NULL,
	[Fecha] [smalldatetime] NULL,
 CONSTRAINT [PK_CajaMenorEnc] PRIMARY KEY CLUSTERED 
(
	[Documento] ASC,
	[IdEgreso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Calificacion]

-- %%
/****** Object:  Table [dbo].[Calificacion]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Calificacion](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Calificacion] [int] NOT NULL,
	[Significado] [nvarchar](50) NULL,
 CONSTRAINT [PK_Calificacion] PRIMARY KEY CLUSTERED 
(
	[Calificacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Calificaciones]

-- %%
/****** Object:  Table [dbo].[Calificaciones]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Calificaciones](
	[IdCalificaciones] [int] IDENTITY(1,1) NOT NULL,
	[Calificacion] [nvarchar](250) NOT NULL,
	[Significado] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
 CONSTRAINT [PK_Calificaciones] PRIMARY KEY CLUSTERED 
(
	[Calificacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Canales]

-- %%
/****** Object:  Table [dbo].[Canales]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Canales](
	[idcanal] [int] IDENTITY(1,1) NOT NULL,
	[Canal] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Canales] PRIMARY KEY CLUSTERED 
(
	[Canal] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CargarPrestamo]

-- %%
/****** Object:  Table [dbo].[CargarPrestamo]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CargarPrestamo](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Tema] [nvarchar](50) NULL,
 CONSTRAINT [PK_CargarPrestamo] PRIMARY KEY CLUSTERED 
(
	[Referencia] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cargos]

-- %%
/****** Object:  Table [dbo].[Cargos]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cargos](
	[iDCARGOS] [int] IDENTITY(1,1) NOT NULL,
	[cARGO] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Cargos] PRIMARY KEY CLUSTERED 
(
	[cARGO] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CargueInventarios]

-- %%
/****** Object:  Table [dbo].[CargueInventarios]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CargueInventarios](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Descripcion] [nvarchar](50) NULL,
	[Marca] [nvarchar](50) NULL,
	[Preciofinal] [int] NULL,
	[Tarifa] [float] NULL,
	[Cantidad] [float] NULL,
	[Costo] [float] NULL,
	[Peso] [float] NULL,
	[Us] [float] NULL,
	[Lista2] [int] NULL,
	[Lista3] [int] NULL,
 CONSTRAINT [PK_CargueInventarios] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CargueTerceros]

-- %%
/****** Object:  Table [dbo].[CargueTerceros]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CargueTerceros](
	[Idterceros] [int] IDENTITY(1,1) NOT NULL,
	[Tipoter] [nvarchar](50) NULL,
	[Identificacion] [nvarchar](50) NOT NULL,
	[DV] [nvarchar](50) NULL,
	[Nombre] [nvarchar](50) NULL,
	[Direccion] [nvarchar](250) NULL,
	[Telefono] [nvarchar](50) NULL,
	[Celular] [nvarchar](50) NULL,
	[Contacto] [nvarchar](50) NULL,
	[Email] [nvarchar](50) NULL,
 CONSTRAINT [PK_CargueTerceros] PRIMARY KEY CLUSTERED 
(
	[Identificacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CarteraInteractiva0]

-- %%
/****** Object:  Table [dbo].[CarteraInteractiva0]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CarteraInteractiva0](
	[Cliente] [nvarchar](50) NULL,
	[doc] [nvarchar](50) NOT NULL,
	[factura] [int] NOT NULL,
	[saldo] [int] NULL,
 CONSTRAINT [PK_CarteraInteractiva0] PRIMARY KEY CLUSTERED 
(
	[doc] ASC,
	[factura] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Categorías de activo]

-- %%
/****** Object:  Table [dbo].[Categorías de activo]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categorías de activo](
	[IdCategoríaActivo] [int] NOT NULL,
	[CategoríaActivo] [nvarchar](250) NOT NULL,
 CONSTRAINT [PK_Categorías de activo] PRIMARY KEY CLUSTERED 
(
	[CategoríaActivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Categoriaslicencias]

-- %%
/****** Object:  Table [dbo].[Categoriaslicencias]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categoriaslicencias](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Categoria] [nvarchar](50) NULL,
 CONSTRAINT [PK_Categoriaslicencias] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Causacion]

-- %%
/****** Object:  Table [dbo].[Causacion]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Causacion](
	[Idcausacion] [int] IDENTITY(1,1) NOT NULL,
	[Documento] [nvarchar](250) NOT NULL,
	[Comprobante] [int] NOT NULL,
	[Fecha] [smalldatetime] NOT NULL,
	[Concepto] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Niif] [nvarchar](50) NULL,
	[Local] [nvarchar](50) NULL,
	[Cierre] [nvarchar](50) NULL,
 CONSTRAINT [PK_Causacion] PRIMARY KEY CLUSTERED 
(
	[Documento] ASC,
	[Comprobante] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CCF]

-- %%
/****** Object:  Table [dbo].[CCF]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CCF](
	[Idcaja] [int] IDENTITY(1,1) NOT NULL,
	[Caja] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Tercero] [nvarchar](50) NULL,
	[ICBF] [nvarchar](50) NULL,
	[Sena] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_CCF] PRIMARY KEY CLUSTERED 
(
	[Caja] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Centros]

-- %%
/****** Object:  Table [dbo].[Centros]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Centros](
	[Idcentros] [int] IDENTITY(1,1) NOT NULL,
	[Centro] [nvarchar](250) NOT NULL,
	[Significado] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Situacion] [nvarchar](50) NULL,
 CONSTRAINT [PK_Centros] PRIMARY KEY CLUSTERED 
(
	[Centro] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Centrosop]

-- %%
/****** Object:  Table [dbo].[Centrosop]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Centrosop](
	[Idcentros] [int] IDENTITY(1,1) NOT NULL,
	[Centroop] [nvarchar](250) NOT NULL,
	[Significado] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Centrosop] PRIMARY KEY CLUSTERED 
(
	[Centroop] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CentrosSucursales]

-- %%
/****** Object:  Table [dbo].[CentrosSucursales]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CentrosSucursales](
	[Idcentros] [int] IDENTITY(1,1) NOT NULL,
	[Centro] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Situacion] [nvarchar](50) NULL,
 CONSTRAINT [PK_CentrosSucursales] PRIMARY KEY CLUSTERED 
(
	[Centro] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Certificados]

-- %%
/****** Object:  Table [dbo].[Certificados]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Certificados](
	[IdCertificado] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Codigo] [nvarchar](50) NULL,
	[Año] [int] NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Certificados] PRIMARY KEY CLUSTERED 
(
	[IdCertificado] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Certiretencion]

-- %%
/****** Object:  Table [dbo].[Certiretencion]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Certiretencion](
	[Idcertificado] [float] NOT NULL,
	[Año] [float] NULL,
	[Retenidoa] [nvarchar](250) NULL,
	[Identificacion] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[Base] [float] NULL,
	[Retencion] [float] NULL,
	[Fecha] [smalldatetime] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Firma] [nvarchar](250) NULL,
	[Ciudad] [nvarchar](250) NULL,
 CONSTRAINT [PK_Certiretencion] PRIMARY KEY CLUSTERED 
(
	[Idcertificado] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Chequesrecibidos]

-- %%
/****** Object:  Table [dbo].[Chequesrecibidos]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Chequesrecibidos](
	[IdCheques] [int] IDENTITY(1,1) NOT NULL,
	[IdCaja] [int] NOT NULL,
	[NCheque] [int] NULL,
	[Banco] [nvarchar](250) NULL,
	[Girado] [float] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Situacion] [nvarchar](250) NULL,
	[TipoMedio] [nvarchar](250) NULL,
 CONSTRAINT [PK_Chequesrecibidos] PRIMARY KEY CLUSTERED 
(
	[IdCheques] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cieerrelcl]

-- %%
/****** Object:  Table [dbo].[Cieerrelcl]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cieerrelcl](
	[IdContenedor] [int] IDENTITY(1,1) NOT NULL,
	[BLNo] [nvarchar](250) NULL,
	[Contenedor] [nvarchar](250) NULL,
	[Patio] [nvarchar](250) NULL,
	[Tercero] [nvarchar](250) NULL,
	[FAtraque] [smalldatetime] NULL,
	[Flibredo] [smalldatetime] NULL,
	[Fvaciado] [smalldatetime] NULL,
	[CdgActivi] [nvarchar](250) NULL,
	[estado] [int] NULL,
 CONSTRAINT [PK_Cieerrelcl] PRIMARY KEY CLUSTERED 
(
	[IdContenedor] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cierrecontrato]

-- %%
/****** Object:  Table [dbo].[Cierrecontrato]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cierrecontrato](
	[Consecutivo] [int] NOT NULL,
	[ContratoNo] [int] NULL,
	[BLNo] [nvarchar](250) NULL,
	[Contenedor] [nvarchar](250) NULL,
	[Patio] [nvarchar](250) NULL,
	[Tercero] [nvarchar](250) NULL,
	[FAtraque] [smalldatetime] NULL,
	[FConfirmacion] [smalldatetime] NULL,
	[FEntrada] [smalldatetime] NULL,
	[estado] [int] NULL,
	[CdgActivi] [nvarchar](250) NULL,
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
 CONSTRAINT [PK_Cierrecontrato] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cierrecontratosub]

-- %%
/****** Object:  Table [dbo].[Cierrecontratosub]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cierrecontratosub](
	[idCierre] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NULL,
	[grupestado] [nvarchar](250) NULL,
	[tipodan] [nvarchar](250) NULL,
	[Cantidad] [float] NULL,
	[Valorpatio] [float] NULL,
	[ValorAgencia] [float] NULL,
	[Cargo] [nvarchar](50) NULL,
 CONSTRAINT [PK_Cierrecontratosub] PRIMARY KEY CLUSTERED 
(
	[idCierre] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cierredo]

-- %%
/****** Object:  Table [dbo].[Cierredo]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cierredo](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Ctado] [nvarchar](50) NULL,
	[CtaUtilidad] [nvarchar](50) NULL,
	[CtaIva] [nvarchar](50) NULL,
	[Tarifaiva] [float] NULL,
	[Ctaperdida] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Idcausacion] [int] NULL,
	[Estado] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[CD] [int] NULL,
	[Tarifacree] [float] NULL,
	[Ctadebitocree] [nvarchar](50) NULL,
	[Ctacreditocree] [nvarchar](50) NULL,
 CONSTRAINT [PK_Cierredo] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cierredosub]

-- %%
/****** Object:  Table [dbo].[Cierredosub]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cierredosub](
	[idcierredosub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[DO] [int] NOT NULL,
	[Saldodebito] [int] NULL,
	[Saldocredito] [int] NULL,
 CONSTRAINT [PK_Cierredosub] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC,
	[DO] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cierrelclsub]

-- %%
/****** Object:  Table [dbo].[Cierrelclsub]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cierrelclsub](
	[idCierre] [int] IDENTITY(1,1) NOT NULL,
	[IdContenedor] [int] NULL,
	[grupestado] [nvarchar](50) NULL,
	[tipodan] [nvarchar](50) NULL,
	[Cantidad] [float] NULL,
	[Valorpatio] [float] NULL,
	[ValorAgencia] [float] NULL,
	[Cargo] [nvarchar](50) NULL,
 CONSTRAINT [PK_Cierrelclsub] PRIMARY KEY CLUSTERED 
(
	[idCierre] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cierrelinea]

-- %%
/****** Object:  Table [dbo].[Cierrelinea]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cierrelinea](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[idcierre] [int] NOT NULL,
	[Fcierre] [smalldatetime] NULL,
	[Linea] [nvarchar](250) NULL,
	[Tipocierre] [nvarchar](250) NULL,
 CONSTRAINT [PK_Cierrelinea] PRIMARY KEY CLUSTERED 
(
	[idcierre] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cierrelineasub]

-- %%
/****** Object:  Table [dbo].[Cierrelineasub]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cierrelineasub](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[idcierre] [int] NULL,
	[Frecibo] [smalldatetime] NULL,
	[Referencia] [nvarchar](250) NULL,
	[CentroCostos] [nvarchar](250) NULL,
	[Factura] [int] NULL,
	[BLNo] [nvarchar](250) NULL,
	[Contenedor] [nvarchar](250) NULL,
	[USFaturado] [float] NULL,
	[UScredi] [float] NULL,
	[Netocol] [float] NULL,
	[Estadocr] [nvarchar](50) NULL,
	[TipoCierr] [nvarchar](250) NULL,
 CONSTRAINT [PK_Cierrelineasub] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Clases]

-- %%
/****** Object:  Table [dbo].[Clases]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Clases](
	[IdClase] [int] IDENTITY(1,1) NOT NULL,
	[Clase] [nvarchar](250) NOT NULL,
	[Significado] [nvarchar](250) NULL,
	[Letra] [nvarchar](250) NULL,
	[Mpio] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Clases] PRIMARY KEY CLUSTERED 
(
	[Clase] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Coberturas]

-- %%
/****** Object:  Table [dbo].[Coberturas]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Coberturas](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Documento] [nvarchar](50) NULL,
	[DocNo] [int] NOT NULL,
	[Referencia] [nvarchar](50) NULL,
	[Cobertura] [nvarchar](50) NULL,
	[Finicial] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
	[VAsegurado] [int] NULL,
	[Vigencia] [int] NULL,
	[Prima] [int] NULL,
	[Tasa] [float] NULL,
	[Proveedor] [nvarchar](50) NULL,
 CONSTRAINT [PK_Coberturas] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cobranza]

-- %%
/****** Object:  Table [dbo].[Cobranza]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cobranza](
	[Idseguimiento] [int] IDENTITY(1,1) NOT NULL,
	[Cliente] [nvarchar](50) NULL,
	[Fecha] [smalldatetime] NULL,
	[Resultado] [ntext] NULL,
	[Contacto] [nvarchar](50) NULL,
	[FNueva] [smalldatetime] NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Cobranza] PRIMARY KEY CLUSTERED 
(
	[Idseguimiento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cobrodaños]

-- %%
/****** Object:  Table [dbo].[Cobrodaños]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cobrodaños](
	[IdCargodaño] [int] IDENTITY(1,1) NOT NULL,
	[codigocargo] [nvarchar](250) NULL,
	[Nombrecargo] [nvarchar](250) NULL,
 CONSTRAINT [PK_Cobrodaños] PRIMARY KEY CLUSTERED 
(
	[IdCargodaño] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Codigos]

-- %%
/****** Object:  Table [dbo].[Codigos]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Codigos](
	[IdCodigo] [int] IDENTITY(1,1) NOT NULL,
	[Municipio] [nvarchar](250) NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Depto] [nvarchar](50) NULL,
	[Ica] [float] NULL,
	[Pais] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Parametro] [nvarchar](50) NULL,
	[CodDpto] [nvarchar](50) NULL,
 CONSTRAINT [PK_Codigos] PRIMARY KEY CLUSTERED 
(
	[Municipio] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CodigosCon]

-- %%
/****** Object:  Table [dbo].[CodigosCon]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CodigosCon](
	[IdCodigo] [int] IDENTITY(1,1) NOT NULL,
	[Municipio] [nvarchar](250) NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Depto] [nvarchar](50) NULL,
	[Ica] [float] NULL,
	[Pais] [nvarchar](50) NULL,
	[CodCiudad] [nvarchar](250) NULL,
	[CiudadInternal] [nvarchar](250) NULL,
	[CodPais] [nvarchar](250) NULL,
	[Patio] [nvarchar](250) NULL,
 CONSTRAINT [PK_CodigosCon] PRIMARY KEY CLUSTERED 
(
	[Municipio] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CodigosPostales]

-- %%
/****** Object:  Table [dbo].[CodigosPostales]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CodigosPostales](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[CodigoPostal] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_CodigosPostales] PRIMARY KEY CLUSTERED 
(
	[CodigoPostal] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CodigosTrans]

-- %%
/****** Object:  Table [dbo].[CodigosTrans]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CodigosTrans](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Municipio] [nvarchar](50) NULL,
	[Poblacion] [nvarchar](50) NULL,
	[Departamento] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_CodigosTrans] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ComercioExterior]

-- %%
/****** Object:  Table [dbo].[ComercioExterior]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ComercioExterior](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[TipoOperacion] [nvarchar](50) NULL,
	[DONo] [int] NULL,
	[Deposito] [nvarchar](50) NULL,
	[Vendeposito] [smalldatetime] NULL,
	[Doctransporte] [nvarchar](50) NULL,
	[Freconocimiento] [smalldatetime] NULL,
	[Fsolanticipo] [smalldatetime] NULL,
	[Frecanticipo] [smalldatetime] NULL,
	[Fpago] [smalldatetime] NULL,
	[Flevante] [smalldatetime] NULL,
	[Ffinaliza] [smalldatetime] NULL,
	[Ffactura] [smalldatetime] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[SaeNo] [nvarchar](50) NULL,
	[Fsae] [smalldatetime] NULL,
	[DexNo] [nvarchar](50) NULL,
	[Fdex] [smalldatetime] NULL,
	[DtaNo] [nvarchar](50) NULL,
	[Fdta] [smalldatetime] NULL,
	[Estado] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Ptollegada] [nvarchar](50) NULL,
	[Fpoderes] [smalldatetime] NULL,
	[Fenviodoc] [smalldatetime] NULL,
	[Descripcion] [nvarchar](250) NULL,
	[Naviera] [nvarchar](50) NULL,
	[FantSuper] [smalldatetime] NULL,
	[FenvioContinen] [smalldatetime] NULL,
	[Flevantepto] [smalldatetime] NULL,
	[Fcargue] [smalldatetime] NULL,
	[FacSuper] [nvarchar](50) NULL,
	[FacturaNo] [int] NULL,
	[Selectividad] [nvarchar](50) NULL,
	[Fentrega] [smalldatetime] NULL,
	[Fprorroga] [smalldatetime] NULL,
 CONSTRAINT [PK_ComercioExterior] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Comisiones]

-- %%
/****** Object:  Table [dbo].[Comisiones]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Comisiones](
	[IdComisiones] [int] IDENTITY(1,1) NOT NULL,
	[Dias] [int] NOT NULL,
	[Comision] [float] NULL,
 CONSTRAINT [PK_Comisiones] PRIMARY KEY CLUSTERED 
(
	[Dias] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Comparativopar]

-- %%
/****** Object:  Table [dbo].[Comparativopar]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Comparativopar](
	[idpar] [int] IDENTITY(1,1) NOT NULL,
	[NúmCuenta] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Comparativopar] PRIMARY KEY CLUSTERED 
(
	[NúmCuenta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Comparendos]

-- %%
/****** Object:  Table [dbo].[Comparendos]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Comparendos](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Cedula] [nvarchar](50) NULL,
	[Placa] [nvarchar](50) NULL,
	[ComparendoNo] [int] NULL,
	[Fecha] [smalldatetime] NULL,
	[Neto] [int] NULL,
	[Notas] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Comparendos] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Composicion]

-- %%
/****** Object:  Table [dbo].[Composicion]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Composicion](
	[Composicion] [int] NOT NULL,
	[Referencia] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[PAjuste] [float] NULL,
	[Ajuste] [int] NULL,
	[CostoTotal] [int] NULL,
	[Fecha] [smalldatetime] NULL,
	[PPrecio] [float] NULL,
	[PFinal] [int] NULL,
	[Piva] [float] NULL,
	[Iva] [int] NULL,
	[TotalPV] [int] NULL,
	[Final] [int] NULL,
	[Base] [float] NULL,
	[Porcentaje] [float] NULL,
	[Elaboro] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Composicion] PRIMARY KEY CLUSTERED 
(
	[Composicion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Composicionsub]

-- %%
/****** Object:  Table [dbo].[Composicionsub]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Composicionsub](
	[Idcomposicionsub] [int] IDENTITY(1,1) NOT NULL,
	[Composicion] [int] NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Insumo] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
	[Unitario] [float] NULL,
	[Total] [int] NULL,
	[Peso] [float] NULL,
	[UnidadActual] [nvarchar](250) NULL,
	[Convertir] [nvarchar](250) NULL,
	[Neto] [float] NULL,
	[Convertidor] [float] NULL,
	[Subtotal] [int] NULL,
 CONSTRAINT [PK_Composicionsub] PRIMARY KEY CLUSTERED 
(
	[Idcomposicionsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Compras]

-- %%
/****** Object:  Table [dbo].[Compras]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Compras](
	[Prefijo] [nvarchar](50) NOT NULL,
	[Nofacturap] [int] NOT NULL,
	[Proveedor] [nvarchar](250) NOT NULL,
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Estado] [int] NULL,
	[IdEntradas] [int] NOT NULL,
	[Tipo] [nvarchar](50) NULL,
	[Fecha] [smalldatetime] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Ordencompra] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[Abono] [int] NULL,
	[Saldo] [int] NULL,
	[Dias] [int] NULL,
	[Fletes] [int] NULL,
	[Financiacion] [int] NULL,
	[Fproceso] [smalldatetime] NULL,
	[PRetencion] [float] NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[TRM] [float] NULL,
	[PReteIva] [float] NULL,
	[Descarga] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[Diferencia] [int] NULL,
	[IvaServ] [int] NULL,
	[Seguros] [int] NULL,
	[Nacionalizacion] [int] NULL,
	[Prorratear] [int] NULL,
	[CostoUnitario] [float] NULL,
	[Pincremento] [float] NULL,
	[Rete] [int] NULL,
	[Anticipo] [int] NULL,
	[Aranus] [float] NULL,
	[Ivaopus] [float] NULL,
	[Ivaserus] [float] NULL,
	[Nalus] [float] NULL,
	[Reteus] [float] NULL,
	[Estado2] [int] NULL,
	[Retencion] [nvarchar](50) NULL,
	[Us] [float] NULL,
	[Situacion] [nvarchar](50) NULL,
	[Control2] [int] NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[BL] [nvarchar](50) NULL,
	[Importa] [int] NULL,
 CONSTRAINT [PK_Compras_1] PRIMARY KEY CLUSTERED 
(
	[Nofacturap] ASC,
	[Proveedor] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ComprasFletes]

-- %%
/****** Object:  Table [dbo].[ComprasFletes]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ComprasFletes](
	[Idimporta] [int] IDENTITY(1,1) NOT NULL,
	[Id] [int] NOT NULL,
	[Concepto] [nvarchar](250) NULL,
	[Neto] [int] NULL,
	[Us] [float] NULL,
 CONSTRAINT [PK_ComprasFletes] PRIMARY KEY CLUSTERED 
(
	[Idimporta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ComprasNacionaliza]

-- %%
/****** Object:  Table [dbo].[ComprasNacionaliza]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ComprasNacionaliza](
	[Idimporta] [int] IDENTITY(1,1) NOT NULL,
	[Id] [int] NOT NULL,
	[Concepto] [nvarchar](250) NULL,
	[Neto] [int] NULL,
	[Us] [float] NULL,
	[CompraNo] [int] NULL,
 CONSTRAINT [PK_ComprasNacionaliza] PRIMARY KEY CLUSTERED 
(
	[Idimporta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ComprasSeguros]

-- %%
/****** Object:  Table [dbo].[ComprasSeguros]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ComprasSeguros](
	[Idimporta] [int] IDENTITY(1,1) NOT NULL,
	[Id] [int] NOT NULL,
	[Concepto] [nvarchar](250) NULL,
	[Neto] [int] NULL,
	[Us] [float] NULL,
 CONSTRAINT [PK_ComprasSeguros] PRIMARY KEY CLUSTERED 
(
	[Idimporta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Comprasub]

-- %%
/****** Object:  Table [dbo].[Comprasub]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Comprasub](
	[idcomprassub] [int] IDENTITY(1,1) NOT NULL,
	[Prefijo] [nvarchar](50) NOT NULL,
	[Nofacturap] [int] NOT NULL,
	[Proveedor] [nvarchar](250) NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
	[Descuento] [float] NULL,
	[Precio] [float] NULL,
	[PIva] [float] NULL,
	[Precio total] [int] NULL,
	[Neto] [int] NULL,
	[Subtotal] [int] NULL,
	[Exentos] [int] NULL,
	[DesExentos] [int] NULL,
	[DesGravados] [int] NULL,
	[Dolares] [float] NULL,
	[PRete] [float] NULL,
	[Retencion] [int] NULL,
	[DO] [int] NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[Peso] [float] NULL,
	[Base] [int] NULL,
	[CUdol] [float] NULL,
	[Nal] [float] NULL,
	[CTU] [float] NULL,
	[PVF] [float] NULL,
	[Serial] [nvarchar](250) NULL,
	[PArancel] [float] NULL,
	[Arancel] [int] NULL,
	[Placa] [nvarchar](50) NULL,
	[VPropina] [int] NULL,
	[Cree] [int] NULL,
 CONSTRAINT [PK_Comprasub] PRIMARY KEY CLUSTERED 
(
	[idcomprassub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Comprobanteegreso]

-- %%
/****** Object:  Table [dbo].[Comprobanteegreso]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Comprobanteegreso](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Idegreso] [int] NOT NULL,
	[Estado] [int] NULL,
	[Tipo] [nvarchar](250) NULL,
	[Pagado a] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Ciudad] [nvarchar](250) NULL,
	[Letras] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[Forma de pago] [nvarchar](250) NULL,
	[Pagador] [nvarchar](250) NULL,
	[Aprobado] [nvarchar](250) NULL,
	[Document] [nvarchar](50) NULL,
	[Documento] [nvarchar](250) NULL,
	[PDesc] [float] NULL,
	[Descuento] [float] NULL,
	[PRetencion] [float] NULL,
	[Retefuente] [int] NULL,
	[Pagar] [float] NULL,
	[Netor] [float] NULL,
	[Ivar] [int] NULL,
	[Pivar] [float] NULL,
	[PReteIca] [float] NULL,
	[ReteIca] [int] NULL,
	[PReteIva] [float] NULL,
	[ReteIva] [int] NULL,
	[Adicion] [float] NULL,
	[Banco] [nvarchar](250) NULL,
	[Comprobante] [int] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Situacion] [nvarchar](50) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[DO] [int] NULL,
	[Girado] [nvarchar](50) NULL,
	[DifCambio] [int] NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Consecutivo] [int] NULL,
 CONSTRAINT [PK_Comprobanteegreso] PRIMARY KEY CLUSTERED 
(
	[Idegreso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Conactividades]

-- %%
/****** Object:  Table [dbo].[Conactividades]    Script Date: 12/12/2022 08:38:52 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Conactividades](
	[ID1] [int] IDENTITY(1,1) NOT NULL,
	[ID] [float] NULL,
	[Actividad] [nvarchar](250) NULL,
	[NomActividad] [nvarchar](250) NULL,
	[ModalBL] [nvarchar](250) NULL,
	[EstConte] [nvarchar](250) NULL,
	[Operación] [nvarchar](250) NULL,
	[gate] [nvarchar](250) NULL,
	[Orden] [float] NULL,
	[Inventario] [nvarchar](250) NULL,
 CONSTRAINT [PK_Conactividades] PRIMARY KEY CLUSTERED 
(
	[ID1] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Conalmagrario]

-- %%
/****** Object:  Table [dbo].[Conalmagrario]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Conalmagrario](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Contenedor] [nvarchar](250) NULL,
	[SrlPresupuesto] [float] NULL,
	[Tam] [float] NULL,
	[tipo] [nvarchar](250) NULL,
	[FEntrada] [smalldatetime] NULL,
	[Cliente] [nvarchar](250) NULL,
	[NomEstadoContenedor] [nvarchar](250) NULL,
	[CodDano] [nvarchar](250) NULL,
	[LocElemento] [nvarchar](250) NULL,
	[CodCorrectivo] [nvarchar](250) NULL,
	[CodElemento] [nvarchar](250) NULL,
	[Dimension1] [float] NULL,
	[Dimension2] [float] NULL,
	[HorHombre] [float] NULL,
	[VlrHorHombre] [float] NULL,
	[VlrMaterial] [float] NULL,
	[VlrIva] [float] NULL,
	[VlrTotal] [float] NULL,
	[Acargo] [nvarchar](250) NULL,
	[NomSucursal] [nvarchar](250) NULL,
 CONSTRAINT [PK_Conalmagrario] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConBL]

-- %%
/****** Object:  Table [dbo].[ConBL]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConBL](
	[IdBL] [int] IDENTITY(1,1) NOT NULL,
	[Recalada] [int] NULL,
	[BLNo] [nvarchar](200) NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Trafico] [nvarchar](250) NULL,
	[TFlete] [nvarchar](250) NULL,
	[TImportacion] [nvarchar](250) NULL,
	[Shipper] [nvarchar](250) NULL,
	[Consignatario] [nvarchar](250) NULL,
	[Notify] [nvarchar](250) NULL,
	[Puerto] [nvarchar](250) NULL,
	[Origen] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Documento] [nvarchar](250) NULL,
	[BookingNo] [int] NULL,
	[Arribo] [nvarchar](250) NULL,
	[Clientefinal] [nvarchar](250) NULL,
 CONSTRAINT [PK_ConBL] PRIMARY KEY CLUSTERED 
(
	[BLNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConbokingFte]

-- %%
/****** Object:  Table [dbo].[ConbokingFte]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConbokingFte](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Boking] [int] NULL,
	[Concepto] [nvarchar](250) NULL,
	[Usd] [int] NULL,
 CONSTRAINT [PK_ConbokingFte] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Conboocntr]

-- %%
/****** Object:  Table [dbo].[Conboocntr]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Conboocntr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Boking] [int] NULL,
	[Tipo] [nvarchar](250) NULL,
	[Tamaño] [int] NULL,
	[Cantidad] [int] NULL,
 CONSTRAINT [PK_Conboocntr] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Conbooking]

-- %%
/****** Object:  Table [dbo].[Conbooking]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Conbooking](
	[Idbook] [int] IDENTITY(1,1) NOT NULL,
	[CentroOp] [nvarchar](250) NULL,
	[Booking] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Exportador] [nvarchar](250) NULL,
	[PtoOrigen] [nvarchar](250) NULL,
	[PtoDestino] [nvarchar](250) NULL,
	[Motonave] [nvarchar](250) NULL,
	[Viaje] [nvarchar](250) NULL,
	[Patio] [nvarchar](250) NULL,
	[Cantidad] [nvarchar](250) NULL,
	[Tamaño] [nvarchar](250) NULL,
	[EstadoContene] [nvarchar](250) NULL,
	[Tipocarga] [nvarchar](250) NULL,
	[estado] [int] NULL,
	[Vendedor] [nvarchar](250) NULL,
	[Tflete] [nvarchar](250) NULL,
	[Consignatario] [nvarchar](250) NULL,
	[Emisionbl] [nvarchar](250) NULL,
	[facturacion] [nvarchar](250) NULL,
	[modalcntr] [nvarchar](250) NULL,
	[contacto] [nvarchar](250) NULL,
 CONSTRAINT [PK_Conbooking] PRIMARY KEY CLUSTERED 
(
	[Booking] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Concarguecierre]

-- %%
/****** Object:  Table [dbo].[Concarguecierre]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Concarguecierre](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[idcierre] [int] NULL,
	[Frecibo] [smalldatetime] NULL,
	[Referencia] [nvarchar](250) NULL,
	[CentroCostos] [nvarchar](250) NULL,
	[Factura] [int] NULL,
	[BLNo] [nvarchar](250) NULL,
	[Contenedor] [nvarchar](250) NULL,
	[USFaturado] [float] NULL,
	[UScredi] [float] NULL,
	[Netocol] [float] NULL,
	[Estadocr] [nvarchar](250) NULL,
	[TipoCierr] [nvarchar](250) NULL,
 CONSTRAINT [PK_Concarguecierre] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Conceptosegresos]

-- %%
/****** Object:  Table [dbo].[Conceptosegresos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Conceptosegresos](
	[Idconceptos] [int] IDENTITY(1,1) NOT NULL,
	[Concepto] [nvarchar](250) NOT NULL,
 CONSTRAINT [PK_Conceptosegresos] PRIMARY KEY CLUSTERED 
(
	[Concepto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConceptosMedios]

-- %%
/****** Object:  Table [dbo].[ConceptosMedios]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConceptosMedios](
	[IdConceptos] [int] IDENTITY(1,1) NOT NULL,
	[IdEgreso] [int] NOT NULL,
	[Concepto] [nvarchar](250) NULL,
	[Neto] [int] NULL,
	[Documento] [nvarchar](50) NULL,
 CONSTRAINT [PK_ConceptosMedios] PRIMARY KEY CLUSTERED 
(
	[IdConceptos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConceptosMediosVir]

-- %%
/****** Object:  Table [dbo].[ConceptosMediosVir]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConceptosMediosVir](
	[IdConceptos] [int] IDENTITY(1,1) NOT NULL,
	[IdEgreso] [int] NOT NULL,
	[Concepto] [nvarchar](250) NULL,
	[Neto] [int] NULL,
	[Documento] [nvarchar](50) NULL,
 CONSTRAINT [PK_ConceptosMediosVir] PRIMARY KEY CLUSTERED 
(
	[IdConceptos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConciliaBancaria]

-- %%
/****** Object:  Table [dbo].[ConciliaBancaria]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConciliaBancaria](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Finicial] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Idcausacion] [int] NULL,
	[Estado] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[CD] [int] NULL,
 CONSTRAINT [PK_ConciliaBancaria] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConciliaBancariapar]

-- %%
/****** Object:  Table [dbo].[ConciliaBancariapar]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConciliaBancariapar](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Concepto] [nvarchar](5) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_ConciliaBancariapar] PRIMARY KEY CLUSTERED 
(
	[Concepto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Conciliadorpar]

-- %%
/****** Object:  Table [dbo].[Conciliadorpar]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Conciliadorpar](
	[idpar] [int] IDENTITY(1,1) NOT NULL,
	[Tema] [nvarchar](50) NOT NULL,
	[Cuenta] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Conciliadorpar] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC,
	[Cuenta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConContenedor]

-- %%
/****** Object:  Table [dbo].[ConContenedor]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConContenedor](
	[IdContenedor] [int] IDENTITY(1,1) NOT NULL,
	[Recalada] [int] NULL,
	[BLNo] [nvarchar](200) NOT NULL,
	[Contenedor] [nvarchar](200) NOT NULL,
	[Tonelada] [float] NULL,
	[Tipocarga] [nvarchar](250) NULL,
	[Metros] [int] NULL,
 CONSTRAINT [PK_ConContenedor] PRIMARY KEY CLUSTERED 
(
	[BLNo] ASC,
	[Contenedor] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConContenedorTipo]

-- %%
/****** Object:  Table [dbo].[ConContenedorTipo]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConContenedorTipo](
	[IdContenedorTipo] [int] IDENTITY(1,1) NOT NULL,
	[ContenedorNo] [nvarchar](50) NOT NULL,
	[Tipo] [nvarchar](50) NULL,
	[Notas] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_ConContenedorTipo] PRIMARY KEY CLUSTERED 
(
	[ContenedorNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Concorrectivo]

-- %%
/****** Object:  Table [dbo].[Concorrectivo]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Concorrectivo](
	[Codigo] [nvarchar](250) NULL,
	[Nomreparar] [nvarchar](250) NULL,
	[Descripcion] [nvarchar](250) NULL,
	[DescripcionIngles] [nvarchar](250) NULL,
	[ID] [int] IDENTITY(1,1) NOT NULL,
 CONSTRAINT [PK_Concorrectivo] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Conductores]

-- %%
/****** Object:  Table [dbo].[Conductores]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Conductores](
	[idConductor] [int] IDENTITY(1,1) NOT NULL,
	[Cedula] [nvarchar](50) NOT NULL,
	[Expedicion] [nvarchar](250) NULL,
	[Nombre] [nvarchar](250) NULL,
	[Direccion] [nvarchar](250) NULL,
	[Telefono] [nvarchar](250) NULL,
	[Ciudad] [nvarchar](250) NULL,
	[Licencia] [nvarchar](250) NULL,
	[Categoria] [nvarchar](50) NULL,
	[Celular] [nvarchar](250) NULL,
	[RH] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Vencimiento] [smalldatetime] NULL,
	[ExpLicencia] [nvarchar](250) NULL,
	[Clase] [nvarchar](250) NULL,
	[RutaFoto] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Apellido1] [nvarchar](50) NULL,
	[Apellido2] [nvarchar](50) NULL,
	[Nombre1] [nvarchar](50) NULL,
	[Nombre2] [nvarchar](50) NULL,
	[EPS] [nvarchar](50) NULL,
	[ARP] [nvarchar](50) NULL,
	[Pension] [nvarchar](250) NULL,
	[PasadoJudicial] [nvarchar](50) NULL,
	[VenPJ] [smalldatetime] NULL,
	[Referencia1] [nvarchar](250) NULL,
	[Telref1] [nvarchar](50) NULL,
	[Referencia2] [nvarchar](250) NULL,
	[Telref2] [nvarchar](50) NULL,
	[Referencia3] [nvarchar](250) NULL,
	[Telref3] [nvarchar](50) NULL,
	[Situacion] [nvarchar](50) NULL,
	[DV] [nvarchar](50) NULL,
	[Vinculacion] [smalldatetime] NULL,
	[Ciudadfin] [nvarchar](50) NULL,
	[Email] [nvarchar](250) NULL,
 CONSTRAINT [PK_Conductores] PRIMARY KEY CLUSTERED 
(
	[Cedula] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConductorPendientes]

-- %%
/****** Object:  Table [dbo].[ConductorPendientes]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConductorPendientes](
	[IdDocumental] [int] IDENTITY(1,1) NOT NULL,
	[Cedula] [nvarchar](50) NOT NULL,
	[Tipo] [nvarchar](250) NULL,
	[Situacion] [nvarchar](250) NULL,
	[Notas] [nvarchar](250) NULL,
	[RutaFoto] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Estado] [int] NULL,
	[Gestor] [nvarchar](50) NULL,
 CONSTRAINT [PK_ConductorPendientes] PRIMARY KEY CLUSTERED 
(
	[IdDocumental] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Conestados]

-- %%
/****** Object:  Table [dbo].[Conestados]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Conestados](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[estado] [int] NULL,
	[tipoestado] [nvarchar](250) NULL,
	[Tipo esta] [nvarchar](250) NULL,
 CONSTRAINT [PK_Conestados] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConFletes]

-- %%
/****** Object:  Table [dbo].[ConFletes]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConFletes](
	[IdFletes] [int] IDENTITY(1,1) NOT NULL,
	[Recalada] [int] NULL,
	[BLNo] [nvarchar](200) NOT NULL,
	[Concepto] [nvarchar](200) NOT NULL,
	[US] [float] NULL,
 CONSTRAINT [PK_ConFletes] PRIMARY KEY CLUSTERED 
(
	[BLNo] ASC,
	[Concepto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[congrupdaño]

-- %%
/****** Object:  Table [dbo].[congrupdaño]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[congrupdaño](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[grupda] [nvarchar](250) NULL,
	[nombre] [nvarchar](250) NULL,
 CONSTRAINT [PK_congrupdaño] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Conguiasrepar]

-- %%
/****** Object:  Table [dbo].[Conguiasrepar]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Conguiasrepar](
	[Idguia] [int] IDENTITY(1,1) NOT NULL,
	[Numguia] [int] NULL,
	[Contenedor] [nvarchar](250) NOT NULL,
	[FEntrada] [smalldatetime] NOT NULL,
	[Tam] [float] NULL,
	[tipo] [nvarchar](250) NULL,
	[NomSucursal] [nvarchar](250) NULL,
	[Autorizado] [nvarchar](250) NULL,
	[Fechaautorizado] [smalldatetime] NULL,
	[Notas] [nvarchar](250) NULL,
 CONSTRAINT [PK_Conguiasrepar] PRIMARY KEY CLUSTERED 
(
	[Contenedor] ASC,
	[FEntrada] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Conguiasreparsub]

-- %%
/****** Object:  Table [dbo].[Conguiasreparsub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Conguiasreparsub](
	[Idguiasub] [int] IDENTITY(1,1) NOT NULL,
	[numguia] [int] NULL,
	[Contenedor] [nvarchar](250) NULL,
	[FEntrada] [smalldatetime] NULL,
	[SrlPresupuesto] [float] NULL,
	[Tam] [float] NULL,
	[tipo] [nvarchar](250) NULL,
	[Cliente] [nvarchar](250) NULL,
	[NomEstadoContenedor] [nvarchar](250) NULL,
	[CodDano] [nvarchar](250) NULL,
	[LocElemento] [nvarchar](250) NULL,
	[CodCorrectivo] [nvarchar](250) NULL,
	[CodElemento] [nvarchar](250) NULL,
	[Dimension1] [float] NULL,
	[Dimension2] [float] NULL,
	[HorHombre] [float] NULL,
	[VlrHorHombre] [float] NULL,
	[VlrMaterial] [float] NULL,
	[VlrIva] [float] NULL,
	[VlrTotal] [float] NULL,
	[Acargo] [nvarchar](250) NULL,
	[NomSucursal] [nvarchar](250) NULL,
 CONSTRAINT [PK_Conguiasreparsub] PRIMARY KEY CLUSTERED 
(
	[Idguiasub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Coningresoexp]

-- %%
/****** Object:  Table [dbo].[Coningresoexp]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Coningresoexp](
	[IdContenedor] [int] IDENTITY(1,1) NOT NULL,
	[Ordensalida] [int] NULL,
	[Contenedor] [nvarchar](250) NULL,
	[PatioIngreso] [nvarchar](250) NULL,
	[FEntrada] [smalldatetime] NULL,
	[Estadoingreso] [nvarchar](250) NULL,
	[CdgActivi] [nvarchar](250) NULL,
	[estado] [int] NULL,
 CONSTRAINT [PK_Coningresoexp] PRIMARY KEY CLUSTERED 
(
	[IdContenedor] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConMotonaves]

-- %%
/****** Object:  Table [dbo].[ConMotonaves]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConMotonaves](
	[IdMotonave] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](250) NOT NULL,
	[Motonave] [nvarchar](50) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Identificacion] [nvarchar](250) NULL,
 CONSTRAINT [PK_ConMotonaves] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Connompatios]

-- %%
/****** Object:  Table [dbo].[Connompatios]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Connompatios](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ingreso] [nvarchar](250) NULL,
	[Codigo] [nvarchar](250) NULL,
 CONSTRAINT [PK_Connompatios] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConRecalada]

-- %%
/****** Object:  Table [dbo].[ConRecalada]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConRecalada](
	[IdRecalada] [int] IDENTITY(1,1) NOT NULL,
	[RecaladaNo] [int] NOT NULL,
	[Motonave] [nvarchar](250) NULL,
	[Viaje] [nvarchar](250) NULL,
	[Rumbo] [nvarchar](250) NULL,
	[Puerto] [nvarchar](250) NULL,
	[Linea] [nvarchar](250) NULL,
	[Farribo] [smalldatetime] NULL,
	[Harribo] [nvarchar](50) NULL,
	[FAtraque] [smalldatetime] NULL,
	[Hatraque] [nvarchar](50) NULL,
	[FZarpe] [smalldatetime] NULL,
	[Hzarpe] [nvarchar](50) NULL,
	[RegistroCapitania] [nvarchar](250) NULL,
	[RegistroAduana] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Origen] [nvarchar](250) NULL,
	[Destino] [nvarchar](250) NULL,
 CONSTRAINT [PK_ConRecalada] PRIMARY KEY CLUSTERED 
(
	[RecaladaNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConSalidapatio]

-- %%
/****** Object:  Table [dbo].[ConSalidapatio]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConSalidapatio](
	[IdContenedor] [int] IDENTITY(1,1) NOT NULL,
	[Ordensalida] [int] NULL,
	[Tercero] [nvarchar](250) NULL,
	[Contenedor] [nvarchar](250) NULL,
	[PatioOrigen] [nvarchar](250) NULL,
	[PatioDestino] [nvarchar](250) NULL,
	[FEntrada] [smalldatetime] NULL,
	[FReserva] [smalldatetime] NULL,
	[FSalida] [smalldatetime] NULL,
	[Estadosalida] [nvarchar](250) NULL,
	[CdgActivi] [nvarchar](50) NULL,
	[estado] [int] NULL,
 CONSTRAINT [PK_ConSalidapatio] PRIMARY KEY CLUSTERED 
(
	[IdContenedor] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConsultaCostos]

-- %%
/****** Object:  Table [dbo].[ConsultaCostos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConsultaCostos](
	[idcomprassub] [int] IDENTITY(1,1) NOT NULL,
	[Nofacturap] [int] NULL,
	[Proveedor] [nvarchar](250) NULL,
	[Identradas] [int] NULL,
	[Referencia] [nvarchar](250) NULL,
	[Cantidad] [float] NULL,
	[Descuento] [float] NULL,
	[Precio] [float] NULL,
	[PIva] [float] NULL,
	[Precio total] [int] NULL,
	[Neto] [int] NULL,
	[Subtotal] [int] NULL,
 CONSTRAINT [PK_ConsultaCostos] PRIMARY KEY CLUSTERED 
(
	[idcomprassub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Contactos]

-- %%
/****** Object:  Table [dbo].[Contactos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Contactos](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Identificacion] [nvarchar](50) NOT NULL,
	[Contacto] [nvarchar](50) NOT NULL,
	[Telefono] [nvarchar](50) NULL,
	[Ciudad] [nvarchar](50) NULL,
	[Dependencia] [nvarchar](50) NULL,
	[Email] [nvarchar](250) NULL,
	[Notas] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Contactos] PRIMARY KEY CLUSTERED 
(
	[Identificacion] ASC,
	[Contacto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConTarifasdemoras]

-- %%
/****** Object:  Table [dbo].[ConTarifasdemoras]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConTarifasdemoras](
	[ldmtam] [int] NOT NULL,
	[ltip] [nvarchar](50) NOT NULL,
	[Tarifa1] [int] NULL,
	[Desde1] [nvarchar](250) NULL,
	[Tarifa2] [int] NULL,
	[Desde2] [nvarchar](250) NULL,
	[lfevi] [smalldatetime] NULL,
	[tipocont] [nvarchar](50) NULL,
	[control] [int] IDENTITY(1,1) NOT NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_ConTarifasdemoras] PRIMARY KEY CLUSTERED 
(
	[ldmtam] ASC,
	[ltip] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ContenedorPendientes]

-- %%
/****** Object:  Table [dbo].[ContenedorPendientes]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ContenedorPendientes](
	[IdContenedorpendientes] [int] IDENTITY(1,1) NOT NULL,
	[Remesa] [int] NOT NULL,
	[Tipo] [nvarchar](250) NULL,
	[Situacion] [nvarchar](250) NULL,
	[Notas] [nvarchar](250) NULL,
 CONSTRAINT [PK_ContenedorPendientes] PRIMARY KEY CLUSTERED 
(
	[IdContenedorpendientes] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Contipocierre]

-- %%
/****** Object:  Table [dbo].[Contipocierre]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Contipocierre](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Tipocierre] [nvarchar](250) NULL,
 CONSTRAINT [PK_Contipocierre] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConTipoCon]

-- %%
/****** Object:  Table [dbo].[ConTipoCon]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConTipoCon](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[tipcon] [nvarchar](250) NOT NULL,
	[tamcon] [int] NOT NULL,
	[matcon] [nvarchar](250) NULL,
	[tarcon] [nvarchar](250) NULL,
	[anccon] [int] NULL,
	[larcon] [int] NULL,
	[capcon] [int] NULL,
	[altcon] [int] NULL,
	[volcon] [int] NULL,
	[fchfab] [nvarchar](250) NULL,
	[nomtip] [nvarchar](250) NULL,
	[iso] [int] NULL,
 CONSTRAINT [PK_ConTipoCon] PRIMARY KEY CLUSTERED 
(
	[tipcon] ASC,
	[tamcon] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConTipoConcepto]

-- %%
/****** Object:  Table [dbo].[ConTipoConcepto]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConTipoConcepto](
	[IdTipo] [int] IDENTITY(1,1) NOT NULL,
	[TipoConcepto] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Cuenta] [nvarchar](250) NULL,
 CONSTRAINT [PK_ConTipoConcepto] PRIMARY KEY CLUSTERED 
(
	[TipoConcepto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Contiposdañosinv]

-- %%
/****** Object:  Table [dbo].[Contiposdañosinv]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Contiposdañosinv](
	[Iddaños] [int] IDENTITY(1,1) NOT NULL,
	[grupestado] [nvarchar](250) NULL,
	[tipodan] [nvarchar](200) NOT NULL,
	[Nombredan] [nvarchar](200) NOT NULL,
	[Namedan] [nvarchar](250) NULL,
	[Dañoinventa] [nvarchar](250) NULL,
	[Notas] [nvarchar](250) NULL,
 CONSTRAINT [PK_Contiposdañosinv] PRIMARY KEY CLUSTERED 
(
	[tipodan] ASC,
	[Nombredan] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Contratos]

-- %%
/****** Object:  Table [dbo].[Contratos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Contratos](
	[IdContratos] [int] IDENTITY(1,1) NOT NULL,
	[ContratoNo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Dias] [int] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Tercero] [nvarchar](250) NULL,
	[Capital] [int] NULL,
	[Tasa] [float] NULL,
	[Meses] [int] NULL,
	[Intereses] [int] NULL,
	[Total] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Documento] [nvarchar](50) NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[PReteica] [float] NULL,
	[ReteIca] [int] NULL,
	[PRetencion] [float] NULL,
	[Retencion] [int] NULL,
	[Responsable] [nvarchar](50) NULL,
	[Terminal] [int] NULL,
	[Sia] [nvarchar](50) NULL,
	[Contenedor] [nvarchar](50) NULL,
	[BLNo] [nvarchar](50) NULL,
	[Sitiodev] [nvarchar](50) NULL,
	[Socport] [nvarchar](50) NULL,
	[Concepto] [nvarchar](50) NULL,
	[FConfirmacion] [smalldatetime] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Situacion] [nvarchar](50) NULL,
	[CentroOp] [nvarchar](50) NULL,
	[Finicio] [smalldatetime] NULL,
	[Hinicio] [datetime] NULL,
	[Ffin] [smalldatetime] NULL,
	[Hfin] [datetime] NULL,
	[Tipocontrato] [nvarchar](50) NULL,
	[Notas] [ntext] NULL,
	[Tiposervicio] [nvarchar](50) NULL,
 CONSTRAINT [PK_Contratos_1] PRIMARY KEY CLUSTERED 
(
	[ContratoNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ContratosArticulado]

-- %%
/****** Object:  Table [dbo].[ContratosArticulado]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ContratosArticulado](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Articulado] [ntext] NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_ContratosArticulado] PRIMARY KEY CLUSTERED 
(
	[idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Contratosub]

-- %%
/****** Object:  Table [dbo].[Contratosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Contratosub](
	[idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[ContratoNo] [int] NOT NULL,
	[OrigenDestino] [nvarchar](50) NULL,
	[Cantidad] [float] NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Pasajeros] [int] NULL,
	[Venta] [int] NULL,
	[Placa] [nvarchar](50) NULL,
	[Costo] [int] NULL,
 CONSTRAINT [PK_Contratosub] PRIMARY KEY CLUSTERED 
(
	[idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ControlMantenimiento]

-- %%
/****** Object:  Table [dbo].[ControlMantenimiento]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ControlMantenimiento](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Maquina] [nvarchar](250) NULL,
	[HorometroActual] [int] NULL,
 CONSTRAINT [PK_ControlMantenimiento] PRIMARY KEY CLUSTERED 
(
	[IdControl] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Conversiones]

-- %%
/****** Object:  Table [dbo].[Conversiones]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Conversiones](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Cliente] [nvarchar](50) NULL,
	[Correo] [nvarchar](50) NULL,
	[Celular] [nvarchar](50) NULL,
	[Canal] [nvarchar](50) NULL,
	[Notas] [ntext] NULL,
	[Status] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Conversiones] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Convertir]

-- %%
/****** Object:  Table [dbo].[Convertir]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Convertir](
	[IdConvertir] [int] IDENTITY(1,1) NOT NULL,
	[Actual] [nvarchar](50) NOT NULL,
	[Nueva] [nvarchar](50) NOT NULL,
	[Operacion] [int] NULL,
 CONSTRAINT [PK_Convertir] PRIMARY KEY CLUSTERED 
(
	[Actual] ASC,
	[Nueva] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Correos]

-- %%
/****** Object:  Table [dbo].[Correos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Correos](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Usuario] [nvarchar](50) NOT NULL,
	[Correo] [nvarchar](50) NULL,
	[Password] [nvarchar](50) NULL,
	[Nombre] [nvarchar](50) NULL,
	[Cargo1] [nvarchar](50) NULL,
	[Movil1] [nvarchar](50) NULL,
	[Fijo1] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Valpw] [nvarchar](50) NULL,
 CONSTRAINT [PK_Correos] PRIMARY KEY CLUSTERED 
(
	[Usuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CorreosDominio]

-- %%
/****** Object:  Table [dbo].[CorreosDominio]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CorreosDominio](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Dominio] [nvarchar](50) NULL,
	[Servidor] [nvarchar](50) NULL,
	[Puerto] [nvarchar](50) NULL,
	[Abs] [nvarchar](50) NULL,
	[Copia] [nvarchar](50) NULL,
	[Formato] [nvarchar](50) NULL,
	[PuertoCorreo] [nvarchar](50) NULL,
 CONSTRAINT [PK_CorreosDominio] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Costos]

-- %%
/****** Object:  Table [dbo].[Costos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Costos](
	[IdCosto] [int] NOT NULL,
	[Finicial] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
	[Documento] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Finicialcosteo] [smalldatetime] NULL,
	[Ffinalcosteo] [smalldatetime] NULL,
 CONSTRAINT [PK_Costos] PRIMARY KEY CLUSTERED 
(
	[IdCosto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CostosCIF]

-- %%
/****** Object:  Table [dbo].[CostosCIF]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CostosCIF](
	[IdCIF] [int] IDENTITY(1,1) NOT NULL,
	[Orden] [int] NOT NULL,
	[Finicial] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
	[Producidas] [float] NULL,
	[Prorratear] [float] NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_CostosCIF] PRIMARY KEY CLUSTERED 
(
	[Orden] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CostosCIF2]

-- %%
/****** Object:  Table [dbo].[CostosCIF2]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CostosCIF2](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Orden] [int] NULL,
	[Referencia] [nvarchar](250) NULL,
	[Neto] [int] NULL,
 CONSTRAINT [PK_CostosCIF2] PRIMARY KEY CLUSTERED 
(
	[IdControl] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CostosManoObra]

-- %%
/****** Object:  Table [dbo].[CostosManoObra]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CostosManoObra](
	[IdMano] [int] IDENTITY(1,1) NOT NULL,
	[Estado] [int] NULL,
	[Produccion] [int] NULL,
	[Fecha] [smalldatetime] NULL,
	[Referencia] [nvarchar](250) NULL,
	[Empleado] [nvarchar](50) NULL,
	[Proceso] [nvarchar](50) NULL,
	[Horas] [float] NULL,
	[Cantidad] [float] NULL,
 CONSTRAINT [PK_CostosManoObra] PRIMARY KEY CLUSTERED 
(
	[IdMano] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CostosProceso]

-- %%
/****** Object:  Table [dbo].[CostosProceso]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CostosProceso](
	[IdProceso] [int] IDENTITY(1,1) NOT NULL,
	[Proceso] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](50) NULL,
 CONSTRAINT [PK_CostosProceso] PRIMARY KEY CLUSTERED 
(
	[Proceso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cotizacion]

-- %%
/****** Object:  Table [dbo].[Cotizacion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cotizacion](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[NCotizacion] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Nombre] [nvarchar](250) NULL,
	[Vendedor] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Transporte] [float] NULL,
	[Fproceso] [smalldatetime] NULL,
	[Centro costos] [nvarchar](250) NULL,
	[Letras] [nvarchar](250) NULL,
	[Tipotercero] [nvarchar](50) NULL,
	[TRM] [float] NULL,
	[Estado] [int] NULL,
	[Doc] [nvarchar](50) NULL,
	[Dias] [int] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Documento] [nvarchar](50) NULL,
	[Terminal] [int] NULL,
	[PDescuento] [float] NULL,
	[Placa] [nvarchar](50) NULL,
	[Prospecto] [nvarchar](50) NULL,
	[Origen] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
	[Via] [nvarchar](50) NULL,
	[ICO] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[RMinima] [float] NULL,
	[Condiciones] [nvarchar](250) NULL,
	[Piezas] [nvarchar](50) NULL,
	[Peso] [float] NULL,
	[Dimensiones] [nvarchar](50) NULL,
	[CIF] [int] NULL,
	[TTransito] [nvarchar](50) NULL,
	[Frecuencia] [nvarchar](50) NULL,
	[Volumen] [float] NULL,
	[Pesofin] [float] NULL,
	[Lista] [nvarchar](50) NULL,
	[Imprevistos] [int] NULL,
	[Pimprevistos] [float] NULL,
	[Admon] [int] NULL,
	[PAdmon] [float] NULL,
	[Utilidadest] [int] NULL,
	[PUtilidadest] [float] NULL,
	[Status] [nvarchar](50) NULL,
	[Estado2] [int] NULL,
	[Tipomail] [nvarchar](50) NULL,
	[Valormercancia] [float] NULL,
	[Medida] [nvarchar](50) NULL,
	[TipoMoneda] [nvarchar](50) NULL,
	[CotizaNo] [int] NULL,
	[ValorFlete] [float] NULL,
	[TipoOperacion] [nvarchar](50) NULL,
	[Largo] [float] NULL,
	[Ancho] [float] NULL,
	[Alto] [float] NULL,
	[FStatus] [smalldatetime] NULL,
 CONSTRAINT [PK_Cotizacion] PRIMARY KEY CLUSTERED 
(
	[NCotizacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cotizacioninsumos]

-- %%
/****** Object:  Table [dbo].[Cotizacioninsumos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cotizacioninsumos](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[idpedir] [int] NULL,
	[Cotizacion] [int] NOT NULL,
	[Referencia] [nvarchar](250) NULL,
	[Insumo] [nvarchar](50) NULL,
	[Cantidad] [float] NULL,
	[Costo] [float] NULL,
	[CantidadRef] [int] NULL,
	[Total] [int] NULL,
	[Proveedor] [nvarchar](50) NULL,
 CONSTRAINT [PK_Cotizacioninsumos] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cotizacionsub]

-- %%
/****** Object:  Table [dbo].[Cotizacionsub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cotizacionsub](
	[IdCotizacionsub] [int] IDENTITY(1,1) NOT NULL,
	[NCotizacion] [int] NOT NULL,
	[Cantidad] [float] NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Descuento] [float] NULL,
	[Precio] [float] NULL,
	[PIva] [float] NULL,
	[Precio total] [int] NULL,
	[Neto] [int] NULL,
	[Peso] [float] NULL,
	[Subtotal] [int] NULL,
	[Notas] [nvarchar](250) NULL,
	[CUDol] [float] NULL,
	[Dolares] [float] NULL,
	[Origen] [nvarchar](250) NULL,
	[Destino] [nvarchar](250) NULL,
	[cod_naturaleza] [int] NULL,
	[cod_empaque] [int] NULL,
	[Cantidades] [int] NULL,
	[cod_producto] [nvarchar](50) NULL,
	[Medida] [int] NULL,
	[Producto] [nvarchar](250) NULL,
	[Costo] [int] NULL,
	[Tercero] [nvarchar](50) NULL,
	[Moneda] [nvarchar](50) NULL,
	[TRMS] [float] NULL,
	[Viasub] [nvarchar](50) NULL,
	[CTotal] [float] NULL,
	[VPropina] [int] NULL,
	[Minima] [float] NULL,
	[Rebaja] [int] NULL,
 CONSTRAINT [PK_Cotizacionsub] PRIMARY KEY CLUSTERED 
(
	[IdCotizacionsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CotizaDimensiones]

-- %%
/****** Object:  Table [dbo].[CotizaDimensiones]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CotizaDimensiones](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[NCotizacion] [int] NOT NULL,
	[Largo] [float] NULL,
	[Ancho] [float] NULL,
	[Alto] [float] NULL,
	[Dimensiones] [nvarchar](50) NULL,
	[Volumen] [float] NULL,
	[Piezas] [float] NULL,
 CONSTRAINT [PK_CotizaDimensiones] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CPuestos]

-- %%
/****** Object:  Table [dbo].[CPuestos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CPuestos](
	[IdPuestos] [int] IDENTITY(1,1) NOT NULL,
	[Puesto] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
 CONSTRAINT [PK_CPuestos] PRIMARY KEY CLUSTERED 
(
	[Puesto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Crucecuenta]

-- %%
/****** Object:  Table [dbo].[Crucecuenta]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Crucecuenta](
	[IdCruce] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Tercero] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
 CONSTRAINT [PK_Crucecuenta] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Crucecuentasub]

-- %%
/****** Object:  Table [dbo].[Crucecuentasub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Crucecuentasub](
	[IdCrucesub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NULL,
	[FacturaVenta] [int] NULL,
	[FacturaCompra] [int] NULL,
	[Neto] [float] NULL,
	[Notas] [nvarchar](250) NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Us] [float] NULL,
	[Docu] [nvarchar](50) NULL,
	[Docu2] [nvarchar](50) NULL,
	[Resolucion] [nvarchar](50) NULL,
	[DO] [int] NULL,
	[Proveedor] [nvarchar](50) NULL,
	[Prefijo] [nvarchar](50) NULL,
 CONSTRAINT [PK_Crucecuentasub] PRIMARY KEY CLUSTERED 
(
	[IdCrucesub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ctrafico]

-- %%
/****** Object:  Table [dbo].[Ctrafico]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ctrafico](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[ControlNo] [int] NOT NULL,
	[Origen] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
	[Ruta] [nvarchar](250) NULL,
	[CentroCostos] [nvarchar](50) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Estado] [int] NULL,
	[Terminal] [int] NULL,
	[Conductor] [nvarchar](50) NULL,
	[Placa] [nvarchar](50) NULL,
	[Hinicio] [datetime] NULL,
	[Manifiesto] [int] NULL,
 CONSTRAINT [PK_Ctrafico] PRIMARY KEY CLUSTERED 
(
	[ControlNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CtraficoMatrix]

-- %%
/****** Object:  Table [dbo].[CtraficoMatrix]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CtraficoMatrix](
	[IdRuta] [int] IDENTITY(1,1) NOT NULL,
	[Ruta] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
 CONSTRAINT [PK_CtraficoMatrix] PRIMARY KEY CLUSTERED 
(
	[Ruta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CtraficoMatrixsub]

-- %%
/****** Object:  Table [dbo].[CtraficoMatrixsub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CtraficoMatrixsub](
	[IdRutasub] [int] IDENTITY(1,1) NOT NULL,
	[Ruta] [nvarchar](250) NOT NULL,
	[PuestoControl] [nvarchar](250) NULL,
	[Testimado] [datetime] NULL,
	[Dia] [int] NULL,
 CONSTRAINT [PK_CtraficoMatrixsub] PRIMARY KEY CLUSTERED 
(
	[IdRutasub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ctraficosub]

-- %%
/****** Object:  Table [dbo].[Ctraficosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ctraficosub](
	[IdControlsub] [int] IDENTITY(1,1) NOT NULL,
	[ControlNo] [int] NULL,
	[PuestoControl] [nvarchar](250) NULL,
	[Testimado] [datetime] NULL,
	[TReal] [datetime] NULL,
	[Notas] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
 CONSTRAINT [PK_Ctraficosub] PRIMARY KEY CLUSTERED 
(
	[IdControlsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cuentas]

-- %%
/****** Object:  Table [dbo].[Cuentas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cuentas](
	[IdCuentas] [int] IDENTITY(1,1) NOT NULL,
	[NúmCuenta] [nvarchar](50) NOT NULL,
	[NombreCuenta] [nvarchar](250) NULL,
	[TipoCuenta] [nvarchar](50) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Estado] [int] NULL,
	[Imputable] [nvarchar](50) NULL,
	[ConceptoM] [nvarchar](50) NULL,
	[Equivalencia] [nvarchar](50) NULL,
	[Deducible] [nvarchar](50) NULL,
	[Tributario] [nvarchar](50) NULL,
	[Nota] [int] NULL,
 CONSTRAINT [PK_Cuentas] PRIMARY KEY CLUSTERED 
(
	[NúmCuenta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cuentas de cobro]

-- %%
/****** Object:  Table [dbo].[Cuentas de cobro]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cuentas de cobro](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[IdCuenta] [int] NOT NULL,
	[FECHA] [smalldatetime] NULL,
	[ACREEDOR] [nvarchar](250) NULL,
	[VALOR] [int] NULL,
	[SUMA] [nvarchar](250) NULL,
	[CONCEPTO] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Neto] [int] NULL,
	[PReteIca] [float] NULL,
	[Reteica] [int] NULL,
	[PReteIva] [float] NULL,
	[ReteIva] [int] NULL,
	[Documento] [nvarchar](250) NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Situacion] [nvarchar](250) NULL,
	[Aplicacion] [int] NULL,
	[ConceptoM] [nvarchar](250) NULL,
	[Base] [int] NULL,
	[DO] [int] NULL,
	[Dias] [int] NULL,
	[Estado] [int] NULL,
	[Retencion] [nvarchar](50) NULL,
	[TRM] [float] NULL,
	[Us] [float] NULL,
	[Ordencompra] [int] NULL,
	[Descuentos] [int] NULL,
	[Anticipo] [int] NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Alterno] [int] NULL,
	[Prefijo] [nvarchar](50) NULL,
 CONSTRAINT [PK_Cuentas de cobro] PRIMARY KEY CLUSTERED 
(
	[IdCuenta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cuentasub]

-- %%
/****** Object:  Table [dbo].[Cuentasub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cuentasub](
	[IdCotizacionsub] [int] IDENTITY(1,1) NOT NULL,
	[IdCuenta] [int] NOT NULL,
	[Cantidad] [float] NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Descuento] [float] NULL,
	[Precio] [float] NULL,
	[PIva] [float] NULL,
	[Precio total] [int] NULL,
	[Neto] [int] NULL,
	[Peso] [float] NULL,
	[Subtotal] [int] NULL,
	[DO] [int] NULL,
	[Exentos] [int] NULL,
	[DesExentos] [int] NULL,
	[DesGravados] [int] NULL,
	[PRete] [float] NULL,
	[Retencion] [int] NULL,
	[TipoRetencion] [nvarchar](50) NULL,
	[Concepto] [nvarchar](50) NULL,
	[Serial] [nvarchar](250) NULL,
	[Placa] [nvarchar](50) NULL,
	[VPropina] [int] NULL,
	[Cree] [int] NULL,
 CONSTRAINT [PK_Cuentasub] PRIMARY KEY CLUSTERED 
(
	[IdCotizacionsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cuentasubdescuentos]

-- %%
/****** Object:  Table [dbo].[Cuentasubdescuentos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cuentasubdescuentos](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[IdCuenta] [int] NULL,
	[Referencia] [nvarchar](50) NULL,
	[Neto] [int] NULL,
	[Placa] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Comprobante] [int] NULL,
 CONSTRAINT [PK_Cuentasubdescuentos] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cumplido]

-- %%
/****** Object:  Table [dbo].[Cumplido]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cumplido](
	[idCumplido] [int] IDENTITY(1,1) NOT NULL,
	[CumplidoNo] [int] NOT NULL,
	[Ciudad] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Cliente] [nvarchar](250) NULL,
	[OCargue] [int] NULL,
	[Placa] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Planilla] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[Conductor] [nvarchar](250) NULL,
	[Destinatario] [nvarchar](50) NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Firma] [nvarchar](50) NULL,
	[Cargue] [nvarchar](250) NULL,
	[Descargue] [nvarchar](250) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Tipo] [nvarchar](50) NULL,
	[DFinal] [nvarchar](50) NULL,
	[Propietariosub] [nvarchar](50) NULL,
	[Semiremolque] [nvarchar](250) NULL,
	[ICO] [nvarchar](50) NULL,
	[Piezas] [nvarchar](50) NULL,
	[Tenedor] [nvarchar](50) NULL,
	[FVenlic] [smalldatetime] NULL,
	[SOAT] [smalldatetime] NULL,
	[Anticipo] [int] NULL,
	[Egreso] [int] NULL,
	[Banco] [nvarchar](50) NULL,
 CONSTRAINT [PK_Cumplido] PRIMARY KEY CLUSTERED 
(
	[CumplidoNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cumplidosub]

-- %%
/****** Object:  Table [dbo].[Cumplidosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cumplidosub](
	[Controlsub] [int] IDENTITY(1,1) NOT NULL,
	[IdCumplidosub] [int] NULL,
	[CumplidoNo] [int] NOT NULL,
	[Cantidad] [float] NULL,
	[Peso] [float] NULL,
	[Producto] [nvarchar](250) NULL,
	[Origen] [nvarchar](250) NULL,
	[Destino] [nvarchar](250) NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Estado] [int] NULL,
	[Neto] [int] NULL,
	[Costo] [int] NULL,
	[Gastos] [int] NULL,
	[Medida] [int] NULL,
	[cod_naturaleza] [int] NULL,
	[cod_empaque] [int] NULL,
	[cod_producto] [nvarchar](50) NULL,
	[EstadoMan] [int] NULL,
	[DO] [int] NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Factura] [int] NULL,
	[idpedire] [int] NULL,
	[Centro] [nvarchar](50) NULL,
	[DirecOrigen] [nvarchar](250) NULL,
	[DirecDestino] [nvarchar](250) NULL,
	[SedeOrigen] [nvarchar](50) NULL,
	[SedeDestino] [nvarchar](50) NULL,
	[CantIni] [float] NULL,
	[CostoIni] [int] NULL,
	[NetoIni] [int] NULL,
 CONSTRAINT [PK_Cumplidosub] PRIMARY KEY CLUSTERED 
(
	[Controlsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cumplir]

-- %%
/****** Object:  Table [dbo].[Cumplir]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cumplir](
	[IdCumplir] [int] IDENTITY(1,1) NOT NULL,
	[CumplidoNo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Placa] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Conductor] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[NAprobacion] [int] NULL,
 CONSTRAINT [PK_Cumplir] PRIMARY KEY CLUSTERED 
(
	[CumplidoNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cumplirsub]

-- %%
/****** Object:  Table [dbo].[Cumplirsub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cumplirsub](
	[idcumplirsub] [int] IDENTITY(1,1) NOT NULL,
	[CumplidoNo] [int] NOT NULL,
	[Remesa] [int] NULL,
	[Cliente] [nvarchar](250) NULL,
	[Notas] [nvarchar](250) NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[OCargue] [int] NULL,
	[Manifiesto] [int] NULL,
	[Origen] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
	[Tipo] [nvarchar](50) NULL,
	[Costos] [int] NULL,
	[Ingresos] [int] NULL,
 CONSTRAINT [PK_Cumplirsub] PRIMARY KEY CLUSTERED 
(
	[idcumplirsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cursos]

-- %%
/****** Object:  Table [dbo].[Cursos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cursos](
	[IdCursos] [int] IDENTITY(1,1) NOT NULL,
	[Curso] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
 CONSTRAINT [PK_Cursos] PRIMARY KEY CLUSTERED 
(
	[Curso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Datos]

-- %%
/****** Object:  Table [dbo].[Datos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Datos](
	[Iddatos] [int] IDENTITY(1,1) NOT NULL,
	[Clase] [nvarchar](250) NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NOT NULL,
	[NúmCuenta] [nvarchar](50) NOT NULL,
	[Documento] [nvarchar](250) NOT NULL,
	[Comprobante] [int] NOT NULL,
	[Identificacion] [nvarchar](250) NULL,
	[Débitos] [float] NOT NULL,
	[Créditos] [float] NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Documento2] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Estado] [int] NULL,
	[IdControl] [int] NULL,
	[DO] [int] NULL,
	[Cheque] [int] NULL,
	[IdEntradas] [int] NULL,
	[Base] [int] NULL,
	[Tarifa] [float] NULL,
	[IvaMayor] [int] NULL,
	[Nit2] [nvarchar](250) NULL,
	[Docu] [nvarchar](50) NULL,
	[Aplicacion] [int] NULL,
	[Niif] [nvarchar](50) NULL,
	[Local] [nvarchar](50) NULL,
	[Definitivo] [int] NULL,
	[Cierre] [nvarchar](50) NULL,
 CONSTRAINT [PK_Datos] PRIMARY KEY CLUSTERED 
(
	[Iddatos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Debilidades]

-- %%
/****** Object:  Table [dbo].[Debilidades]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Debilidades](
	[IdDebilidades] [int] IDENTITY(1,1) NOT NULL,
	[Materia] [nvarchar](250) NULL,
	[Periodo] [int] NULL,
	[Codigodeb] [int] NULL,
	[Significado] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Curso] [nvarchar](50) NULL,
	[Año] [int] NULL,
 CONSTRAINT [PK_Debilidades] PRIMARY KEY CLUSTERED 
(
	[IdDebilidades] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Declaracion]

-- %%
/****** Object:  Table [dbo].[Declaracion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Declaracion](
	[IdDeclaracion] [int] IDENTITY(1,1) NOT NULL,
	[Renglon] [int] NOT NULL,
	[Nombre] [nvarchar](250) NULL,
 CONSTRAINT [PK_Declaracion] PRIMARY KEY CLUSTERED 
(
	[Renglon] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Declaracionsub]

-- %%
/****** Object:  Table [dbo].[Declaracionsub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Declaracionsub](
	[IdDeclaracionsub] [int] IDENTITY(1,1) NOT NULL,
	[Renglon] [int] NOT NULL,
	[Cuenta] [nvarchar](250) NULL,
 CONSTRAINT [PK_Declaracionsub] PRIMARY KEY CLUSTERED 
(
	[IdDeclaracionsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Demos]

-- %%
/****** Object:  Table [dbo].[Demos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Demos](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Prospecto] [nvarchar](50) NULL,
	[Cliente] [nvarchar](50) NULL,
	[Tipo] [nvarchar](50) NULL,
	[Demo] [nvarchar](250) NULL,
	[Comercial] [nvarchar](50) NULL,
	[Objeciones] [nvarchar](250) NULL,
	[Tratamiento] [nvarchar](250) NULL,
	[Notas] [nvarchar](250) NULL,
	[NFecha] [smalldatetime] NULL,
	[Estado] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Status] [nvarchar](50) NULL,
 CONSTRAINT [PK_Demos] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Depreciación]

-- %%
/****** Object:  Table [dbo].[Depreciación]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Depreciación](
	[IdDepreciación] [int] IDENTITY(1,1) NOT NULL,
	[IdActivo] [int] NOT NULL,
	[FechaDepreciación] [smalldatetime] NOT NULL,
	[ImporteDepreciación] [int] NULL,
	[Contabilizado] [int] NULL,
 CONSTRAINT [PK_Depreciación] PRIMARY KEY CLUSTERED 
(
	[IdActivo] ASC,
	[FechaDepreciación] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Despachos]

-- %%
/****** Object:  Table [dbo].[Despachos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Despachos](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[NDespacho] [int] NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NOT NULL,
	[Vendedor] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[Descarga] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Terminal] [int] NULL,
	[Bloque] [int] NULL,
	[Cargar] [nvarchar](50) NULL,
	[Tipotercero] [nvarchar](50) NULL,
	[Dias] [int] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Doc] [nvarchar](250) NULL,
	[Sucursal] [nvarchar](250) NULL,
	[PDescuento] [float] NULL,
	[Procesar] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Letras] [nvarchar](250) NULL,
	[Formapago] [nvarchar](250) NULL,
	[Lista] [nvarchar](50) NULL,
 CONSTRAINT [PK_Despachos] PRIMARY KEY CLUSTERED 
(
	[NDespacho] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Despachosub]

-- %%
/****** Object:  Table [dbo].[Despachosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Despachosub](
	[IdCotizacionsub] [int] IDENTITY(1,1) NOT NULL,
	[NDespacho] [int] NOT NULL,
	[Cantidad] [float] NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Descuento] [float] NULL,
	[Precio] [float] NULL,
	[PIva] [float] NULL,
	[Precio total] [int] NULL,
	[Neto] [int] NULL,
	[Peso] [float] NULL,
	[Subtotal] [int] NULL,
	[Notas] [nvarchar](250) NULL,
	[Centrosuc] [nvarchar](250) NULL,
	[Pedido] [int] NULL,
	[Controlfinal] [float] NULL,
	[Lote] [int] NULL,
	[OCompra] [float] NULL,
	[Cajas] [int] NULL,
 CONSTRAINT [PK_Despachosub] PRIMARY KEY CLUSTERED 
(
	[IdCotizacionsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Devoluciones]

-- %%
/****** Object:  Table [dbo].[Devoluciones]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Devoluciones](
	[IdDevoluciones] [int] IDENTITY(1,1) NOT NULL,
	[Devolucion] [int] NOT NULL,
	[Fecha] [smalldatetime] NOT NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Cliente] [nvarchar](250) NULL,
	[Chequenumero] [int] NULL,
	[Banco] [nvarchar](250) NULL,
	[Neto] [int] NULL,
	[Centro Costos] [nvarchar](250) NULL,
	[Promotor] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[Adicional] [int] NULL,
	[Total] [int] NULL,
	[Estado] [int] NULL,
	[Us] [float] NULL,
	[TRM] [float] NULL,
	[Resolucion] [nvarchar](50) NULL,
 CONSTRAINT [PK_Devoluciones] PRIMARY KEY CLUSTERED 
(
	[Devolucion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Diario]

-- %%
/****** Object:  Table [dbo].[Diario]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Diario](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[PlanillaNo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Ruta] [nvarchar](50) NULL,
	[Notas] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Contado] [int] NULL,
	[Cartera] [int] NULL,
	[Gastos] [int] NULL,
	[Credito] [int] NULL,
	[Ncredito] [int] NULL,
	[Estado2] [int] NULL,
	[Placa] [nvarchar](50) NULL,
	[Conductor] [nvarchar](50) NULL,
	[Ayudante] [nvarchar](50) NULL,
	[ContadoP] [int] NULL,
	[CreditoP] [int] NULL,
	[NcreditoP] [int] NULL,
	[CarteraP] [int] NULL,
	[Documento] [nvarchar](50) NULL,
	[Centrocostos] [nvarchar](50) NULL,
 CONSTRAINT [PK_Diario] PRIMARY KEY CLUSTERED 
(
	[PlanillaNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DiarioA]

-- %%
/****** Object:  Table [dbo].[DiarioA]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DiarioA](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[DiarioNo] [int] NOT NULL,
	[Resolucion] [nvarchar](50) NOT NULL,
	[Facturanumero] [int] NOT NULL,
	[Total] [int] NULL,
	[Cliente] [nvarchar](50) NULL,
	[Pagado] [int] NULL,
 CONSTRAINT [PK_DiarioA] PRIMARY KEY CLUSTERED 
(
	[DiarioNo] ASC,
	[Resolucion] ASC,
	[Facturanumero] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DiarioB]

-- %%
/****** Object:  Table [dbo].[DiarioB]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DiarioB](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[DiarioNo] [int] NOT NULL,
	[Facturanumero] [int] NOT NULL,
	[Total] [int] NULL,
	[Cliente] [nvarchar](50) NULL,
	[Pagado] [int] NULL,
 CONSTRAINT [PK_DiarioB] PRIMARY KEY CLUSTERED 
(
	[DiarioNo] ASC,
	[Facturanumero] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DiarioC]

-- %%
/****** Object:  Table [dbo].[DiarioC]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DiarioC](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[DiarioNo] [int] NOT NULL,
	[Facturanumero] [int] NULL,
	[Total] [int] NULL,
	[Cliente] [nvarchar](50) NULL,
	[Pagado] [int] NULL,
 CONSTRAINT [PK_DiarioC] PRIMARY KEY CLUSTERED 
(
	[idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DiarioD]

-- %%
/****** Object:  Table [dbo].[DiarioD]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DiarioD](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[DiarioNo] [int] NOT NULL,
	[Facturanumero] [int] NULL,
	[Total] [int] NULL,
	[Cliente] [nvarchar](50) NULL,
	[Concepto] [nvarchar](250) NULL,
 CONSTRAINT [PK_DiarioD] PRIMARY KEY CLUSTERED 
(
	[idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DiarioE]

-- %%
/****** Object:  Table [dbo].[DiarioE]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DiarioE](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[DiarioNo] [int] NOT NULL,
	[Facturanumero] [int] NOT NULL,
	[Total] [int] NULL,
	[Cliente] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[NotaNo] [int] NULL,
	[Pagado] [int] NULL,
 CONSTRAINT [PK_DiarioE] PRIMARY KEY CLUSTERED 
(
	[DiarioNo] ASC,
	[Facturanumero] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DiarioF]

-- %%
/****** Object:  Table [dbo].[DiarioF]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DiarioF](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[DiarioNo] [int] NOT NULL,
	[Facturanumero] [int] NOT NULL,
	[Total] [int] NULL,
	[Cliente] [nvarchar](50) NULL,
	[Pagado] [int] NULL,
 CONSTRAINT [PK_DiarioF] PRIMARY KEY CLUSTERED 
(
	[DiarioNo] ASC,
	[Facturanumero] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Diferidos]

-- %%
/****** Object:  Table [dbo].[Diferidos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Diferidos](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[Prorateo] [float] NULL,
	[FCorte] [smalldatetime] NULL,
	[Cuenta] [nvarchar](50) NULL,
	[CuentaAjuste] [nvarchar](50) NULL,
 CONSTRAINT [PK_Diferidos] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DiferidosCargar]

-- %%
/****** Object:  Table [dbo].[DiferidosCargar]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DiferidosCargar](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[NúmCuenta] [nvarchar](50) NULL,
	[Total] [int] NULL,
	[Identificacion] [nvarchar](50) NULL,
	[CuentaAjuste] [nvarchar](50) NULL,
 CONSTRAINT [PK_DiferidosCargar] PRIMARY KEY CLUSTERED 
(
	[IdControl] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Disponibilidadvehicular]

-- %%
/****** Object:  Table [dbo].[Disponibilidadvehicular]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Disponibilidadvehicular](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Placa] [nvarchar](50) NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Estado] [int] NULL,
	[Cumplido] [int] NULL,
 CONSTRAINT [PK_Disponibilidadvehicular] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Documentacion]

-- %%
/****** Object:  Table [dbo].[Documentacion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Documentacion](
	[IdDocumental] [int] IDENTITY(1,1) NOT NULL,
	[Cedula] [nvarchar](50) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Situacion] [nvarchar](250) NULL,
	[Notas] [nvarchar](250) NULL,
	[RutaFoto] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Gestor] [nvarchar](50) NULL,
 CONSTRAINT [PK_Documentacion] PRIMARY KEY CLUSTERED 
(
	[Cedula] ASC,
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DocumentacionDO]

-- %%
/****** Object:  Table [dbo].[DocumentacionDO]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DocumentacionDO](
	[IdDocumental] [int] IDENTITY(1,1) NOT NULL,
	[DO] [int] NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Situacion] [nvarchar](50) NULL,
	[Notas] [nvarchar](250) NULL,
	[RutaFoto] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Gestor] [nvarchar](50) NULL,
 CONSTRAINT [PK_DocumentacionDO] PRIMARY KEY CLUSTERED 
(
	[DO] ASC,
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Documentacionplaca]

-- %%
/****** Object:  Table [dbo].[Documentacionplaca]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Documentacionplaca](
	[IdDocumental] [int] IDENTITY(1,1) NOT NULL,
	[Placa] [nvarchar](50) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Situacion] [nvarchar](250) NULL,
	[Notas] [nvarchar](250) NULL,
	[RutaFoto] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Gestor] [nvarchar](50) NULL,
 CONSTRAINT [PK_Documentacionplaca] PRIMARY KEY CLUSTERED 
(
	[Placa] ASC,
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DocumentacionRemesa]

-- %%
/****** Object:  Table [dbo].[DocumentacionRemesa]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DocumentacionRemesa](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[Remesa] [int] NOT NULL,
	[Documento] [nvarchar](50) NOT NULL,
	[Neto] [int] NULL,
	[Destinatario] [nvarchar](50) NULL,
 CONSTRAINT [PK_DocumentacionRemesa] PRIMARY KEY CLUSTERED 
(
	[Remesa] ASC,
	[Documento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Documentaciontercero]

-- %%
/****** Object:  Table [dbo].[Documentaciontercero]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Documentaciontercero](
	[IdDocumental] [int] IDENTITY(1,1) NOT NULL,
	[Identificacion] [nvarchar](50) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Situacion] [nvarchar](50) NULL,
	[Notas] [nvarchar](250) NULL,
	[RutaFoto] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Gestor] [nvarchar](50) NULL,
 CONSTRAINT [PK_Documentaciontercero] PRIMARY KEY CLUSTERED 
(
	[Identificacion] ASC,
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Documentos]

-- %%
/****** Object:  Table [dbo].[Documentos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Documentos](
	[Iddocumento] [int] IDENTITY(1,1) NOT NULL,
	[Sigla] [nvarchar](250) NOT NULL,
	[Documento] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Documentos] PRIMARY KEY CLUSTERED 
(
	[Sigla] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DSAgencias]

-- %%
/****** Object:  Table [dbo].[DSAgencias]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DSAgencias](
	[Idagencia] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Agencia] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_DSAgencias] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DSVia]

-- %%
/****** Object:  Table [dbo].[DSVia]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DSVia](
	[Idagencia] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Agencia] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_DSVia] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ejecucion]

-- %%
/****** Object:  Table [dbo].[Ejecucion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ejecucion](
	[IdEjecucion] [int] IDENTITY(1,1) NOT NULL,
	[Finicial] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
	[Per1] [smalldatetime] NULL,
 CONSTRAINT [PK_Ejecucion] PRIMARY KEY CLUSTERED 
(
	[IdEjecucion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Empleado]

-- %%
/****** Object:  Table [dbo].[Empleado]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Empleado](
	[Cedula] [nvarchar](50) NOT NULL,
	[IdEmpleados] [int] IDENTITY(1,1) NOT NULL,
	[Salario] [float] NULL,
	[Tipo] [nvarchar](250) NULL,
	[Empleado] [nvarchar](250) NULL,
	[Cargo] [nvarchar](250) NULL,
	[Direccion] [nvarchar](250) NULL,
	[Telefono] [nvarchar](250) NULL,
	[Fecha nacimiento] [smalldatetime] NULL,
	[Fecha contrato] [smalldatetime] NULL,
	[Tipo contrato] [nvarchar](250) NULL,
	[Estudios1] [nvarchar](250) NULL,
	[Laborales1] [nvarchar](250) NULL,
	[Referencias1] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Extension] [nvarchar](250) NULL,
	[Jefe] [nvarchar](250) NULL,
	[Tratamiento] [nvarchar](250) NULL,
	[RH] [nvarchar](250) NULL,
	[Tipoempleado] [nvarchar](250) NULL,
	[EPS] [nvarchar](250) NULL,
	[Comision] [float] NULL,
	[Pension] [nvarchar](250) NULL,
	[ARP] [nvarchar](250) NULL,
	[RIP] [float] NULL,
	[Cuenta] [nvarchar](250) NULL,
	[Banco] [nvarchar](250) NULL,
	[Clase] [nvarchar](250) NULL,
	[FCesantia] [nvarchar](250) NULL,
	[RutaFoto] [nvarchar](250) NULL,
	[Codigo] [nvarchar](50) NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Situacion] [nvarchar](50) NULL,
	[Compensacion] [int] NULL,
	[Total] [int] NULL,
	[Estado] [int] NULL,
	[FRetiro] [smalldatetime] NULL,
	[Caja] [nvarchar](50) NULL,
	[Celular] [nvarchar](50) NULL,
	[Email] [nvarchar](50) NULL,
	[Parafiscales] [nvarchar](50) NULL,
	[Integral] [nvarchar](50) NULL,
	[Procedimiento] [nvarchar](50) NULL,
	[PRetefte] [float] NULL,
	[Apellido1] [nvarchar](50) NULL,
	[Apellido2] [nvarchar](50) NULL,
	[Nombre1] [nvarchar](50) NULL,
	[Nombre2] [nvarchar](50) NULL,
	[Frecuencia] [nvarchar](50) NULL,
	[TipoTrabajador] [nvarchar](50) NULL,
	[SubTipoTrabajador] [nvarchar](50) NULL,
	[TipoCuenta] [nvarchar](50) NULL,
	[AltoRiesgoPension] [bit] NULL,
	[Pais] [nvarchar](50) NULL,
	[Arquetipo] [nvarchar](50) NULL,
	[TipoMoneda] [nvarchar](50) NULL,
	[Aprendiz] [nchar](10) NULL,
 CONSTRAINT [PK_Empleado] PRIMARY KEY CLUSTERED 
(
	[Cedula] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EmpleadoCompensa]

-- %%
/****** Object:  Table [dbo].[EmpleadoCompensa]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EmpleadoCompensa](
	[Idescuentos] [int] IDENTITY(1,1) NOT NULL,
	[Cedula] [nvarchar](50) NULL,
	[Concepto] [nvarchar](50) NULL,
	[Neto] [int] NULL,
 CONSTRAINT [PK_EmpleadoCompensa] PRIMARY KEY CLUSTERED 
(
	[Idescuentos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EmpleadoContrato]

-- %%
/****** Object:  Table [dbo].[EmpleadoContrato]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EmpleadoContrato](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[TipoContrato] [nvarchar](50) NOT NULL,
	[Articulado] [ntext] NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_EmpleadoContrato] PRIMARY KEY CLUSTERED 
(
	[TipoContrato] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Empleadoexenciones]

-- %%
/****** Object:  Table [dbo].[Empleadoexenciones]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Empleadoexenciones](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Cedula] [nvarchar](50) NULL,
	[Concepto] [nvarchar](50) NULL,
	[Neto] [int] NULL,
	[Notas] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Gestor] [nvarchar](50) NULL,
 CONSTRAINT [PK_Empleadoexenciones] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EmpleadoTipo]

-- %%
/****** Object:  Table [dbo].[EmpleadoTipo]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EmpleadoTipo](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_EmpleadoTipo] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EmpleadoTipocontrato]

-- %%
/****** Object:  Table [dbo].[EmpleadoTipocontrato]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EmpleadoTipocontrato](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_EmpleadoTipocontrato] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EmpleadoVacaciones]

-- %%
/****** Object:  Table [dbo].[EmpleadoVacaciones]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EmpleadoVacaciones](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Cedula] [nvarchar](50) NOT NULL,
	[Finicial] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
	[Salariomes] [int] NULL,
	[salariodia] [float] NULL,
	[Diascausa] [int] NULL,
	[Diasvac] [int] NULL,
	[Total] [int] NULL,
	[Finidisfrute] [smalldatetime] NULL,
	[Ffindisfrute] [smalldatetime] NULL,
	[Notas] [nvarchar](250) NULL,
	[Gestor] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Festivos] [int] NULL,
	[Tipovac] [nvarchar](50) NULL,
 CONSTRAINT [PK_EmpleadoVacaciones] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Encuesta]

-- %%
/****** Object:  Table [dbo].[Encuesta]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Encuesta](
	[IdEncuesta] [int] NOT NULL,
	[Estado] [int] NULL,
	[Fecha] [smalldatetime] NULL,
	[Cliente] [nvarchar](50) NULL,
	[Profesional] [nvarchar](50) NULL,
	[Informacion] [int] NULL,
	[Amabilidad] [int] NULL,
	[InfoPro] [int] NULL,
	[AmaPro] [int] NULL,
	[Comodidad] [int] NULL,
	[Confianza] [int] NULL,
	[Calidad] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Ejecutivo] [nvarchar](50) NULL,
	[Variable1] [int] NULL,
	[Variable2] [int] NULL,
	[Variable3] [int] NULL,
	[Variable4] [int] NULL,
	[Variable5] [int] NULL,
	[Variable6] [int] NULL,
	[Variable7] [int] NULL,
	[Documento] [nvarchar](50) NULL,
 CONSTRAINT [PK_Encuesta] PRIMARY KEY CLUSTERED 
(
	[IdEncuesta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Encuestasub]

-- %%
/****** Object:  Table [dbo].[Encuestasub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Encuestasub](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[IdEncuesta] [int] NOT NULL,
	[Variable] [int] NULL,
	[Calificacion] [int] NULL,
	[Notas] [ntext] NULL,
 CONSTRAINT [PK_Encuestasub] PRIMARY KEY CLUSTERED 
(
	[idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EncuestaVariables]

-- %%
/****** Object:  Table [dbo].[EncuestaVariables]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EncuestaVariables](
	[idPreguntas] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Variable] [nvarchar](250) NULL,
	[Pregunta] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Status] [nvarchar](50) NULL,
 CONSTRAINT [PK_EncuestaVariables] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Entrada]

-- %%
/****** Object:  Table [dbo].[Entrada]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Entrada](
	[Idproyectos] [int] IDENTITY(1,1) NOT NULL,
	[FECHA] [smalldatetime] NULL,
	[Nombre usuario] [nvarchar](250) NULL,
	[NIT] [nvarchar](250) NULL,
	[Direccion] [nvarchar](250) NULL,
	[Telefono] [nvarchar](250) NULL,
	[Regimen] [nvarchar](250) NULL,
	[Resolucion] [nvarchar](250) NULL,
	[Rango] [nvarchar](250) NULL,
	[Factura] [nvarchar](250) NULL,
	[Código ICA] [nvarchar](250) NULL,
	[Tarifa ICA] [float] NULL,
	[Computador] [nvarchar](250) NULL,
	[Nota] [nvarchar](250) NULL,
	[AMORTIZACION] [nvarchar](250) NULL,
	[VALOR PRESENTE] [int] NULL,
	[VALOR FUTURO] [int] NULL,
	[PERIODOS] [int] NULL,
	[TASA INICIAL] [nvarchar](250) NULL,
	[CONTROL] [int] NULL,
	[Prefijo] [nvarchar](50) NULL,
	[Resolucion2] [nvarchar](250) NULL,
	[Rango2] [nvarchar](250) NULL,
	[Computador2] [nvarchar](250) NULL,
	[DV] [nvarchar](250) NULL,
	[Mail] [nvarchar](250) NULL,
	[Costos] [int] NULL,
	[Descargue] [int] NULL,
	[Academico] [int] NULL,
	[Reservas] [int] NULL,
	[Matrix] [int] NULL,
	[CallCenter] [int] NULL,
	[Transporte] [int] NULL,
	[Peso] [int] NULL,
	[Dolares] [int] NULL,
	[Restaurantes] [int] NULL,
	[Mostrador] [int] NULL,
	[Estandar] [int] NULL,
	[Finicial] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
	[Licenciado] [int] NULL,
	[Proceso] [int] NULL,
	[CExistencia] [int] NULL,
	[Rebaja] [int] NULL,
	[Consolidado] [int] NULL,
	[Contratos] [int] NULL,
	[Prefijo2] [nvarchar](50) NULL,
	[Horas] [int] NULL,
	[Importaciones] [int] NULL,
	[Ciudad] [nvarchar](50) NULL,
	[Talleres] [int] NULL,
	[Planpagos] [int] NULL,
	[Asegurar] [int] NULL,
	[Cupo] [int] NULL,
	[ControlUsuarios] [int] NULL,
	[ConseReferencias] [int] NULL,
	[Constructoras] [int] NULL,
	[AgentesCarga] [int] NULL,
	[Dolares2] [int] NULL,
	[Media] [int] NULL,
	[Saldocentros] [int] NULL,
	[Composicion] [int] NULL,
	[DesFactura] [int] NULL,
	[Planillas] [int] NULL,
	[AnticiposPos] [int] NULL,
	[CupoMos] [int] NULL,
	[RetefteMos] [int] NULL,
	[Seguros] [int] NULL,
	[RendMinimo] [float] NULL,
	[ControlRen] [int] NULL,
	[Liquidos] [int] NULL,
	[Contabilizar] [int] NULL,
	[Actiretecree] [nvarchar](50) NULL,
	[PRetecree] [float] NULL,
	[FCorte] [smalldatetime] NULL,
	[Pasajeros] [int] NULL,
	[Carteraus] [int] NULL,
	[Deudasus] [int] NULL,
	[Multiresolucion] [int] NULL,
	[Multilistas] [int] NULL,
	[TipoCuenta] [nvarchar](50) NULL,
	[NoCuenta] [nvarchar](50) NULL,
	[Formato] [nvarchar](250) NULL,
	[SFavor] [int] NULL,
	[Bolsas] [int] NULL,
	[UBolsa] [int] NULL,
	[Aduanas] [int] NULL,
	[DestinoSeguro] [int] NULL,
	[RutaDS] [nvarchar](250) NULL,
	[RutaQR] [nvarchar](250) NULL,
	[RutaDIAN] [nvarchar](250) NULL,
	[QRDian] [nvarchar](250) NULL,
	[URLDian] [nvarchar](250) NULL,
	[Tareas] [int] NULL,
	[Pagosproveedores] [int] NULL,
	[PaisGenerador] [nvarchar](50) NULL,
	[Municipio] [nvarchar](50) NULL,
	[TestSetIDFE] [nvarchar](50) NULL,
	[TestSetIDNE] [nvarchar](50) NULL,
	[CertName] [nvarchar](50) NULL,
	[CertPsw] [nvarchar](50) NULL,
 CONSTRAINT [PK_Entrada] PRIMARY KEY CLUSTERED 
(
	[Idproyectos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EPS]

-- %%
/****** Object:  Table [dbo].[EPS]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EPS](
	[ideps] [int] IDENTITY(1,1) NOT NULL,
	[EPS] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Tercero] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_EPS] PRIMARY KEY CLUSTERED 
(
	[EPS] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Escalacotizacion]

-- %%
/****** Object:  Table [dbo].[Escalacotizacion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Escalacotizacion](
	[Idescala] [int] IDENTITY(1,1) NOT NULL,
	[Doc] [int] NULL,
	[Referencia] [nvarchar](250) NULL,
	[Notas] [nvarchar](250) NULL,
	[Precio20] [float] NULL,
	[Precio40] [float] NULL,
	[Precio40HC] [float] NULL,
	[Peso1] [float] NULL,
	[Peso2] [float] NULL,
	[Peso3] [float] NULL,
	[Peso4] [float] NULL,
	[Peso5] [float] NULL,
	[PesoMin] [float] NULL,
	[IdCotizacionsub] [int] NULL,
 CONSTRAINT [PK_Escalacotizacion] PRIMARY KEY CLUSTERED 
(
	[Idescala] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Evaluacion]

-- %%
/****** Object:  Table [dbo].[Evaluacion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Evaluacion](
	[IdEvaluacion] [int] IDENTITY(1,1) NOT NULL,
	[Identificacion] [nvarchar](250) NULL,
	[Etapa] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Criterio] [nvarchar](250) NULL,
	[Puntaje] [float] NULL,
	[Estado] [int] NULL,
	[Gestor] [nvarchar](50) NULL,
 CONSTRAINT [PK_Evaluacion] PRIMARY KEY CLUSTERED 
(
	[IdEvaluacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Extracontrato]

-- %%
/****** Object:  Table [dbo].[Extracontrato]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Extracontrato](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Dias] [int] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Placa] [nvarchar](50) NULL,
	[Contratante] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Documento] [nvarchar](50) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[DO] [int] NULL,
	[Conductor] [nvarchar](50) NULL,
	[Convenio] [nvarchar](50) NULL,
	[FContrato] [smalldatetime] NULL,
	[NContrato] [int] NULL,
	[Idordentra] [int] NULL,
	[Tipomail] [nvarchar](50) NULL,
 CONSTRAINT [PK_Extracontrato] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Extracontratosub]

-- %%
/****** Object:  Table [dbo].[Extracontratosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Extracontratosub](
	[idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[OrigenDestino] [nvarchar](50) NULL,
	[Recorrido] [ntext] NULL,
 CONSTRAINT [PK_Extracontratosub] PRIMARY KEY CLUSTERED 
(
	[idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Extracto]

-- %%
/****** Object:  Table [dbo].[Extracto]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Extracto](
	[IdExtracto] [int] NOT NULL,
	[Cuenta] [nvarchar](250) NULL,
	[Finicial] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Extracto] PRIMARY KEY CLUSTERED 
(
	[IdExtracto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Extractosub]

-- %%
/****** Object:  Table [dbo].[Extractosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Extractosub](
	[IdExtractosub] [int] IDENTITY(1,1) NOT NULL,
	[IdExtracto] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Entrada] [float] NULL,
	[Concepto] [nvarchar](250) NULL,
 CONSTRAINT [PK_Extractosub] PRIMARY KEY CLUSTERED 
(
	[IdExtractosub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Factura]

-- %%
/****** Object:  Table [dbo].[Factura]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Factura](
	[IdFACTURAS] [int] IDENTITY(1,1) NOT NULL,
	[Facturanumero] [int] NOT NULL,
	[Estado] [int] NULL,
	[Fechafac] [smalldatetime] NOT NULL,
	[Tipo] [nvarchar](50) NULL,
	[Cliente] [nvarchar](250) NULL,
	[Promotor] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Valortransporte] [int] NULL,
	[Formapago] [nvarchar](250) NULL,
	[Dias] [float] NOT NULL,
	[Vencimiento] [smalldatetime] NOT NULL,
	[Documento] [nvarchar](250) NULL,
	[Saldo] [float] NULL,
	[Medio] [nvarchar](250) NULL,
	[Bloque] [int] NULL,
	[Centro costos] [nvarchar](250) NULL,
	[Letras] [nvarchar](250) NULL,
	[PReteIca] [float] NULL,
	[Reteica] [int] NOT NULL,
	[PReteIva] [float] NULL,
	[ReteIva] [int] NOT NULL,
	[Fproceso] [smalldatetime] NULL,
	[Situacion] [nvarchar](250) NULL,
	[FechaEntrega] [smalldatetime] NULL,
	[PDescuento] [float] NULL,
	[TRM] [float] NULL,
	[LetrasDOL] [nvarchar](250) NULL,
	[Itinerario] [nvarchar](250) NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[Cupo] [int] NULL,
	[Diasvencimiento] [int] NULL,
	[Cartera] [int] NULL,
	[Edad] [int] NULL,
	[Estadoter] [int] NULL,
	[Descarga] [nvarchar](250) NULL,
	[Matrix] [int] NULL,
	[PFlete] [float] NULL,
	[Terminal] [int] NULL,
	[Cargar] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[FValidacion] [smalldatetime] NULL,
	[Diferencia] [int] NULL,
	[ARetencion] [nvarchar](50) NULL,
	[Anticipos] [float] NOT NULL,
	[Tipotercero] [nvarchar](50) NULL,
	[Us] [float] NULL,
	[Sucursal] [nvarchar](250) NULL,
	[Remisiones] [nvarchar](250) NULL,
	[Pedidos] [nvarchar](250) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[PUtilidadest] [float] NULL,
	[Utilidadest] [int] NULL,
	[DocumentoBL] [nvarchar](50) NULL,
	[DONo] [int] NULL,
	[Control] [int] NULL,
	[Orige] [nvarchar](50) NULL,
	[Destin] [nvarchar](50) NULL,
	[Via] [nvarchar](50) NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Imprevistos] [int] NULL,
	[Pimprevistos] [float] NULL,
	[Admon] [int] NULL,
	[PAdmon] [float] NULL,
	[Dimensiones] [nvarchar](50) NULL,
	[CIF] [int] NULL,
	[Lista] [nvarchar](50) NULL,
	[PRetefte] [float] NULL,
	[Retefte] [int] NULL,
	[CantBolsas] [int] NULL,
	[ValBolsas] [int] NULL,
	[TipoMoneda] [nvarchar](50) NULL,
	[StatusDian] [int] NULL,
	[StatusCliente] [int] NULL,
	[RespuestaDian] [ntext] NULL,
	[FDian] [smalldatetime] NULL,
	[FCliente] [smalldatetime] NULL,
	[CUFE] [nvarchar](250) NULL,
	[Tipomail] [nvarchar](50) NULL,
	[Horafin] [smalldatetime] NULL,
	[ArchivoDian] [ntext] NULL,
	[TipoFactura] [nvarchar](50) NULL,
	[TipoOperacion] [nvarchar](50) NULL,
	[FacReferencia] [nvarchar](50) NULL,
	[FechaOrden] [smalldatetime] NULL,
	[Docu] [nvarchar](50) NULL,
	[RecajaNo] [int] NULL,
	[FechaRC] [smalldatetime] NULL,
 CONSTRAINT [PK_Factura] PRIMARY KEY CLUSTERED 
(
	[Facturanumero] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Facturapos]

-- %%
/****** Object:  Table [dbo].[Facturapos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Facturapos](
	[IdFACTURAS] [int] IDENTITY(1,1) NOT NULL,
	[Resolucion] [nvarchar](50) NOT NULL,
	[Facturanumero] [int] NOT NULL,
	[Estado] [int] NULL,
	[Fechafac] [smalldatetime] NOT NULL,
	[Tipo] [nvarchar](50) NULL,
	[Cliente] [nvarchar](250) NULL,
	[Promotor] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Valortransporte] [int] NULL,
	[Formapago] [nvarchar](250) NULL,
	[Dias] [float] NOT NULL,
	[Vencimiento] [smalldatetime] NOT NULL,
	[Documento] [nvarchar](250) NULL,
	[Base] [int] NULL,
	[Adicion] [nvarchar](250) NULL,
	[Abono] [float] NULL,
	[Saldo] [float] NULL,
	[Medio] [nvarchar](250) NULL,
	[Bloque] [int] NULL,
	[Fecha solicitud] [smalldatetime] NULL,
	[OCC] [nvarchar](250) NULL,
	[Direntrega] [nvarchar](250) NULL,
	[Letras] [nvarchar](250) NULL,
	[PRetencion] [float] NULL,
	[PReteIca] [float] NULL,
	[Reteica] [float] NOT NULL,
	[PReteIva] [float] NULL,
	[ReteIva] [float] NOT NULL,
	[Fproceso] [smalldatetime] NULL,
	[TipoTarjeta] [nvarchar](250) NULL,
	[Banco] [nvarchar](250) NULL,
	[Numero] [float] NULL,
	[Billete] [int] NULL,
	[Vueltas] [int] NULL,
	[Control] [int] NULL,
	[Descarga] [nvarchar](250) NULL,
	[PFlete] [float] NULL,
	[Terminal] [int] NULL,
	[Cargar] [nvarchar](250) NULL,
	[FValidacion] [smalldatetime] NULL,
	[Banco2] [nvarchar](250) NULL,
	[Numero2] [float] NULL,
	[PDescuento] [float] NULL,
	[Centro costos] [nvarchar](50) NULL,
	[TRM] [float] NULL,
	[Us] [float] NULL,
	[Cupo] [int] NULL,
	[Diasvencimiento] [int] NULL,
	[Cartera] [int] NULL,
	[Edad] [int] NULL,
	[Tipotercero] [nvarchar](50) NULL,
	[Estadoter] [int] NULL,
	[Diferencia] [int] NULL,
	[Retencion] [int] NULL,
	[Destinatario] [nvarchar](50) NULL,
	[Direcdestino] [nvarchar](250) NULL,
	[Teldestino] [nvarchar](50) NULL,
	[Ciudestino] [nvarchar](50) NULL,
	[Declarado] [int] NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
	[ARetencion] [nvarchar](50) NULL,
	[Situacion] [nvarchar](50) NULL,
	[FechaEntrega] [smalldatetime] NULL,
	[LetrasDOL] [nvarchar](250) NULL,
	[Itinerario] [nvarchar](50) NULL,
	[TipoRetencion] [nvarchar](50) NULL,
	[Matrix] [int] NULL,
	[Concepto] [nvarchar](50) NULL,
	[Anticipos] [float] NOT NULL,
	[Sucursal] [nvarchar](50) NULL,
	[Remisiones] [nvarchar](50) NULL,
	[Pedidos] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[PUtilidadest] [float] NULL,
	[Utilidadest] [int] NULL,
	[DocumentoBL] [nvarchar](50) NULL,
	[DONo] [int] NULL,
	[Orige] [nvarchar](50) NULL,
	[Destin] [nvarchar](50) NULL,
	[Via] [nvarchar](50) NULL,
	[Imprevistos] [int] NULL,
	[Pimprevistos] [float] NULL,
	[Admon] [int] NULL,
	[PAdmon] [float] NULL,
	[Dimensiones] [nvarchar](50) NULL,
	[CIF] [int] NULL,
	[Status] [nvarchar](50) NULL,
	[Lista] [nvarchar](50) NULL,
	[ImpReteica] [int] NULL,
	[ImpReteiva] [int] NULL,
	[CantBolsas] [int] NULL,
	[ValBolsas] [int] NULL,
	[TipoMoneda] [nvarchar](50) NULL,
	[StatusDian] [int] NULL,
	[StatusCliente] [int] NULL,
	[RespuestaDian] [ntext] NULL,
	[FDian] [smalldatetime] NULL,
	[FCliente] [smalldatetime] NULL,
	[CUFE] [nvarchar](250) NULL,
	[Tipomail] [nvarchar](50) NULL,
	[Horafin] [smalldatetime] NULL,
	[ArchivoDian] [ntext] NULL,
	[TipoFactura] [nvarchar](50) NULL,
	[TipoOperacion] [nvarchar](50) NULL,
	[FacReferencia] [nvarchar](50) NULL,
	[FechaOrden] [smalldatetime] NULL,
	[Docu] [nvarchar](50) NULL,
	[RecajaNo] [int] NULL,
	[FechaRC] [smalldatetime] NULL,
 CONSTRAINT [PK_Facturapos] PRIMARY KEY CLUSTERED 
(
	[Resolucion] ASC,
	[Facturanumero] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Facturaposub]

-- %%
/****** Object:  Table [dbo].[Facturaposub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Facturaposub](
	[Idpedir] [int] IDENTITY(1,1) NOT NULL,
	[Resolucion] [nvarchar](50) NOT NULL,
	[Facturanumero] [int] NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
	[PIva] [float] NULL,
	[Descuento] [float] NULL,
	[Precio] [float] NULL,
	[Subtotal] [float] NULL,
	[Neto] [float] NULL,
	[Precio total] [float] NULL,
	[Exentos] [int] NULL,
	[DesExentos] [int] NULL,
	[DesGravados] [int] NULL,
	[Peso] [float] NULL,
	[VPropina] [int] NULL,
	[Controlfinal] [float] NULL,
	[Rebaja] [int] NULL,
	[Producto] [nvarchar](50) NULL,
	[Origen] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
	[Costo] [int] NULL,
	[Gastos] [int] NULL,
	[Medida] [int] NULL,
	[cod_naturaleza] [int] NULL,
	[cod_empaque] [int] NULL,
	[cod_producto] [nvarchar](50) NULL,
	[Notas] [nvarchar](250) NULL,
	[Serial] [nvarchar](250) NULL,
	[DO] [int] NULL,
	[Largo] [float] NULL,
	[Ancho] [float] NULL,
	[Alto] [float] NULL,
	[Volumen] [float] NULL,
	[Pimpoconsumo] [float] NULL,
	[ImpCon] [int] NULL,
	[Dolares] [float] NULL,
	[Costear] [float] NULL,
	[Detalle] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Placa] [nvarchar](50) NULL,
	[Remesa] [int] NULL,
	[PRete] [float] NULL,
	[Retencion] [float] NULL,
	[TipoRetencion] [nvarchar](50) NULL,
	[Manifiesto] [int] NULL,
	[Detalle2] [nvarchar](250) NULL,
	[Centrosuc] [nvarchar](50) NULL,
	[Cargado] [int] NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Cuota] [int] NULL,
	[Moneda] [nvarchar](50) NULL,
	[TRMS] [float] NULL,
	[Cree] [int] NULL,
	[Doc] [nvarchar](50) NULL,
	[Proveedor] [nvarchar](50) NULL,
	[PReteIcasub] [float] NULL,
	[ReteIcasub] [float] NULL,
 CONSTRAINT [PK_Facturaposub] PRIMARY KEY CLUSTERED 
(
	[Idpedir] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Facturasub]

-- %%
/****** Object:  Table [dbo].[Facturasub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Facturasub](
	[Idpedir] [int] IDENTITY(1,1) NOT NULL,
	[Facturanumero] [int] NOT NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
	[PIva] [float] NULL,
	[Descuento] [float] NULL,
	[Precio] [float] NULL,
	[Subtotal] [float] NULL,
	[Neto] [float] NULL,
	[Precio total] [float] NULL,
	[Exentos] [int] NULL,
	[DesExentos] [int] NULL,
	[DesGravados] [int] NULL,
	[Dolares] [float] NULL,
	[Costear] [float] NULL,
	[Peso] [float] NULL,
	[Detalle] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Placa] [nvarchar](250) NULL,
	[Remesa] [int] NULL,
	[VPropina] [int] NULL,
	[Controlfinal] [float] NULL,
	[Rebaja] [int] NULL,
	[PRete] [float] NULL,
	[Retencion] [float] NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[Manifiesto] [int] NULL,
	[Detalle2] [nvarchar](250) NULL,
	[DO] [int] NULL,
	[Origen] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
	[Centrosuc] [nvarchar](250) NULL,
	[Cargado] [int] NULL,
	[Cuota] [int] NULL,
	[Moneda] [nvarchar](50) NULL,
	[TRMS] [float] NULL,
	[Pimpoconsumo] [float] NULL,
	[ImpCon] [int] NULL,
	[Cree] [int] NULL,
	[Doc] [nvarchar](50) NULL,
	[Costo] [int] NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Proveedor] [nvarchar](50) NULL,
	[PReteIcasub] [float] NULL,
	[ReteIcasub] [float] NULL,
 CONSTRAINT [PK_Facturasub] PRIMARY KEY CLUSTERED 
(
	[Idpedir] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FCesantias]

-- %%
/****** Object:  Table [dbo].[FCesantias]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FCesantias](
	[idcesantias] [int] IDENTITY(1,1) NOT NULL,
	[FCesantias] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Tercero] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_FCesantias] PRIMARY KEY CLUSTERED 
(
	[FCesantias] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Flujo]

-- %%
/****** Object:  Table [dbo].[Flujo]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Flujo](
	[Idflujo] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](250) NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Tercero] [nvarchar](250) NULL,
	[Valor] [int] NULL,
	[Concepto] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Ejecucion] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Flujo] PRIMARY KEY CLUSTERED 
(
	[Idflujo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FlujoCaja]

-- %%
/****** Object:  Table [dbo].[FlujoCaja]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FlujoCaja](
	[IdFlujo] [int] IDENTITY(1,1) NOT NULL,
	[Finicial] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
	[FMostrador] [nvarchar](250) NULL,
	[FCredito] [nvarchar](250) NULL,
	[PEmpleados] [nvarchar](250) NULL,
	[PProveedores] [nvarchar](250) NULL,
	[PAdmonVentas] [nvarchar](250) NULL,
	[PFinancieros] [nvarchar](250) NULL,
	[PTxtIva] [nvarchar](250) NULL,
	[PTxtRetefuente] [nvarchar](250) NULL,
	[PTxtIca] [nvarchar](250) NULL,
	[RInversiones] [nvarchar](250) NULL,
	[Compra ppe] [nvarchar](250) NULL,
	[CompraInv] [nvarchar](250) NULL,
	[VentaInv] [nvarchar](250) NULL,
	[Emision] [nvarchar](250) NULL,
	[Nuevasobligaciones] [nvarchar](250) NULL,
	[Pagoobligacioneslp] [nvarchar](250) NULL,
	[Pagodividendos] [nvarchar](250) NULL,
	[Efectivo] [nvarchar](250) NULL,
 CONSTRAINT [PK_FlujoCaja] PRIMARY KEY CLUSTERED 
(
	[IdFlujo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Formapago]

-- %%
/****** Object:  Table [dbo].[Formapago]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Formapago](
	[Idpago] [int] IDENTITY(1,1) NOT NULL,
	[Formapago] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Codigo] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Formapago] PRIMARY KEY CLUSTERED 
(
	[Formapago] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Fortalezas]

-- %%
/****** Object:  Table [dbo].[Fortalezas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Fortalezas](
	[Idfortaleza] [int] IDENTITY(1,1) NOT NULL,
	[Codigofor] [int] NULL,
	[Materia] [nvarchar](250) NULL,
	[Periodo] [int] NULL,
	[Significad] [nvarchar](250) NULL,
	[Curso] [nvarchar](50) NULL,
	[Año] [int] NULL,
 CONSTRAINT [PK_Fortalezas] PRIMARY KEY CLUSTERED 
(
	[Idfortaleza] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Gasolina]

-- %%
/****** Object:  Table [dbo].[Gasolina]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Gasolina](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Documento] [nvarchar](50) NULL,
	[Placa] [nvarchar](50) NULL,
	[Conductor] [nvarchar](50) NULL,
	[Consumo] [int] NULL,
	[KmAnterior] [int] NULL,
	[KmNuevo] [int] NULL,
	[GalonesConsumo] [float] NULL,
	[VlrGalon] [int] NULL,
	[Total] [int] NULL,
	[Notas] [nvarchar](250) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Gasolina] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Grupo]

-- %%
/****** Object:  Table [dbo].[Grupo]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Grupo](
	[IdMarca] [int] IDENTITY(1,1) NOT NULL,
	[Marca] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Grupo] PRIMARY KEY CLUSTERED 
(
	[Marca] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Gruposub]

-- %%
/****** Object:  Table [dbo].[Gruposub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Gruposub](
	[IdSubgrupo] [int] IDENTITY(1,1) NOT NULL,
	[Subgrupo] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Orden] [int] NULL,
 CONSTRAINT [PK_Gruposub] PRIMARY KEY CLUSTERED 
(
	[Subgrupo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Guia]

-- %%
/****** Object:  Table [dbo].[Guia]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Guia](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Prefijo] [nvarchar](50) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Shpper] [nvarchar](50) NULL,
	[Consignatario] [nvarchar](50) NULL,
	[Agente] [nvarchar](50) NULL,
	[Agentecod] [nvarchar](50) NULL,
	[Aerosalida] [nvarchar](50) NULL,
	[Destino1] [nvarchar](50) NULL,
	[Transportador] [nvarchar](50) NULL,
	[Destino2] [nvarchar](50) NULL,
	[Transportador2] [nvarchar](50) NULL,
	[Destino3] [nvarchar](50) NULL,
	[Transportador3] [nvarchar](50) NULL,
	[Moneda] [nvarchar](50) NULL,
	[Cambio] [nvarchar](50) NULL,
	[Pesoprepago] [nvarchar](1) NULL,
	[Pesocollect] [nvarchar](1) NULL,
	[Otrosprepago] [nvarchar](1) NULL,
	[Otroscollect] [nvarchar](1) NULL,
	[DeclaraTransporte] [nvarchar](50) NULL,
	[DeclaraAduanas] [nvarchar](50) NULL,
	[Aerodestino] [nvarchar](50) NULL,
	[Asegurado] [nvarchar](50) NULL,
	[Manipulacion] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Numero] [int] NULL,
	[Docu] [nvarchar](50) NULL,
	[DO] [int] NULL,
	[Expedicion] [nvarchar](50) NULL,
	[Doctransporte] [nvarchar](50) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Tipo] [nvarchar](50) NULL,
	[Notify] [nvarchar](50) NULL,
	[Letras] [nvarchar](250) NULL,
	[Tipocarga] [ntext] NULL,
 CONSTRAINT [PK_Guia] PRIMARY KEY CLUSTERED 
(
	[Prefijo] ASC,
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Guiasub]

-- %%
/****** Object:  Table [dbo].[Guiasub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Guiasub](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Prefijo] [nvarchar](50) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Concepto] [nvarchar](50) NULL,
	[Tipo] [nvarchar](50) NULL,
	[Bultos] [int] NOT NULL,
	[Pbruto] [float] NOT NULL,
	[Medida] [nvarchar](50) NULL,
	[Ctarifa] [nvarchar](50) NULL,
	[Pesocobrar] [float] NOT NULL,
	[Tarifa] [float] NOT NULL,
	[Neto] [float] NOT NULL,
	[Impuestos] [float] NOT NULL,
	[Total] [float] NOT NULL,
	[Destino] [nvarchar](50) NULL,
 CONSTRAINT [PK_Guiasub] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Histoambito]

-- %%
/****** Object:  Table [dbo].[Histoambito]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Histoambito](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[CodAmbito] [nvarchar](50) NOT NULL,
	[ambito] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Histoambito] PRIMARY KEY CLUSTERED 
(
	[CodAmbito] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HistoClinica]

-- %%
/****** Object:  Table [dbo].[HistoClinica]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HistoClinica](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[HistoriaNo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Tercero] [nvarchar](50) NULL,
	[Sintomas] [nvarchar](250) NULL,
	[Diagnostico] [nvarchar](250) NULL,
	[Receta] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Elaborado] [nvarchar](50) NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Edad] [int] NULL,
	[Administradora] [nvarchar](50) NULL,
 CONSTRAINT [PK_HistoClinica] PRIMARY KEY CLUSTERED 
(
	[HistoriaNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HistoClinicasub]

-- %%
/****** Object:  Table [dbo].[HistoClinicasub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HistoClinicasub](
	[idcontrol] [int] NOT NULL,
	[HistoriaNo] [int] NOT NULL,
	[Referencia] [nvarchar](50) NOT NULL,
	[numAutorizacion] [nvarchar](50) NULL,
	[codProce] [nvarchar](50) NULL,
	[ambito] [nvarchar](50) NULL,
	[finalidad] [nvarchar](50) NULL,
	[personal] [nvarchar](50) NULL,
	[diagnostico] [nvarchar](250) NULL,
	[dxrelacionado] [nvarchar](50) NULL,
	[complicacion] [nvarchar](50) NULL,
	[formaRealizacion] [nvarchar](50) NULL,
	[valorProce] [int] NULL,
	[Estadosub] [int] NULL,
	[Factura] [int] NULL,
	[Cantidad] [float] NULL,
	[Precio] [float] NULL,
 CONSTRAINT [PK_HistoClinicasub] PRIMARY KEY CLUSTERED 
(
	[idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Histofinalidad]

-- %%
/****** Object:  Table [dbo].[Histofinalidad]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Histofinalidad](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[CodFinalidad] [nvarchar](50) NOT NULL,
	[finalidad] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Histofinalidad] PRIMARY KEY CLUSTERED 
(
	[CodFinalidad] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Histoprocedimiento]

-- %%
/****** Object:  Table [dbo].[Histoprocedimiento]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Histoprocedimiento](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[CodProcedimiento] [nvarchar](50) NOT NULL,
	[Procedimiento] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Histoprocedimiento] PRIMARY KEY CLUSTERED 
(
	[CodProcedimiento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HistoTipouser]

-- %%
/****** Object:  Table [dbo].[HistoTipouser]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HistoTipouser](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[CodTipo] [nvarchar](50) NOT NULL,
	[Tipo] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_HistoTipouser] PRIMARY KEY CLUSTERED 
(
	[CodTipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Identificacion]

-- %%
/****** Object:  Table [dbo].[Identificacion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Identificacion](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Nombre del proyecto] [nvarchar](50) NULL,
	[Necesidad] [nvarchar](250) NULL,
	[Solucion] [nvarchar](250) NULL,
	[Objetivo general] [nvarchar](250) NULL,
	[Estrategia] [nvarchar](250) NULL,
	[Misión] [nvarchar](250) NULL,
	[Visión] [nvarchar](250) NULL,
	[Valores corporativos] [nvarchar](250) NULL,
	[Socios] [nvarchar](250) NULL,
	[Cedula] [nvarchar](250) NULL,
	[Experiencia] [nvarchar](250) NULL,
	[Tipo de organización] [nvarchar](50) NULL,
	[Ciudad de domicilio] [nvarchar](50) NULL,
	[Dirección] [nvarchar](50) NULL,
	[Teléfonos] [nvarchar](50) NULL,
	[Fecha de iniciación] [nvarchar](250) NULL,
 CONSTRAINT [PK_Identificacion] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Indicadores]

-- %%
/****** Object:  Table [dbo].[Indicadores]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Indicadores](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Idindicador] [int] NOT NULL,
	[Indicador] [nvarchar](50) NULL,
 CONSTRAINT [PK_Indicadores] PRIMARY KEY CLUSTERED 
(
	[Idindicador] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Indicadoresub1]

-- %%
/****** Object:  Table [dbo].[Indicadoresub1]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Indicadoresub1](
	[Idindicadorsub] [int] IDENTITY(1,1) NOT NULL,
	[Idindicador] [int] NULL,
	[Cuenta] [nvarchar](250) NULL,
 CONSTRAINT [PK_Indicadoresub1] PRIMARY KEY CLUSTERED 
(
	[Idindicadorsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Indicadoresub2]

-- %%
/****** Object:  Table [dbo].[Indicadoresub2]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Indicadoresub2](
	[Idindicadorsub] [int] IDENTITY(1,1) NOT NULL,
	[Idindicador] [int] NULL,
	[Cuenta] [nvarchar](250) NULL,
 CONSTRAINT [PK_Indicadoresub2] PRIMARY KEY CLUSTERED 
(
	[Idindicadorsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Iniciales]

-- %%
/****** Object:  Table [dbo].[Iniciales]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Iniciales](
	[IdIniciales] [int] IDENTITY(1,1) NOT NULL,
	[Fechafac] [smalldatetime] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Cliente] [nvarchar](250) NULL,
	[Facturanumero] [int] NOT NULL,
	[Neto] [int] NULL,
	[Centro Costos] [nvarchar](250) NULL,
	[Promotor] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[IdControl] [int] NOT NULL,
	[Documento] [nvarchar](50) NULL,
	[Dias] [int] NULL,
	[Us] [float] NULL,
	[Iva] [int] NULL,
	[Anteiva] [int] NULL,
	[Resolucion] [nvarchar](50) NULL,
 CONSTRAINT [PK_Iniciales] PRIMARY KEY CLUSTERED 
(
	[Facturanumero] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Iniciales28]

-- %%
/****** Object:  Table [dbo].[Iniciales28]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Iniciales28](
	[IdIniciales] [int] IDENTITY(1,1) NOT NULL,
	[IdControl] [int] NULL,
	[Fechafdoc] [smalldatetime] NULL,
	[Facturanumero] [int] NULL,
	[Cliente] [nvarchar](250) NULL,
	[Neto] [int] NULL,
	[Centro Costos] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[BLNO] [nvarchar](250) NULL,
	[Contenedor] [nvarchar](250) NULL,
	[US] [float] NULL,
 CONSTRAINT [PK_Iniciales28] PRIMARY KEY CLUSTERED 
(
	[IdIniciales] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InicialescEnc]

-- %%
/****** Object:  Table [dbo].[InicialescEnc]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InicialescEnc](
	[IdControl] [int] NOT NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_InicialescEnc] PRIMARY KEY CLUSTERED 
(
	[IdControl] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Inicialescontenedores]

-- %%
/****** Object:  Table [dbo].[Inicialescontenedores]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Inicialescontenedores](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Documento] [nvarchar](50) NULL,
 CONSTRAINT [PK_Inicialescontenedores] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Inicialescontenedoresub]

-- %%
/****** Object:  Table [dbo].[Inicialescontenedoresub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Inicialescontenedoresub](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Recalada] [int] NULL,
	[BL] [nvarchar](50) NULL,
	[Contenedor] [nvarchar](50) NULL,
	[Cantidad] [int] NULL,
	[Origen] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
	[Situacion] [nvarchar](50) NULL,
	[Notas] [nvarchar](250) NULL,
	[FEntrada] [smalldatetime] NULL,
 CONSTRAINT [PK_Inicialescontenedoresub] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InicialesCXP]

-- %%
/****** Object:  Table [dbo].[InicialesCXP]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InicialesCXP](
	[IdIniciales] [int] IDENTITY(1,1) NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Proveedor] [nvarchar](250) NOT NULL,
	[Factura] [int] NOT NULL,
	[Neto] [int] NULL,
	[Concepto] [nvarchar](250) NULL,
	[IdControl] [int] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Documento] [nvarchar](50) NULL,
	[Dias] [int] NULL,
	[Us] [float] NULL,
 CONSTRAINT [PK_InicialesCXP] PRIMARY KEY CLUSTERED 
(
	[Proveedor] ASC,
	[Factura] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InicialesEncCXP]

-- %%
/****** Object:  Table [dbo].[InicialesEncCXP]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InicialesEncCXP](
	[IdControl] [int] NOT NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_InicialesEncCXP] PRIMARY KEY CLUSTERED 
(
	[IdControl] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InicialesInventario]

-- %%
/****** Object:  Table [dbo].[InicialesInventario]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InicialesInventario](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[IdIniciaIn] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Situacion] [nvarchar](250) NULL,
	[Marca] [nvarchar](50) NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Tercero] [nvarchar](50) NULL,
	[Tipo] [nvarchar](50) NULL,
 CONSTRAINT [PK_InicialesInventario] PRIMARY KEY CLUSTERED 
(
	[IdIniciaIn] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InicialesInventariosub]

-- %%
/****** Object:  Table [dbo].[InicialesInventariosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InicialesInventariosub](
	[IdIniciaInventariosub] [int] IDENTITY(1,1) NOT NULL,
	[IdIniciaIn] [int] NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
	[Costo] [float] NULL,
	[CostoTotal] [int] NULL,
	[Peso] [float] NULL,
	[CentroCostos] [nvarchar](250) NULL,
	[Serial] [nvarchar](250) NULL,
	[Precio] [float] NULL,
	[PrecioTotal] [int] NULL,
	[Ubicacion] [nvarchar](250) NULL,
	[Controlfinal] [float] NULL,
 CONSTRAINT [PK_InicialesInventariosub] PRIMARY KEY CLUSTERED 
(
	[IdIniciaInventariosub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InicialesMPrima]

-- %%
/****** Object:  Table [dbo].[InicialesMPrima]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InicialesMPrima](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[IdIniciaIn] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[CentroCostos] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Situacion] [nvarchar](50) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Proveedor] [nvarchar](250) NULL,
	[OPNo] [int] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Regimen] [nvarchar](50) NULL,
	[Nofacturap] [int] NULL,
 CONSTRAINT [PK_InicialesMPrima] PRIMARY KEY CLUSTERED 
(
	[IdIniciaIn] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InicialesMPrimasub]

-- %%
/****** Object:  Table [dbo].[InicialesMPrimasub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InicialesMPrimasub](
	[IdIniciaInventariosub] [int] IDENTITY(1,1) NOT NULL,
	[IdIniciaIn] [int] NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
	[Costo] [float] NULL,
	[CostoTotal] [decimal](18, 0) NULL,
	[Peso] [float] NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[OProduccion] [int] NULL,
	[Controlfinal] [float] NULL,
	[Viable] [int] NULL,
 CONSTRAINT [PK_InicialesMPrimasub] PRIMARY KEY CLUSTERED 
(
	[IdIniciaInventariosub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InicialesMPrimaterminado]

-- %%
/****** Object:  Table [dbo].[InicialesMPrimaterminado]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InicialesMPrimaterminado](
	[IdIniciaInventariosub] [int] IDENTITY(1,1) NOT NULL,
	[IdIniciaIn] [int] NULL,
	[Referencia] [nvarchar](250) NULL,
	[Cantidad] [float] NULL,
	[Costo] [float] NULL,
	[CostoTotal] [int] NULL,
	[Peso] [float] NULL,
	[CentroCostos] [nvarchar](50) NULL,
	[Serial] [nvarchar](250) NULL,
	[PesoSIN] [float] NULL,
 CONSTRAINT [PK_InicialesMPrimaterminado] PRIMARY KEY CLUSTERED 
(
	[IdIniciaInventariosub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InicialesTesoreria]

-- %%
/****** Object:  Table [dbo].[InicialesTesoreria]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InicialesTesoreria](
	[IdTeso] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Estado] [int] NULL,
	[Documento] [nvarchar](50) NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
 CONSTRAINT [PK_InicialesTesoreria] PRIMARY KEY CLUSTERED 
(
	[IdTeso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InicialesTesoreriasub]

-- %%
/****** Object:  Table [dbo].[InicialesTesoreriasub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InicialesTesoreriasub](
	[IdCheques] [int] IDENTITY(1,1) NOT NULL,
	[IdTeso] [int] NOT NULL,
	[TipoMedio] [nvarchar](250) NULL,
	[NCheque] [int] NULL,
	[Banco] [nvarchar](250) NULL,
	[Girado] [int] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Situacion] [nvarchar](250) NULL,
 CONSTRAINT [PK_InicialesTesoreriasub] PRIMARY KEY CLUSTERED 
(
	[IdCheques] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Inversion]

-- %%
/****** Object:  Table [dbo].[Inversion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Inversion](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Proyecto] [nvarchar](250) NULL,
	[Otros] [nvarchar](250) NULL,
	[ValorO] [int] NULL,
 CONSTRAINT [PK_Inversion] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Jornada]

-- %%
/****** Object:  Table [dbo].[Jornada]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Jornada](
	[Idjornada] [int] IDENTITY(1,1) NOT NULL,
	[Jornada] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
 CONSTRAINT [PK_Jornada] PRIMARY KEY CLUSTERED 
(
	[Jornada] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Know1]

-- %%
/****** Object:  Table [dbo].[Know1]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Know1](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Tema] [nvarchar](50) NULL,
	[Resumen] [nvarchar](250) NULL,
	[Problema] [ntext] NULL,
	[Solucion] [ntext] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Status] [nvarchar](50) NULL,
	[RutaVideo] [ntext] NULL,
 CONSTRAINT [PK_Know1] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[KnowAudita]

-- %%
/****** Object:  Table [dbo].[KnowAudita]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[KnowAudita](
	[IdAuditoria] [int] IDENTITY(1,1) NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Hora] [smalldatetime] NULL,
	[Nombre] [nvarchar](50) NULL,
	[Tema] [nvarchar](50) NULL,
	[Comprobante] [int] NULL,
	[Cantidad] [int] NULL,
 CONSTRAINT [PK_KnowAudita] PRIMARY KEY CLUSTERED 
(
	[IdAuditoria] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[KnowIdeas]

-- %%
/****** Object:  Table [dbo].[KnowIdeas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[KnowIdeas](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Tema] [nvarchar](50) NULL,
	[Resumen] [nvarchar](250) NULL,
	[Problema] [ntext] NULL,
	[Solucion] [ntext] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Status] [nvarchar](50) NULL,
 CONSTRAINT [PK_KnowIdeas] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[KnowStatus]

-- %%
/****** Object:  Table [dbo].[KnowStatus]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[KnowStatus](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_KnowStatus] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[KnowTipo]

-- %%
/****** Object:  Table [dbo].[KnowTipo]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[KnowTipo](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Notas] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_KnowTipo] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Legalizaciones]

-- %%
/****** Object:  Table [dbo].[Legalizaciones]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Legalizaciones](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Documento] [nvarchar](50) NULL,
	[CD] [int] NULL,
	[Anticipo] [int] NULL,
	[Estado] [int] NULL,
	[Tercero] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Idcausacion] [int] NULL,
 CONSTRAINT [PK_Legalizaciones] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Legalizacionesub]

-- %%
/****** Object:  Table [dbo].[Legalizacionesub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Legalizacionesub](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Docu] [nvarchar](50) NULL,
	[Comprobante] [int] NULL,
	[Neto] [int] NULL,
 CONSTRAINT [PK_Legalizacionesub] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Liquidacion final]

-- %%
/****** Object:  Table [dbo].[Liquidacion final]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Liquidacion final](
	[Idparnomina] [int] NULL,
	[Idliquida] [int] IDENTITY(1,1) NOT NULL,
	[Cedula] [nvarchar](50) NULL,
	[IdLiquidacion final] [float] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Iniciacion] [smalldatetime] NULL,
	[Finalizacion] [smalldatetime] NULL,
	[Salario básico] [float] NULL,
	[Auxilio transporte] [float] NULL,
	[Dias trabajados] [float] NULL,
	[Horario de trabajo] [nvarchar](50) NULL,
	[Prima] [int] NULL,
	[Vacaciones] [float] NULL,
	[Indemnizacion] [float] NULL,
	[Cesantia] [int] NULL,
	[ICesantia] [int] NULL,
	[TPrima] [int] NULL,
	[TVacaciones] [int] NULL,
	[TCesantia] [int] NULL,
	[TICesantia] [int] NULL,
	[TIndemnizacion] [int] NULL,
	[TPagar] [int] NULL,
	[Documento] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Diasvaca] [float] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Descuentos] [int] NULL,
	[Neto] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[ProCesantia] [int] NULL,
	[ProInteres] [int] NULL,
	[ProPrima] [int] NULL,
	[ProVacaciones] [int] NULL,
	[ProSalud] [int] NULL,
	[ProPension] [int] NULL,
	[ProCaja] [int] NULL,
	[ProFamiliar] [int] NULL,
	[ProSena] [int] NULL,
	[Estado] [int] NULL,
	[Finidisfrute] [smalldatetime] NULL,
	[Ffindisfrute] [smalldatetime] NULL,
	[Finicio] [smalldatetime] NULL,
	[FRetiro] [smalldatetime] NULL,
	[Tipovac] [nvarchar](50) NULL,
	[Tipoempleado] [nvarchar](50) NULL,
	[DTotal] [int] NULL,
 CONSTRAINT [PK_Liquidacion final] PRIMARY KEY CLUSTERED 
(
	[IdLiquidacion final] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LiquidafleteDO]

-- %%
/****** Object:  Table [dbo].[LiquidafleteDO]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LiquidafleteDO](
	[idliquida] [int] IDENTITY(1,1) NOT NULL,
	[Nliquidacion] [int] NULL,
	[DO] [int] NULL,
 CONSTRAINT [PK_LiquidafleteDO] PRIMARY KEY CLUSTERED 
(
	[idliquida] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LiquidaFletes]

-- %%
/****** Object:  Table [dbo].[LiquidaFletes]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LiquidaFletes](
	[IdLiquida] [int] IDENTITY(1,1) NOT NULL,
	[Nliquida] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Nombre] [nvarchar](250) NULL,
	[Por1] [float] NULL,
	[Desc1] [int] NULL,
	[Por2] [float] NULL,
	[Desc2] [int] NULL,
	[Por3] [float] NULL,
	[Desc3] [int] NULL,
	[Por4] [float] NULL,
	[Desc4] [int] NULL,
	[Total] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Documento] [nvarchar](50) NULL,
	[Con1] [nvarchar](50) NULL,
	[Con2] [nvarchar](50) NULL,
	[Con3] [nvarchar](50) NULL,
	[Con4] [nvarchar](50) NULL,
	[Letras] [nvarchar](250) NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Situacion] [nvarchar](50) NULL,
	[Dias] [int] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[TipoRetencion] [nvarchar](50) NULL,
	[Concepto] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Us] [float] NULL,
	[Gtotal] [int] NULL,
	[Anticipo] [int] NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
 CONSTRAINT [PK_LiquidaFletes] PRIMARY KEY CLUSTERED 
(
	[Nliquida] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Liquidafletessub]

-- %%
/****** Object:  Table [dbo].[Liquidafletessub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Liquidafletessub](
	[idliquidasub] [int] IDENTITY(1,1) NOT NULL,
	[Nliquida] [int] NOT NULL,
	[Manifiesto] [int] NULL,
	[Flete] [int] NULL,
	[Retencion] [int] NULL,
	[ReteIca] [int] NULL,
	[Anticipo] [int] NULL,
	[Neto] [int] NULL,
	[Origen] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
	[Despactados] [int] NULL,
	[Remesa] [int] NULL,
	[PRetefuente] [float] NULL,
	[PReteica] [float] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Placa] [nvarchar](50) NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Doc] [nvarchar](50) NULL,
	[TransferNo] [int] NULL,
 CONSTRAINT [PK_Liquidafletessub] PRIMARY KEY CLUSTERED 
(
	[idliquidasub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Llamadas]

-- %%
/****** Object:  Table [dbo].[Llamadas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Llamadas](
	[IdLlamadas] [int] IDENTITY(1,1) NOT NULL,
	[Estado] [int] NULL,
	[Fecha] [smalldatetime] NULL,
	[Tipo] [nvarchar](250) NULL,
	[Nombre] [nvarchar](250) NULL,
	[Empresa] [nvarchar](250) NULL,
	[Telefono] [nvarchar](250) NULL,
	[Asesor] [nvarchar](250) NULL,
	[Cita] [smalldatetime] NULL,
	[Hora] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Régimen] [nvarchar](250) NULL,
	[Direccion] [nvarchar](250) NULL,
	[Antiguo] [nvarchar](250) NULL,
 CONSTRAINT [PK_Llamadas] PRIMARY KEY CLUSTERED 
(
	[IdLlamadas] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Llamadaster]

-- %%
/****** Object:  Table [dbo].[Llamadaster]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Llamadaster](
	[IdProspectos] [int] IDENTITY(1,1) NOT NULL,
	[Identificacion] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Direccion] [nvarchar](250) NULL,
	[Telefono] [nvarchar](50) NULL,
	[Celular] [nvarchar](50) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Situacion] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Email] [nvarchar](250) NULL,
	[Contacto] [nvarchar](250) NULL,
	[Ciudad] [nvarchar](250) NULL,
	[Clase] [nvarchar](50) NULL,
	[Promotor] [nvarchar](50) NULL,
 CONSTRAINT [PK_Llamadaster] PRIMARY KEY CLUSTERED 
(
	[Identificacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Magneticos]

-- %%
/****** Object:  Table [dbo].[Magneticos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Magneticos](
	[Idmedios] [int] IDENTITY(1,1) NOT NULL,
	[Finicial] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
	[Cuenta1] [nvarchar](50) NULL,
	[Cuenta2] [nvarchar](50) NULL,
	[Cuenta3] [nvarchar](50) NULL,
	[Cuenta4] [nvarchar](50) NULL,
	[Cuenta5] [nvarchar](50) NULL,
	[Cuenta6] [nvarchar](50) NULL,
	[Cuenta7] [nvarchar](50) NULL,
	[Cuenta8] [nvarchar](50) NULL,
	[Cuenta9] [nvarchar](50) NULL,
	[BasePago] [int] NULL,
	[LimiteIng] [int] NULL,
	[Cuenta10] [nvarchar](50) NULL,
	[Cuenta11] [nvarchar](50) NULL,
	[Cuenta12] [nvarchar](50) NULL,
	[Cuenta13] [nvarchar](50) NULL,
	[Cuenta14] [nvarchar](50) NULL,
	[LimiteIng2] [int] NULL,
	[DesBsSv] [nvarchar](50) NULL,
	[OpSimp] [nvarchar](50) NULL,
	[DevAnuladas] [nvarchar](50) NULL,
	[SvNodom] [nvarchar](50) NULL,
	[Reteiva] [nvarchar](50) NULL,
	[Cuenta21] [nvarchar](50) NULL,
	[Cuenta22] [nvarchar](50) NULL,
	[Cuenta23] [nvarchar](50) NULL,
	[Cuenta24] [nvarchar](50) NULL,
	[Cuenta25] [nvarchar](50) NULL,
	[Cuenta26] [nvarchar](50) NULL,
	[Cuenta27] [nvarchar](50) NULL,
	[Cuenta28] [nvarchar](50) NULL,
	[Cuenta29] [nvarchar](50) NULL,
	[Cuenta30] [nvarchar](50) NULL,
	[Cuenta31] [nvarchar](50) NULL,
	[Cuenta32] [nvarchar](50) NULL,
 CONSTRAINT [PK_Magneticos] PRIMARY KEY CLUSTERED 
(
	[Idmedios] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Magneticos2]

-- %%
/****** Object:  Table [dbo].[Magneticos2]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Magneticos2](
	[idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Cuenta] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Magneticos2] PRIMARY KEY CLUSTERED 
(
	[Cuenta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Manifiesto]

-- %%
/****** Object:  Table [dbo].[Manifiesto]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Manifiesto](
	[idCargue] [int] IDENTITY(1,1) NOT NULL,
	[ManifiestoNo] [int] NOT NULL,
	[Ciudad] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Conductor] [nvarchar](50) NULL,
	[Placa] [nvarchar](250) NULL,
	[Estado] [nvarchar](50) NULL,
	[Flete] [int] NULL,
	[PRetefuente] [float] NULL,
	[Retefuente] [int] NULL,
	[Descuentos] [int] NULL,
	[FleteNuevo] [int] NULL,
	[Anticipo] [int] NULL,
	[Neto] [int] NULL,
	[Egreso] [int] NULL,
	[LugarSaldo] [nvarchar](250) NULL,
	[FechaSaldo] [smalldatetime] NULL,
	[PagoCargue] [nvarchar](250) NULL,
	[PagoDescargue] [nvarchar](250) NULL,
	[CiaSeguro] [nvarchar](250) NULL,
	[PolizaNo] [nvarchar](250) NULL,
	[VigenciaPoliza] [smalldatetime] NULL,
	[Letras] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[Vencimiento] [smalldatetime] NULL,
	[SOAT] [smalldatetime] NULL,
	[LicConductor] [smalldatetime] NULL,
	[PReteIca] [float] NULL,
	[DFinal] [nvarchar](250) NULL,
	[Dias] [int] NULL,
	[Situacion] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Propietario] [nvarchar](50) NULL,
	[Tenedor] [nvarchar](50) NULL,
	[Terminal] [int] NULL,
	[Despactados] [int] NULL,
	[PDesc] [float] NULL,
	[FProceso] [smalldatetime] NULL,
	[Ruta1] [nvarchar](50) NULL,
	[Ruta2] [nvarchar](50) NULL,
	[Kilometros] [int] NULL,
	[MinisterioNo] [int] NULL,
	[Firma] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Us] [float] NULL,
	[Origen] [nvarchar](250) NULL,
	[MotAnula] [nvarchar](50) NULL,
	[Semiremolque] [nvarchar](250) NULL,
	[EstSigueme] [int] NULL,
	[AgenciaEnc] [nvarchar](50) NULL,
	[Via] [nvarchar](50) NULL,
	[Seguridad] [nvarchar](50) NULL,
	[ObservacionesMinTrans] [nvarchar](50) NULL,
 CONSTRAINT [PK_Manifiesto] PRIMARY KEY CLUSTERED 
(
	[ManifiestoNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Manifiestosub]

-- %%
/****** Object:  Table [dbo].[Manifiestosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Manifiestosub](
	[IdCarguesub] [int] IDENTITY(1,1) NOT NULL,
	[ManifiestoNo] [int] NOT NULL,
	[Cantidad] [float] NULL,
	[Medida] [int] NULL,
	[Peso] [float] NULL,
	[num_remesa] [int] NULL,
	[cod_naturaleza] [int] NULL,
	[cod_empaque] [int] NULL,
	[cod_producto] [nvarchar](50) NULL,
	[Producto] [nvarchar](250) NULL,
	[Remitente] [nvarchar](25) NULL,
	[Destinatario] [nvarchar](250) NULL,
	[Destino] [nvarchar](250) NULL,
	[Anticipo] [int] NULL,
	[DO] [int] NULL,
	[Costo] [int] NULL,
	[MerAsegurada] [nvarchar](250) NULL,
	[TomadorSeg] [nvarchar](250) NULL,
	[Origensub] [nvarchar](50) NULL,
	[CiaSegurosub] [nvarchar](50) NULL,
	[Polizasub] [nvarchar](50) NULL,
	[DirecOrigen] [nvarchar](250) NULL,
	[DirecDestino] [nvarchar](250) NULL,
	[Propietariosub] [nvarchar](50) NULL,
	[Dueñopoliza] [nvarchar](50) NULL,
	[Vencipoliza] [smalldatetime] NULL,
	[SedeOrigen] [nvarchar](50) NULL,
	[SedeDestino] [nvarchar](50) NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Riesgo] [nvarchar](50) NULL,
 CONSTRAINT [PK_Manifiestosub] PRIMARY KEY CLUSTERED 
(
	[IdCarguesub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Mantenimiento]

-- %%
/****** Object:  Table [dbo].[Mantenimiento]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Mantenimiento](
	[IdMantenimiento] [int] IDENTITY(1,1) NOT NULL,
	[NoMantenimiento] [int] NOT NULL,
	[Maquina] [int] NULL,
	[Fecha] [smalldatetime] NULL,
	[HorometroEnc] [int] NULL,
	[Observaciones] [nvarchar](255) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Mantenimiento] PRIMARY KEY CLUSTERED 
(
	[NoMantenimiento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Mantenimientosub]

-- %%
/****** Object:  Table [dbo].[Mantenimientosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Mantenimientosub](
	[idmantenimientosub] [int] IDENTITY(1,1) NOT NULL,
	[NoMantenimiento] [int] NOT NULL,
	[Componente] [int] NULL,
	[Cantidad] [int] NULL,
	[Neto] [int] NULL,
	[Realizado] [nvarchar](50) NULL,
	[Autorizado] [nvarchar](50) NULL,
 CONSTRAINT [PK_Mantenimientosub] PRIMARY KEY CLUSTERED 
(
	[idmantenimientosub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Materias]

-- %%
/****** Object:  Table [dbo].[Materias]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Materias](
	[Idcolegios] [int] IDENTITY(1,1) NOT NULL,
	[Materia] [nvarchar](200) NOT NULL,
	[Curso] [nvarchar](200) NOT NULL,
	[Area] [nvarchar](250) NULL,
	[Profesor] [nvarchar](250) NULL,
	[Intensidad] [nvarchar](250) NULL,
 CONSTRAINT [PK_Materias] PRIMARY KEY CLUSTERED 
(
	[Materia] ASC,
	[Curso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Matrix]

-- %%
/****** Object:  Table [dbo].[Matrix]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Matrix](
	[IdFACTURAS] [int] IDENTITY(1,1) NOT NULL,
	[Factura] [int] NOT NULL,
	[Estado] [int] NULL,
	[Fechafac] [smalldatetime] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Cliente] [nvarchar](250) NULL,
	[Promotor] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Valortransporte] [int] NULL,
	[Formapago] [nvarchar](250) NULL,
	[Dias] [float] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Documento] [nvarchar](250) NULL,
	[Saldo] [int] NULL,
	[Medio] [nvarchar](250) NULL,
	[Bloque] [int] NULL,
	[Centro costos] [nvarchar](250) NULL,
	[Letras] [nvarchar](250) NULL,
	[PReteIca] [float] NULL,
	[Reteica] [int] NULL,
	[PReteIva] [float] NULL,
	[ReteIva] [int] NULL,
	[Fproceso] [smalldatetime] NULL,
	[Situacion] [nvarchar](250) NULL,
	[FechaEntrega] [smalldatetime] NULL,
	[PDescuento] [float] NULL,
	[TRM] [float] NULL,
	[LetrasDOL] [nvarchar](250) NULL,
	[Itinerario] [nvarchar](250) NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[Cupo] [int] NULL,
	[Diasvencimiento] [int] NULL,
	[Cartera] [int] NULL,
	[Edad] [int] NULL,
	[Estadoter] [int] NULL,
	[Descarga] [nvarchar](250) NULL,
	[Matrix] [int] NULL,
	[PFlete] [float] NULL,
	[Terminal] [int] NULL,
	[Cargar] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[FValidacion] [smalldatetime] NULL,
	[Diferencia] [int] NULL,
	[PRetencion] [float] NULL,
	[Anticipos] [int] NULL,
	[ARetencion] [nvarchar](50) NULL,
	[TipoTercero] [nvarchar](50) NULL,
 CONSTRAINT [PK_Matrix] PRIMARY KEY CLUSTERED 
(
	[Factura] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MatrixNomina]

-- %%
/****** Object:  Table [dbo].[MatrixNomina]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MatrixNomina](
	[Idparnomina] [int] NULL,
	[Documento] [nvarchar](250) NULL,
	[Periodo] [int] NULL,
	[Idnomina] [int] NOT NULL,
	[Cedula] [nvarchar](50) NULL,
	[Fecha] [smalldatetime] NULL,
	[Fecha inicial] [smalldatetime] NULL,
	[Fecha final] [smalldatetime] NULL,
	[Días trabajados] [float] NULL,
	[HEDO] [float] NULL,
	[HENO] [float] NULL,
	[HEDF] [float] NULL,
	[HENF] [float] NULL,
	[RN] [float] NULL,
	[Otrosdevengados] [int] NULL,
	[Otrasdeducciones] [int] NULL,
	[Notas] [nvarchar](250) NULL,
	[Basico] [int] NULL,
	[TDO] [int] NULL,
	[TNO] [int] NULL,
	[TDF] [int] NULL,
	[TNF] [int] NULL,
	[TRN] [int] NULL,
	[Auxilio] [int] NULL,
	[TDevengado] [int] NULL,
	[Aportesalud] [int] NULL,
	[Aportepension] [int] NULL,
	[FondoSP] [int] NULL,
	[Retefuente] [int] NULL,
	[TDeducido] [int] NULL,
	[Netopagado] [int] NULL,
	[ProCesantia] [int] NULL,
	[ProInteres] [int] NULL,
	[ProPrima] [int] NULL,
	[ProVacaciones] [int] NULL,
	[ProSalud] [int] NULL,
	[ProPension] [int] NULL,
	[ProCaja] [int] NULL,
	[ProFamiliar] [int] NULL,
	[ProSena] [int] NULL,
	[ProRiesgos] [int] NULL,
	[ProParafiscales] [int] NULL,
	[Horas] [float] NULL,
	[Fproceso] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Extraordinaria] [int] NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[Otrosdescuentos] [int] NULL,
	[Otra] [int] NULL,
	[Tipoempleado] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_MatrixNomina_1] PRIMARY KEY CLUSTERED 
(
	[Idnomina] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Matrixsub]

-- %%
/****** Object:  Table [dbo].[Matrixsub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Matrixsub](
	[Idpedir] [int] IDENTITY(1,1) NOT NULL,
	[Factura] [int] NOT NULL,
	[Cantidad] [float] NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Descuento] [float] NULL,
	[Precio] [float] NULL,
	[PIva] [float] NULL,
	[Precio total] [int] NULL,
	[Neto] [int] NULL,
	[Subtotal] [int] NULL,
	[Exentos] [int] NULL,
	[DesExentos] [int] NULL,
	[DesGravados] [int] NULL,
	[Dolares] [float] NULL,
	[Costear] [float] NULL,
	[Peso] [float] NULL,
	[Detalle] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Placa] [nvarchar](250) NULL,
	[Remesa] [int] NULL,
	[VPropina] [int] NULL,
	[Controlfinal] [int] NULL,
	[Rebaja] [int] NULL,
	[Base] [int] NULL,
	[PRete] [float] NULL,
	[Retencion] [int] NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[Manifiesto] [int] NULL,
	[Detalle2] [nvarchar](250) NULL,
	[DO] [int] NULL,
	[Origen] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
 CONSTRAINT [PK_Matrixsub] PRIMARY KEY CLUSTERED 
(
	[Idpedir] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Mercadeo]

-- %%
/****** Object:  Table [dbo].[Mercadeo]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Mercadeo](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[IdMercadeo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Prospecto] [nvarchar](50) NULL,
	[Resultado] [nvarchar](250) NULL,
	[NuevaFecha] [smalldatetime] NULL,
	[Estado] [int] NULL,
	[Terminal] [int] NULL,
	[Responsable] [nvarchar](250) NULL,
	[Documento] [nvarchar](50) NULL,
	[Cliente] [nvarchar](50) NULL,
	[Contacto] [nvarchar](50) NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Sucursal] [nvarchar](50) NULL,
	[Ultima] [smalldatetime] NULL,
	[Novedad] [nvarchar](50) NULL,
 CONSTRAINT [PK_Mercadeo] PRIMARY KEY CLUSTERED 
(
	[IdMercadeo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Meses]

-- %%
/****** Object:  Table [dbo].[Meses]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Meses](
	[IdMeses] [int] IDENTITY(1,1) NOT NULL,
	[codigo] [int] NOT NULL,
	[mes] [nvarchar](250) NULL,
 CONSTRAINT [PK_Meses] PRIMARY KEY CLUSTERED 
(
	[codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MinCombinaciones]

-- %%
/****** Object:  Table [dbo].[MinCombinaciones]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MinCombinaciones](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[codvehiculo] [nvarchar](50) NULL,
	[codsemiremolque] [nvarchar](50) NULL,
	[namevehiculo] [nvarchar](50) NULL,
	[namesemiremolque] [nvarchar](50) NULL,
	[descvehiculo] [nvarchar](50) NULL,
	[descsemiremolque] [nvarchar](50) NULL,
	[codcombinacion] [nvarchar](50) NULL,
	[Unido] [nvarchar](50) NULL,
 CONSTRAINT [PK_MinCombinaciones] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MinConfiguracion]

-- %%
/****** Object:  Table [dbo].[MinConfiguracion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MinConfiguracion](
	[IdCodigo] [int] NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Descripcion] [nvarchar](250) NULL,
	[Tipo] [nvarchar](50) NULL,
 CONSTRAINT [PK_MinConfiguracion] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MinEmpaque]

-- %%
/****** Object:  Table [dbo].[MinEmpaque]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MinEmpaque](
	[IdCodigo] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [int] NOT NULL,
	[Descripcion] [nvarchar](250) NULL,
 CONSTRAINT [PK_MinEmpaque] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MinMDependencias]

-- %%
/****** Object:  Table [dbo].[MinMDependencias]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MinMDependencias](
	[IdCodigo] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [int] NOT NULL,
	[Descripcion] [nvarchar](250) NULL,
 CONSTRAINT [PK_MinMDependencias] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MinMedida]

-- %%
/****** Object:  Table [dbo].[MinMedida]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MinMedida](
	[IdCodigo] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [int] NOT NULL,
	[Descripcion] [nvarchar](250) NULL,
 CONSTRAINT [PK_MinMedida] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MinMmarca]

-- %%
/****** Object:  Table [dbo].[MinMmarca]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MinMmarca](
	[IdCodigo] [int] IDENTITY(1,1) NOT NULL,
	[Marca] [nvarchar](50) NOT NULL,
	[Linea] [int] NOT NULL,
	[Descripcion] [nvarchar](250) NULL,
 CONSTRAINT [PK_MinMmarca] PRIMARY KEY CLUSTERED 
(
	[Marca] ASC,
	[Linea] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MinMotivoanula]

-- %%
/****** Object:  Table [dbo].[MinMotivoanula]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MinMotivoanula](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Descripcion] [nvarchar](50) NULL,
 CONSTRAINT [PK_MinMotivoanula] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MinMproduct]

-- %%
/****** Object:  Table [dbo].[MinMproduct]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MinMproduct](
	[IdCodigo] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Descripcion] [ntext] NULL,
	[TipoProducto] [nvarchar](250) NULL,
 CONSTRAINT [PK_MinMproduct] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MinMticarroceria]

-- %%
/****** Object:  Table [dbo].[MinMticarroceria]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MinMticarroceria](
	[IdCodigo] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [int] NOT NULL,
	[Descripcion] [nvarchar](250) NULL,
 CONSTRAINT [PK_MinMticarroceria] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MinMtima]

-- %%
/****** Object:  Table [dbo].[MinMtima]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MinMtima](
	[IdCodigo] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Codigo] [nvarchar](250) NOT NULL,
	[Descripcion] [nvarchar](250) NULL,
 CONSTRAINT [PK_MinMtima] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC,
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MinNaturaleza]

-- %%
/****** Object:  Table [dbo].[MinNaturaleza]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MinNaturaleza](
	[IdCodigo] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [int] NOT NULL,
	[Descripcion] [nvarchar](250) NULL,
 CONSTRAINT [PK_MinNaturaleza] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MinNcolp]

-- %%
/****** Object:  Table [dbo].[MinNcolp]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MinNcolp](
	[IdCodigo] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [int] NOT NULL,
	[Descripcion] [nvarchar](250) NULL,
 CONSTRAINT [PK_MinNcolp] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MinRutas]

-- %%
/****** Object:  Table [dbo].[MinRutas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MinRutas](
	[IdRuta] [int] IDENTITY(1,1) NOT NULL,
	[CodigoRuta] [nvarchar](50) NOT NULL,
	[Origen] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
	[Nombre] [nvarchar](50) NULL,
	[Kilometros] [int] NULL,
	[ValorTonelada] [int] NULL,
 CONSTRAINT [PK_MinRutas] PRIMARY KEY CLUSTERED 
(
	[CodigoRuta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ModificaValor]

-- %%
/****** Object:  Table [dbo].[ModificaValor]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ModificaValor](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[ManifiestoNo] [int] NOT NULL,
	[Cantidad] [int] NULL,
	[Total] [int] NULL,
	[PRetefte] [float] NULL,
	[Retefuente] [int] NULL,
	[PReteica] [float] NULL,
	[ReteIca] [int] NULL,
	[Neto] [int] NULL,
	[Anticipo] [int] NULL,
	[Saldo] [int] NULL,
	[FPago] [smalldatetime] NULL,
	[Lugar] [nvarchar](50) NULL,
	[Letras] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Documento] [nvarchar](50) NULL,
 CONSTRAINT [PK_ModificaValor] PRIMARY KEY CLUSTERED 
(
	[ManifiestoNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Modos]

-- %%
/****** Object:  Table [dbo].[Modos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Modos](
	[Idmodos] [int] IDENTITY(1,1) NOT NULL,
	[Modo] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
 CONSTRAINT [PK_Modos] PRIMARY KEY CLUSTERED 
(
	[Modo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Mostrador]

-- %%
/****** Object:  Table [dbo].[Mostrador]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Mostrador](
	[IdFACTURAS] [int] IDENTITY(1,1) NOT NULL,
	[Resolucion] [nvarchar](50) NOT NULL,
	[Facturanumero] [int] NOT NULL,
	[Estado] [int] NULL,
	[Fechafac] [smalldatetime] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Cliente] [nvarchar](250) NULL,
	[Promotor] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Valortransporte] [int] NULL,
	[Formapago] [nvarchar](250) NULL,
	[Dias] [float] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Documento] [nvarchar](250) NULL,
	[Base] [int] NULL,
	[Adicion] [nvarchar](250) NULL,
	[Abono] [float] NULL,
	[Saldo] [float] NULL,
	[Medio] [nvarchar](250) NULL,
	[Bloque] [int] NULL,
	[Fecha solicitud] [smalldatetime] NULL,
	[OCC] [nvarchar](250) NULL,
	[Direntrega] [nvarchar](250) NULL,
	[Letras] [nvarchar](250) NULL,
	[PRetencion] [float] NULL,
	[PReteIca] [float] NULL,
	[Reteica] [float] NULL,
	[PReteIva] [float] NULL,
	[ReteIva] [float] NULL,
	[Fproceso] [smalldatetime] NULL,
	[TipoTarjeta] [nvarchar](250) NULL,
	[Banco] [nvarchar](250) NULL,
	[Numero] [float] NULL,
	[Billete] [int] NULL,
	[Vueltas] [int] NULL,
	[Control] [int] NULL,
	[Descarga] [nvarchar](250) NULL,
	[PFlete] [float] NULL,
	[Terminal] [int] NULL,
	[Cargar] [nvarchar](250) NULL,
	[FValidacion] [smalldatetime] NULL,
	[Banco2] [nvarchar](250) NULL,
	[Numero2] [float] NULL,
	[PDescuento] [float] NULL,
	[Centro costos] [nvarchar](50) NULL,
	[TRM] [float] NULL,
	[Us] [float] NULL,
	[Cupo] [int] NULL,
	[Diasvencimiento] [int] NULL,
	[Cartera] [int] NULL,
	[Edad] [int] NULL,
	[Tipotercero] [nvarchar](50) NULL,
	[Estadoter] [int] NULL,
	[Diferencia] [int] NULL,
	[Retencion] [int] NULL,
	[Destinatario] [nvarchar](50) NULL,
	[Direcdestino] [nvarchar](250) NULL,
	[Teldestino] [nvarchar](50) NULL,
	[Ciudestino] [nvarchar](50) NULL,
	[Declarado] [int] NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
	[ARetencion] [nvarchar](50) NULL,
	[Situacion] [nvarchar](50) NULL,
	[FechaEntrega] [smalldatetime] NULL,
	[LetrasDOL] [nvarchar](250) NULL,
	[Itinerario] [nvarchar](50) NULL,
	[TipoRetencion] [nvarchar](50) NULL,
	[Matrix] [int] NULL,
	[Concepto] [nvarchar](50) NULL,
	[Anticipos] [float] NULL,
	[Sucursal] [nvarchar](50) NULL,
	[Remisiones] [nvarchar](50) NULL,
	[Pedidos] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[PUtilidadest] [float] NULL,
	[Utilidadest] [int] NULL,
	[DocumentoBL] [nvarchar](50) NULL,
	[DONo] [int] NULL,
	[Orige] [nvarchar](50) NULL,
	[Destin] [nvarchar](50) NULL,
	[Via] [nvarchar](50) NULL,
	[Imprevistos] [int] NULL,
	[Pimprevistos] [float] NULL,
	[Admon] [int] NULL,
	[PAdmon] [float] NULL,
	[Dimensiones] [nvarchar](50) NULL,
	[CIF] [int] NULL,
	[Status] [nvarchar](50) NULL,
	[Lista] [nvarchar](50) NULL,
	[ImpReteica] [int] NULL,
	[ImpReteiva] [int] NULL,
	[CantBolsas] [int] NULL,
	[ValBolsas] [int] NULL,
	[TipoMoneda] [nvarchar](50) NULL,
	[StatusDian] [int] NULL,
	[StatusCliente] [int] NULL,
	[RespuestaDian] [ntext] NULL,
	[FDian] [smalldatetime] NULL,
	[FCliente] [smalldatetime] NULL,
	[CUFE] [nvarchar](250) NULL,
	[Tipomail] [nvarchar](50) NULL,
	[Horafin] [smalldatetime] NULL,
	[ArchivoDian] [ntext] NULL,
	[TipoFactura] [nvarchar](50) NULL,
	[TipoOperacion] [nvarchar](50) NULL,
	[FacReferencia] [nvarchar](50) NULL,
	[FechaOrden] [smalldatetime] NULL,
	[Docu] [nvarchar](50) NULL,
	[RecajaNo] [int] NULL,
	[FechaRC] [smalldatetime] NULL,
 CONSTRAINT [PK_Mostrador] PRIMARY KEY CLUSTERED 
(
	[Resolucion] ASC,
	[Facturanumero] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Mostradorinsumos]

-- %%
/****** Object:  Table [dbo].[Mostradorinsumos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Mostradorinsumos](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[idpedir] [int] NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Factura] [int] NULL,
	[Referencia] [nvarchar](250) NULL,
	[Insumo] [nvarchar](250) NULL,
	[Cantidad] [float] NULL,
	[Peso] [float] NULL,
	[CantidadRef] [float] NULL,
 CONSTRAINT [PK_Mostradorinsumos] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Mostradorsub]

-- %%
/****** Object:  Table [dbo].[Mostradorsub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Mostradorsub](
	[Idpedir] [int] IDENTITY(1,1) NOT NULL,
	[Resolucion] [nvarchar](50) NOT NULL,
	[Facturanumero] [int] NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
	[Descuento] [float] NULL,
	[PIva] [float] NULL,
	[Precio] [float] NULL,
	[Subtotal] [float] NULL,
	[Neto] [float] NULL,
	[Precio total] [float] NULL,
	[Exentos] [int] NULL,
	[DesExentos] [int] NULL,
	[DesGravados] [int] NULL,
	[Peso] [float] NULL,
	[VPropina] [int] NULL,
	[Controlfinal] [float] NULL,
	[Rebaja] [int] NULL,
	[Producto] [nvarchar](50) NULL,
	[Origen] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
	[Costo] [int] NULL,
	[Gastos] [int] NULL,
	[Medida] [int] NULL,
	[cod_naturaleza] [int] NULL,
	[cod_empaque] [int] NULL,
	[cod_producto] [nvarchar](50) NULL,
	[Notas] [nvarchar](250) NULL,
	[Serial] [nvarchar](250) NULL,
	[DO] [int] NULL,
	[Largo] [float] NULL,
	[Ancho] [float] NULL,
	[Alto] [float] NULL,
	[Volumen] [float] NULL,
	[Pimpoconsumo] [float] NULL,
	[ImpCon] [int] NULL,
	[Dolares] [float] NULL,
	[Costear] [float] NULL,
	[Detalle] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Placa] [nvarchar](50) NULL,
	[Remesa] [int] NULL,
	[PRete] [float] NULL,
	[Retencion] [float] NULL,
	[TipoRetencion] [nvarchar](50) NULL,
	[Manifiesto] [int] NULL,
	[Detalle2] [nvarchar](250) NULL,
	[Centrosuc] [nvarchar](50) NULL,
	[Cargado] [int] NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Cuota] [int] NULL,
	[Moneda] [nvarchar](50) NULL,
	[TRMS] [float] NULL,
	[Cree] [int] NULL,
	[Doc] [nvarchar](50) NULL,
	[Proveedor] [nvarchar](50) NULL,
	[PReteIcasub] [float] NULL,
	[ReteIcasub] [float] NULL,
 CONSTRAINT [PK_Mostradorsub] PRIMARY KEY CLUSTERED 
(
	[Idpedir] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Multimodal]

-- %%
/****** Object:  Table [dbo].[Multimodal]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Multimodal](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[TipoOperacion] [nvarchar](50) NULL,
	[DONo] [int] NULL,
	[FacturaNo] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Transportador] [nvarchar](50) NULL,
	[Frecogida] [smalldatetime] NULL,
	[Fentrega] [smalldatetime] NULL,
	[Fingreso] [smalldatetime] NULL,
	[Fsalida] [smalldatetime] NULL,
	[Farribo] [smalldatetime] NULL,
	[DocTransporte] [nvarchar](50) NULL,
	[Fdoctransporte] [smalldatetime] NULL,
	[Proveedor] [nvarchar](50) NULL,
	[VlrAsegurado] [int] NULL,
 CONSTRAINT [PK_Multimodal] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NCredito]

-- %%
/****** Object:  Table [dbo].[NCredito]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NCredito](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Idncredito] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Nombre] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[Elaboro] [nvarchar](250) NULL,
	[Aprobo] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[Tipo] [nvarchar](250) NULL,
	[Facturanumero] [int] NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Reteica] [int] NULL,
	[ReteIva] [int] NULL,
	[Retefuente] [int] NULL,
	[Neto] [int] NULL,
	[Fproceso] [smalldatetime] NULL,
	[PRetencion] [float] NULL,
	[PReteIca] [float] NULL,
	[PReteIva] [float] NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[Terminal] [int] NULL,
	[Descarga] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Idplan] [int] NULL,
	[Us] [float] NULL,
	[TRM] [float] NULL,
	[Docu] [nvarchar](50) NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
	[ARetencion] [nvarchar](50) NULL,
	[Resolucion] [nvarchar](50) NULL,
	[TipoMoneda] [nvarchar](50) NULL,
	[StatusDian] [int] NULL,
	[StatusCliente] [int] NULL,
	[RespuestaDian] [ntext] NULL,
	[FDian] [smalldatetime] NULL,
	[FCliente] [smalldatetime] NULL,
	[CUDE] [nvarchar](250) NULL,
	[Horafin] [smalldatetime] NULL,
	[Codconcepto] [nvarchar](50) NULL,
	[ArchivoDian] [ntext] NULL,
	[TipoFactura] [nvarchar](50) NULL,
	[TipoOperacion] [nvarchar](50) NULL,
 CONSTRAINT [PK_NCredito] PRIMARY KEY CLUSTERED 
(
	[Idncredito] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NCreditoPos]

-- %%
/****** Object:  Table [dbo].[NCreditoPos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NCreditoPos](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Resolucion] [nvarchar](50) NOT NULL,
	[Idncreditopos] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Nombre] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[Elaboro] [nvarchar](250) NULL,
	[Aprobo] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[Tipo] [nvarchar](250) NULL,
	[Facturanumero] [int] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Reteica] [int] NULL,
	[ReteIva] [int] NULL,
	[Retefuente] [int] NULL,
	[Neto] [int] NULL,
	[Fproceso] [smalldatetime] NULL,
	[Terminal] [int] NULL,
	[Descarga] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Docu] [nvarchar](50) NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
	[Retencion] [int] NULL,
	[ImpReteica] [int] NULL,
	[ImpReteiva] [int] NULL,
	[PRetencion] [float] NULL,
	[PReteIca] [float] NULL,
	[PReteIva] [float] NULL,
	[TipoMoneda] [nvarchar](50) NULL,
	[StatusDian] [int] NULL,
	[StatusCliente] [int] NULL,
	[RespuestaDian] [ntext] NULL,
	[FDian] [smalldatetime] NULL,
	[FCliente] [smalldatetime] NULL,
	[CUDE] [nvarchar](250) NULL,
	[Horafin] [smalldatetime] NULL,
	[Codconcepto] [nvarchar](50) NULL,
	[ArchivoDian] [ntext] NULL,
	[TipoFactura] [nvarchar](50) NULL,
	[TipoOperacion] [nvarchar](50) NULL,
	[Us] [float] NULL,
	[TRM] [float] NULL,
 CONSTRAINT [PK_NCreditoPos] PRIMARY KEY CLUSTERED 
(
	[Resolucion] ASC,
	[Idncreditopos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NCreditoproveedores]

-- %%
/****** Object:  Table [dbo].[NCreditoproveedores]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NCreditoproveedores](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Idncreditopro] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Nombre] [nvarchar](250) NULL,
	[Concepto] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Aprobo] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Nofacturap] [int] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Reteica] [int] NULL,
	[ReteIva] [int] NULL,
	[Retefuente] [int] NULL,
	[Neto] [int] NULL,
	[Fproceso] [smalldatetime] NULL,
	[TipoRetencion] [nvarchar](50) NULL,
	[DO] [int] NULL,
	[Descarga] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Regimen] [nvarchar](50) NULL,
	[Us] [float] NULL,
	[TRM] [float] NULL,
	[PRetencion] [float] NULL,
	[PReteIca] [float] NULL,
	[PReteIva] [float] NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
	[Prefijo] [nvarchar](50) NULL,
 CONSTRAINT [PK_NCreditoproveedores] PRIMARY KEY CLUSTERED 
(
	[Idncreditopro] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NCreditoproveedoresub]

-- %%
/****** Object:  Table [dbo].[NCreditoproveedoresub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NCreditoproveedoresub](
	[Idndesub] [int] IDENTITY(1,1) NOT NULL,
	[Idncreditopro] [int] NOT NULL,
	[Referencia] [nvarchar](250) NULL,
	[PIva] [float] NULL,
	[Cantidad] [float] NULL,
	[Precio total] [int] NULL,
	[Neto] [int] NULL,
	[Descuento] [float] NULL,
	[Precio] [float] NULL,
	[Peso] [float] NULL,
	[Subtotal] [int] NULL,
	[DO] [int] NULL,
	[PRete] [float] NULL,
	[Retencion] [int] NULL,
	[VPropina] [int] NULL,
 CONSTRAINT [PK_NCreditoproveedoresub] PRIMARY KEY CLUSTERED 
(
	[Idndesub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NCreditosub]

-- %%
/****** Object:  Table [dbo].[NCreditosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NCreditosub](
	[Idncresub] [int] IDENTITY(1,1) NOT NULL,
	[Idncredito] [int] NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
	[Descuento] [float] NULL,
	[PIva] [float] NULL,
	[Precio] [float] NULL,
	[Subtotal] [float] NULL,
	[Neto] [float] NULL,
	[Precio total] [float] NULL,
	[Peso] [float] NULL,
	[DO] [int] NULL,
	[Pimpoconsumo] [float] NULL,
	[ImpCon] [int] NULL,
	[PRete] [float] NULL,
	[Retencion] [int] NULL,
	[VPropina] [int] NULL,
	[Cree] [int] NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Costo] [int] NULL,
	[Proveedor] [nvarchar](50) NULL,
 CONSTRAINT [PK_NCreditosub] PRIMARY KEY CLUSTERED 
(
	[Idncresub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NCreditosubPos]

-- %%
/****** Object:  Table [dbo].[NCreditosubPos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NCreditosubPos](
	[Idncresub] [int] IDENTITY(1,1) NOT NULL,
	[Resolucion] [nvarchar](50) NOT NULL,
	[Idncreditopos] [int] NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
	[Descuento] [float] NULL,
	[PIva] [float] NULL,
	[Precio] [float] NULL,
	[Subtotal] [float] NULL,
	[Neto] [float] NULL,
	[Precio total] [float] NULL,
	[Peso] [float] NULL,
	[DO] [int] NULL,
	[Pimpoconsumo] [float] NULL,
	[ImpCon] [int] NULL,
	[VPropina] [int] NULL,
	[Cree] [int] NULL,
	[PRete] [float] NULL,
	[Retencion] [int] NULL,
	[Costo] [int] NULL,
	[Proveedor] [nvarchar](50) NULL,
 CONSTRAINT [PK_NCreditosubPos] PRIMARY KEY CLUSTERED 
(
	[Idncresub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NDebito]

-- %%
/****** Object:  Table [dbo].[NDebito]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NDebito](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Idndebito] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Nombre] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[Elaboro] [nvarchar](250) NULL,
	[Aprobo] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[Nofacturap] [int] NULL,
	[Tipo] [nvarchar](250) NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Reteica] [int] NULL,
	[ReteIva] [int] NULL,
	[Retefuente] [int] NULL,
	[Neto] [int] NULL,
	[Fproceso] [smalldatetime] NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[DO] [int] NULL,
	[Descarga] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Regimen] [nvarchar](50) NULL,
	[TRM] [float] NULL,
	[Us] [float] NULL,
	[PRetencion] [float] NULL,
	[PReteIca] [float] NULL,
	[PReteIva] [float] NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
	[Prefijo] [nvarchar](50) NULL,
 CONSTRAINT [PK_NDebito] PRIMARY KEY CLUSTERED 
(
	[Idndebito] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NDebitoClientes]

-- %%
/****** Object:  Table [dbo].[NDebitoClientes]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NDebitoClientes](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Idncredito] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Nombre] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[Elaboro] [nvarchar](250) NULL,
	[Aprobo] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[Tipo] [nvarchar](250) NULL,
	[Facturanumero] [int] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Reteica] [int] NULL,
	[ReteIva] [int] NULL,
	[Retefuente] [int] NULL,
	[Neto] [int] NULL,
	[Fproceso] [smalldatetime] NULL,
	[PRetencion] [float] NULL,
	[PReteIca] [float] NULL,
	[PReteIva] [float] NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[Terminal] [int] NULL,
	[Descarga] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Idplan] [int] NULL,
	[Us] [float] NULL,
	[TRM] [float] NULL,
	[Docu] [nvarchar](50) NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
	[ARetencion] [nvarchar](50) NULL,
	[Resolucion] [nvarchar](50) NULL,
	[TipoMoneda] [nvarchar](50) NULL,
	[StatusDian] [int] NULL,
	[StatusCliente] [int] NULL,
	[RespuestaDian] [ntext] NULL,
	[FDian] [smalldatetime] NULL,
	[FCliente] [smalldatetime] NULL,
	[CUDE] [nvarchar](250) NULL,
	[Horafin] [smalldatetime] NULL,
	[Codconcepto] [nvarchar](50) NULL,
	[ArchivoDian] [ntext] NULL,
	[TipoFactura] [nvarchar](50) NULL,
	[TipoOperacion] [nvarchar](50) NULL,
 CONSTRAINT [PK_NDebitoClientes] PRIMARY KEY CLUSTERED 
(
	[Idncredito] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NDebitoClientesub]

-- %%
/****** Object:  Table [dbo].[NDebitoClientesub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NDebitoClientesub](
	[Idncresub] [int] IDENTITY(1,1) NOT NULL,
	[Idncredito] [int] NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
	[PIva] [float] NULL,
	[Precio] [float] NULL,
	[Subtotal] [float] NULL,
	[Neto] [float] NULL,
	[Precio total] [float] NULL,
	[Descuento] [float] NULL,
	[Peso] [int] NULL,
	[DO] [int] NULL,
	[Controlfinal] [float] NULL,
	[Notas] [nvarchar](250) NULL,
	[Pimpoconsumo] [float] NULL,
	[ImpCon] [int] NULL,
	[PRete] [float] NULL,
	[Retencion] [int] NULL,
	[VPropina] [int] NULL,
	[Cree] [int] NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Costo] [int] NULL,
	[Proveedor] [nvarchar](50) NULL,
 CONSTRAINT [PK_NDebitoClientesub] PRIMARY KEY CLUSTERED 
(
	[Idncresub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NDebitosub]

-- %%
/****** Object:  Table [dbo].[NDebitosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NDebitosub](
	[Idndesub] [int] IDENTITY(1,1) NOT NULL,
	[Idndebito] [int] NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[PIva] [float] NULL,
	[Cantidad] [float] NULL,
	[Precio total] [int] NULL,
	[Neto] [int] NULL,
	[Descuento] [float] NULL,
	[Precio] [float] NULL,
	[Peso] [float] NULL,
	[Subtotal] [int] NULL,
	[DO] [int] NULL,
	[PRete] [float] NULL,
	[Retencion] [int] NULL,
	[VPropina] [int] NULL,
 CONSTRAINT [PK_NDebitosub] PRIMARY KEY CLUSTERED 
(
	[Idndesub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Negocios]

-- %%
/****** Object:  Table [dbo].[Negocios]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Negocios](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Cliente] [nvarchar](50) NULL,
	[Usuario] [nvarchar](50) NULL,
	[Solicitud] [ntext] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Notas] [ntext] NULL,
	[Status] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[FStatus] [smalldatetime] NULL,
 CONSTRAINT [PK_Negocios] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NifCuentas]

-- %%
/****** Object:  Table [dbo].[NifCuentas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NifCuentas](
	[IdCuentas] [int] IDENTITY(1,1) NOT NULL,
	[NúmCuenta] [nvarchar](50) NOT NULL,
	[NombreCuenta] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Estado] [int] NULL,
	[Imputable] [nvarchar](50) NULL,
	[ConceptoM] [nvarchar](50) NULL,
	[Deducible] [nvarchar](50) NULL,
	[Tributario] [nvarchar](50) NULL,
	[Nota] [int] NULL,
 CONSTRAINT [PK_NifCuentas] PRIMARY KEY CLUSTERED 
(
	[NúmCuenta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NifDeterioro]

-- %%
/****** Object:  Table [dbo].[NifDeterioro]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NifDeterioro](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Documento] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Niif] [nvarchar](50) NULL,
	[Local] [nvarchar](50) NULL,
 CONSTRAINT [PK_NifDeterioro] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NifDeteriorosub]

-- %%
/****** Object:  Table [dbo].[NifDeteriorosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NifDeteriorosub](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Docu] [nvarchar](50) NULL,
	[Aplicacion] [int] NULL,
	[Tercero] [nvarchar](50) NULL,
	[Saldo] [int] NULL,
	[Edad] [int] NULL,
	[Dcausados] [int] NULL,
	[Dajuste] [int] NULL,
	[Ajuste] [int] NULL,
	[Idplan] [int] NULL,
	[Resolucion] [nvarchar](50) NULL,
 CONSTRAINT [PK_NifDeteriorosub] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NifInteres]

-- %%
/****** Object:  Table [dbo].[NifInteres]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NifInteres](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Documento] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Niif] [nvarchar](50) NULL,
	[Local] [nvarchar](50) NULL,
 CONSTRAINT [PK_NifInteres] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NifInteresub]

-- %%
/****** Object:  Table [dbo].[NifInteresub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NifInteresub](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Docu] [nvarchar](50) NULL,
	[Aplicacion] [int] NULL,
	[Tercero] [nvarchar](50) NULL,
	[Saldo] [int] NULL,
	[Edad] [int] NULL,
	[Dcausados] [int] NULL,
	[Dajuste] [int] NULL,
	[Ajuste] [int] NULL,
	[Idplan] [int] NULL,
	[Resolucion] [nvarchar](50) NULL,
 CONSTRAINT [PK_NifInteresub] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nifpar]

-- %%
/****** Object:  Table [dbo].[Nifpar]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nifpar](
	[idpar] [int] IDENTITY(1,1) NOT NULL,
	[Tema] [nvarchar](50) NOT NULL,
	[Cuenta] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Nifpar] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC,
	[Cuenta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NifRangos]

-- %%
/****** Object:  Table [dbo].[NifRangos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NifRangos](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[inicio] [int] NULL,
	[final] [int] NULL,
	[Tasa] [float] NULL,
 CONSTRAINT [PK_Table_1] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NifRangosInt]

-- %%
/****** Object:  Table [dbo].[NifRangosInt]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NifRangosInt](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[inicio] [int] NULL,
	[final] [int] NULL,
	[Tasa] [float] NULL,
 CONSTRAINT [PK_NifRangosInt] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NifReversion]

-- %%
/****** Object:  Table [dbo].[NifReversion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NifReversion](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Ajustedebito] [nvarchar](50) NULL,
	[Ajuestecredito] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Idcausacion] [int] NULL,
	[Estado] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[CD] [int] NULL,
 CONSTRAINT [PK_NifReversion] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nifreversionsub]

-- %%
/****** Object:  Table [dbo].[Nifreversionsub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nifreversionsub](
	[iddeteriorosub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Docu] [nvarchar](50) NULL,
	[Aplicacion] [int] NULL,
	[Tercero] [nvarchar](50) NULL,
	[Saldo] [int] NULL,
 CONSTRAINT [PK_Nifreversionsub] PRIMARY KEY CLUSTERED 
(
	[iddeteriorosub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NiifRevelaciones]

-- %%
/****** Object:  Table [dbo].[NiifRevelaciones]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NiifRevelaciones](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Nota] [int] NULL,
	[Observaciones] [text] NULL,
	[Estado] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Reporte] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
 CONSTRAINT [PK_NiifRevelaciones] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nomina]

-- %%
/****** Object:  Table [dbo].[Nomina]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nomina](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Idparnomina] [int] NOT NULL,
	[Documento] [nvarchar](250) NULL,
	[Idnomina] [int] NOT NULL,
	[Cedula] [nvarchar](50) NULL,
	[Fecha] [smalldatetime] NULL,
	[Fecha inicial] [smalldatetime] NULL,
	[Fecha final] [smalldatetime] NULL,
	[Días trabajados] [float] NULL,
	[HEDO] [float] NULL,
	[HENO] [float] NULL,
	[HEDF] [float] NULL,
	[HENF] [float] NULL,
	[RN] [float] NULL,
	[Otrosdevengados] [int] NULL,
	[Otrasdeducciones] [int] NULL,
	[Notas] [nvarchar](250) NULL,
	[Basico] [int] NULL,
	[TDO] [int] NULL,
	[TNO] [int] NULL,
	[TDF] [int] NULL,
	[TNF] [int] NULL,
	[TRN] [int] NULL,
	[Auxilio] [int] NULL,
	[TDevengado] [int] NULL,
	[Aportesalud] [int] NULL,
	[Aportepension] [int] NULL,
	[FondoSP] [int] NULL,
	[Retefuente] [int] NULL,
	[TDeducido] [int] NULL,
	[Netopagado] [int] NULL,
	[ProCesantia] [int] NULL,
	[ProInteres] [int] NULL,
	[ProPrima] [int] NULL,
	[ProVacaciones] [int] NULL,
	[ProSalud] [int] NULL,
	[ProPension] [int] NULL,
	[ProCaja] [int] NULL,
	[ProFamiliar] [int] NULL,
	[ProSena] [int] NULL,
	[ProRiesgos] [int] NULL,
	[ProParafiscales] [int] NULL,
	[Horas] [float] NULL,
	[Fproceso] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Extraordinaria] [int] NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[Otrosdescuentos] [int] NULL,
	[Otra] [int] NULL,
	[Situacion] [nvarchar](50) NULL,
	[Tipoempleado] [nvarchar](50) NULL,
	[Incapacidad] [int] NULL,
	[diasincapacidad] [float] NULL,
	[Estado] [int] NULL,
	[Us] [float] NULL,
	[Diastrans] [float] NULL,
	[Diasvaca] [float] NULL,
	[Vaca] [int] NULL,
	[HEF] [float] NULL,
	[TF] [int] NULL,
	[BaseSalud] [int] NULL,
	[BasePension] [int] NULL,
	[BaseCaja] [int] NULL,
	[BaseParafiscal] [int] NULL,
	[BaseRiesgos] [int] NULL,
	[ing] [nvarchar](1) NULL,
	[ret] [nvarchar](1) NULL,
	[tde] [nvarchar](1) NULL,
	[tae] [nvarchar](1) NULL,
	[tdp] [nvarchar](1) NULL,
	[tap] [nvarchar](1) NULL,
	[vsp] [nvarchar](1) NULL,
	[cor] [nvarchar](1) NULL,
	[vst] [nvarchar](1) NULL,
	[sln] [nvarchar](1) NULL,
	[ige] [nvarchar](1) NULL,
	[lma] [nvarchar](1) NULL,
	[vac] [nvarchar](1) NULL,
	[avp] [nvarchar](1) NULL,
	[vct] [nvarchar](1) NULL,
	[irp] [nvarchar](1) NULL,
	[vip] [nvarchar](1) NULL,
	[Procedimiento] [nvarchar](50) NULL,
	[ApvolPension] [int] NULL,
	[ApvolSalud] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Prefijo] [nvarchar](50) NULL,
	[Consecutivo] [int] NULL,
	[TRM] [float] NULL,
	[Formapago] [nvarchar](50) NULL,
	[Medio] [nvarchar](50) NULL,
	[FechaPago] [smalldatetime] NULL,
	[HRNDF] [float] NULL,
	[THRNDF] [int] NULL,
	[StatusDian] [int] NULL,
	[FDian] [smalldatetime] NULL,
	[StatusCliente] [int] NULL,
	[FCliente] [smalldatetime] NULL,
	[ArchivoDian] [ntext] NULL,
	[RespuestaDian] [ntext] NULL,
	[CUNE] [ntext] NULL,
	[LicenciaNR] [int] NULL,
	[Diasalud] [int] NULL,
	[Diapension] [int] NULL,
	[LicenciaRem] [int] NULL,
	[TipoVaca] [nvarchar](50) NULL,
	[DiasPrimas] [int] NULL,
	[Primas] [int] NULL,
	[PagoCesantias] [int] NULL,
	[PorcentajeCesantias] [int] NULL,
	[PagoInteresesCesantias] [int] NULL,
	[Indemnizacion] [int] NULL,
 CONSTRAINT [PK_Nomina] PRIMARY KEY CLUSTERED 
(
	[Idnomina] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaCandidatos]

-- %%
/****** Object:  Table [dbo].[NominaCandidatos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaCandidatos](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Celular] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Correo] [nvarchar](50) NULL,
	[Edad] [int] NULL,
	[Direccion] [nvarchar](50) NULL,
	[Zona] [nvarchar](50) NULL,
	[Profesion] [nvarchar](50) NULL,
	[Experiencia] [nvarchar](250) NULL,
	[Notas] [ntext] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[RutaHV] [nvarchar](250) NULL,
 CONSTRAINT [PK_NominaCandidatos] PRIMARY KEY CLUSTERED 
(
	[Celular] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaCargo]

-- %%
/****** Object:  Table [dbo].[NominaCargo]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaCargo](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Cargo] [nvarchar](50) NOT NULL,
	[Departamento] [nvarchar](50) NULL,
	[Salario] [int] NULL,
	[Notas] [ntext] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_NominaCargo] PRIMARY KEY CLUSTERED 
(
	[Cargo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaCargodes]

-- %%
/****** Object:  Table [dbo].[NominaCargodes]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaCargodes](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Definicion] [ntext] NULL,
	[Roles] [ntext] NULL,
 CONSTRAINT [PK_NominaCargodes] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaCargofun]

-- %%
/****** Object:  Table [dbo].[NominaCargofun]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaCargofun](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Cargo] [nvarchar](50) NOT NULL,
	[Funcion] [ntext] NULL,
 CONSTRAINT [PK_NominaCargofun] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaCargosub]

-- %%
/****** Object:  Table [dbo].[NominaCargosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaCargosub](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Cargo] [nvarchar](50) NOT NULL,
	[Tipo] [nvarchar](50) NULL,
	[Descripcion] [nvarchar](50) NULL,
	[Nivel] [ntext] NULL,
	[Pondera] [float] NULL,
 CONSTRAINT [PK_NominaCargosub] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaCargoTipos]

-- %%
/****** Object:  Table [dbo].[NominaCargoTipos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaCargoTipos](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_NominaCargoTipos] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nominacompensacion]

-- %%
/****** Object:  Table [dbo].[Nominacompensacion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nominacompensacion](
	[Idescuentos] [int] IDENTITY(1,1) NOT NULL,
	[IdNomina] [int] NULL,
	[Concepto] [nvarchar](50) NULL,
	[Neto] [int] NULL,
 CONSTRAINT [PK_Nominacompensacion] PRIMARY KEY CLUSTERED 
(
	[Idescuentos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nominadescuentos]

-- %%
/****** Object:  Table [dbo].[Nominadescuentos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nominadescuentos](
	[Idescuentos] [int] IDENTITY(1,1) NOT NULL,
	[IdNomina] [int] NOT NULL,
	[Concepto] [nvarchar](50) NULL,
	[Neto] [int] NULL,
	[Cuenta] [nvarchar](50) NULL,
 CONSTRAINT [PK_Nominadescuentos] PRIMARY KEY CLUSTERED 
(
	[Idescuentos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nominadevengos]

-- %%
/****** Object:  Table [dbo].[Nominadevengos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nominadevengos](
	[Idescuentos] [int] IDENTITY(1,1) NOT NULL,
	[IdNomina] [int] NULL,
	[Concepto] [nvarchar](50) NULL,
	[Neto] [int] NULL,
	[Cuenta] [nvarchar](50) NULL,
 CONSTRAINT [PK_Nominadevengos] PRIMARY KEY CLUSTERED 
(
	[Idescuentos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaDian]

-- %%
/****** Object:  Table [dbo].[NominaDian]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaDian](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Idparnomina] [int] NOT NULL,
	[Documento] [nvarchar](250) NULL,
	[Idnomina] [int] NOT NULL,
	[Cedula] [nvarchar](50) NULL,
	[Fecha] [smalldatetime] NULL,
	[Fecha inicial] [smalldatetime] NULL,
	[Fecha final] [smalldatetime] NULL,
	[Días trabajados] [float] NULL,
	[HEDO] [float] NULL,
	[HENO] [float] NULL,
	[HEDF] [float] NULL,
	[HENF] [float] NULL,
	[RN] [float] NULL,
	[Otrosdevengados] [int] NULL,
	[Otrasdeducciones] [int] NULL,
	[Notas] [nvarchar](250) NULL,
	[Basico] [int] NULL,
	[TDO] [int] NULL,
	[TNO] [int] NULL,
	[TDF] [int] NULL,
	[TNF] [int] NULL,
	[TRN] [int] NULL,
	[Auxilio] [int] NULL,
	[TDevengado] [int] NULL,
	[Aportesalud] [int] NULL,
	[Aportepension] [int] NULL,
	[FondoSP] [int] NULL,
	[Retefuente] [int] NULL,
	[TDeducido] [int] NULL,
	[Netopagado] [int] NULL,
	[ProCesantia] [int] NULL,
	[ProInteres] [int] NULL,
	[ProPrima] [int] NULL,
	[ProVacaciones] [int] NULL,
	[ProSalud] [int] NULL,
	[ProPension] [int] NULL,
	[ProCaja] [int] NULL,
	[ProFamiliar] [int] NULL,
	[ProSena] [int] NULL,
	[ProRiesgos] [int] NULL,
	[ProParafiscales] [int] NULL,
	[Horas] [float] NULL,
	[Fproceso] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Extraordinaria] [int] NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[Otrosdescuentos] [int] NULL,
	[Otra] [int] NULL,
	[Situacion] [nvarchar](50) NULL,
	[Tipoempleado] [nvarchar](50) NULL,
	[Incapacidad] [int] NULL,
	[diasincapacidad] [float] NULL,
	[Estado] [int] NULL,
	[Us] [float] NULL,
	[Diastrans] [float] NULL,
	[Diasvaca] [float] NULL,
	[Vaca] [int] NULL,
	[HEF] [float] NULL,
	[TF] [int] NULL,
	[BaseSalud] [int] NULL,
	[BasePension] [int] NULL,
	[BaseCaja] [int] NULL,
	[BaseParafiscal] [int] NULL,
	[BaseRiesgos] [int] NULL,
	[Procedimiento] [nvarchar](50) NULL,
	[ApvolPension] [int] NULL,
	[ApvolSalud] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Prefijo] [nvarchar](50) NULL,
	[Consecutivo] [int] NULL,
	[TRM] [float] NULL,
	[Formapago] [nvarchar](50) NULL,
	[Medio] [nvarchar](50) NULL,
	[FechaPago] [smalldatetime] NULL,
	[HRNDF] [float] NULL,
	[THRNDF] [int] NULL,
	[StatusDian] [int] NULL,
	[FDian] [smalldatetime] NULL,
	[StatusCliente] [int] NULL,
	[FCliente] [smalldatetime] NULL,
	[ArchivoDian] [ntext] NULL,
	[RespuestaDian] [ntext] NULL,
	[CUNE] [ntext] NULL,
	[LicenciaNR] [int] NULL,
	[Diasalud] [int] NULL,
	[Diapension] [int] NULL,
	[LicenciaRem] [int] NULL,
	[TipoVaca] [nvarchar](50) NULL,
	[DiasPrimas] [int] NULL,
	[Primas] [int] NULL,
	[PagoCesantias] [int] NULL,
	[PorcentajeCesantias] [int] NULL,
	[PagoInteresesCesantias] [int] NULL,
	[Indemnizacion] [int] NULL,
 CONSTRAINT [PK_NominaDian] PRIMARY KEY CLUSTERED 
(
	[Idnomina] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaDO]

-- %%
/****** Object:  Table [dbo].[NominaDO]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaDO](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[IdNomina] [int] NOT NULL,
	[Horas] [float] NULL,
	[Neto] [int] NULL,
	[DO] [int] NULL,
	[Referencia] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_NominaDO] PRIMARY KEY CLUSTERED 
(
	[IdControl] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaElimina]

-- %%
/****** Object:  Table [dbo].[NominaElimina]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaElimina](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Prefijo] [nvarchar](50) NOT NULL,
	[FechaGen] [smalldatetime] NULL,
	[HoraGen] [datetime] NULL,
	[Notas] [ntext] NULL,
	[CUNE] [ntext] NULL,
	[NumeroPred] [int] NULL,
	[Estado] [int] NULL,
	[StatusDian] [int] NULL,
	[FDian] [smalldatetime] NULL,
	[StatusCliente] [int] NULL,
	[FCliente] [smalldatetime] NULL,
	[ArchivoDian] [ntext] NULL,
	[RespuestaDian] [ntext] NULL,
	[Elaboro] [nvarchar](50) NULL,
 CONSTRAINT [PK_NominaElimina_1] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC,
	[Prefijo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaIncapacidad]

-- %%
/****** Object:  Table [dbo].[NominaIncapacidad]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaIncapacidad](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_NominaIncapacidad] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nominaingresos]

-- %%
/****** Object:  Table [dbo].[Nominaingresos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nominaingresos](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[Cesantias] [nvarchar](50) NULL,
	[Representacion] [nvarchar](50) NULL,
	[Jubilacion] [nvarchar](50) NULL,
	[Otros] [nvarchar](50) NULL,
	[Aportevoluntarios] [nvarchar](50) NULL,
 CONSTRAINT [PK_Nominaingresos] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaIngresospar]

-- %%
/****** Object:  Table [dbo].[NominaIngresospar]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaIngresospar](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Cuenta] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_NominaIngresospar] PRIMARY KEY CLUSTERED 
(
	[Cuenta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaNovedades]

-- %%
/****** Object:  Table [dbo].[NominaNovedades]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaNovedades](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Idparnomina] [int] NOT NULL,
	[ConsecutivoNo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Documento] [nvarchar](50) NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Empleado] [nvarchar](50) NULL,
	[Cliente] [nvarchar](50) NULL,
	[Novedad] [nvarchar](50) NULL,
	[Observaciones] [ntext] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[HEDO] [float] NULL,
	[HENO] [float] NULL,
	[HEDF] [float] NULL,
	[HENF] [float] NULL,
	[HEF] [float] NULL,
	[RN] [float] NULL,
	[TDO] [int] NULL,
	[TNO] [int] NULL,
	[TDF] [int] NULL,
	[TNF] [int] NULL,
	[TF] [int] NULL,
	[TRN] [int] NULL,
	[Otrosdevengados] [int] NULL,
	[Incapacidad] [int] NULL,
	[diasincapacidad] [float] NULL,
	[Ausencias] [int] NULL,
	[diasausencias] [float] NULL,
	[IncapacidadBase] [int] NULL,
	[Extra] [int] NULL,
	[HRNDF] [float] NULL,
	[THRNDF] [int] NULL,
	[CodigoIncapacidad] [nvarchar](50) NULL,
 CONSTRAINT [PK_NominaNovedades] PRIMARY KEY CLUSTERED 
(
	[ConsecutivoNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nominapar]

-- %%
/****** Object:  Table [dbo].[Nominapar]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nominapar](
	[Idparnomina] [int] NOT NULL,
	[Salminimo] [float] NULL,
	[Auxitransporte] [float] NULL,
	[DORD] [float] NULL,
	[NORD] [float] NULL,
	[DFES] [float] NULL,
	[NFES] [float] NULL,
	[RNOC] [float] NULL,
	[SALU] [float] NULL,
	[PENSIO] [float] NULL,
	[FSP] [float] NULL,
	[Cesantia] [float] NULL,
	[ICesan] [float] NULL,
	[Prima] [float] NULL,
	[Vacaciones] [float] NULL,
	[ICBF] [float] NULL,
	[Sena] [float] NULL,
	[CCF] [float] NULL,
	[Sal] [float] NULL,
	[pen] [float] NULL,
	[PICesantia] [float] NULL,
	[Estado] [int] NULL,
	[Festivas] [float] NULL,
	[UVT] [float] NULL,
	[RNF] [float] NULL,
 CONSTRAINT [PK_Nominapar] PRIMARY KEY CLUSTERED 
(
	[Idparnomina] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaPeriodo]

-- %%
/****** Object:  Table [dbo].[NominaPeriodo]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaPeriodo](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_NominaPeriodo] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nominaprestamos]

-- %%
/****** Object:  Table [dbo].[Nominaprestamos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nominaprestamos](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[NominaNo] [int] NOT NULL,
	[AnticipoNo] [int] NULL,
	[Nombre] [nvarchar](50) NULL,
	[Fecha] [smalldatetime] NULL,
	[Pago] [int] NULL,
	[Concepto] [nvarchar](50) NULL,
 CONSTRAINT [PK_Nominaprestamos] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaProfesiones]

-- %%
/****** Object:  Table [dbo].[NominaProfesiones]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaProfesiones](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_NominaProfesiones] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaPrueba]

-- %%
/****** Object:  Table [dbo].[NominaPrueba]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaPrueba](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Candidato] [nvarchar](50) NULL,
	[Cargo] [nvarchar](50) NULL,
	[Notas] [ntext] NULL,
	[Status] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_NominaPrueba] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaPruebasub]

-- %%
/****** Object:  Table [dbo].[NominaPruebasub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaPruebasub](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Tipo] [nvarchar](50) NULL,
	[Descripcion] [ntext] NULL,
	[Pondera] [float] NULL,
	[Calificacion] [float] NULL,
	[Resultado] [float] NULL,
 CONSTRAINT [PK_NominaPruebasub] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NominaPruebaTipos]

-- %%
/****** Object:  Table [dbo].[NominaPruebaTipos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NominaPruebaTipos](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_NominaPruebaTipos] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Novedadestel]

-- %%
/****** Object:  Table [dbo].[Novedadestel]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Novedadestel](
	[IdNovedades] [int] IDENTITY(1,1) NOT NULL,
	[Novedad] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Novedadestel] PRIMARY KEY CLUSTERED 
(
	[Novedad] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OCargue]

-- %%
/****** Object:  Table [dbo].[OCargue]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OCargue](
	[idCargue] [int] IDENTITY(1,1) NOT NULL,
	[OrdenNo] [int] NOT NULL,
	[Ciudad] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Cliente] [nvarchar](250) NULL,
	[Conductor] [nvarchar](250) NULL,
	[Placa] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Destinatario] [nvarchar](50) NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[DO] [int] NULL,
	[Cargue] [nvarchar](250) NULL,
	[Descargue] [nvarchar](250) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Tipo] [nvarchar](50) NULL,
	[DFinal] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
	[Semiremolque] [nvarchar](250) NULL,
	[SOAT] [smalldatetime] NULL,
	[Hidroneumatica] [smalldatetime] NULL,
	[LuzNegra] [smalldatetime] NULL,
	[ICO] [nvarchar](50) NULL,
	[Piezas] [nvarchar](50) NULL,
	[FVenlic] [smalldatetime] NULL,
	[Firma] [nvarchar](50) NULL,
	[Tenedor] [nvarchar](50) NULL,
	[Propietariosub] [nvarchar](50) NULL,
	[Fcargue] [smalldatetime] NULL,
	[Hcargue] [datetime] NULL,
	[Status] [nvarchar](50) NULL,
 CONSTRAINT [PK_OCargue] PRIMARY KEY CLUSTERED 
(
	[OrdenNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OCarguesub]

-- %%
/****** Object:  Table [dbo].[OCarguesub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OCarguesub](
	[IdCarguesub] [int] IDENTITY(1,1) NOT NULL,
	[OrdenNo] [int] NOT NULL,
	[Cantidad] [float] NULL,
	[Peso] [float] NULL,
	[Producto] [nvarchar](250) NULL,
	[Origen] [nvarchar](250) NULL,
	[Destino] [nvarchar](250) NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Neto] [int] NULL,
	[Costo] [int] NULL,
	[Gastos] [int] NULL,
	[Medida] [int] NULL,
	[cod_naturaleza] [int] NULL,
	[cod_empaque] [int] NULL,
	[cod_producto] [nvarchar](50) NULL,
	[DirecOrigen] [nvarchar](250) NULL,
	[DirecDestino] [nvarchar](250) NULL,
 CONSTRAINT [PK_OCarguesub] PRIMARY KEY CLUSTERED 
(
	[IdCarguesub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Orden]

-- %%
/****** Object:  Table [dbo].[Orden]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Orden](
	[idOrdencompra] [int] IDENTITY(1,1) NOT NULL,
	[Ordencompra] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Proveedor] [nvarchar](250) NULL,
	[Entregar] [smalldatetime] NULL,
	[Elaborado] [nvarchar](250) NULL,
	[Aprobado] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[Fentrega] [smalldatetime] NULL,
	[TRM] [float] NULL,
	[Estado] [int] NULL,
	[Situacion] [nvarchar](50) NULL,
 CONSTRAINT [PK_Orden] PRIMARY KEY CLUSTERED 
(
	[Ordencompra] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ordencompra]

-- %%
/****** Object:  Table [dbo].[Ordencompra]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ordencompra](
	[idOrdencompra] [int] IDENTITY(1,1) NOT NULL,
	[Ordencompra] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Proveedor] [nvarchar](250) NULL,
	[Elaborado] [nvarchar](250) NULL,
	[Aprobado] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Descarga] [nvarchar](250) NULL,
	[Bloque] [int] NULL,
	[Destino] [nvarchar](50) NULL,
	[Tipo] [nvarchar](50) NULL,
 CONSTRAINT [PK_Ordencompra] PRIMARY KEY CLUSTERED 
(
	[Ordencompra] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ordencomprasub]

-- %%
/****** Object:  Table [dbo].[Ordencomprasub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ordencomprasub](
	[Idordensub] [int] IDENTITY(1,1) NOT NULL,
	[Ordencompra] [int] NOT NULL,
	[Cantidad] [float] NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Descuento] [float] NULL,
	[Precio] [float] NULL,
	[PIva] [float] NULL,
	[Precio total] [int] NULL,
	[Neto] [int] NULL,
	[Peso] [float] NULL,
	[Subtotal] [int] NULL,
	[Serial] [nvarchar](250) NULL,
	[Controlfinal] [float] NULL,
 CONSTRAINT [PK_Ordencomprasub] PRIMARY KEY CLUSTERED 
(
	[Idordensub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ordensub]

-- %%
/****** Object:  Table [dbo].[Ordensub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ordensub](
	[Idordensub] [int] IDENTITY(1,1) NOT NULL,
	[Ordencompra] [int] NOT NULL,
	[Cantidad] [float] NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Descuento] [float] NULL,
	[Precio] [float] NULL,
	[PIva] [float] NULL,
	[Precio total] [int] NULL,
	[Neto] [int] NULL,
	[Peso] [float] NULL,
	[Subtotal] [int] NULL,
	[CUDol] [float] NULL,
	[Dolares] [float] NULL,
	[Notas] [nvarchar](250) NULL,
	[Placa] [nvarchar](50) NULL,
	[DO] [int] NULL,
 CONSTRAINT [PK_Ordensub] PRIMARY KEY CLUSTERED 
(
	[Idordensub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrdenTrabajo]

-- %%
/****** Object:  Table [dbo].[OrdenTrabajo]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrdenTrabajo](
	[IdOrdenes] [int] IDENTITY(1,1) NOT NULL,
	[OrdTra] [int] NOT NULL,
	[Estado] [int] NULL,
	[Fechafac] [smalldatetime] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Cliente] [nvarchar](250) NULL,
	[Promotor] [nvarchar](50) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Valortransporte] [int] NULL,
	[Kilometraje] [int] NULL,
	[Dias] [float] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Documento] [nvarchar](250) NULL,
	[Adicion] [nvarchar](250) NULL,
	[Abono] [int] NULL,
	[Saldo] [int] NULL,
	[Medio] [nvarchar](250) NULL,
	[Bloque] [int] NULL,
	[Centro costos] [nvarchar](250) NULL,
	[Letras] [nvarchar](250) NULL,
	[PRetencion] [float] NULL,
	[PReteIca] [float] NULL,
	[Reteica] [int] NULL,
	[PReteIva] [float] NULL,
	[ReteIva] [int] NULL,
	[Fproceso] [smalldatetime] NULL,
	[PDescuento] [float] NULL,
	[Situacion] [nvarchar](250) NULL,
	[TRM] [float] NULL,
	[PFlete] [float] NULL,
	[Terminal] [int] NULL,
	[Anticipos] [int] NULL,
	[Rendir] [float] NULL,
	[Cotizacion] [int] NULL,
	[Tipotercero] [nvarchar](50) NULL,
	[Placa] [nvarchar](50) NULL,
	[Destinatario] [nvarchar](50) NULL,
	[Cargue] [nvarchar](250) NULL,
	[Descargue] [nvarchar](250) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Declarado] [int] NULL,
	[DFinal] [nvarchar](50) NULL,
	[Doc] [nvarchar](50) NULL,
	[Sucursal] [nvarchar](250) NULL,
	[Acompañamiento] [nvarchar](50) NULL,
	[Acargo] [nvarchar](50) NULL,
	[CiaAcompañamiento] [nvarchar](50) NULL,
	[Procesar] [nvarchar](50) NULL,
	[Origen] [nvarchar](50) NULL,
	[RMinima] [float] NULL,
	[Descarga] [nvarchar](250) NULL,
	[Destino] [nvarchar](50) NULL,
	[Via] [nvarchar](50) NULL,
	[ICO] [nvarchar](50) NULL,
	[Piezas] [nvarchar](50) NULL,
	[Peso] [nvarchar](50) NULL,
	[Dimensiones] [nvarchar](50) NULL,
	[CIF] [int] NULL,
	[NContrato] [int] NULL,
	[FContrato] [smalldatetime] NULL,
	[Lista] [nvarchar](50) NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Consecutivo] [int] NULL,
	[Tipotrafico] [nvarchar](50) NULL,
	[Shpper] [nvarchar](50) NULL,
	[Consignatario] [nvarchar](50) NULL,
	[TImportacion] [nvarchar](50) NULL,
	[Tflete] [nvarchar](50) NULL,
	[NotasEmbarque] [ntext] NULL,
	[Operativo] [nvarchar](50) NULL,
	[Estadoembarque] [int] NULL,
	[Notify] [nvarchar](50) NULL,
	[TipoOperacion] [nvarchar](50) NULL,
	[Agente] [nvarchar](50) NULL,
 CONSTRAINT [PK_OrdenTrabajo] PRIMARY KEY CLUSTERED 
(
	[OrdTra] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ordentrabajosub]

-- %%
/****** Object:  Table [dbo].[Ordentrabajosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ordentrabajosub](
	[Idordentra] [int] IDENTITY(1,1) NOT NULL,
	[OrdTra] [int] NOT NULL,
	[Cantidad] [float] NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Descuento] [float] NULL,
	[Precio] [float] NULL,
	[PIva] [float] NULL,
	[Precio total] [int] NULL,
	[Neto] [int] NULL,
	[Subtotal] [int] NULL,
	[Exentos] [int] NULL,
	[DesExentos] [int] NULL,
	[DesGravados] [int] NULL,
	[Tercero] [nvarchar](250) NULL,
	[Tipo] [nvarchar](250) NULL,
	[Dolares] [float] NULL,
	[Fecha] [smalldatetime] NULL,
	[Peso] [float] NULL,
	[VPropina] [int] NULL,
	[Producto] [nvarchar](50) NULL,
	[Origen] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
	[Costo] [int] NULL,
	[Gastos] [int] NULL,
	[Medida] [int] NULL,
	[cod_naturaleza] [int] NULL,
	[cod_empaque] [int] NULL,
	[cod_producto] [nvarchar](50) NULL,
	[Serial] [nvarchar](250) NULL,
	[Notas] [nvarchar](250) NULL,
	[Centrosuc] [nvarchar](250) NULL,
	[Declarado] [int] NULL,
	[Porcentaje] [float] NULL,
	[Segurito] [int] NULL,
	[Existencia] [float] NULL,
	[EstOC] [int] NULL,
	[CTotal] [float] NULL,
	[Moneda] [nvarchar](50) NULL,
	[TRMS] [float] NULL,
	[Placa] [nvarchar](50) NULL,
	[Conductor] [nvarchar](50) NULL,
	[Invoice] [nvarchar](50) NULL,
	[FControl] [smalldatetime] NULL,
	[DirecOrigen] [nvarchar](250) NULL,
	[DirecDestino] [nvarchar](250) NULL,
	[Viasub] [nvarchar](50) NULL,
	[Estadosub] [int] NULL,
	[Hllegacargue] [datetime] NULL,
	[Ffincargue] [smalldatetime] NULL,
	[Hfincargue] [datetime] NULL,
 CONSTRAINT [PK_Ordentrabajosub] PRIMARY KEY CLUSTERED 
(
	[Idordentra] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pacientes]

-- %%
/****** Object:  Table [dbo].[Pacientes]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pacientes](
	[IdProspectos] [int] IDENTITY(1,1) NOT NULL,
	[Identificacion] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Direccion] [nvarchar](250) NULL,
	[Telefono] [nvarchar](50) NULL,
	[Celular] [nvarchar](50) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Situacion] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Email] [nvarchar](250) NULL,
	[Contacto] [nvarchar](250) NULL,
	[Ciudad] [nvarchar](250) NULL,
	[Clase] [nvarchar](50) NULL,
	[Promotor] [nvarchar](50) NULL,
	[Apellido1] [nvarchar](50) NULL,
	[Apellido2] [nvarchar](50) NULL,
	[Nombre1] [nvarchar](50) NULL,
	[Nombre2] [nvarchar](50) NULL,
	[Zona] [nvarchar](50) NULL,
	[Tipousuario] [nvarchar](50) NULL,
	[PlanBeneficio] [nvarchar](50) NULL,
	[Sexo] [nvarchar](50) NULL,
	[Fnacimiento] [smalldatetime] NULL,
 CONSTRAINT [PK_Pacientes] PRIMARY KEY CLUSTERED 
(
	[Identificacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PagoCartera]

-- %%
/****** Object:  Table [dbo].[PagoCartera]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PagoCartera](
	[IdPago] [int] IDENTITY(1,1) NOT NULL,
	[IdCaja] [int] NOT NULL,
	[Factura] [int] NULL,
	[Idcontrol] [int] NULL,
	[Fecha] [smalldatetime] NULL,
	[Cliente] [nvarchar](250) NULL,
	[Neto] [float] NULL,
	[Us] [float] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Docu] [nvarchar](50) NULL,
 CONSTRAINT [PK_PagoCartera] PRIMARY KEY CLUSTERED 
(
	[IdPago] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PagoNomina]

-- %%
/****** Object:  Table [dbo].[PagoNomina]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PagoNomina](
	[IdPagoNomina] [int] IDENTITY(1,1) NOT NULL,
	[IdEgreso] [int] NULL,
	[NominaNo] [int] NULL,
	[Fecha] [smalldatetime] NULL,
	[Empleado] [nvarchar](50) NULL,
	[Neto] [int] NULL,
	[Us] [float] NULL,
	[Docu] [nvarchar](50) NULL,
 CONSTRAINT [PK_PagoNomina] PRIMARY KEY CLUSTERED 
(
	[IdPagoNomina] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PagoProveedores]

-- %%
/****** Object:  Table [dbo].[PagoProveedores]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PagoProveedores](
	[Idaplica] [int] IDENTITY(1,1) NOT NULL,
	[IdEgreso] [int] NOT NULL,
	[Proveedor] [nvarchar](50) NULL,
	[Docu] [nvarchar](50) NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Prefijo] [nvarchar](50) NULL,
	[Factura] [int] NULL,
	[DO] [int] NULL,
	[Neto] [int] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Us] [float] NULL,
 CONSTRAINT [PK_PagoProveedores] PRIMARY KEY CLUSTERED 
(
	[Idaplica] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pagos]

-- %%
/****** Object:  Table [dbo].[Pagos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pagos](
	[Idpago] [int] IDENTITY(1,1) NOT NULL,
	[Pago] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Pagos] PRIMARY KEY CLUSTERED 
(
	[Pago] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Paises]

-- %%
/****** Object:  Table [dbo].[Paises]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Paises](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Pais] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[PaisISO] [nvarchar](250) NULL,
	[CodigoAlfa2] [nvarchar](50) NULL,
	[CodigoAlfa3] [nvarchar](50) NULL,
 CONSTRAINT [PK_Paises] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosAjustes]

-- %%
/****** Object:  Table [dbo].[ParametrosAjustes]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosAjustes](
	[IDCuenta] [int] NULL,
	[Paag] [float] NULL,
	[Cuenta] [nvarchar](250) NOT NULL,
	[Partida] [nvarchar](250) NULL,
	[Imputacion] [nvarchar](250) NULL,
	[Contra] [nvarchar](250) NULL,
	[ImputaContra] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosAjustes] PRIMARY KEY CLUSTERED 
(
	[Cuenta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosAnticipos]

-- %%
/****** Object:  Table [dbo].[ParametrosAnticipos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosAnticipos](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosAnticipos] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosCausaciones]

-- %%
/****** Object:  Table [dbo].[ParametrosCausaciones]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosCausaciones](
	[IDCuenta] [int] IDENTITY(1,1) NOT NULL,
	[NúmCuenta] [nvarchar](50) NOT NULL,
	[Débitos] [float] NOT NULL,
	[Créditos] [float] NOT NULL,
	[Identificacion] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosCausaciones] PRIMARY KEY CLUSTERED 
(
	[IDCuenta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosCCobro]

-- %%
/****** Object:  Table [dbo].[ParametrosCCobro]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosCCobro](
	[IDContador] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosCCobro] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosCheques]

-- %%
/****** Object:  Table [dbo].[ParametrosCheques]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosCheques](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosCheques] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosCIF]

-- %%
/****** Object:  Table [dbo].[ParametrosCIF]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosCIF](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](250) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosCIF] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosContratos]

-- %%
/****** Object:  Table [dbo].[ParametrosContratos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosContratos](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Imputacion] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosContratos] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosCostos]

-- %%
/****** Object:  Table [dbo].[ParametrosCostos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosCostos](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
	[Tercero] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosCostos] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosCruce]

-- %%
/****** Object:  Table [dbo].[ParametrosCruce]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosCruce](
	[IDCuenta] [int] NULL,
	[Tema] [nvarchar](50) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Imputacion] [nvarchar](50) NULL,
 CONSTRAINT [PK_ParámetrosCruce] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Parametroscuentas]

-- %%
/****** Object:  Table [dbo].[Parametroscuentas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Parametroscuentas](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Imputacion] [nvarchar](250) NULL,
 CONSTRAINT [PK_Parametroscuentas] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosDepreciacion]

-- %%
/****** Object:  Table [dbo].[ParametrosDepreciacion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosDepreciacion](
	[IDCuenta] [int] IDENTITY(1,1) NOT NULL,
	[IdActivo] [int] NULL,
	[Tema] [nvarchar](250) NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Imputacion] [nvarchar](250) NULL,
	[Tercero] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosDepreciacion] PRIMARY KEY CLUSTERED 
(
	[IDCuenta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosDespachos]

-- %%
/****** Object:  Table [dbo].[ParametrosDespachos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosDespachos](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Imputacion] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosDespachos] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosDeterioro]

-- %%
/****** Object:  Table [dbo].[ParametrosDeterioro]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosDeterioro](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](50) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](50) NULL,
 CONSTRAINT [PK_ParametrosDeterioro] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Parametrosegresos]

-- %%
/****** Object:  Table [dbo].[Parametrosegresos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Parametrosegresos](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_Parametrosegresos] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosEgresosVirtual]

-- %%
/****** Object:  Table [dbo].[ParametrosEgresosVirtual]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosEgresosVirtual](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosEgresosVirtual] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Parametrosentradas]

-- %%
/****** Object:  Table [dbo].[Parametrosentradas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Parametrosentradas](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_Parametrosentradas] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosImportaciones]

-- %%
/****** Object:  Table [dbo].[ParametrosImportaciones]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosImportaciones](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosImportaciones] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Parametrosinteres]

-- %%
/****** Object:  Table [dbo].[Parametrosinteres]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Parametrosinteres](
	[IDCuenta] [int] IDENTITY(1,1) NOT NULL,
	[Tema] [nvarchar](50) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](50) NULL,
 CONSTRAINT [PK_Parametrosinteres] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Parametrosliquidacion]

-- %%
/****** Object:  Table [dbo].[Parametrosliquidacion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Parametrosliquidacion](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_Parametrosliquidacion] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosLiquidaflete]

-- %%
/****** Object:  Table [dbo].[ParametrosLiquidaflete]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosLiquidaflete](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosLiquidaflete] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosManifiesto]

-- %%
/****** Object:  Table [dbo].[ParametrosManifiesto]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosManifiesto](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosManifiesto] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosMostrador]

-- %%
/****** Object:  Table [dbo].[ParametrosMostrador]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosMostrador](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Imputacion] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosMostrador] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosNcredito]

-- %%
/****** Object:  Table [dbo].[ParametrosNcredito]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosNcredito](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosNcredito] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosNCreditopos]

-- %%
/****** Object:  Table [dbo].[ParametrosNCreditopos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosNCreditopos](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosNCreditopos] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosNcreditoprov]

-- %%
/****** Object:  Table [dbo].[ParametrosNcreditoprov]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosNcreditoprov](
	[IDCuenta] [int] NULL,
	[Tema] [nvarchar](50) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](50) NULL,
 CONSTRAINT [PK_ParametrosNcreditoprov] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosNdebito]

-- %%
/****** Object:  Table [dbo].[ParametrosNdebito]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosNdebito](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosNdebito] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosNDebitoClientes]

-- %%
/****** Object:  Table [dbo].[ParametrosNDebitoClientes]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosNDebitoClientes](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosNDebitoClientes] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosNomina]

-- %%
/****** Object:  Table [dbo].[ParametrosNomina]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosNomina](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Imputacion] [nvarchar](250) NULL,
	[Tipo] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_ParametrosNomina] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC,
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosOCompra]

-- %%
/****** Object:  Table [dbo].[ParametrosOCompra]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosOCompra](
	[IDCuenta] [int] NULL,
	[Tema] [nvarchar](50) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Imputacion] [nvarchar](50) NULL,
 CONSTRAINT [PK_ParametrosOCompra] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosPagoNomina]

-- %%
/****** Object:  Table [dbo].[ParametrosPagoNomina]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosPagoNomina](
	[IDCuenta] [int] NULL,
	[Tema] [nvarchar](50) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](50) NULL,
 CONSTRAINT [PK_ParametrosPagoNomina] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosProceinventarios]

-- %%
/****** Object:  Table [dbo].[ParametrosProceinventarios]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosProceinventarios](
	[IDCuenta] [int] NULL,
	[Tema] [nvarchar](50) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Imputacion] [nvarchar](50) NULL,
 CONSTRAINT [PK_ParametrosProceinventarios] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosProceso]

-- %%
/****** Object:  Table [dbo].[ParametrosProceso]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosProceso](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosProceso] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosProduccion]

-- %%
/****** Object:  Table [dbo].[ParametrosProduccion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosProduccion](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosProduccion] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosProduccionOrden]

-- %%
/****** Object:  Table [dbo].[ParametrosProduccionOrden]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosProduccionOrden](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](50) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nchar](10) NULL,
 CONSTRAINT [PK_ParametrosProduccionOrden] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Parametrosrecaja]

-- %%
/****** Object:  Table [dbo].[Parametrosrecaja]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Parametrosrecaja](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_Parametrosrecaja] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Parametrosrecaja2]

-- %%
/****** Object:  Table [dbo].[Parametrosrecaja2]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Parametrosrecaja2](
	[IDCuenta] [int] NULL,
	[Tema] [nvarchar](50) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Imputacion] [nvarchar](50) NULL,
 CONSTRAINT [PK_Parametrosrecaja2] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Parametrosrecajavirtual]

-- %%
/****** Object:  Table [dbo].[Parametrosrecajavirtual]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Parametrosrecajavirtual](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
 CONSTRAINT [PK_Parametrosrecajavirtual] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosReferencias]

-- %%
/****** Object:  Table [dbo].[ParametrosReferencias]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosReferencias](
	[Idreferencia] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](250) NOT NULL,
	[Fproceso] [smalldatetime] NULL,
	[Situacion] [nvarchar](50) NULL,
	[Cuenta] [nvarchar](250) NULL,
	[Imputacion] [nvarchar](50) NULL,
	[CuentaIva] [nvarchar](250) NULL,
	[ImputacionIva] [nvarchar](50) NULL,
	[TipoRete] [nvarchar](50) NULL,
	[TipoPago] [nvarchar](50) NULL,
	[Ingreso] [nvarchar](250) NULL,
	[ImputacionIngreso] [nvarchar](50) NULL,
	[CuentaRetencion] [nvarchar](250) NULL,
	[ImputacionRetencion] [nvarchar](50) NULL,
	[CuentaRRetenida] [nvarchar](250) NULL,
	[ImputacionRRetenida] [nvarchar](50) NULL,
	[TipoReteRetenida] [nvarchar](50) NULL,
	[CuentaIvaCompras] [nvarchar](250) NULL,
	[ImputacionIvaCompras] [nvarchar](50) NULL,
	[CuentaDescuento] [nvarchar](250) NULL,
	[ImputacionDescuento] [nvarchar](50) NULL,
	[CuentaDevolucion] [nvarchar](250) NULL,
	[ImputacionDevolucion] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[CuentaIvaDevolucion] [nvarchar](250) NULL,
	[ImputacionIvaDevolucion] [nvarchar](50) NULL,
	[CuentaIvateorico] [nvarchar](250) NULL,
	[ImputacionIvateorico] [nvarchar](50) NULL,
	[CuentaImpoconsumo] [nvarchar](250) NULL,
	[ImputacionImpoconsumo] [nvarchar](50) NULL,
	[IngresoTercero] [nvarchar](50) NULL,
	[ImputacionIngresoTercero] [nvarchar](50) NULL,
	[ReteIca] [nvarchar](50) NULL,
	[ImputacionReteIca] [nvarchar](50) NULL,
	[CuentaCosto] [nvarchar](50) NULL,
	[ImputacionCosto] [nvarchar](50) NULL,
 CONSTRAINT [PK_ParametrosReferencias] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosRetiros]

-- %%
/****** Object:  Table [dbo].[ParametrosRetiros]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosRetiros](
	[IDCuenta] [int] IDENTITY(1,1) NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
	[Tercero] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosRetiros] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParametrosSalidas]

-- %%
/****** Object:  Table [dbo].[ParametrosSalidas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParametrosSalidas](
	[IDCuenta] [int] NOT NULL,
	[Tema] [nvarchar](250) NOT NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Naturaleza] [nvarchar](250) NULL,
	[Tercero] [nvarchar](250) NULL,
 CONSTRAINT [PK_ParametrosSalidas] PRIMARY KEY CLUSTERED 
(
	[Tema] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pareto]

-- %%
/****** Object:  Table [dbo].[Pareto]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pareto](
	[IdPareto] [int] IDENTITY(1,1) NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
 CONSTRAINT [PK_Pareto] PRIMARY KEY CLUSTERED 
(
	[Referencia] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pareto2]

-- %%
/****** Object:  Table [dbo].[Pareto2]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pareto2](
	[IdPareto] [int] IDENTITY(1,1) NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
 CONSTRAINT [PK_Pareto2] PRIMARY KEY CLUSTERED 
(
	[Referencia] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pareto3]

-- %%
/****** Object:  Table [dbo].[Pareto3]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pareto3](
	[IdPareto] [int] IDENTITY(1,1) NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
 CONSTRAINT [PK_Pareto3] PRIMARY KEY CLUSTERED 
(
	[Referencia] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pedidos]

-- %%
/****** Object:  Table [dbo].[Pedidos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pedidos](
	[IdFACTURAS] [int] IDENTITY(1,1) NOT NULL,
	[Facturanumero] [int] NOT NULL,
	[Estado] [int] NULL,
	[Fechafac] [smalldatetime] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Cliente] [nvarchar](250) NULL,
	[Promotor] [nvarchar](50) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Valortransporte] [int] NULL,
	[Formapago] [nvarchar](250) NULL,
	[Dias] [float] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Documento] [nvarchar](250) NULL,
	[Saldo] [float] NULL,
	[Medio] [nvarchar](250) NULL,
	[Bloque] [int] NULL,
	[Centro costos] [nvarchar](250) NULL,
	[Letras] [nvarchar](250) NULL,
	[PReteIca] [float] NULL,
	[Reteica] [int] NULL,
	[PReteIva] [float] NULL,
	[ReteIva] [int] NULL,
	[Fproceso] [smalldatetime] NULL,
	[Situacion] [nvarchar](250) NULL,
	[FechaEntrega] [smalldatetime] NULL,
	[PDescuento] [float] NULL,
	[TRM] [float] NULL,
	[LetrasDOL] [nvarchar](250) NULL,
	[Itinerario] [nvarchar](250) NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[Cupo] [int] NULL,
	[Diasvencimiento] [int] NULL,
	[Cartera] [int] NULL,
	[Edad] [int] NULL,
	[Estadoter] [int] NULL,
	[Descarga] [nvarchar](250) NULL,
	[Matrix] [int] NULL,
	[PFlete] [float] NULL,
	[Terminal] [int] NULL,
	[Cargar] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[FValidacion] [smalldatetime] NULL,
	[Diferencia] [int] NULL,
	[ARetencion] [nvarchar](50) NULL,
	[Anticipos] [float] NULL,
	[Tipotercero] [nvarchar](50) NULL,
	[Us] [float] NULL,
	[Sucursal] [nvarchar](250) NULL,
	[Remisiones] [nvarchar](250) NULL,
	[Pedidos] [nvarchar](250) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[PUtilidadest] [float] NULL,
	[Utilidadest] [int] NULL,
	[DocumentoBL] [nvarchar](50) NULL,
	[DONo] [int] NULL,
	[Control] [int] NULL,
	[Orige] [nvarchar](50) NULL,
	[Destin] [nvarchar](50) NULL,
	[Via] [nvarchar](50) NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Imprevistos] [int] NULL,
	[Pimprevistos] [float] NULL,
	[Admon] [int] NULL,
	[PAdmon] [float] NULL,
	[Dimensiones] [nvarchar](50) NULL,
	[CIF] [int] NULL,
	[Lista] [nvarchar](50) NULL,
	[PRetefte] [float] NULL,
	[Retefte] [int] NULL,
	[CantBolsas] [int] NULL,
	[ValBolsas] [int] NULL,
	[TipoMoneda] [nvarchar](50) NULL,
	[StatusDian] [int] NULL,
	[StatusCliente] [int] NULL,
	[RespuestaDian] [ntext] NULL,
	[FDian] [smalldatetime] NULL,
	[FCliente] [smalldatetime] NULL,
	[CUFE] [nvarchar](250) NULL,
	[Tipomail] [nvarchar](50) NULL,
	[Horafin] [smalldatetime] NULL,
	[ArchivoDian] [ntext] NULL,
	[TipoFactura] [nvarchar](50) NULL,
	[TipoOperacion] [nvarchar](50) NULL,
	[FacReferencia] [nvarchar](50) NULL,
	[FechaOrden] [smalldatetime] NULL,
	[Docu] [nvarchar](50) NULL,
	[RecajaNo] [int] NULL,
	[FechaRC] [smalldatetime] NULL,
 CONSTRAINT [PK_Pedidos] PRIMARY KEY CLUSTERED 
(
	[Facturanumero] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PedidosAdjuntos]

-- %%
/****** Object:  Table [dbo].[PedidosAdjuntos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PedidosAdjuntos](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Docu] [nvarchar](50) NOT NULL,
	[Resolucion] [nvarchar](50) NOT NULL,
	[Factura] [int] NOT NULL,
	[Ruta] [ntext] NULL,
	[Gestor] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_PedidosAdjuntos] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pedisub]

-- %%
/****** Object:  Table [dbo].[Pedisub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pedisub](
	[Idpedir] [int] IDENTITY(1,1) NOT NULL,
	[Facturanumero] [int] NOT NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
	[Descuento] [float] NULL,
	[PIva] [float] NULL,
	[Precio] [float] NULL,
	[Subtotal] [float] NULL,
	[Neto] [float] NULL,
	[Precio total] [float] NULL,
	[Exentos] [int] NULL,
	[DesExentos] [int] NULL,
	[DesGravados] [int] NULL,
	[Dolares] [float] NULL,
	[Costear] [float] NULL,
	[Peso] [float] NULL,
	[Detalle] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Placa] [nvarchar](250) NULL,
	[Remesa] [int] NULL,
	[VPropina] [int] NULL,
	[Controlfinal] [float] NULL,
	[Rebaja] [int] NULL,
	[PRete] [float] NULL,
	[Retencion] [float] NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[Manifiesto] [int] NULL,
	[Detalle2] [nvarchar](250) NULL,
	[DO] [int] NULL,
	[Origen] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
	[Centrosuc] [nvarchar](250) NULL,
	[Cargado] [int] NULL,
	[Cuota] [int] NULL,
	[Moneda] [nvarchar](50) NULL,
	[TRMS] [float] NULL,
	[Pimpoconsumo] [float] NULL,
	[ImpCon] [int] NULL,
	[Cree] [int] NULL,
	[Doc] [nvarchar](50) NULL,
	[Costo] [int] NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Proveedor] [nvarchar](50) NULL,
	[PReteIcasub] [float] NULL,
	[ReteIcasub] [float] NULL,
 CONSTRAINT [PK_Pedisub] PRIMARY KEY CLUSTERED 
(
	[Idpedir] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pension]

-- %%
/****** Object:  Table [dbo].[Pension]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pension](
	[idpension] [int] IDENTITY(1,1) NOT NULL,
	[Pension] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Tercero] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Pension] PRIMARY KEY CLUSTERED 
(
	[Pension] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Periodos]

-- %%
/****** Object:  Table [dbo].[Periodos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Periodos](
	[Idperiodo] [int] NULL,
	[Periodo] [int] NOT NULL,
	[Significado] [nvarchar](250) NULL,
 CONSTRAINT [PK_Periodos] PRIMARY KEY CLUSTERED 
(
	[Periodo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Plan negocios]

-- %%
/****** Object:  Table [dbo].[Plan negocios]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Plan negocios](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Proyecto] [nvarchar](250) NULL,
	[Descripcion] [nvarchar](250) NULL,
	[Ciclo de vida] [nvarchar](250) NULL,
	[Bondades] [nvarchar](250) NULL,
	[Clientes hombres] [nvarchar](250) NULL,
	[Edad] [nvarchar](250) NULL,
	[Informacion] [nvarchar](250) NULL,
	[Porque compra] [nvarchar](250) NULL,
	[Sitio compra] [nvarchar](250) NULL,
	[Frecuencia] [nvarchar](250) NULL,
	[Estudio] [nvarchar](250) NULL,
	[Laboral] [nvarchar](250) NULL,
	[Ingresos] [nvarchar](250) NULL,
	[Comercial] [nvarchar](250) NULL,
	[Precio] [nvarchar](250) NULL,
	[Sustitutos] [nvarchar](250) NULL,
	[Competidores] [nvarchar](250) NULL,
	[Necesidades tecnicas] [nvarchar](250) NULL,
	[Inversion inicial] [nvarchar](250) NULL,
	[Garantias] [nvarchar](250) NULL,
	[TIR] [nvarchar](250) NULL,
	[VPN] [nvarchar](250) NULL,
	[RBC] [nvarchar](250) NULL,
 CONSTRAINT [PK_Plan negocios] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Plandescuentos]

-- %%
/****** Object:  Table [dbo].[Plandescuentos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Plandescuentos](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Placa] [nvarchar](250) NULL,
	[Concepto] [nvarchar](50) NULL,
	[Neto] [int] NULL,
	[Documento] [nvarchar](50) NULL,
	[Notas] [nvarchar](250) NULL,
 CONSTRAINT [PK_Plandescuentos] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Planilla]

-- %%
/****** Object:  Table [dbo].[Planilla]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Planilla](
	[IdPlanilla] [int] IDENTITY(1,1) NOT NULL,
	[Facturanumero] [int] NOT NULL,
	[Placa] [nvarchar](50) NULL,
	[Diasven] [int] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Neto] [int] NULL,
	[Situacion] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Nombre] [nvarchar](250) NULL,
	[Notas] [nvarchar](250) NULL,
 CONSTRAINT [PK_Planilla] PRIMARY KEY CLUSTERED 
(
	[IdPlanilla] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlanillaMatrix]

-- %%
/****** Object:  Table [dbo].[PlanillaMatrix]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlanillaMatrix](
	[IdPlanilla] [int] IDENTITY(1,1) NOT NULL,
	[Factura] [int] NOT NULL,
	[Placa] [nvarchar](50) NULL,
	[Diasven] [int] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Neto] [int] NULL,
	[Situacion] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Nombre] [nvarchar](250) NULL,
	[Notas] [nvarchar](250) NULL,
 CONSTRAINT [PK_PlanillaMatrix] PRIMARY KEY CLUSTERED 
(
	[IdPlanilla] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlanPagos]

-- %%
/****** Object:  Table [dbo].[PlanPagos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlanPagos](
	[Idplan] [int] IDENTITY(1,1) NOT NULL,
	[Facturanumero] [int] NOT NULL,
	[Fecha] [smalldatetime] NOT NULL,
	[Pago] [float] NULL,
	[Dias] [int] NULL,
 CONSTRAINT [PK_PlanPagos] PRIMARY KEY CLUSTERED 
(
	[Idplan] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Planta cargos]

-- %%
/****** Object:  Table [dbo].[Planta cargos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Planta cargos](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Idproyectos] [int] NOT NULL,
	[Cargo1] [nvarchar](250) NULL,
	[cant1] [int] NULL,
	[Suel1] [int] NULL,
	[Suel2] [int] NULL,
 CONSTRAINT [PK_Planta cargos] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ponderacion]

-- %%
/****** Object:  Table [dbo].[Ponderacion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ponderacion](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Proceso] [nvarchar](250) NOT NULL,
	[Ponderacion] [float] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Ponderacion] PRIMARY KEY CLUSTERED 
(
	[Proceso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Precios]

-- %%
/****** Object:  Table [dbo].[Precios]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Precios](
	[Idprecios] [int] IDENTITY(1,1) NOT NULL,
	[Cantidad] [float] NULL,
	[Referencia] [nvarchar](250) NULL,
	[Descuento] [float] NULL,
	[Precio] [float] NULL,
	[PIva] [float] NULL,
	[Precio total] [int] NULL,
	[Neto] [int] NULL,
	[Exentos] [int] NULL,
	[Fproceso] [smalldatetime] NULL,
 CONSTRAINT [PK_Precios] PRIMARY KEY CLUSTERED 
(
	[Idprecios] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Prestamos]

-- %%
/****** Object:  Table [dbo].[Prestamos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Prestamos](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Idprestamos] [int] NOT NULL,
	[Proyecto] [nvarchar](250) NULL,
	[TASA INICIAL] [float] NULL,
	[MODO ACTUAL] [int] NULL,
	[MODO DESEADO] [int] NULL,
	[TASA] [float] NULL,
	[CUOTA] [int] NULL,
	[CAPITAL] [int] NULL,
	[TIEMPO] [int] NULL,
	[Estado] [int] NULL,
	[Intereses] [int] NULL,
	[IngBruto] [int] NULL,
	[Gastos] [int] NULL,
	[IngNeto] [int] NULL,
	[PCapacidad] [float] NULL,
	[CapacPago] [int] NULL,
	[Fecha] [smalldatetime] NULL,
	[Factor] [float] NULL,
	[Proyectado] [int] NULL,
	[Meses] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[interes1] [int] NULL,
	[capital1] [int] NULL,
	[Saldo1] [int] NULL,
	[interes2] [int] NULL,
	[capital2] [int] NULL,
	[Saldo2] [int] NULL,
	[interes3] [int] NULL,
	[capital3] [int] NULL,
	[Saldo3] [int] NULL,
	[interes4] [int] NULL,
	[capital4] [int] NULL,
	[Saldo4] [int] NULL,
	[interes5] [int] NULL,
	[capital5] [int] NULL,
	[Saldo5] [int] NULL,
	[interes6] [int] NULL,
	[capital6] [int] NULL,
	[Saldo6] [int] NULL,
	[interes7] [int] NULL,
	[capital7] [int] NULL,
	[Saldo7] [int] NULL,
	[interes8] [int] NULL,
	[capital8] [int] NULL,
	[Saldo8] [int] NULL,
	[interes9] [int] NULL,
	[capital9] [int] NULL,
	[Saldo9] [int] NULL,
	[interes10] [int] NULL,
	[capital10] [int] NULL,
	[Saldo10] [int] NULL,
	[interes11] [int] NULL,
	[capital11] [int] NULL,
	[Saldo11] [int] NULL,
	[interes12] [int] NULL,
	[capital12] [int] NULL,
	[Saldo12] [int] NULL,
 CONSTRAINT [PK_Prestamos] PRIMARY KEY CLUSTERED 
(
	[Idprestamos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Presupuestar]

-- %%
/****** Object:  Table [dbo].[Presupuestar]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Presupuestar](
	[idpresupuesto] [int] IDENTITY(1,1) NOT NULL,
	[PresupuestoNo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Documento] [nvarchar](50) NULL,
 CONSTRAINT [PK_Presupuestar] PRIMARY KEY CLUSTERED 
(
	[PresupuestoNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Presupuestarsub]

-- %%
/****** Object:  Table [dbo].[Presupuestarsub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Presupuestarsub](
	[IdPresupuestosub] [int] IDENTITY(1,1) NOT NULL,
	[PresupuestoNo] [int] NOT NULL,
	[Cuenta] [nvarchar](250) NULL,
	[Debitos] [int] NULL,
	[Creditos] [int] NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Fecha] [smalldatetime] NULL,
 CONSTRAINT [PK_Presupuestarsub] PRIMARY KEY CLUSTERED 
(
	[IdPresupuestosub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Presupuesto]

-- %%
/****** Object:  Table [dbo].[Presupuesto]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Presupuesto](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[idpresupuesto] [int] NOT NULL,
	[centrocostos] [nvarchar](250) NULL,
	[Finicial] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
	[Fproceso] [smalldatetime] NULL,
	[Estado] [int] NULL,
	[FValidacion] [smalldatetime] NULL,
 CONSTRAINT [PK_Presupuesto] PRIMARY KEY CLUSTERED 
(
	[idpresupuesto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Presupuestosub]

-- %%
/****** Object:  Table [dbo].[Presupuestosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Presupuestosub](
	[Idpresupuestosub] [int] IDENTITY(1,1) NOT NULL,
	[Idpresupuesto] [int] NOT NULL,
	[vendedor] [nvarchar](250) NULL,
	[CuotaCantidad] [int] NULL,
	[Precio] [float] NULL,
	[Total] [int] NULL,
	[Peso] [float] NULL,
 CONSTRAINT [PK_Presupuestosub] PRIMARY KEY CLUSTERED 
(
	[Idpresupuestosub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PricingAereo]

-- %%
/****** Object:  Table [dbo].[PricingAereo]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PricingAereo](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[Operacion] [nvarchar](50) NOT NULL,
	[Identificacion] [nvarchar](50) NOT NULL,
	[Referencia] [nvarchar](50) NOT NULL,
	[Origen] [nvarchar](50) NOT NULL,
	[Destino] [nvarchar](50) NOT NULL,
	[Vigencia] [smalldatetime] NULL,
	[Dcredito] [int] NULL,
	[Dlibres] [int] NULL,
	[Exoneracion] [nvarchar](50) NULL,
	[Liberacion] [nvarchar](50) NULL,
	[PesoMin] [float] NULL,
	[Peso1] [float] NULL,
	[Peso2] [float] NULL,
	[Peso3] [float] NULL,
	[Peso4] [float] NULL,
	[CostoMin] [float] NULL,
	[Costo1] [float] NULL,
	[Costo2] [float] NULL,
	[Costo3] [float] NULL,
	[Costo4] [float] NULL,
	[DTransito] [int] NULL,
	[Frecuencia] [nvarchar](50) NULL,
	[Peso5] [float] NULL,
	[Costo5] [float] NULL,
 CONSTRAINT [PK_PricingAereo] PRIMARY KEY CLUSTERED 
(
	[Operacion] ASC,
	[Identificacion] ASC,
	[Referencia] ASC,
	[Origen] ASC,
	[Destino] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PricingAereoBase]

-- %%
/****** Object:  Table [dbo].[PricingAereoBase]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PricingAereoBase](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Operacion] [nvarchar](50) NOT NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_PricingAereoBase] PRIMARY KEY CLUSTERED 
(
	[Operacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PricingAereoEscala]

-- %%
/****** Object:  Table [dbo].[PricingAereoEscala]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PricingAereoEscala](
	[Idescala] [int] IDENTITY(1,1) NOT NULL,
	[Escala1] [int] NULL,
	[Escala2] [int] NULL,
	[Escala3] [int] NULL,
	[Escala4] [int] NULL,
	[Escala5] [int] NULL,
	[Signo1] [nvarchar](50) NULL,
	[Signo2] [nvarchar](50) NULL,
	[Signo3] [nvarchar](50) NULL,
	[Signo4] [nvarchar](50) NULL,
	[Signo5] [nvarchar](50) NULL,
 CONSTRAINT [PK_PricingAereoEscala] PRIMARY KEY CLUSTERED 
(
	[Idescala] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PricingFCL]

-- %%
/****** Object:  Table [dbo].[PricingFCL]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PricingFCL](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[Operacion] [nvarchar](50) NOT NULL,
	[Identificacion] [nvarchar](50) NOT NULL,
	[Referencia] [nvarchar](50) NOT NULL,
	[Origen] [nvarchar](50) NOT NULL,
	[Destino] [nvarchar](50) NOT NULL,
	[Vigencia] [smalldatetime] NULL,
	[Dcredito] [int] NULL,
	[Dlibres] [int] NULL,
	[Exoneracion] [nvarchar](50) NULL,
	[Liberacion] [nvarchar](50) NULL,
	[Precio20] [float] NULL,
	[Precio40] [float] NULL,
	[Precio40HC] [float] NULL,
	[Costo20] [float] NULL,
	[Costo40] [float] NULL,
	[Costo40HC] [float] NULL,
	[DTHC] [nvarchar](50) NULL,
	[DTransito] [int] NULL,
	[Frecuencia] [nvarchar](50) NULL,
 CONSTRAINT [PK_PricingFCL] PRIMARY KEY CLUSTERED 
(
	[Operacion] ASC,
	[Identificacion] ASC,
	[Referencia] ASC,
	[Origen] ASC,
	[Destino] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PricingFCLBase]

-- %%
/****** Object:  Table [dbo].[PricingFCLBase]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PricingFCLBase](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Operacion] [nvarchar](50) NOT NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_PricingFCLBase] PRIMARY KEY CLUSTERED 
(
	[Operacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PricingFijos]

-- %%
/****** Object:  Table [dbo].[PricingFijos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PricingFijos](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[Operacion] [nvarchar](50) NOT NULL,
	[Identificacion] [nvarchar](50) NOT NULL,
	[Referencia] [nvarchar](50) NOT NULL,
	[Vigencia] [smalldatetime] NULL,
	[Costo] [float] NULL,
	[Venta] [float] NULL,
	[Notas] [nvarchar](250) NULL,
	[MinVenta] [float] NULL,
	[MinCosto] [float] NULL,
	[Costocop] [int] NULL,
	[Ventacop] [int] NULL,
	[MinVentacop] [int] NULL,
	[MinCostocop] [int] NULL,
 CONSTRAINT [PK_PricingFijos] PRIMARY KEY CLUSTERED 
(
	[Operacion] ASC,
	[Identificacion] ASC,
	[Referencia] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PricingLCL]

-- %%
/****** Object:  Table [dbo].[PricingLCL]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PricingLCL](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[Operacion] [nvarchar](50) NOT NULL,
	[Identificacion] [nvarchar](50) NOT NULL,
	[Referencia] [nvarchar](50) NOT NULL,
	[Origen] [nvarchar](50) NOT NULL,
	[Destino] [nvarchar](50) NOT NULL,
	[Vigencia] [smalldatetime] NULL,
	[Dcredito] [int] NULL,
	[Dlibres] [int] NULL,
	[Exoneracion] [nvarchar](50) NULL,
	[Liberacion] [nvarchar](50) NULL,
	[MinVenta] [float] NULL,
	[Venta] [float] NULL,
	[MinCosto] [float] NULL,
	[Costo] [float] NULL,
	[DTransito] [int] NULL,
	[Frecuencia] [nvarchar](50) NULL,
 CONSTRAINT [PK_PricingLCL] PRIMARY KEY CLUSTERED 
(
	[Operacion] ASC,
	[Identificacion] ASC,
	[Referencia] ASC,
	[Origen] ASC,
	[Destino] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PricingLCLBase]

-- %%
/****** Object:  Table [dbo].[PricingLCLBase]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PricingLCLBase](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Operacion] [nvarchar](50) NOT NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_PricingLCLBase] PRIMARY KEY CLUSTERED 
(
	[Operacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PricingOTM]

-- %%
/****** Object:  Table [dbo].[PricingOTM]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PricingOTM](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[Operacion] [nvarchar](50) NOT NULL,
	[Identificacion] [nvarchar](50) NOT NULL,
	[Referencia] [nvarchar](50) NOT NULL,
	[Origen] [nvarchar](50) NOT NULL,
	[Destino] [nvarchar](50) NOT NULL,
	[Vigencia] [smalldatetime] NULL,
	[Dcredito] [int] NULL,
	[Tipocon] [nvarchar](50) NULL,
	[Peso] [float] NULL,
	[Costo] [float] NULL,
	[Venta] [float] NULL,
 CONSTRAINT [PK_PricingOTM] PRIMARY KEY CLUSTERED 
(
	[Operacion] ASC,
	[Identificacion] ASC,
	[Referencia] ASC,
	[Origen] ASC,
	[Destino] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PricingOTMBase]

-- %%
/****** Object:  Table [dbo].[PricingOTMBase]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PricingOTMBase](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Operacion] [nvarchar](50) NOT NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_PricingOTMBase] PRIMARY KEY CLUSTERED 
(
	[Operacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PricingTerrestre]

-- %%
/****** Object:  Table [dbo].[PricingTerrestre]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PricingTerrestre](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[Operacion] [nvarchar](50) NOT NULL,
	[Identificacion] [nvarchar](50) NOT NULL,
	[Referencia] [nvarchar](50) NOT NULL,
	[Origen] [nvarchar](50) NOT NULL,
	[Destino] [nvarchar](50) NOT NULL,
	[Tipocon] [nvarchar](50) NULL,
	[Vigencia] [smalldatetime] NULL,
	[Dcredito] [int] NULL,
	[Peso] [float] NULL,
	[Costo] [float] NULL,
	[Venta] [float] NULL,
 CONSTRAINT [PK_PricingTerrestre] PRIMARY KEY CLUSTERED 
(
	[Operacion] ASC,
	[Identificacion] ASC,
	[Referencia] ASC,
	[Origen] ASC,
	[Destino] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PricingTerrestreBase]

-- %%
/****** Object:  Table [dbo].[PricingTerrestreBase]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PricingTerrestreBase](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Operacion] [nvarchar](50) NOT NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_PricingTerrestreBase] PRIMARY KEY CLUSTERED 
(
	[Operacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Proceso]

-- %%
/****** Object:  Table [dbo].[Proceso]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Proceso](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Idproduccion] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Documento] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[IdEntradas] [int] NULL,
	[Descarga] [nvarchar](250) NULL,
	[Referencia] [nvarchar](50) NULL,
	[Cantidad] [float] NULL,
	[Costo] [float] NULL,
 CONSTRAINT [PK_Proceso] PRIMARY KEY CLUSTERED 
(
	[Idproduccion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Procesosub]

-- %%
/****** Object:  Table [dbo].[Procesosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Procesosub](
	[Idproduccionsub] [int] IDENTITY(1,1) NOT NULL,
	[IdProduccion] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
	[Costounitario] [float] NULL,
	[Costo] [int] NULL,
	[Peso] [float] NULL,
	[Especificaciones] [nvarchar](250) NULL,
 CONSTRAINT [PK_Procesosub] PRIMARY KEY CLUSTERED 
(
	[Idproduccionsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Produccion]

-- %%
/****** Object:  Table [dbo].[Produccion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Produccion](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Idproduccion] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Documento] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Descarga] [nvarchar](250) NULL,
	[Producidas] [int] NULL,
	[CIF] [int] NULL,
	[MDO] [int] NULL,
	[Estado] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[OPNo] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
 CONSTRAINT [PK_Produccion] PRIMARY KEY CLUSTERED 
(
	[Idproduccion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProduccionOrden]

-- %%
/****** Object:  Table [dbo].[ProduccionOrden]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProduccionOrden](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Idproduccion] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Documento] [nvarchar](50) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Referencia] [nvarchar](50) NULL,
	[DO] [int] NULL,
	[Situacion] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
 CONSTRAINT [PK_ProduccionOrden] PRIMARY KEY CLUSTERED 
(
	[Idproduccion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProduccionOrdenref]

-- %%
/****** Object:  Table [dbo].[ProduccionOrdenref]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProduccionOrdenref](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Idproduccion] [int] NOT NULL,
	[Referencia] [nvarchar](50) NOT NULL,
	[Producidas] [int] NULL,
 CONSTRAINT [PK_ProduccionOrdenref] PRIMARY KEY CLUSTERED 
(
	[Idproduccion] ASC,
	[Referencia] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Produccionordensub]

-- %%
/****** Object:  Table [dbo].[Produccionordensub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Produccionordensub](
	[Idproduccionsub] [int] IDENTITY(1,1) NOT NULL,
	[IdProduccion] [int] NOT NULL,
	[Insumo] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
	[Costounitario] [float] NULL,
	[Costo] [int] NULL,
	[Peso] [float] NULL,
	[Subtotal] [int] NULL,
	[Referencia] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Produccionordensub] PRIMARY KEY CLUSTERED 
(
	[Idproduccionsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Produccionsub]

-- %%
/****** Object:  Table [dbo].[Produccionsub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Produccionsub](
	[Idproduccionsub] [int] IDENTITY(1,1) NOT NULL,
	[IdProduccion] [int] NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
	[Costounitario] [float] NULL,
	[Costo] [int] NULL,
	[Peso] [float] NULL,
	[Subtotal] [int] NULL,
	[DO] [int] NULL,
 CONSTRAINT [PK_Produccionsub] PRIMARY KEY CLUSTERED 
(
	[Idproduccionsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Profesionales]

-- %%
/****** Object:  Table [dbo].[Profesionales]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Profesionales](
	[IdProfesional] [int] IDENTITY(1,1) NOT NULL,
	[Profesional] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Profesionales] PRIMARY KEY CLUSTERED 
(
	[Profesional] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProyecCostos]

-- %%
/****** Object:  Table [dbo].[ProyecCostos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProyecCostos](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Idproyectos] [int] NOT NULL,
	[Concepto] [nvarchar](50) NULL,
	[Neto] [int] NULL,
	[Cuenta] [nvarchar](50) NULL,
 CONSTRAINT [PK_ProyecCostos] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Proyecventas2]

-- %%
/****** Object:  Table [dbo].[Proyecventas2]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Proyecventas2](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Idproyectos] [int] NOT NULL,
	[Proyecto] [nvarchar](250) NULL,
	[Producto] [nvarchar](50) NULL,
	[Cantidad1] [int] NULL,
	[Ventas1] [int] NULL,
	[Cantidad2] [int] NULL,
	[Ventas2] [int] NULL,
	[Cantidad3] [int] NULL,
	[Ventas3] [int] NULL,
	[Cantidad4] [int] NULL,
	[Ventas4] [int] NULL,
	[Cantidad5] [int] NULL,
	[Ventas5] [int] NULL,
	[Cantidad6] [int] NULL,
	[Ventas6] [int] NULL,
	[Cantidad7] [int] NULL,
	[Ventas7] [int] NULL,
	[Cantidad8] [int] NULL,
	[Ventas8] [int] NULL,
	[Cantidad9] [int] NULL,
	[Ventas9] [int] NULL,
	[Cantidad10] [int] NULL,
	[Ventas10] [int] NULL,
	[Cantidad11] [int] NULL,
	[Ventas11] [int] NULL,
	[Cantidad12] [int] NULL,
	[Ventas12] [int] NULL,
	[periodos registrados] [int] NULL,
	[x1] [float] NULL,
	[x2] [float] NULL,
	[x3] [float] NULL,
	[x4] [float] NULL,
	[x5] [float] NULL,
	[x6] [float] NULL,
	[x7] [float] NULL,
	[x8] [float] NULL,
	[x9] [float] NULL,
	[x10] [float] NULL,
	[x11] [float] NULL,
	[x12] [float] NULL,
	[BV0] [float] NULL,
	[BV1] [float] NULL,
	[r] [float] NULL,
	[r2] [float] NULL,
	[Precio final] [float] NULL,
	[Factor precios] [float] NULL,
	[Porcentaje de captura] [float] NULL,
	[Costos] [float] NULL,
	[Arriendo] [float] NULL,
	[Salarios] [float] NULL,
	[Servicios públicos] [float] NULL,
	[Publicidad] [float] NULL,
	[Papelería] [float] NULL,
	[Imprev] [float] NULL,
	[Depreciacion] [float] NULL,
	[Materia prima] [float] NULL,
	[Mano de obra] [float] NULL,
	[Costos generales] [float] NULL,
	[Period] [float] NULL,
	[BC0] [float] NULL,
	[BC1] [float] NULL,
	[Tasa impositiva] [float] NULL,
	[Valor residual] [float] NULL,
	[Inversion inicial] [float] NULL,
	[Estado] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
 CONSTRAINT [PK_Proyecventas2] PRIMARY KEY CLUSTERED 
(
	[Idproyectos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Recaja]

-- %%
/****** Object:  Table [dbo].[Recaja]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Recaja](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Idcaja] [int] NOT NULL,
	[Estado] [int] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Ciudad] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Nombre] [nvarchar](250) NULL,
	[Suma] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[Formapago] [nvarchar](250) NULL,
	[Firma] [nvarchar](250) NULL,
	[Tipos] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[Document] [nvarchar](250) NULL,
	[PDesc] [float] NULL,
	[Descuento] [float] NULL,
	[PRetencion] [float] NULL,
	[Retefuente] [int] NULL,
	[Pagar] [float] NULL,
	[Netor] [float] NULL,
	[Ivar] [int] NULL,
	[Pivar] [float] NULL,
	[PReteIca] [float] NULL,
	[ReteIca] [int] NULL,
	[PReteIva] [float] NULL,
	[ReteIva] [int] NULL,
	[Adicion] [float] NULL,
	[Fproceso] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[DifCambio] [int] NULL,
	[Tercero] [nvarchar](50) NULL,
	[Saldo] [int] NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Resolucion] [nvarchar](50) NULL,
	[Consecutivo] [int] NULL,
 CONSTRAINT [PK_Recaja] PRIMARY KEY CLUSTERED 
(
	[Idcaja] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Reclasificacion]

-- %%
/****** Object:  Table [dbo].[Reclasificacion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Reclasificacion](
	[IdReclasificacion] [int] IDENTITY(1,1) NOT NULL,
	[DocNo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Documento] [nvarchar](50) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[CuentaDebito] [nvarchar](50) NULL,
	[CuentaCredito] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Reclasificacion] PRIMARY KEY CLUSTERED 
(
	[DocNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Reclasificacionsub]

-- %%
/****** Object:  Table [dbo].[Reclasificacionsub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Reclasificacionsub](
	[idreclasificacionsub] [int] IDENTITY(1,1) NOT NULL,
	[DocNo] [int] NOT NULL,
	[Factura] [int] NULL,
	[Cliente] [nvarchar](250) NULL,
	[Neto] [int] NULL,
	[Centrocostos] [nvarchar](50) NULL,
 CONSTRAINT [PK_Reclasificacionsub] PRIMARY KEY CLUSTERED 
(
	[idreclasificacionsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Recomendaciones]

-- %%
/****** Object:  Table [dbo].[Recomendaciones]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Recomendaciones](
	[IdRecomendaciones] [int] IDENTITY(1,1) NOT NULL,
	[Codigorec] [int] NULL,
	[Materia] [nvarchar](250) NULL,
	[Periodo] [int] NULL,
	[Significa] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Curso] [nvarchar](50) NULL,
	[Año] [int] NULL,
 CONSTRAINT [PK_Recomendaciones] PRIMARY KEY CLUSTERED 
(
	[IdRecomendaciones] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Referencias]

-- %%
/****** Object:  Table [dbo].[Referencias]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Referencias](
	[Idreferencia] [int] IDENTITY(1,1) NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Nombreref] [nvarchar](250) NULL,
	[Características] [nvarchar](250) NULL,
	[Stock] [float] NULL,
	[Seguridad] [float] NULL,
	[Precioventa] [float] NULL,
	[IVA] [float] NULL,
	[Comiventas] [float] NULL,
	[Marca] [nvarchar](250) NULL,
	[Subgrupo] [nvarchar](50) NULL,
	[Unidad] [nvarchar](250) NULL,
	[Caja] [float] NULL,
	[Ubicacion] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[CBarras] [nvarchar](250) NULL,
	[Situacion] [nvarchar](250) NULL,
	[Costo] [float] NULL,
	[Descuen] [float] NULL,
	[PRetencion] [float] NULL,
	[Cuenta] [nvarchar](250) NULL,
	[Imputacion] [nvarchar](250) NULL,
	[CuentaIva] [nvarchar](250) NULL,
	[ImputacionIva] [nvarchar](250) NULL,
	[TipoRete] [nvarchar](250) NULL,
	[TipoPago] [nvarchar](250) NULL,
	[VER] [nvarchar](250) NULL,
	[Ingreso] [nvarchar](250) NULL,
	[ImputacionIngreso] [nvarchar](250) NULL,
	[Propina] [nvarchar](250) NULL,
	[Tipo] [nvarchar](250) NULL,
	[CuentaRetencion] [nvarchar](250) NULL,
	[ImputacionRetencion] [nvarchar](250) NULL,
	[Preciofinal] [int] NULL,
	[Estado] [int] NULL,
	[RutaFoto] [nvarchar](250) NULL,
	[FValidacion] [smalldatetime] NULL,
	[CuentaRRetenida] [nvarchar](250) NULL,
	[ImputacionRRetenida] [nvarchar](250) NULL,
	[TipoReteRetenida] [nvarchar](250) NULL,
	[CuentaIvaCompras] [nvarchar](50) NULL,
	[ImputacionIvaCompras] [nvarchar](50) NULL,
	[CuentaDescuento] [nvarchar](50) NULL,
	[ImputacionDescuento] [nvarchar](50) NULL,
	[CuentaDevolucion] [nvarchar](50) NULL,
	[ImputacionDevolucion] [nvarchar](50) NULL,
	[TipoIva] [nvarchar](50) NULL,
	[Tiporeferencia] [nvarchar](250) NULL,
	[CuentaIvaDevolucion] [nvarchar](250) NULL,
	[ImputacionIvaDevolucion] [nvarchar](50) NULL,
	[CuentaIvateorico] [nvarchar](250) NULL,
	[ImputacionIvateorico] [nvarchar](50) NULL,
	[Costear] [nvarchar](50) NULL,
	[Existencia] [nvarchar](50) NULL,
	[Facturar] [nvarchar](50) NULL,
	[Pimpoconsumor] [float] NULL,
	[CuentaImpoconsumo] [nvarchar](250) NULL,
	[ImputacionImpoconsumo] [nvarchar](50) NULL,
	[Retecree] [nvarchar](50) NULL,
	[IngresoTercero] [nvarchar](50) NULL,
	[ImputacionIngresoTercero] [nvarchar](50) NULL,
	[Lista2] [int] NULL,
	[Lista3] [int] NULL,
	[Comision] [nvarchar](50) NULL,
	[Peso] [nvarchar](50) NULL,
	[Pflete] [float] NULL,
	[Pcosto] [float] NULL,
	[Minima] [float] NULL,
	[ReteIca] [nvarchar](50) NULL,
	[ImputacionReteIca] [nvarchar](50) NULL,
	[CuentaCosto] [nvarchar](50) NULL,
	[ImputacionCosto] [nvarchar](50) NULL,
 CONSTRAINT [PK_Referencias] PRIMARY KEY CLUSTERED 
(
	[Referencia] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Resoluciones]

-- %%
/****** Object:  Table [dbo].[Resoluciones]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Resoluciones](
	[Idcentros] [int] IDENTITY(1,1) NOT NULL,
	[Centro] [nvarchar](50) NOT NULL,
	[Significado] [nvarchar](50) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[DireccionC] [nvarchar](250) NULL,
	[TelefonoC] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Situacion] [nvarchar](50) NULL,
	[Serial] [nvarchar](50) NULL,
	[Ciudad] [nvarchar](50) NULL,
	[Establecimiento] [nvarchar](250) NULL,
	[Tipo] [nvarchar](50) NULL,
	[ICA] [nvarchar](50) NULL,
	[ClTec] [nvarchar](250) NULL,
	[NroResolucion] [nvarchar](50) NULL,
	[FechaResolucion] [smalldatetime] NULL,
	[Desde] [nvarchar](50) NULL,
	[Hasta] [nvarchar](50) NULL,
	[IdProveedor] [nvarchar](50) NULL,
	[IdSoftware] [nvarchar](50) NULL,
	[NombreSoftware] [nvarchar](250) NULL,
	[Pin] [nvarchar](50) NULL,
	[CodigoSeguridad] [nvarchar](50) NULL,
	[Vigencia] [smalldatetime] NULL,
	[TipoAmbiente] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
 CONSTRAINT [PK_Resoluciones] PRIMARY KEY CLUSTERED 
(
	[Centro] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RespFiscal]

-- %%
/****** Object:  Table [dbo].[RespFiscal]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RespFiscal](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_RespFiscal] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Resuldebilidades]

-- %%
/****** Object:  Table [dbo].[Resuldebilidades]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Resuldebilidades](
	[IdResuldebilidades] [int] IDENTITY(1,1) NOT NULL,
	[Idcolegios] [int] NOT NULL,
	[Codigodeb] [int] NULL,
 CONSTRAINT [PK_Resuldebilidades] PRIMARY KEY CLUSTERED 
(
	[IdResuldebilidades] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Resulfortalezas]

-- %%
/****** Object:  Table [dbo].[Resulfortalezas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Resulfortalezas](
	[IdResulFortalezas] [int] IDENTITY(1,1) NOT NULL,
	[Idcolegios] [int] NOT NULL,
	[Codigofor] [int] NULL,
 CONSTRAINT [PK_Resulfortalezas] PRIMARY KEY CLUSTERED 
(
	[IdResulFortalezas] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Resulrecomendaciones]

-- %%
/****** Object:  Table [dbo].[Resulrecomendaciones]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Resulrecomendaciones](
	[IdResulrecomendaciones] [int] IDENTITY(1,1) NOT NULL,
	[Idcolegios] [int] NOT NULL,
	[Codigorec] [int] NULL,
 CONSTRAINT [PK_Resulrecomendaciones] PRIMARY KEY CLUSTERED 
(
	[IdResulrecomendaciones] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Resultados]

-- %%
/****** Object:  Table [dbo].[Resultados]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Resultados](
	[Idcolegios] [int] IDENTITY(1,1) NOT NULL,
	[Año] [int] NULL,
	[Periodo] [int] NULL,
	[Codigo] [nvarchar](50) NULL,
	[Materia] [nvarchar](250) NULL,
	[Calificacion] [nvarchar](250) NULL,
	[Fallas] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Curso] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Resultados] PRIMARY KEY CLUSTERED 
(
	[Idcolegios] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RetiroCaja]

-- %%
/****** Object:  Table [dbo].[RetiroCaja]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RetiroCaja](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[IdRetiro] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Nombre] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_RetiroCaja] PRIMARY KEY CLUSTERED 
(
	[IdRetiro] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Retirosub]

-- %%
/****** Object:  Table [dbo].[Retirosub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Retirosub](
	[IdRetirosub] [int] IDENTITY(1,1) NOT NULL,
	[IdRetiro] [int] NOT NULL,
	[TipoMedio] [nvarchar](250) NULL,
	[NDocumento] [int] NULL,
	[Banco] [nvarchar](250) NULL,
	[Neto] [int] NULL,
	[Notas] [nvarchar](250) NULL,
	[Tema] [nvarchar](250) NULL,
 CONSTRAINT [PK_Retirosub] PRIMARY KEY CLUSTERED 
(
	[IdRetirosub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Rutas]

-- %%
/****** Object:  Table [dbo].[Rutas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Rutas](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[OrigenDestino] [nvarchar](50) NOT NULL,
	[Origen] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
	[Recorrido] [ntext] NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Rutas] PRIMARY KEY CLUSTERED 
(
	[OrigenDestino] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Rutasub]

-- %%
/****** Object:  Table [dbo].[Rutasub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Rutasub](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Cobertura] [nvarchar](50) NULL,
	[Centrocostos] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Rutasub] PRIMARY KEY CLUSTERED 
(
	[Centrocostos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Salidas]

-- %%
/****** Object:  Table [dbo].[Salidas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Salidas](
	[Idsalidas] [int] IDENTITY(1,1) NOT NULL,
	[Idinventarios] [int] NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Cantidadsal] [float] NULL,
	[Precio] [float] NULL,
	[Precio total] [int] NULL,
	[Descuento] [float] NULL,
	[Peso] [float] NULL,
	[Subtotal] [int] NULL,
	[Serial] [nvarchar](250) NULL,
	[DO] [int] NULL,
	[Placa] [nvarchar](50) NULL,
 CONSTRAINT [PK_Salidas] PRIMARY KEY CLUSTERED 
(
	[Idsalidas] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Salidasenc]

-- %%
/****** Object:  Table [dbo].[Salidasenc]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Salidasenc](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Idinventarios] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Tercero] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Estado] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
 CONSTRAINT [PK_Salidasenc] PRIMARY KEY CLUSTERED 
(
	[Idinventarios] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Seguimiento]

-- %%
/****** Object:  Table [dbo].[Seguimiento]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Seguimiento](
	[Idseguimiento] [int] IDENTITY(1,1) NOT NULL,
	[NCotizacion] [int] NULL,
	[Fecha] [smalldatetime] NULL,
	[Resultado] [nvarchar](250) NULL,
	[Contacto] [nvarchar](250) NULL,
	[DO] [int] NULL,
	[FNueva] [smalldatetime] NULL,
	[Estado] [int] NULL,
	[Ejecucion] [nvarchar](50) NULL,
 CONSTRAINT [PK_Seguimiento] PRIMARY KEY CLUSTERED 
(
	[Idseguimiento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Seguimientotrans]

-- %%
/****** Object:  Table [dbo].[Seguimientotrans]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Seguimientotrans](
	[Idseguimiento] [int] IDENTITY(1,1) NOT NULL,
	[Fechaseg] [smalldatetime] NULL,
	[Hora] [smalldatetime] NULL,
	[Resultado] [nvarchar](50) NULL,
	[FProceso] [smalldatetime] NULL,
	[Tiposeguimiento] [int] NULL,
	[TipoDocumento] [nvarchar](50) NULL,
	[Gestor] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Nota] [nvarchar](250) NULL,
	[Placa] [nvarchar](250) NULL,
	[Conductor] [nvarchar](250) NULL,
	[Remesa] [int] NULL,
	[Status] [nvarchar](50) NULL,
 CONSTRAINT [PK_Seguimientotrans] PRIMARY KEY CLUSTERED 
(
	[Idseguimiento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SerialCompras]

-- %%
/****** Object:  Table [dbo].[SerialCompras]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SerialCompras](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[IdEntrada] [int] NULL,
	[Referencia] [nvarchar](50) NULL,
	[Serial] [nvarchar](250) NULL,
	[Fvenc] [smalldatetime] NULL,
 CONSTRAINT [PK_SerialCompras] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Sexo]

-- %%
/****** Object:  Table [dbo].[Sexo]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Sexo](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[codigo] [nvarchar](50) NOT NULL,
	[Sexo] [nvarchar](50) NULL,
 CONSTRAINT [PK_Sexo] PRIMARY KEY CLUSTERED 
(
	[codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Simulador]

-- %%
/****** Object:  Table [dbo].[Simulador]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Simulador](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[SimulaNo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Cedula] [nvarchar](50) NULL,
	[IngresoNeto] [int] NULL,
	[PExento] [float] NULL,
	[Bgravable] [int] NULL,
	[Meses] [int] NULL,
	[Promediomes] [int] NULL,
	[UVT] [int] NULL,
	[tuvt] [float] NULL,
	[Retencion] [int] NULL,
	[Pretefte] [float] NULL,
	[Estado] [int] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Documento] [nvarchar](50) NULL,
 CONSTRAINT [PK_Simulador] PRIMARY KEY CLUSTERED 
(
	[SimulaNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Simuladorsub]

-- %%
/****** Object:  Table [dbo].[Simuladorsub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Simuladorsub](
	[idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[SimulaNo] [int] NULL,
	[Concepto] [nvarchar](50) NULL,
	[Neto] [int] NULL,
	[Notas] [nvarchar](50) NULL,
 CONSTRAINT [PK_Simuladorsub] PRIMARY KEY CLUSTERED 
(
	[idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Situacion]

-- %%
/****** Object:  Table [dbo].[Situacion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Situacion](
	[Idsituacion] [int] IDENTITY(1,1) NOT NULL,
	[Situacion] [nvarchar](50) NOT NULL,
	[Observacion] [nvarchar](50) NULL,
 CONSTRAINT [PK_Situacion] PRIMARY KEY CLUSTERED 
(
	[Situacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Situación]

-- %%
/****** Object:  Table [dbo].[Situación]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Situación](
	[IdSituación] [int] IDENTITY(1,1) NOT NULL,
	[Situación] [nvarchar](20) NULL,
 CONSTRAINT [PK_Situación] PRIMARY KEY CLUSTERED 
(
	[IdSituación] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StatusCRM]

-- %%
/****** Object:  Table [dbo].[StatusCRM]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StatusCRM](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_StatusCRM] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy1]

-- %%
/****** Object:  Table [dbo].[Strategy1]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy1](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Empresa] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Strategy1] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy12]

-- %%
/****** Object:  Table [dbo].[Strategy12]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy12](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Tema] [nvarchar](50) NULL,
	[Descripcion] [ntext] NULL,
 CONSTRAINT [PK_Strategy12] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy13]

-- %%
/****** Object:  Table [dbo].[Strategy13]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy13](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Tipo] [nvarchar](50) NULL,
	[Nombre] [nvarchar](50) NULL,
	[Descripcion] [ntext] NULL,
 CONSTRAINT [PK_Strategy13] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy14]

-- %%
/****** Object:  Table [dbo].[Strategy14]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy14](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Tema] [nvarchar](50) NULL,
	[Descripcion] [ntext] NULL,
 CONSTRAINT [PK_Strategy14] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy15]

-- %%
/****** Object:  Table [dbo].[Strategy15]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy15](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Tema] [nvarchar](50) NULL,
	[Descripcion] [ntext] NULL,
 CONSTRAINT [PK_Strategy15] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy16]

-- %%
/****** Object:  Table [dbo].[Strategy16]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy16](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Tema] [nvarchar](50) NULL,
	[Descripcion] [ntext] NULL,
 CONSTRAINT [PK_Strategy16] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy17]

-- %%
/****** Object:  Table [dbo].[Strategy17]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy17](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Tipo] [nvarchar](50) NULL,
	[Factores] [nvarchar](50) NULL,
	[Descripcion] [ntext] NULL,
 CONSTRAINT [PK_Strategy17] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy18]

-- %%
/****** Object:  Table [dbo].[Strategy18]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy18](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Matrix] [nvarchar](50) NULL,
	[Tipo] [nvarchar](50) NULL,
	[Descripcion] [ntext] NULL,
	[Pondera] [float] NULL,
	[Calificacion] [float] NULL,
	[Resultado] [float] NULL,
 CONSTRAINT [PK_Strategy18] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy181]

-- %%
/****** Object:  Table [dbo].[Strategy181]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy181](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Matrix] [nvarchar](50) NULL,
	[Inicio] [float] NULL,
	[Fin] [float] NULL,
	[Status] [nvarchar](50) NULL,
	[Cuadrante] [nvarchar](50) NULL,
 CONSTRAINT [PK_Strategy181] PRIMARY KEY CLUSTERED 
(
	[idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy19]

-- %%
/****** Object:  Table [dbo].[Strategy19]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy19](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Descripcion] [ntext] NULL,
	[PonderaC0] [float] NULL,
	[CalificaC0] [float] NULL,
	[ResultadoC0] [float] NULL,
	[PonderaC1] [float] NULL,
	[CalificaC1] [float] NULL,
	[ResultadoC1] [float] NULL,
	[PonderaC2] [float] NULL,
	[CalificaC2] [float] NULL,
	[ResultadoC2] [float] NULL,
	[PonderaC3] [float] NULL,
	[CalificaC3] [float] NULL,
	[ResultadoC3] [float] NULL,
 CONSTRAINT [PK_Strategy19] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy2]

-- %%
/****** Object:  Table [dbo].[Strategy2]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy2](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Diagnostico] [int] NULL,
	[Empresa] [nvarchar](50) NULL,
	[Observaciones] [ntext] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Finicial] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
 CONSTRAINT [PK_Strategy2] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy20]

-- %%
/****** Object:  Table [dbo].[Strategy20]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy20](
	[Idcontrolbas] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Descripcion] [ntext] NULL,
	[Estado] [int] NULL,
	[Medida] [nvarchar](50) NULL,
 CONSTRAINT [PK_Strategy20] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy21]

-- %%
/****** Object:  Table [dbo].[Strategy21]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy21](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Meta] [int] NULL,
	[Responsable] [nvarchar](50) NULL,
 CONSTRAINT [PK_Strategy21] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC,
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy22]

-- %%
/****** Object:  Table [dbo].[Strategy22]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy22](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[FInicio] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
	[Costo] [int] NULL,
	[Responsable] [nvarchar](50) NULL,
 CONSTRAINT [PK_Strategy22] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC,
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy23]

-- %%
/****** Object:  Table [dbo].[Strategy23]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy23](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Nivel] [int] NOT NULL,
	[Significa] [nvarchar](50) NULL,
 CONSTRAINT [PK_Strategy23] PRIMARY KEY CLUSTERED 
(
	[Nivel] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy3]

-- %%
/****** Object:  Table [dbo].[Strategy3]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy3](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Formulacion] [int] NULL,
	[Empresa] [nvarchar](50) NULL,
	[Observaciones] [ntext] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Strategy3] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy31]

-- %%
/****** Object:  Table [dbo].[Strategy31]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy31](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Resultado] [int] NULL,
	[Responsable] [nvarchar](50) NULL,
 CONSTRAINT [PK_Strategy31] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC,
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy32]

-- %%
/****** Object:  Table [dbo].[Strategy32]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy32](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Resultado] [int] NULL,
	[Responsable] [nvarchar](50) NULL,
 CONSTRAINT [PK_Strategy32] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC,
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy5]

-- %%
/****** Object:  Table [dbo].[Strategy5]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy5](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Empresa] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Componente] [nvarchar](50) NULL,
 CONSTRAINT [PK_Strategy5] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy50]

-- %%
/****** Object:  Table [dbo].[Strategy50]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy50](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Empresa] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Componente] [nvarchar](50) NULL,
 CONSTRAINT [PK_Strategy50] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy51]

-- %%
/****** Object:  Table [dbo].[Strategy51]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy51](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Variable] [nvarchar](50) NOT NULL,
	[Descriptor] [nvarchar](50) NULL,
	[Codigo] [nvarchar](50) NULL,
	[Total] [float] NULL,
 CONSTRAINT [PK_Strategy51] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC,
	[Variable] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy52]

-- %%
/****** Object:  Table [dbo].[Strategy52]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy52](
	[Idcontrolbas] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Pondera] [float] NULL,
	[Qvar] [int] NULL,
	[Descripcion] [ntext] NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Strategy52] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy53]

-- %%
/****** Object:  Table [dbo].[Strategy53]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy53](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Nivel] [int] NOT NULL,
	[Significa] [nvarchar](50) NULL,
 CONSTRAINT [PK_Strategy53] PRIMARY KEY CLUSTERED 
(
	[Nivel] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy54]

-- %%
/****** Object:  Table [dbo].[Strategy54]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy54](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Componente] [nvarchar](50) NULL,
	[Tema] [nvarchar](50) NULL,
	[Descripcion] [ntext] NULL,
	[Responsable] [nvarchar](50) NULL,
 CONSTRAINT [PK_Strategy54] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy6]

-- %%
/****** Object:  Table [dbo].[Strategy6]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy6](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Empresa] [nvarchar](50) NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Componente] [nvarchar](50) NULL,
 CONSTRAINT [PK_Strategy6] PRIMARY KEY CLUSTERED 
(
	[Consecutivo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy61]

-- %%
/****** Object:  Table [dbo].[Strategy61]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy61](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Consecutivo] [int] NOT NULL,
	[Variable] [nvarchar](50) NULL,
	[Descriptor] [nvarchar](50) NULL,
	[Califica] [float] NULL,
 CONSTRAINT [PK_Strategy61] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Strategy62]

-- %%
/****** Object:  Table [dbo].[Strategy62]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Strategy62](
	[Idcontrolbas] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Descripcion] [ntext] NULL,
	[Estado] [int] NULL,
	[Pondera] [float] NULL,
 CONSTRAINT [PK_Strategy62] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Sucursales]

-- %%
/****** Object:  Table [dbo].[Sucursales]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Sucursales](
	[IdSucursales] [int] IDENTITY(1,1) NOT NULL,
	[Identificacion] [nvarchar](250) NOT NULL,
	[Sucursal] [nvarchar](100) NOT NULL,
	[Centro costos] [nvarchar](100) NOT NULL,
	[Ciudad] [nvarchar](250) NULL,
	[Direccion] [nvarchar](250) NULL,
	[Telefono] [nvarchar](250) NULL,
	[Contacto] [nvarchar](250) NULL,
	[Nombre] [nvarchar](250) NULL,
	[Promotor] [nvarchar](250) NULL,
	[Cumpleaños] [smalldatetime] NULL,
	[Horario] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Coordenadas] [nvarchar](50) NULL,
	[Llamar] [nvarchar](50) NULL,
 CONSTRAINT [PK_Sucursales_1] PRIMARY KEY CLUSTERED 
(
	[Identificacion] ASC,
	[Sucursal] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TablaUSistema]

-- %%
/****** Object:  Table [dbo].[TablaUSistema]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TablaUSistema](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[NombreUsuario] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_TablaUSistema] PRIMARY KEY CLUSTERED 
(
	[NombreUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tareas]

-- %%
/****** Object:  Table [dbo].[Tareas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tareas](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Destinatario] [nvarchar](50) NULL,
	[Fecha] [smalldatetime] NULL,
	[Elaboro] [nvarchar](50) NULL,
	[Tarea] [ntext] NULL,
	[Estado] [int] NULL,
	[Hecho] [nvarchar](50) NULL,
	[Ffinal] [smalldatetime] NULL,
	[Notas] [ntext] NULL,
	[Estado2] [int] NULL,
 CONSTRAINT [PK_Tareas] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tarifario]

-- %%
/****** Object:  Table [dbo].[Tarifario]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tarifario](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Origen] [nvarchar](50) NOT NULL,
	[Destino] [nvarchar](50) NOT NULL,
	[Tarifa] [float] NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Tarifario] PRIMARY KEY CLUSTERED 
(
	[Origen] ASC,
	[Destino] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tasa]

-- %%
/****** Object:  Table [dbo].[Tasa]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tasa](
	[idtasa] [int] IDENTITY(1,1) NOT NULL,
	[Fecha] [smalldatetime] NOT NULL,
	[Tasa] [float] NULL,
	[Estado] [int] NULL,
	[Neta] [float] NULL,
	[Adicion] [float] NULL,
 CONSTRAINT [PK_Tasa] PRIMARY KEY CLUSTERED 
(
	[Fecha] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TerceroEnviado]

-- %%
/****** Object:  Table [dbo].[TerceroEnviado]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TerceroEnviado](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[NUMIDTERCERO] [nvarchar](50) NOT NULL,
	[CODSEDETERCERO] [nvarchar](50) NOT NULL,
	[IDENVIADO] [nvarchar](50) NOT NULL,
	[NUMLICENCIA] [nvarchar](50) NULL,
 CONSTRAINT [PK_TerceroEnviado] PRIMARY KEY CLUSTERED 
(
	[NUMIDTERCERO] ASC,
	[CODSEDETERCERO] ASC,
	[IDENVIADO] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Terceros]

-- %%
/****** Object:  Table [dbo].[Terceros]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Terceros](
	[Idterceros] [int] IDENTITY(1,1) NOT NULL,
	[Tipoter] [nvarchar](250) NULL,
	[Identificacion] [nvarchar](250) NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Direccion] [nvarchar](250) NULL,
	[Telefono] [nvarchar](250) NULL,
	[Contacto] [nvarchar](250) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Retencion] [nvarchar](50) NULL,
	[PReteIca] [float] NULL,
	[PReteIva] [float] NULL,
	[Centro costos] [nvarchar](250) NULL,
	[Promotor] [nvarchar](250) NULL,
	[DiasPago] [int] NULL,
	[Medio] [nvarchar](250) NULL,
	[FormaPago] [nvarchar](250) NULL,
	[PDescuento] [float] NULL,
	[Vinculacion] [smalldatetime] NULL,
	[Cumpleaños] [smalldatetime] NULL,
	[Situacion] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Cupo] [int] NULL,
	[DiasVencimiento] [int] NULL,
	[DV] [nvarchar](250) NULL,
	[Clase] [nvarchar](250) NULL,
	[CodigoMpio] [nvarchar](250) NULL,
	[Codigo] [nvarchar](50) NULL,
	[Expedicion] [nvarchar](250) NULL,
	[Cuota] [int] NULL,
	[Cuenta] [nvarchar](250) NULL,
	[Imputacion] [nvarchar](250) NULL,
	[Apellido1] [nvarchar](50) NULL,
	[Apellido2] [nvarchar](50) NULL,
	[Nombre1] [nvarchar](50) NULL,
	[Nombre2] [nvarchar](50) NULL,
	[RazonSocial] [nvarchar](250) NULL,
	[FValidacion] [smalldatetime] NULL,
	[Celular] [nvarchar](250) NULL,
	[Pais] [nvarchar](50) NULL,
	[Email] [nvarchar](250) NULL,
	[Web] [nvarchar](250) NULL,
	[Zona] [nvarchar](50) NULL,
	[Acuerdos] [nvarchar](250) NULL,
	[Canal] [nvarchar](50) NULL,
	[Actividad] [nvarchar](50) NULL,
	[CodigoMpiofin] [nvarchar](50) NULL,
	[Cuentacartera] [nvarchar](50) NULL,
	[Imputacioncartera] [nvarchar](50) NULL,
	[PRetecree] [float] NULL,
	[CuentaRetecree] [nvarchar](50) NULL,
	[ImputacionRetecree] [nvarchar](50) NULL,
	[CuentaBanco] [nvarchar](50) NULL,
	[Banco] [nvarchar](50) NULL,
	[Lista] [nvarchar](50) NULL,
	[NumContrato] [int] NULL,
	[NumPoliza] [int] NULL,
	[CodHabilta] [nvarchar](50) NULL,
	[Regimen] [nvarchar](50) NULL,
	[Tipopersona] [nvarchar](50) NULL,
	[CodigoPostal] [nvarchar](50) NULL,
	[ResFiscal] [nvarchar](50) NULL,
 CONSTRAINT [PK_Terceros] PRIMARY KEY CLUSTERED 
(
	[Identificacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TercerosConceptos]

-- %%
/****** Object:  Table [dbo].[TercerosConceptos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TercerosConceptos](
	[IdConcepto] [int] IDENTITY(1,1) NOT NULL,
	[Tercero] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[Dias] [int] NULL,
	[Vigencia] [smalldatetime] NULL,
	[Notas] [nvarchar](250) NULL,
	[FchaInicio] [smalldatetime] NULL,
	[Fchacarta] [smalldatetime] NULL,
 CONSTRAINT [PK_TercerosConceptos] PRIMARY KEY CLUSTERED 
(
	[IdConcepto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tercerosref2]

-- %%
/****** Object:  Table [dbo].[Tercerosref2]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tercerosref2](
	[Idimporta] [int] IDENTITY(1,1) NOT NULL,
	[Id] [int] NOT NULL,
	[Concepto] [nvarchar](50) NULL,
	[Neto] [int] NULL,
 CONSTRAINT [PK_Tercerosref2] PRIMARY KEY CLUSTERED 
(
	[Idimporta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tercerosreferencias]

-- %%
/****** Object:  Table [dbo].[Tercerosreferencias]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tercerosreferencias](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[Identificacion] [nvarchar](250) NOT NULL,
	[Referenciater] [nvarchar](100) NOT NULL,
	[Ivater] [float] NULL,
	[Precioter] [float] NULL,
	[Costo] [float] NULL,
	[Utilidad] [int] NULL,
	[Rendimiento] [float] NULL,
	[Factualiza] [smalldatetime] NULL,
	[CodigoMpio] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Origen] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
	[Via] [nvarchar](50) NULL,
 CONSTRAINT [PK_Tercerosreferencias] PRIMARY KEY CLUSTERED 
(
	[Identificacion] ASC,
	[Referenciater] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Textomail]

-- %%
/****** Object:  Table [dbo].[Textomail]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Textomail](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Textomail] [ntext] NULL,
	[Copiamail] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Textomail] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tiempos]

-- %%
/****** Object:  Table [dbo].[Tiempos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tiempos](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Cumplido] [int] NULL,
	[Manifiesto] [int] NULL,
	[Remesa] [int] NULL,
	[HpacCargue] [int] NULL,
	[HpacDescargue] [int] NULL,
	[Fllegacargue] [smalldatetime] NULL,
	[Hllegacargue] [datetime] NULL,
	[Ffincargue] [smalldatetime] NULL,
	[Hfincargue] [datetime] NULL,
	[Fllegadescargue] [smalldatetime] NULL,
	[Hllegadescargue] [datetime] NULL,
	[Ffindescargue] [smalldatetime] NULL,
	[Hfindescargue] [datetime] NULL,
	[Placa] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Tiempos] PRIMARY KEY CLUSTERED 
(
	[idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TiemposPlaneado]

-- %%
/****** Object:  Table [dbo].[TiemposPlaneado]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TiemposPlaneado](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[OCargue] [int] NULL,
	[Manifiesto] [int] NULL,
	[Remesa] [int] NULL,
	[HpacCargue] [int] NULL,
	[HpacDescargue] [int] NULL,
	[Fllegacargue] [smalldatetime] NULL,
	[Hllegacargue] [datetime] NULL,
	[Ffincargue] [smalldatetime] NULL,
	[Hfincargue] [datetime] NULL,
	[Fllegadescargue] [smalldatetime] NULL,
	[Hllegadescargue] [datetime] NULL,
	[Ffindescargue] [smalldatetime] NULL,
	[Hfindescargue] [datetime] NULL,
	[Placa] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TiemposPlaneado] PRIMARY KEY CLUSTERED 
(
	[idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoAnticipo]

-- %%
/****** Object:  Table [dbo].[TipoAnticipo]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoAnticipo](
	[IdConcepto] [int] IDENTITY(1,1) NOT NULL,
	[Concepto] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoAnticipo] PRIMARY KEY CLUSTERED 
(
	[Concepto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoCoberturas]

-- %%
/****** Object:  Table [dbo].[TipoCoberturas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoCoberturas](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Cobertura] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoCoberturas] PRIMARY KEY CLUSTERED 
(
	[Cobertura] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoConcepto]

-- %%
/****** Object:  Table [dbo].[TipoConcepto]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoConcepto](
	[IdConcepto] [int] IDENTITY(1,1) NOT NULL,
	[Concepto] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoConcepto] PRIMARY KEY CLUSTERED 
(
	[Concepto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoConceptoNC]

-- %%
/****** Object:  Table [dbo].[TipoConceptoNC]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoConceptoNC](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoConceptoNC] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoConceptoND]

-- %%
/****** Object:  Table [dbo].[TipoConceptoND]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoConceptoND](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoConceptoND] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoContenedores]

-- %%
/****** Object:  Table [dbo].[TipoContenedores]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoContenedores](
	[IdContenedor] [int] IDENTITY(1,1) NOT NULL,
	[TipoPendiente] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
 CONSTRAINT [PK_TipoContenedores] PRIMARY KEY CLUSTERED 
(
	[TipoPendiente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoContrato]

-- %%
/****** Object:  Table [dbo].[TipoContrato]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoContrato](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoContrato] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoDocumento]

-- %%
/****** Object:  Table [dbo].[TipoDocumento]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoDocumento](
	[IdDocumentos] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoDocumento] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tipoempleado]

-- %%
/****** Object:  Table [dbo].[Tipoempleado]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tipoempleado](
	[Idtipoempleado] [int] IDENTITY(1,1) NOT NULL,
	[Tipoempleado] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
 CONSTRAINT [PK_Tipoempleado] PRIMARY KEY CLUSTERED 
(
	[Tipoempleado] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoEstado]

-- %%
/****** Object:  Table [dbo].[TipoEstado]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoEstado](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoEstado] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoFactura]

-- %%
/****** Object:  Table [dbo].[TipoFactura]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoFactura](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoFactura] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoFirmas]

-- %%
/****** Object:  Table [dbo].[TipoFirmas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoFirmas](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Significado] [nvarchar](50) NULL,
 CONSTRAINT [PK_TipoFirmas] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tipoguia]

-- %%
/****** Object:  Table [dbo].[Tipoguia]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tipoguia](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Tipoguia] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tipollamada]

-- %%
/****** Object:  Table [dbo].[Tipollamada]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tipollamada](
	[Idtipollamada] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
 CONSTRAINT [PK_Tipollamada] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoMoneda]

-- %%
/****** Object:  Table [dbo].[TipoMoneda]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoMoneda](
	[IdDocumentos] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoMoneda] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoNovedad]

-- %%
/****** Object:  Table [dbo].[TipoNovedad]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoNovedad](
	[IdDocumentos] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoNovedad] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoOperacion]

-- %%
/****** Object:  Table [dbo].[TipoOperacion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoOperacion](
	[Idcentros] [int] IDENTITY(1,1) NOT NULL,
	[Centro] [nvarchar](50) NOT NULL,
	[Significado] [nvarchar](250) NULL,
	[Observaciones] [ntext] NULL,
	[Estado] [int] NULL,
	[Situacion] [nvarchar](50) NULL,
	[Mostrar] [ntext] NULL,
	[Alterno] [nvarchar](50) NULL,
 CONSTRAINT [PK_TipoOperacion] PRIMARY KEY CLUSTERED 
(
	[Centro] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoOperfac]

-- %%
/****** Object:  Table [dbo].[TipoOperfac]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoOperfac](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoOperfac] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoOperNC]

-- %%
/****** Object:  Table [dbo].[TipoOperNC]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoOperNC](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](100) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoOperNC] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoOperND]

-- %%
/****** Object:  Table [dbo].[TipoOperND]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoOperND](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](100) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoOperND] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoPago]

-- %%
/****** Object:  Table [dbo].[TipoPago]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoPago](
	[IdConceptos] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](250) NOT NULL,
	[Concepto] [nvarchar](250) NULL,
	[Cuenta] [nvarchar](250) NULL,
	[Imputacion] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoPago] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoPendientes]

-- %%
/****** Object:  Table [dbo].[TipoPendientes]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoPendientes](
	[IdPendientes] [int] IDENTITY(1,1) NOT NULL,
	[TipoPendiente] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
 CONSTRAINT [PK_TipoPendientes] PRIMARY KEY CLUSTERED 
(
	[TipoPendiente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoPendientesConductor]

-- %%
/****** Object:  Table [dbo].[TipoPendientesConductor]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoPendientesConductor](
	[IdPendientes] [int] IDENTITY(1,1) NOT FOR REPLICATION NOT NULL,
	[TipoPendiente] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
 CONSTRAINT [PK_TipoPendientesConductor] PRIMARY KEY CLUSTERED 
(
	[TipoPendiente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoPersona]

-- %%
/****** Object:  Table [dbo].[TipoPersona]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoPersona](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoPersona] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoRegimen]

-- %%
/****** Object:  Table [dbo].[TipoRegimen]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoRegimen](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoRegimen] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoRetePracticada]

-- %%
/****** Object:  Table [dbo].[TipoRetePracticada]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoRetePracticada](
	[IdConceptos] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](250) NOT NULL,
	[Concepto] [nvarchar](250) NULL,
	[Cuenta] [nvarchar](250) NULL,
	[Imputacion] [nvarchar](250) NULL,
	[Base] [int] NULL,
	[Porcentaje] [float] NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoRetePracticada] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoReteRetenida]

-- %%
/****** Object:  Table [dbo].[TipoReteRetenida]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoReteRetenida](
	[IdConceptos] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](250) NOT NULL,
	[Concepto] [nvarchar](250) NULL,
	[Base] [int] NULL,
	[Porcentaje] [float] NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoReteRetenida] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tiposdaños]

-- %%
/****** Object:  Table [dbo].[Tiposdaños]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tiposdaños](
	[Iddaños] [int] IDENTITY(1,1) NOT NULL,
	[grupestado] [nvarchar](50) NULL,
	[tipodan] [nvarchar](250) NULL,
	[Nombredan] [nvarchar](250) NULL,
	[Namedan] [nvarchar](250) NULL,
	[Notas] [nvarchar](250) NULL,
 CONSTRAINT [PK_Tiposdaños_1] PRIMARY KEY CLUSTERED 
(
	[Iddaños] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoStatus]

-- %%
/****** Object:  Table [dbo].[TipoStatus]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoStatus](
	[IdDocumentos] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](50) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoStatus] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoStatusDian]

-- %%
/****** Object:  Table [dbo].[TipoStatusDian]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoStatusDian](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [int] NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoStatusDian] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoTarjeta]

-- %%
/****** Object:  Table [dbo].[TipoTarjeta]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoTarjeta](
	[IdTipotarjeta] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](250) NOT NULL,
	[Comision] [float] NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Cuenta] [nvarchar](50) NULL,
	[Imputacion] [nvarchar](50) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoTarjeta] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tipotercero]

-- %%
/****** Object:  Table [dbo].[Tipotercero]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tipotercero](
	[Tipoter] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
 CONSTRAINT [PK_Tipotercero] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoVehiculo]

-- %%
/****** Object:  Table [dbo].[TipoVehiculo]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoVehiculo](
	[IdTipov] [int] IDENTITY(1,1) NOT NULL,
	[Tipo] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_TipoVehiculo] PRIMARY KEY CLUSTERED 
(
	[Tipo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Transporte]

-- %%
/****** Object:  Table [dbo].[Transporte]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Transporte](
	[Idtransporte] [int] IDENTITY(1,1) NOT NULL,
	[Resolucion] [nvarchar](250) NULL,
	[CodRegional] [int] NULL,
	[CodEmpresa] [nvarchar](250) NULL,
	[Rangos] [nvarchar](250) NULL,
	[Prefijo] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Control] [nvarchar](50) NULL,
	[CiaSeguro] [nvarchar](50) NULL,
	[PolizaNo] [nvarchar](50) NULL,
	[VigenciaPoliza] [smalldatetime] NULL,
	[Ciudad] [nvarchar](50) NULL,
	[PorAnticipo] [float] NULL,
 CONSTRAINT [PK_Transporte] PRIMARY KEY CLUSTERED 
(
	[Idtransporte] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TransporteInformes]

-- %%
/****** Object:  Table [dbo].[TransporteInformes]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TransporteInformes](
	[IdInforme] [int] IDENTITY(1,1) NOT NULL,
	[Finicial] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
	[Limite] [int] NULL,
 CONSTRAINT [PK_TransporteInformes] PRIMARY KEY CLUSTERED 
(
	[IdInforme] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Trayectos]

-- %%
/****** Object:  Table [dbo].[Trayectos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Trayectos](
	[idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Ciudad] [nvarchar](50) NOT NULL,
	[Estado] [int] NULL,
	[Notas] [nvarchar](250) NULL,
 CONSTRAINT [PK_Trayectos] PRIMARY KEY CLUSTERED 
(
	[Ciudad] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Traza]

-- %%
/****** Object:  Table [dbo].[Traza]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Traza](
	[Idtraza] [int] IDENTITY(1,1) NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Funcionario] [nvarchar](250) NULL,
	[Actividades] [nvarchar](250) NULL,
	[Notas] [nvarchar](250) NULL,
 CONSTRAINT [PK_Traza] PRIMARY KEY CLUSTERED 
(
	[Idtraza] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tributaria]

-- %%
/****** Object:  Table [dbo].[Tributaria]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tributaria](
	[IdTributaria] [int] IDENTITY(1,1) NOT NULL,
	[IngresosGravados5] [nvarchar](50) NULL,
	[DescuentosGravados5] [nvarchar](50) NULL,
	[IngresosGravados16] [nvarchar](50) NULL,
	[DescuentosGravados16] [nvarchar](50) NULL,
	[IngresosExentos] [nvarchar](50) NULL,
	[DescuentosExentos] [nvarchar](50) NULL,
	[IngresosExcluidos] [nvarchar](50) NULL,
	[DescuentosExcluidos] [nvarchar](50) NULL,
	[IngresosNogravados] [nvarchar](50) NULL,
	[DescuentosNogravados] [nvarchar](50) NULL,
	[DevVentas] [nvarchar](50) NULL,
	[CompraBienes5] [nvarchar](50) NULL,
	[CompraBienes16] [nvarchar](50) NULL,
	[CompraServicios5] [nvarchar](50) NULL,
	[CompraServicios16] [nvarchar](50) NULL,
	[CompraNogravada] [nvarchar](50) NULL,
	[DevCompras] [nvarchar](50) NULL,
	[IvaGenerado5] [nvarchar](50) NULL,
	[IvaGenerado16] [nvarchar](50) NULL,
	[IvaDevolucionesCompras] [nvarchar](50) NULL,
	[DescontableCompraBienes5] [nvarchar](50) NULL,
	[DescontableCompraBienes16] [nvarchar](50) NULL,
	[DescontableCompraServicios5] [nvarchar](50) NULL,
	[DescontableCompraServicios16] [nvarchar](50) NULL,
	[IvaSimplificado] [nvarchar](50) NULL,
	[IvaDevVentas] [nvarchar](50) NULL,
	[ReteIvaDescontable] [nvarchar](50) NULL,
	[FAnterior] [nvarchar](50) NULL,
	[SancionIva] [int] NULL,
	[ReteIca descontable] [nvarchar](50) NULL,
	[TarifaIca] [float] NULL,
	[TarifaAvisos] [float] NULL,
	[SancionICA] [int] NULL,
	[RetefuenteCompras] [nvarchar](50) NULL,
	[RetefuenteServicios] [nvarchar](50) NULL,
	[RetefuenteHonorarios] [nvarchar](50) NULL,
	[RetefuenteComisiones] [nvarchar](50) NULL,
	[RetefuenteArriendos] [nvarchar](50) NULL,
	[RetefuenteSalarios] [nvarchar](50) NULL,
	[RetefuenteOtras] [nvarchar](50) NULL,
	[SancionRetefuente] [int] NULL,
	[ReteivaComun] [nvarchar](50) NULL,
	[ReteivaSimplificado] [nvarchar](50) NULL,
	[MoraIva] [float] NULL,
	[MoraIca] [float] NULL,
	[MoraRetefuente] [float] NULL,
	[Finicial] [smalldatetime] NULL,
	[Ffinal] [smalldatetime] NULL,
	[Retecree03] [nvarchar](50) NULL,
	[Retecree06] [nvarchar](50) NULL,
	[Retecree15] [nvarchar](50) NULL,
	[AutoRetecree03] [nvarchar](50) NULL,
	[AutoRetecree06] [nvarchar](50) NULL,
	[AutoRetecree15] [nvarchar](50) NULL,
	[SancionRetecree] [int] NULL,
 CONSTRAINT [PK_Tributaria] PRIMARY KEY CLUSTERED 
(
	[IdTributaria] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ubicaciondaños]

-- %%
/****** Object:  Table [dbo].[Ubicaciondaños]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ubicaciondaños](
	[Iddaños] [int] IDENTITY(1,1) NOT NULL,
	[Ubica] [nvarchar](50) NULL,
	[Nombreparte] [nvarchar](250) NULL,
	[Namedan] [nvarchar](250) NULL,
 CONSTRAINT [PK_Ubicaciondaños] PRIMARY KEY CLUSTERED 
(
	[Iddaños] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Unidades]

-- %%
/****** Object:  Table [dbo].[Unidades]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Unidades](
	[IdUnidad] [int] IDENTITY(1,1) NOT NULL,
	[Unidad] [nvarchar](250) NOT NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Unidades] PRIMARY KEY CLUSTERED 
(
	[Unidad] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UsAdmon]

-- %%
/****** Object:  Table [dbo].[UsAdmon]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UsAdmon](
	[usuario] [nvarchar](50) NOT NULL,
	[password] [nvarchar](50) NULL,
 CONSTRAINT [PK_UsAdmon] PRIMARY KEY CLUSTERED 
(
	[usuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[Idusuarios] [int] IDENTITY(1,1) NOT NULL,
	[usuario] [nvarchar](50) NOT NULL,
	[password] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Datosbasicos] [int] NULL,
	[Inventarios] [int] NULL,
	[Tesoreria] [int] NULL,
	[Nomina] [int] NULL,
	[Contabilidad] [int] NULL,
	[Activos] [int] NULL,
	[Presupuesto] [int] NULL,
	[Comerciales] [int] NULL,
	[Validador] [int] NULL,
	[Borrado] [int] NULL,
	[Interfaz] [int] NULL,
	[VER] [int] NULL,
	[Creacion] [int] NULL,
	[Terminal] [int] NOT NULL,
	[Validaseguridad] [int] NULL,
	[Mostrador] [int] NULL,
	[Credito] [int] NULL,
	[Diario] [int] NULL,
	[Bprecio] [int] NULL,
	[CentroCostos] [nvarchar](50) NULL,
	[CentroOperacion] [nvarchar](50) NULL,
	[Bcentro] [int] NULL,
	[Salidas] [int] NULL,
	[Parametros] [int] NULL,
	[Cotizaciones] [int] NULL,
	[Pedidos] [int] NULL,
	[Remisiones] [int] NULL,
	[NotasClientes] [int] NULL,
	[Inforcomerciales] [int] NULL,
	[Inforinventario] [int] NULL,
	[Compras] [int] NULL,
	[Traslados] [int] NULL,
	[NotasProveedores] [int] NULL,
	[Proceinventarios] [int] NULL,
	[Costoventas] [int] NULL,
	[Recaja] [int] NULL,
	[Egreso] [int] NULL,
	[Recajavirtual] [int] NULL,
	[Egresovirtual] [int] NULL,
	[Retiros] [int] NULL,
	[Chdevueltos] [int] NULL,
	[Infortesoreria] [int] NULL,
	[Despachos] [int] NULL,
	[Interes] [int] NULL,
	[Validacontable] [int] NULL,
	[Remote] [int] NULL,
	[Comex] [int] NULL,
	[ControlDO] [int] NULL,
	[Trans] [int] NULL,
	[Autentica] [int] NULL,
	[Admon] [int] NULL,
	[Valpw] [nvarchar](50) NULL,
	[Produccion] [int] NULL,
	[Calcenter] [int] NULL,
	[Consultafac] [int] NULL,
	[Aduanas] [int] NULL,
	[DIAN] [int] NULL,
	[ResCred] [nvarchar](50) NULL,
	[Multiresolucion] [int] NULL,
	[ResMulti] [nvarchar](50) NULL,
	[Conocimiento] [int] NULL,
 CONSTRAINT [PK_Users] PRIMARY KEY CLUSTERED 
(
	[usuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
/****** Object:  Table [dbo].[Usuarios]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[usuario] [nvarchar](250) NOT NULL,
	[password] [nvarchar](250) NULL,
 CONSTRAINT [PK_Usuarios] PRIMARY KEY CLUSTERED 
(
	[usuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Vehiculos]

-- %%
/****** Object:  Table [dbo].[Vehiculos]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Vehiculos](
	[IdVehiculos] [int] IDENTITY(1,1) NOT NULL,
	[Placa] [nvarchar](250) NOT NULL,
	[Marca] [nvarchar](250) NULL,
	[Linea] [int] NULL,
	[Modelo] [int] NULL,
	[Modelo_rep] [int] NULL,
	[Serie] [nvarchar](250) NULL,
	[Color] [int] NULL,
	[Carroceria] [int] NULL,
	[Reg_nal_carga] [nvarchar](250) NULL,
	[Configuracion] [nvarchar](255) NULL,
	[Peso_vacio] [int] NULL,
	[Num_pol_soat] [nvarchar](255) NULL,
	[Com_seg_soat] [nvarchar](250) NULL,
	[Ven_soat] [smalldatetime] NULL,
	[Placa_semi] [nvarchar](255) NULL,
	[Doc_Prop] [nvarchar](50) NULL,
	[Doc_ten] [nvarchar](50) NULL,
	[MOTOR] [nvarchar](50) NULL,
	[CAPACIDAD] [int] NULL,
	[EJES] [nvarchar](50) NULL,
	[Conductor] [nvarchar](50) NULL,
	[Repotenciado] [nvarchar](50) NULL,
	[TARJ PROP] [nvarchar](50) NULL,
	[FECHA EXP] [smalldatetime] NULL,
	[FECHA REG N] [smalldatetime] NULL,
	[AFILIACION] [nvarchar](50) NULL,
	[Nº AFILIAC] [nvarchar](50) NULL,
	[FECHA VENC 1] [smalldatetime] NULL,
	[GASES] [nvarchar](50) NULL,
	[FECHA VENC 2] [smalldatetime] NULL,
	[Matricula] [nvarchar](250) NULL,
	[Tipo] [nvarchar](250) NULL,
	[Vinculacion] [smalldatetime] NULL,
	[RutaFoto] [nvarchar](250) NULL,
	[Centrocostos] [nvarchar](250) NULL,
	[Estado] [int] NULL,
	[Situacion] [nvarchar](50) NULL,
	[Ruta] [nvarchar](250) NULL,
	[Combustible] [int] NULL,
	[Celular] [nvarchar](50) NULL,
	[Hidroneumatica] [smalldatetime] NULL,
	[LuzNegra] [smalldatetime] NULL,
	[Aforo] [nvarchar](50) NULL,
	[Clase] [nvarchar](50) NULL,
	[Enviado] [int] NULL,
	[Contractual] [nvarchar](50) NULL,
	[Vencontractual] [smalldatetime] NULL,
	[Ciacontratual] [nvarchar](50) NULL,
	[Extra] [nvarchar](50) NULL,
	[Venextra] [smalldatetime] NULL,
	[Ciaextra] [nvarchar](50) NULL,
	[Conductor2] [nvarchar](50) NULL,
	[Conductor3] [nvarchar](50) NULL,
	[Interno] [nvarchar](50) NULL,
	[Consumo] [int] NULL,
	[Movil] [nvarchar](50) NULL,
 CONSTRAINT [PK_Vehiculos] PRIMARY KEY CLUSTERED 
(
	[Placa] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[VehiculosEjecucion]

-- %%
/****** Object:  Table [dbo].[VehiculosEjecucion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[VehiculosEjecucion](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Placa] [nvarchar](50) NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Dias] [int] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Lectura] [int] NULL,
	[Referencia] [nvarchar](50) NULL,
	[Cantidad] [float] NULL,
	[Descripcion] [nvarchar](50) NULL,
	[Proveedor] [nvarchar](50) NULL,
	[Costo] [int] NULL,
	[Notas] [nvarchar](250) NULL,
	[Soporte] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Status] [nvarchar](50) NULL,
	[Ocompra] [int] NULL,
	[idplaneacion] [int] NULL,
	[Tipo] [nvarchar](50) NULL,
 CONSTRAINT [PK_VehiculosEjecucion] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Vehiculosmanteniento]

-- %%
/****** Object:  Table [dbo].[Vehiculosmanteniento]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Vehiculosmanteniento](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Placa] [nvarchar](50) NOT NULL,
	[Fecha] [smalldatetime] NULL,
	[Dias] [int] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Lectura] [int] NULL,
	[Referencia] [nvarchar](50) NULL,
	[Cantidad] [float] NULL,
	[Descripcion] [nvarchar](50) NULL,
	[Proveedor] [nvarchar](50) NULL,
	[Costo] [int] NULL,
	[Notas] [nvarchar](250) NULL,
	[Soporte] [nvarchar](50) NULL,
	[Estado] [int] NULL,
	[Status] [nvarchar](50) NULL,
	[Ocompra] [int] NULL,
	[Fplaneacion] [smalldatetime] NULL,
	[Fproceso] [smalldatetime] NULL,
	[Frealizado] [smalldatetime] NULL,
	[idplaneacion] [int] NULL,
 CONSTRAINT [PK_Vehiculosmanteniento] PRIMARY KEY CLUSTERED 
(
	[Idcontrol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[VehiculosPendientes]

-- %%
/****** Object:  Table [dbo].[VehiculosPendientes]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[VehiculosPendientes](
	[IdVehipendientes] [int] IDENTITY(1,1) NOT NULL,
	[Placa] [nvarchar](250) NOT NULL,
	[Tipo] [nvarchar](250) NULL,
	[Situacion] [nvarchar](250) NULL,
	[Notas] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Estado] [int] NULL,
	[Gestor] [nvarchar](50) NULL,
 CONSTRAINT [PK_VehiculosPendientes] PRIMARY KEY CLUSTERED 
(
	[IdVehipendientes] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Verificacion]

-- %%
/****** Object:  Table [dbo].[Verificacion]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Verificacion](
	[Idcontrol] [int] IDENTITY(1,1) NOT NULL,
	[Lista] [nvarchar](50) NOT NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Verificacion] PRIMARY KEY CLUSTERED 
(
	[Lista] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Verificacionsub]

-- %%
/****** Object:  Table [dbo].[Verificacionsub]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Verificacionsub](
	[Idcontrolsub] [int] IDENTITY(1,1) NOT NULL,
	[Lista] [nvarchar](50) NOT NULL,
	[Referencia] [nvarchar](250) NOT NULL,
	[Cantidad] [float] NULL,
	[Us] [float] NULL,
	[Precio] [float] NULL,
	[PIva] [float] NULL,
	[Notas] [nvarchar](250) NULL,
	[Placa] [nvarchar](50) NULL,
	[Origen] [nvarchar](50) NULL,
	[Destino] [nvarchar](50) NULL,
	[Costo] [int] NULL,
 CONSTRAINT [PK_Verificacionsub] PRIMARY KEY CLUSTERED 
(
	[Idcontrolsub] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[VersionDocumental]

-- %%
/****** Object:  Table [dbo].[VersionDocumental]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[VersionDocumental](
	[IdVersion] [int] IDENTITY(1,1) NOT NULL,
	[TipoDocumento] [nvarchar](50) NOT NULL,
	[Codversion] [nvarchar](50) NULL,
	[Version] [nvarchar](50) NULL,
	[Fversion] [smalldatetime] NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_VersionDocumental] PRIMARY KEY CLUSTERED 
(
	[TipoDocumento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[VirtualCEgreso]

-- %%
/****** Object:  Table [dbo].[VirtualCEgreso]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[VirtualCEgreso](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Idegreso] [int] NOT NULL,
	[Estado] [int] NULL,
	[Tipo] [nvarchar](250) NULL,
	[Pagado a] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Ciudad] [nvarchar](250) NULL,
	[Letras] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[Forma de pago] [nvarchar](250) NULL,
	[Pagador] [nvarchar](250) NULL,
	[Aprobado] [nvarchar](250) NULL,
	[Document] [nvarchar](50) NULL,
	[Documento] [nvarchar](250) NULL,
	[PDesc] [float] NULL,
	[Descuento] [float] NULL,
	[PRetencion] [float] NULL,
	[Retefuente] [int] NULL,
	[Pagar] [float] NULL,
	[Netor] [float] NULL,
	[Ivar] [int] NULL,
	[Pivar] [float] NULL,
	[PReteIca] [float] NULL,
	[ReteIca] [int] NULL,
	[PReteIva] [float] NULL,
	[ReteIva] [int] NULL,
	[Adicion] [float] NULL,
	[Banco] [nvarchar](250) NULL,
	[Comprobante] [int] NULL,
	[Vencimiento] [smalldatetime] NULL,
	[Situacion] [nvarchar](50) NULL,
	[Fproceso] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[DO] [int] NULL,
	[DifCambio] [int] NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
 CONSTRAINT [PK_VirtualCEgreso] PRIMARY KEY CLUSTERED 
(
	[Idegreso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[VirtualRecaja]

-- %%
/****** Object:  Table [dbo].[VirtualRecaja]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[VirtualRecaja](
	[IdControl] [int] IDENTITY(1,1) NOT NULL,
	[Idcaja] [int] NOT NULL,
	[Estado] [int] NULL,
	[Tipo] [nvarchar](50) NULL,
	[Ciudad] [nvarchar](250) NULL,
	[Fecha] [smalldatetime] NULL,
	[Nombre] [nvarchar](250) NULL,
	[Suma] [nvarchar](250) NULL,
	[Concepto] [nvarchar](250) NULL,
	[Formapago] [nvarchar](250) NULL,
	[Firma] [nvarchar](250) NULL,
	[Tipos] [nvarchar](250) NULL,
	[Documento] [nvarchar](250) NULL,
	[Document] [nvarchar](250) NULL,
	[PDesc] [float] NULL,
	[Descuento] [float] NULL,
	[PRetencion] [float] NULL,
	[Retefuente] [int] NULL,
	[Pagar] [float] NULL,
	[Netor] [float] NULL,
	[Ivar] [int] NULL,
	[Pivar] [float] NULL,
	[PReteIca] [float] NULL,
	[ReteIca] [int] NULL,
	[PReteIva] [float] NULL,
	[ReteIva] [int] NULL,
	[Adicion] [float] NULL,
	[Fproceso] [smalldatetime] NULL,
	[Centrocostos] [nvarchar](50) NULL,
	[TipoRetencion] [nvarchar](250) NULL,
	[DifCambio] [int] NULL,
	[Banco] [nvarchar](50) NULL,
	[Pcree] [float] NULL,
	[Retecree] [int] NULL,
	[Elaboro] [nvarchar](50) NULL,
 CONSTRAINT [PK_VirtualRecaja] PRIMARY KEY CLUSTERED 
(
	[Idcaja] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Zonas]

-- %%
/****** Object:  Table [dbo].[Zonas]    Script Date: 12/12/2022 08:38:53 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Zonas](
	[Idzona] [int] IDENTITY(1,1) NOT NULL,
	[Zona] [nvarchar](50) NOT NULL,
	[Significado] [nvarchar](50) NULL,
	[Observaciones] [nvarchar](250) NULL,
	[Estado] [int] NULL,
 CONSTRAINT [PK_Zonas] PRIMARY KEY CLUSTERED 
(
	[Zona] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_Academica_Estado]

-- %%
ALTER TABLE [dbo].[Academica] ADD  CONSTRAINT [DF_Academica_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Actividades_TCree]

-- %%
ALTER TABLE [dbo].[Actividades] ADD  CONSTRAINT [DF_Actividades_TCree]  DEFAULT ((0)) FOR [TCree]
GO

-- %% [markdown]
-- # [DF_Actividades_Estado]

-- %%
ALTER TABLE [dbo].[Actividades] ADD  CONSTRAINT [DF_Actividades_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Activos_PrecioCompra]

-- %%
ALTER TABLE [dbo].[Activos] ADD  CONSTRAINT [DF_Activos_PrecioCompra]  DEFAULT ((0)) FOR [PrecioCompra]
GO

-- %% [markdown]
-- # [DF_Activos_VidaDepreciable]

-- %%
ALTER TABLE [dbo].[Activos] ADD  CONSTRAINT [DF_Activos_VidaDepreciable]  DEFAULT ((0)) FOR [VidaDepreciable]
GO

-- %% [markdown]
-- # [DF_Activos_ValorRescate]

-- %%
ALTER TABLE [dbo].[Activos] ADD  CONSTRAINT [DF_Activos_ValorRescate]  DEFAULT ((0)) FOR [ValorRescate]
GO

-- %% [markdown]
-- # [DF_Activos_ValorActual]

-- %%
ALTER TABLE [dbo].[Activos] ADD  CONSTRAINT [DF_Activos_ValorActual]  DEFAULT ((0)) FOR [ValorActual]
GO

-- %% [markdown]
-- # [DF_Activos_Fproceso]

-- %%
ALTER TABLE [dbo].[Activos] ADD  CONSTRAINT [DF_Activos_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Activos_Documento]

-- %%
ALTER TABLE [dbo].[Activos] ADD  CONSTRAINT [DF_Activos_Documento]  DEFAULT (N'DP') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Activos_Estado]

-- %%
ALTER TABLE [dbo].[Activos] ADD  CONSTRAINT [DF_Activos_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Activos_Neto]

-- %%
ALTER TABLE [dbo].[Activos] ADD  CONSTRAINT [DF_Activos_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Activos_Procesar]

-- %%
ALTER TABLE [dbo].[Activos] ADD  CONSTRAINT [DF_Activos_Procesar]  DEFAULT (N'SI') FOR [Procesar]
GO

-- %% [markdown]
-- # [DF_Activos_Niif]

-- %%
ALTER TABLE [dbo].[Activos] ADD  CONSTRAINT [DF_Activos_Niif]  DEFAULT (N'SI') FOR [Niif]
GO

-- %% [markdown]
-- # [DF_Activos_Local]

-- %%
ALTER TABLE [dbo].[Activos] ADD  CONSTRAINT [DF_Activos_Local]  DEFAULT (N'SI') FOR [Local]
GO

-- %% [markdown]
-- # [DF_Activos fijos_Q1]

-- %%
ALTER TABLE [dbo].[Activos fijos] ADD  CONSTRAINT [DF_Activos fijos_Q1]  DEFAULT ((0)) FOR [Q1]
GO

-- %% [markdown]
-- # [DF_Activos fijos_CU1]

-- %%
ALTER TABLE [dbo].[Activos fijos] ADD  CONSTRAINT [DF_Activos fijos_CU1]  DEFAULT ((0)) FOR [CU1]
GO

-- %% [markdown]
-- # [DF_Activos fijos_VU1]

-- %%
ALTER TABLE [dbo].[Activos fijos] ADD  CONSTRAINT [DF_Activos fijos_VU1]  DEFAULT ((0)) FOR [VU1]
GO

-- %% [markdown]
-- # [DF_Activos fijos_Q2]

-- %%
ALTER TABLE [dbo].[Activos fijos] ADD  CONSTRAINT [DF_Activos fijos_Q2]  DEFAULT ((0)) FOR [Q2]
GO

-- %% [markdown]
-- # [DF_Activos fijos_CU2]

-- %%
ALTER TABLE [dbo].[Activos fijos] ADD  CONSTRAINT [DF_Activos fijos_CU2]  DEFAULT ((0)) FOR [CU2]
GO

-- %% [markdown]
-- # [DF_Activosub_Vida]

-- %%
ALTER TABLE [dbo].[Activosub] ADD  CONSTRAINT [DF_Activosub_Vida]  DEFAULT (0) FOR [Vida]
GO

-- %% [markdown]
-- # [DF_Adicion_Fecha]

-- %%
ALTER TABLE [dbo].[Adicion] ADD  CONSTRAINT [DF_Adicion_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Adicion_Estado]

-- %%
ALTER TABLE [dbo].[Adicion] ADD  CONSTRAINT [DF_Adicion_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Adicion_Documento]

-- %%
ALTER TABLE [dbo].[Adicion] ADD  CONSTRAINT [DF_Adicion_Documento]  DEFAULT (N'AT') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Adicionsub_Cantidad]

-- %%
ALTER TABLE [dbo].[Adicionsub] ADD  CONSTRAINT [DF_Adicionsub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Adicionsub_Neto]

-- %%
ALTER TABLE [dbo].[Adicionsub] ADD  CONSTRAINT [DF_Adicionsub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Adicionsub_Costo]

-- %%
ALTER TABLE [dbo].[Adicionsub] ADD  CONSTRAINT [DF_Adicionsub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Adicionsub_Estadosub]

-- %%
ALTER TABLE [dbo].[Adicionsub] ADD  CONSTRAINT [DF_Adicionsub_Estadosub]  DEFAULT ((0)) FOR [Estadosub]
GO

-- %% [markdown]
-- # [DF_Adicionsub_Estadoliq]

-- %%
ALTER TABLE [dbo].[Adicionsub] ADD  CONSTRAINT [DF_Adicionsub_Estadoliq]  DEFAULT ((0)) FOR [Estadoliq]
GO

-- %% [markdown]
-- # [DF_AduanaDeclara_Estado]

-- %%
ALTER TABLE [dbo].[AduanaDeclara] ADD  CONSTRAINT [DF_AduanaDeclara_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaDps_Estado]

-- %%
ALTER TABLE [dbo].[AduanaDps] ADD  CONSTRAINT [DF_AduanaDps_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaDpto_Estado]

-- %%
ALTER TABLE [dbo].[AduanaDpto] ADD  CONSTRAINT [DF_AduanaDpto_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaEmb_Estado]

-- %%
ALTER TABLE [dbo].[AduanaEmb] ADD  CONSTRAINT [DF_AduanaEmb_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_Documento]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_Documento]  DEFAULT ('DE') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_Estado]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_Fecha]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_TotalMoneda]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_TotalMoneda]  DEFAULT ((0)) FOR [TotalMoneda]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_PesoBruto]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_PesoBruto]  DEFAULT ((0)) FOR [PesoBruto]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_QPgAnticipados]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_QPgAnticipados]  DEFAULT ((0)) FOR [QPgAnticipados]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_QEmbarques]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_QEmbarques]  DEFAULT ((0)) FOR [QEmbarques]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_QEmbalajes]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_QEmbalajes]  DEFAULT ((0)) FOR [QEmbalajes]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_Cantidad]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_PesoNeto]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_PesoNeto]  DEFAULT ((0)) FOR [PesoNeto]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_VlrFOB]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_VlrFOB]  DEFAULT ((0)) FOR [VlrFOB]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_VAN]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_VAN]  DEFAULT ((0)) FOR [VAN]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_CIP]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_CIP]  DEFAULT ((0)) FOR [CIP]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_QSubpartidas]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_QSubpartidas]  DEFAULT ((0)) FOR [QSubpartidas]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_TPesoNeto]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_TPesoNeto]  DEFAULT ((0)) FOR [TPesoNeto]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_TFOB]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_TFOB]  DEFAULT ((0)) FOR [TFOB]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_TVAN]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_TVAN]  DEFAULT ((0)) FOR [TVAN]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_QHojasAnexas]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_QHojasAnexas]  DEFAULT ((0)) FOR [QHojasAnexas]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_VlrFletes]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_VlrFletes]  DEFAULT ((0)) FOR [VlrFletes]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_VlrSeguros]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_VlrSeguros]  DEFAULT ((0)) FOR [VlrSeguros]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_VlrOtros]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_VlrOtros]  DEFAULT ((0)) FOR [VlrOtros]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_VlrTExpo]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_VlrTExpo]  DEFAULT ((0)) FOR [VlrTExpo]
GO

-- %% [markdown]
-- # [DF_AduanaExpo_VlrReintegro]

-- %%
ALTER TABLE [dbo].[AduanaExpo] ADD  CONSTRAINT [DF_AduanaExpo_VlrReintegro]  DEFAULT ((0)) FOR [VlrReintegro]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_Documento]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_Documento]  DEFAULT ('DI') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_Estado]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_Fecha]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_TRM]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_TRM]  DEFAULT ((0)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_Cuotas]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_Cuotas]  DEFAULT ((0)) FOR [Cuotas]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_VlrCuotas]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_VlrCuotas]  DEFAULT ((0)) FOR [VlrCuotas]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_PesoBruto]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_PesoBruto]  DEFAULT ((0)) FOR [PesoBruto]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_PesoNeto]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_PesoNeto]  DEFAULT ((0)) FOR [PesoNeto]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_Bultos]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_Bultos]  DEFAULT ((0)) FOR [Bultos]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_NoSubpartidas]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_NoSubpartidas]  DEFAULT ((0)) FOR [NoSubpartidas]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_Cantidad]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_VlrFOB]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_VlrFOB]  DEFAULT ((0)) FOR [VlrFOB]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_VlrFletes]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_VlrFletes]  DEFAULT ((0)) FOR [VlrFletes]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_VlrSeguros]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_VlrSeguros]  DEFAULT ((0)) FOR [VlrSeguros]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_VlrOtros]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_VlrOtros]  DEFAULT ((0)) FOR [VlrOtros]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_VlrAjuste]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_VlrAjuste]  DEFAULT ((0)) FOR [VlrAjuste]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_VlrAduana]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_VlrAduana]  DEFAULT ((0)) FOR [VlrAduana]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_PArancel]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_PArancel]  DEFAULT ((0)) FOR [PArancel]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_BArancel]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_BArancel]  DEFAULT ((0)) FOR [BArancel]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_SArancel]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_SArancel]  DEFAULT ((0)) FOR [SArancel]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_TArancel]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_TArancel]  DEFAULT ((0)) FOR [TArancel]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_UArancel]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_UArancel]  DEFAULT ((0)) FOR [UArancel]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_PIVA]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_PIVA]  DEFAULT ((0)) FOR [PIVA]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_BIVA]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_BIVA]  DEFAULT ((0)) FOR [BIVA]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_SIVA]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_SIVA]  DEFAULT ((0)) FOR [SIVA]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_TIVA]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_TIVA]  DEFAULT ((0)) FOR [TIVA]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_UIVA]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_UIVA]  DEFAULT ((0)) FOR [UIVA]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_PSalva]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_PSalva]  DEFAULT ((0)) FOR [PSalva]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_BSalva]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_BSalva]  DEFAULT ((0)) FOR [BSalva]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_SSalva]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_SSalva]  DEFAULT ((0)) FOR [SSalva]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_TSalva]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_TSalva]  DEFAULT ((0)) FOR [TSalva]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_USalva]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_USalva]  DEFAULT ((0)) FOR [USalva]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_PCompensa]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_PCompensa]  DEFAULT ((0)) FOR [PCompensa]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_BCompensa]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_BCompensa]  DEFAULT ((0)) FOR [BCompensa]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_SCompensa]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_SCompensa]  DEFAULT ((0)) FOR [SCompensa]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_TCompensa]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_TCompensa]  DEFAULT ((0)) FOR [TCompensa]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_UCompensa]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_UCompensa]  DEFAULT ((0)) FOR [UCompensa]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_PAntid]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_PAntid]  DEFAULT ((0)) FOR [PAntid]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_BAntid]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_BAntid]  DEFAULT ((0)) FOR [BAntid]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_SAntid]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_SAntid]  DEFAULT ((0)) FOR [SAntid]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_TAntid]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_TAntid]  DEFAULT ((0)) FOR [TAntid]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_UAntid]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_UAntid]  DEFAULT ((0)) FOR [UAntid]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_PSancion]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_PSancion]  DEFAULT ((0)) FOR [PSancion]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_BSancion]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_BSancion]  DEFAULT ((0)) FOR [BSancion]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_SSancion]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_SSancion]  DEFAULT ((0)) FOR [SSancion]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_TSancion]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_TSancion]  DEFAULT ((0)) FOR [TSancion]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_PRescate]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_PRescate]  DEFAULT ((0)) FOR [PRescate]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_BRescate]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_BRescate]  DEFAULT ((0)) FOR [BRescate]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_SRescate]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_SRescate]  DEFAULT ((0)) FOR [SRescate]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_TRescate]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_TRescate]  DEFAULT ((0)) FOR [TRescate]
GO

-- %% [markdown]
-- # [DF_AduanaImpo_Pagoant]

-- %%
ALTER TABLE [dbo].[AduanaImpo] ADD  CONSTRAINT [DF_AduanaImpo_Pagoant]  DEFAULT ((0)) FOR [Pagoant]
GO

-- %% [markdown]
-- # [DF_AduanaIng_Estado]

-- %%
ALTER TABLE [dbo].[AduanaIng] ADD  CONSTRAINT [DF_AduanaIng_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaLiq_Fecha]

-- %%
ALTER TABLE [dbo].[AduanaLiq] ADD  CONSTRAINT [DF_AduanaLiq_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_AduanaLiq_TRM]

-- %%
ALTER TABLE [dbo].[AduanaLiq] ADD  CONSTRAINT [DF_AduanaLiq_TRM]  DEFAULT ((0)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_AduanaLiq_Documento]

-- %%
ALTER TABLE [dbo].[AduanaLiq] ADD  CONSTRAINT [DF_AduanaLiq_Documento]  DEFAULT ('LI') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_AduanaLiq_Estado]

-- %%
ALTER TABLE [dbo].[AduanaLiq] ADD  CONSTRAINT [DF_AduanaLiq_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_PesoBruto]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_PesoBruto]  DEFAULT ((0)) FOR [PesoBruto]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_PesoNeto]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_PesoNeto]  DEFAULT ((0)) FOR [PesoNeto]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_Bultos]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_Bultos]  DEFAULT ((0)) FOR [Bultos]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_Cantidad]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_FOB]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_FOB]  DEFAULT ((0)) FOR [FOB]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_Fletes]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_Fletes]  DEFAULT ((0)) FOR [Fletes]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_Seguro]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_Seguro]  DEFAULT ((0)) FOR [Seguro]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_Otros]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_Otros]  DEFAULT ((0)) FOR [Otros]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_Ajustes]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_Ajustes]  DEFAULT ((0)) FOR [Ajustes]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_Aduana]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_Aduana]  DEFAULT ((0)) FOR [Aduana]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_CIF]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_CIF]  DEFAULT ((0)) FOR [CIF]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_PArancel]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_PArancel]  DEFAULT ((0)) FOR [PArancel]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_Arancel]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_Arancel]  DEFAULT ((0)) FOR [Arancel]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_Piva]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_Piva]  DEFAULT ((0)) FOR [Piva]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_Iva]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_Iva]  DEFAULT ((0)) FOR [Iva]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_Sanciones]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_Sanciones]  DEFAULT ((0)) FOR [Sanciones]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_OtrosPagos]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_OtrosPagos]  DEFAULT ((0)) FOR [OtrosPagos]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_PagoAnt]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_PagoAnt]  DEFAULT ((0)) FOR [PagoAnt]
GO

-- %% [markdown]
-- # [DF_AduanaLiqsub_TPagar]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub] ADD  CONSTRAINT [DF_AduanaLiqsub_TPagar]  DEFAULT ((0)) FOR [TPagar]
GO

-- %% [markdown]
-- # [DF_AduanaMdEx_Estado]

-- %%
ALTER TABLE [dbo].[AduanaMdEx] ADD  CONSTRAINT [DF_AduanaMdEx_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaMod_Estado]

-- %%
ALTER TABLE [dbo].[AduanaMod] ADD  CONSTRAINT [DF_AduanaMod_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaPago_Estado]

-- %%
ALTER TABLE [dbo].[AduanaPago] ADD  CONSTRAINT [DF_AduanaPago_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaPartidas_Estado]

-- %%
ALTER TABLE [dbo].[AduanaPartidas] ADD  CONSTRAINT [DF_AduanaPartidas_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaPartidas_PArancelp]

-- %%
ALTER TABLE [dbo].[AduanaPartidas] ADD  CONSTRAINT [DF_AduanaPartidas_PArancelp]  DEFAULT ((0)) FOR [PArancelp]
GO

-- %% [markdown]
-- # [DF_AduanaPartidas_PIvap]

-- %%
ALTER TABLE [dbo].[AduanaPartidas] ADD  CONSTRAINT [DF_AduanaPartidas_PIvap]  DEFAULT ((0)) FOR [PIvap]
GO

-- %% [markdown]
-- # [DF_AduanaReg_Estado]

-- %%
ALTER TABLE [dbo].[AduanaReg] ADD  CONSTRAINT [DF_AduanaReg_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaSec_Estado]

-- %%
ALTER TABLE [dbo].[AduanaSec] ADD  CONSTRAINT [DF_AduanaSec_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaTimp_Estado]

-- %%
ALTER TABLE [dbo].[AduanaTimp] ADD  CONSTRAINT [DF_AduanaTimp_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaTrans_Estado]

-- %%
ALTER TABLE [dbo].[AduanaTrans] ADD  CONSTRAINT [DF_AduanaTrans_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_AduanaUni_Estado]

-- %%
ALTER TABLE [dbo].[AduanaUni] ADD  CONSTRAINT [DF_AduanaUni_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Aerolineas_Estado]

-- %%
ALTER TABLE [dbo].[Aerolineas] ADD  CONSTRAINT [DF_Aerolineas_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Aeropuertos_Estado]

-- %%
ALTER TABLE [dbo].[Aeropuertos] ADD  CONSTRAINT [DF_Aeropuertos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Afactura_Factura]

-- %%
ALTER TABLE [dbo].[Afactura] ADD  CONSTRAINT [DF_Afactura_Factura]  DEFAULT ((0)) FOR [Factura]
GO

-- %% [markdown]
-- # [DF_Afactura_Neto]

-- %%
ALTER TABLE [dbo].[Afactura] ADD  CONSTRAINT [DF_Afactura_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Afactura_US]

-- %%
ALTER TABLE [dbo].[Afactura] ADD  CONSTRAINT [DF_Afactura_US]  DEFAULT ((0)) FOR [US]
GO

-- %% [markdown]
-- # [DF_Afactura_VRecibido]

-- %%
ALTER TABLE [dbo].[Afactura] ADD  CONSTRAINT [DF_Afactura_VRecibido]  DEFAULT ((0)) FOR [VRecibido]
GO

-- %% [markdown]
-- # [DF_Afactura_Tasa]

-- %%
ALTER TABLE [dbo].[Afactura] ADD  CONSTRAINT [DF_Afactura_Tasa]  DEFAULT ((0)) FOR [Tasa]
GO

-- %% [markdown]
-- # [DF_Afactura_Docu]

-- %%
ALTER TABLE [dbo].[Afactura] ADD  CONSTRAINT [DF_Afactura_Docu]  DEFAULT (N'FV') FOR [Docu]
GO

-- %% [markdown]
-- # [DF_Afactura_Dias]

-- %%
ALTER TABLE [dbo].[Afactura] ADD  CONSTRAINT [DF_Afactura_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Afactura_TRM]

-- %%
ALTER TABLE [dbo].[Afactura] ADD  CONSTRAINT [DF_Afactura_TRM]  DEFAULT ((0)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Afacturaegreso_Factura]

-- %%
ALTER TABLE [dbo].[Afacturaegreso] ADD  CONSTRAINT [DF_Afacturaegreso_Factura]  DEFAULT ((0)) FOR [Factura]
GO

-- %% [markdown]
-- # [DF_Afacturaegreso_Neto]

-- %%
ALTER TABLE [dbo].[Afacturaegreso] ADD  CONSTRAINT [DF_Afacturaegreso_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Afacturaegreso_US]

-- %%
ALTER TABLE [dbo].[Afacturaegreso] ADD  CONSTRAINT [DF_Afacturaegreso_US]  DEFAULT ((0)) FOR [US]
GO

-- %% [markdown]
-- # [DF_Afacturaegreso_VRecibido]

-- %%
ALTER TABLE [dbo].[Afacturaegreso] ADD  CONSTRAINT [DF_Afacturaegreso_VRecibido]  DEFAULT ((0)) FOR [VRecibido]
GO

-- %% [markdown]
-- # [DF_Afacturaegreso_Tasa]

-- %%
ALTER TABLE [dbo].[Afacturaegreso] ADD  CONSTRAINT [DF_Afacturaegreso_Tasa]  DEFAULT ((0)) FOR [Tasa]
GO

-- %% [markdown]
-- # [DF_Afacturaegreso_TRM]

-- %%
ALTER TABLE [dbo].[Afacturaegreso] ADD  CONSTRAINT [DF_Afacturaegreso_TRM]  DEFAULT ((0)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Afacturaegreso_Docu]

-- %%
ALTER TABLE [dbo].[Afacturaegreso] ADD  CONSTRAINT [DF_Afacturaegreso_Docu]  DEFAULT (N'FP') FOR [Docu]
GO

-- %% [markdown]
-- # [DF_Afacturaegreso_Manifiesto]

-- %%
ALTER TABLE [dbo].[Afacturaegreso] ADD  CONSTRAINT [DF_Afacturaegreso_Manifiesto]  DEFAULT ((0)) FOR [Manifiesto]
GO

-- %% [markdown]
-- # [DF_Afacturaegreso_Doctransporte]

-- %%
ALTER TABLE [dbo].[Afacturaegreso] ADD  CONSTRAINT [DF_Afacturaegreso_Doctransporte]  DEFAULT (N'MC') FOR [Doctransporte]
GO

-- %% [markdown]
-- # [DF_AfacturaEgresoVirtual_Factura]

-- %%
ALTER TABLE [dbo].[AfacturaEgresoVirtual] ADD  CONSTRAINT [DF_AfacturaEgresoVirtual_Factura]  DEFAULT ((0)) FOR [Factura]
GO

-- %% [markdown]
-- # [DF_AfacturaEgresoVirtual_Neto]

-- %%
ALTER TABLE [dbo].[AfacturaEgresoVirtual] ADD  CONSTRAINT [DF_AfacturaEgresoVirtual_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_AfacturaEgresoVirtual_US]

-- %%
ALTER TABLE [dbo].[AfacturaEgresoVirtual] ADD  CONSTRAINT [DF_AfacturaEgresoVirtual_US]  DEFAULT ((0)) FOR [US]
GO

-- %% [markdown]
-- # [DF_AfacturaEgresoVirtual_VRecibido]

-- %%
ALTER TABLE [dbo].[AfacturaEgresoVirtual] ADD  CONSTRAINT [DF_AfacturaEgresoVirtual_VRecibido]  DEFAULT ((0)) FOR [VRecibido]
GO

-- %% [markdown]
-- # [DF_AfacturaEgresoVirtual_Tasa]

-- %%
ALTER TABLE [dbo].[AfacturaEgresoVirtual] ADD  CONSTRAINT [DF_AfacturaEgresoVirtual_Tasa]  DEFAULT ((0)) FOR [Tasa]
GO

-- %% [markdown]
-- # [DF_AfacturaEgresoVirtual_TRM]

-- %%
ALTER TABLE [dbo].[AfacturaEgresoVirtual] ADD  CONSTRAINT [DF_AfacturaEgresoVirtual_TRM]  DEFAULT ((0)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_AfacturaEgresoVirtual_Manifiesto]

-- %%
ALTER TABLE [dbo].[AfacturaEgresoVirtual] ADD  CONSTRAINT [DF_AfacturaEgresoVirtual_Manifiesto]  DEFAULT ((0)) FOR [Manifiesto]
GO

-- %% [markdown]
-- # [DF_AfacturaEgresoVirtual_Docu]

-- %%
ALTER TABLE [dbo].[AfacturaEgresoVirtual] ADD  CONSTRAINT [DF_AfacturaEgresoVirtual_Docu]  DEFAULT (N'FP') FOR [Docu]
GO

-- %% [markdown]
-- # [DF_AfacturaEgresoVirtual_Doctransporte]

-- %%
ALTER TABLE [dbo].[AfacturaEgresoVirtual] ADD  CONSTRAINT [DF_AfacturaEgresoVirtual_Doctransporte]  DEFAULT (N'MC') FOR [Doctransporte]
GO

-- %% [markdown]
-- # [DF_AfacturaVirtual_Factura]

-- %%
ALTER TABLE [dbo].[AfacturaVirtual] ADD  CONSTRAINT [DF_AfacturaVirtual_Factura]  DEFAULT ((0)) FOR [Factura]
GO

-- %% [markdown]
-- # [DF_AfacturaVirtual_Neto]

-- %%
ALTER TABLE [dbo].[AfacturaVirtual] ADD  CONSTRAINT [DF_AfacturaVirtual_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_AfacturaVirtual_US]

-- %%
ALTER TABLE [dbo].[AfacturaVirtual] ADD  CONSTRAINT [DF_AfacturaVirtual_US]  DEFAULT ((0)) FOR [US]
GO

-- %% [markdown]
-- # [DF_AfacturaVirtual_VRecibido]

-- %%
ALTER TABLE [dbo].[AfacturaVirtual] ADD  CONSTRAINT [DF_AfacturaVirtual_VRecibido]  DEFAULT ((0)) FOR [VRecibido]
GO

-- %% [markdown]
-- # [DF_AfacturaVirtual_Tasa]

-- %%
ALTER TABLE [dbo].[AfacturaVirtual] ADD  CONSTRAINT [DF_AfacturaVirtual_Tasa]  DEFAULT ((0)) FOR [Tasa]
GO

-- %% [markdown]
-- # [DF_AfacturaVirtual_Docu]

-- %%
ALTER TABLE [dbo].[AfacturaVirtual] ADD  CONSTRAINT [DF_AfacturaVirtual_Docu]  DEFAULT (N'FV') FOR [Docu]
GO

-- %% [markdown]
-- # [DF_AfacturaVirtual_TRM]

-- %%
ALTER TABLE [dbo].[AfacturaVirtual] ADD  CONSTRAINT [DF_AfacturaVirtual_TRM]  DEFAULT ((0)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Agenda2_Estado]

-- %%
ALTER TABLE [dbo].[Agenda2] ADD  CONSTRAINT [DF_Agenda2_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Agentes_Estado]

-- %%
ALTER TABLE [dbo].[Agentes] ADD  CONSTRAINT [DF_Agentes_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Aghouse_Fecha]

-- %%
ALTER TABLE [dbo].[Aghouse] ADD  CONSTRAINT [DF_Aghouse_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Aghouse_estado]

-- %%
ALTER TABLE [dbo].[Aghouse] ADD  CONSTRAINT [DF_Aghouse_estado]  DEFAULT ((0)) FOR [estado]
GO

-- %% [markdown]
-- # [DF_Aghouse_EstadoOrden]

-- %%
ALTER TABLE [dbo].[Aghouse] ADD  CONSTRAINT [DF_Aghouse_EstadoOrden]  DEFAULT (N'ABR') FOR [EstadoOrden]
GO

-- %% [markdown]
-- # [DF_Aghouse_TipoDocumento]

-- %%
ALTER TABLE [dbo].[Aghouse] ADD  CONSTRAINT [DF_Aghouse_TipoDocumento]  DEFAULT (N'HBL') FOR [TipoDocumento]
GO

-- %% [markdown]
-- # [DF_Aghouse_Terminal]

-- %%
ALTER TABLE [dbo].[Aghouse] ADD  CONSTRAINT [DF_Aghouse_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_Aghouse_FCambioestado]

-- %%
ALTER TABLE [dbo].[Aghouse] ADD  CONSTRAINT [DF_Aghouse_FCambioestado]  DEFAULT (getdate()) FOR [FCambioestado]
GO

-- %% [markdown]
-- # [DF_Aghouse_TRM]

-- %%
ALTER TABLE [dbo].[Aghouse] ADD  CONSTRAINT [DF_Aghouse_TRM]  DEFAULT ((0)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Aghouse_TContenedores]

-- %%
ALTER TABLE [dbo].[Aghouse] ADD  CONSTRAINT [DF_Aghouse_TContenedores]  DEFAULT ((0)) FOR [TContenedores]
GO

-- %% [markdown]
-- # [DF_Aghouse_TBL]

-- %%
ALTER TABLE [dbo].[Aghouse] ADD  CONSTRAINT [DF_Aghouse_TBL]  DEFAULT ((0)) FOR [TBL]
GO

-- %% [markdown]
-- # [DF_Aghouseanexos_Estado]

-- %%
ALTER TABLE [dbo].[Aghouseanexos] ADD  CONSTRAINT [DF_Aghouseanexos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Aghousecontenedor_Tamaño]

-- %%
ALTER TABLE [dbo].[Aghousecontenedor] ADD  CONSTRAINT [DF_Aghousecontenedor_Tamaño]  DEFAULT ((0)) FOR [Tamaño]
GO

-- %% [markdown]
-- # [DF_Aghousecontenedor_Cantidad]

-- %%
ALTER TABLE [dbo].[Aghousecontenedor] ADD  CONSTRAINT [DF_Aghousecontenedor_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Aghousecontenedor_Kilos]

-- %%
ALTER TABLE [dbo].[Aghousecontenedor] ADD  CONSTRAINT [DF_Aghousecontenedor_Kilos]  DEFAULT ((0)) FOR [Kilos]
GO

-- %% [markdown]
-- # [DF_Aghousecontenedor_Volumen]

-- %%
ALTER TABLE [dbo].[Aghousecontenedor] ADD  CONSTRAINT [DF_Aghousecontenedor_Volumen]  DEFAULT ((0)) FOR [Volumen]
GO

-- %% [markdown]
-- # [DF_Aghousefletes_Neto]

-- %%
ALTER TABLE [dbo].[Aghousefletes] ADD  CONSTRAINT [DF_Aghousefletes_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Aghousefletes_Netoreal]

-- %%
ALTER TABLE [dbo].[Aghousefletes] ADD  CONSTRAINT [DF_Aghousefletes_Netoreal]  DEFAULT ((0)) FOR [Netoreal]
GO

-- %% [markdown]
-- # [DF_Aghousefletes_TRM1]

-- %%
ALTER TABLE [dbo].[Aghousefletes] ADD  CONSTRAINT [DF_Aghousefletes_TRM1]  DEFAULT ((0)) FOR [TRM1]
GO

-- %% [markdown]
-- # [DF_Aghousefletes_TRM2]

-- %%
ALTER TABLE [dbo].[Aghousefletes] ADD  CONSTRAINT [DF_Aghousefletes_TRM2]  DEFAULT ((0)) FOR [TRM2]
GO

-- %% [markdown]
-- # [DF_Aghousefletes_Certifica]

-- %%
ALTER TABLE [dbo].[Aghousefletes] ADD  CONSTRAINT [DF_Aghousefletes_Certifica]  DEFAULT (N'SI') FOR [Certifica]
GO

-- %% [markdown]
-- # [DF_Aghousefletes_Pesos]

-- %%
ALTER TABLE [dbo].[Aghousefletes] ADD  CONSTRAINT [DF_Aghousefletes_Pesos]  DEFAULT ((0)) FOR [Pesos]
GO

-- %% [markdown]
-- # [DF_Aghousefletes_Cantidad]

-- %%
ALTER TABLE [dbo].[Aghousefletes] ADD  CONSTRAINT [DF_Aghousefletes_Cantidad]  DEFAULT ((1)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Aghousefletes_Anticipo]

-- %%
ALTER TABLE [dbo].[Aghousefletes] ADD  CONSTRAINT [DF_Aghousefletes_Anticipo]  DEFAULT ((0)) FOR [Anticipo]
GO

-- %% [markdown]
-- # [DF_Aghousefletes_Costous]

-- %%
ALTER TABLE [dbo].[Aghousefletes] ADD  CONSTRAINT [DF_Aghousefletes_Costous]  DEFAULT ((0)) FOR [Costous]
GO

-- %% [markdown]
-- # [DF_Aghousefletes_Estado]

-- %%
ALTER TABLE [dbo].[Aghousefletes] ADD  CONSTRAINT [DF_Aghousefletes_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Aghousefletes_Peso]

-- %%
ALTER TABLE [dbo].[Aghousefletes] ADD  CONSTRAINT [DF_Aghousefletes_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Aghousefletes_Preciounit]

-- %%
ALTER TABLE [dbo].[Aghousefletes] ADD  CONSTRAINT [DF_Aghousefletes_Preciounit]  DEFAULT ((0)) FOR [Preciounit]
GO

-- %% [markdown]
-- # [DF_Aghousefletes_Costounit]

-- %%
ALTER TABLE [dbo].[Aghousefletes] ADD  CONSTRAINT [DF_Aghousefletes_Costounit]  DEFAULT ((0)) FOR [Costounit]
GO

-- %% [markdown]
-- # [DF_Aghouseservicios_Neto]

-- %%
ALTER TABLE [dbo].[Aghouseservicios] ADD  CONSTRAINT [DF_Aghouseservicios_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Aghouseservicios_Netoreal]

-- %%
ALTER TABLE [dbo].[Aghouseservicios] ADD  CONSTRAINT [DF_Aghouseservicios_Netoreal]  DEFAULT ((0)) FOR [Netoreal]
GO

-- %% [markdown]
-- # [DF_Agicoterms_Estado]

-- %%
ALTER TABLE [dbo].[Agicoterms] ADD  CONSTRAINT [DF_Agicoterms_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Agordenactividad_Estado]

-- %%
ALTER TABLE [dbo].[Agordenactividad] ADD  CONSTRAINT [DF_Agordenactividad_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Agordenruta_Fecha]

-- %%
ALTER TABLE [dbo].[Agordenruta] ADD  CONSTRAINT [DF_Agordenruta_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Agordenruta_estado]

-- %%
ALTER TABLE [dbo].[Agordenruta] ADD  CONSTRAINT [DF_Agordenruta_estado]  DEFAULT ((0)) FOR [estado]
GO

-- %% [markdown]
-- # [DF_Agordenruta_EstadoOrden]

-- %%
ALTER TABLE [dbo].[Agordenruta] ADD  CONSTRAINT [DF_Agordenruta_EstadoOrden]  DEFAULT (N'ABR') FOR [EstadoOrden]
GO

-- %% [markdown]
-- # [DF_Agordenruta_TipoDocumento]

-- %%
ALTER TABLE [dbo].[Agordenruta] ADD  CONSTRAINT [DF_Agordenruta_TipoDocumento]  DEFAULT (N'BL') FOR [TipoDocumento]
GO

-- %% [markdown]
-- # [DF_Agordenruta_Terminal]

-- %%
ALTER TABLE [dbo].[Agordenruta] ADD  CONSTRAINT [DF_Agordenruta_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_Agordenruta_FCambioestado]

-- %%
ALTER TABLE [dbo].[Agordenruta] ADD  CONSTRAINT [DF_Agordenruta_FCambioestado]  DEFAULT (getdate()) FOR [FCambioestado]
GO

-- %% [markdown]
-- # [DF_Agordenruta_diasdemora]

-- %%
ALTER TABLE [dbo].[Agordenruta] ADD  CONSTRAINT [DF_Agordenruta_diasdemora]  DEFAULT ((0)) FOR [diasdemora]
GO

-- %% [markdown]
-- # [DF_Agordenruta_diaslibres]

-- %%
ALTER TABLE [dbo].[Agordenruta] ADD  CONSTRAINT [DF_Agordenruta_diaslibres]  DEFAULT ((0)) FOR [diaslibres]
GO

-- %% [markdown]
-- # [DF_Agordenruta_TRM]

-- %%
ALTER TABLE [dbo].[Agordenruta] ADD  CONSTRAINT [DF_Agordenruta_TRM]  DEFAULT ((0)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Agordenruta_TContenedores]

-- %%
ALTER TABLE [dbo].[Agordenruta] ADD  CONSTRAINT [DF_Agordenruta_TContenedores]  DEFAULT ((0)) FOR [TContenedores]
GO

-- %% [markdown]
-- # [DF_Agordenruta_TBL]

-- %%
ALTER TABLE [dbo].[Agordenruta] ADD  CONSTRAINT [DF_Agordenruta_TBL]  DEFAULT ((0)) FOR [TBL]
GO

-- %% [markdown]
-- # [DF_Agordenrutaanexos_Estado]

-- %%
ALTER TABLE [dbo].[Agordenrutaanexos] ADD  CONSTRAINT [DF_Agordenrutaanexos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Agordenrutacontenedor_Tamaño]

-- %%
ALTER TABLE [dbo].[Agordenrutacontenedor] ADD  CONSTRAINT [DF_Agordenrutacontenedor_Tamaño]  DEFAULT ((0)) FOR [Tamaño]
GO

-- %% [markdown]
-- # [DF_Agordenrutacontenedor_Cantidad]

-- %%
ALTER TABLE [dbo].[Agordenrutacontenedor] ADD  CONSTRAINT [DF_Agordenrutacontenedor_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Agordenrutacontenedor_Kilos]

-- %%
ALTER TABLE [dbo].[Agordenrutacontenedor] ADD  CONSTRAINT [DF_Agordenrutacontenedor_Kilos]  DEFAULT ((0)) FOR [Kilos]
GO

-- %% [markdown]
-- # [DF_Agordenrutacontenedor_Volumen]

-- %%
ALTER TABLE [dbo].[Agordenrutacontenedor] ADD  CONSTRAINT [DF_Agordenrutacontenedor_Volumen]  DEFAULT ((0)) FOR [Volumen]
GO

-- %% [markdown]
-- # [DF_Agordenrutafletes_Neto]

-- %%
ALTER TABLE [dbo].[Agordenrutafletes] ADD  CONSTRAINT [DF_Agordenrutafletes_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Agordenrutafletes_Netoreal]

-- %%
ALTER TABLE [dbo].[Agordenrutafletes] ADD  CONSTRAINT [DF_Agordenrutafletes_Netoreal]  DEFAULT ((0)) FOR [Netoreal]
GO

-- %% [markdown]
-- # [DF_Agordenrutafletes_TRM1]

-- %%
ALTER TABLE [dbo].[Agordenrutafletes] ADD  CONSTRAINT [DF_Agordenrutafletes_TRM1]  DEFAULT ((0)) FOR [TRM1]
GO

-- %% [markdown]
-- # [DF_Agordenrutafletes_TRM2]

-- %%
ALTER TABLE [dbo].[Agordenrutafletes] ADD  CONSTRAINT [DF_Agordenrutafletes_TRM2]  DEFAULT ((0)) FOR [TRM2]
GO

-- %% [markdown]
-- # [DF_Agordenrutafletes_Certifica]

-- %%
ALTER TABLE [dbo].[Agordenrutafletes] ADD  CONSTRAINT [DF_Agordenrutafletes_Certifica]  DEFAULT (N'SI') FOR [Certifica]
GO

-- %% [markdown]
-- # [DF_Agordenrutafletes_Pesos]

-- %%
ALTER TABLE [dbo].[Agordenrutafletes] ADD  CONSTRAINT [DF_Agordenrutafletes_Pesos]  DEFAULT ((0)) FOR [Pesos]
GO

-- %% [markdown]
-- # [DF_Agordenrutafletes_Cantidad]

-- %%
ALTER TABLE [dbo].[Agordenrutafletes] ADD  CONSTRAINT [DF_Agordenrutafletes_Cantidad]  DEFAULT ((1)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Agordenrutafletes_Costous]

-- %%
ALTER TABLE [dbo].[Agordenrutafletes] ADD  CONSTRAINT [DF_Agordenrutafletes_Costous]  DEFAULT ((0)) FOR [Costous]
GO

-- %% [markdown]
-- # [DF_Agordenrutafletes_Anticipo]

-- %%
ALTER TABLE [dbo].[Agordenrutafletes] ADD  CONSTRAINT [DF_Agordenrutafletes_Anticipo]  DEFAULT ((0)) FOR [Anticipo]
GO

-- %% [markdown]
-- # [DF_Agordenrutafletes_Estado]

-- %%
ALTER TABLE [dbo].[Agordenrutafletes] ADD  CONSTRAINT [DF_Agordenrutafletes_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Agordenrutafletes_Peso]

-- %%
ALTER TABLE [dbo].[Agordenrutafletes] ADD  CONSTRAINT [DF_Agordenrutafletes_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Agordenrutafletes_Preciounit]

-- %%
ALTER TABLE [dbo].[Agordenrutafletes] ADD  CONSTRAINT [DF_Agordenrutafletes_Preciounit]  DEFAULT ((0)) FOR [Preciounit]
GO

-- %% [markdown]
-- # [DF_Agordenrutafletes_Costounit]

-- %%
ALTER TABLE [dbo].[Agordenrutafletes] ADD  CONSTRAINT [DF_Agordenrutafletes_Costounit]  DEFAULT ((0)) FOR [Costounit]
GO

-- %% [markdown]
-- # [DF_Agordenrutaservicios_Neto]

-- %%
ALTER TABLE [dbo].[Agordenrutaservicios] ADD  CONSTRAINT [DF_Agordenrutaservicios_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Agordenrutaservicios_Netoreal]

-- %%
ALTER TABLE [dbo].[Agordenrutaservicios] ADD  CONSTRAINT [DF_Agordenrutaservicios_Netoreal]  DEFAULT ((0)) FOR [Netoreal]
GO

-- %% [markdown]
-- # [DF_AgrupaMenor_Estado]

-- %%
ALTER TABLE [dbo].[AgrupaMenor] ADD  CONSTRAINT [DF_AgrupaMenor_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Agseguimiento_Fechaseg]

-- %%
ALTER TABLE [dbo].[Agseguimiento] ADD  CONSTRAINT [DF_Agseguimiento_Fechaseg]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fechaseg]
GO

-- %% [markdown]
-- # [DF_Agseguimiento_Hora]

-- %%
ALTER TABLE [dbo].[Agseguimiento] ADD  CONSTRAINT [DF_Agseguimiento_Hora]  DEFAULT (getdate()) FOR [Hora]
GO

-- %% [markdown]
-- # [DF_Agseguimiento_FProceso]

-- %%
ALTER TABLE [dbo].[Agseguimiento] ADD  CONSTRAINT [DF_Agseguimiento_FProceso]  DEFAULT (getdate()) FOR [FProceso]
GO

-- %% [markdown]
-- # [DF_Agseguimiento_Estado]

-- %%
ALTER TABLE [dbo].[Agseguimiento] ADD  CONSTRAINT [DF_Agseguimiento_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Agseguimientohouse_Fechaseg]

-- %%
ALTER TABLE [dbo].[Agseguimientohouse] ADD  CONSTRAINT [DF_Agseguimientohouse_Fechaseg]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fechaseg]
GO

-- %% [markdown]
-- # [DF_Agseguimientohouse_Hora]

-- %%
ALTER TABLE [dbo].[Agseguimientohouse] ADD  CONSTRAINT [DF_Agseguimientohouse_Hora]  DEFAULT (getdate()) FOR [Hora]
GO

-- %% [markdown]
-- # [DF_Agseguimientohouse_FProceso]

-- %%
ALTER TABLE [dbo].[Agseguimientohouse] ADD  CONSTRAINT [DF_Agseguimientohouse_FProceso]  DEFAULT (getdate()) FOR [FProceso]
GO

-- %% [markdown]
-- # [DF_Agseguimientohouse_Estado]

-- %%
ALTER TABLE [dbo].[Agseguimientohouse] ADD  CONSTRAINT [DF_Agseguimientohouse_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Agtipoanexos_Estado]

-- %%
ALTER TABLE [dbo].[Agtipoanexos] ADD  CONSTRAINT [DF_Agtipoanexos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Agtipocon_Tarcon]

-- %%
ALTER TABLE [dbo].[Agtipocon] ADD  CONSTRAINT [DF_Agtipocon_Tarcon]  DEFAULT ((0)) FOR [Tarcon]
GO

-- %% [markdown]
-- # [DF_Agtipocon_Capcon]

-- %%
ALTER TABLE [dbo].[Agtipocon] ADD  CONSTRAINT [DF_Agtipocon_Capcon]  DEFAULT ((0)) FOR [Capcon]
GO

-- %% [markdown]
-- # [DF_AgTipoguia_Estado]

-- %%
ALTER TABLE [dbo].[AgTipoguia] ADD  CONSTRAINT [DF_AgTipoguia_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Agtiposervicio_Estado]

-- %%
ALTER TABLE [dbo].[Agtiposervicio] ADD  CONSTRAINT [DF_Agtiposervicio_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Ajustes_Saldo]

-- %%
ALTER TABLE [dbo].[Ajustes] ADD  CONSTRAINT [DF_Ajustes_Saldo]  DEFAULT (0) FOR [Saldo]
GO

-- %% [markdown]
-- # [DF_Ajustes_Paag]

-- %%
ALTER TABLE [dbo].[Ajustes] ADD  CONSTRAINT [DF_Ajustes_Paag]  DEFAULT (0) FOR [Paag]
GO

-- %% [markdown]
-- # [DF_Ajustes_Valor]

-- %%
ALTER TABLE [dbo].[Ajustes] ADD  CONSTRAINT [DF_Ajustes_Valor]  DEFAULT (0) FOR [Valor]
GO

-- %% [markdown]
-- # [DF_Ajustes_ValorNegativo]

-- %%
ALTER TABLE [dbo].[Ajustes] ADD  CONSTRAINT [DF_Ajustes_ValorNegativo]  DEFAULT (0) FOR [ValorNegativo]
GO

-- %% [markdown]
-- # [DF_Alumnos_Tipo]

-- %%
ALTER TABLE [dbo].[Alumnos] ADD  CONSTRAINT [DF_Alumnos_Tipo]  DEFAULT (N'ALUMNO') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_Alumnos_Valor matricula]

-- %%
ALTER TABLE [dbo].[Alumnos] ADD  CONSTRAINT [DF_Alumnos_Valor matricula]  DEFAULT ((0)) FOR [Valor matricula]
GO

-- %% [markdown]
-- # [DF_Alumnos_Pension]

-- %%
ALTER TABLE [dbo].[Alumnos] ADD  CONSTRAINT [DF_Alumnos_Pension]  DEFAULT ((0)) FOR [Pension]
GO

-- %% [markdown]
-- # [DF_Alumnos_Materiales]

-- %%
ALTER TABLE [dbo].[Alumnos] ADD  CONSTRAINT [DF_Alumnos_Materiales]  DEFAULT ((0)) FOR [Materiales]
GO

-- %% [markdown]
-- # [DF_Alumnos_Uniformes]

-- %%
ALTER TABLE [dbo].[Alumnos] ADD  CONSTRAINT [DF_Alumnos_Uniformes]  DEFAULT ((0)) FOR [Uniformes]
GO

-- %% [markdown]
-- # [DF_Alumnos_Otros]

-- %%
ALTER TABLE [dbo].[Alumnos] ADD  CONSTRAINT [DF_Alumnos_Otros]  DEFAULT ((0)) FOR [Otros]
GO

-- %% [markdown]
-- # [DF_Alumnos_Estado2]

-- %%
ALTER TABLE [dbo].[Alumnos] ADD  CONSTRAINT [DF_Alumnos_Estado2]  DEFAULT ((0)) FOR [Estado2]
GO

-- %% [markdown]
-- # [DF_Anticipos_Fecha]

-- %%
ALTER TABLE [dbo].[Anticipos] ADD  CONSTRAINT [DF_Anticipos_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Anticipos_Anticipo]

-- %%
ALTER TABLE [dbo].[Anticipos] ADD  CONSTRAINT [DF_Anticipos_Anticipo]  DEFAULT ((0)) FOR [Anticipo]
GO

-- %% [markdown]
-- # [DF_Anticipos_Fproceso]

-- %%
ALTER TABLE [dbo].[Anticipos] ADD  CONSTRAINT [DF_Anticipos_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Anticipos_Documento]

-- %%
ALTER TABLE [dbo].[Anticipos] ADD  CONSTRAINT [DF_Anticipos_Documento]  DEFAULT (N'AN') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Anticipos_Estado]

-- %%
ALTER TABLE [dbo].[Anticipos] ADD  CONSTRAINT [DF_Anticipos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Anticipos_Capital]

-- %%
ALTER TABLE [dbo].[Anticipos] ADD  CONSTRAINT [DF_Anticipos_Capital]  DEFAULT ((0)) FOR [Capital]
GO

-- %% [markdown]
-- # [DF_Anticipos_Tasa]

-- %%
ALTER TABLE [dbo].[Anticipos] ADD  CONSTRAINT [DF_Anticipos_Tasa]  DEFAULT ((0)) FOR [Tasa]
GO

-- %% [markdown]
-- # [DF_Anticipos_Tiempo]

-- %%
ALTER TABLE [dbo].[Anticipos] ADD  CONSTRAINT [DF_Anticipos_Tiempo]  DEFAULT ((0)) FOR [Tiempo]
GO

-- %% [markdown]
-- # [DF_Anticipos_Cuota]

-- %%
ALTER TABLE [dbo].[Anticipos] ADD  CONSTRAINT [DF_Anticipos_Cuota]  DEFAULT ((0)) FOR [Cuota]
GO

-- %% [markdown]
-- # [DF_Anticipossub_Pago]

-- %%
ALTER TABLE [dbo].[Anticipossub] ADD  CONSTRAINT [DF_Anticipossub_Pago]  DEFAULT (0) FOR [Pago]
GO

-- %% [markdown]
-- # [DF_Anticipostrans_Documento]

-- %%
ALTER TABLE [dbo].[Anticipostrans] ADD  CONSTRAINT [DF_Anticipostrans_Documento]  DEFAULT (N'MC') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Anticipostrans_Fecha]

-- %%
ALTER TABLE [dbo].[Anticipostrans] ADD  CONSTRAINT [DF_Anticipostrans_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Anticipostrans_Flete]

-- %%
ALTER TABLE [dbo].[Anticipostrans] ADD  CONSTRAINT [DF_Anticipostrans_Flete]  DEFAULT ((0)) FOR [Flete]
GO

-- %% [markdown]
-- # [DF_Anticipostrans_Porc]

-- %%
ALTER TABLE [dbo].[Anticipostrans] ADD  CONSTRAINT [DF_Anticipostrans_Porc]  DEFAULT ((0)) FOR [Porc]
GO

-- %% [markdown]
-- # [DF_Anticipostrans_Neto]

-- %%
ALTER TABLE [dbo].[Anticipostrans] ADD  CONSTRAINT [DF_Anticipostrans_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Anticipostrans_Estado]

-- %%
ALTER TABLE [dbo].[Anticipostrans] ADD  CONSTRAINT [DF_Anticipostrans_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Anticipostrans_Fproceso]

-- %%
ALTER TABLE [dbo].[Anticipostrans] ADD  CONSTRAINT [DF_Anticipostrans_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Anticipostrans_Terminal]

-- %%
ALTER TABLE [dbo].[Anticipostrans] ADD  CONSTRAINT [DF_Anticipostrans_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_Anticipostrans_Tipo]

-- %%
ALTER TABLE [dbo].[Anticipostrans] ADD  CONSTRAINT [DF_Anticipostrans_Tipo]  DEFAULT (N'Anticipo') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_Anticipostrans_Autorizado]

-- %%
ALTER TABLE [dbo].[Anticipostrans] ADD  CONSTRAINT [DF_Anticipostrans_Autorizado]  DEFAULT ((0)) FOR [Autorizado]
GO

-- %% [markdown]
-- # [DF_Anticipostrans_Control]

-- %%
ALTER TABLE [dbo].[Anticipostrans] ADD  CONSTRAINT [DF_Anticipostrans_Control]  DEFAULT ((0)) FOR [Control]
GO

-- %% [markdown]
-- # [DF_ARP_Estado]

-- %%
ALTER TABLE [dbo].[ARP] ADD  CONSTRAINT [DF_ARP_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Auditoria_Fecha]

-- %%
ALTER TABLE [dbo].[Auditoria] ADD  CONSTRAINT [DF_Auditoria_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Auditoria_Hora]

-- %%
ALTER TABLE [dbo].[Auditoria] ADD  CONSTRAINT [DF_Auditoria_Hora]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(8)),(1))) FOR [Hora]
GO

-- %% [markdown]
-- # [DF_Auditoria_Transac]

-- %%
ALTER TABLE [dbo].[Auditoria] ADD  CONSTRAINT [DF_Auditoria_Transac]  DEFAULT (N'Admon') FOR [Transac]
GO

-- %% [markdown]
-- # [DF_Autentica_Estado]

-- %%
ALTER TABLE [dbo].[Autentica] ADD  CONSTRAINT [DF_Autentica_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Autorizaciones_Fecha]

-- %%
ALTER TABLE [dbo].[Autorizaciones] ADD  CONSTRAINT [DF_Autorizaciones_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Autorizaciones_Neto]

-- %%
ALTER TABLE [dbo].[Autorizaciones] ADD  CONSTRAINT [DF_Autorizaciones_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Autorizaciones_Documento]

-- %%
ALTER TABLE [dbo].[Autorizaciones] ADD  CONSTRAINT [DF_Autorizaciones_Documento]  DEFAULT (N'AT') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Autorizaciones_Estado]

-- %%
ALTER TABLE [dbo].[Autorizaciones] ADD  CONSTRAINT [DF_Autorizaciones_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Bancos_NInicial]

-- %%
ALTER TABLE [dbo].[Bancos] ADD  CONSTRAINT [DF_Bancos_NInicial]  DEFAULT (0) FOR [NInicial]
GO

-- %% [markdown]
-- # [DF_Bancos_NFinal]

-- %%
ALTER TABLE [dbo].[Bancos] ADD  CONSTRAINT [DF_Bancos_NFinal]  DEFAULT (0) FOR [NFinal]
GO

-- %% [markdown]
-- # [DF_Bancos_Pimpuesto]

-- %%
ALTER TABLE [dbo].[Bancos] ADD  CONSTRAINT [DF_Bancos_Pimpuesto]  DEFAULT (0) FOR [Pimpuesto]
GO

-- %% [markdown]
-- # [DF_Bancos_Estado]

-- %%
ALTER TABLE [dbo].[Bancos] ADD  CONSTRAINT [DF_Bancos_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Bancos_Comision]

-- %%
ALTER TABLE [dbo].[Bancos] ADD  CONSTRAINT [DF_Bancos_Comision]  DEFAULT (0) FOR [Comision]
GO

-- %% [markdown]
-- # [DF_Bancos_PRetefuente]

-- %%
ALTER TABLE [dbo].[Bancos] ADD  CONSTRAINT [DF_Bancos_PRetefuente]  DEFAULT (0) FOR [PRetefuente]
GO

-- %% [markdown]
-- # [DF_Bancos_PReteiva]

-- %%
ALTER TABLE [dbo].[Bancos] ADD  CONSTRAINT [DF_Bancos_PReteiva]  DEFAULT (0) FOR [PReteiva]
GO

-- %% [markdown]
-- # [DF_Bancos_PReteica]

-- %%
ALTER TABLE [dbo].[Bancos] ADD  CONSTRAINT [DF_Bancos_PReteica]  DEFAULT (0) FOR [PReteica]
GO

-- %% [markdown]
-- # [DF_BaseConductor_Estado]

-- %%
ALTER TABLE [dbo].[BaseConductor] ADD  CONSTRAINT [DF_BaseConductor_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_BaseContenedor_Remesa]

-- %%
ALTER TABLE [dbo].[BaseContenedor] ADD  CONSTRAINT [DF_BaseContenedor_Remesa]  DEFAULT (0) FOR [Remesa]
GO

-- %% [markdown]
-- # [DF_BaseContenedor_Estado]

-- %%
ALTER TABLE [dbo].[BaseContenedor] ADD  CONSTRAINT [DF_BaseContenedor_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_BaseVehiculos_Estado]

-- %%
ALTER TABLE [dbo].[BaseVehiculos] ADD  CONSTRAINT [DF_BaseVehiculos_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_CajaMenor_Neto]

-- %%
ALTER TABLE [dbo].[CajaMenor] ADD  CONSTRAINT [DF_CajaMenor_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_CajaMenor_iva]

-- %%
ALTER TABLE [dbo].[CajaMenor] ADD  CONSTRAINT [DF_CajaMenor_iva]  DEFAULT ((0)) FOR [iva]
GO

-- %% [markdown]
-- # [DF_CajaMenor_total]

-- %%
ALTER TABLE [dbo].[CajaMenor] ADD  CONSTRAINT [DF_CajaMenor_total]  DEFAULT ((0)) FOR [total]
GO

-- %% [markdown]
-- # [DF_CajaMenor_Doc]

-- %%
ALTER TABLE [dbo].[CajaMenor] ADD  CONSTRAINT [DF_CajaMenor_Doc]  DEFAULT (N'CE') FOR [Doc]
GO

-- %% [markdown]
-- # [DF_CajaMenor_Retefte]

-- %%
ALTER TABLE [dbo].[CajaMenor] ADD  CONSTRAINT [DF_CajaMenor_Retefte]  DEFAULT ((0)) FOR [Retefte]
GO

-- %% [markdown]
-- # [DF_CajaMenorEnc_Documento]

-- %%
ALTER TABLE [dbo].[CajaMenorEnc] ADD  CONSTRAINT [DF_CajaMenorEnc_Documento]  DEFAULT (N'CE') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_CajaMenorEnc_Anticipo]

-- %%
ALTER TABLE [dbo].[CajaMenorEnc] ADD  CONSTRAINT [DF_CajaMenorEnc_Anticipo]  DEFAULT ((0)) FOR [Anticipo]
GO

-- %% [markdown]
-- # [DF_CajaMenorEnc_Estado]

-- %%
ALTER TABLE [dbo].[CajaMenorEnc] ADD  CONSTRAINT [DF_CajaMenorEnc_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Canales_Estado]

-- %%
ALTER TABLE [dbo].[Canales] ADD  CONSTRAINT [DF_Canales_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Cargos_Estado]

-- %%
ALTER TABLE [dbo].[Cargos] ADD  CONSTRAINT [DF_Cargos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_CargueInventarios_Preciofinal]

-- %%
ALTER TABLE [dbo].[CargueInventarios] ADD  CONSTRAINT [DF_CargueInventarios_Preciofinal]  DEFAULT ((0)) FOR [Preciofinal]
GO

-- %% [markdown]
-- # [DF_CargueInventarios_Tarifa]

-- %%
ALTER TABLE [dbo].[CargueInventarios] ADD  CONSTRAINT [DF_CargueInventarios_Tarifa]  DEFAULT ((0)) FOR [Tarifa]
GO

-- %% [markdown]
-- # [DF_CargueInventarios_Cantidad]

-- %%
ALTER TABLE [dbo].[CargueInventarios] ADD  CONSTRAINT [DF_CargueInventarios_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_CargueInventarios_Costo]

-- %%
ALTER TABLE [dbo].[CargueInventarios] ADD  CONSTRAINT [DF_CargueInventarios_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_CargueInventarios_Peso]

-- %%
ALTER TABLE [dbo].[CargueInventarios] ADD  CONSTRAINT [DF_CargueInventarios_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_CargueInventarios_Us]

-- %%
ALTER TABLE [dbo].[CargueInventarios] ADD  CONSTRAINT [DF_CargueInventarios_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_CargueInventarios_Lista2]

-- %%
ALTER TABLE [dbo].[CargueInventarios] ADD  CONSTRAINT [DF_CargueInventarios_Lista2]  DEFAULT ((0)) FOR [Lista2]
GO

-- %% [markdown]
-- # [DF_CargueInventarios_Lista3]

-- %%
ALTER TABLE [dbo].[CargueInventarios] ADD  CONSTRAINT [DF_CargueInventarios_Lista3]  DEFAULT ((0)) FOR [Lista3]
GO

-- %% [markdown]
-- # [DF_CarteraInteractiva0_saldo]

-- %%
ALTER TABLE [dbo].[CarteraInteractiva0] ADD  CONSTRAINT [DF_CarteraInteractiva0_saldo]  DEFAULT ((0)) FOR [saldo]
GO

-- %% [markdown]
-- # [DF_Causacion_Documento]

-- %%
ALTER TABLE [dbo].[Causacion] ADD  CONSTRAINT [DF_Causacion_Documento]  DEFAULT (N'CD') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Causacion_Fecha]

-- %%
ALTER TABLE [dbo].[Causacion] ADD  CONSTRAINT [DF_Causacion_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Causacion_Fproceso]

-- %%
ALTER TABLE [dbo].[Causacion] ADD  CONSTRAINT [DF_Causacion_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Causacion_Niif]

-- %%
ALTER TABLE [dbo].[Causacion] ADD  CONSTRAINT [DF_Causacion_Niif]  DEFAULT (N'SI') FOR [Niif]
GO

-- %% [markdown]
-- # [DF_Causacion_Local]

-- %%
ALTER TABLE [dbo].[Causacion] ADD  CONSTRAINT [DF_Causacion_Local]  DEFAULT (N'SI') FOR [Local]
GO

-- %% [markdown]
-- # [DF_CCF_Estado]

-- %%
ALTER TABLE [dbo].[CCF] ADD  CONSTRAINT [DF_CCF_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Centros_Estado]

-- %%
ALTER TABLE [dbo].[Centros] ADD  CONSTRAINT [DF_Centros_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Centros_Situacion]

-- %%
ALTER TABLE [dbo].[Centros] ADD  CONSTRAINT [DF_Centros_Situacion]  DEFAULT (N'ACTIVADO') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Centrosop_Estado]

-- %%
ALTER TABLE [dbo].[Centrosop] ADD  CONSTRAINT [DF_Centrosop_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_CentrosSucursales_Estado]

-- %%
ALTER TABLE [dbo].[CentrosSucursales] ADD  CONSTRAINT [DF_CentrosSucursales_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_CentrosSucursales_Situacion]

-- %%
ALTER TABLE [dbo].[CentrosSucursales] ADD  CONSTRAINT [DF_CentrosSucursales_Situacion]  DEFAULT (N'ACTIVADO') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Certificados_Fecha]

-- %%
ALTER TABLE [dbo].[Certificados] ADD  CONSTRAINT [DF_Certificados_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Certificados_Estado]

-- %%
ALTER TABLE [dbo].[Certificados] ADD  CONSTRAINT [DF_Certificados_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Certiretencion_Fecha]

-- %%
ALTER TABLE [dbo].[Certiretencion] ADD  CONSTRAINT [DF_Certiretencion_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Chequesrecibidos_Girado]

-- %%
ALTER TABLE [dbo].[Chequesrecibidos] ADD  CONSTRAINT [DF_Chequesrecibidos_Girado]  DEFAULT ((0)) FOR [Girado]
GO

-- %% [markdown]
-- # [DF_Cieerrelcl_estado]

-- %%
ALTER TABLE [dbo].[Cieerrelcl] ADD  CONSTRAINT [DF_Cieerrelcl_estado]  DEFAULT ((0)) FOR [estado]
GO

-- %% [markdown]
-- # [DF_Cierrecontrato_estado]

-- %%
ALTER TABLE [dbo].[Cierrecontrato] ADD  CONSTRAINT [DF_Cierrecontrato_estado]  DEFAULT ((0)) FOR [estado]
GO

-- %% [markdown]
-- # [DF_Cierrecontratosub_Cantidad]

-- %%
ALTER TABLE [dbo].[Cierrecontratosub] ADD  CONSTRAINT [DF_Cierrecontratosub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Cierrecontratosub_Valorpatio]

-- %%
ALTER TABLE [dbo].[Cierrecontratosub] ADD  CONSTRAINT [DF_Cierrecontratosub_Valorpatio]  DEFAULT ((0)) FOR [Valorpatio]
GO

-- %% [markdown]
-- # [DF_Cierrecontratosub_ValorAgencia]

-- %%
ALTER TABLE [dbo].[Cierrecontratosub] ADD  CONSTRAINT [DF_Cierrecontratosub_ValorAgencia]  DEFAULT ((0)) FOR [ValorAgencia]
GO

-- %% [markdown]
-- # [DF_Cierredo_Fecha]

-- %%
ALTER TABLE [dbo].[Cierredo] ADD  CONSTRAINT [DF_Cierredo_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Cierredo_Tarifaiva]

-- %%
ALTER TABLE [dbo].[Cierredo] ADD  CONSTRAINT [DF_Cierredo_Tarifaiva]  DEFAULT ((0)) FOR [Tarifaiva]
GO

-- %% [markdown]
-- # [DF_Cierredo_Documento]

-- %%
ALTER TABLE [dbo].[Cierredo] ADD  CONSTRAINT [DF_Cierredo_Documento]  DEFAULT (N'CDO') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Cierredo_Estado]

-- %%
ALTER TABLE [dbo].[Cierredo] ADD  CONSTRAINT [DF_Cierredo_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Cierredo_Tarifacree]

-- %%
ALTER TABLE [dbo].[Cierredo] ADD  CONSTRAINT [DF_Cierredo_Tarifacree]  DEFAULT ((0)) FOR [Tarifacree]
GO

-- %% [markdown]
-- # [DF_Cierredosub_Saldodebito]

-- %%
ALTER TABLE [dbo].[Cierredosub] ADD  CONSTRAINT [DF_Cierredosub_Saldodebito]  DEFAULT ((0)) FOR [Saldodebito]
GO

-- %% [markdown]
-- # [DF_Cierredosub_Saldocredito]

-- %%
ALTER TABLE [dbo].[Cierredosub] ADD  CONSTRAINT [DF_Cierredosub_Saldocredito]  DEFAULT ((0)) FOR [Saldocredito]
GO

-- %% [markdown]
-- # [DF_Cierrelclsub_Cantidad]

-- %%
ALTER TABLE [dbo].[Cierrelclsub] ADD  CONSTRAINT [DF_Cierrelclsub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Cierrelclsub_Valorpatio]

-- %%
ALTER TABLE [dbo].[Cierrelclsub] ADD  CONSTRAINT [DF_Cierrelclsub_Valorpatio]  DEFAULT ((0)) FOR [Valorpatio]
GO

-- %% [markdown]
-- # [DF_Cierrelclsub_ValorAgencia]

-- %%
ALTER TABLE [dbo].[Cierrelclsub] ADD  CONSTRAINT [DF_Cierrelclsub_ValorAgencia]  DEFAULT ((0)) FOR [ValorAgencia]
GO

-- %% [markdown]
-- # [DF_Cierrelineasub_idcierre]

-- %%
ALTER TABLE [dbo].[Cierrelineasub] ADD  CONSTRAINT [DF_Cierrelineasub_idcierre]  DEFAULT ((0)) FOR [idcierre]
GO

-- %% [markdown]
-- # [DF_Cierrelineasub_USFaturado]

-- %%
ALTER TABLE [dbo].[Cierrelineasub] ADD  CONSTRAINT [DF_Cierrelineasub_USFaturado]  DEFAULT ((0)) FOR [USFaturado]
GO

-- %% [markdown]
-- # [DF_Cierrelineasub_UScredi]

-- %%
ALTER TABLE [dbo].[Cierrelineasub] ADD  CONSTRAINT [DF_Cierrelineasub_UScredi]  DEFAULT ((0)) FOR [UScredi]
GO

-- %% [markdown]
-- # [DF_Cierrelineasub_Netocol]

-- %%
ALTER TABLE [dbo].[Cierrelineasub] ADD  CONSTRAINT [DF_Cierrelineasub_Netocol]  DEFAULT ((0)) FOR [Netocol]
GO

-- %% [markdown]
-- # [DF_Clases_Estado]

-- %%
ALTER TABLE [dbo].[Clases] ADD  CONSTRAINT [DF_Clases_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Coberturas_VAsegurado]

-- %%
ALTER TABLE [dbo].[Coberturas] ADD  CONSTRAINT [DF_Coberturas_VAsegurado]  DEFAULT ((0)) FOR [VAsegurado]
GO

-- %% [markdown]
-- # [DF_Coberturas_Vigencia]

-- %%
ALTER TABLE [dbo].[Coberturas] ADD  CONSTRAINT [DF_Coberturas_Vigencia]  DEFAULT ((0)) FOR [Vigencia]
GO

-- %% [markdown]
-- # [DF_Coberturas_Prima]

-- %%
ALTER TABLE [dbo].[Coberturas] ADD  CONSTRAINT [DF_Coberturas_Prima]  DEFAULT ((0)) FOR [Prima]
GO

-- %% [markdown]
-- # [DF_Coberturas_Tasa]

-- %%
ALTER TABLE [dbo].[Coberturas] ADD  CONSTRAINT [DF_Coberturas_Tasa]  DEFAULT ((0)) FOR [Tasa]
GO

-- %% [markdown]
-- # [DF_Cobranza_Estado]

-- %%
ALTER TABLE [dbo].[Cobranza] ADD  CONSTRAINT [DF_Cobranza_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Codigos_Ica]

-- %%
ALTER TABLE [dbo].[Codigos] ADD  CONSTRAINT [DF_Codigos_Ica]  DEFAULT ((0)) FOR [Ica]
GO

-- %% [markdown]
-- # [DF_Codigos_Estado]

-- %%
ALTER TABLE [dbo].[Codigos] ADD  CONSTRAINT [DF_Codigos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_CodigosCon_Ica]

-- %%
ALTER TABLE [dbo].[CodigosCon] ADD  CONSTRAINT [DF_CodigosCon_Ica]  DEFAULT ((0)) FOR [Ica]
GO

-- %% [markdown]
-- # [DF_CodigosPostales_Estado]

-- %%
ALTER TABLE [dbo].[CodigosPostales] ADD  CONSTRAINT [DF_CodigosPostales_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_CodigosTrans_Estado]

-- %%
ALTER TABLE [dbo].[CodigosTrans] ADD  CONSTRAINT [DF_CodigosTrans_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_ComercioExterior_Fecha]

-- %%
ALTER TABLE [dbo].[ComercioExterior] ADD  CONSTRAINT [DF_ComercioExterior_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_ComercioExterior_Estado]

-- %%
ALTER TABLE [dbo].[ComercioExterior] ADD  CONSTRAINT [DF_ComercioExterior_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_ComercioExterior_Documento]

-- %%
ALTER TABLE [dbo].[ComercioExterior] ADD  CONSTRAINT [DF_ComercioExterior_Documento]  DEFAULT (N'CCE') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Comparendos_Neto]

-- %%
ALTER TABLE [dbo].[Comparendos] ADD  CONSTRAINT [DF_Comparendos_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Comparendos_Estado]

-- %%
ALTER TABLE [dbo].[Comparendos] ADD  CONSTRAINT [DF_Comparendos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Composicion_Fproceso]

-- %%
ALTER TABLE [dbo].[Composicion] ADD  CONSTRAINT [DF_Composicion_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Composicion_PAjuste]

-- %%
ALTER TABLE [dbo].[Composicion] ADD  CONSTRAINT [DF_Composicion_PAjuste]  DEFAULT (0) FOR [PAjuste]
GO

-- %% [markdown]
-- # [DF_Composicion_Ajuste]

-- %%
ALTER TABLE [dbo].[Composicion] ADD  CONSTRAINT [DF_Composicion_Ajuste]  DEFAULT (0) FOR [Ajuste]
GO

-- %% [markdown]
-- # [DF_Composicion_CostoTotal]

-- %%
ALTER TABLE [dbo].[Composicion] ADD  CONSTRAINT [DF_Composicion_CostoTotal]  DEFAULT (0) FOR [CostoTotal]
GO

-- %% [markdown]
-- # [DF_Composicion_Fecha]

-- %%
ALTER TABLE [dbo].[Composicion] ADD  CONSTRAINT [DF_Composicion_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Composicion_PPrecio]

-- %%
ALTER TABLE [dbo].[Composicion] ADD  CONSTRAINT [DF_Composicion_PPrecio]  DEFAULT (0) FOR [PPrecio]
GO

-- %% [markdown]
-- # [DF_Composicion_PFinal]

-- %%
ALTER TABLE [dbo].[Composicion] ADD  CONSTRAINT [DF_Composicion_PFinal]  DEFAULT (0) FOR [PFinal]
GO

-- %% [markdown]
-- # [DF_Composicion_Piva]

-- %%
ALTER TABLE [dbo].[Composicion] ADD  CONSTRAINT [DF_Composicion_Piva]  DEFAULT (0) FOR [Piva]
GO

-- %% [markdown]
-- # [DF_Composicion_Iva]

-- %%
ALTER TABLE [dbo].[Composicion] ADD  CONSTRAINT [DF_Composicion_Iva]  DEFAULT (0) FOR [Iva]
GO

-- %% [markdown]
-- # [DF_Composicion_TotalPV]

-- %%
ALTER TABLE [dbo].[Composicion] ADD  CONSTRAINT [DF_Composicion_TotalPV]  DEFAULT (0) FOR [TotalPV]
GO

-- %% [markdown]
-- # [DF_Composicion_Final]

-- %%
ALTER TABLE [dbo].[Composicion] ADD  CONSTRAINT [DF_Composicion_Final]  DEFAULT (0) FOR [Final]
GO

-- %% [markdown]
-- # [DF_Composicion_Base]

-- %%
ALTER TABLE [dbo].[Composicion] ADD  CONSTRAINT [DF_Composicion_Base]  DEFAULT (0) FOR [Base]
GO

-- %% [markdown]
-- # [DF_Composicion_Porcentaje]

-- %%
ALTER TABLE [dbo].[Composicion] ADD  CONSTRAINT [DF_Composicion_Porcentaje]  DEFAULT (0) FOR [Porcentaje]
GO

-- %% [markdown]
-- # [DF_Composicion_Estado]

-- %%
ALTER TABLE [dbo].[Composicion] ADD  CONSTRAINT [DF_Composicion_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Composicionsub_Cantidad]

-- %%
ALTER TABLE [dbo].[Composicionsub] ADD  CONSTRAINT [DF_Composicionsub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Composicionsub_Unitario]

-- %%
ALTER TABLE [dbo].[Composicionsub] ADD  CONSTRAINT [DF_Composicionsub_Unitario]  DEFAULT ((0)) FOR [Unitario]
GO

-- %% [markdown]
-- # [DF_Composicionsub_Total]

-- %%
ALTER TABLE [dbo].[Composicionsub] ADD  CONSTRAINT [DF_Composicionsub_Total]  DEFAULT ((0)) FOR [Total]
GO

-- %% [markdown]
-- # [DF_Composicionsub_Peso]

-- %%
ALTER TABLE [dbo].[Composicionsub] ADD  CONSTRAINT [DF_Composicionsub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Composicionsub_Neto]

-- %%
ALTER TABLE [dbo].[Composicionsub] ADD  CONSTRAINT [DF_Composicionsub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Composicionsub_Convertidor]

-- %%
ALTER TABLE [dbo].[Composicionsub] ADD  CONSTRAINT [DF_Composicionsub_Convertidor]  DEFAULT ((0)) FOR [Convertidor]
GO

-- %% [markdown]
-- # [DF_Composicionsub_Subtotal]

-- %%
ALTER TABLE [dbo].[Composicionsub] ADD  CONSTRAINT [DF_Composicionsub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Compras_Estado_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Estado_1]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Compras_Tipo_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Tipo_1]  DEFAULT (N'COMPRA') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_Compras_Fecha_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Fecha_1]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Compras_Documento_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Documento_1]  DEFAULT (N'FP') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Compras_Abono_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Abono_1]  DEFAULT ((0)) FOR [Abono]
GO

-- %% [markdown]
-- # [DF_Compras_Saldo_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Saldo_1]  DEFAULT ((0)) FOR [Saldo]
GO

-- %% [markdown]
-- # [DF_Compras_Dias_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Dias_1]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Compras_Fletes_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Fletes_1]  DEFAULT ((0)) FOR [Fletes]
GO

-- %% [markdown]
-- # [DF_Compras_Financiacion_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Financiacion_1]  DEFAULT ((0)) FOR [Financiacion]
GO

-- %% [markdown]
-- # [DF_Compras_Fproceso_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Fproceso_1]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Compras_PRetencion_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_PRetencion_1]  DEFAULT ((0)) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_Compras_TRM_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_TRM_1]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Compras_PReteIva_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_PReteIva_1]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_Compras_Descarga_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Descarga_1]  DEFAULT (N'CARGAR') FOR [Descarga]
GO

-- %% [markdown]
-- # [DF_Compras_Concepto_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Concepto_1]  DEFAULT ((2201)) FOR [Concepto]
GO

-- %% [markdown]
-- # [DF_Compras_Diferencia_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Diferencia_1]  DEFAULT ((0)) FOR [Diferencia]
GO

-- %% [markdown]
-- # [DF_Compras_IvaServ_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_IvaServ_1]  DEFAULT ((0)) FOR [IvaServ]
GO

-- %% [markdown]
-- # [DF_Compras_Seguros_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Seguros_1]  DEFAULT ((0)) FOR [Seguros]
GO

-- %% [markdown]
-- # [DF_Compras_Nacionalizacion_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Nacionalizacion_1]  DEFAULT ((0)) FOR [Nacionalizacion]
GO

-- %% [markdown]
-- # [DF_Compras_Prorratear_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Prorratear_1]  DEFAULT ((0)) FOR [Prorratear]
GO

-- %% [markdown]
-- # [DF_Compras_CostoUnitario_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_CostoUnitario_1]  DEFAULT ((0)) FOR [CostoUnitario]
GO

-- %% [markdown]
-- # [DF_Compras_Pincremento_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Pincremento_1]  DEFAULT ((0)) FOR [Pincremento]
GO

-- %% [markdown]
-- # [DF_Compras_Rete_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Rete_1]  DEFAULT ((0)) FOR [Rete]
GO

-- %% [markdown]
-- # [DF_Compras_Anticipo_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Anticipo_1]  DEFAULT ((0)) FOR [Anticipo]
GO

-- %% [markdown]
-- # [DF_Compras_Aranus_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Aranus_1]  DEFAULT ((0)) FOR [Aranus]
GO

-- %% [markdown]
-- # [DF_Compras_Ivaopus_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Ivaopus_1]  DEFAULT ((0)) FOR [Ivaopus]
GO

-- %% [markdown]
-- # [DF_Compras_Ivaserus_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Ivaserus_1]  DEFAULT ((0)) FOR [Ivaserus]
GO

-- %% [markdown]
-- # [DF_Compras_Nalus_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Nalus_1]  DEFAULT ((0)) FOR [Nalus]
GO

-- %% [markdown]
-- # [DF_Compras_Reteus_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Reteus_1]  DEFAULT ((0)) FOR [Reteus]
GO

-- %% [markdown]
-- # [DF_Compras_Estado2_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Estado2_1]  DEFAULT ((0)) FOR [Estado2]
GO

-- %% [markdown]
-- # [DF_Compras_Us_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Us_1]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_Compras_Situacion_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Situacion_1]  DEFAULT (N'CAUSAR CXP') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Compras_Pcree_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Pcree_1]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_Compras_Retecree_1]

-- %%
ALTER TABLE [dbo].[Compras] ADD  CONSTRAINT [DF_Compras_Retecree_1]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_ComprasFletes_Neto]

-- %%
ALTER TABLE [dbo].[ComprasFletes] ADD  CONSTRAINT [DF_ComprasFletes_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_ComprasFletes_Us]

-- %%
ALTER TABLE [dbo].[ComprasFletes] ADD  CONSTRAINT [DF_ComprasFletes_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_ComprasNacionaliza_Neto]

-- %%
ALTER TABLE [dbo].[ComprasNacionaliza] ADD  CONSTRAINT [DF_ComprasNacionaliza_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_ComprasNacionaliza_Us]

-- %%
ALTER TABLE [dbo].[ComprasNacionaliza] ADD  CONSTRAINT [DF_ComprasNacionaliza_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_ComprasSeguros_Neto]

-- %%
ALTER TABLE [dbo].[ComprasSeguros] ADD  CONSTRAINT [DF_ComprasSeguros_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_ComprasSeguros_Us]

-- %%
ALTER TABLE [dbo].[ComprasSeguros] ADD  CONSTRAINT [DF_ComprasSeguros_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_Comprasub_Cantidad]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Comprasub_Descuento]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_Comprasub_Precio]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Comprasub_PIva]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_Comprasub_Precio total]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_Comprasub_Neto]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Comprasub_Subtotal]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Comprasub_Exentos]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_Exentos]  DEFAULT ((0)) FOR [Exentos]
GO

-- %% [markdown]
-- # [DF_Comprasub_DesExentos]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_DesExentos]  DEFAULT ((0)) FOR [DesExentos]
GO

-- %% [markdown]
-- # [DF_Comprasub_DesGravados]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_DesGravados]  DEFAULT ((0)) FOR [DesGravados]
GO

-- %% [markdown]
-- # [DF_Comprasub_Dolares]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_Dolares]  DEFAULT ((0)) FOR [Dolares]
GO

-- %% [markdown]
-- # [DF_Comprasub_PRete]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_PRete]  DEFAULT ((0)) FOR [PRete]
GO

-- %% [markdown]
-- # [DF_Comprasub_Retencion]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_Comprasub_TipoRetencion]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_TipoRetencion]  DEFAULT ((2302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_Comprasub_Peso]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Comprasub_Base]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_Base]  DEFAULT ((0)) FOR [Base]
GO

-- %% [markdown]
-- # [DF_Comprasub_CUdol]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_CUdol]  DEFAULT ((0)) FOR [CUdol]
GO

-- %% [markdown]
-- # [DF_Comprasub_Nal]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_Nal]  DEFAULT ((0)) FOR [Nal]
GO

-- %% [markdown]
-- # [DF_Comprasub_CTU]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_CTU]  DEFAULT ((0)) FOR [CTU]
GO

-- %% [markdown]
-- # [DF_Comprasub_PVF]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_PVF]  DEFAULT ((0)) FOR [PVF]
GO

-- %% [markdown]
-- # [DF_Comprasub_PArancel]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_PArancel]  DEFAULT ((0)) FOR [PArancel]
GO

-- %% [markdown]
-- # [DF_Comprasub_Arancel]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_Arancel]  DEFAULT ((0)) FOR [Arancel]
GO

-- %% [markdown]
-- # [DF_Comprasub_VPropina]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_VPropina]  DEFAULT ((0)) FOR [VPropina]
GO

-- %% [markdown]
-- # [DF_Comprasub_Cree]

-- %%
ALTER TABLE [dbo].[Comprasub] ADD  CONSTRAINT [DF_Comprasub_Cree]  DEFAULT ((0)) FOR [Cree]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Estado]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Tipo]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Tipo]  DEFAULT (N'PAGO') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Fecha]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Ciudad]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Ciudad]  DEFAULT (N'Bogotá, D.C.') FOR [Ciudad]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Document]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Document]  DEFAULT (N'CH') FOR [Document]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Documento]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Documento]  DEFAULT (N'CE') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_PDesc]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_PDesc]  DEFAULT ((0)) FOR [PDesc]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Descuento]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_PRetencion]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_PRetencion]  DEFAULT ((0)) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Retefuente]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Retefuente]  DEFAULT ((0)) FOR [Retefuente]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Pagar]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Pagar]  DEFAULT ((0)) FOR [Pagar]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Netor]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Netor]  DEFAULT ((0)) FOR [Netor]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Ivar]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Ivar]  DEFAULT ((0)) FOR [Ivar]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Pivar]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Pivar]  DEFAULT ((0)) FOR [Pivar]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_PReteIca]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_ReteIca]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_ReteIca]  DEFAULT ((0)) FOR [ReteIca]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_PReteIva]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_ReteIva]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_ReteIva]  DEFAULT ((0)) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Adicion]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Adicion]  DEFAULT ((0)) FOR [Adicion]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Comprobante]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Comprobante]  DEFAULT ((0)) FOR [Comprobante]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Fproceso]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_TipoRetencion]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_TipoRetencion]  DEFAULT ((2302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_DO]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_DO]  DEFAULT ((0)) FOR [DO]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_DifCambio]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_DifCambio]  DEFAULT ((0)) FOR [DifCambio]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Pcree]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Pcree]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_Comprobanteegreso_Retecree]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso] ADD  CONSTRAINT [DF_Comprobanteegreso_Retecree]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_Conactividades_ID]

-- %%
ALTER TABLE [dbo].[Conactividades] ADD  CONSTRAINT [DF_Conactividades_ID]  DEFAULT ((0)) FOR [ID]
GO

-- %% [markdown]
-- # [DF_Conactividades_Orden]

-- %%
ALTER TABLE [dbo].[Conactividades] ADD  CONSTRAINT [DF_Conactividades_Orden]  DEFAULT ((0)) FOR [Orden]
GO

-- %% [markdown]
-- # [DF_Conalmagrario_SrlPresupuesto]

-- %%
ALTER TABLE [dbo].[Conalmagrario] ADD  CONSTRAINT [DF_Conalmagrario_SrlPresupuesto]  DEFAULT ((0)) FOR [SrlPresupuesto]
GO

-- %% [markdown]
-- # [DF_Conalmagrario_Tam]

-- %%
ALTER TABLE [dbo].[Conalmagrario] ADD  CONSTRAINT [DF_Conalmagrario_Tam]  DEFAULT ((0)) FOR [Tam]
GO

-- %% [markdown]
-- # [DF_Conalmagrario_Dimension1]

-- %%
ALTER TABLE [dbo].[Conalmagrario] ADD  CONSTRAINT [DF_Conalmagrario_Dimension1]  DEFAULT ((0)) FOR [Dimension1]
GO

-- %% [markdown]
-- # [DF_Conalmagrario_Dimension2]

-- %%
ALTER TABLE [dbo].[Conalmagrario] ADD  CONSTRAINT [DF_Conalmagrario_Dimension2]  DEFAULT ((0)) FOR [Dimension2]
GO

-- %% [markdown]
-- # [DF_Conalmagrario_HorHombre]

-- %%
ALTER TABLE [dbo].[Conalmagrario] ADD  CONSTRAINT [DF_Conalmagrario_HorHombre]  DEFAULT ((0)) FOR [HorHombre]
GO

-- %% [markdown]
-- # [DF_Conalmagrario_VlrHorHombre]

-- %%
ALTER TABLE [dbo].[Conalmagrario] ADD  CONSTRAINT [DF_Conalmagrario_VlrHorHombre]  DEFAULT ((0)) FOR [VlrHorHombre]
GO

-- %% [markdown]
-- # [DF_Conalmagrario_VlrMaterial]

-- %%
ALTER TABLE [dbo].[Conalmagrario] ADD  CONSTRAINT [DF_Conalmagrario_VlrMaterial]  DEFAULT ((0)) FOR [VlrMaterial]
GO

-- %% [markdown]
-- # [DF_Conalmagrario_VlrIva]

-- %%
ALTER TABLE [dbo].[Conalmagrario] ADD  CONSTRAINT [DF_Conalmagrario_VlrIva]  DEFAULT ((0)) FOR [VlrIva]
GO

-- %% [markdown]
-- # [DF_Conalmagrario_VlrTotal]

-- %%
ALTER TABLE [dbo].[Conalmagrario] ADD  CONSTRAINT [DF_Conalmagrario_VlrTotal]  DEFAULT ((0)) FOR [VlrTotal]
GO

-- %% [markdown]
-- # [DF_Conalmagrario_Acargo]

-- %%
ALTER TABLE [dbo].[Conalmagrario] ADD  CONSTRAINT [DF_Conalmagrario_Acargo]  DEFAULT (N'LI') FOR [Acargo]
GO

-- %% [markdown]
-- # [DF_ConBL_Estado]

-- %%
ALTER TABLE [dbo].[ConBL] ADD  CONSTRAINT [DF_ConBL_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_ConBL_Documento]

-- %%
ALTER TABLE [dbo].[ConBL] ADD  CONSTRAINT [DF_ConBL_Documento]  DEFAULT (N'BL') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_ConbokingFte_Boking]

-- %%
ALTER TABLE [dbo].[ConbokingFte] ADD  CONSTRAINT [DF_ConbokingFte_Boking]  DEFAULT ((0)) FOR [Boking]
GO

-- %% [markdown]
-- # [DF_Conboocntr_Boking]

-- %%
ALTER TABLE [dbo].[Conboocntr] ADD  CONSTRAINT [DF_Conboocntr_Boking]  DEFAULT ((0)) FOR [Boking]
GO

-- %% [markdown]
-- # [DF_Conboocntr_Tamaño]

-- %%
ALTER TABLE [dbo].[Conboocntr] ADD  CONSTRAINT [DF_Conboocntr_Tamaño]  DEFAULT ((0)) FOR [Tamaño]
GO

-- %% [markdown]
-- # [DF_Conboocntr_Cantidad]

-- %%
ALTER TABLE [dbo].[Conboocntr] ADD  CONSTRAINT [DF_Conboocntr_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Conbooking_Fecha]

-- %%
ALTER TABLE [dbo].[Conbooking] ADD  CONSTRAINT [DF_Conbooking_Fecha]  DEFAULT (getdate()) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Conbooking_estado]

-- %%
ALTER TABLE [dbo].[Conbooking] ADD  CONSTRAINT [DF_Conbooking_estado]  DEFAULT ((0)) FOR [estado]
GO

-- %% [markdown]
-- # [DF_Concarguecierre_idcierre]

-- %%
ALTER TABLE [dbo].[Concarguecierre] ADD  CONSTRAINT [DF_Concarguecierre_idcierre]  DEFAULT ((0)) FOR [idcierre]
GO

-- %% [markdown]
-- # [DF_Concarguecierre_Factura]

-- %%
ALTER TABLE [dbo].[Concarguecierre] ADD  CONSTRAINT [DF_Concarguecierre_Factura]  DEFAULT ((0)) FOR [Factura]
GO

-- %% [markdown]
-- # [DF_Concarguecierre_USFaturado]

-- %%
ALTER TABLE [dbo].[Concarguecierre] ADD  CONSTRAINT [DF_Concarguecierre_USFaturado]  DEFAULT ((0)) FOR [USFaturado]
GO

-- %% [markdown]
-- # [DF_Concarguecierre_UScredi]

-- %%
ALTER TABLE [dbo].[Concarguecierre] ADD  CONSTRAINT [DF_Concarguecierre_UScredi]  DEFAULT ((0)) FOR [UScredi]
GO

-- %% [markdown]
-- # [DF_Concarguecierre_Netocol]

-- %%
ALTER TABLE [dbo].[Concarguecierre] ADD  CONSTRAINT [DF_Concarguecierre_Netocol]  DEFAULT ((0)) FOR [Netocol]
GO

-- %% [markdown]
-- # [DF_ConceptosMedios_Neto]

-- %%
ALTER TABLE [dbo].[ConceptosMedios] ADD  CONSTRAINT [DF_ConceptosMedios_Neto]  DEFAULT (0) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_ConceptosMediosVir_Neto]

-- %%
ALTER TABLE [dbo].[ConceptosMediosVir] ADD  CONSTRAINT [DF_ConceptosMediosVir_Neto]  DEFAULT (0) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_ConciliaBancaria_Fecha]

-- %%
ALTER TABLE [dbo].[ConciliaBancaria] ADD  CONSTRAINT [DF_ConciliaBancaria_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_ConciliaBancaria_Documento]

-- %%
ALTER TABLE [dbo].[ConciliaBancaria] ADD  CONSTRAINT [DF_ConciliaBancaria_Documento]  DEFAULT (N'CB') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_ConciliaBancaria_Estado]

-- %%
ALTER TABLE [dbo].[ConciliaBancaria] ADD  CONSTRAINT [DF_ConciliaBancaria_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_ConciliaBancariapar_Estado]

-- %%
ALTER TABLE [dbo].[ConciliaBancariapar] ADD  CONSTRAINT [DF_ConciliaBancariapar_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_ConContenedor_Tonelada]

-- %%
ALTER TABLE [dbo].[ConContenedor] ADD  CONSTRAINT [DF_ConContenedor_Tonelada]  DEFAULT ((0)) FOR [Tonelada]
GO

-- %% [markdown]
-- # [DF_ConContenedor_Metros]

-- %%
ALTER TABLE [dbo].[ConContenedor] ADD  CONSTRAINT [DF_ConContenedor_Metros]  DEFAULT ((0)) FOR [Metros]
GO

-- %% [markdown]
-- # [DF_ConContenedorTipo_Estado]

-- %%
ALTER TABLE [dbo].[ConContenedorTipo] ADD  CONSTRAINT [DF_ConContenedorTipo_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Conductores_Clase]

-- %%
ALTER TABLE [dbo].[Conductores] ADD  CONSTRAINT [DF_Conductores_Clase]  DEFAULT ((13)) FOR [Clase]
GO

-- %% [markdown]
-- # [DF_Conductores_Estado]

-- %%
ALTER TABLE [dbo].[Conductores] ADD  CONSTRAINT [DF_Conductores_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Conductores_Situacion]

-- %%
ALTER TABLE [dbo].[Conductores] ADD  CONSTRAINT [DF_Conductores_Situacion]  DEFAULT (N'ACTIVADO') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_ConductorPendientes_Estado]

-- %%
ALTER TABLE [dbo].[ConductorPendientes] ADD  CONSTRAINT [DF_ConductorPendientes_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Conestados_estado]

-- %%
ALTER TABLE [dbo].[Conestados] ADD  CONSTRAINT [DF_Conestados_estado]  DEFAULT ((0)) FOR [estado]
GO

-- %% [markdown]
-- # [DF_ConFletes_Recalada]

-- %%
ALTER TABLE [dbo].[ConFletes] ADD  CONSTRAINT [DF_ConFletes_Recalada]  DEFAULT ((0)) FOR [Recalada]
GO

-- %% [markdown]
-- # [DF_ConFletes_US]

-- %%
ALTER TABLE [dbo].[ConFletes] ADD  CONSTRAINT [DF_ConFletes_US]  DEFAULT ((0)) FOR [US]
GO

-- %% [markdown]
-- # [DF_Conguiasrepar_Tam]

-- %%
ALTER TABLE [dbo].[Conguiasrepar] ADD  CONSTRAINT [DF_Conguiasrepar_Tam]  DEFAULT ((0)) FOR [Tam]
GO

-- %% [markdown]
-- # [DF_Conguiasreparsub_SrlPresupuesto]

-- %%
ALTER TABLE [dbo].[Conguiasreparsub] ADD  CONSTRAINT [DF_Conguiasreparsub_SrlPresupuesto]  DEFAULT ((0)) FOR [SrlPresupuesto]
GO

-- %% [markdown]
-- # [DF_Conguiasreparsub_Tam]

-- %%
ALTER TABLE [dbo].[Conguiasreparsub] ADD  CONSTRAINT [DF_Conguiasreparsub_Tam]  DEFAULT ((0)) FOR [Tam]
GO

-- %% [markdown]
-- # [DF_Conguiasreparsub_Dimension1]

-- %%
ALTER TABLE [dbo].[Conguiasreparsub] ADD  CONSTRAINT [DF_Conguiasreparsub_Dimension1]  DEFAULT ((0)) FOR [Dimension1]
GO

-- %% [markdown]
-- # [DF_Conguiasreparsub_Dimension2]

-- %%
ALTER TABLE [dbo].[Conguiasreparsub] ADD  CONSTRAINT [DF_Conguiasreparsub_Dimension2]  DEFAULT ((0)) FOR [Dimension2]
GO

-- %% [markdown]
-- # [DF_Conguiasreparsub_HorHombre]

-- %%
ALTER TABLE [dbo].[Conguiasreparsub] ADD  CONSTRAINT [DF_Conguiasreparsub_HorHombre]  DEFAULT ((0)) FOR [HorHombre]
GO

-- %% [markdown]
-- # [DF_Conguiasreparsub_VlrHorHombre]

-- %%
ALTER TABLE [dbo].[Conguiasreparsub] ADD  CONSTRAINT [DF_Conguiasreparsub_VlrHorHombre]  DEFAULT ((0)) FOR [VlrHorHombre]
GO

-- %% [markdown]
-- # [DF_Conguiasreparsub_VlrMaterial]

-- %%
ALTER TABLE [dbo].[Conguiasreparsub] ADD  CONSTRAINT [DF_Conguiasreparsub_VlrMaterial]  DEFAULT ((0)) FOR [VlrMaterial]
GO

-- %% [markdown]
-- # [DF_Conguiasreparsub_VlrIva]

-- %%
ALTER TABLE [dbo].[Conguiasreparsub] ADD  CONSTRAINT [DF_Conguiasreparsub_VlrIva]  DEFAULT ((0)) FOR [VlrIva]
GO

-- %% [markdown]
-- # [DF_Conguiasreparsub_VlrTotal]

-- %%
ALTER TABLE [dbo].[Conguiasreparsub] ADD  CONSTRAINT [DF_Conguiasreparsub_VlrTotal]  DEFAULT ((0)) FOR [VlrTotal]
GO

-- %% [markdown]
-- # [DF_Conguiasreparsub_Acargo]

-- %%
ALTER TABLE [dbo].[Conguiasreparsub] ADD  CONSTRAINT [DF_Conguiasreparsub_Acargo]  DEFAULT (N'LI') FOR [Acargo]
GO

-- %% [markdown]
-- # [DF_Coningresoexp_estado]

-- %%
ALTER TABLE [dbo].[Coningresoexp] ADD  CONSTRAINT [DF_Coningresoexp_estado]  DEFAULT ((0)) FOR [estado]
GO

-- %% [markdown]
-- # [DF_ConMotonaves_Estado]

-- %%
ALTER TABLE [dbo].[ConMotonaves] ADD  CONSTRAINT [DF_ConMotonaves_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_ConRecalada_Estado]

-- %%
ALTER TABLE [dbo].[ConRecalada] ADD  CONSTRAINT [DF_ConRecalada_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_ConSalidapatio_estado]

-- %%
ALTER TABLE [dbo].[ConSalidapatio] ADD  CONSTRAINT [DF_ConSalidapatio_estado]  DEFAULT ((0)) FOR [estado]
GO

-- %% [markdown]
-- # [DF_ConsultaCostos_Cantidad]

-- %%
ALTER TABLE [dbo].[ConsultaCostos] ADD  CONSTRAINT [DF_ConsultaCostos_Cantidad]  DEFAULT (0) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_ConsultaCostos_Descuento]

-- %%
ALTER TABLE [dbo].[ConsultaCostos] ADD  CONSTRAINT [DF_ConsultaCostos_Descuento]  DEFAULT (0) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_ConsultaCostos_Precio]

-- %%
ALTER TABLE [dbo].[ConsultaCostos] ADD  CONSTRAINT [DF_ConsultaCostos_Precio]  DEFAULT (0) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_ConsultaCostos_PIva]

-- %%
ALTER TABLE [dbo].[ConsultaCostos] ADD  CONSTRAINT [DF_ConsultaCostos_PIva]  DEFAULT (0) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_ConsultaCostos_Precio total]

-- %%
ALTER TABLE [dbo].[ConsultaCostos] ADD  CONSTRAINT [DF_ConsultaCostos_Precio total]  DEFAULT (0) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_ConsultaCostos_Neto]

-- %%
ALTER TABLE [dbo].[ConsultaCostos] ADD  CONSTRAINT [DF_ConsultaCostos_Neto]  DEFAULT (0) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_ConsultaCostos_Subtotal]

-- %%
ALTER TABLE [dbo].[ConsultaCostos] ADD  CONSTRAINT [DF_ConsultaCostos_Subtotal]  DEFAULT (0) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Contactos_Estado]

-- %%
ALTER TABLE [dbo].[Contactos] ADD  CONSTRAINT [DF_Contactos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_ConTarifasdemoras_ldmtam]

-- %%
ALTER TABLE [dbo].[ConTarifasdemoras] ADD  CONSTRAINT [DF_ConTarifasdemoras_ldmtam]  DEFAULT ((0)) FOR [ldmtam]
GO

-- %% [markdown]
-- # [DF_ConTarifasdemoras_Tarifa1]

-- %%
ALTER TABLE [dbo].[ConTarifasdemoras] ADD  CONSTRAINT [DF_ConTarifasdemoras_Tarifa1]  DEFAULT ((0)) FOR [Tarifa1]
GO

-- %% [markdown]
-- # [DF_ConTarifasdemoras_Tarifa2]

-- %%
ALTER TABLE [dbo].[ConTarifasdemoras] ADD  CONSTRAINT [DF_ConTarifasdemoras_Tarifa2]  DEFAULT ((0)) FOR [Tarifa2]
GO

-- %% [markdown]
-- # [DF_ConTarifasdemoras_Estado]

-- %%
ALTER TABLE [dbo].[ConTarifasdemoras] ADD  CONSTRAINT [DF_ConTarifasdemoras_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_ContenedorPendientes_Remesa]

-- %%
ALTER TABLE [dbo].[ContenedorPendientes] ADD  CONSTRAINT [DF_ContenedorPendientes_Remesa]  DEFAULT (0) FOR [Remesa]
GO

-- %% [markdown]
-- # [DF_ConTipoConcepto_Estado]

-- %%
ALTER TABLE [dbo].[ConTipoConcepto] ADD  CONSTRAINT [DF_ConTipoConcepto_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Contratos_Fecha]

-- %%
ALTER TABLE [dbo].[Contratos] ADD  CONSTRAINT [DF_Contratos_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Contratos_Dias]

-- %%
ALTER TABLE [dbo].[Contratos] ADD  CONSTRAINT [DF_Contratos_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Contratos_Capital]

-- %%
ALTER TABLE [dbo].[Contratos] ADD  CONSTRAINT [DF_Contratos_Capital]  DEFAULT ((0)) FOR [Capital]
GO

-- %% [markdown]
-- # [DF_Contratos_Tasa]

-- %%
ALTER TABLE [dbo].[Contratos] ADD  CONSTRAINT [DF_Contratos_Tasa]  DEFAULT ((0)) FOR [Tasa]
GO

-- %% [markdown]
-- # [DF_Contratos_Meses]

-- %%
ALTER TABLE [dbo].[Contratos] ADD  CONSTRAINT [DF_Contratos_Meses]  DEFAULT ((0)) FOR [Meses]
GO

-- %% [markdown]
-- # [DF_Contratos_Intereses]

-- %%
ALTER TABLE [dbo].[Contratos] ADD  CONSTRAINT [DF_Contratos_Intereses]  DEFAULT ((0)) FOR [Intereses]
GO

-- %% [markdown]
-- # [DF_Contratos_Total]

-- %%
ALTER TABLE [dbo].[Contratos] ADD  CONSTRAINT [DF_Contratos_Total]  DEFAULT ((0)) FOR [Total]
GO

-- %% [markdown]
-- # [DF_Contratos_Estado]

-- %%
ALTER TABLE [dbo].[Contratos] ADD  CONSTRAINT [DF_Contratos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Contratos_Documento]

-- %%
ALTER TABLE [dbo].[Contratos] ADD  CONSTRAINT [DF_Contratos_Documento]  DEFAULT (N'CT') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Contratos_PReteica]

-- %%
ALTER TABLE [dbo].[Contratos] ADD  CONSTRAINT [DF_Contratos_PReteica]  DEFAULT ((0)) FOR [PReteica]
GO

-- %% [markdown]
-- # [DF_Contratos_ReteIca]

-- %%
ALTER TABLE [dbo].[Contratos] ADD  CONSTRAINT [DF_Contratos_ReteIca]  DEFAULT ((0)) FOR [ReteIca]
GO

-- %% [markdown]
-- # [DF_Contratos_PRetencion]

-- %%
ALTER TABLE [dbo].[Contratos] ADD  CONSTRAINT [DF_Contratos_PRetencion]  DEFAULT ((0)) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_Contratos_Retencion]

-- %%
ALTER TABLE [dbo].[Contratos] ADD  CONSTRAINT [DF_Contratos_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_Contratos_Terminal]

-- %%
ALTER TABLE [dbo].[Contratos] ADD  CONSTRAINT [DF_Contratos_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_ContratosArticulado_Estado]

-- %%
ALTER TABLE [dbo].[ContratosArticulado] ADD  CONSTRAINT [DF_ContratosArticulado_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Contratosub_Cantidad]

-- %%
ALTER TABLE [dbo].[Contratosub] ADD  CONSTRAINT [DF_Contratosub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Contratosub_Pasajeros_1]

-- %%
ALTER TABLE [dbo].[Contratosub] ADD  CONSTRAINT [DF_Contratosub_Pasajeros_1]  DEFAULT ((0)) FOR [Pasajeros]
GO

-- %% [markdown]
-- # [DF_Contratosub_Venta_1]

-- %%
ALTER TABLE [dbo].[Contratosub] ADD  CONSTRAINT [DF_Contratosub_Venta_1]  DEFAULT ((0)) FOR [Venta]
GO

-- %% [markdown]
-- # [DF_Contratosub_Costo]

-- %%
ALTER TABLE [dbo].[Contratosub] ADD  CONSTRAINT [DF_Contratosub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_ControlMantenimiento_Fecha]

-- %%
ALTER TABLE [dbo].[ControlMantenimiento] ADD  CONSTRAINT [DF_ControlMantenimiento_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_ControlMantenimiento_HorometroActual]

-- %%
ALTER TABLE [dbo].[ControlMantenimiento] ADD  CONSTRAINT [DF_ControlMantenimiento_HorometroActual]  DEFAULT (0) FOR [HorometroActual]
GO

-- %% [markdown]
-- # [DF_Conversiones_Fecha]

-- %%
ALTER TABLE [dbo].[Conversiones] ADD  CONSTRAINT [DF_Conversiones_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Conversiones_Estado]

-- %%
ALTER TABLE [dbo].[Conversiones] ADD  CONSTRAINT [DF_Conversiones_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Convertir_Operacion]

-- %%
ALTER TABLE [dbo].[Convertir] ADD  CONSTRAINT [DF_Convertir_Operacion]  DEFAULT (0) FOR [Operacion]
GO

-- %% [markdown]
-- # [DF_Correos_Estado]

-- %%
ALTER TABLE [dbo].[Correos] ADD  CONSTRAINT [DF_Correos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_CorreosDominio_Abs]

-- %%
ALTER TABLE [dbo].[CorreosDominio] ADD  CONSTRAINT [DF_CorreosDominio_Abs]  DEFAULT ((1)) FOR [Abs]
GO

-- %% [markdown]
-- # [DF_CorreosDominio_Copia]

-- %%
ALTER TABLE [dbo].[CorreosDominio] ADD  CONSTRAINT [DF_CorreosDominio_Copia]  DEFAULT (N'NO') FOR [Copia]
GO

-- %% [markdown]
-- # [DF_CorreosDominio_Formato]

-- %%
ALTER TABLE [dbo].[CorreosDominio] ADD  CONSTRAINT [DF_CorreosDominio_Formato]  DEFAULT (N'Formato Snapshot') FOR [Formato]
GO

-- %% [markdown]
-- # [DF_Costos_Documento]

-- %%
ALTER TABLE [dbo].[Costos] ADD  CONSTRAINT [DF_Costos_Documento]  DEFAULT (N'CS') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Costos_Fproceso]

-- %%
ALTER TABLE [dbo].[Costos] ADD  CONSTRAINT [DF_Costos_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_CostosCIF_Producidas]

-- %%
ALTER TABLE [dbo].[CostosCIF] ADD  CONSTRAINT [DF_CostosCIF_Producidas]  DEFAULT (0) FOR [Producidas]
GO

-- %% [markdown]
-- # [DF_CostosCIF_Prorratear]

-- %%
ALTER TABLE [dbo].[CostosCIF] ADD  CONSTRAINT [DF_CostosCIF_Prorratear]  DEFAULT (0) FOR [Prorratear]
GO

-- %% [markdown]
-- # [DF_CostosCIF_Estado]

-- %%
ALTER TABLE [dbo].[CostosCIF] ADD  CONSTRAINT [DF_CostosCIF_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_CostosCIF2_Neto]

-- %%
ALTER TABLE [dbo].[CostosCIF2] ADD  CONSTRAINT [DF_CostosCIF2_Neto]  DEFAULT (0) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_CostosManoObra_Estado]

-- %%
ALTER TABLE [dbo].[CostosManoObra] ADD  CONSTRAINT [DF_CostosManoObra_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_CostosManoObra_Fecha]

-- %%
ALTER TABLE [dbo].[CostosManoObra] ADD  CONSTRAINT [DF_CostosManoObra_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_CostosManoObra_Horas]

-- %%
ALTER TABLE [dbo].[CostosManoObra] ADD  CONSTRAINT [DF_CostosManoObra_Horas]  DEFAULT (0) FOR [Horas]
GO

-- %% [markdown]
-- # [DF_CostosManoObra_Cantidad]

-- %%
ALTER TABLE [dbo].[CostosManoObra] ADD  CONSTRAINT [DF_CostosManoObra_Cantidad]  DEFAULT (0) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Fecha]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Transporte]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Transporte]  DEFAULT ((0)) FOR [Transporte]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Fproceso]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Cotizacion_TRM]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_TRM]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Estado]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Doc]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Doc]  DEFAULT (N'COTIZACION') FOR [Doc]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Dias]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Documento]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Documento]  DEFAULT (N'COT') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Terminal]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_Cotizacion_PDescuento]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_PDescuento]  DEFAULT ((0)) FOR [PDescuento]
GO

-- %% [markdown]
-- # [DF_Cotizacion_RMinima]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_RMinima]  DEFAULT ((0)) FOR [RMinima]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Peso]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Volumen]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Volumen]  DEFAULT ((0)) FOR [Volumen]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Pesofin]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Pesofin]  DEFAULT ((0)) FOR [Pesofin]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Imprevistos]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Imprevistos]  DEFAULT ((0)) FOR [Imprevistos]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Pimprevistos]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Pimprevistos]  DEFAULT ((0)) FOR [Pimprevistos]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Admon]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Admon]  DEFAULT ((0)) FOR [Admon]
GO

-- %% [markdown]
-- # [DF_Cotizacion_PAdmon]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_PAdmon]  DEFAULT ((0)) FOR [PAdmon]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Utilidadest]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Utilidadest]  DEFAULT ((0)) FOR [Utilidadest]
GO

-- %% [markdown]
-- # [DF_Cotizacion_PUtilidadest]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_PUtilidadest]  DEFAULT ((0)) FOR [PUtilidadest]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Status]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Status]  DEFAULT (N'PENDIENTE') FOR [Status]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Estado2]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Estado2]  DEFAULT ((0)) FOR [Estado2]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Valormercancia]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Valormercancia]  DEFAULT ((0)) FOR [Valormercancia]
GO

-- %% [markdown]
-- # [DF_Cotizacion_ValorFlete]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_ValorFlete]  DEFAULT ((0)) FOR [ValorFlete]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Largo]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Largo]  DEFAULT ((0)) FOR [Largo]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Ancho]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Ancho]  DEFAULT ((0)) FOR [Ancho]
GO

-- %% [markdown]
-- # [DF_Cotizacion_Alto]

-- %%
ALTER TABLE [dbo].[Cotizacion] ADD  CONSTRAINT [DF_Cotizacion_Alto]  DEFAULT ((0)) FOR [Alto]
GO

-- %% [markdown]
-- # [DF_Cotizacioninsumos_Cantidad]

-- %%
ALTER TABLE [dbo].[Cotizacioninsumos] ADD  CONSTRAINT [DF_Cotizacioninsumos_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Cotizacioninsumos_Costo]

-- %%
ALTER TABLE [dbo].[Cotizacioninsumos] ADD  CONSTRAINT [DF_Cotizacioninsumos_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Cotizacioninsumos_Total]

-- %%
ALTER TABLE [dbo].[Cotizacioninsumos] ADD  CONSTRAINT [DF_Cotizacioninsumos_Total]  DEFAULT ((0)) FOR [Total]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_Cantidad]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_Cantidad]  DEFAULT ((1)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_Descuento]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_Precio]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_PIva]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_Precio total]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_Neto]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_Peso]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_Subtotal]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_CUDol]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_CUDol]  DEFAULT ((0)) FOR [CUDol]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_Dolares]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_Dolares]  DEFAULT ((0)) FOR [Dolares]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_Cantidades]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_Cantidades]  DEFAULT ((0)) FOR [Cantidades]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_Costo]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_Moneda]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_Moneda]  DEFAULT (N'COP') FOR [Moneda]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_TRMS]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_TRMS]  DEFAULT ((1)) FOR [TRMS]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_CTotal]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_CTotal]  DEFAULT ((0)) FOR [CTotal]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_VPropina]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_VPropina]  DEFAULT ((0)) FOR [VPropina]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_Minima]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_Minima]  DEFAULT ((0)) FOR [Minima]
GO

-- %% [markdown]
-- # [DF_Cotizacionsub_Rebaja]

-- %%
ALTER TABLE [dbo].[Cotizacionsub] ADD  CONSTRAINT [DF_Cotizacionsub_Rebaja]  DEFAULT ((0)) FOR [Rebaja]
GO

-- %% [markdown]
-- # [DF_CotizaDimensiones_Largo]

-- %%
ALTER TABLE [dbo].[CotizaDimensiones] ADD  CONSTRAINT [DF_CotizaDimensiones_Largo]  DEFAULT ((0)) FOR [Largo]
GO

-- %% [markdown]
-- # [DF_CotizaDimensiones_Ancho]

-- %%
ALTER TABLE [dbo].[CotizaDimensiones] ADD  CONSTRAINT [DF_CotizaDimensiones_Ancho]  DEFAULT ((0)) FOR [Ancho]
GO

-- %% [markdown]
-- # [DF_CotizaDimensiones_Alto]

-- %%
ALTER TABLE [dbo].[CotizaDimensiones] ADD  CONSTRAINT [DF_CotizaDimensiones_Alto]  DEFAULT ((0)) FOR [Alto]
GO

-- %% [markdown]
-- # [DF_CotizaDimensiones_Volumen]

-- %%
ALTER TABLE [dbo].[CotizaDimensiones] ADD  CONSTRAINT [DF_CotizaDimensiones_Volumen]  DEFAULT ((0)) FOR [Volumen]
GO

-- %% [markdown]
-- # [DF_CotizaDimensiones_Piezas]

-- %%
ALTER TABLE [dbo].[CotizaDimensiones] ADD  CONSTRAINT [DF_CotizaDimensiones_Piezas]  DEFAULT ((0)) FOR [Piezas]
GO

-- %% [markdown]
-- # [DF_Crucecuenta_Fecha]

-- %%
ALTER TABLE [dbo].[Crucecuenta] ADD  CONSTRAINT [DF_Crucecuenta_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Crucecuenta_Estado]

-- %%
ALTER TABLE [dbo].[Crucecuenta] ADD  CONSTRAINT [DF_Crucecuenta_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Crucecuenta_Documento]

-- %%
ALTER TABLE [dbo].[Crucecuenta] ADD  CONSTRAINT [DF_Crucecuenta_Documento]  DEFAULT (N'CRC') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Crucecuentasub_Neto]

-- %%
ALTER TABLE [dbo].[Crucecuentasub] ADD  CONSTRAINT [DF_Crucecuentasub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Crucecuentasub_Us]

-- %%
ALTER TABLE [dbo].[Crucecuentasub] ADD  CONSTRAINT [DF_Crucecuentasub_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_Crucecuentasub_Docu]

-- %%
ALTER TABLE [dbo].[Crucecuentasub] ADD  CONSTRAINT [DF_Crucecuentasub_Docu]  DEFAULT (N'FV') FOR [Docu]
GO

-- %% [markdown]
-- # [DF_Crucecuentasub_Docu2]

-- %%
ALTER TABLE [dbo].[Crucecuentasub] ADD  CONSTRAINT [DF_Crucecuentasub_Docu2]  DEFAULT (N'FP') FOR [Docu2]
GO

-- %% [markdown]
-- # [DF_Ctrafico_Fecha]

-- %%
ALTER TABLE [dbo].[Ctrafico] ADD  CONSTRAINT [DF_Ctrafico_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Ctrafico_Estado]

-- %%
ALTER TABLE [dbo].[Ctrafico] ADD  CONSTRAINT [DF_Ctrafico_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Ctrafico_Terminal]

-- %%
ALTER TABLE [dbo].[Ctrafico] ADD  CONSTRAINT [DF_Ctrafico_Terminal]  DEFAULT (1) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_CtraficoMatrixsub_Dia]

-- %%
ALTER TABLE [dbo].[CtraficoMatrixsub] ADD  CONSTRAINT [DF_CtraficoMatrixsub_Dia]  DEFAULT (0) FOR [Dia]
GO

-- %% [markdown]
-- # [DF_Ctraficosub_Fecha]

-- %%
ALTER TABLE [dbo].[Ctraficosub] ADD  CONSTRAINT [DF_Ctraficosub_Fecha]  DEFAULT (getdate()) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Cuentas_Estado]

-- %%
ALTER TABLE [dbo].[Cuentas] ADD  CONSTRAINT [DF_Cuentas_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Cuentas_Imputable]

-- %%
ALTER TABLE [dbo].[Cuentas] ADD  CONSTRAINT [DF_Cuentas_Imputable]  DEFAULT (N'SI') FOR [Imputable]
GO

-- %% [markdown]
-- # [DF_Cuentas_Deducible]

-- %%
ALTER TABLE [dbo].[Cuentas] ADD  CONSTRAINT [DF_Cuentas_Deducible]  DEFAULT (N'SI') FOR [Deducible]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_FECHA]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_FECHA]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [FECHA]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_VALOR]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_VALOR]  DEFAULT ((0)) FOR [VALOR]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_Fproceso]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_Neto]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_PReteIca]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_Reteica]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_Reteica]  DEFAULT ((0)) FOR [Reteica]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_PReteIva]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_ReteIva]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_ReteIva]  DEFAULT ((0)) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_Documento]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_Documento]  DEFAULT (N'NCS') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_TipoRetencion]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_TipoRetencion]  DEFAULT ((2302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_Situacion]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_Situacion]  DEFAULT (N'CAUSAR CXP') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_Aplicacion]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_Aplicacion]  DEFAULT ((0)) FOR [Aplicacion]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_ConceptoM]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_ConceptoM]  DEFAULT ((2201)) FOR [ConceptoM]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_Base]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_Base]  DEFAULT ((0)) FOR [Base]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_DO]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_DO]  DEFAULT ((0)) FOR [DO]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_Dias]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_Estado]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_TRM]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_TRM]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_Us]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_Descuentos]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_Descuentos]  DEFAULT ((0)) FOR [Descuentos]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_Anticipo]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_Anticipo]  DEFAULT ((0)) FOR [Anticipo]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_Pcree]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_Pcree]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_Retecree]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_Retecree]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_Cuentas de cobro_Tipo]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro] ADD  CONSTRAINT [DF_Cuentas de cobro_Tipo]  DEFAULT (N'GASTO') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_Cuentasub_Cantidad]

-- %%
ALTER TABLE [dbo].[Cuentasub] ADD  CONSTRAINT [DF_Cuentasub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Cuentasub_Descuento]

-- %%
ALTER TABLE [dbo].[Cuentasub] ADD  CONSTRAINT [DF_Cuentasub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_Cuentasub_Precio]

-- %%
ALTER TABLE [dbo].[Cuentasub] ADD  CONSTRAINT [DF_Cuentasub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Cuentasub_PIva]

-- %%
ALTER TABLE [dbo].[Cuentasub] ADD  CONSTRAINT [DF_Cuentasub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_Cuentasub_Precio total]

-- %%
ALTER TABLE [dbo].[Cuentasub] ADD  CONSTRAINT [DF_Cuentasub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_Cuentasub_Neto]

-- %%
ALTER TABLE [dbo].[Cuentasub] ADD  CONSTRAINT [DF_Cuentasub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Cuentasub_Peso]

-- %%
ALTER TABLE [dbo].[Cuentasub] ADD  CONSTRAINT [DF_Cuentasub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Cuentasub_Subtotal]

-- %%
ALTER TABLE [dbo].[Cuentasub] ADD  CONSTRAINT [DF_Cuentasub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Cuentasub_Exentos]

-- %%
ALTER TABLE [dbo].[Cuentasub] ADD  CONSTRAINT [DF_Cuentasub_Exentos]  DEFAULT ((0)) FOR [Exentos]
GO

-- %% [markdown]
-- # [DF_Cuentasub_DesExentos]

-- %%
ALTER TABLE [dbo].[Cuentasub] ADD  CONSTRAINT [DF_Cuentasub_DesExentos]  DEFAULT ((0)) FOR [DesExentos]
GO

-- %% [markdown]
-- # [DF_Cuentasub_DesGravados]

-- %%
ALTER TABLE [dbo].[Cuentasub] ADD  CONSTRAINT [DF_Cuentasub_DesGravados]  DEFAULT ((0)) FOR [DesGravados]
GO

-- %% [markdown]
-- # [DF_Cuentasub_PRete]

-- %%
ALTER TABLE [dbo].[Cuentasub] ADD  CONSTRAINT [DF_Cuentasub_PRete]  DEFAULT ((0)) FOR [PRete]
GO

-- %% [markdown]
-- # [DF_Cuentasub_Retencion]

-- %%
ALTER TABLE [dbo].[Cuentasub] ADD  CONSTRAINT [DF_Cuentasub_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_Cuentasub_VPropina]

-- %%
ALTER TABLE [dbo].[Cuentasub] ADD  CONSTRAINT [DF_Cuentasub_VPropina]  DEFAULT ((0)) FOR [VPropina]
GO

-- %% [markdown]
-- # [DF_Cuentasub_Cree]

-- %%
ALTER TABLE [dbo].[Cuentasub] ADD  CONSTRAINT [DF_Cuentasub_Cree]  DEFAULT ((0)) FOR [Cree]
GO

-- %% [markdown]
-- # [DF_Cuentasubdescuentos_Neto]

-- %%
ALTER TABLE [dbo].[Cuentasubdescuentos] ADD  CONSTRAINT [DF_Cuentasubdescuentos_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Cumplido_Fecha]

-- %%
ALTER TABLE [dbo].[Cumplido] ADD  CONSTRAINT [DF_Cumplido_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Cumplido_OCargue]

-- %%
ALTER TABLE [dbo].[Cumplido] ADD  CONSTRAINT [DF_Cumplido_OCargue]  DEFAULT (0) FOR [OCargue]
GO

-- %% [markdown]
-- # [DF_Cumplido_Estado]

-- %%
ALTER TABLE [dbo].[Cumplido] ADD  CONSTRAINT [DF_Cumplido_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Cumplido_Documento]

-- %%
ALTER TABLE [dbo].[Cumplido] ADD  CONSTRAINT [DF_Cumplido_Documento]  DEFAULT (N'RM') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Cumplido_Anticipo]

-- %%
ALTER TABLE [dbo].[Cumplido] ADD  CONSTRAINT [DF_Cumplido_Anticipo]  DEFAULT ((0)) FOR [Anticipo]
GO

-- %% [markdown]
-- # [DF_Cumplidosub_Bultos]

-- %%
ALTER TABLE [dbo].[Cumplidosub] ADD  CONSTRAINT [DF_Cumplidosub_Bultos]  DEFAULT ((1)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Cumplidosub_Kilos]

-- %%
ALTER TABLE [dbo].[Cumplidosub] ADD  CONSTRAINT [DF_Cumplidosub_Kilos]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Cumplidosub_Estado]

-- %%
ALTER TABLE [dbo].[Cumplidosub] ADD  CONSTRAINT [DF_Cumplidosub_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Cumplidosub_Neto]

-- %%
ALTER TABLE [dbo].[Cumplidosub] ADD  CONSTRAINT [DF_Cumplidosub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Cumplidosub_Costo]

-- %%
ALTER TABLE [dbo].[Cumplidosub] ADD  CONSTRAINT [DF_Cumplidosub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Cumplidosub_Gastos]

-- %%
ALTER TABLE [dbo].[Cumplidosub] ADD  CONSTRAINT [DF_Cumplidosub_Gastos]  DEFAULT ((0)) FOR [Gastos]
GO

-- %% [markdown]
-- # [DF_Cumplidosub_EstadoMan]

-- %%
ALTER TABLE [dbo].[Cumplidosub] ADD  CONSTRAINT [DF_Cumplidosub_EstadoMan]  DEFAULT ((0)) FOR [EstadoMan]
GO

-- %% [markdown]
-- # [DF_Cumplidosub_CantIni]

-- %%
ALTER TABLE [dbo].[Cumplidosub] ADD  CONSTRAINT [DF_Cumplidosub_CantIni]  DEFAULT ((1)) FOR [CantIni]
GO

-- %% [markdown]
-- # [DF_Cumplidosub_CostoIni]

-- %%
ALTER TABLE [dbo].[Cumplidosub] ADD  CONSTRAINT [DF_Cumplidosub_CostoIni]  DEFAULT ((0)) FOR [CostoIni]
GO

-- %% [markdown]
-- # [DF_Cumplidosub_NetoIni]

-- %%
ALTER TABLE [dbo].[Cumplidosub] ADD  CONSTRAINT [DF_Cumplidosub_NetoIni]  DEFAULT ((0)) FOR [NetoIni]
GO

-- %% [markdown]
-- # [DF_Cumplir_Fecha]

-- %%
ALTER TABLE [dbo].[Cumplir] ADD  CONSTRAINT [DF_Cumplir_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Cumplir_Estado]

-- %%
ALTER TABLE [dbo].[Cumplir] ADD  CONSTRAINT [DF_Cumplir_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Cumplir_Documento]

-- %%
ALTER TABLE [dbo].[Cumplir] ADD  CONSTRAINT [DF_Cumplir_Documento]  DEFAULT (N'CP') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Cumplirsub_OCargue]

-- %%
ALTER TABLE [dbo].[Cumplirsub] ADD  CONSTRAINT [DF_Cumplirsub_OCargue]  DEFAULT (0) FOR [OCargue]
GO

-- %% [markdown]
-- # [DF_Cumplirsub_Manifiesto]

-- %%
ALTER TABLE [dbo].[Cumplirsub] ADD  CONSTRAINT [DF_Cumplirsub_Manifiesto]  DEFAULT (0) FOR [Manifiesto]
GO

-- %% [markdown]
-- # [DF_Cumplirsub_Costos]

-- %%
ALTER TABLE [dbo].[Cumplirsub] ADD  CONSTRAINT [DF_Cumplirsub_Costos]  DEFAULT ((0)) FOR [Costos]
GO

-- %% [markdown]
-- # [DF_Cumplirsub_Ingresos]

-- %%
ALTER TABLE [dbo].[Cumplirsub] ADD  CONSTRAINT [DF_Cumplirsub_Ingresos]  DEFAULT ((0)) FOR [Ingresos]
GO

-- %% [markdown]
-- # [DF_Datos_Fecha]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Datos_Comprobante]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_Comprobante]  DEFAULT ((0)) FOR [Comprobante]
GO

-- %% [markdown]
-- # [DF_Datos_Débitos]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_Débitos]  DEFAULT ((0)) FOR [Débitos]
GO

-- %% [markdown]
-- # [DF_Datos_Créditos]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_Créditos]  DEFAULT ((0)) FOR [Créditos]
GO

-- %% [markdown]
-- # [DF_Datos_Fproceso]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Datos_Estado]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Datos_IdControl]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_IdControl]  DEFAULT ((0)) FOR [IdControl]
GO

-- %% [markdown]
-- # [DF_Datos_Cheque]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_Cheque]  DEFAULT ((0)) FOR [Cheque]
GO

-- %% [markdown]
-- # [DF_Datos_IdEntradas]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_IdEntradas]  DEFAULT ((0)) FOR [IdEntradas]
GO

-- %% [markdown]
-- # [DF_Datos_Base]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_Base]  DEFAULT ((0)) FOR [Base]
GO

-- %% [markdown]
-- # [DF_Datos_Tarifa]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_Tarifa]  DEFAULT ((0)) FOR [Tarifa]
GO

-- %% [markdown]
-- # [DF_Datos_IvaMayor]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_IvaMayor]  DEFAULT ((0)) FOR [IvaMayor]
GO

-- %% [markdown]
-- # [DF_Datos_Niif]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_Niif]  DEFAULT (N'SI') FOR [Docu]
GO

-- %% [markdown]
-- # [DF_Datos_Niif_1]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_Niif_1]  DEFAULT (N'SI') FOR [Niif]
GO

-- %% [markdown]
-- # [DF_Datos_Local]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_Local]  DEFAULT (N'SI') FOR [Local]
GO

-- %% [markdown]
-- # [DF_Datos_Definitivo]

-- %%
ALTER TABLE [dbo].[Datos] ADD  CONSTRAINT [DF_Datos_Definitivo]  DEFAULT ((0)) FOR [Definitivo]
GO

-- %% [markdown]
-- # [DF_Debilidades_Periodo]

-- %%
ALTER TABLE [dbo].[Debilidades] ADD  CONSTRAINT [DF_Debilidades_Periodo]  DEFAULT (0) FOR [Periodo]
GO

-- %% [markdown]
-- # [DF_Debilidades_Codigodeb]

-- %%
ALTER TABLE [dbo].[Debilidades] ADD  CONSTRAINT [DF_Debilidades_Codigodeb]  DEFAULT (0) FOR [Codigodeb]
GO

-- %% [markdown]
-- # [DF_Debilidades_Año]

-- %%
ALTER TABLE [dbo].[Debilidades] ADD  CONSTRAINT [DF_Debilidades_Año]  DEFAULT (0) FOR [Año]
GO

-- %% [markdown]
-- # [DF_Demos_Fecha]

-- %%
ALTER TABLE [dbo].[Demos] ADD  CONSTRAINT [DF_Demos_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Demos_Estado]

-- %%
ALTER TABLE [dbo].[Demos] ADD  CONSTRAINT [DF_Demos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Depreciación_ImporteDepreciación]

-- %%
ALTER TABLE [dbo].[Depreciación] ADD  CONSTRAINT [DF_Depreciación_ImporteDepreciación]  DEFAULT ((0)) FOR [ImporteDepreciación]
GO

-- %% [markdown]
-- # [DF_Depreciación_Contabilizado]

-- %%
ALTER TABLE [dbo].[Depreciación] ADD  CONSTRAINT [DF_Depreciación_Contabilizado]  DEFAULT ((0)) FOR [Contabilizado]
GO

-- %% [markdown]
-- # [DF_Despachos_Fecha]

-- %%
ALTER TABLE [dbo].[Despachos] ADD  CONSTRAINT [DF_Despachos_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Despachos_Fproceso]

-- %%
ALTER TABLE [dbo].[Despachos] ADD  CONSTRAINT [DF_Despachos_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Despachos_Documento]

-- %%
ALTER TABLE [dbo].[Despachos] ADD  CONSTRAINT [DF_Despachos_Documento]  DEFAULT (N'RE') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Despachos_Descarga]

-- %%
ALTER TABLE [dbo].[Despachos] ADD  CONSTRAINT [DF_Despachos_Descarga]  DEFAULT (N'NO DESCARGAR') FOR [Descarga]
GO

-- %% [markdown]
-- # [DF_Despachos_Estado]

-- %%
ALTER TABLE [dbo].[Despachos] ADD  CONSTRAINT [DF_Despachos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Despachos_Terminal]

-- %%
ALTER TABLE [dbo].[Despachos] ADD  CONSTRAINT [DF_Despachos_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_Despachos_Dias]

-- %%
ALTER TABLE [dbo].[Despachos] ADD  CONSTRAINT [DF_Despachos_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Despachos_Doc]

-- %%
ALTER TABLE [dbo].[Despachos] ADD  CONSTRAINT [DF_Despachos_Doc]  DEFAULT (N'REMISION') FOR [Doc]
GO

-- %% [markdown]
-- # [DF_Despachos_PDescuento]

-- %%
ALTER TABLE [dbo].[Despachos] ADD  CONSTRAINT [DF_Despachos_PDescuento]  DEFAULT ((0)) FOR [PDescuento]
GO

-- %% [markdown]
-- # [DF_Despachos_Procesar]

-- %%
ALTER TABLE [dbo].[Despachos] ADD  CONSTRAINT [DF_Despachos_Procesar]  DEFAULT (N'SI') FOR [Procesar]
GO

-- %% [markdown]
-- # [DF_Despachosub_Cantidad]

-- %%
ALTER TABLE [dbo].[Despachosub] ADD  CONSTRAINT [DF_Despachosub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Despachosub_Descuento]

-- %%
ALTER TABLE [dbo].[Despachosub] ADD  CONSTRAINT [DF_Despachosub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_Despachosub_Precio]

-- %%
ALTER TABLE [dbo].[Despachosub] ADD  CONSTRAINT [DF_Despachosub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Despachosub_PIva]

-- %%
ALTER TABLE [dbo].[Despachosub] ADD  CONSTRAINT [DF_Despachosub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_Despachosub_Precio total]

-- %%
ALTER TABLE [dbo].[Despachosub] ADD  CONSTRAINT [DF_Despachosub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_Despachosub_Neto]

-- %%
ALTER TABLE [dbo].[Despachosub] ADD  CONSTRAINT [DF_Despachosub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Despachosub_Peso]

-- %%
ALTER TABLE [dbo].[Despachosub] ADD  CONSTRAINT [DF_Despachosub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Despachosub_Subtotal]

-- %%
ALTER TABLE [dbo].[Despachosub] ADD  CONSTRAINT [DF_Despachosub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Despachosub_Controlfinal]

-- %%
ALTER TABLE [dbo].[Despachosub] ADD  CONSTRAINT [DF_Despachosub_Controlfinal]  DEFAULT ((0)) FOR [Controlfinal]
GO

-- %% [markdown]
-- # [DF_Devoluciones_Fecha]

-- %%
ALTER TABLE [dbo].[Devoluciones] ADD  CONSTRAINT [DF_Devoluciones_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Devoluciones_Chequenumero]

-- %%
ALTER TABLE [dbo].[Devoluciones] ADD  CONSTRAINT [DF_Devoluciones_Chequenumero]  DEFAULT (0) FOR [Chequenumero]
GO

-- %% [markdown]
-- # [DF_Devoluciones_Neto]

-- %%
ALTER TABLE [dbo].[Devoluciones] ADD  CONSTRAINT [DF_Devoluciones_Neto]  DEFAULT (0) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Devoluciones_Documento]

-- %%
ALTER TABLE [dbo].[Devoluciones] ADD  CONSTRAINT [DF_Devoluciones_Documento]  DEFAULT (N'CHD') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Devoluciones_Concepto]

-- %%
ALTER TABLE [dbo].[Devoluciones] ADD  CONSTRAINT [DF_Devoluciones_Concepto]  DEFAULT (1317) FOR [Concepto]
GO

-- %% [markdown]
-- # [DF_Devoluciones_Adicional]

-- %%
ALTER TABLE [dbo].[Devoluciones] ADD  CONSTRAINT [DF_Devoluciones_Adicional]  DEFAULT (0) FOR [Adicional]
GO

-- %% [markdown]
-- # [DF_Devoluciones_Total]

-- %%
ALTER TABLE [dbo].[Devoluciones] ADD  CONSTRAINT [DF_Devoluciones_Total]  DEFAULT (0) FOR [Total]
GO

-- %% [markdown]
-- # [DF_Devoluciones_Estado]

-- %%
ALTER TABLE [dbo].[Devoluciones] ADD  CONSTRAINT [DF_Devoluciones_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Devoluciones_Us]

-- %%
ALTER TABLE [dbo].[Devoluciones] ADD  CONSTRAINT [DF_Devoluciones_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_Devoluciones_TRM]

-- %%
ALTER TABLE [dbo].[Devoluciones] ADD  CONSTRAINT [DF_Devoluciones_TRM]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Diario_Fecha]

-- %%
ALTER TABLE [dbo].[Diario] ADD  CONSTRAINT [DF_Diario_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Diario_Estado]

-- %%
ALTER TABLE [dbo].[Diario] ADD  CONSTRAINT [DF_Diario_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Diario_Contado]

-- %%
ALTER TABLE [dbo].[Diario] ADD  CONSTRAINT [DF_Diario_Contado]  DEFAULT ((0)) FOR [Contado]
GO

-- %% [markdown]
-- # [DF_Diario_Cartera]

-- %%
ALTER TABLE [dbo].[Diario] ADD  CONSTRAINT [DF_Diario_Cartera]  DEFAULT ((0)) FOR [Cartera]
GO

-- %% [markdown]
-- # [DF_Diario_Gastos]

-- %%
ALTER TABLE [dbo].[Diario] ADD  CONSTRAINT [DF_Diario_Gastos]  DEFAULT ((0)) FOR [Gastos]
GO

-- %% [markdown]
-- # [DF_Diario_Credito]

-- %%
ALTER TABLE [dbo].[Diario] ADD  CONSTRAINT [DF_Diario_Credito]  DEFAULT ((0)) FOR [Credito]
GO

-- %% [markdown]
-- # [DF_Diario_Ncredito]

-- %%
ALTER TABLE [dbo].[Diario] ADD  CONSTRAINT [DF_Diario_Ncredito]  DEFAULT ((0)) FOR [Ncredito]
GO

-- %% [markdown]
-- # [DF_Diario_Estado2]

-- %%
ALTER TABLE [dbo].[Diario] ADD  CONSTRAINT [DF_Diario_Estado2]  DEFAULT ((0)) FOR [Estado2]
GO

-- %% [markdown]
-- # [DF_Diario_ContadoP]

-- %%
ALTER TABLE [dbo].[Diario] ADD  CONSTRAINT [DF_Diario_ContadoP]  DEFAULT ((0)) FOR [ContadoP]
GO

-- %% [markdown]
-- # [DF_Diario_ContadoP1]

-- %%
ALTER TABLE [dbo].[Diario] ADD  CONSTRAINT [DF_Diario_ContadoP1]  DEFAULT ((0)) FOR [CreditoP]
GO

-- %% [markdown]
-- # [DF_Diario_ContadoP2]

-- %%
ALTER TABLE [dbo].[Diario] ADD  CONSTRAINT [DF_Diario_ContadoP2]  DEFAULT ((0)) FOR [NcreditoP]
GO

-- %% [markdown]
-- # [DF_Diario_ContadoP3]

-- %%
ALTER TABLE [dbo].[Diario] ADD  CONSTRAINT [DF_Diario_ContadoP3]  DEFAULT ((0)) FOR [CarteraP]
GO

-- %% [markdown]
-- # [DF_Diario_Documento]

-- %%
ALTER TABLE [dbo].[Diario] ADD  CONSTRAINT [DF_Diario_Documento]  DEFAULT (N'DC') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_DiarioA_Total]

-- %%
ALTER TABLE [dbo].[DiarioA] ADD  CONSTRAINT [DF_DiarioA_Total]  DEFAULT ((0)) FOR [Total]
GO

-- %% [markdown]
-- # [DF_DiarioA_Pagado]

-- %%
ALTER TABLE [dbo].[DiarioA] ADD  CONSTRAINT [DF_DiarioA_Pagado]  DEFAULT ((0)) FOR [Pagado]
GO

-- %% [markdown]
-- # [DF_DiarioB_Total]

-- %%
ALTER TABLE [dbo].[DiarioB] ADD  CONSTRAINT [DF_DiarioB_Total]  DEFAULT ((0)) FOR [Total]
GO

-- %% [markdown]
-- # [DF_DiarioB_Pagado]

-- %%
ALTER TABLE [dbo].[DiarioB] ADD  CONSTRAINT [DF_DiarioB_Pagado]  DEFAULT ((0)) FOR [Pagado]
GO

-- %% [markdown]
-- # [DF_DiarioC_Total]

-- %%
ALTER TABLE [dbo].[DiarioC] ADD  CONSTRAINT [DF_DiarioC_Total]  DEFAULT ((0)) FOR [Total]
GO

-- %% [markdown]
-- # [DF_DiarioC_Pagado]

-- %%
ALTER TABLE [dbo].[DiarioC] ADD  CONSTRAINT [DF_DiarioC_Pagado]  DEFAULT ((0)) FOR [Pagado]
GO

-- %% [markdown]
-- # [DF_DiarioD_Total]

-- %%
ALTER TABLE [dbo].[DiarioD] ADD  CONSTRAINT [DF_DiarioD_Total]  DEFAULT ((0)) FOR [Total]
GO

-- %% [markdown]
-- # [DF_DiarioE_Total]

-- %%
ALTER TABLE [dbo].[DiarioE] ADD  CONSTRAINT [DF_DiarioE_Total]  DEFAULT ((0)) FOR [Total]
GO

-- %% [markdown]
-- # [DF_DiarioE_Pagado]

-- %%
ALTER TABLE [dbo].[DiarioE] ADD  CONSTRAINT [DF_DiarioE_Pagado]  DEFAULT ((0)) FOR [Pagado]
GO

-- %% [markdown]
-- # [DF_DiarioF_Total]

-- %%
ALTER TABLE [dbo].[DiarioF] ADD  CONSTRAINT [DF_DiarioF_Total]  DEFAULT ((0)) FOR [Total]
GO

-- %% [markdown]
-- # [DF_DiarioF_Pagado]

-- %%
ALTER TABLE [dbo].[DiarioF] ADD  CONSTRAINT [DF_DiarioF_Pagado]  DEFAULT ((0)) FOR [Pagado]
GO

-- %% [markdown]
-- # [DF_Disponibilidadvehicular_Fecha]

-- %%
ALTER TABLE [dbo].[Disponibilidadvehicular] ADD  CONSTRAINT [DF_Disponibilidadvehicular_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Disponibilidadvehicular_Estado]

-- %%
ALTER TABLE [dbo].[Disponibilidadvehicular] ADD  CONSTRAINT [DF_Disponibilidadvehicular_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Documentacion_Estado]

-- %%
ALTER TABLE [dbo].[Documentacion] ADD  CONSTRAINT [DF_Documentacion_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_DocumentacionDO_Estado]

-- %%
ALTER TABLE [dbo].[DocumentacionDO] ADD  CONSTRAINT [DF_DocumentacionDO_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Documentacionplaca_Estado]

-- %%
ALTER TABLE [dbo].[Documentacionplaca] ADD  CONSTRAINT [DF_Documentacionplaca_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_DocumentacionRemesa_Neto]

-- %%
ALTER TABLE [dbo].[DocumentacionRemesa] ADD  CONSTRAINT [DF_DocumentacionRemesa_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Documentaciontercero_Estado]

-- %%
ALTER TABLE [dbo].[Documentaciontercero] ADD  CONSTRAINT [DF_Documentaciontercero_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Documentos_Estado]

-- %%
ALTER TABLE [dbo].[Documentos] ADD  CONSTRAINT [DF_Documentos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_DSAgencias_Estado]

-- %%
ALTER TABLE [dbo].[DSAgencias] ADD  CONSTRAINT [DF_DSAgencias_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_DSVia_Estado]

-- %%
ALTER TABLE [dbo].[DSVia] ADD  CONSTRAINT [DF_DSVia_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Empleado_Salario]

-- %%
ALTER TABLE [dbo].[Empleado] ADD  CONSTRAINT [DF_Empleado_Salario]  DEFAULT ((0)) FOR [Salario]
GO

-- %% [markdown]
-- # [DF_Empleado_Tipo]

-- %%
ALTER TABLE [dbo].[Empleado] ADD  CONSTRAINT [DF_Empleado_Tipo]  DEFAULT (N'SI') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_Empleado_Comision]

-- %%
ALTER TABLE [dbo].[Empleado] ADD  CONSTRAINT [DF_Empleado_Comision]  DEFAULT ((0)) FOR [Comision]
GO

-- %% [markdown]
-- # [DF_Empleado_RIP]

-- %%
ALTER TABLE [dbo].[Empleado] ADD  CONSTRAINT [DF_Empleado_RIP]  DEFAULT ((0)) FOR [RIP]
GO

-- %% [markdown]
-- # [DF_Empleado_Situacion]

-- %%
ALTER TABLE [dbo].[Empleado] ADD  CONSTRAINT [DF_Empleado_Situacion]  DEFAULT (N'ACTIVADO') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Empleado_Compensacion]

-- %%
ALTER TABLE [dbo].[Empleado] ADD  CONSTRAINT [DF_Empleado_Compensacion]  DEFAULT ((0)) FOR [Compensacion]
GO

-- %% [markdown]
-- # [DF_Empleado_Total]

-- %%
ALTER TABLE [dbo].[Empleado] ADD  CONSTRAINT [DF_Empleado_Total]  DEFAULT ((0)) FOR [Total]
GO

-- %% [markdown]
-- # [DF_Empleado_Estado]

-- %%
ALTER TABLE [dbo].[Empleado] ADD  CONSTRAINT [DF_Empleado_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Empleado_Parafiscales]

-- %%
ALTER TABLE [dbo].[Empleado] ADD  CONSTRAINT [DF_Empleado_Parafiscales]  DEFAULT (N'SI') FOR [Parafiscales]
GO

-- %% [markdown]
-- # [DF_Empleado_PRetefte]

-- %%
ALTER TABLE [dbo].[Empleado] ADD  CONSTRAINT [DF_Empleado_PRetefte]  DEFAULT ((0)) FOR [PRetefte]
GO

-- %% [markdown]
-- # [DF_Empleado_SubTipoTrabajador]

-- %%
ALTER TABLE [dbo].[Empleado] ADD  CONSTRAINT [DF_Empleado_SubTipoTrabajador]  DEFAULT (N'00') FOR [SubTipoTrabajador]
GO

-- %% [markdown]
-- # [DF_EmpleadoCompensa_Neto]

-- %%
ALTER TABLE [dbo].[EmpleadoCompensa] ADD  CONSTRAINT [DF_EmpleadoCompensa_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_EmpleadoContrato_Estado]

-- %%
ALTER TABLE [dbo].[EmpleadoContrato] ADD  CONSTRAINT [DF_EmpleadoContrato_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Empleadoexenciones_Neto]

-- %%
ALTER TABLE [dbo].[Empleadoexenciones] ADD  CONSTRAINT [DF_Empleadoexenciones_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Empleadoexenciones_Estado]

-- %%
ALTER TABLE [dbo].[Empleadoexenciones] ADD  CONSTRAINT [DF_Empleadoexenciones_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_EmpleadoTipo_Estado]

-- %%
ALTER TABLE [dbo].[EmpleadoTipo] ADD  CONSTRAINT [DF_EmpleadoTipo_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_EmpleadoTipocontrato_Estado]

-- %%
ALTER TABLE [dbo].[EmpleadoTipocontrato] ADD  CONSTRAINT [DF_EmpleadoTipocontrato_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_EmpleadoVacaciones_Salariomes]

-- %%
ALTER TABLE [dbo].[EmpleadoVacaciones] ADD  CONSTRAINT [DF_EmpleadoVacaciones_Salariomes]  DEFAULT ((0)) FOR [Salariomes]
GO

-- %% [markdown]
-- # [DF_EmpleadoVacaciones_salariodia]

-- %%
ALTER TABLE [dbo].[EmpleadoVacaciones] ADD  CONSTRAINT [DF_EmpleadoVacaciones_salariodia]  DEFAULT ((0)) FOR [salariodia]
GO

-- %% [markdown]
-- # [DF_EmpleadoVacaciones_Diascausa]

-- %%
ALTER TABLE [dbo].[EmpleadoVacaciones] ADD  CONSTRAINT [DF_EmpleadoVacaciones_Diascausa]  DEFAULT ((0)) FOR [Diascausa]
GO

-- %% [markdown]
-- # [DF_EmpleadoVacaciones_Diasvac]

-- %%
ALTER TABLE [dbo].[EmpleadoVacaciones] ADD  CONSTRAINT [DF_EmpleadoVacaciones_Diasvac]  DEFAULT ((0)) FOR [Diasvac]
GO

-- %% [markdown]
-- # [DF_EmpleadoVacaciones_Total]

-- %%
ALTER TABLE [dbo].[EmpleadoVacaciones] ADD  CONSTRAINT [DF_EmpleadoVacaciones_Total]  DEFAULT ((0)) FOR [Total]
GO

-- %% [markdown]
-- # [DF_EmpleadoVacaciones_Estado]

-- %%
ALTER TABLE [dbo].[EmpleadoVacaciones] ADD  CONSTRAINT [DF_EmpleadoVacaciones_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_EmpleadoVacaciones_Festivos]

-- %%
ALTER TABLE [dbo].[EmpleadoVacaciones] ADD  CONSTRAINT [DF_EmpleadoVacaciones_Festivos]  DEFAULT ((0)) FOR [Festivos]
GO

-- %% [markdown]
-- # [DF_Encuesta_Estado]

-- %%
ALTER TABLE [dbo].[Encuesta] ADD  CONSTRAINT [DF_Encuesta_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Encuesta_Fecha]

-- %%
ALTER TABLE [dbo].[Encuesta] ADD  CONSTRAINT [DF_Encuesta_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Encuesta_Variable1]

-- %%
ALTER TABLE [dbo].[Encuesta] ADD  CONSTRAINT [DF_Encuesta_Variable1]  DEFAULT ((1)) FOR [Variable1]
GO

-- %% [markdown]
-- # [DF_Encuesta_Variable2]

-- %%
ALTER TABLE [dbo].[Encuesta] ADD  CONSTRAINT [DF_Encuesta_Variable2]  DEFAULT ((2)) FOR [Variable2]
GO

-- %% [markdown]
-- # [DF_Encuesta_Variable3]

-- %%
ALTER TABLE [dbo].[Encuesta] ADD  CONSTRAINT [DF_Encuesta_Variable3]  DEFAULT ((3)) FOR [Variable3]
GO

-- %% [markdown]
-- # [DF_Encuesta_Variable4]

-- %%
ALTER TABLE [dbo].[Encuesta] ADD  CONSTRAINT [DF_Encuesta_Variable4]  DEFAULT ((4)) FOR [Variable4]
GO

-- %% [markdown]
-- # [DF_Encuesta_Variable5]

-- %%
ALTER TABLE [dbo].[Encuesta] ADD  CONSTRAINT [DF_Encuesta_Variable5]  DEFAULT ((5)) FOR [Variable5]
GO

-- %% [markdown]
-- # [DF_Encuesta_Variable6]

-- %%
ALTER TABLE [dbo].[Encuesta] ADD  CONSTRAINT [DF_Encuesta_Variable6]  DEFAULT ((6)) FOR [Variable6]
GO

-- %% [markdown]
-- # [DF_Encuesta_Variable7]

-- %%
ALTER TABLE [dbo].[Encuesta] ADD  CONSTRAINT [DF_Encuesta_Variable7]  DEFAULT ((7)) FOR [Variable7]
GO

-- %% [markdown]
-- # [DF_Encuesta_Documento]

-- %%
ALTER TABLE [dbo].[Encuesta] ADD  CONSTRAINT [DF_Encuesta_Documento]  DEFAULT (N'EN') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_EncuestaVariables_Estado]

-- %%
ALTER TABLE [dbo].[EncuestaVariables] ADD  CONSTRAINT [DF_EncuestaVariables_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_EncuestaVariables_Status]

-- %%
ALTER TABLE [dbo].[EncuestaVariables] ADD  CONSTRAINT [DF_EncuestaVariables_Status]  DEFAULT (N'SI') FOR [Status]
GO

-- %% [markdown]
-- # [DF_Entrada_Código ICA]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Código ICA]  DEFAULT ((0)) FOR [Código ICA]
GO

-- %% [markdown]
-- # [DF_Entrada_Tarifa ICA]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Tarifa ICA]  DEFAULT ((0)) FOR [Tarifa ICA]
GO

-- %% [markdown]
-- # [DF_Entrada_VALOR PRESENTE]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_VALOR PRESENTE]  DEFAULT ((0)) FOR [VALOR PRESENTE]
GO

-- %% [markdown]
-- # [DF_Entrada_VALOR FUTURO]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_VALOR FUTURO]  DEFAULT ((0)) FOR [VALOR FUTURO]
GO

-- %% [markdown]
-- # [DF_Entrada_PERIODOS]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_PERIODOS]  DEFAULT ((0)) FOR [PERIODOS]
GO

-- %% [markdown]
-- # [DF_Entrada_CONTROL]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_CONTROL]  DEFAULT ((0)) FOR [CONTROL]
GO

-- %% [markdown]
-- # [DF_Entrada_Costos]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Costos]  DEFAULT ((0)) FOR [Costos]
GO

-- %% [markdown]
-- # [DF_Entrada_Descargue]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Descargue]  DEFAULT ((0)) FOR [Descargue]
GO

-- %% [markdown]
-- # [DF_Entrada_Academico]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Academico]  DEFAULT ((0)) FOR [Academico]
GO

-- %% [markdown]
-- # [DF_Entrada_Reservas]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Reservas]  DEFAULT ((0)) FOR [Reservas]
GO

-- %% [markdown]
-- # [DF_Entrada_Matrix]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Matrix]  DEFAULT ((0)) FOR [Matrix]
GO

-- %% [markdown]
-- # [DF_Entrada_CallCenter]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_CallCenter]  DEFAULT ((0)) FOR [CallCenter]
GO

-- %% [markdown]
-- # [DF_Entrada_Transporte]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Transporte]  DEFAULT ((0)) FOR [Transporte]
GO

-- %% [markdown]
-- # [DF_Entrada_Peso]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Entrada_Dolares]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Dolares]  DEFAULT ((0)) FOR [Dolares]
GO

-- %% [markdown]
-- # [DF_Entrada_Restaurantes]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Restaurantes]  DEFAULT ((0)) FOR [Restaurantes]
GO

-- %% [markdown]
-- # [DF_Entrada_Mostrador]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Mostrador]  DEFAULT ((0)) FOR [Mostrador]
GO

-- %% [markdown]
-- # [DF_Entrada_Estandar]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Estandar]  DEFAULT ((0)) FOR [Estandar]
GO

-- %% [markdown]
-- # [DF_Entrada_Licenciado]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Licenciado]  DEFAULT ((0)) FOR [Licenciado]
GO

-- %% [markdown]
-- # [DF_Entrada_Proceso]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Proceso]  DEFAULT ((0)) FOR [Proceso]
GO

-- %% [markdown]
-- # [DF_Entrada_CExistencia]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_CExistencia]  DEFAULT ((0)) FOR [CExistencia]
GO

-- %% [markdown]
-- # [DF_Entrada_Rebaja]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Rebaja]  DEFAULT ((0)) FOR [Rebaja]
GO

-- %% [markdown]
-- # [DF_Entrada_Consolidado]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Consolidado]  DEFAULT ((0)) FOR [Consolidado]
GO

-- %% [markdown]
-- # [DF_Entrada_Contratos]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Contratos]  DEFAULT ((0)) FOR [Contratos]
GO

-- %% [markdown]
-- # [DF_Entrada_Horas]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Horas]  DEFAULT ((0)) FOR [Horas]
GO

-- %% [markdown]
-- # [DF_Entrada_Importaciones]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Importaciones]  DEFAULT ((0)) FOR [Importaciones]
GO

-- %% [markdown]
-- # [DF_Entrada_Talleres]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Talleres]  DEFAULT ((0)) FOR [Talleres]
GO

-- %% [markdown]
-- # [DF_Entrada_Planpagos]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Planpagos]  DEFAULT ((0)) FOR [Planpagos]
GO

-- %% [markdown]
-- # [DF_Entrada_Asegurar]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Asegurar]  DEFAULT ((0)) FOR [Asegurar]
GO

-- %% [markdown]
-- # [DF_Entrada_Cupo]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Cupo]  DEFAULT ((0)) FOR [Cupo]
GO

-- %% [markdown]
-- # [DF_Entrada_ConseReferencias]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_ConseReferencias]  DEFAULT ((0)) FOR [ConseReferencias]
GO

-- %% [markdown]
-- # [DF_Entrada_Constructoras]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Constructoras]  DEFAULT ((0)) FOR [Constructoras]
GO

-- %% [markdown]
-- # [DF_Entrada_AgentesCarga]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_AgentesCarga]  DEFAULT ((0)) FOR [AgentesCarga]
GO

-- %% [markdown]
-- # [DF_Entrada_Dolares2]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Dolares2]  DEFAULT ((0)) FOR [Dolares2]
GO

-- %% [markdown]
-- # [DF_Entrada_Media]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Media]  DEFAULT ((0)) FOR [Media]
GO

-- %% [markdown]
-- # [DF_Entrada_Saldocentros]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Saldocentros]  DEFAULT ((0)) FOR [Saldocentros]
GO

-- %% [markdown]
-- # [DF_Entrada_Composicion]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Composicion]  DEFAULT ((0)) FOR [Composicion]
GO

-- %% [markdown]
-- # [DF_Entrada_DesFactura]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_DesFactura]  DEFAULT ((0)) FOR [DesFactura]
GO

-- %% [markdown]
-- # [DF_Entrada_Planillas]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Planillas]  DEFAULT ((0)) FOR [Planillas]
GO

-- %% [markdown]
-- # [DF_Entrada_AnticiposPos]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_AnticiposPos]  DEFAULT ((0)) FOR [AnticiposPos]
GO

-- %% [markdown]
-- # [DF_Entrada_CupoMos]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_CupoMos]  DEFAULT ((0)) FOR [CupoMos]
GO

-- %% [markdown]
-- # [DF_Entrada_RetefteMos]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_RetefteMos]  DEFAULT ((0)) FOR [RetefteMos]
GO

-- %% [markdown]
-- # [DF_Entrada_Seguros]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Seguros]  DEFAULT ((0)) FOR [Seguros]
GO

-- %% [markdown]
-- # [DF_Entrada_RendMinimo]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_RendMinimo]  DEFAULT ((0)) FOR [RendMinimo]
GO

-- %% [markdown]
-- # [DF_Entrada_ControlRen]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_ControlRen]  DEFAULT ((0)) FOR [ControlRen]
GO

-- %% [markdown]
-- # [DF_Entrada_Liquidos]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Liquidos]  DEFAULT ((0)) FOR [Liquidos]
GO

-- %% [markdown]
-- # [DF_Entrada_Contabilizar]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Contabilizar]  DEFAULT ((0)) FOR [Contabilizar]
GO

-- %% [markdown]
-- # [DF_Entrada_PRetecree]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_PRetecree]  DEFAULT ((0)) FOR [PRetecree]
GO

-- %% [markdown]
-- # [DF_Entrada_Pasajeros]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Pasajeros]  DEFAULT ((0)) FOR [Pasajeros]
GO

-- %% [markdown]
-- # [DF_Entrada_Carteraus]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Carteraus]  DEFAULT ((0)) FOR [Carteraus]
GO

-- %% [markdown]
-- # [DF_Entrada_Deudasus]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Deudasus]  DEFAULT ((0)) FOR [Deudasus]
GO

-- %% [markdown]
-- # [DF_Entrada_Multiresolucion]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Multiresolucion]  DEFAULT ((0)) FOR [Multiresolucion]
GO

-- %% [markdown]
-- # [DF_Entrada_Multilistas]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Multilistas]  DEFAULT ((0)) FOR [Multilistas]
GO

-- %% [markdown]
-- # [DF_Entrada_SFavor]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_SFavor]  DEFAULT ((0)) FOR [SFavor]
GO

-- %% [markdown]
-- # [DF_Entrada_Bolsas]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Bolsas]  DEFAULT ((0)) FOR [Bolsas]
GO

-- %% [markdown]
-- # [DF_Entrada_UBolsa]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_UBolsa]  DEFAULT ((0)) FOR [UBolsa]
GO

-- %% [markdown]
-- # [DF_Entrada_Aduanas]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Aduanas]  DEFAULT ((0)) FOR [Aduanas]
GO

-- %% [markdown]
-- # [DF_Entrada_DestinoSeguro]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_DestinoSeguro]  DEFAULT ((0)) FOR [DestinoSeguro]
GO

-- %% [markdown]
-- # [DF_Entrada_Tareas]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Tareas]  DEFAULT ((0)) FOR [Tareas]
GO

-- %% [markdown]
-- # [DF_Entrada_Pagosproveedores]

-- %%
ALTER TABLE [dbo].[Entrada] ADD  CONSTRAINT [DF_Entrada_Pagosproveedores]  DEFAULT ((0)) FOR [Pagosproveedores]
GO

-- %% [markdown]
-- # [DF_EPS_Estado]

-- %%
ALTER TABLE [dbo].[EPS] ADD  CONSTRAINT [DF_EPS_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Escalacotizacion_Precio20]

-- %%
ALTER TABLE [dbo].[Escalacotizacion] ADD  CONSTRAINT [DF_Escalacotizacion_Precio20]  DEFAULT ((0)) FOR [Precio20]
GO

-- %% [markdown]
-- # [DF_Escalacotizacion_Precio40]

-- %%
ALTER TABLE [dbo].[Escalacotizacion] ADD  CONSTRAINT [DF_Escalacotizacion_Precio40]  DEFAULT ((0)) FOR [Precio40]
GO

-- %% [markdown]
-- # [DF_Escalacotizacion_Precio40HC]

-- %%
ALTER TABLE [dbo].[Escalacotizacion] ADD  CONSTRAINT [DF_Escalacotizacion_Precio40HC]  DEFAULT ((0)) FOR [Precio40HC]
GO

-- %% [markdown]
-- # [DF_Escalacotizacion_Peso1]

-- %%
ALTER TABLE [dbo].[Escalacotizacion] ADD  CONSTRAINT [DF_Escalacotizacion_Peso1]  DEFAULT ((0)) FOR [Peso1]
GO

-- %% [markdown]
-- # [DF_Escalacotizacion_Peso2]

-- %%
ALTER TABLE [dbo].[Escalacotizacion] ADD  CONSTRAINT [DF_Escalacotizacion_Peso2]  DEFAULT ((0)) FOR [Peso2]
GO

-- %% [markdown]
-- # [DF_Escalacotizacion_Peso3]

-- %%
ALTER TABLE [dbo].[Escalacotizacion] ADD  CONSTRAINT [DF_Escalacotizacion_Peso3]  DEFAULT ((0)) FOR [Peso3]
GO

-- %% [markdown]
-- # [DF_Escalacotizacion_Peso31]

-- %%
ALTER TABLE [dbo].[Escalacotizacion] ADD  CONSTRAINT [DF_Escalacotizacion_Peso31]  DEFAULT ((0)) FOR [Peso4]
GO

-- %% [markdown]
-- # [DF_Escalacotizacion_Peso5]

-- %%
ALTER TABLE [dbo].[Escalacotizacion] ADD  CONSTRAINT [DF_Escalacotizacion_Peso5]  DEFAULT ((0)) FOR [Peso5]
GO

-- %% [markdown]
-- # [DF_Escalacotizacion_PesoMin]

-- %%
ALTER TABLE [dbo].[Escalacotizacion] ADD  CONSTRAINT [DF_Escalacotizacion_PesoMin]  DEFAULT ((0)) FOR [PesoMin]
GO

-- %% [markdown]
-- # [DF_Evaluacion_Fecha]

-- %%
ALTER TABLE [dbo].[Evaluacion] ADD  CONSTRAINT [DF_Evaluacion_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Evaluacion_Puntaje]

-- %%
ALTER TABLE [dbo].[Evaluacion] ADD  CONSTRAINT [DF_Evaluacion_Puntaje]  DEFAULT ((0)) FOR [Puntaje]
GO

-- %% [markdown]
-- # [DF_Evaluacion_Estado]

-- %%
ALTER TABLE [dbo].[Evaluacion] ADD  CONSTRAINT [DF_Evaluacion_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Extracontrato_Fecha]

-- %%
ALTER TABLE [dbo].[Extracontrato] ADD  CONSTRAINT [DF_Extracontrato_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Extracontrato_Dias]

-- %%
ALTER TABLE [dbo].[Extracontrato] ADD  CONSTRAINT [DF_Extracontrato_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Extracontrato_Estado]

-- %%
ALTER TABLE [dbo].[Extracontrato] ADD  CONSTRAINT [DF_Extracontrato_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Extracontrato_Documento]

-- %%
ALTER TABLE [dbo].[Extracontrato] ADD  CONSTRAINT [DF_Extracontrato_Documento]  DEFAULT (N'EC') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Extracto_Estado]

-- %%
ALTER TABLE [dbo].[Extracto] ADD  CONSTRAINT [DF_Extracto_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Extractosub_Entrada]

-- %%
ALTER TABLE [dbo].[Extractosub] ADD  CONSTRAINT [DF_Extractosub_Entrada]  DEFAULT (0) FOR [Entrada]
GO

-- %% [markdown]
-- # [DF_Factura_Estado]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Factura_Fechafac]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Fechafac]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fechafac]
GO

-- %% [markdown]
-- # [DF_Factura_Tipo]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Tipo]  DEFAULT (N'VENTA') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_Factura_Valortransporte]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Valortransporte]  DEFAULT ((0)) FOR [Valortransporte]
GO

-- %% [markdown]
-- # [DF_Factura_Dias]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Factura_Vencimiento]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Vencimiento]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Vencimiento]
GO

-- %% [markdown]
-- # [DF_Factura_Documento]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Documento]  DEFAULT (N'FV') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Factura_Saldo]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Saldo]  DEFAULT ((0)) FOR [Saldo]
GO

-- %% [markdown]
-- # [DF_Factura_Bloque]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Bloque]  DEFAULT ((0)) FOR [Bloque]
GO

-- %% [markdown]
-- # [DF_Factura_PReteIca]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_Factura_Reteica]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Reteica]  DEFAULT ((0)) FOR [Reteica]
GO

-- %% [markdown]
-- # [DF_Factura_PReteIva]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_Factura_ReteIva]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_ReteIva]  DEFAULT ((0)) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_Factura_Fproceso]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Factura_PDescuento]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_PDescuento]  DEFAULT ((0)) FOR [PDescuento]
GO

-- %% [markdown]
-- # [DF_Factura_TRM]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_TRM]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Factura_TipoRetencion]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_TipoRetencion]  DEFAULT ((1302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_Factura_Cupo]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Cupo]  DEFAULT ((0)) FOR [Cupo]
GO

-- %% [markdown]
-- # [DF_Factura_Diasvencimiento]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Diasvencimiento]  DEFAULT ((0)) FOR [Diasvencimiento]
GO

-- %% [markdown]
-- # [DF_Factura_Cartera]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Cartera]  DEFAULT ((0)) FOR [Cartera]
GO

-- %% [markdown]
-- # [DF_Factura_Edad]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Edad]  DEFAULT ((0)) FOR [Edad]
GO

-- %% [markdown]
-- # [DF_Factura_Estadoter]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Estadoter]  DEFAULT ((0)) FOR [Estadoter]
GO

-- %% [markdown]
-- # [DF_Factura_Descarga]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Descarga]  DEFAULT (N'DESCARGAR') FOR [Descarga]
GO

-- %% [markdown]
-- # [DF_Factura_Matrix]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Matrix]  DEFAULT ((0)) FOR [Matrix]
GO

-- %% [markdown]
-- # [DF_Factura_PFlete]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_PFlete]  DEFAULT ((0)) FOR [PFlete]
GO

-- %% [markdown]
-- # [DF_Factura_Terminal]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_Factura_Concepto]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Concepto]  DEFAULT ((1315)) FOR [Concepto]
GO

-- %% [markdown]
-- # [DF_Factura_Diferencia]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Diferencia]  DEFAULT ((0)) FOR [Diferencia]
GO

-- %% [markdown]
-- # [DF_Factura_Anticipos]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Anticipos]  DEFAULT ((0)) FOR [Anticipos]
GO

-- %% [markdown]
-- # [DF_Factura_Us]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_Factura_PUtilidadest]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_PUtilidadest]  DEFAULT ((0)) FOR [PUtilidadest]
GO

-- %% [markdown]
-- # [DF_Factura_Utilidadest]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Utilidadest]  DEFAULT ((0)) FOR [Utilidadest]
GO

-- %% [markdown]
-- # [DF_Factura_Control]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Control]  DEFAULT ((0)) FOR [Control]
GO

-- %% [markdown]
-- # [DF_Factura_Pcree]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Pcree]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_Factura_Retecree]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Retecree]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_Factura_Imprevistos]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Imprevistos]  DEFAULT ((0)) FOR [Imprevistos]
GO

-- %% [markdown]
-- # [DF_Factura_Pimprevistos]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Pimprevistos]  DEFAULT ((0)) FOR [Pimprevistos]
GO

-- %% [markdown]
-- # [DF_Factura_Admon]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Admon]  DEFAULT ((0)) FOR [Admon]
GO

-- %% [markdown]
-- # [DF_Factura_PAdmon]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_PAdmon]  DEFAULT ((0)) FOR [PAdmon]
GO

-- %% [markdown]
-- # [DF_Factura_PRetefte]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_PRetefte]  DEFAULT ((0)) FOR [PRetefte]
GO

-- %% [markdown]
-- # [DF_Factura_Retefte]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Retefte]  DEFAULT ((0)) FOR [Retefte]
GO

-- %% [markdown]
-- # [DF_Factura_CantBolsas]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_CantBolsas]  DEFAULT ((0)) FOR [CantBolsas]
GO

-- %% [markdown]
-- # [DF_Factura_ValBolsas]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_ValBolsas]  DEFAULT ((0)) FOR [ValBolsas]
GO

-- %% [markdown]
-- # [DF_Factura_StatusDian]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_StatusDian]  DEFAULT ((0)) FOR [StatusDian]
GO

-- %% [markdown]
-- # [DF_Factura_StatusCliente]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_StatusCliente]  DEFAULT ((0)) FOR [StatusCliente]
GO

-- %% [markdown]
-- # [DF_Factura_Horafin]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_Horafin]  DEFAULT (getdate()) FOR [Horafin]
GO

-- %% [markdown]
-- # [DF_Factura_TipoFactura]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_TipoFactura]  DEFAULT (N'01') FOR [TipoFactura]
GO

-- %% [markdown]
-- # [DF_Factura_TipoOperacion]

-- %%
ALTER TABLE [dbo].[Factura] ADD  CONSTRAINT [DF_Factura_TipoOperacion]  DEFAULT (N'10') FOR [TipoOperacion]
GO

-- %% [markdown]
-- # [DF_Facturapos_Estado]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Facturapos_Fechafac]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Fechafac]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fechafac]
GO

-- %% [markdown]
-- # [DF_Facturapos_Tipo]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Tipo]  DEFAULT (N'Ventapos') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_Facturapos_Valortransporte]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Valortransporte]  DEFAULT ((0)) FOR [Valortransporte]
GO

-- %% [markdown]
-- # [DF_Facturapos_Formapago]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Formapago]  DEFAULT (N'CONTADO') FOR [Formapago]
GO

-- %% [markdown]
-- # [DF_Facturapos_Dias]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Facturapos_Vencimiento]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Vencimiento]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Vencimiento]
GO

-- %% [markdown]
-- # [DF_Facturapos_Documento]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Documento]  DEFAULT (N'FM') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Facturapos_Base]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Base]  DEFAULT ((0)) FOR [Base]
GO

-- %% [markdown]
-- # [DF_Facturapos_Abono]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Abono]  DEFAULT ((0)) FOR [Abono]
GO

-- %% [markdown]
-- # [DF_Facturapos_Saldo]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Saldo]  DEFAULT ((0)) FOR [Saldo]
GO

-- %% [markdown]
-- # [DF_Facturapos_Bloque]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Bloque]  DEFAULT ((0)) FOR [Bloque]
GO

-- %% [markdown]
-- # [DF_Facturapos_PRetencion]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_PRetencion]  DEFAULT ((0)) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_Facturapos_PReteIca]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_Facturapos_Reteica]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Reteica]  DEFAULT ((0)) FOR [Reteica]
GO

-- %% [markdown]
-- # [DF_Facturapos_PReteIva]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_Facturapos_ReteIva]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_ReteIva]  DEFAULT ((0)) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_Facturapos_Numero]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Numero]  DEFAULT ((0)) FOR [Numero]
GO

-- %% [markdown]
-- # [DF_Facturapos_Billete]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Billete]  DEFAULT ((0)) FOR [Billete]
GO

-- %% [markdown]
-- # [DF_Facturapos_Vueltas]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Vueltas]  DEFAULT ((0)) FOR [Vueltas]
GO

-- %% [markdown]
-- # [DF_Facturapos_Control]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Control]  DEFAULT ((0)) FOR [Control]
GO

-- %% [markdown]
-- # [DF_Facturapos_Descarga]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Descarga]  DEFAULT (N'DESCARGAR') FOR [Descarga]
GO

-- %% [markdown]
-- # [DF_Facturapos_PFlete]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_PFlete]  DEFAULT ((0)) FOR [PFlete]
GO

-- %% [markdown]
-- # [DF_Facturapos_Terminal]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_Facturapos_Numero2]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Numero2]  DEFAULT ((0)) FOR [Numero2]
GO

-- %% [markdown]
-- # [DF_Facturapos_PDescuento]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_PDescuento]  DEFAULT ((0)) FOR [PDescuento]
GO

-- %% [markdown]
-- # [DF_Facturapos_TRM]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_TRM]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Facturapos_Us]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_Facturapos_Cupo]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Cupo]  DEFAULT ((0)) FOR [Cupo]
GO

-- %% [markdown]
-- # [DF_Facturapos_Diasvencimiento]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Diasvencimiento]  DEFAULT ((0)) FOR [Diasvencimiento]
GO

-- %% [markdown]
-- # [DF_Facturapos_Cartera]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Cartera]  DEFAULT ((0)) FOR [Cartera]
GO

-- %% [markdown]
-- # [DF_Facturapos_Edad]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Edad]  DEFAULT ((0)) FOR [Edad]
GO

-- %% [markdown]
-- # [DF_Facturapos_Estadoter]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Estadoter]  DEFAULT ((0)) FOR [Estadoter]
GO

-- %% [markdown]
-- # [DF_Facturapos_Diferencia]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Diferencia]  DEFAULT ((0)) FOR [Diferencia]
GO

-- %% [markdown]
-- # [DF_Facturapos_Retencion]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_Facturapos_Declarado]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Declarado]  DEFAULT ((0)) FOR [Declarado]
GO

-- %% [markdown]
-- # [DF_Facturapos_Pcree]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Pcree]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_Facturapos_Retecree]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Retecree]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_Facturapos_Situacion]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Situacion]  DEFAULT (N'PENDIENTE') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Facturapos_TipoRetencion]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_TipoRetencion]  DEFAULT ((1302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_Facturapos_Matrix]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Matrix]  DEFAULT ((0)) FOR [Matrix]
GO

-- %% [markdown]
-- # [DF_Facturapos_Concepto]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Concepto]  DEFAULT ((1315)) FOR [Concepto]
GO

-- %% [markdown]
-- # [DF_Facturapos_Anticipos]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Anticipos]  DEFAULT ((0)) FOR [Anticipos]
GO

-- %% [markdown]
-- # [DF_Facturapos_PUtilidadest]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_PUtilidadest]  DEFAULT ((0)) FOR [PUtilidadest]
GO

-- %% [markdown]
-- # [DF_Facturapos_Utilidadest]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Utilidadest]  DEFAULT ((0)) FOR [Utilidadest]
GO

-- %% [markdown]
-- # [DF_Facturapos_Imprevistos]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Imprevistos]  DEFAULT ((0)) FOR [Imprevistos]
GO

-- %% [markdown]
-- # [DF_Facturapos_Pimprevistos]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Pimprevistos]  DEFAULT ((0)) FOR [Pimprevistos]
GO

-- %% [markdown]
-- # [DF_Facturapos_Admon]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Admon]  DEFAULT ((0)) FOR [Admon]
GO

-- %% [markdown]
-- # [DF_Facturapos_PAdmon]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_PAdmon]  DEFAULT ((0)) FOR [PAdmon]
GO

-- %% [markdown]
-- # [DF_Facturapos_Status]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Status]  DEFAULT (N'EN PROCESO') FOR [Status]
GO

-- %% [markdown]
-- # [DF_Facturapos_ImpReteica]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_ImpReteica]  DEFAULT ((0)) FOR [ImpReteica]
GO

-- %% [markdown]
-- # [DF_Facturapos_ImpReteiva]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_ImpReteiva]  DEFAULT ((0)) FOR [ImpReteiva]
GO

-- %% [markdown]
-- # [DF_Facturapos_CantBolsas]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_CantBolsas]  DEFAULT ((0)) FOR [CantBolsas]
GO

-- %% [markdown]
-- # [DF_Facturapos_ValBolsas]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_ValBolsas]  DEFAULT ((0)) FOR [ValBolsas]
GO

-- %% [markdown]
-- # [DF_Facturapos_StatusDian]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_StatusDian]  DEFAULT ((0)) FOR [StatusDian]
GO

-- %% [markdown]
-- # [DF_Facturapos_StatusCliente]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_StatusCliente]  DEFAULT ((0)) FOR [StatusCliente]
GO

-- %% [markdown]
-- # [DF_Facturapos_Horafin]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_Horafin]  DEFAULT (getdate()) FOR [Horafin]
GO

-- %% [markdown]
-- # [DF_Facturapos_TipoFactura]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_TipoFactura]  DEFAULT (N'01') FOR [TipoFactura]
GO

-- %% [markdown]
-- # [DF_Facturapos_TipoOperacion]

-- %%
ALTER TABLE [dbo].[Facturapos] ADD  CONSTRAINT [DF_Facturapos_TipoOperacion]  DEFAULT (N'10') FOR [TipoOperacion]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Cantidad]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Facturaposub_PIva]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Descuento]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Precio]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Subtotal]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Neto]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Precio total]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Exentos]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Exentos]  DEFAULT ((0)) FOR [Exentos]
GO

-- %% [markdown]
-- # [DF_Facturaposub_DesExentos]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_DesExentos]  DEFAULT ((0)) FOR [DesExentos]
GO

-- %% [markdown]
-- # [DF_Facturaposub_DesGravados]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_DesGravados]  DEFAULT ((0)) FOR [DesGravados]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Peso]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Facturaposub_VPropina]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_VPropina]  DEFAULT ((0)) FOR [VPropina]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Controlfinal]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Controlfinal]  DEFAULT ((0)) FOR [Controlfinal]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Rebaja]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Rebaja]  DEFAULT ((0)) FOR [Rebaja]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Costo]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Gastos]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Gastos]  DEFAULT ((0)) FOR [Gastos]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Largo]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Largo]  DEFAULT ((0)) FOR [Largo]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Ancho]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Ancho]  DEFAULT ((0)) FOR [Ancho]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Alto]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Alto]  DEFAULT ((0)) FOR [Alto]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Volumen]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Volumen]  DEFAULT ((0)) FOR [Volumen]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Pimpoconsumo]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Pimpoconsumo]  DEFAULT ((0)) FOR [Pimpoconsumo]
GO

-- %% [markdown]
-- # [DF_Facturaposub_ImpCon]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_ImpCon]  DEFAULT ((0)) FOR [ImpCon]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Dolares]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Dolares]  DEFAULT ((0)) FOR [Dolares]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Costear]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Costear]  DEFAULT ((0)) FOR [Costear]
GO

-- %% [markdown]
-- # [DF_Facturaposub_PRete]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_PRete]  DEFAULT ((0)) FOR [PRete]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Retencion]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_Facturaposub_TipoRetencion]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_TipoRetencion]  DEFAULT ((1302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Moneda]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Moneda]  DEFAULT (N'COP') FOR [Moneda]
GO

-- %% [markdown]
-- # [DF_Facturaposub_TRMS]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_TRMS]  DEFAULT ((1)) FOR [TRMS]
GO

-- %% [markdown]
-- # [DF_Facturaposub_Cree]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_Cree]  DEFAULT ((0)) FOR [Cree]
GO

-- %% [markdown]
-- # [DF_Facturaposub_PReteIcasub]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_PReteIcasub]  DEFAULT ((0)) FOR [PReteIcasub]
GO

-- %% [markdown]
-- # [DF_Facturaposub_ReteIcasub]

-- %%
ALTER TABLE [dbo].[Facturaposub] ADD  CONSTRAINT [DF_Facturaposub_ReteIcasub]  DEFAULT ((0)) FOR [ReteIcasub]
GO

-- %% [markdown]
-- # [DF_Facturasub_Cantidad]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Facturasub_PIva]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_Facturasub_Descuento]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_Facturasub_Precio]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Facturasub_Subtotal]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Facturasub_Neto]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Facturasub_Precio total]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_Facturasub_Exentos]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Exentos]  DEFAULT ((0)) FOR [Exentos]
GO

-- %% [markdown]
-- # [DF_Facturasub_DesExentos]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_DesExentos]  DEFAULT ((0)) FOR [DesExentos]
GO

-- %% [markdown]
-- # [DF_Facturasub_DesGravados]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_DesGravados]  DEFAULT ((0)) FOR [DesGravados]
GO

-- %% [markdown]
-- # [DF_Facturasub_Dolares]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Dolares]  DEFAULT ((0)) FOR [Dolares]
GO

-- %% [markdown]
-- # [DF_Facturasub_Costear]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Costear]  DEFAULT ((0)) FOR [Costear]
GO

-- %% [markdown]
-- # [DF_Facturasub_Peso]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Facturasub_Remesa]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Remesa]  DEFAULT ((0)) FOR [Remesa]
GO

-- %% [markdown]
-- # [DF_Facturasub_VPropina]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_VPropina]  DEFAULT ((0)) FOR [VPropina]
GO

-- %% [markdown]
-- # [DF_Facturasub_Controlfinal]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Controlfinal]  DEFAULT ((0)) FOR [Controlfinal]
GO

-- %% [markdown]
-- # [DF_Facturasub_Rebaja]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Rebaja]  DEFAULT ((0)) FOR [Rebaja]
GO

-- %% [markdown]
-- # [DF_Facturasub_PRete]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_PRete]  DEFAULT ((0)) FOR [PRete]
GO

-- %% [markdown]
-- # [DF_Facturasub_Retencion]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_Facturasub_Manifiesto]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Manifiesto]  DEFAULT ((0)) FOR [Manifiesto]
GO

-- %% [markdown]
-- # [DF_Facturasub_Cuota]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Cuota]  DEFAULT ((0)) FOR [Cuota]
GO

-- %% [markdown]
-- # [DF_Facturasub_Moneda]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Moneda]  DEFAULT (N'COP') FOR [Moneda]
GO

-- %% [markdown]
-- # [DF_Facturasub_TRMS]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_TRMS]  DEFAULT ((1)) FOR [TRMS]
GO

-- %% [markdown]
-- # [DF_Facturasub_Pimpoconsumo]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Pimpoconsumo]  DEFAULT ((0)) FOR [Pimpoconsumo]
GO

-- %% [markdown]
-- # [DF_Facturasub_ImpCon]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_ImpCon]  DEFAULT ((0)) FOR [ImpCon]
GO

-- %% [markdown]
-- # [DF_Facturasub_Cree]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Cree]  DEFAULT ((0)) FOR [Cree]
GO

-- %% [markdown]
-- # [DF_Facturasub_Costo]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Facturasub_PReteIcasub]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_PReteIcasub]  DEFAULT ((0)) FOR [PReteIcasub]
GO

-- %% [markdown]
-- # [DF_Facturasub_ReteIcasub]

-- %%
ALTER TABLE [dbo].[Facturasub] ADD  CONSTRAINT [DF_Facturasub_ReteIcasub]  DEFAULT ((0)) FOR [ReteIcasub]
GO

-- %% [markdown]
-- # [DF_FCesantias_Estado]

-- %%
ALTER TABLE [dbo].[FCesantias] ADD  CONSTRAINT [DF_FCesantias_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Flujo_Tipo]

-- %%
ALTER TABLE [dbo].[Flujo] ADD  CONSTRAINT [DF_Flujo_Tipo]  DEFAULT (N'INGRESOS') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_Flujo_Valor]

-- %%
ALTER TABLE [dbo].[Flujo] ADD  CONSTRAINT [DF_Flujo_Valor]  DEFAULT (0) FOR [Valor]
GO

-- %% [markdown]
-- # [DF_Flujo_Fproceso]

-- %%
ALTER TABLE [dbo].[Flujo] ADD  CONSTRAINT [DF_Flujo_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Flujo_Ejecucion]

-- %%
ALTER TABLE [dbo].[Flujo] ADD  CONSTRAINT [DF_Flujo_Ejecucion]  DEFAULT (N'NO') FOR [Ejecucion]
GO

-- %% [markdown]
-- # [DF_Flujo_Estado]

-- %%
ALTER TABLE [dbo].[Flujo] ADD  CONSTRAINT [DF_Flujo_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Formapago_Estado]

-- %%
ALTER TABLE [dbo].[Formapago] ADD  CONSTRAINT [DF_Formapago_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Fortalezas_Periodo]

-- %%
ALTER TABLE [dbo].[Fortalezas] ADD  CONSTRAINT [DF_Fortalezas_Periodo]  DEFAULT (0) FOR [Periodo]
GO

-- %% [markdown]
-- # [DF_Fortalezas_Año]

-- %%
ALTER TABLE [dbo].[Fortalezas] ADD  CONSTRAINT [DF_Fortalezas_Año]  DEFAULT (0) FOR [Año]
GO

-- %% [markdown]
-- # [DF_Gasolina_Fecha]

-- %%
ALTER TABLE [dbo].[Gasolina] ADD  CONSTRAINT [DF_Gasolina_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Gasolina_Documento]

-- %%
ALTER TABLE [dbo].[Gasolina] ADD  CONSTRAINT [DF_Gasolina_Documento]  DEFAULT (N'CG') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Gasolina_Consumo]

-- %%
ALTER TABLE [dbo].[Gasolina] ADD  CONSTRAINT [DF_Gasolina_Consumo]  DEFAULT ((0)) FOR [Consumo]
GO

-- %% [markdown]
-- # [DF_Gasolina_KmAnterior]

-- %%
ALTER TABLE [dbo].[Gasolina] ADD  CONSTRAINT [DF_Gasolina_KmAnterior]  DEFAULT ((0)) FOR [KmAnterior]
GO

-- %% [markdown]
-- # [DF_Gasolina_KmNuevo]

-- %%
ALTER TABLE [dbo].[Gasolina] ADD  CONSTRAINT [DF_Gasolina_KmNuevo]  DEFAULT ((0)) FOR [KmNuevo]
GO

-- %% [markdown]
-- # [DF_Gasolina_GalonesConsumo]

-- %%
ALTER TABLE [dbo].[Gasolina] ADD  CONSTRAINT [DF_Gasolina_GalonesConsumo]  DEFAULT ((0)) FOR [GalonesConsumo]
GO

-- %% [markdown]
-- # [DF_Gasolina_VlrGalon]

-- %%
ALTER TABLE [dbo].[Gasolina] ADD  CONSTRAINT [DF_Gasolina_VlrGalon]  DEFAULT ((0)) FOR [VlrGalon]
GO

-- %% [markdown]
-- # [DF_Gasolina_Total]

-- %%
ALTER TABLE [dbo].[Gasolina] ADD  CONSTRAINT [DF_Gasolina_Total]  DEFAULT ((0)) FOR [Total]
GO

-- %% [markdown]
-- # [DF_Gasolina_Estado]

-- %%
ALTER TABLE [dbo].[Gasolina] ADD  CONSTRAINT [DF_Gasolina_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Grupo_Estado]

-- %%
ALTER TABLE [dbo].[Grupo] ADD  CONSTRAINT [DF_Grupo_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Gruposub_Estado]

-- %%
ALTER TABLE [dbo].[Gruposub] ADD  CONSTRAINT [DF_Gruposub_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Guia_Fecha]

-- %%
ALTER TABLE [dbo].[Guia] ADD  CONSTRAINT [DF_Guia_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Guia_Estado]

-- %%
ALTER TABLE [dbo].[Guia] ADD  CONSTRAINT [DF_Guia_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Guia_Documento]

-- %%
ALTER TABLE [dbo].[Guia] ADD  CONSTRAINT [DF_Guia_Documento]  DEFAULT (N'GA') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Guia_Tipo]

-- %%
ALTER TABLE [dbo].[Guia] ADD  CONSTRAINT [DF_Guia_Tipo]  DEFAULT (N'AEREA') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_Guiasub_Bultos]

-- %%
ALTER TABLE [dbo].[Guiasub] ADD  CONSTRAINT [DF_Guiasub_Bultos]  DEFAULT ((0)) FOR [Bultos]
GO

-- %% [markdown]
-- # [DF_Guiasub_Pbruto]

-- %%
ALTER TABLE [dbo].[Guiasub] ADD  CONSTRAINT [DF_Guiasub_Pbruto]  DEFAULT ((0)) FOR [Pbruto]
GO

-- %% [markdown]
-- # [DF_Guiasub_Pesocobrar]

-- %%
ALTER TABLE [dbo].[Guiasub] ADD  CONSTRAINT [DF_Guiasub_Pesocobrar]  DEFAULT ((0)) FOR [Pesocobrar]
GO

-- %% [markdown]
-- # [DF_Guiasub_Tarifa]

-- %%
ALTER TABLE [dbo].[Guiasub] ADD  CONSTRAINT [DF_Guiasub_Tarifa]  DEFAULT ((0)) FOR [Tarifa]
GO

-- %% [markdown]
-- # [DF_Guiasub_Neto]

-- %%
ALTER TABLE [dbo].[Guiasub] ADD  CONSTRAINT [DF_Guiasub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Guiasub_Impuestos]

-- %%
ALTER TABLE [dbo].[Guiasub] ADD  CONSTRAINT [DF_Guiasub_Impuestos]  DEFAULT ((0)) FOR [Impuestos]
GO

-- %% [markdown]
-- # [DF_Guiasub_Total]

-- %%
ALTER TABLE [dbo].[Guiasub] ADD  CONSTRAINT [DF_Guiasub_Total]  DEFAULT ((0)) FOR [Total]
GO

-- %% [markdown]
-- # [DF_Histoambito_Estado]

-- %%
ALTER TABLE [dbo].[Histoambito] ADD  CONSTRAINT [DF_Histoambito_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_HistoClinica_Fecha]

-- %%
ALTER TABLE [dbo].[HistoClinica] ADD  CONSTRAINT [DF_HistoClinica_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_HistoClinica_Estado]

-- %%
ALTER TABLE [dbo].[HistoClinica] ADD  CONSTRAINT [DF_HistoClinica_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_HistoClinica_Documento]

-- %%
ALTER TABLE [dbo].[HistoClinica] ADD  CONSTRAINT [DF_HistoClinica_Documento]  DEFAULT (N'HC') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_HistoClinica_Edad]

-- %%
ALTER TABLE [dbo].[HistoClinica] ADD  CONSTRAINT [DF_HistoClinica_Edad]  DEFAULT ((0)) FOR [Edad]
GO

-- %% [markdown]
-- # [DF_HistoClinicasub_valorProce]

-- %%
ALTER TABLE [dbo].[HistoClinicasub] ADD  CONSTRAINT [DF_HistoClinicasub_valorProce]  DEFAULT ((0)) FOR [valorProce]
GO

-- %% [markdown]
-- # [DF_HistoClinicasub_Estadosub]

-- %%
ALTER TABLE [dbo].[HistoClinicasub] ADD  CONSTRAINT [DF_HistoClinicasub_Estadosub]  DEFAULT ((0)) FOR [Estadosub]
GO

-- %% [markdown]
-- # [DF_HistoClinicasub_Cantidad]

-- %%
ALTER TABLE [dbo].[HistoClinicasub] ADD  CONSTRAINT [DF_HistoClinicasub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_HistoClinicasub_Precio]

-- %%
ALTER TABLE [dbo].[HistoClinicasub] ADD  CONSTRAINT [DF_HistoClinicasub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Histofinalidad_Estado]

-- %%
ALTER TABLE [dbo].[Histofinalidad] ADD  CONSTRAINT [DF_Histofinalidad_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Histoprocedimiento_Estado]

-- %%
ALTER TABLE [dbo].[Histoprocedimiento] ADD  CONSTRAINT [DF_Histoprocedimiento_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_HistoTipouser_Estado]

-- %%
ALTER TABLE [dbo].[HistoTipouser] ADD  CONSTRAINT [DF_HistoTipouser_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Iniciales_Neto]

-- %%
ALTER TABLE [dbo].[Iniciales] ADD  CONSTRAINT [DF_Iniciales_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Iniciales_IdControl]

-- %%
ALTER TABLE [dbo].[Iniciales] ADD  CONSTRAINT [DF_Iniciales_IdControl]  DEFAULT ((1)) FOR [IdControl]
GO

-- %% [markdown]
-- # [DF_Iniciales_Documento]

-- %%
ALTER TABLE [dbo].[Iniciales] ADD  CONSTRAINT [DF_Iniciales_Documento]  DEFAULT (N'SICC') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Iniciales_Dias]

-- %%
ALTER TABLE [dbo].[Iniciales] ADD  CONSTRAINT [DF_Iniciales_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Iniciales_Us]

-- %%
ALTER TABLE [dbo].[Iniciales] ADD  CONSTRAINT [DF_Iniciales_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_Iniciales_Iva]

-- %%
ALTER TABLE [dbo].[Iniciales] ADD  CONSTRAINT [DF_Iniciales_Iva]  DEFAULT ((0)) FOR [Iva]
GO

-- %% [markdown]
-- # [DF_Iniciales_Anteiva]

-- %%
ALTER TABLE [dbo].[Iniciales] ADD  CONSTRAINT [DF_Iniciales_Anteiva]  DEFAULT ((0)) FOR [Anteiva]
GO

-- %% [markdown]
-- # [DF_Iniciales28_IdControl]

-- %%
ALTER TABLE [dbo].[Iniciales28] ADD  CONSTRAINT [DF_Iniciales28_IdControl]  DEFAULT ((1)) FOR [IdControl]
GO

-- %% [markdown]
-- # [DF_Iniciales28_Neto]

-- %%
ALTER TABLE [dbo].[Iniciales28] ADD  CONSTRAINT [DF_Iniciales28_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Iniciales28_Documento]

-- %%
ALTER TABLE [dbo].[Iniciales28] ADD  CONSTRAINT [DF_Iniciales28_Documento]  DEFAULT (N'SI28') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Iniciales28_US]

-- %%
ALTER TABLE [dbo].[Iniciales28] ADD  CONSTRAINT [DF_Iniciales28_US]  DEFAULT ((0)) FOR [US]
GO

-- %% [markdown]
-- # [DF_InicialescEnc_Estado]

-- %%
ALTER TABLE [dbo].[InicialescEnc] ADD  CONSTRAINT [DF_InicialescEnc_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Inicialescontenedores_Fecha]

-- %%
ALTER TABLE [dbo].[Inicialescontenedores] ADD  CONSTRAINT [DF_Inicialescontenedores_Fecha]  DEFAULT (getdate()) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Inicialescontenedores_Estado]

-- %%
ALTER TABLE [dbo].[Inicialescontenedores] ADD  CONSTRAINT [DF_Inicialescontenedores_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Inicialescontenedores_Documento]

-- %%
ALTER TABLE [dbo].[Inicialescontenedores] ADD  CONSTRAINT [DF_Inicialescontenedores_Documento]  DEFAULT (N'PC') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Inicialescontenedoresub_Cantidad]

-- %%
ALTER TABLE [dbo].[Inicialescontenedoresub] ADD  CONSTRAINT [DF_Inicialescontenedoresub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_InicialesCXP_Neto]

-- %%
ALTER TABLE [dbo].[InicialesCXP] ADD  CONSTRAINT [DF_InicialesCXP_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_InicialesCXP_IdControl]

-- %%
ALTER TABLE [dbo].[InicialesCXP] ADD  CONSTRAINT [DF_InicialesCXP_IdControl]  DEFAULT ((1)) FOR [IdControl]
GO

-- %% [markdown]
-- # [DF_InicialesCXP_Documento]

-- %%
ALTER TABLE [dbo].[InicialesCXP] ADD  CONSTRAINT [DF_InicialesCXP_Documento]  DEFAULT (N'SICP') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_InicialesCXP_Dias]

-- %%
ALTER TABLE [dbo].[InicialesCXP] ADD  CONSTRAINT [DF_InicialesCXP_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_InicialesCXP_Us]

-- %%
ALTER TABLE [dbo].[InicialesCXP] ADD  CONSTRAINT [DF_InicialesCXP_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_InicialesEncCXP_Estado]

-- %%
ALTER TABLE [dbo].[InicialesEncCXP] ADD  CONSTRAINT [DF_InicialesEncCXP_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_InicialesInventario_Fecha]

-- %%
ALTER TABLE [dbo].[InicialesInventario] ADD  CONSTRAINT [DF_InicialesInventario_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_InicialesInventario_Estado]

-- %%
ALTER TABLE [dbo].[InicialesInventario] ADD  CONSTRAINT [DF_InicialesInventario_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_InicialesInventario_Situacion]

-- %%
ALTER TABLE [dbo].[InicialesInventario] ADD  CONSTRAINT [DF_InicialesInventario_Situacion]  DEFAULT (N'NO CAUSAR COSTOS') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_InicialesInventario_Marca]

-- %%
ALTER TABLE [dbo].[InicialesInventario] ADD  CONSTRAINT [DF_InicialesInventario_Marca]  DEFAULT (N'Iniciales') FOR [Marca]
GO

-- %% [markdown]
-- # [DF_InicialesInventario_Documento]

-- %%
ALTER TABLE [dbo].[InicialesInventario] ADD  CONSTRAINT [DF_InicialesInventario_Documento]  DEFAULT (N'PI') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_InicialesInventariosub_Cantidad]

-- %%
ALTER TABLE [dbo].[InicialesInventariosub] ADD  CONSTRAINT [DF_InicialesInventariosub_Cantidad]  DEFAULT (0) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_InicialesInventariosub_Costo]

-- %%
ALTER TABLE [dbo].[InicialesInventariosub] ADD  CONSTRAINT [DF_InicialesInventariosub_Costo]  DEFAULT (0) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_InicialesInventariosub_CostoTotal]

-- %%
ALTER TABLE [dbo].[InicialesInventariosub] ADD  CONSTRAINT [DF_InicialesInventariosub_CostoTotal]  DEFAULT (0) FOR [CostoTotal]
GO

-- %% [markdown]
-- # [DF_InicialesInventariosub_Peso]

-- %%
ALTER TABLE [dbo].[InicialesInventariosub] ADD  CONSTRAINT [DF_InicialesInventariosub_Peso]  DEFAULT (0) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_InicialesInventariosub_Costo1]

-- %%
ALTER TABLE [dbo].[InicialesInventariosub] ADD  CONSTRAINT [DF_InicialesInventariosub_Costo1]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_InicialesInventariosub_CostoTotal1]

-- %%
ALTER TABLE [dbo].[InicialesInventariosub] ADD  CONSTRAINT [DF_InicialesInventariosub_CostoTotal1]  DEFAULT ((0)) FOR [PrecioTotal]
GO

-- %% [markdown]
-- # [DF_InicialesInventariosub_Controlfinal]

-- %%
ALTER TABLE [dbo].[InicialesInventariosub] ADD  CONSTRAINT [DF_InicialesInventariosub_Controlfinal]  DEFAULT ((0)) FOR [Controlfinal]
GO

-- %% [markdown]
-- # [DF_InicialesMPrima_Fecha]

-- %%
ALTER TABLE [dbo].[InicialesMPrima] ADD  CONSTRAINT [DF_InicialesMPrima_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_InicialesMPrima_Estado]

-- %%
ALTER TABLE [dbo].[InicialesMPrima] ADD  CONSTRAINT [DF_InicialesMPrima_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_InicialesMPrima_Situacion]

-- %%
ALTER TABLE [dbo].[InicialesMPrima] ADD  CONSTRAINT [DF_InicialesMPrima_Situacion]  DEFAULT (N'NO CAUSAR COSTOS') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_InicialesMPrima_Documento]

-- %%
ALTER TABLE [dbo].[InicialesMPrima] ADD  CONSTRAINT [DF_InicialesMPrima_Documento]  DEFAULT (N'PMP') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_InicialesMPrimasub_Cantidad]

-- %%
ALTER TABLE [dbo].[InicialesMPrimasub] ADD  CONSTRAINT [DF_InicialesMPrimasub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_InicialesMPrimasub_Costo]

-- %%
ALTER TABLE [dbo].[InicialesMPrimasub] ADD  CONSTRAINT [DF_InicialesMPrimasub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_InicialesMPrimasub_CostoTotal]

-- %%
ALTER TABLE [dbo].[InicialesMPrimasub] ADD  CONSTRAINT [DF_InicialesMPrimasub_CostoTotal]  DEFAULT ((0)) FOR [CostoTotal]
GO

-- %% [markdown]
-- # [DF_InicialesMPrimasub_Peso]

-- %%
ALTER TABLE [dbo].[InicialesMPrimasub] ADD  CONSTRAINT [DF_InicialesMPrimasub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_InicialesMPrimasub_Controlfinal]

-- %%
ALTER TABLE [dbo].[InicialesMPrimasub] ADD  CONSTRAINT [DF_InicialesMPrimasub_Controlfinal]  DEFAULT ((0)) FOR [Controlfinal]
GO

-- %% [markdown]
-- # [DF_InicialesMPrimasub_Viable]

-- %%
ALTER TABLE [dbo].[InicialesMPrimasub] ADD  CONSTRAINT [DF_InicialesMPrimasub_Viable]  DEFAULT ((0)) FOR [Viable]
GO

-- %% [markdown]
-- # [DF_InicialesMPrimaterminado_Cantidad]

-- %%
ALTER TABLE [dbo].[InicialesMPrimaterminado] ADD  CONSTRAINT [DF_InicialesMPrimaterminado_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_InicialesMPrimaterminado_Costo]

-- %%
ALTER TABLE [dbo].[InicialesMPrimaterminado] ADD  CONSTRAINT [DF_InicialesMPrimaterminado_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_InicialesMPrimaterminado_CostoTotal]

-- %%
ALTER TABLE [dbo].[InicialesMPrimaterminado] ADD  CONSTRAINT [DF_InicialesMPrimaterminado_CostoTotal]  DEFAULT ((0)) FOR [CostoTotal]
GO

-- %% [markdown]
-- # [DF_InicialesMPrimaterminado_Peso]

-- %%
ALTER TABLE [dbo].[InicialesMPrimaterminado] ADD  CONSTRAINT [DF_InicialesMPrimaterminado_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_InicialesMPrimaterminado_PesoSIN]

-- %%
ALTER TABLE [dbo].[InicialesMPrimaterminado] ADD  CONSTRAINT [DF_InicialesMPrimaterminado_PesoSIN]  DEFAULT ((0)) FOR [PesoSIN]
GO

-- %% [markdown]
-- # [DF_InicialesTesoreria_Fecha]

-- %%
ALTER TABLE [dbo].[InicialesTesoreria] ADD  CONSTRAINT [DF_InicialesTesoreria_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_InicialesTesoreria_Estado]

-- %%
ALTER TABLE [dbo].[InicialesTesoreria] ADD  CONSTRAINT [DF_InicialesTesoreria_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_InicialesTesoreria_Documento]

-- %%
ALTER TABLE [dbo].[InicialesTesoreria] ADD  CONSTRAINT [DF_InicialesTesoreria_Documento]  DEFAULT (N'IT') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_InicialesTesoreriasub_NCheque]

-- %%
ALTER TABLE [dbo].[InicialesTesoreriasub] ADD  CONSTRAINT [DF_InicialesTesoreriasub_NCheque]  DEFAULT (0) FOR [NCheque]
GO

-- %% [markdown]
-- # [DF_InicialesTesoreriasub_Girado]

-- %%
ALTER TABLE [dbo].[InicialesTesoreriasub] ADD  CONSTRAINT [DF_InicialesTesoreriasub_Girado]  DEFAULT (0) FOR [Girado]
GO

-- %% [markdown]
-- # [DF_Inversion_ValorO_1]

-- %%
ALTER TABLE [dbo].[Inversion] ADD  CONSTRAINT [DF_Inversion_ValorO_1]  DEFAULT ((0)) FOR [ValorO]
GO

-- %% [markdown]
-- # [DF_Know1_Fecha]

-- %%
ALTER TABLE [dbo].[Know1] ADD  CONSTRAINT [DF_Know1_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Know1_Estado]

-- %%
ALTER TABLE [dbo].[Know1] ADD  CONSTRAINT [DF_Know1_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_KnowAudita_Fecha]

-- %%
ALTER TABLE [dbo].[KnowAudita] ADD  CONSTRAINT [DF_KnowAudita_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_KnowAudita_Hora]

-- %%
ALTER TABLE [dbo].[KnowAudita] ADD  CONSTRAINT [DF_KnowAudita_Hora]  DEFAULT (getdate()) FOR [Hora]
GO

-- %% [markdown]
-- # [DF_KnowAudita_Cantidad]

-- %%
ALTER TABLE [dbo].[KnowAudita] ADD  CONSTRAINT [DF_KnowAudita_Cantidad]  DEFAULT ((1)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_KnowIdeas_Fecha]

-- %%
ALTER TABLE [dbo].[KnowIdeas] ADD  CONSTRAINT [DF_KnowIdeas_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_KnowIdeas_Estado]

-- %%
ALTER TABLE [dbo].[KnowIdeas] ADD  CONSTRAINT [DF_KnowIdeas_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_KnowStatus_Estado]

-- %%
ALTER TABLE [dbo].[KnowStatus] ADD  CONSTRAINT [DF_KnowStatus_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_KnowTipo_Estado]

-- %%
ALTER TABLE [dbo].[KnowTipo] ADD  CONSTRAINT [DF_KnowTipo_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Legalizaciones_Fecha]

-- %%
ALTER TABLE [dbo].[Legalizaciones] ADD  CONSTRAINT [DF_Legalizaciones_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Legalizaciones_Documento]

-- %%
ALTER TABLE [dbo].[Legalizaciones] ADD  CONSTRAINT [DF_Legalizaciones_Documento]  DEFAULT (N'LG') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Legalizaciones_Anticipo]

-- %%
ALTER TABLE [dbo].[Legalizaciones] ADD  CONSTRAINT [DF_Legalizaciones_Anticipo]  DEFAULT ((0)) FOR [Anticipo]
GO

-- %% [markdown]
-- # [DF_Legalizaciones_Estado]

-- %%
ALTER TABLE [dbo].[Legalizaciones] ADD  CONSTRAINT [DF_Legalizaciones_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Legalizacionesub_Neto]

-- %%
ALTER TABLE [dbo].[Legalizacionesub] ADD  CONSTRAINT [DF_Legalizacionesub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_Idparnomina]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_Idparnomina]  DEFAULT ((1)) FOR [Idparnomina]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_Fecha]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_Finalizacion]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_Finalizacion]  DEFAULT (getdate()) FOR [Finalizacion]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_Salario básico]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_Salario básico]  DEFAULT ((0)) FOR [Salario básico]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_Auxilio transporte]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_Auxilio transporte]  DEFAULT ((0)) FOR [Auxilio transporte]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_Dias trabajados]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_Dias trabajados]  DEFAULT ((0)) FOR [Dias trabajados]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_Prima]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_Prima]  DEFAULT ((0)) FOR [Prima]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_Vacaciones]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_Vacaciones]  DEFAULT ((0)) FOR [Vacaciones]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_Indemnizacion]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_Indemnizacion]  DEFAULT ((0)) FOR [Indemnizacion]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_Cesantia]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_Cesantia]  DEFAULT ((0)) FOR [Cesantia]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_ICesantia]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_ICesantia]  DEFAULT ((0)) FOR [ICesantia]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_TPrima]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_TPrima]  DEFAULT ((0)) FOR [TPrima]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_TVacaciones]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_TVacaciones]  DEFAULT ((0)) FOR [TVacaciones]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_TCesantia]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_TCesantia]  DEFAULT ((0)) FOR [TCesantia]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_TICesantia]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_TICesantia]  DEFAULT ((0)) FOR [TICesantia]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_TIndemnizacion]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_TIndemnizacion]  DEFAULT ((0)) FOR [TIndemnizacion]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_TPagar]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_TPagar]  DEFAULT ((0)) FOR [TPagar]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_Documento]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_Documento]  DEFAULT (N'LP') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_Diasvaca]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_Diasvaca]  DEFAULT ((0)) FOR [Diasvaca]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_Descuentos]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_Descuentos]  DEFAULT ((0)) FOR [Descuentos]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_Neto]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_ProCesantia]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_ProCesantia]  DEFAULT ((0)) FOR [ProCesantia]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_ProInteres]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_ProInteres]  DEFAULT ((0)) FOR [ProInteres]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_ProPrima]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_ProPrima]  DEFAULT ((0)) FOR [ProPrima]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_ProVacaciones]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_ProVacaciones]  DEFAULT ((0)) FOR [ProVacaciones]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_ProSalud]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_ProSalud]  DEFAULT ((0)) FOR [ProSalud]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_ProPension]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_ProPension]  DEFAULT ((0)) FOR [ProPension]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_ProCaja]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_ProCaja]  DEFAULT ((0)) FOR [ProCaja]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_ProFamiliar]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_ProFamiliar]  DEFAULT ((0)) FOR [ProFamiliar]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_ProSena]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_ProSena]  DEFAULT ((0)) FOR [ProSena]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_Estado]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Liquidacion final_DTotal]

-- %%
ALTER TABLE [dbo].[Liquidacion final] ADD  CONSTRAINT [DF_Liquidacion final_DTotal]  DEFAULT ((0)) FOR [DTotal]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Fecha]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Por1]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Por1]  DEFAULT (0) FOR [Por1]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Desc1]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Desc1]  DEFAULT (0) FOR [Desc1]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Por2]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Por2]  DEFAULT (0) FOR [Por2]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Desc2]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Desc2]  DEFAULT (0) FOR [Desc2]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Por3]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Por3]  DEFAULT (0) FOR [Por3]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Desc3]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Desc3]  DEFAULT (0) FOR [Desc3]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Por4]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Por4]  DEFAULT (0) FOR [Por4]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Desc4]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Desc4]  DEFAULT (0) FOR [Desc4]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Total]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Total]  DEFAULT (0) FOR [Total]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Estado]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Documento]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Documento]  DEFAULT (N'LF') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Situacion]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Situacion]  DEFAULT (N'CAUSAR CXP') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Dias]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Dias]  DEFAULT (0) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Us]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Gtotal]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Gtotal]  DEFAULT ((0)) FOR [Gtotal]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Anticipo]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Anticipo]  DEFAULT ((0)) FOR [Anticipo]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Pcree]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Pcree]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_LiquidaFletes_Retecree]

-- %%
ALTER TABLE [dbo].[LiquidaFletes] ADD  CONSTRAINT [DF_LiquidaFletes_Retecree]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_Liquidafletessub_Flete]

-- %%
ALTER TABLE [dbo].[Liquidafletessub] ADD  CONSTRAINT [DF_Liquidafletessub_Flete]  DEFAULT ((0)) FOR [Flete]
GO

-- %% [markdown]
-- # [DF_Liquidafletessub_Retencion]

-- %%
ALTER TABLE [dbo].[Liquidafletessub] ADD  CONSTRAINT [DF_Liquidafletessub_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_Liquidafletessub_ReteIca]

-- %%
ALTER TABLE [dbo].[Liquidafletessub] ADD  CONSTRAINT [DF_Liquidafletessub_ReteIca]  DEFAULT ((0)) FOR [ReteIca]
GO

-- %% [markdown]
-- # [DF_Liquidafletessub_Anticipo]

-- %%
ALTER TABLE [dbo].[Liquidafletessub] ADD  CONSTRAINT [DF_Liquidafletessub_Anticipo]  DEFAULT ((0)) FOR [Anticipo]
GO

-- %% [markdown]
-- # [DF_Liquidafletessub_Neto]

-- %%
ALTER TABLE [dbo].[Liquidafletessub] ADD  CONSTRAINT [DF_Liquidafletessub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Liquidafletessub_Despactados]

-- %%
ALTER TABLE [dbo].[Liquidafletessub] ADD  CONSTRAINT [DF_Liquidafletessub_Despactados]  DEFAULT ((0)) FOR [Despactados]
GO

-- %% [markdown]
-- # [DF_Liquidafletessub_PRetefuente]

-- %%
ALTER TABLE [dbo].[Liquidafletessub] ADD  CONSTRAINT [DF_Liquidafletessub_PRetefuente]  DEFAULT ((0)) FOR [PRetefuente]
GO

-- %% [markdown]
-- # [DF_Liquidafletessub_PReteica]

-- %%
ALTER TABLE [dbo].[Liquidafletessub] ADD  CONSTRAINT [DF_Liquidafletessub_PReteica]  DEFAULT ((0)) FOR [PReteica]
GO

-- %% [markdown]
-- # [DF_Llamadas_Estado]

-- %%
ALTER TABLE [dbo].[Llamadas] ADD  CONSTRAINT [DF_Llamadas_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Llamadas_Fecha]

-- %%
ALTER TABLE [dbo].[Llamadas] ADD  CONSTRAINT [DF_Llamadas_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Llamadaster_Situacion]

-- %%
ALTER TABLE [dbo].[Llamadaster] ADD  CONSTRAINT [DF_Llamadaster_Situacion]  DEFAULT (N'ACTIVADO') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Llamadaster_Estado]

-- %%
ALTER TABLE [dbo].[Llamadaster] ADD  CONSTRAINT [DF_Llamadaster_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Magneticos_BasePago]

-- %%
ALTER TABLE [dbo].[Magneticos] ADD  CONSTRAINT [DF_Magneticos_BasePago]  DEFAULT ((0)) FOR [BasePago]
GO

-- %% [markdown]
-- # [DF_Magneticos_LimiteIng]

-- %%
ALTER TABLE [dbo].[Magneticos] ADD  CONSTRAINT [DF_Magneticos_LimiteIng]  DEFAULT ((0)) FOR [LimiteIng]
GO

-- %% [markdown]
-- # [DF_Magneticos_LimiteIng1]

-- %%
ALTER TABLE [dbo].[Magneticos] ADD  CONSTRAINT [DF_Magneticos_LimiteIng1]  DEFAULT ((0)) FOR [LimiteIng2]
GO

-- %% [markdown]
-- # [DF_Manifiesto_Ciudad]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_Ciudad]  DEFAULT ((11001)) FOR [Ciudad]
GO

-- %% [markdown]
-- # [DF_Manifiesto_Fecha]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Manifiesto_Estado]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_Estado]  DEFAULT (N'C') FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Manifiesto_Flete]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_Flete]  DEFAULT ((0)) FOR [Flete]
GO

-- %% [markdown]
-- # [DF_Manifiesto_PRetefuente]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_PRetefuente]  DEFAULT ((1)) FOR [PRetefuente]
GO

-- %% [markdown]
-- # [DF_Manifiesto_Retefuente]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_Retefuente]  DEFAULT ((0)) FOR [Retefuente]
GO

-- %% [markdown]
-- # [DF_Manifiesto_Descuentos]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_Descuentos]  DEFAULT ((0)) FOR [Descuentos]
GO

-- %% [markdown]
-- # [DF_Manifiesto_FleteNuevo]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_FleteNuevo]  DEFAULT ((0)) FOR [FleteNuevo]
GO

-- %% [markdown]
-- # [DF_Manifiesto_Anticipo]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_Anticipo]  DEFAULT ((0)) FOR [Anticipo]
GO

-- %% [markdown]
-- # [DF_Manifiesto_Neto]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Manifiesto_Egreso]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_Egreso]  DEFAULT ((0)) FOR [Egreso]
GO

-- %% [markdown]
-- # [DF_Manifiesto_Documento]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_Documento]  DEFAULT (N'MC') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Manifiesto_TipoRetencion]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_TipoRetencion]  DEFAULT ((2305)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_Manifiesto_PReteIca]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_Manifiesto_Dias]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Manifiesto_Situacion]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_Situacion]  DEFAULT (N'NO CAUSAR CXP') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Manifiesto_Terminal]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_Manifiesto_Despactados]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_Despactados]  DEFAULT ((0)) FOR [Despactados]
GO

-- %% [markdown]
-- # [DF_Manifiesto_PDesc]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_PDesc]  DEFAULT ((0)) FOR [PDesc]
GO

-- %% [markdown]
-- # [DF_Manifiesto_FProceso]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_FProceso]  DEFAULT (getdate()) FOR [FProceso]
GO

-- %% [markdown]
-- # [DF_Manifiesto_Us]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_Manifiesto_EstSigueme]

-- %%
ALTER TABLE [dbo].[Manifiesto] ADD  CONSTRAINT [DF_Manifiesto_EstSigueme]  DEFAULT ((0)) FOR [EstSigueme]
GO

-- %% [markdown]
-- # [DF_Manifiestosub_Cantidad]

-- %%
ALTER TABLE [dbo].[Manifiestosub] ADD  CONSTRAINT [DF_Manifiestosub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Manifiestosub_Peso]

-- %%
ALTER TABLE [dbo].[Manifiestosub] ADD  CONSTRAINT [DF_Manifiestosub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Manifiestosub_cod_naturaleza]

-- %%
ALTER TABLE [dbo].[Manifiestosub] ADD  CONSTRAINT [DF_Manifiestosub_cod_naturaleza]  DEFAULT ((0)) FOR [cod_naturaleza]
GO

-- %% [markdown]
-- # [DF_Manifiestosub_cod_empaque]

-- %%
ALTER TABLE [dbo].[Manifiestosub] ADD  CONSTRAINT [DF_Manifiestosub_cod_empaque]  DEFAULT ((0)) FOR [cod_empaque]
GO

-- %% [markdown]
-- # [DF_Manifiestosub_cod_producto]

-- %%
ALTER TABLE [dbo].[Manifiestosub] ADD  CONSTRAINT [DF_Manifiestosub_cod_producto]  DEFAULT ((0)) FOR [cod_producto]
GO

-- %% [markdown]
-- # [DF_Manifiestosub_Anticipo]

-- %%
ALTER TABLE [dbo].[Manifiestosub] ADD  CONSTRAINT [DF_Manifiestosub_Anticipo]  DEFAULT ((0)) FOR [Anticipo]
GO

-- %% [markdown]
-- # [DF_Manifiestosub_Costo]

-- %%
ALTER TABLE [dbo].[Manifiestosub] ADD  CONSTRAINT [DF_Manifiestosub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Mantenimiento_Fecha]

-- %%
ALTER TABLE [dbo].[Mantenimiento] ADD  CONSTRAINT [DF_Mantenimiento_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Mantenimiento_HorometroEnc]

-- %%
ALTER TABLE [dbo].[Mantenimiento] ADD  CONSTRAINT [DF_Mantenimiento_HorometroEnc]  DEFAULT (0) FOR [HorometroEnc]
GO

-- %% [markdown]
-- # [DF_Mantenimiento_Estado]

-- %%
ALTER TABLE [dbo].[Mantenimiento] ADD  CONSTRAINT [DF_Mantenimiento_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Mantenimientosub_Cantidad]

-- %%
ALTER TABLE [dbo].[Mantenimientosub] ADD  CONSTRAINT [DF_Mantenimientosub_Cantidad]  DEFAULT (0) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Mantenimientosub_Neto]

-- %%
ALTER TABLE [dbo].[Mantenimientosub] ADD  CONSTRAINT [DF_Mantenimientosub_Neto]  DEFAULT (0) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Matrix_Estado]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Matrix_Valortransporte]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Valortransporte]  DEFAULT (0) FOR [Valortransporte]
GO

-- %% [markdown]
-- # [DF_Matrix_Dias]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Dias]  DEFAULT (0) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Matrix_Documento]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Documento]  DEFAULT (N'FV') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Matrix_Saldo]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Saldo]  DEFAULT (0) FOR [Saldo]
GO

-- %% [markdown]
-- # [DF_Matrix_Bloque]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Bloque]  DEFAULT (0) FOR [Bloque]
GO

-- %% [markdown]
-- # [DF_Matrix_PReteIca]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_PReteIca]  DEFAULT (0) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_Matrix_Reteica]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Reteica]  DEFAULT (0) FOR [Reteica]
GO

-- %% [markdown]
-- # [DF_Matrix_PReteIva]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_PReteIva]  DEFAULT (0) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_Matrix_ReteIva]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_ReteIva]  DEFAULT (0) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_Matrix_Fproceso]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Matrix_Situacion]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Situacion]  DEFAULT (N'PENDIENTE') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Matrix_PDescuento]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_PDescuento]  DEFAULT (0) FOR [PDescuento]
GO

-- %% [markdown]
-- # [DF_Matrix_TRM]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_TRM]  DEFAULT (0) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Matrix_Cupo]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Cupo]  DEFAULT (0) FOR [Cupo]
GO

-- %% [markdown]
-- # [DF_Matrix_Diasvencimiento]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Diasvencimiento]  DEFAULT (0) FOR [Diasvencimiento]
GO

-- %% [markdown]
-- # [DF_Matrix_Cartera]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Cartera]  DEFAULT (0) FOR [Cartera]
GO

-- %% [markdown]
-- # [DF_Matrix_Edad]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Edad]  DEFAULT (0) FOR [Edad]
GO

-- %% [markdown]
-- # [DF_Matrix_Estadoter]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Estadoter]  DEFAULT (0) FOR [Estadoter]
GO

-- %% [markdown]
-- # [DF_Matrix_PFlete]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_PFlete]  DEFAULT (0) FOR [PFlete]
GO

-- %% [markdown]
-- # [DF_Matrix_Terminal]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Terminal]  DEFAULT (1) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_Matrix_Diferencia]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Diferencia]  DEFAULT (0) FOR [Diferencia]
GO

-- %% [markdown]
-- # [DF_Matrix_PRetencion]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_PRetencion]  DEFAULT (0) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_Matrix_Anticipos]

-- %%
ALTER TABLE [dbo].[Matrix] ADD  CONSTRAINT [DF_Matrix_Anticipos]  DEFAULT (0) FOR [Anticipos]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Idparnomina]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Idparnomina]  DEFAULT ((1)) FOR [Idparnomina]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Documento]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Documento]  DEFAULT (N'NM') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Periodo]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Periodo]  DEFAULT ((0)) FOR [Periodo]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Fecha]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Días trabajados]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Días trabajados]  DEFAULT ((0)) FOR [Días trabajados]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_HEDO]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_HEDO]  DEFAULT ((0)) FOR [HEDO]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_HENO]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_HENO]  DEFAULT ((0)) FOR [HENO]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_HEDF]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_HEDF]  DEFAULT ((0)) FOR [HEDF]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_HENF]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_HENF]  DEFAULT ((0)) FOR [HENF]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_RN]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_RN]  DEFAULT ((0)) FOR [RN]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Otrosdevengados]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Otrosdevengados]  DEFAULT ((0)) FOR [Otrosdevengados]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Otrasdeducciones]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Otrasdeducciones]  DEFAULT ((0)) FOR [Otrasdeducciones]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Basico]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Basico]  DEFAULT ((0)) FOR [Basico]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_TDO]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_TDO]  DEFAULT ((0)) FOR [TDO]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_TNO]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_TNO]  DEFAULT ((0)) FOR [TNO]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_TDF]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_TDF]  DEFAULT ((0)) FOR [TDF]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_TNF]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_TNF]  DEFAULT ((0)) FOR [TNF]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_TRN]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_TRN]  DEFAULT ((0)) FOR [TRN]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Auxilio]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Auxilio]  DEFAULT ((0)) FOR [Auxilio]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_TDevengado]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_TDevengado]  DEFAULT ((0)) FOR [TDevengado]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Aportesalud]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Aportesalud]  DEFAULT ((0)) FOR [Aportesalud]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Aportepension]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Aportepension]  DEFAULT ((0)) FOR [Aportepension]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_FondoSP]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_FondoSP]  DEFAULT ((0)) FOR [FondoSP]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Retefuente]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Retefuente]  DEFAULT ((0)) FOR [Retefuente]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_TDeducido]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_TDeducido]  DEFAULT ((0)) FOR [TDeducido]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Netopagado]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Netopagado]  DEFAULT ((0)) FOR [Netopagado]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_ProCesantia]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_ProCesantia]  DEFAULT ((0)) FOR [ProCesantia]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_ProInteres]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_ProInteres]  DEFAULT ((0)) FOR [ProInteres]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_ProPrima]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_ProPrima]  DEFAULT ((0)) FOR [ProPrima]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_ProVacaciones]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_ProVacaciones]  DEFAULT ((0)) FOR [ProVacaciones]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_ProSalud]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_ProSalud]  DEFAULT ((0)) FOR [ProSalud]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_ProPension]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_ProPension]  DEFAULT ((0)) FOR [ProPension]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_ProCaja]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_ProCaja]  DEFAULT ((0)) FOR [ProCaja]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_ProFamiliar]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_ProFamiliar]  DEFAULT ((0)) FOR [ProFamiliar]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_ProSena]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_ProSena]  DEFAULT ((0)) FOR [ProSena]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_ProRiesgos]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_ProRiesgos]  DEFAULT ((0)) FOR [ProRiesgos]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_ProParafiscales]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_ProParafiscales]  DEFAULT ((0)) FOR [ProParafiscales]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Horas]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Horas]  DEFAULT ((0)) FOR [Horas]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Fproceso]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Extraordinaria]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Extraordinaria]  DEFAULT ((0)) FOR [Extraordinaria]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Otrosdescuentos]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Otrosdescuentos]  DEFAULT ((0)) FOR [Otrosdescuentos]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Otra]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Otra]  DEFAULT ((0)) FOR [Otra]
GO

-- %% [markdown]
-- # [DF_MatrixNomina_Estado]

-- %%
ALTER TABLE [dbo].[MatrixNomina] ADD  CONSTRAINT [DF_MatrixNomina_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Matrixsub_Cantidad]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Matrixsub_Descuento]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_Matrixsub_Precio]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Matrixsub_PIva]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_Matrixsub_Precio total]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_Matrixsub_Neto]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Matrixsub_Subtotal]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Matrixsub_Exentos]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_Exentos]  DEFAULT ((0)) FOR [Exentos]
GO

-- %% [markdown]
-- # [DF_Matrixsub_DesExentos]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_DesExentos]  DEFAULT ((0)) FOR [DesExentos]
GO

-- %% [markdown]
-- # [DF_Matrixsub_DesGravados]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_DesGravados]  DEFAULT ((0)) FOR [DesGravados]
GO

-- %% [markdown]
-- # [DF_Matrixsub_Dolares]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_Dolares]  DEFAULT ((0)) FOR [Dolares]
GO

-- %% [markdown]
-- # [DF_Matrixsub_Costear]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_Costear]  DEFAULT ((0)) FOR [Costear]
GO

-- %% [markdown]
-- # [DF_Matrixsub_Peso]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Matrixsub_Remesa]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_Remesa]  DEFAULT ((0)) FOR [Remesa]
GO

-- %% [markdown]
-- # [DF_Matrixsub_VPropina]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_VPropina]  DEFAULT ((0)) FOR [VPropina]
GO

-- %% [markdown]
-- # [DF_Matrixsub_Controlfinal]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_Controlfinal]  DEFAULT ((0)) FOR [Controlfinal]
GO

-- %% [markdown]
-- # [DF_Matrixsub_Rebaja]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_Rebaja]  DEFAULT ((0)) FOR [Rebaja]
GO

-- %% [markdown]
-- # [DF_Matrixsub_Base]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_Base]  DEFAULT ((0)) FOR [Base]
GO

-- %% [markdown]
-- # [DF_Matrixsub_PRete]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_PRete]  DEFAULT ((0)) FOR [PRete]
GO

-- %% [markdown]
-- # [DF_Matrixsub_Retencion]

-- %%
ALTER TABLE [dbo].[Matrixsub] ADD  CONSTRAINT [DF_Matrixsub_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_Mercadeo_Fecha]

-- %%
ALTER TABLE [dbo].[Mercadeo] ADD  CONSTRAINT [DF_Mercadeo_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Mercadeo_Estado]

-- %%
ALTER TABLE [dbo].[Mercadeo] ADD  CONSTRAINT [DF_Mercadeo_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Mercadeo_Terminal]

-- %%
ALTER TABLE [dbo].[Mercadeo] ADD  CONSTRAINT [DF_Mercadeo_Terminal]  DEFAULT ((0)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_Mercadeo_Documento]

-- %%
ALTER TABLE [dbo].[Mercadeo] ADD  CONSTRAINT [DF_Mercadeo_Documento]  DEFAULT (N'TG') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_MinMmarca_Linea]

-- %%
ALTER TABLE [dbo].[MinMmarca] ADD  CONSTRAINT [DF_MinMmarca_Linea]  DEFAULT ((0)) FOR [Linea]
GO

-- %% [markdown]
-- # [DF_MinRutas_Kilometros]

-- %%
ALTER TABLE [dbo].[MinRutas] ADD  CONSTRAINT [DF_MinRutas_Kilometros]  DEFAULT ((0)) FOR [Kilometros]
GO

-- %% [markdown]
-- # [DF_MinRutas_ValorTonelada]

-- %%
ALTER TABLE [dbo].[MinRutas] ADD  CONSTRAINT [DF_MinRutas_ValorTonelada]  DEFAULT ((0)) FOR [ValorTonelada]
GO

-- %% [markdown]
-- # [DF_ModificaValor_Cantidad]

-- %%
ALTER TABLE [dbo].[ModificaValor] ADD  CONSTRAINT [DF_ModificaValor_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_ModificaValor_Total]

-- %%
ALTER TABLE [dbo].[ModificaValor] ADD  CONSTRAINT [DF_ModificaValor_Total]  DEFAULT ((0)) FOR [Total]
GO

-- %% [markdown]
-- # [DF_ModificaValor_PRetefte]

-- %%
ALTER TABLE [dbo].[ModificaValor] ADD  CONSTRAINT [DF_ModificaValor_PRetefte]  DEFAULT ((0)) FOR [PRetefte]
GO

-- %% [markdown]
-- # [DF_ModificaValor_Retefuente]

-- %%
ALTER TABLE [dbo].[ModificaValor] ADD  CONSTRAINT [DF_ModificaValor_Retefuente]  DEFAULT ((0)) FOR [Retefuente]
GO

-- %% [markdown]
-- # [DF_ModificaValor_PReteica]

-- %%
ALTER TABLE [dbo].[ModificaValor] ADD  CONSTRAINT [DF_ModificaValor_PReteica]  DEFAULT ((0)) FOR [PReteica]
GO

-- %% [markdown]
-- # [DF_ModificaValor_ReteIca]

-- %%
ALTER TABLE [dbo].[ModificaValor] ADD  CONSTRAINT [DF_ModificaValor_ReteIca]  DEFAULT ((0)) FOR [ReteIca]
GO

-- %% [markdown]
-- # [DF_ModificaValor_Neto]

-- %%
ALTER TABLE [dbo].[ModificaValor] ADD  CONSTRAINT [DF_ModificaValor_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_ModificaValor_Anticipo]

-- %%
ALTER TABLE [dbo].[ModificaValor] ADD  CONSTRAINT [DF_ModificaValor_Anticipo]  DEFAULT ((0)) FOR [Anticipo]
GO

-- %% [markdown]
-- # [DF_ModificaValor_Saldo]

-- %%
ALTER TABLE [dbo].[ModificaValor] ADD  CONSTRAINT [DF_ModificaValor_Saldo]  DEFAULT ((0)) FOR [Saldo]
GO

-- %% [markdown]
-- # [DF_ModificaValor_FPago]

-- %%
ALTER TABLE [dbo].[ModificaValor] ADD  CONSTRAINT [DF_ModificaValor_FPago]  DEFAULT (getdate()) FOR [FPago]
GO

-- %% [markdown]
-- # [DF_ModificaValor_Estado]

-- %%
ALTER TABLE [dbo].[ModificaValor] ADD  CONSTRAINT [DF_ModificaValor_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_ModificaValor_Documento]

-- %%
ALTER TABLE [dbo].[ModificaValor] ADD  CONSTRAINT [DF_ModificaValor_Documento]  DEFAULT (N'MVM') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Mostrador_Estado]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Mostrador_Fechafac]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Fechafac]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fechafac]
GO

-- %% [markdown]
-- # [DF_Mostrador_Tipo]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Tipo]  DEFAULT (N'Ventapos') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_Mostrador_Valortransporte]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Valortransporte]  DEFAULT ((0)) FOR [Valortransporte]
GO

-- %% [markdown]
-- # [DF_Mostrador_Dias]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Mostrador_Documento]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Documento]  DEFAULT (N'FM') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Mostrador_Base]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Base]  DEFAULT ((0)) FOR [Base]
GO

-- %% [markdown]
-- # [DF_Mostrador_Abono]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Abono]  DEFAULT ((0)) FOR [Abono]
GO

-- %% [markdown]
-- # [DF_Mostrador_Saldo]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Saldo]  DEFAULT ((0)) FOR [Saldo]
GO

-- %% [markdown]
-- # [DF_Mostrador_Bloque]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Bloque]  DEFAULT ((0)) FOR [Bloque]
GO

-- %% [markdown]
-- # [DF_Mostrador_PRetencion]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_PRetencion]  DEFAULT ((0)) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_Mostrador_PReteIca]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_Mostrador_Reteica]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Reteica]  DEFAULT ((0)) FOR [Reteica]
GO

-- %% [markdown]
-- # [DF_Mostrador_PReteIva]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_Mostrador_ReteIva]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_ReteIva]  DEFAULT ((0)) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_Mostrador_Numero]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Numero]  DEFAULT ((0)) FOR [Numero]
GO

-- %% [markdown]
-- # [DF_Mostrador_Billete]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Billete]  DEFAULT ((0)) FOR [Billete]
GO

-- %% [markdown]
-- # [DF_Mostrador_Vueltas]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Vueltas]  DEFAULT ((0)) FOR [Vueltas]
GO

-- %% [markdown]
-- # [DF_Mostrador_Control]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Control]  DEFAULT ((0)) FOR [Control]
GO

-- %% [markdown]
-- # [DF_Mostrador_Descarga]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Descarga]  DEFAULT (N'DESCARGAR') FOR [Descarga]
GO

-- %% [markdown]
-- # [DF_Mostrador_PFlete]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_PFlete]  DEFAULT ((0)) FOR [PFlete]
GO

-- %% [markdown]
-- # [DF_Mostrador_Terminal]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_Mostrador_Numero2]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Numero2]  DEFAULT ((0)) FOR [Numero2]
GO

-- %% [markdown]
-- # [DF_Mostrador_PDescuento]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_PDescuento]  DEFAULT ((0)) FOR [PDescuento]
GO

-- %% [markdown]
-- # [DF_Mostrador_TRM]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_TRM]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Mostrador_Us]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_Mostrador_Cupo]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Cupo]  DEFAULT ((0)) FOR [Cupo]
GO

-- %% [markdown]
-- # [DF_Mostrador_Diasvencimiento]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Diasvencimiento]  DEFAULT ((0)) FOR [Diasvencimiento]
GO

-- %% [markdown]
-- # [DF_Mostrador_Cartera]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Cartera]  DEFAULT ((0)) FOR [Cartera]
GO

-- %% [markdown]
-- # [DF_Mostrador_Edad]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Edad]  DEFAULT ((0)) FOR [Edad]
GO

-- %% [markdown]
-- # [DF_Mostrador_Estadoter]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Estadoter]  DEFAULT ((0)) FOR [Estadoter]
GO

-- %% [markdown]
-- # [DF_Mostrador_Diferencia]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Diferencia]  DEFAULT ((0)) FOR [Diferencia]
GO

-- %% [markdown]
-- # [DF_Mostrador_Retencion]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_Mostrador_Declarado]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Declarado]  DEFAULT ((0)) FOR [Declarado]
GO

-- %% [markdown]
-- # [DF_Mostrador_Pcree]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Pcree]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_Mostrador_Retecree]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Retecree]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_Mostrador_Situacion]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Situacion]  DEFAULT (N'PENDIENTE') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Mostrador_TipoRetencion]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_TipoRetencion]  DEFAULT ((1302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_Mostrador_Matrix]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Matrix]  DEFAULT ((0)) FOR [Matrix]
GO

-- %% [markdown]
-- # [DF_Mostrador_Concepto]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Concepto]  DEFAULT ((1315)) FOR [Concepto]
GO

-- %% [markdown]
-- # [DF_Mostrador_Anticipos]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Anticipos]  DEFAULT ((0)) FOR [Anticipos]
GO

-- %% [markdown]
-- # [DF_Mostrador_PUtilidadest]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_PUtilidadest]  DEFAULT ((0)) FOR [PUtilidadest]
GO

-- %% [markdown]
-- # [DF_Mostrador_Utilidadest]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Utilidadest]  DEFAULT ((0)) FOR [Utilidadest]
GO

-- %% [markdown]
-- # [DF_Mostrador_Imprevistos]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Imprevistos]  DEFAULT ((0)) FOR [Imprevistos]
GO

-- %% [markdown]
-- # [DF_Mostrador_Pimprevistos]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Pimprevistos]  DEFAULT ((0)) FOR [Pimprevistos]
GO

-- %% [markdown]
-- # [DF_Mostrador_Admon]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Admon]  DEFAULT ((0)) FOR [Admon]
GO

-- %% [markdown]
-- # [DF_Mostrador_PAdmon]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_PAdmon]  DEFAULT ((0)) FOR [PAdmon]
GO

-- %% [markdown]
-- # [DF_Mostrador_ImpReteica]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_ImpReteica]  DEFAULT ((0)) FOR [ImpReteica]
GO

-- %% [markdown]
-- # [DF_Mostrador_ImpReteiva]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_ImpReteiva]  DEFAULT ((0)) FOR [ImpReteiva]
GO

-- %% [markdown]
-- # [DF_Mostrador_CantBolsas]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_CantBolsas]  DEFAULT ((0)) FOR [CantBolsas]
GO

-- %% [markdown]
-- # [DF_Mostrador_ValBolsas]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_ValBolsas]  DEFAULT ((0)) FOR [ValBolsas]
GO

-- %% [markdown]
-- # [DF_Mostrador_StatusDian]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_StatusDian]  DEFAULT ((0)) FOR [StatusDian]
GO

-- %% [markdown]
-- # [DF_Mostrador_StatusCliente]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_StatusCliente]  DEFAULT ((0)) FOR [StatusCliente]
GO

-- %% [markdown]
-- # [DF_Mostrador_Horafin]

-- %%
ALTER TABLE [dbo].[Mostrador] ADD  CONSTRAINT [DF_Mostrador_Horafin]  DEFAULT (getdate()) FOR [Horafin]
GO

-- %% [markdown]
-- # [DF_Mostradorinsumos_Cantidad]

-- %%
ALTER TABLE [dbo].[Mostradorinsumos] ADD  CONSTRAINT [DF_Mostradorinsumos_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Mostradorinsumos_Peso]

-- %%
ALTER TABLE [dbo].[Mostradorinsumos] ADD  CONSTRAINT [DF_Mostradorinsumos_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Mostradorinsumos_CantidadRef]

-- %%
ALTER TABLE [dbo].[Mostradorinsumos] ADD  CONSTRAINT [DF_Mostradorinsumos_CantidadRef]  DEFAULT ((1)) FOR [CantidadRef]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Cantidad]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Descuento]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_PIva]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Precio]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Subtotal]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Neto]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Precio total]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Exentos]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Exentos]  DEFAULT ((0)) FOR [Exentos]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_DesExentos]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_DesExentos]  DEFAULT ((0)) FOR [DesExentos]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_DesGravados]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_DesGravados]  DEFAULT ((0)) FOR [DesGravados]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Peso]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_VPropina]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_VPropina]  DEFAULT ((0)) FOR [VPropina]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Controlfinal]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Controlfinal]  DEFAULT ((0)) FOR [Controlfinal]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Rebaja]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Rebaja]  DEFAULT ((0)) FOR [Rebaja]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Costo]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Gastos]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Gastos]  DEFAULT ((0)) FOR [Gastos]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Largo]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Largo]  DEFAULT ((0)) FOR [Largo]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Ancho]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Ancho]  DEFAULT ((0)) FOR [Ancho]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Alto]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Alto]  DEFAULT ((0)) FOR [Alto]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Volumen]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Volumen]  DEFAULT ((0)) FOR [Volumen]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Pimpoconsumo]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Pimpoconsumo]  DEFAULT ((0)) FOR [Pimpoconsumo]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_ImpCon]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_ImpCon]  DEFAULT ((0)) FOR [ImpCon]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Dolares]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Dolares]  DEFAULT ((0)) FOR [Dolares]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Costear]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Costear]  DEFAULT ((0)) FOR [Costear]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_PRete]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_PRete]  DEFAULT ((0)) FOR [PRete]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Retencion]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_TipoRetencion]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_TipoRetencion]  DEFAULT ((1302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Moneda]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Moneda]  DEFAULT (N'COP') FOR [Moneda]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_TRMS]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_TRMS]  DEFAULT ((1)) FOR [TRMS]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_Cree]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_Cree]  DEFAULT ((0)) FOR [Cree]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_PReteIcasub]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_PReteIcasub]  DEFAULT ((0)) FOR [PReteIcasub]
GO

-- %% [markdown]
-- # [DF_Mostradorsub_ReteIcasub]

-- %%
ALTER TABLE [dbo].[Mostradorsub] ADD  CONSTRAINT [DF_Mostradorsub_ReteIcasub]  DEFAULT ((0)) FOR [ReteIcasub]
GO

-- %% [markdown]
-- # [DF_Multimodal_Fecha]

-- %%
ALTER TABLE [dbo].[Multimodal] ADD  CONSTRAINT [DF_Multimodal_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Multimodal_Estado]

-- %%
ALTER TABLE [dbo].[Multimodal] ADD  CONSTRAINT [DF_Multimodal_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Multimodal_Documento]

-- %%
ALTER TABLE [dbo].[Multimodal] ADD  CONSTRAINT [DF_Multimodal_Documento]  DEFAULT (N'OTM') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Multimodal_VlrAsegurado]

-- %%
ALTER TABLE [dbo].[Multimodal] ADD  CONSTRAINT [DF_Multimodal_VlrAsegurado]  DEFAULT ((0)) FOR [VlrAsegurado]
GO

-- %% [markdown]
-- # [DF_NCredito_Fecha]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_NCredito_Documento]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_Documento]  DEFAULT (N'NC') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_NCredito_Tipo]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_Tipo]  DEFAULT (N'NCredito') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_NCredito_Reteica]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_Reteica]  DEFAULT ((0)) FOR [Reteica]
GO

-- %% [markdown]
-- # [DF_NCredito_ReteIva]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_ReteIva]  DEFAULT ((0)) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_NCredito_Retefuente]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_Retefuente]  DEFAULT ((0)) FOR [Retefuente]
GO

-- %% [markdown]
-- # [DF_NCredito_Neto]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_NCredito_Fproceso]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_NCredito_PRetencion]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_PRetencion]  DEFAULT ((0)) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_NCredito_PReteIca]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_NCredito_PReteIva]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_NCredito_TipoRetencion]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_TipoRetencion]  DEFAULT ((1302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_NCredito_Terminal]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_NCredito_Descarga]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_Descarga]  DEFAULT (N'CARGAR') FOR [Descarga]
GO

-- %% [markdown]
-- # [DF_NCredito_Estado]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NCredito_Us]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_NCredito_TRM]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_TRM]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_NCredito_Docu]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_Docu]  DEFAULT (N'FV') FOR [Docu]
GO

-- %% [markdown]
-- # [DF_NCredito_Pcree]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_Pcree]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_NCredito_Retecree]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_Retecree]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_NCredito_StatusDian]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_StatusDian]  DEFAULT ((0)) FOR [StatusDian]
GO

-- %% [markdown]
-- # [DF_NCredito_StatusCliente]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_StatusCliente]  DEFAULT ((0)) FOR [StatusCliente]
GO

-- %% [markdown]
-- # [DF_NCredito_Horafin]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_Horafin]  DEFAULT (getdate()) FOR [Horafin]
GO

-- %% [markdown]
-- # [DF_NCredito_TipoFactura]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_TipoFactura]  DEFAULT (N'91') FOR [TipoFactura]
GO

-- %% [markdown]
-- # [DF_NCredito_TipoOperacion]

-- %%
ALTER TABLE [dbo].[NCredito] ADD  CONSTRAINT [DF_NCredito_TipoOperacion]  DEFAULT (N'20') FOR [TipoOperacion]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Fecha]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Documento]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Documento]  DEFAULT (N'NCM') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Tipo]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Tipo]  DEFAULT (N'NCreditopos') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Reteica]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Reteica]  DEFAULT ((0)) FOR [Reteica]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_ReteIva]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_ReteIva]  DEFAULT ((0)) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Retefuente]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Retefuente]  DEFAULT ((0)) FOR [Retefuente]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Neto]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Fproceso]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Terminal]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Descarga]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Descarga]  DEFAULT (N'CARGAR') FOR [Descarga]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Estado]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Docu]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Docu]  DEFAULT (N'FM') FOR [Docu]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Pcree]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Pcree]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Retecree]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Retecree]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Retencion]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_ImpReteica]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_ImpReteica]  DEFAULT ((0)) FOR [ImpReteica]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_ImpReteiva]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_ImpReteiva]  DEFAULT ((0)) FOR [ImpReteiva]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_PRetencion]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_PRetencion]  DEFAULT ((0)) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_PReteIca]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_PReteIva]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_StatusDian]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_StatusDian]  DEFAULT ((0)) FOR [StatusDian]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_StatusCliente]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_StatusCliente]  DEFAULT ((0)) FOR [StatusCliente]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Horafin]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Horafin]  DEFAULT (getdate()) FOR [Horafin]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_TipoFactura]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_TipoFactura]  DEFAULT (N'91') FOR [TipoFactura]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_TipoOperacion]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_TipoOperacion]  DEFAULT (N'20') FOR [TipoOperacion]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_Us]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_NCreditoPos_TRM]

-- %%
ALTER TABLE [dbo].[NCreditoPos] ADD  CONSTRAINT [DF_NCreditoPos_TRM]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_Fecha]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_Documento]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_Documento]  DEFAULT (N'NCP') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_Tipo]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_Tipo]  DEFAULT (N'Ncreditoprov') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_Reteica]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_Reteica]  DEFAULT ((0)) FOR [Reteica]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_ReteIva]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_ReteIva]  DEFAULT ((0)) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_Retefuente]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_Retefuente]  DEFAULT ((0)) FOR [Retefuente]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_Neto]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_Fproceso]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_TipoRetencion]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_TipoRetencion]  DEFAULT ((2302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_DO]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_DO]  DEFAULT ((0)) FOR [DO]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_Descarga]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_Descarga]  DEFAULT (N'CARGAR') FOR [Descarga]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_Estado]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_Us]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_TRM]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_TRM]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_PRetencion]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_PRetencion]  DEFAULT ((0)) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_PReteIca]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_PReteIva]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_Pcree]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_Pcree]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedores_Retecree]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores] ADD  CONSTRAINT [DF_NCreditoproveedores_Retecree]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedoresub_PIva]

-- %%
ALTER TABLE [dbo].[NCreditoproveedoresub] ADD  CONSTRAINT [DF_NCreditoproveedoresub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedoresub_Cantidad]

-- %%
ALTER TABLE [dbo].[NCreditoproveedoresub] ADD  CONSTRAINT [DF_NCreditoproveedoresub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedoresub_Precio total]

-- %%
ALTER TABLE [dbo].[NCreditoproveedoresub] ADD  CONSTRAINT [DF_NCreditoproveedoresub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedoresub_Neto]

-- %%
ALTER TABLE [dbo].[NCreditoproveedoresub] ADD  CONSTRAINT [DF_NCreditoproveedoresub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedoresub_Descuento]

-- %%
ALTER TABLE [dbo].[NCreditoproveedoresub] ADD  CONSTRAINT [DF_NCreditoproveedoresub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedoresub_Precio]

-- %%
ALTER TABLE [dbo].[NCreditoproveedoresub] ADD  CONSTRAINT [DF_NCreditoproveedoresub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedoresub_Peso]

-- %%
ALTER TABLE [dbo].[NCreditoproveedoresub] ADD  CONSTRAINT [DF_NCreditoproveedoresub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedoresub_Subtotal]

-- %%
ALTER TABLE [dbo].[NCreditoproveedoresub] ADD  CONSTRAINT [DF_NCreditoproveedoresub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedoresub_PRete]

-- %%
ALTER TABLE [dbo].[NCreditoproveedoresub] ADD  CONSTRAINT [DF_NCreditoproveedoresub_PRete]  DEFAULT ((0)) FOR [PRete]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedoresub_Retencion]

-- %%
ALTER TABLE [dbo].[NCreditoproveedoresub] ADD  CONSTRAINT [DF_NCreditoproveedoresub_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_NCreditoproveedoresub_VPropina]

-- %%
ALTER TABLE [dbo].[NCreditoproveedoresub] ADD  CONSTRAINT [DF_NCreditoproveedoresub_VPropina]  DEFAULT ((0)) FOR [VPropina]
GO

-- %% [markdown]
-- # [DF_NCreditosub_Cantidad]

-- %%
ALTER TABLE [dbo].[NCreditosub] ADD  CONSTRAINT [DF_NCreditosub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_NCreditosub_Descuento]

-- %%
ALTER TABLE [dbo].[NCreditosub] ADD  CONSTRAINT [DF_NCreditosub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_NCreditosub_PIva]

-- %%
ALTER TABLE [dbo].[NCreditosub] ADD  CONSTRAINT [DF_NCreditosub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_NCreditosub_Precio]

-- %%
ALTER TABLE [dbo].[NCreditosub] ADD  CONSTRAINT [DF_NCreditosub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_NCreditosub_Subtotal]

-- %%
ALTER TABLE [dbo].[NCreditosub] ADD  CONSTRAINT [DF_NCreditosub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_NCreditosub_Neto]

-- %%
ALTER TABLE [dbo].[NCreditosub] ADD  CONSTRAINT [DF_NCreditosub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_NCreditosub_Precio total]

-- %%
ALTER TABLE [dbo].[NCreditosub] ADD  CONSTRAINT [DF_NCreditosub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_NCreditosub_Peso]

-- %%
ALTER TABLE [dbo].[NCreditosub] ADD  CONSTRAINT [DF_NCreditosub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_NCreditosub_Pimpoconsumo]

-- %%
ALTER TABLE [dbo].[NCreditosub] ADD  CONSTRAINT [DF_NCreditosub_Pimpoconsumo]  DEFAULT ((0)) FOR [Pimpoconsumo]
GO

-- %% [markdown]
-- # [DF_NCreditosub_ImpCon]

-- %%
ALTER TABLE [dbo].[NCreditosub] ADD  CONSTRAINT [DF_NCreditosub_ImpCon]  DEFAULT ((0)) FOR [ImpCon]
GO

-- %% [markdown]
-- # [DF_NCreditosub_PRete]

-- %%
ALTER TABLE [dbo].[NCreditosub] ADD  CONSTRAINT [DF_NCreditosub_PRete]  DEFAULT ((0)) FOR [PRete]
GO

-- %% [markdown]
-- # [DF_NCreditosub_Retencion]

-- %%
ALTER TABLE [dbo].[NCreditosub] ADD  CONSTRAINT [DF_NCreditosub_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_NCreditosub_VPropina]

-- %%
ALTER TABLE [dbo].[NCreditosub] ADD  CONSTRAINT [DF_NCreditosub_VPropina]  DEFAULT ((0)) FOR [VPropina]
GO

-- %% [markdown]
-- # [DF_NCreditosub_Cree]

-- %%
ALTER TABLE [dbo].[NCreditosub] ADD  CONSTRAINT [DF_NCreditosub_Cree]  DEFAULT ((0)) FOR [Cree]
GO

-- %% [markdown]
-- # [DF_NCreditosub_Costo]

-- %%
ALTER TABLE [dbo].[NCreditosub] ADD  CONSTRAINT [DF_NCreditosub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_NCreditosubPos_Cantidad]

-- %%
ALTER TABLE [dbo].[NCreditosubPos] ADD  CONSTRAINT [DF_NCreditosubPos_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_NCreditosubPos_Descuento]

-- %%
ALTER TABLE [dbo].[NCreditosubPos] ADD  CONSTRAINT [DF_NCreditosubPos_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_NCreditosubPos_PIva]

-- %%
ALTER TABLE [dbo].[NCreditosubPos] ADD  CONSTRAINT [DF_NCreditosubPos_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_NCreditosubPos_Precio]

-- %%
ALTER TABLE [dbo].[NCreditosubPos] ADD  CONSTRAINT [DF_NCreditosubPos_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_NCreditosubPos_Subtotal]

-- %%
ALTER TABLE [dbo].[NCreditosubPos] ADD  CONSTRAINT [DF_NCreditosubPos_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_NCreditosubPos_Neto]

-- %%
ALTER TABLE [dbo].[NCreditosubPos] ADD  CONSTRAINT [DF_NCreditosubPos_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_NCreditosubPos_Precio total]

-- %%
ALTER TABLE [dbo].[NCreditosubPos] ADD  CONSTRAINT [DF_NCreditosubPos_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_NCreditosubPos_Peso]

-- %%
ALTER TABLE [dbo].[NCreditosubPos] ADD  CONSTRAINT [DF_NCreditosubPos_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_NCreditosubPos_Pimpoconsumo]

-- %%
ALTER TABLE [dbo].[NCreditosubPos] ADD  CONSTRAINT [DF_NCreditosubPos_Pimpoconsumo]  DEFAULT ((0)) FOR [Pimpoconsumo]
GO

-- %% [markdown]
-- # [DF_NCreditosubPos_ImpCon]

-- %%
ALTER TABLE [dbo].[NCreditosubPos] ADD  CONSTRAINT [DF_NCreditosubPos_ImpCon]  DEFAULT ((0)) FOR [ImpCon]
GO

-- %% [markdown]
-- # [DF_NCreditosubPos_VPropina]

-- %%
ALTER TABLE [dbo].[NCreditosubPos] ADD  CONSTRAINT [DF_NCreditosubPos_VPropina]  DEFAULT ((0)) FOR [VPropina]
GO

-- %% [markdown]
-- # [DF_NCreditosubPos_Cree]

-- %%
ALTER TABLE [dbo].[NCreditosubPos] ADD  CONSTRAINT [DF_NCreditosubPos_Cree]  DEFAULT ((0)) FOR [Cree]
GO

-- %% [markdown]
-- # [DF_NCreditosubPos_PRete]

-- %%
ALTER TABLE [dbo].[NCreditosubPos] ADD  CONSTRAINT [DF_NCreditosubPos_PRete]  DEFAULT ((0)) FOR [PRete]
GO

-- %% [markdown]
-- # [DF_NCreditosubPos_Retencion]

-- %%
ALTER TABLE [dbo].[NCreditosubPos] ADD  CONSTRAINT [DF_NCreditosubPos_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_NCreditosubPos_Costo]

-- %%
ALTER TABLE [dbo].[NCreditosubPos] ADD  CONSTRAINT [DF_NCreditosubPos_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_NDebito_Fecha]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_NDebito_Documento]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_Documento]  DEFAULT (N'ND') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_NDebito_Tipo]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_Tipo]  DEFAULT (N'NDebito') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_NDebito_Reteica]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_Reteica]  DEFAULT ((0)) FOR [Reteica]
GO

-- %% [markdown]
-- # [DF_NDebito_ReteIva]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_ReteIva]  DEFAULT ((0)) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_NDebito_Retefuente]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_Retefuente]  DEFAULT ((0)) FOR [Retefuente]
GO

-- %% [markdown]
-- # [DF_NDebito_Neto]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_NDebito_Fproceso]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_NDebito_TipoRetencion]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_TipoRetencion]  DEFAULT ((2302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_NDebito_DO]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_DO]  DEFAULT ((0)) FOR [DO]
GO

-- %% [markdown]
-- # [DF_NDebito_Descarga]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_Descarga]  DEFAULT (N'DESCARGAR') FOR [Descarga]
GO

-- %% [markdown]
-- # [DF_NDebito_Estado]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NDebito_TRM]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_TRM]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_NDebito_Us]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_NDebito_PRetencion]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_PRetencion]  DEFAULT ((0)) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_NDebito_PReteIca]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_NDebito_PReteIva]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_NDebito_Pcree]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_Pcree]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_NDebito_Retecree]

-- %%
ALTER TABLE [dbo].[NDebito] ADD  CONSTRAINT [DF_NDebito_Retecree]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Fecha]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Documento]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Documento]  DEFAULT (N'NDC') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Tipo]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Tipo]  DEFAULT (N'NDebitoCliente') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Reteica]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Reteica]  DEFAULT ((0)) FOR [Reteica]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_ReteIva]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_ReteIva]  DEFAULT ((0)) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Retefuente]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Retefuente]  DEFAULT ((0)) FOR [Retefuente]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Neto]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Fproceso]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_PRetencion]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_PRetencion]  DEFAULT ((0)) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_PReteIca]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_PReteIva]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_TipoRetencion]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_TipoRetencion]  DEFAULT ((1302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Terminal]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Descarga]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Descarga]  DEFAULT (N'DESCARGAR') FOR [Descarga]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Estado]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Idplan]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Idplan]  DEFAULT ((0)) FOR [Idplan]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Us]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_TRM]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_TRM]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Docu]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Docu]  DEFAULT (N'FV') FOR [Docu]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Pcree]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Pcree]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Retecree]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Retecree]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_StatusDian]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_StatusDian]  DEFAULT ((0)) FOR [StatusDian]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_StatusCliente]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_StatusCliente]  DEFAULT ((0)) FOR [StatusCliente]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_Horafin]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_Horafin]  DEFAULT (getdate()) FOR [Horafin]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_TipoFactura]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_TipoFactura]  DEFAULT (N'92') FOR [TipoFactura]
GO

-- %% [markdown]
-- # [DF_NDebitoClientes_TipoOperacion]

-- %%
ALTER TABLE [dbo].[NDebitoClientes] ADD  CONSTRAINT [DF_NDebitoClientes_TipoOperacion]  DEFAULT (N'30') FOR [TipoOperacion]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_Cantidad]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_PIva]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_Precio]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_Subtotal]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_Neto]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_Precio total]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_Descuento]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_Peso]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_Controlfinal]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_Controlfinal]  DEFAULT ((0)) FOR [Controlfinal]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_Pimpoconsumo]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_Pimpoconsumo]  DEFAULT ((0)) FOR [Pimpoconsumo]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_ImpCon]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_ImpCon]  DEFAULT ((0)) FOR [ImpCon]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_PRete]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_PRete]  DEFAULT ((0)) FOR [PRete]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_Retencion]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_VPropina]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_VPropina]  DEFAULT ((0)) FOR [VPropina]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_Cree]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_Cree]  DEFAULT ((0)) FOR [Cree]
GO

-- %% [markdown]
-- # [DF_NDebitoClientesub_Costo]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub] ADD  CONSTRAINT [DF_NDebitoClientesub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_NDebitosub_PIva]

-- %%
ALTER TABLE [dbo].[NDebitosub] ADD  CONSTRAINT [DF_NDebitosub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_NDebitosub_Cantidad]

-- %%
ALTER TABLE [dbo].[NDebitosub] ADD  CONSTRAINT [DF_NDebitosub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_NDebitosub_Precio total]

-- %%
ALTER TABLE [dbo].[NDebitosub] ADD  CONSTRAINT [DF_NDebitosub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_NDebitosub_Neto]

-- %%
ALTER TABLE [dbo].[NDebitosub] ADD  CONSTRAINT [DF_NDebitosub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_NDebitosub_Descuento]

-- %%
ALTER TABLE [dbo].[NDebitosub] ADD  CONSTRAINT [DF_NDebitosub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_NDebitosub_Precio]

-- %%
ALTER TABLE [dbo].[NDebitosub] ADD  CONSTRAINT [DF_NDebitosub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_NDebitosub_Peso]

-- %%
ALTER TABLE [dbo].[NDebitosub] ADD  CONSTRAINT [DF_NDebitosub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_NDebitosub_Subtotal]

-- %%
ALTER TABLE [dbo].[NDebitosub] ADD  CONSTRAINT [DF_NDebitosub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_NDebitosub_PRete]

-- %%
ALTER TABLE [dbo].[NDebitosub] ADD  CONSTRAINT [DF_NDebitosub_PRete]  DEFAULT ((0)) FOR [PRete]
GO

-- %% [markdown]
-- # [DF_NDebitosub_Retencion]

-- %%
ALTER TABLE [dbo].[NDebitosub] ADD  CONSTRAINT [DF_NDebitosub_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_NDebitosub_VPropina]

-- %%
ALTER TABLE [dbo].[NDebitosub] ADD  CONSTRAINT [DF_NDebitosub_VPropina]  DEFAULT ((0)) FOR [VPropina]
GO

-- %% [markdown]
-- # [DF_Negocios_Fecha]

-- %%
ALTER TABLE [dbo].[Negocios] ADD  CONSTRAINT [DF_Negocios_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Negocios_Estado]

-- %%
ALTER TABLE [dbo].[Negocios] ADD  CONSTRAINT [DF_Negocios_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NifCuentas_Estado]

-- %%
ALTER TABLE [dbo].[NifCuentas] ADD  CONSTRAINT [DF_NifCuentas_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NifCuentas_Imputable]

-- %%
ALTER TABLE [dbo].[NifCuentas] ADD  CONSTRAINT [DF_NifCuentas_Imputable]  DEFAULT (N'SI') FOR [Imputable]
GO

-- %% [markdown]
-- # [DF_NifCuentas_Deducible]

-- %%
ALTER TABLE [dbo].[NifCuentas] ADD  CONSTRAINT [DF_NifCuentas_Deducible]  DEFAULT (N'SI') FOR [Deducible]
GO

-- %% [markdown]
-- # [DF_NifDeterioro_Fecha]

-- %%
ALTER TABLE [dbo].[NifDeterioro] ADD  CONSTRAINT [DF_NifDeterioro_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_NifDeterioro_Documento]

-- %%
ALTER TABLE [dbo].[NifDeterioro] ADD  CONSTRAINT [DF_NifDeterioro_Documento]  DEFAULT (N'DCN') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_NifDeterioro_Estado]

-- %%
ALTER TABLE [dbo].[NifDeterioro] ADD  CONSTRAINT [DF_NifDeterioro_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NifDeterioro_Niif]

-- %%
ALTER TABLE [dbo].[NifDeterioro] ADD  CONSTRAINT [DF_NifDeterioro_Niif]  DEFAULT (N'SI') FOR [Niif]
GO

-- %% [markdown]
-- # [DF_NifDeterioro_Local]

-- %%
ALTER TABLE [dbo].[NifDeterioro] ADD  CONSTRAINT [DF_NifDeterioro_Local]  DEFAULT (N'NO') FOR [Local]
GO

-- %% [markdown]
-- # [DF_NifDeteriorosub_Saldo]

-- %%
ALTER TABLE [dbo].[NifDeteriorosub] ADD  CONSTRAINT [DF_NifDeteriorosub_Saldo]  DEFAULT ((0)) FOR [Saldo]
GO

-- %% [markdown]
-- # [DF_NifDeteriorosub_Edad]

-- %%
ALTER TABLE [dbo].[NifDeteriorosub] ADD  CONSTRAINT [DF_NifDeteriorosub_Edad]  DEFAULT ((0)) FOR [Edad]
GO

-- %% [markdown]
-- # [DF_NifDeteriorosub_Dcausados]

-- %%
ALTER TABLE [dbo].[NifDeteriorosub] ADD  CONSTRAINT [DF_NifDeteriorosub_Dcausados]  DEFAULT ((0)) FOR [Dcausados]
GO

-- %% [markdown]
-- # [DF_NifDeteriorosub_Dajuste]

-- %%
ALTER TABLE [dbo].[NifDeteriorosub] ADD  CONSTRAINT [DF_NifDeteriorosub_Dajuste]  DEFAULT ((0)) FOR [Dajuste]
GO

-- %% [markdown]
-- # [DF_NifDeteriorosub_Ajuste]

-- %%
ALTER TABLE [dbo].[NifDeteriorosub] ADD  CONSTRAINT [DF_NifDeteriorosub_Ajuste]  DEFAULT ((0)) FOR [Ajuste]
GO

-- %% [markdown]
-- # [DF_NifInteres_Fecha]

-- %%
ALTER TABLE [dbo].[NifInteres] ADD  CONSTRAINT [DF_NifInteres_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_NifInteres_Documento]

-- %%
ALTER TABLE [dbo].[NifInteres] ADD  CONSTRAINT [DF_NifInteres_Documento]  DEFAULT (N'IM') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_NifInteres_Estado]

-- %%
ALTER TABLE [dbo].[NifInteres] ADD  CONSTRAINT [DF_NifInteres_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NifInteres_Niif]

-- %%
ALTER TABLE [dbo].[NifInteres] ADD  CONSTRAINT [DF_NifInteres_Niif]  DEFAULT (N'SI') FOR [Niif]
GO

-- %% [markdown]
-- # [DF_NifInteres_Local]

-- %%
ALTER TABLE [dbo].[NifInteres] ADD  CONSTRAINT [DF_NifInteres_Local]  DEFAULT (N'SI') FOR [Local]
GO

-- %% [markdown]
-- # [DF_NifInteresub_Saldo]

-- %%
ALTER TABLE [dbo].[NifInteresub] ADD  CONSTRAINT [DF_NifInteresub_Saldo]  DEFAULT ((0)) FOR [Saldo]
GO

-- %% [markdown]
-- # [DF_NifInteresub_Edad]

-- %%
ALTER TABLE [dbo].[NifInteresub] ADD  CONSTRAINT [DF_NifInteresub_Edad]  DEFAULT ((0)) FOR [Edad]
GO

-- %% [markdown]
-- # [DF_NifInteresub_Dcausados]

-- %%
ALTER TABLE [dbo].[NifInteresub] ADD  CONSTRAINT [DF_NifInteresub_Dcausados]  DEFAULT ((0)) FOR [Dcausados]
GO

-- %% [markdown]
-- # [DF_NifInteresub_Dajuste]

-- %%
ALTER TABLE [dbo].[NifInteresub] ADD  CONSTRAINT [DF_NifInteresub_Dajuste]  DEFAULT ((0)) FOR [Dajuste]
GO

-- %% [markdown]
-- # [DF_NifInteresub_Ajuste]

-- %%
ALTER TABLE [dbo].[NifInteresub] ADD  CONSTRAINT [DF_NifInteresub_Ajuste]  DEFAULT ((0)) FOR [Ajuste]
GO

-- %% [markdown]
-- # [DF_Table_1_Tasa]

-- %%
ALTER TABLE [dbo].[NifRangos] ADD  CONSTRAINT [DF_Table_1_Tasa]  DEFAULT ((0)) FOR [Tasa]
GO

-- %% [markdown]
-- # [DF_NifRangosInt_Tasa]

-- %%
ALTER TABLE [dbo].[NifRangosInt] ADD  CONSTRAINT [DF_NifRangosInt_Tasa]  DEFAULT ((0)) FOR [Tasa]
GO

-- %% [markdown]
-- # [DF_NifReversion_Fecha]

-- %%
ALTER TABLE [dbo].[NifReversion] ADD  CONSTRAINT [DF_NifReversion_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_NifReversion_Documento]

-- %%
ALTER TABLE [dbo].[NifReversion] ADD  CONSTRAINT [DF_NifReversion_Documento]  DEFAULT (N'RD') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_NifReversion_Estado]

-- %%
ALTER TABLE [dbo].[NifReversion] ADD  CONSTRAINT [DF_NifReversion_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Nifreversionsub_Saldo]

-- %%
ALTER TABLE [dbo].[Nifreversionsub] ADD  CONSTRAINT [DF_Nifreversionsub_Saldo]  DEFAULT ((0)) FOR [Saldo]
GO

-- %% [markdown]
-- # [DF_NiifRevelaciones_Fecha]

-- %%
ALTER TABLE [dbo].[NiifRevelaciones] ADD  CONSTRAINT [DF_NiifRevelaciones_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_NiifRevelaciones_Estado]

-- %%
ALTER TABLE [dbo].[NiifRevelaciones] ADD  CONSTRAINT [DF_NiifRevelaciones_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NiifRevelaciones_Documento]

-- %%
ALTER TABLE [dbo].[NiifRevelaciones] ADD  CONSTRAINT [DF_NiifRevelaciones_Documento]  DEFAULT (N'RV') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Nomina_Idparnomina]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Idparnomina]  DEFAULT ((1)) FOR [Idparnomina]
GO

-- %% [markdown]
-- # [DF_Nomina_Documento]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Documento]  DEFAULT (N'NM') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Nomina_Fecha]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Nomina_Días trabajados]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Días trabajados]  DEFAULT ((0)) FOR [Días trabajados]
GO

-- %% [markdown]
-- # [DF_Nomina_HEDO]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_HEDO]  DEFAULT ((0)) FOR [HEDO]
GO

-- %% [markdown]
-- # [DF_Nomina_HENO]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_HENO]  DEFAULT ((0)) FOR [HENO]
GO

-- %% [markdown]
-- # [DF_Nomina_HEDF]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_HEDF]  DEFAULT ((0)) FOR [HEDF]
GO

-- %% [markdown]
-- # [DF_Nomina_HENF]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_HENF]  DEFAULT ((0)) FOR [HENF]
GO

-- %% [markdown]
-- # [DF_Nomina_RN]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_RN]  DEFAULT ((0)) FOR [RN]
GO

-- %% [markdown]
-- # [DF_Nomina_Otrosdevengados]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Otrosdevengados]  DEFAULT ((0)) FOR [Otrosdevengados]
GO

-- %% [markdown]
-- # [DF_Nomina_Otrasdeducciones]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Otrasdeducciones]  DEFAULT ((0)) FOR [Otrasdeducciones]
GO

-- %% [markdown]
-- # [DF_Nomina_Basico]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Basico]  DEFAULT ((0)) FOR [Basico]
GO

-- %% [markdown]
-- # [DF_Nomina_TDO]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_TDO]  DEFAULT ((0)) FOR [TDO]
GO

-- %% [markdown]
-- # [DF_Nomina_TNO]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_TNO]  DEFAULT ((0)) FOR [TNO]
GO

-- %% [markdown]
-- # [DF_Nomina_TDF]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_TDF]  DEFAULT ((0)) FOR [TDF]
GO

-- %% [markdown]
-- # [DF_Nomina_TNF]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_TNF]  DEFAULT ((0)) FOR [TNF]
GO

-- %% [markdown]
-- # [DF_Nomina_TRN]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_TRN]  DEFAULT ((0)) FOR [TRN]
GO

-- %% [markdown]
-- # [DF_Nomina_Auxilio]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Auxilio]  DEFAULT ((0)) FOR [Auxilio]
GO

-- %% [markdown]
-- # [DF_Nomina_TDevengado]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_TDevengado]  DEFAULT ((0)) FOR [TDevengado]
GO

-- %% [markdown]
-- # [DF_Nomina_Aportesalud]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Aportesalud]  DEFAULT ((0)) FOR [Aportesalud]
GO

-- %% [markdown]
-- # [DF_Nomina_Aportepension]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Aportepension]  DEFAULT ((0)) FOR [Aportepension]
GO

-- %% [markdown]
-- # [DF_Nomina_FondoSP]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_FondoSP]  DEFAULT ((0)) FOR [FondoSP]
GO

-- %% [markdown]
-- # [DF_Nomina_Retefuente]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Retefuente]  DEFAULT ((0)) FOR [Retefuente]
GO

-- %% [markdown]
-- # [DF_Nomina_TDeducido]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_TDeducido]  DEFAULT ((0)) FOR [TDeducido]
GO

-- %% [markdown]
-- # [DF_Nomina_Netopagado]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Netopagado]  DEFAULT ((0)) FOR [Netopagado]
GO

-- %% [markdown]
-- # [DF_Nomina_ProCesantia]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_ProCesantia]  DEFAULT ((0)) FOR [ProCesantia]
GO

-- %% [markdown]
-- # [DF_Nomina_ProInteres]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_ProInteres]  DEFAULT ((0)) FOR [ProInteres]
GO

-- %% [markdown]
-- # [DF_Nomina_ProPrima]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_ProPrima]  DEFAULT ((0)) FOR [ProPrima]
GO

-- %% [markdown]
-- # [DF_Nomina_ProVacaciones]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_ProVacaciones]  DEFAULT ((0)) FOR [ProVacaciones]
GO

-- %% [markdown]
-- # [DF_Nomina_ProSalud]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_ProSalud]  DEFAULT ((0)) FOR [ProSalud]
GO

-- %% [markdown]
-- # [DF_Nomina_ProPension]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_ProPension]  DEFAULT ((0)) FOR [ProPension]
GO

-- %% [markdown]
-- # [DF_Nomina_ProCaja]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_ProCaja]  DEFAULT ((0)) FOR [ProCaja]
GO

-- %% [markdown]
-- # [DF_Nomina_ProFamiliar]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_ProFamiliar]  DEFAULT ((0)) FOR [ProFamiliar]
GO

-- %% [markdown]
-- # [DF_Nomina_ProSena]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_ProSena]  DEFAULT ((0)) FOR [ProSena]
GO

-- %% [markdown]
-- # [DF_Nomina_ProRiesgos]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_ProRiesgos]  DEFAULT ((0)) FOR [ProRiesgos]
GO

-- %% [markdown]
-- # [DF_Nomina_ProParafiscales]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_ProParafiscales]  DEFAULT ((0)) FOR [ProParafiscales]
GO

-- %% [markdown]
-- # [DF_Nomina_Horas]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Horas]  DEFAULT ((0)) FOR [Horas]
GO

-- %% [markdown]
-- # [DF_Nomina_Fproceso]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Nomina_Extraordinaria]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Extraordinaria]  DEFAULT ((0)) FOR [Extraordinaria]
GO

-- %% [markdown]
-- # [DF_Nomina_Otrosdescuentos]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Otrosdescuentos]  DEFAULT ((0)) FOR [Otrosdescuentos]
GO

-- %% [markdown]
-- # [DF_Nomina_Otra]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Otra]  DEFAULT ((0)) FOR [Otra]
GO

-- %% [markdown]
-- # [DF_Nomina_Situacion]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Situacion]  DEFAULT (N'CAUSAR CXP') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Nomina_Incapacidad]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Incapacidad]  DEFAULT ((0)) FOR [Incapacidad]
GO

-- %% [markdown]
-- # [DF_Nomina_diasincapacidad]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_diasincapacidad]  DEFAULT ((0)) FOR [diasincapacidad]
GO

-- %% [markdown]
-- # [DF_Nomina_Estado]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Nomina_Us]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_Nomina_Diastrans]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Diastrans]  DEFAULT ((0)) FOR [Diastrans]
GO

-- %% [markdown]
-- # [DF_Nomina_Diasvaca]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Diasvaca]  DEFAULT ((0)) FOR [Diasvaca]
GO

-- %% [markdown]
-- # [DF_Nomina_Vaca]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Vaca]  DEFAULT ((0)) FOR [Vaca]
GO

-- %% [markdown]
-- # [DF_Nomina_HEF]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_HEF]  DEFAULT ((0)) FOR [HEF]
GO

-- %% [markdown]
-- # [DF_Nomina_TF]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_TF]  DEFAULT ((0)) FOR [TF]
GO

-- %% [markdown]
-- # [DF_Nomina_BaseSalud_1]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_BaseSalud_1]  DEFAULT ((0)) FOR [BaseSalud]
GO

-- %% [markdown]
-- # [DF_Nomina_BasePension_1]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_BasePension_1]  DEFAULT ((0)) FOR [BasePension]
GO

-- %% [markdown]
-- # [DF_Nomina_BaseCaja_1]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_BaseCaja_1]  DEFAULT ((0)) FOR [BaseCaja]
GO

-- %% [markdown]
-- # [DF_Nomina_BaseParafiscal_1]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_BaseParafiscal_1]  DEFAULT ((0)) FOR [BaseParafiscal]
GO

-- %% [markdown]
-- # [DF_Nomina_BaseRiesgos_1]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_BaseRiesgos_1]  DEFAULT ((0)) FOR [BaseRiesgos]
GO

-- %% [markdown]
-- # [DF_Nomina_ApvolPension]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_ApvolPension]  DEFAULT ((0)) FOR [ApvolPension]
GO

-- %% [markdown]
-- # [DF_Nomina_ApvolSalud]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_ApvolSalud]  DEFAULT ((0)) FOR [ApvolSalud]
GO

-- %% [markdown]
-- # [DF_Nomina_TRM]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_TRM]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Nomina_HRNDF]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_HRNDF]  DEFAULT ((0)) FOR [HRNDF]
GO

-- %% [markdown]
-- # [DF_Nomina_ValorHRNDF]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_ValorHRNDF]  DEFAULT ((0)) FOR [THRNDF]
GO

-- %% [markdown]
-- # [DF_Nomina_StatusDian]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_StatusDian]  DEFAULT ((0)) FOR [StatusDian]
GO

-- %% [markdown]
-- # [DF_Nomina_StatusCliente]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_StatusCliente]  DEFAULT ((0)) FOR [StatusCliente]
GO

-- %% [markdown]
-- # [DF_Nomina_LicenciaNR]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_LicenciaNR]  DEFAULT ((0)) FOR [LicenciaNR]
GO

-- %% [markdown]
-- # [DF_Nomina_Diasalud]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Diasalud]  DEFAULT ((0)) FOR [Diasalud]
GO

-- %% [markdown]
-- # [DF_Nomina_Diapension]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Diapension]  DEFAULT ((0)) FOR [Diapension]
GO

-- %% [markdown]
-- # [DF_Nomina_LicenciaRem]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_LicenciaRem]  DEFAULT ((0)) FOR [LicenciaRem]
GO

-- %% [markdown]
-- # [DF_Nomina_DiasPrimas_1]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_DiasPrimas_1]  DEFAULT ((0)) FOR [DiasPrimas]
GO

-- %% [markdown]
-- # [DF_Nomina_Primas_1]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Primas_1]  DEFAULT ((0)) FOR [Primas]
GO

-- %% [markdown]
-- # [DF_Nomina_PagoCesantias_1]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_PagoCesantias_1]  DEFAULT ((0)) FOR [PagoCesantias]
GO

-- %% [markdown]
-- # [DF_Nomina_PorcentajeCesantias_1]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_PorcentajeCesantias_1]  DEFAULT ((0)) FOR [PorcentajeCesantias]
GO

-- %% [markdown]
-- # [DF_Nomina_PagoInteresesCesantias_1]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_PagoInteresesCesantias_1]  DEFAULT ((0)) FOR [PagoInteresesCesantias]
GO

-- %% [markdown]
-- # [DF_Nomina_Indemnizacion_1]

-- %%
ALTER TABLE [dbo].[Nomina] ADD  CONSTRAINT [DF_Nomina_Indemnizacion_1]  DEFAULT ((0)) FOR [Indemnizacion]
GO

-- %% [markdown]
-- # [DF_NominaCandidatos_Edad]

-- %%
ALTER TABLE [dbo].[NominaCandidatos] ADD  CONSTRAINT [DF_NominaCandidatos_Edad]  DEFAULT ((0)) FOR [Edad]
GO

-- %% [markdown]
-- # [DF_NominaCandidatos_Estado]

-- %%
ALTER TABLE [dbo].[NominaCandidatos] ADD  CONSTRAINT [DF_NominaCandidatos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NominaCargo_Salario]

-- %%
ALTER TABLE [dbo].[NominaCargo] ADD  CONSTRAINT [DF_NominaCargo_Salario]  DEFAULT ((0)) FOR [Salario]
GO

-- %% [markdown]
-- # [DF_NominaCargo_Estado]

-- %%
ALTER TABLE [dbo].[NominaCargo] ADD  CONSTRAINT [DF_NominaCargo_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NominaCargodes_Estado]

-- %%
ALTER TABLE [dbo].[NominaCargodes] ADD  CONSTRAINT [DF_NominaCargodes_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NominaCargosub_Pondera]

-- %%
ALTER TABLE [dbo].[NominaCargosub] ADD  CONSTRAINT [DF_NominaCargosub_Pondera]  DEFAULT ((0)) FOR [Pondera]
GO

-- %% [markdown]
-- # [DF_NominaCargoTipos_Estado]

-- %%
ALTER TABLE [dbo].[NominaCargoTipos] ADD  CONSTRAINT [DF_NominaCargoTipos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Nominacompensacion_Neto]

-- %%
ALTER TABLE [dbo].[Nominacompensacion] ADD  CONSTRAINT [DF_Nominacompensacion_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Nominadescuentos_Neto]

-- %%
ALTER TABLE [dbo].[Nominadescuentos] ADD  CONSTRAINT [DF_Nominadescuentos_Neto]  DEFAULT (0) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Nominadevengos_Neto]

-- %%
ALTER TABLE [dbo].[Nominadevengos] ADD  CONSTRAINT [DF_Nominadevengos_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_NominaDian_Idparnomina]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Idparnomina]  DEFAULT ((1)) FOR [Idparnomina]
GO

-- %% [markdown]
-- # [DF_NominaDian_Documento]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Documento]  DEFAULT (N'NE') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_NominaDian_Fecha]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_NominaDian_Días trabajados]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Días trabajados]  DEFAULT ((0)) FOR [Días trabajados]
GO

-- %% [markdown]
-- # [DF_NominaDian_HEDO]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_HEDO]  DEFAULT ((0)) FOR [HEDO]
GO

-- %% [markdown]
-- # [DF_NominaDian_HENO]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_HENO]  DEFAULT ((0)) FOR [HENO]
GO

-- %% [markdown]
-- # [DF_NominaDian_HEDF]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_HEDF]  DEFAULT ((0)) FOR [HEDF]
GO

-- %% [markdown]
-- # [DF_NominaDian_HENF]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_HENF]  DEFAULT ((0)) FOR [HENF]
GO

-- %% [markdown]
-- # [DF_NominaDian_RN]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_RN]  DEFAULT ((0)) FOR [RN]
GO

-- %% [markdown]
-- # [DF_NominaDian_Otrosdevengados]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Otrosdevengados]  DEFAULT ((0)) FOR [Otrosdevengados]
GO

-- %% [markdown]
-- # [DF_NominaDian_Otrasdeducciones]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Otrasdeducciones]  DEFAULT ((0)) FOR [Otrasdeducciones]
GO

-- %% [markdown]
-- # [DF_NominaDian_Basico]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Basico]  DEFAULT ((0)) FOR [Basico]
GO

-- %% [markdown]
-- # [DF_NominaDian_TDO]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_TDO]  DEFAULT ((0)) FOR [TDO]
GO

-- %% [markdown]
-- # [DF_NominaDian_TNO]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_TNO]  DEFAULT ((0)) FOR [TNO]
GO

-- %% [markdown]
-- # [DF_NominaDian_TDF]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_TDF]  DEFAULT ((0)) FOR [TDF]
GO

-- %% [markdown]
-- # [DF_NominaDian_TNF]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_TNF]  DEFAULT ((0)) FOR [TNF]
GO

-- %% [markdown]
-- # [DF_NominaDian_TRN]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_TRN]  DEFAULT ((0)) FOR [TRN]
GO

-- %% [markdown]
-- # [DF_NominaDian_Auxilio]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Auxilio]  DEFAULT ((0)) FOR [Auxilio]
GO

-- %% [markdown]
-- # [DF_NominaDian_TDevengado]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_TDevengado]  DEFAULT ((0)) FOR [TDevengado]
GO

-- %% [markdown]
-- # [DF_NominaDian_Aportesalud]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Aportesalud]  DEFAULT ((0)) FOR [Aportesalud]
GO

-- %% [markdown]
-- # [DF_NominaDian_Aportepension]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Aportepension]  DEFAULT ((0)) FOR [Aportepension]
GO

-- %% [markdown]
-- # [DF_NominaDian_FondoSP]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_FondoSP]  DEFAULT ((0)) FOR [FondoSP]
GO

-- %% [markdown]
-- # [DF_NominaDian_Retefuente]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Retefuente]  DEFAULT ((0)) FOR [Retefuente]
GO

-- %% [markdown]
-- # [DF_NominaDian_TDeducido]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_TDeducido]  DEFAULT ((0)) FOR [TDeducido]
GO

-- %% [markdown]
-- # [DF_NominaDian_Netopagado]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Netopagado]  DEFAULT ((0)) FOR [Netopagado]
GO

-- %% [markdown]
-- # [DF_NominaDian_ProCesantia]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_ProCesantia]  DEFAULT ((0)) FOR [ProCesantia]
GO

-- %% [markdown]
-- # [DF_NominaDian_ProInteres]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_ProInteres]  DEFAULT ((0)) FOR [ProInteres]
GO

-- %% [markdown]
-- # [DF_NominaDian_ProPrima]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_ProPrima]  DEFAULT ((0)) FOR [ProPrima]
GO

-- %% [markdown]
-- # [DF_NominaDian_ProVacaciones]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_ProVacaciones]  DEFAULT ((0)) FOR [ProVacaciones]
GO

-- %% [markdown]
-- # [DF_NominaDian_ProSalud]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_ProSalud]  DEFAULT ((0)) FOR [ProSalud]
GO

-- %% [markdown]
-- # [DF_NominaDian_ProPension]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_ProPension]  DEFAULT ((0)) FOR [ProPension]
GO

-- %% [markdown]
-- # [DF_NominaDian_ProCaja]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_ProCaja]  DEFAULT ((0)) FOR [ProCaja]
GO

-- %% [markdown]
-- # [DF_NominaDian_ProFamiliar]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_ProFamiliar]  DEFAULT ((0)) FOR [ProFamiliar]
GO

-- %% [markdown]
-- # [DF_NominaDian_ProSena]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_ProSena]  DEFAULT ((0)) FOR [ProSena]
GO

-- %% [markdown]
-- # [DF_NominaDian_ProRiesgos]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_ProRiesgos]  DEFAULT ((0)) FOR [ProRiesgos]
GO

-- %% [markdown]
-- # [DF_NominaDian_ProParafiscales]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_ProParafiscales]  DEFAULT ((0)) FOR [ProParafiscales]
GO

-- %% [markdown]
-- # [DF_NominaDian_Horas]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Horas]  DEFAULT ((0)) FOR [Horas]
GO

-- %% [markdown]
-- # [DF_NominaDian_Fproceso]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_NominaDian_Extraordinaria]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Extraordinaria]  DEFAULT ((0)) FOR [Extraordinaria]
GO

-- %% [markdown]
-- # [DF_NominaDian_Otrosdescuentos]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Otrosdescuentos]  DEFAULT ((0)) FOR [Otrosdescuentos]
GO

-- %% [markdown]
-- # [DF_NominaDian_Otra]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Otra]  DEFAULT ((0)) FOR [Otra]
GO

-- %% [markdown]
-- # [DF_NominaDian_Situacion]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Situacion]  DEFAULT (N'CAUSAR CXP') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_NominaDian_Incapacidad]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Incapacidad]  DEFAULT ((0)) FOR [Incapacidad]
GO

-- %% [markdown]
-- # [DF_NominaDian_diasincapacidad]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_diasincapacidad]  DEFAULT ((0)) FOR [diasincapacidad]
GO

-- %% [markdown]
-- # [DF_NominaDian_Estado]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NominaDian_Us]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_NominaDian_Diastrans]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Diastrans]  DEFAULT ((0)) FOR [Diastrans]
GO

-- %% [markdown]
-- # [DF_NominaDian_Diasvaca]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Diasvaca]  DEFAULT ((0)) FOR [Diasvaca]
GO

-- %% [markdown]
-- # [DF_NominaDian_Vaca]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Vaca]  DEFAULT ((0)) FOR [Vaca]
GO

-- %% [markdown]
-- # [DF_NominaDian_HEF]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_HEF]  DEFAULT ((0)) FOR [HEF]
GO

-- %% [markdown]
-- # [DF_NominaDian_TF]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_TF]  DEFAULT ((0)) FOR [TF]
GO

-- %% [markdown]
-- # [DF_NominaDian_BaseSalud]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_BaseSalud]  DEFAULT ((0)) FOR [BaseSalud]
GO

-- %% [markdown]
-- # [DF_NominaDian_BasePension]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_BasePension]  DEFAULT ((0)) FOR [BasePension]
GO

-- %% [markdown]
-- # [DF_NominaDian_BaseCaja]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_BaseCaja]  DEFAULT ((0)) FOR [BaseCaja]
GO

-- %% [markdown]
-- # [DF_NominaDian_BaseParafiscal]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_BaseParafiscal]  DEFAULT ((0)) FOR [BaseParafiscal]
GO

-- %% [markdown]
-- # [DF_NominaDian_BaseRiesgos]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_BaseRiesgos]  DEFAULT ((0)) FOR [BaseRiesgos]
GO

-- %% [markdown]
-- # [DF_NominaDian_ApvolPension]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_ApvolPension]  DEFAULT ((0)) FOR [ApvolPension]
GO

-- %% [markdown]
-- # [DF_NominaDian_ApvolSalud]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_ApvolSalud]  DEFAULT ((0)) FOR [ApvolSalud]
GO

-- %% [markdown]
-- # [DF_NominaDian_TRM]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_TRM]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_NominaDian_HRNDF]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_HRNDF]  DEFAULT ((0)) FOR [HRNDF]
GO

-- %% [markdown]
-- # [DF_NominaDian_THRNDF]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_THRNDF]  DEFAULT ((0)) FOR [THRNDF]
GO

-- %% [markdown]
-- # [DF_NominaDian_StatusDian]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_StatusDian]  DEFAULT ((0)) FOR [StatusDian]
GO

-- %% [markdown]
-- # [DF_NominaDian_StatusCliente]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_StatusCliente]  DEFAULT ((0)) FOR [StatusCliente]
GO

-- %% [markdown]
-- # [DF_NominaDian_LicenciaNR]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_LicenciaNR]  DEFAULT ((0)) FOR [LicenciaNR]
GO

-- %% [markdown]
-- # [DF_NominaDian_Diasalud]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Diasalud]  DEFAULT ((0)) FOR [Diasalud]
GO

-- %% [markdown]
-- # [DF_NominaDian_Diapension]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Diapension]  DEFAULT ((0)) FOR [Diapension]
GO

-- %% [markdown]
-- # [DF_NominaDian_LicenciaRem]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_LicenciaRem]  DEFAULT ((0)) FOR [LicenciaRem]
GO

-- %% [markdown]
-- # [DF_NominaDian_DiasPrimas_1]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_DiasPrimas_1]  DEFAULT ((0)) FOR [DiasPrimas]
GO

-- %% [markdown]
-- # [DF_NominaDian_Primas_1]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Primas_1]  DEFAULT ((0)) FOR [Primas]
GO

-- %% [markdown]
-- # [DF_NominaDian_PagoCesantias_1]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_PagoCesantias_1]  DEFAULT ((0)) FOR [PagoCesantias]
GO

-- %% [markdown]
-- # [DF_NominaDian_PorcentajeCesantias_1]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_PorcentajeCesantias_1]  DEFAULT ((0)) FOR [PorcentajeCesantias]
GO

-- %% [markdown]
-- # [DF_NominaDian_PagoInteresesCesantias_1]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_PagoInteresesCesantias_1]  DEFAULT ((0)) FOR [PagoInteresesCesantias]
GO

-- %% [markdown]
-- # [DF_NominaDian_Indemnizacion_1]

-- %%
ALTER TABLE [dbo].[NominaDian] ADD  CONSTRAINT [DF_NominaDian_Indemnizacion_1]  DEFAULT ((0)) FOR [Indemnizacion]
GO

-- %% [markdown]
-- # [DF_NominaDO_Horas]

-- %%
ALTER TABLE [dbo].[NominaDO] ADD  CONSTRAINT [DF_NominaDO_Horas]  DEFAULT ((0)) FOR [Horas]
GO

-- %% [markdown]
-- # [DF_NominaDO_Neto]

-- %%
ALTER TABLE [dbo].[NominaDO] ADD  CONSTRAINT [DF_NominaDO_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_NominaElimina_FechaGen]

-- %%
ALTER TABLE [dbo].[NominaElimina] ADD  CONSTRAINT [DF_NominaElimina_FechaGen]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [FechaGen]
GO

-- %% [markdown]
-- # [DF_NominaElimina_HoraGen]

-- %%
ALTER TABLE [dbo].[NominaElimina] ADD  CONSTRAINT [DF_NominaElimina_HoraGen]  DEFAULT (getdate()) FOR [HoraGen]
GO

-- %% [markdown]
-- # [DF_NominaElimina_Estado]

-- %%
ALTER TABLE [dbo].[NominaElimina] ADD  CONSTRAINT [DF_NominaElimina_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NominaElimina_StatusDian]

-- %%
ALTER TABLE [dbo].[NominaElimina] ADD  CONSTRAINT [DF_NominaElimina_StatusDian]  DEFAULT ((0)) FOR [StatusDian]
GO

-- %% [markdown]
-- # [DF_NominaElimina_StatusCliente]

-- %%
ALTER TABLE [dbo].[NominaElimina] ADD  CONSTRAINT [DF_NominaElimina_StatusCliente]  DEFAULT ((0)) FOR [StatusCliente]
GO

-- %% [markdown]
-- # [DF_NominaIncapacidad_Estado]

-- %%
ALTER TABLE [dbo].[NominaIncapacidad] ADD  CONSTRAINT [DF_NominaIncapacidad_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_Idparnomina]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_Idparnomina]  DEFAULT ((1)) FOR [Idparnomina]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_Fecha]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_Documento]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_Documento]  DEFAULT (N'NVN') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_Estado]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_HEDO]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_HEDO]  DEFAULT ((0)) FOR [HEDO]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_HENO]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_HENO]  DEFAULT ((0)) FOR [HENO]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_HEDF]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_HEDF]  DEFAULT ((0)) FOR [HEDF]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_HENF]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_HENF]  DEFAULT ((0)) FOR [HENF]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_HEF]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_HEF]  DEFAULT ((0)) FOR [HEF]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_RN]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_RN]  DEFAULT ((0)) FOR [RN]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_TDO]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_TDO]  DEFAULT ((0)) FOR [TDO]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_TNO]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_TNO]  DEFAULT ((0)) FOR [TNO]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_TDF]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_TDF]  DEFAULT ((0)) FOR [TDF]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_TNF]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_TNF]  DEFAULT ((0)) FOR [TNF]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_TF]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_TF]  DEFAULT ((0)) FOR [TF]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_TRN]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_TRN]  DEFAULT ((0)) FOR [TRN]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_Otrosdevengados]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_Otrosdevengados]  DEFAULT ((0)) FOR [Otrosdevengados]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_Incapacidad]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_Incapacidad]  DEFAULT ((0)) FOR [Incapacidad]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_diasincapacidad]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_diasincapacidad]  DEFAULT ((0)) FOR [diasincapacidad]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_Ausencias]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_Ausencias]  DEFAULT ((0)) FOR [Ausencias]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_diasausencias]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_diasausencias]  DEFAULT ((0)) FOR [diasausencias]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_IncapacidadBase]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_IncapacidadBase]  DEFAULT ((0)) FOR [IncapacidadBase]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_Extra]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_Extra]  DEFAULT ((0)) FOR [Extra]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_HRNDF]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_HRNDF]  DEFAULT ((0)) FOR [HRNDF]
GO

-- %% [markdown]
-- # [DF_NominaNovedades_ValorHRNDF]

-- %%
ALTER TABLE [dbo].[NominaNovedades] ADD  CONSTRAINT [DF_NominaNovedades_ValorHRNDF]  DEFAULT ((0)) FOR [THRNDF]
GO

-- %% [markdown]
-- # [DF_Nominapar_Idparnomina]

-- %%
ALTER TABLE [dbo].[Nominapar] ADD  CONSTRAINT [DF_Nominapar_Idparnomina]  DEFAULT (1) FOR [Idparnomina]
GO

-- %% [markdown]
-- # [DF_Nominapar_Estado]

-- %%
ALTER TABLE [dbo].[Nominapar] ADD  CONSTRAINT [DF_Nominapar_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Nominapar_Festivas]

-- %%
ALTER TABLE [dbo].[Nominapar] ADD  CONSTRAINT [DF_Nominapar_Festivas]  DEFAULT ((0)) FOR [Festivas]
GO

-- %% [markdown]
-- # [DF_Nominapar_UVT]

-- %%
ALTER TABLE [dbo].[Nominapar] ADD  CONSTRAINT [DF_Nominapar_UVT]  DEFAULT ((0)) FOR [UVT]
GO

-- %% [markdown]
-- # [DF_Nominapar_RNF]

-- %%
ALTER TABLE [dbo].[Nominapar] ADD  CONSTRAINT [DF_Nominapar_RNF]  DEFAULT ((0)) FOR [RNF]
GO

-- %% [markdown]
-- # [DF_NominaPeriodo_Estado]

-- %%
ALTER TABLE [dbo].[NominaPeriodo] ADD  CONSTRAINT [DF_NominaPeriodo_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Nominaprestamos_Pago]

-- %%
ALTER TABLE [dbo].[Nominaprestamos] ADD  CONSTRAINT [DF_Nominaprestamos_Pago]  DEFAULT ((0)) FOR [Pago]
GO

-- %% [markdown]
-- # [DF_NominaProfesiones_Estado]

-- %%
ALTER TABLE [dbo].[NominaProfesiones] ADD  CONSTRAINT [DF_NominaProfesiones_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NominaPrueba_Fecha]

-- %%
ALTER TABLE [dbo].[NominaPrueba] ADD  CONSTRAINT [DF_NominaPrueba_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_NominaPrueba_Status]

-- %%
ALTER TABLE [dbo].[NominaPrueba] ADD  CONSTRAINT [DF_NominaPrueba_Status]  DEFAULT (N'NO DESCARTADO') FOR [Status]
GO

-- %% [markdown]
-- # [DF_NominaPrueba_Estado]

-- %%
ALTER TABLE [dbo].[NominaPrueba] ADD  CONSTRAINT [DF_NominaPrueba_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_NominaPruebasub_Pondera]

-- %%
ALTER TABLE [dbo].[NominaPruebasub] ADD  CONSTRAINT [DF_NominaPruebasub_Pondera]  DEFAULT ((0)) FOR [Pondera]
GO

-- %% [markdown]
-- # [DF_NominaPruebasub_Calificacion]

-- %%
ALTER TABLE [dbo].[NominaPruebasub] ADD  CONSTRAINT [DF_NominaPruebasub_Calificacion]  DEFAULT ((0)) FOR [Calificacion]
GO

-- %% [markdown]
-- # [DF_NominaPruebasub_Resultado]

-- %%
ALTER TABLE [dbo].[NominaPruebasub] ADD  CONSTRAINT [DF_NominaPruebasub_Resultado]  DEFAULT ((0)) FOR [Resultado]
GO

-- %% [markdown]
-- # [DF_NominaPruebaTipos_Estado]

-- %%
ALTER TABLE [dbo].[NominaPruebaTipos] ADD  CONSTRAINT [DF_NominaPruebaTipos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Novedadestel_Estado]

-- %%
ALTER TABLE [dbo].[Novedadestel] ADD  CONSTRAINT [DF_Novedadestel_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_OCargue_Fecha]

-- %%
ALTER TABLE [dbo].[OCargue] ADD  CONSTRAINT [DF_OCargue_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_OCargue_Estado]

-- %%
ALTER TABLE [dbo].[OCargue] ADD  CONSTRAINT [DF_OCargue_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_OCargue_Documento]

-- %%
ALTER TABLE [dbo].[OCargue] ADD  CONSTRAINT [DF_OCargue_Documento]  DEFAULT (N'OCG') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_OCarguesub_Cantidad]

-- %%
ALTER TABLE [dbo].[OCarguesub] ADD  CONSTRAINT [DF_OCarguesub_Cantidad]  DEFAULT ((1)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_OCarguesub_Kilos]

-- %%
ALTER TABLE [dbo].[OCarguesub] ADD  CONSTRAINT [DF_OCarguesub_Kilos]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_OCarguesub_Neto]

-- %%
ALTER TABLE [dbo].[OCarguesub] ADD  CONSTRAINT [DF_OCarguesub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_OCarguesub_Costo]

-- %%
ALTER TABLE [dbo].[OCarguesub] ADD  CONSTRAINT [DF_OCarguesub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_OCarguesub_Gastos]

-- %%
ALTER TABLE [dbo].[OCarguesub] ADD  CONSTRAINT [DF_OCarguesub_Gastos]  DEFAULT ((0)) FOR [Gastos]
GO

-- %% [markdown]
-- # [DF_Orden_Fecha]

-- %%
ALTER TABLE [dbo].[Orden] ADD  CONSTRAINT [DF_Orden_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Orden_Fproceso]

-- %%
ALTER TABLE [dbo].[Orden] ADD  CONSTRAINT [DF_Orden_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Orden_Documento]

-- %%
ALTER TABLE [dbo].[Orden] ADD  CONSTRAINT [DF_Orden_Documento]  DEFAULT (N'OC') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Orden_TRM]

-- %%
ALTER TABLE [dbo].[Orden] ADD  CONSTRAINT [DF_Orden_TRM]  DEFAULT (1) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Orden_Estado]

-- %%
ALTER TABLE [dbo].[Orden] ADD  CONSTRAINT [DF_Orden_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Orden_Situacion]

-- %%
ALTER TABLE [dbo].[Orden] ADD  CONSTRAINT [DF_Orden_Situacion]  DEFAULT (N'PENDIENTE') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Ordencompra_Fecha]

-- %%
ALTER TABLE [dbo].[Ordencompra] ADD  CONSTRAINT [DF_Ordencompra_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Ordencompra_Fproceso]

-- %%
ALTER TABLE [dbo].[Ordencompra] ADD  CONSTRAINT [DF_Ordencompra_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Ordencompra_Documento]

-- %%
ALTER TABLE [dbo].[Ordencompra] ADD  CONSTRAINT [DF_Ordencompra_Documento]  DEFAULT (N'TM') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Ordencompra_Estado]

-- %%
ALTER TABLE [dbo].[Ordencompra] ADD  CONSTRAINT [DF_Ordencompra_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Ordencompra_Descarga]

-- %%
ALTER TABLE [dbo].[Ordencompra] ADD  CONSTRAINT [DF_Ordencompra_Descarga]  DEFAULT (N'CARGAR') FOR [Descarga]
GO

-- %% [markdown]
-- # [DF_Ordencomprasub_Cantidad]

-- %%
ALTER TABLE [dbo].[Ordencomprasub] ADD  CONSTRAINT [DF_Ordencomprasub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Ordencomprasub_Descuento]

-- %%
ALTER TABLE [dbo].[Ordencomprasub] ADD  CONSTRAINT [DF_Ordencomprasub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_Ordencomprasub_Precio]

-- %%
ALTER TABLE [dbo].[Ordencomprasub] ADD  CONSTRAINT [DF_Ordencomprasub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Ordencomprasub_PIva]

-- %%
ALTER TABLE [dbo].[Ordencomprasub] ADD  CONSTRAINT [DF_Ordencomprasub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_Ordencomprasub_Precio total]

-- %%
ALTER TABLE [dbo].[Ordencomprasub] ADD  CONSTRAINT [DF_Ordencomprasub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_Ordencomprasub_Neto]

-- %%
ALTER TABLE [dbo].[Ordencomprasub] ADD  CONSTRAINT [DF_Ordencomprasub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Ordencomprasub_Peso]

-- %%
ALTER TABLE [dbo].[Ordencomprasub] ADD  CONSTRAINT [DF_Ordencomprasub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Ordencomprasub_Subtotal]

-- %%
ALTER TABLE [dbo].[Ordencomprasub] ADD  CONSTRAINT [DF_Ordencomprasub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Ordencomprasub_Controlfinal]

-- %%
ALTER TABLE [dbo].[Ordencomprasub] ADD  CONSTRAINT [DF_Ordencomprasub_Controlfinal]  DEFAULT ((0)) FOR [Controlfinal]
GO

-- %% [markdown]
-- # [DF_Ordensub_Cantidad]

-- %%
ALTER TABLE [dbo].[Ordensub] ADD  CONSTRAINT [DF_Ordensub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Ordensub_Descuento]

-- %%
ALTER TABLE [dbo].[Ordensub] ADD  CONSTRAINT [DF_Ordensub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_Ordensub_Precio]

-- %%
ALTER TABLE [dbo].[Ordensub] ADD  CONSTRAINT [DF_Ordensub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Ordensub_PIva]

-- %%
ALTER TABLE [dbo].[Ordensub] ADD  CONSTRAINT [DF_Ordensub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_Ordensub_Precio total]

-- %%
ALTER TABLE [dbo].[Ordensub] ADD  CONSTRAINT [DF_Ordensub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_Ordensub_Neto]

-- %%
ALTER TABLE [dbo].[Ordensub] ADD  CONSTRAINT [DF_Ordensub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Ordensub_Peso]

-- %%
ALTER TABLE [dbo].[Ordensub] ADD  CONSTRAINT [DF_Ordensub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Ordensub_Subtotal]

-- %%
ALTER TABLE [dbo].[Ordensub] ADD  CONSTRAINT [DF_Ordensub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Ordensub_CUDol]

-- %%
ALTER TABLE [dbo].[Ordensub] ADD  CONSTRAINT [DF_Ordensub_CUDol]  DEFAULT ((0)) FOR [CUDol]
GO

-- %% [markdown]
-- # [DF_Ordensub_Dolares]

-- %%
ALTER TABLE [dbo].[Ordensub] ADD  CONSTRAINT [DF_Ordensub_Dolares]  DEFAULT ((0)) FOR [Dolares]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Estado]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Fechafac]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Fechafac]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fechafac]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Tipo]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Tipo]  DEFAULT (N'NACIONAL') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Valortransporte]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Valortransporte]  DEFAULT ((0)) FOR [Valortransporte]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Kilometraje]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Kilometraje]  DEFAULT ((0)) FOR [Kilometraje]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Dias]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Documento]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Documento]  DEFAULT (N'DO') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Abono]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Abono]  DEFAULT ((0)) FOR [Abono]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Saldo]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Saldo]  DEFAULT ((0)) FOR [Saldo]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Bloque]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Bloque]  DEFAULT ((0)) FOR [Bloque]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_PRetencion]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_PRetencion]  DEFAULT ((0)) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_PReteIca]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Reteica]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Reteica]  DEFAULT ((0)) FOR [Reteica]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_PReteIva]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_ReteIva]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_ReteIva]  DEFAULT ((0)) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Fproceso]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_PDescuento]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_PDescuento]  DEFAULT ((0)) FOR [PDescuento]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Situacion]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Situacion]  DEFAULT (N'NO REALIZADO') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_TRM]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_TRM]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_PFlete]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_PFlete]  DEFAULT ((0)) FOR [PFlete]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Terminal]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Anticipos]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Anticipos]  DEFAULT ((0)) FOR [Anticipos]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Rendir]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Rendir]  DEFAULT ((0)) FOR [Rendir]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Declarado]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Declarado]  DEFAULT ((0)) FOR [Declarado]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Doc]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Doc]  DEFAULT (N'D.O.') FOR [Doc]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Procesar]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Procesar]  DEFAULT (N'SI') FOR [Procesar]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_RMinima]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_RMinima]  DEFAULT ((0)) FOR [RMinima]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Descarga]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Descarga]  DEFAULT (N'DESCARGAR') FOR [Descarga]
GO

-- %% [markdown]
-- # [DF_OrdenTrabajo_Estadoembarque]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo] ADD  CONSTRAINT [DF_OrdenTrabajo_Estadoembarque]  DEFAULT ((0)) FOR [Estadoembarque]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Cantidad]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Cantidad]  DEFAULT ((1)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Descuento]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Precio]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_PIva]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Precio total]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Neto]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Subtotal]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Exentos]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Exentos]  DEFAULT ((0)) FOR [Exentos]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_DesExentos]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_DesExentos]  DEFAULT ((0)) FOR [DesExentos]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_DesGravados]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_DesGravados]  DEFAULT ((0)) FOR [DesGravados]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Tipo]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Tipo]  DEFAULT (N'NO REALIZADO') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Dolares]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Dolares]  DEFAULT ((0)) FOR [Dolares]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Fecha]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Peso]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_VPropina]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_VPropina]  DEFAULT ((0)) FOR [VPropina]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Costo]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Gastos]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Gastos]  DEFAULT ((0)) FOR [Gastos]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Declarado]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Declarado]  DEFAULT ((0)) FOR [Declarado]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Porcentaje]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Porcentaje]  DEFAULT ((0)) FOR [Porcentaje]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Segurito]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Segurito]  DEFAULT ((0)) FOR [Segurito]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Existencia]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Existencia]  DEFAULT ((0)) FOR [Existencia]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_EstOC]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_EstOC]  DEFAULT ((0)) FOR [EstOC]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_CTotal]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_CTotal]  DEFAULT ((0)) FOR [CTotal]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Moneda]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Moneda]  DEFAULT (N'COP') FOR [Moneda]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_TRMS]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_TRMS]  DEFAULT ((1)) FOR [TRMS]
GO

-- %% [markdown]
-- # [DF_Ordentrabajosub_Estadosub]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub] ADD  CONSTRAINT [DF_Ordentrabajosub_Estadosub]  DEFAULT ((0)) FOR [Estadosub]
GO

-- %% [markdown]
-- # [DF_Pacientes_Situacion]

-- %%
ALTER TABLE [dbo].[Pacientes] ADD  CONSTRAINT [DF_Pacientes_Situacion]  DEFAULT (N'ACTIVADO') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Pacientes_Estado]

-- %%
ALTER TABLE [dbo].[Pacientes] ADD  CONSTRAINT [DF_Pacientes_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_PagoCartera_Neto]

-- %%
ALTER TABLE [dbo].[PagoCartera] ADD  CONSTRAINT [DF_PagoCartera_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_PagoCartera_Us]

-- %%
ALTER TABLE [dbo].[PagoCartera] ADD  CONSTRAINT [DF_PagoCartera_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_PagoCartera_Tipo]

-- %%
ALTER TABLE [dbo].[PagoCartera] ADD  CONSTRAINT [DF_PagoCartera_Tipo]  DEFAULT (N'Pago Masivo') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_PagoCartera_Docu]

-- %%
ALTER TABLE [dbo].[PagoCartera] ADD  CONSTRAINT [DF_PagoCartera_Docu]  DEFAULT (N'FV') FOR [Docu]
GO

-- %% [markdown]
-- # [DF_PagoNomina_Neto]

-- %%
ALTER TABLE [dbo].[PagoNomina] ADD  CONSTRAINT [DF_PagoNomina_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_PagoNomina_Us]

-- %%
ALTER TABLE [dbo].[PagoNomina] ADD  CONSTRAINT [DF_PagoNomina_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_PagoProveedores_Docu]

-- %%
ALTER TABLE [dbo].[PagoProveedores] ADD  CONSTRAINT [DF_PagoProveedores_Docu]  DEFAULT (N'FP') FOR [Docu]
GO

-- %% [markdown]
-- # [DF_PagoProveedores_Neto]

-- %%
ALTER TABLE [dbo].[PagoProveedores] ADD  CONSTRAINT [DF_PagoProveedores_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_PagoProveedores_Tipo]

-- %%
ALTER TABLE [dbo].[PagoProveedores] ADD  CONSTRAINT [DF_PagoProveedores_Tipo]  DEFAULT (N'Pago Masivo') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_PagoProveedores_Us]

-- %%
ALTER TABLE [dbo].[PagoProveedores] ADD  CONSTRAINT [DF_PagoProveedores_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_Pagos_Estado]

-- %%
ALTER TABLE [dbo].[Pagos] ADD  CONSTRAINT [DF_Pagos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Paises_Estado]

-- %%
ALTER TABLE [dbo].[Paises] ADD  CONSTRAINT [DF_Paises_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_ParametrosCausaciones_Débitos]

-- %%
ALTER TABLE [dbo].[ParametrosCausaciones] ADD  CONSTRAINT [DF_ParametrosCausaciones_Débitos]  DEFAULT ((0)) FOR [Débitos]
GO

-- %% [markdown]
-- # [DF_ParametrosCausaciones_Créditos]

-- %%
ALTER TABLE [dbo].[ParametrosCausaciones] ADD  CONSTRAINT [DF_ParametrosCausaciones_Créditos]  DEFAULT ((0)) FOR [Créditos]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_Situacion]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_Situacion]  DEFAULT (N'ACTIVADO') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_Imputacion]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_Imputacion]  DEFAULT (N'DEBITO') FOR [Imputacion]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_ImputacionIva]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_ImputacionIva]  DEFAULT (N'CREDITO') FOR [ImputacionIva]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_TipoRete]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_TipoRete]  DEFAULT ((2302)) FOR [TipoRete]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_ImputacionIngreso]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_ImputacionIngreso]  DEFAULT (N'CREDITO') FOR [ImputacionIngreso]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_ImputacionRetencion]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_ImputacionRetencion]  DEFAULT (N'CREDITO') FOR [ImputacionRetencion]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_ImputacionRRetenida]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_ImputacionRRetenida]  DEFAULT (N'DEBITO') FOR [ImputacionRRetenida]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_TipoReteRetenida]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_TipoReteRetenida]  DEFAULT ((1302)) FOR [TipoReteRetenida]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_ImputacionIvaCompras]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_ImputacionIvaCompras]  DEFAULT (N'DEBITO') FOR [ImputacionIvaCompras]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_ImputacionDescuento]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_ImputacionDescuento]  DEFAULT (N'DEBITO') FOR [ImputacionDescuento]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_ImputacionDevolucion]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_ImputacionDevolucion]  DEFAULT (N'DEBITO') FOR [ImputacionDevolucion]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_Estado]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_ImputacionIvaDevolucion]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_ImputacionIvaDevolucion]  DEFAULT (N'DEBITO') FOR [ImputacionIvaDevolucion]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_ImputacionIvateorico]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_ImputacionIvateorico]  DEFAULT (N'CREDITO') FOR [ImputacionIvateorico]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_ImputacionImpoconsumo]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_ImputacionImpoconsumo]  DEFAULT (N'CREDITO') FOR [ImputacionImpoconsumo]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_ImputacionIngresoTercero]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_ImputacionIngresoTercero]  DEFAULT (N'CREDITO') FOR [ImputacionIngresoTercero]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_ImputacionReteIca]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_ImputacionReteIca]  DEFAULT (N'DEBITO') FOR [ImputacionReteIca]
GO

-- %% [markdown]
-- # [DF_ParametrosReferencias_ImputacionCosto]

-- %%
ALTER TABLE [dbo].[ParametrosReferencias] ADD  CONSTRAINT [DF_ParametrosReferencias_ImputacionCosto]  DEFAULT (N'DEBITO') FOR [ImputacionCosto]
GO

-- %% [markdown]
-- # [DF_Pedidos_Estado]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Pedidos_Fechafac]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Fechafac]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fechafac]
GO

-- %% [markdown]
-- # [DF_Pedidos_Tipo]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Tipo]  DEFAULT (N'VENTA') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_Pedidos_Valortransporte]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Valortransporte]  DEFAULT ((0)) FOR [Valortransporte]
GO

-- %% [markdown]
-- # [DF_Pedidos_Dias]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Pedidos_Documento]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Documento]  DEFAULT (N'FV') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Pedidos_Saldo]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Saldo]  DEFAULT ((0)) FOR [Saldo]
GO

-- %% [markdown]
-- # [DF_Pedidos_Bloque]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Bloque]  DEFAULT ((0)) FOR [Bloque]
GO

-- %% [markdown]
-- # [DF_Pedidos_PReteIca]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_Pedidos_Reteica]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Reteica]  DEFAULT ((0)) FOR [Reteica]
GO

-- %% [markdown]
-- # [DF_Pedidos_PReteIva]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_Pedidos_ReteIva]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_ReteIva]  DEFAULT ((0)) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_Pedidos_Fproceso]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Pedidos_PDescuento]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_PDescuento]  DEFAULT ((0)) FOR [PDescuento]
GO

-- %% [markdown]
-- # [DF_Pedidos_TRM]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_TRM]  DEFAULT ((1)) FOR [TRM]
GO

-- %% [markdown]
-- # [DF_Pedidos_TipoRetencion]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_TipoRetencion]  DEFAULT ((1302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_Pedidos_Cupo]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Cupo]  DEFAULT ((0)) FOR [Cupo]
GO

-- %% [markdown]
-- # [DF_Pedidos_Diasvencimiento]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Diasvencimiento]  DEFAULT ((0)) FOR [Diasvencimiento]
GO

-- %% [markdown]
-- # [DF_Pedidos_Cartera]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Cartera]  DEFAULT ((0)) FOR [Cartera]
GO

-- %% [markdown]
-- # [DF_Pedidos_Edad]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Edad]  DEFAULT ((0)) FOR [Edad]
GO

-- %% [markdown]
-- # [DF_Pedidos_Estadoter]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Estadoter]  DEFAULT ((0)) FOR [Estadoter]
GO

-- %% [markdown]
-- # [DF_Pedidos_Descarga]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Descarga]  DEFAULT (N'DESCARGAR') FOR [Descarga]
GO

-- %% [markdown]
-- # [DF_Pedidos_Matrix]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Matrix]  DEFAULT ((0)) FOR [Matrix]
GO

-- %% [markdown]
-- # [DF_Pedidos_PFlete]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_PFlete]  DEFAULT ((0)) FOR [PFlete]
GO

-- %% [markdown]
-- # [DF_Pedidos_Terminal]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_Pedidos_Concepto]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Concepto]  DEFAULT ((1315)) FOR [Concepto]
GO

-- %% [markdown]
-- # [DF_Pedidos_Diferencia]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Diferencia]  DEFAULT ((0)) FOR [Diferencia]
GO

-- %% [markdown]
-- # [DF_Pedidos_Anticipos]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Anticipos]  DEFAULT ((0)) FOR [Anticipos]
GO

-- %% [markdown]
-- # [DF_Pedidos_Us]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_Pedidos_PUtilidadest]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_PUtilidadest]  DEFAULT ((0)) FOR [PUtilidadest]
GO

-- %% [markdown]
-- # [DF_Pedidos_Utilidadest]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Utilidadest]  DEFAULT ((0)) FOR [Utilidadest]
GO

-- %% [markdown]
-- # [DF_Pedidos_Control]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Control]  DEFAULT ((0)) FOR [Control]
GO

-- %% [markdown]
-- # [DF_Pedidos_Pcree]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Pcree]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_Pedidos_Retecree]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Retecree]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_Pedidos_Imprevistos]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Imprevistos]  DEFAULT ((0)) FOR [Imprevistos]
GO

-- %% [markdown]
-- # [DF_Pedidos_Pimprevistos]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Pimprevistos]  DEFAULT ((0)) FOR [Pimprevistos]
GO

-- %% [markdown]
-- # [DF_Pedidos_Admon]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Admon]  DEFAULT ((0)) FOR [Admon]
GO

-- %% [markdown]
-- # [DF_Pedidos_PAdmon]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_PAdmon]  DEFAULT ((0)) FOR [PAdmon]
GO

-- %% [markdown]
-- # [DF_Pedidos_PRetefte]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_PRetefte]  DEFAULT ((0)) FOR [PRetefte]
GO

-- %% [markdown]
-- # [DF_Pedidos_Retefte]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Retefte]  DEFAULT ((0)) FOR [Retefte]
GO

-- %% [markdown]
-- # [DF_Pedidos_CantBolsas]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_CantBolsas]  DEFAULT ((0)) FOR [CantBolsas]
GO

-- %% [markdown]
-- # [DF_Pedidos_ValBolsas]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_ValBolsas]  DEFAULT ((0)) FOR [ValBolsas]
GO

-- %% [markdown]
-- # [DF_Pedidos_StatusDian]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_StatusDian]  DEFAULT ((0)) FOR [StatusDian]
GO

-- %% [markdown]
-- # [DF_Pedidos_StatusCliente]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_StatusCliente]  DEFAULT ((0)) FOR [StatusCliente]
GO

-- %% [markdown]
-- # [DF_Pedidos_Horafin]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  CONSTRAINT [DF_Pedidos_Horafin]  DEFAULT (getdate()) FOR [Horafin]
GO

-- %% [markdown]
-- # [DF_PedidosAdjuntos_Estado]

-- %%
ALTER TABLE [dbo].[PedidosAdjuntos] ADD  CONSTRAINT [DF_PedidosAdjuntos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Pedisub_Cantidad]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Pedisub_Descuento]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_Pedisub_PIva]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_Pedisub_Precio]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Pedisub_Subtotal]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Pedisub_Neto]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Pedisub_Precio total]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_Pedisub_Exentos]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Exentos]  DEFAULT ((0)) FOR [Exentos]
GO

-- %% [markdown]
-- # [DF_Pedisub_DesExentos]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_DesExentos]  DEFAULT ((0)) FOR [DesExentos]
GO

-- %% [markdown]
-- # [DF_Pedisub_DesGravados]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_DesGravados]  DEFAULT ((0)) FOR [DesGravados]
GO

-- %% [markdown]
-- # [DF_Pedisub_Dolares]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Dolares]  DEFAULT ((0)) FOR [Dolares]
GO

-- %% [markdown]
-- # [DF_Pedisub_Costear]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Costear]  DEFAULT ((0)) FOR [Costear]
GO

-- %% [markdown]
-- # [DF_Pedisub_Peso]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Pedisub_Remesa]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Remesa]  DEFAULT ((0)) FOR [Remesa]
GO

-- %% [markdown]
-- # [DF_Pedisub_VPropina]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_VPropina]  DEFAULT ((0)) FOR [VPropina]
GO

-- %% [markdown]
-- # [DF_Pedisub_Controlfinal]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Controlfinal]  DEFAULT ((0)) FOR [Controlfinal]
GO

-- %% [markdown]
-- # [DF_Pedisub_Rebaja]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Rebaja]  DEFAULT ((0)) FOR [Rebaja]
GO

-- %% [markdown]
-- # [DF_Pedisub_PRete]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_PRete]  DEFAULT ((0)) FOR [PRete]
GO

-- %% [markdown]
-- # [DF_Pedisub_Retencion]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_Pedisub_Manifiesto]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Manifiesto]  DEFAULT ((0)) FOR [Manifiesto]
GO

-- %% [markdown]
-- # [DF_Pedisub_Cuota]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Cuota]  DEFAULT ((0)) FOR [Cuota]
GO

-- %% [markdown]
-- # [DF_Pedisub_Moneda]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Moneda]  DEFAULT (N'COP') FOR [Moneda]
GO

-- %% [markdown]
-- # [DF_Pedisub_TRMS]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_TRMS]  DEFAULT ((1)) FOR [TRMS]
GO

-- %% [markdown]
-- # [DF_Pedisub_Pimpoconsumo]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Pimpoconsumo]  DEFAULT ((0)) FOR [Pimpoconsumo]
GO

-- %% [markdown]
-- # [DF_Pedisub_ImpCon]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_ImpCon]  DEFAULT ((0)) FOR [ImpCon]
GO

-- %% [markdown]
-- # [DF_Pedisub_Cree]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Cree]  DEFAULT ((0)) FOR [Cree]
GO

-- %% [markdown]
-- # [DF_Pedisub_Costo]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Pedisub_PReteIcasub]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_PReteIcasub]  DEFAULT ((0)) FOR [PReteIcasub]
GO

-- %% [markdown]
-- # [DF_Pedisub_ReteIcasub]

-- %%
ALTER TABLE [dbo].[Pedisub] ADD  CONSTRAINT [DF_Pedisub_ReteIcasub]  DEFAULT ((0)) FOR [ReteIcasub]
GO

-- %% [markdown]
-- # [DF_Pension_Estado]

-- %%
ALTER TABLE [dbo].[Pension] ADD  CONSTRAINT [DF_Pension_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Plandescuentos_Neto]

-- %%
ALTER TABLE [dbo].[Plandescuentos] ADD  CONSTRAINT [DF_Plandescuentos_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Plandescuentos_Documento]

-- %%
ALTER TABLE [dbo].[Plandescuentos] ADD  CONSTRAINT [DF_Plandescuentos_Documento]  DEFAULT (N'PD') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Planilla_Diasven]

-- %%
ALTER TABLE [dbo].[Planilla] ADD  CONSTRAINT [DF_Planilla_Diasven]  DEFAULT ((0)) FOR [Diasven]
GO

-- %% [markdown]
-- # [DF_Planilla_Neto]

-- %%
ALTER TABLE [dbo].[Planilla] ADD  CONSTRAINT [DF_Planilla_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Planilla_Estado]

-- %%
ALTER TABLE [dbo].[Planilla] ADD  CONSTRAINT [DF_Planilla_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_PlanillaMatrix_Diasven]

-- %%
ALTER TABLE [dbo].[PlanillaMatrix] ADD  CONSTRAINT [DF_PlanillaMatrix_Diasven]  DEFAULT ((0)) FOR [Diasven]
GO

-- %% [markdown]
-- # [DF_PlanillaMatrix_Neto]

-- %%
ALTER TABLE [dbo].[PlanillaMatrix] ADD  CONSTRAINT [DF_PlanillaMatrix_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_PlanillaMatrix_Estado]

-- %%
ALTER TABLE [dbo].[PlanillaMatrix] ADD  CONSTRAINT [DF_PlanillaMatrix_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_PlanPagos_Pago]

-- %%
ALTER TABLE [dbo].[PlanPagos] ADD  CONSTRAINT [DF_PlanPagos_Pago]  DEFAULT ((0)) FOR [Pago]
GO

-- %% [markdown]
-- # [DF_PlanPagos_Dias]

-- %%
ALTER TABLE [dbo].[PlanPagos] ADD  CONSTRAINT [DF_PlanPagos_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Planta cargos_cant1]

-- %%
ALTER TABLE [dbo].[Planta cargos] ADD  CONSTRAINT [DF_Planta cargos_cant1]  DEFAULT ((0)) FOR [cant1]
GO

-- %% [markdown]
-- # [DF_Planta cargos_Suel1]

-- %%
ALTER TABLE [dbo].[Planta cargos] ADD  CONSTRAINT [DF_Planta cargos_Suel1]  DEFAULT ((0)) FOR [Suel1]
GO

-- %% [markdown]
-- # [DF_Planta cargos_Suel2]

-- %%
ALTER TABLE [dbo].[Planta cargos] ADD  CONSTRAINT [DF_Planta cargos_Suel2]  DEFAULT ((0)) FOR [Suel2]
GO

-- %% [markdown]
-- # [DF_Ponderacion_Ponderacion]

-- %%
ALTER TABLE [dbo].[Ponderacion] ADD  CONSTRAINT [DF_Ponderacion_Ponderacion]  DEFAULT ((0)) FOR [Ponderacion]
GO

-- %% [markdown]
-- # [DF_Ponderacion_Estado]

-- %%
ALTER TABLE [dbo].[Ponderacion] ADD  CONSTRAINT [DF_Ponderacion_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Prestamos_TASA INICIAL]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_TASA INICIAL]  DEFAULT ((0)) FOR [TASA INICIAL]
GO

-- %% [markdown]
-- # [DF_Prestamos_MODO ACTUAL]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_MODO ACTUAL]  DEFAULT ((1)) FOR [MODO ACTUAL]
GO

-- %% [markdown]
-- # [DF_Prestamos_MODO DESEADO]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_MODO DESEADO]  DEFAULT ((12)) FOR [MODO DESEADO]
GO

-- %% [markdown]
-- # [DF_Prestamos_TASA FINAL]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_TASA FINAL]  DEFAULT ((0)) FOR [TASA]
GO

-- %% [markdown]
-- # [DF_Prestamos_CUOTA]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_CUOTA]  DEFAULT ((0)) FOR [CUOTA]
GO

-- %% [markdown]
-- # [DF_Prestamos_CAPITAL]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_CAPITAL]  DEFAULT ((0)) FOR [CAPITAL]
GO

-- %% [markdown]
-- # [DF_Prestamos_TIEMPO]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_TIEMPO]  DEFAULT ((0)) FOR [TIEMPO]
GO

-- %% [markdown]
-- # [DF_Prestamos_Estado]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Prestamos_Intereses]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Intereses]  DEFAULT ((0)) FOR [Intereses]
GO

-- %% [markdown]
-- # [DF_Prestamos_IngBruto]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_IngBruto]  DEFAULT ((0)) FOR [IngBruto]
GO

-- %% [markdown]
-- # [DF_Prestamos_Gastos]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Gastos]  DEFAULT ((0)) FOR [Gastos]
GO

-- %% [markdown]
-- # [DF_Prestamos_IngNeto]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_IngNeto]  DEFAULT ((0)) FOR [IngNeto]
GO

-- %% [markdown]
-- # [DF_Prestamos_PCapacidad]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_PCapacidad]  DEFAULT ((0)) FOR [PCapacidad]
GO

-- %% [markdown]
-- # [DF_Prestamos_CapacPago]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_CapacPago]  DEFAULT ((0)) FOR [CapacPago]
GO

-- %% [markdown]
-- # [DF_Prestamos_Fecha]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Fecha]  DEFAULT (getdate()) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Prestamos_Factor]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Factor]  DEFAULT ((0)) FOR [Factor]
GO

-- %% [markdown]
-- # [DF_Prestamos_Proyectado]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Proyectado]  DEFAULT ((0)) FOR [Proyectado]
GO

-- %% [markdown]
-- # [DF_Prestamos_Meses]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Meses]  DEFAULT ((0)) FOR [Meses]
GO

-- %% [markdown]
-- # [DF_Prestamos_interes1_1]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_interes1_1]  DEFAULT ((0)) FOR [interes1]
GO

-- %% [markdown]
-- # [DF_Prestamos_capital1_1]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_capital1_1]  DEFAULT ((0)) FOR [capital1]
GO

-- %% [markdown]
-- # [DF_Prestamos_Saldo1_1]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Saldo1_1]  DEFAULT ((0)) FOR [Saldo1]
GO

-- %% [markdown]
-- # [DF_Prestamos_interes2]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_interes2]  DEFAULT ((0)) FOR [interes2]
GO

-- %% [markdown]
-- # [DF_Prestamos_capital2]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_capital2]  DEFAULT ((0)) FOR [capital2]
GO

-- %% [markdown]
-- # [DF_Prestamos_Saldo2]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Saldo2]  DEFAULT ((0)) FOR [Saldo2]
GO

-- %% [markdown]
-- # [DF_Prestamos_interes3]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_interes3]  DEFAULT ((0)) FOR [interes3]
GO

-- %% [markdown]
-- # [DF_Prestamos_capital3]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_capital3]  DEFAULT ((0)) FOR [capital3]
GO

-- %% [markdown]
-- # [DF_Prestamos_Saldo3]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Saldo3]  DEFAULT ((0)) FOR [Saldo3]
GO

-- %% [markdown]
-- # [DF_Prestamos_interes4]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_interes4]  DEFAULT ((0)) FOR [interes4]
GO

-- %% [markdown]
-- # [DF_Prestamos_capital4]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_capital4]  DEFAULT ((0)) FOR [capital4]
GO

-- %% [markdown]
-- # [DF_Prestamos_Saldo4]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Saldo4]  DEFAULT ((0)) FOR [Saldo4]
GO

-- %% [markdown]
-- # [DF_Prestamos_interes5]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_interes5]  DEFAULT ((0)) FOR [interes5]
GO

-- %% [markdown]
-- # [DF_Prestamos_capital5]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_capital5]  DEFAULT ((0)) FOR [capital5]
GO

-- %% [markdown]
-- # [DF_Prestamos_Saldo5]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Saldo5]  DEFAULT ((0)) FOR [Saldo5]
GO

-- %% [markdown]
-- # [DF_Prestamos_interes6]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_interes6]  DEFAULT ((0)) FOR [interes6]
GO

-- %% [markdown]
-- # [DF_Prestamos_capital6]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_capital6]  DEFAULT ((0)) FOR [capital6]
GO

-- %% [markdown]
-- # [DF_Prestamos_Saldo6]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Saldo6]  DEFAULT ((0)) FOR [Saldo6]
GO

-- %% [markdown]
-- # [DF_Prestamos_interes7]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_interes7]  DEFAULT ((0)) FOR [interes7]
GO

-- %% [markdown]
-- # [DF_Prestamos_capital7]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_capital7]  DEFAULT ((0)) FOR [capital7]
GO

-- %% [markdown]
-- # [DF_Prestamos_Saldo7]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Saldo7]  DEFAULT ((0)) FOR [Saldo7]
GO

-- %% [markdown]
-- # [DF_Prestamos_interes8]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_interes8]  DEFAULT ((0)) FOR [interes8]
GO

-- %% [markdown]
-- # [DF_Prestamos_capital8]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_capital8]  DEFAULT ((0)) FOR [capital8]
GO

-- %% [markdown]
-- # [DF_Prestamos_Saldo8]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Saldo8]  DEFAULT ((0)) FOR [Saldo8]
GO

-- %% [markdown]
-- # [DF_Prestamos_interes9]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_interes9]  DEFAULT ((0)) FOR [interes9]
GO

-- %% [markdown]
-- # [DF_Prestamos_capital9]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_capital9]  DEFAULT ((0)) FOR [capital9]
GO

-- %% [markdown]
-- # [DF_Prestamos_Saldo9]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Saldo9]  DEFAULT ((0)) FOR [Saldo9]
GO

-- %% [markdown]
-- # [DF_Prestamos_interes10]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_interes10]  DEFAULT ((0)) FOR [interes10]
GO

-- %% [markdown]
-- # [DF_Prestamos_capital10]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_capital10]  DEFAULT ((0)) FOR [capital10]
GO

-- %% [markdown]
-- # [DF_Prestamos_Saldo10]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Saldo10]  DEFAULT ((0)) FOR [Saldo10]
GO

-- %% [markdown]
-- # [DF_Prestamos_interes11]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_interes11]  DEFAULT ((0)) FOR [interes11]
GO

-- %% [markdown]
-- # [DF_Prestamos_capital11]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_capital11]  DEFAULT ((0)) FOR [capital11]
GO

-- %% [markdown]
-- # [DF_Prestamos_Saldo11]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Saldo11]  DEFAULT ((0)) FOR [Saldo11]
GO

-- %% [markdown]
-- # [DF_Prestamos_interes12]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_interes12]  DEFAULT ((0)) FOR [interes12]
GO

-- %% [markdown]
-- # [DF_Prestamos_capital12]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_capital12]  DEFAULT ((0)) FOR [capital12]
GO

-- %% [markdown]
-- # [DF_Prestamos_Saldo12]

-- %%
ALTER TABLE [dbo].[Prestamos] ADD  CONSTRAINT [DF_Prestamos_Saldo12]  DEFAULT ((0)) FOR [Saldo12]
GO

-- %% [markdown]
-- # [DF_Presupuestar_Fecha]

-- %%
ALTER TABLE [dbo].[Presupuestar] ADD  CONSTRAINT [DF_Presupuestar_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Presupuestar_Estado]

-- %%
ALTER TABLE [dbo].[Presupuestar] ADD  CONSTRAINT [DF_Presupuestar_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Presupuestar_Documento]

-- %%
ALTER TABLE [dbo].[Presupuestar] ADD  CONSTRAINT [DF_Presupuestar_Documento]  DEFAULT (N'PR') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Presupuestarsub_Debitos]

-- %%
ALTER TABLE [dbo].[Presupuestarsub] ADD  CONSTRAINT [DF_Presupuestarsub_Debitos]  DEFAULT (0) FOR [Debitos]
GO

-- %% [markdown]
-- # [DF_Presupuestarsub_Creditos]

-- %%
ALTER TABLE [dbo].[Presupuestarsub] ADD  CONSTRAINT [DF_Presupuestarsub_Creditos]  DEFAULT (0) FOR [Creditos]
GO

-- %% [markdown]
-- # [DF_Presupuesto_Fproceso]

-- %%
ALTER TABLE [dbo].[Presupuesto] ADD  CONSTRAINT [DF_Presupuesto_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Presupuesto_Estado]

-- %%
ALTER TABLE [dbo].[Presupuesto] ADD  CONSTRAINT [DF_Presupuesto_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Presupuestosub_CuotaCantidad]

-- %%
ALTER TABLE [dbo].[Presupuestosub] ADD  CONSTRAINT [DF_Presupuestosub_CuotaCantidad]  DEFAULT (0) FOR [CuotaCantidad]
GO

-- %% [markdown]
-- # [DF_Presupuestosub_Precio]

-- %%
ALTER TABLE [dbo].[Presupuestosub] ADD  CONSTRAINT [DF_Presupuestosub_Precio]  DEFAULT (0) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Presupuestosub_Total]

-- %%
ALTER TABLE [dbo].[Presupuestosub] ADD  CONSTRAINT [DF_Presupuestosub_Total]  DEFAULT (0) FOR [Total]
GO

-- %% [markdown]
-- # [DF_Presupuestosub_Peso]

-- %%
ALTER TABLE [dbo].[Presupuestosub] ADD  CONSTRAINT [DF_Presupuestosub_Peso]  DEFAULT (0) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_PricingAereo_Dcredito]

-- %%
ALTER TABLE [dbo].[PricingAereo] ADD  CONSTRAINT [DF_PricingAereo_Dcredito]  DEFAULT ((0)) FOR [Dcredito]
GO

-- %% [markdown]
-- # [DF_PricingAereo_Dlibres]

-- %%
ALTER TABLE [dbo].[PricingAereo] ADD  CONSTRAINT [DF_PricingAereo_Dlibres]  DEFAULT ((0)) FOR [Dlibres]
GO

-- %% [markdown]
-- # [DF_PricingAereo_PesoMin]

-- %%
ALTER TABLE [dbo].[PricingAereo] ADD  CONSTRAINT [DF_PricingAereo_PesoMin]  DEFAULT ((0)) FOR [PesoMin]
GO

-- %% [markdown]
-- # [DF_PricingAereo_Peso1]

-- %%
ALTER TABLE [dbo].[PricingAereo] ADD  CONSTRAINT [DF_PricingAereo_Peso1]  DEFAULT ((0)) FOR [Peso1]
GO

-- %% [markdown]
-- # [DF_PricingAereo_Peso2]

-- %%
ALTER TABLE [dbo].[PricingAereo] ADD  CONSTRAINT [DF_PricingAereo_Peso2]  DEFAULT ((0)) FOR [Peso2]
GO

-- %% [markdown]
-- # [DF_PricingAereo_Peso3]

-- %%
ALTER TABLE [dbo].[PricingAereo] ADD  CONSTRAINT [DF_PricingAereo_Peso3]  DEFAULT ((0)) FOR [Peso3]
GO

-- %% [markdown]
-- # [DF_PricingAereo_Peso4]

-- %%
ALTER TABLE [dbo].[PricingAereo] ADD  CONSTRAINT [DF_PricingAereo_Peso4]  DEFAULT ((0)) FOR [Peso4]
GO

-- %% [markdown]
-- # [DF_PricingAereo_CostoMin]

-- %%
ALTER TABLE [dbo].[PricingAereo] ADD  CONSTRAINT [DF_PricingAereo_CostoMin]  DEFAULT ((0)) FOR [CostoMin]
GO

-- %% [markdown]
-- # [DF_PricingAereo_Costo1]

-- %%
ALTER TABLE [dbo].[PricingAereo] ADD  CONSTRAINT [DF_PricingAereo_Costo1]  DEFAULT ((0)) FOR [Costo1]
GO

-- %% [markdown]
-- # [DF_PricingAereo_Costo2]

-- %%
ALTER TABLE [dbo].[PricingAereo] ADD  CONSTRAINT [DF_PricingAereo_Costo2]  DEFAULT ((0)) FOR [Costo2]
GO

-- %% [markdown]
-- # [DF_PricingAereo_Costo3]

-- %%
ALTER TABLE [dbo].[PricingAereo] ADD  CONSTRAINT [DF_PricingAereo_Costo3]  DEFAULT ((0)) FOR [Costo3]
GO

-- %% [markdown]
-- # [DF_PricingAereo_Costo4]

-- %%
ALTER TABLE [dbo].[PricingAereo] ADD  CONSTRAINT [DF_PricingAereo_Costo4]  DEFAULT ((0)) FOR [Costo4]
GO

-- %% [markdown]
-- # [DF_PricingAereo_DTransito]

-- %%
ALTER TABLE [dbo].[PricingAereo] ADD  CONSTRAINT [DF_PricingAereo_DTransito]  DEFAULT ((0)) FOR [DTransito]
GO

-- %% [markdown]
-- # [DF_PricingAereo_Peso5]

-- %%
ALTER TABLE [dbo].[PricingAereo] ADD  CONSTRAINT [DF_PricingAereo_Peso5]  DEFAULT ((0)) FOR [Peso5]
GO

-- %% [markdown]
-- # [DF_PricingAereo_Costo5]

-- %%
ALTER TABLE [dbo].[PricingAereo] ADD  CONSTRAINT [DF_PricingAereo_Costo5]  DEFAULT ((0)) FOR [Costo5]
GO

-- %% [markdown]
-- # [DF_PricingAereoBase_Estado]

-- %%
ALTER TABLE [dbo].[PricingAereoBase] ADD  CONSTRAINT [DF_PricingAereoBase_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_PricingAereoEscala_Escala1]

-- %%
ALTER TABLE [dbo].[PricingAereoEscala] ADD  CONSTRAINT [DF_PricingAereoEscala_Escala1]  DEFAULT ((0)) FOR [Escala1]
GO

-- %% [markdown]
-- # [DF_PricingAereoEscala_Escala2]

-- %%
ALTER TABLE [dbo].[PricingAereoEscala] ADD  CONSTRAINT [DF_PricingAereoEscala_Escala2]  DEFAULT ((0)) FOR [Escala2]
GO

-- %% [markdown]
-- # [DF_PricingAereoEscala_Escala3]

-- %%
ALTER TABLE [dbo].[PricingAereoEscala] ADD  CONSTRAINT [DF_PricingAereoEscala_Escala3]  DEFAULT ((0)) FOR [Escala3]
GO

-- %% [markdown]
-- # [DF_PricingAereoEscala_Escala4]

-- %%
ALTER TABLE [dbo].[PricingAereoEscala] ADD  CONSTRAINT [DF_PricingAereoEscala_Escala4]  DEFAULT ((0)) FOR [Escala4]
GO

-- %% [markdown]
-- # [DF_PricingAereoEscala_Escala5]

-- %%
ALTER TABLE [dbo].[PricingAereoEscala] ADD  CONSTRAINT [DF_PricingAereoEscala_Escala5]  DEFAULT ((0)) FOR [Escala5]
GO

-- %% [markdown]
-- # [DF_PricingFCL_Dcredito]

-- %%
ALTER TABLE [dbo].[PricingFCL] ADD  CONSTRAINT [DF_PricingFCL_Dcredito]  DEFAULT ((0)) FOR [Dcredito]
GO

-- %% [markdown]
-- # [DF_PricingFCL_Dlibres]

-- %%
ALTER TABLE [dbo].[PricingFCL] ADD  CONSTRAINT [DF_PricingFCL_Dlibres]  DEFAULT ((0)) FOR [Dlibres]
GO

-- %% [markdown]
-- # [DF_PricingFCL_Precio20]

-- %%
ALTER TABLE [dbo].[PricingFCL] ADD  CONSTRAINT [DF_PricingFCL_Precio20]  DEFAULT ((0)) FOR [Precio20]
GO

-- %% [markdown]
-- # [DF_PricingFCL_Precio40]

-- %%
ALTER TABLE [dbo].[PricingFCL] ADD  CONSTRAINT [DF_PricingFCL_Precio40]  DEFAULT ((0)) FOR [Precio40]
GO

-- %% [markdown]
-- # [DF_PricingFCL_Precio40HC]

-- %%
ALTER TABLE [dbo].[PricingFCL] ADD  CONSTRAINT [DF_PricingFCL_Precio40HC]  DEFAULT ((0)) FOR [Precio40HC]
GO

-- %% [markdown]
-- # [DF_PricingFCL_Costo20]

-- %%
ALTER TABLE [dbo].[PricingFCL] ADD  CONSTRAINT [DF_PricingFCL_Costo20]  DEFAULT ((0)) FOR [Costo20]
GO

-- %% [markdown]
-- # [DF_PricingFCL_Costo40]

-- %%
ALTER TABLE [dbo].[PricingFCL] ADD  CONSTRAINT [DF_PricingFCL_Costo40]  DEFAULT ((0)) FOR [Costo40]
GO

-- %% [markdown]
-- # [DF_PricingFCL_Costo40HC]

-- %%
ALTER TABLE [dbo].[PricingFCL] ADD  CONSTRAINT [DF_PricingFCL_Costo40HC]  DEFAULT ((0)) FOR [Costo40HC]
GO

-- %% [markdown]
-- # [DF_PricingFCL_DTransito]

-- %%
ALTER TABLE [dbo].[PricingFCL] ADD  CONSTRAINT [DF_PricingFCL_DTransito]  DEFAULT ((0)) FOR [DTransito]
GO

-- %% [markdown]
-- # [DF_PricingFCLBase_Estado]

-- %%
ALTER TABLE [dbo].[PricingFCLBase] ADD  CONSTRAINT [DF_PricingFCLBase_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_PricingFijos_Costo]

-- %%
ALTER TABLE [dbo].[PricingFijos] ADD  CONSTRAINT [DF_PricingFijos_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_PricingFijos_Venta]

-- %%
ALTER TABLE [dbo].[PricingFijos] ADD  CONSTRAINT [DF_PricingFijos_Venta]  DEFAULT ((0)) FOR [Venta]
GO

-- %% [markdown]
-- # [DF_PricingFijos_MinVenta]

-- %%
ALTER TABLE [dbo].[PricingFijos] ADD  CONSTRAINT [DF_PricingFijos_MinVenta]  DEFAULT ((0)) FOR [MinVenta]
GO

-- %% [markdown]
-- # [DF_PricingFijos_MinCosto]

-- %%
ALTER TABLE [dbo].[PricingFijos] ADD  CONSTRAINT [DF_PricingFijos_MinCosto]  DEFAULT ((0)) FOR [MinCosto]
GO

-- %% [markdown]
-- # [DF_PricingFijos_Costocop]

-- %%
ALTER TABLE [dbo].[PricingFijos] ADD  CONSTRAINT [DF_PricingFijos_Costocop]  DEFAULT ((0)) FOR [Costocop]
GO

-- %% [markdown]
-- # [DF_PricingFijos_Ventacop]

-- %%
ALTER TABLE [dbo].[PricingFijos] ADD  CONSTRAINT [DF_PricingFijos_Ventacop]  DEFAULT ((0)) FOR [Ventacop]
GO

-- %% [markdown]
-- # [DF_PricingFijos_MinVentacop]

-- %%
ALTER TABLE [dbo].[PricingFijos] ADD  CONSTRAINT [DF_PricingFijos_MinVentacop]  DEFAULT ((0)) FOR [MinVentacop]
GO

-- %% [markdown]
-- # [DF_PricingFijos_MinCostocop]

-- %%
ALTER TABLE [dbo].[PricingFijos] ADD  CONSTRAINT [DF_PricingFijos_MinCostocop]  DEFAULT ((0)) FOR [MinCostocop]
GO

-- %% [markdown]
-- # [DF_PricingLCL_Dcredito]

-- %%
ALTER TABLE [dbo].[PricingLCL] ADD  CONSTRAINT [DF_PricingLCL_Dcredito]  DEFAULT ((0)) FOR [Dcredito]
GO

-- %% [markdown]
-- # [DF_PricingLCL_Dlibres]

-- %%
ALTER TABLE [dbo].[PricingLCL] ADD  CONSTRAINT [DF_PricingLCL_Dlibres]  DEFAULT ((0)) FOR [Dlibres]
GO

-- %% [markdown]
-- # [DF_PricingLCL_MinVenta]

-- %%
ALTER TABLE [dbo].[PricingLCL] ADD  CONSTRAINT [DF_PricingLCL_MinVenta]  DEFAULT ((0)) FOR [MinVenta]
GO

-- %% [markdown]
-- # [DF_PricingLCL_Venta]

-- %%
ALTER TABLE [dbo].[PricingLCL] ADD  CONSTRAINT [DF_PricingLCL_Venta]  DEFAULT ((0)) FOR [Venta]
GO

-- %% [markdown]
-- # [DF_PricingLCL_MinCosto]

-- %%
ALTER TABLE [dbo].[PricingLCL] ADD  CONSTRAINT [DF_PricingLCL_MinCosto]  DEFAULT ((0)) FOR [MinCosto]
GO

-- %% [markdown]
-- # [DF_PricingLCL_Costo]

-- %%
ALTER TABLE [dbo].[PricingLCL] ADD  CONSTRAINT [DF_PricingLCL_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_PricingLCL_DTransito]

-- %%
ALTER TABLE [dbo].[PricingLCL] ADD  CONSTRAINT [DF_PricingLCL_DTransito]  DEFAULT ((0)) FOR [DTransito]
GO

-- %% [markdown]
-- # [DF_PricingLCLBase_Estado]

-- %%
ALTER TABLE [dbo].[PricingLCLBase] ADD  CONSTRAINT [DF_PricingLCLBase_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_PricingOTM_Dcredito]

-- %%
ALTER TABLE [dbo].[PricingOTM] ADD  CONSTRAINT [DF_PricingOTM_Dcredito]  DEFAULT ((0)) FOR [Dcredito]
GO

-- %% [markdown]
-- # [DF_PricingOTM_Peso]

-- %%
ALTER TABLE [dbo].[PricingOTM] ADD  CONSTRAINT [DF_PricingOTM_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_PricingOTM_Costo]

-- %%
ALTER TABLE [dbo].[PricingOTM] ADD  CONSTRAINT [DF_PricingOTM_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_PricingOTM_Venta]

-- %%
ALTER TABLE [dbo].[PricingOTM] ADD  CONSTRAINT [DF_PricingOTM_Venta]  DEFAULT ((0)) FOR [Venta]
GO

-- %% [markdown]
-- # [DF_PricingOTMBase_Estado]

-- %%
ALTER TABLE [dbo].[PricingOTMBase] ADD  CONSTRAINT [DF_PricingOTMBase_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_PricingTerrestre_Dcredito]

-- %%
ALTER TABLE [dbo].[PricingTerrestre] ADD  CONSTRAINT [DF_PricingTerrestre_Dcredito]  DEFAULT ((0)) FOR [Dcredito]
GO

-- %% [markdown]
-- # [DF_PricingTerrestre_Peso]

-- %%
ALTER TABLE [dbo].[PricingTerrestre] ADD  CONSTRAINT [DF_PricingTerrestre_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_PricingTerrestre_Costo]

-- %%
ALTER TABLE [dbo].[PricingTerrestre] ADD  CONSTRAINT [DF_PricingTerrestre_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_PricingTerrestre_Venta]

-- %%
ALTER TABLE [dbo].[PricingTerrestre] ADD  CONSTRAINT [DF_PricingTerrestre_Venta]  DEFAULT ((0)) FOR [Venta]
GO

-- %% [markdown]
-- # [DF_PricingTerrestreBase_Estado]

-- %%
ALTER TABLE [dbo].[PricingTerrestreBase] ADD  CONSTRAINT [DF_PricingTerrestreBase_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Proceso_Fecha]

-- %%
ALTER TABLE [dbo].[Proceso] ADD  CONSTRAINT [DF_Proceso_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Proceso_Documento]

-- %%
ALTER TABLE [dbo].[Proceso] ADD  CONSTRAINT [DF_Proceso_Documento]  DEFAULT (N'IP') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Proceso_Fproceso]

-- %%
ALTER TABLE [dbo].[Proceso] ADD  CONSTRAINT [DF_Proceso_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Proceso_Descarga]

-- %%
ALTER TABLE [dbo].[Proceso] ADD  CONSTRAINT [DF_Proceso_Descarga]  DEFAULT (N'CARGAR') FOR [Descarga]
GO

-- %% [markdown]
-- # [DF_Proceso_Cantidad]

-- %%
ALTER TABLE [dbo].[Proceso] ADD  CONSTRAINT [DF_Proceso_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Proceso_Costo]

-- %%
ALTER TABLE [dbo].[Proceso] ADD  CONSTRAINT [DF_Proceso_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Procesosub_Cantidad]

-- %%
ALTER TABLE [dbo].[Procesosub] ADD  CONSTRAINT [DF_Procesosub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Procesosub_Costounitario]

-- %%
ALTER TABLE [dbo].[Procesosub] ADD  CONSTRAINT [DF_Procesosub_Costounitario]  DEFAULT ((0)) FOR [Costounitario]
GO

-- %% [markdown]
-- # [DF_Procesosub_Costo]

-- %%
ALTER TABLE [dbo].[Procesosub] ADD  CONSTRAINT [DF_Procesosub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Procesosub_Peso]

-- %%
ALTER TABLE [dbo].[Procesosub] ADD  CONSTRAINT [DF_Procesosub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Produccion_Fecha]

-- %%
ALTER TABLE [dbo].[Produccion] ADD  CONSTRAINT [DF_Produccion_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Produccion_Documento]

-- %%
ALTER TABLE [dbo].[Produccion] ADD  CONSTRAINT [DF_Produccion_Documento]  DEFAULT (N'PRO') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Produccion_Fproceso]

-- %%
ALTER TABLE [dbo].[Produccion] ADD  CONSTRAINT [DF_Produccion_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Produccion_Descarga]

-- %%
ALTER TABLE [dbo].[Produccion] ADD  CONSTRAINT [DF_Produccion_Descarga]  DEFAULT (N'CARGAR') FOR [Descarga]
GO

-- %% [markdown]
-- # [DF_Produccion_Producidas]

-- %%
ALTER TABLE [dbo].[Produccion] ADD  CONSTRAINT [DF_Produccion_Producidas]  DEFAULT ((0)) FOR [Producidas]
GO

-- %% [markdown]
-- # [DF_Produccion_CIF]

-- %%
ALTER TABLE [dbo].[Produccion] ADD  CONSTRAINT [DF_Produccion_CIF]  DEFAULT ((0)) FOR [CIF]
GO

-- %% [markdown]
-- # [DF_Produccion_MDO]

-- %%
ALTER TABLE [dbo].[Produccion] ADD  CONSTRAINT [DF_Produccion_MDO]  DEFAULT ((0)) FOR [MDO]
GO

-- %% [markdown]
-- # [DF_Produccion_Estado]

-- %%
ALTER TABLE [dbo].[Produccion] ADD  CONSTRAINT [DF_Produccion_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_ProduccionOrden_Fecha]

-- %%
ALTER TABLE [dbo].[ProduccionOrden] ADD  CONSTRAINT [DF_ProduccionOrden_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_ProduccionOrden_Documento]

-- %%
ALTER TABLE [dbo].[ProduccionOrden] ADD  CONSTRAINT [DF_ProduccionOrden_Documento]  DEFAULT (N'OPR') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_ProduccionOrden_Fproceso]

-- %%
ALTER TABLE [dbo].[ProduccionOrden] ADD  CONSTRAINT [DF_ProduccionOrden_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_ProduccionOrden_Estado]

-- %%
ALTER TABLE [dbo].[ProduccionOrden] ADD  CONSTRAINT [DF_ProduccionOrden_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_ProduccionOrden_Situacion]

-- %%
ALTER TABLE [dbo].[ProduccionOrden] ADD  CONSTRAINT [DF_ProduccionOrden_Situacion]  DEFAULT (N'ABIERTA') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_ProduccionOrdenref_Producidas]

-- %%
ALTER TABLE [dbo].[ProduccionOrdenref] ADD  CONSTRAINT [DF_ProduccionOrdenref_Producidas]  DEFAULT ((0)) FOR [Producidas]
GO

-- %% [markdown]
-- # [DF_Produccionordensub_Cantidad]

-- %%
ALTER TABLE [dbo].[Produccionordensub] ADD  CONSTRAINT [DF_Produccionordensub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Produccionordensub_Costounitario]

-- %%
ALTER TABLE [dbo].[Produccionordensub] ADD  CONSTRAINT [DF_Produccionordensub_Costounitario]  DEFAULT ((0)) FOR [Costounitario]
GO

-- %% [markdown]
-- # [DF_Produccionordensub_Costo]

-- %%
ALTER TABLE [dbo].[Produccionordensub] ADD  CONSTRAINT [DF_Produccionordensub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Produccionordensub_Peso]

-- %%
ALTER TABLE [dbo].[Produccionordensub] ADD  CONSTRAINT [DF_Produccionordensub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Produccionordensub_Subtotal]

-- %%
ALTER TABLE [dbo].[Produccionordensub] ADD  CONSTRAINT [DF_Produccionordensub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Produccionsub_Cantidad]

-- %%
ALTER TABLE [dbo].[Produccionsub] ADD  CONSTRAINT [DF_Produccionsub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Produccionsub_Costounitario]

-- %%
ALTER TABLE [dbo].[Produccionsub] ADD  CONSTRAINT [DF_Produccionsub_Costounitario]  DEFAULT ((0)) FOR [Costounitario]
GO

-- %% [markdown]
-- # [DF_Produccionsub_Costo]

-- %%
ALTER TABLE [dbo].[Produccionsub] ADD  CONSTRAINT [DF_Produccionsub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Produccionsub_Peso]

-- %%
ALTER TABLE [dbo].[Produccionsub] ADD  CONSTRAINT [DF_Produccionsub_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Produccionsub_Subtotal]

-- %%
ALTER TABLE [dbo].[Produccionsub] ADD  CONSTRAINT [DF_Produccionsub_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_ProyecCostos_Neto]

-- %%
ALTER TABLE [dbo].[ProyecCostos] ADD  CONSTRAINT [DF_ProyecCostos_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Cantidad1]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Cantidad1]  DEFAULT ((0)) FOR [Cantidad1]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Ventas1]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Ventas1]  DEFAULT ((0)) FOR [Ventas1]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Cantidad2]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Cantidad2]  DEFAULT ((0)) FOR [Cantidad2]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Ventas2]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Ventas2]  DEFAULT ((0)) FOR [Ventas2]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Cantidad3]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Cantidad3]  DEFAULT ((0)) FOR [Cantidad3]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Ventas3]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Ventas3]  DEFAULT ((0)) FOR [Ventas3]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Cantidad4]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Cantidad4]  DEFAULT ((0)) FOR [Cantidad4]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Ventas4]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Ventas4]  DEFAULT ((0)) FOR [Ventas4]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Cantidad5]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Cantidad5]  DEFAULT ((0)) FOR [Cantidad5]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Ventas5]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Ventas5]  DEFAULT ((0)) FOR [Ventas5]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Cantidad6]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Cantidad6]  DEFAULT ((0)) FOR [Cantidad6]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Ventas6]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Ventas6]  DEFAULT ((0)) FOR [Ventas6]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Cantidad7]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Cantidad7]  DEFAULT ((0)) FOR [Cantidad7]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Ventas7]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Ventas7]  DEFAULT ((0)) FOR [Ventas7]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Cantidad8]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Cantidad8]  DEFAULT ((0)) FOR [Cantidad8]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Ventas8]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Ventas8]  DEFAULT ((0)) FOR [Ventas8]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Cantidad9]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Cantidad9]  DEFAULT ((0)) FOR [Cantidad9]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Ventas9]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Ventas9]  DEFAULT ((0)) FOR [Ventas9]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Cantidad10]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Cantidad10]  DEFAULT ((0)) FOR [Cantidad10]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Ventas10]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Ventas10]  DEFAULT ((0)) FOR [Ventas10]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Cantidad11]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Cantidad11]  DEFAULT ((0)) FOR [Cantidad11]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Ventas11]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Ventas11]  DEFAULT ((0)) FOR [Ventas11]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Cantidad12]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Cantidad12]  DEFAULT ((0)) FOR [Cantidad12]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Ventas12]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Ventas12]  DEFAULT ((0)) FOR [Ventas12]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_periodos registrados]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_periodos registrados]  DEFAULT ((0)) FOR [periodos registrados]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_x1]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_x1]  DEFAULT ((0)) FOR [x1]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_x2]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_x2]  DEFAULT ((0)) FOR [x2]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_x3]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_x3]  DEFAULT ((0)) FOR [x3]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_x4]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_x4]  DEFAULT ((0)) FOR [x4]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_x5]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_x5]  DEFAULT ((0)) FOR [x5]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_x6]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_x6]  DEFAULT ((0)) FOR [x6]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_x7]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_x7]  DEFAULT ((0)) FOR [x7]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_x8]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_x8]  DEFAULT ((0)) FOR [x8]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_x9]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_x9]  DEFAULT ((0)) FOR [x9]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_x10]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_x10]  DEFAULT ((0)) FOR [x10]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_x11]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_x11]  DEFAULT ((0)) FOR [x11]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_x12]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_x12]  DEFAULT ((0)) FOR [x12]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_BV0]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_BV0]  DEFAULT ((0)) FOR [BV0]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_BV1]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_BV1]  DEFAULT ((0)) FOR [BV1]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_r]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_r]  DEFAULT ((0)) FOR [r]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_r2]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_r2]  DEFAULT ((0)) FOR [r2]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Precio final]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Precio final]  DEFAULT ((0)) FOR [Precio final]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Factor precios]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Factor precios]  DEFAULT ((1)) FOR [Factor precios]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Porcentaje de captura]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Porcentaje de captura]  DEFAULT ((1)) FOR [Porcentaje de captura]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Costos]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Costos]  DEFAULT ((0)) FOR [Costos]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Arriendo]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Arriendo]  DEFAULT ((0)) FOR [Arriendo]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Salarios]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Salarios]  DEFAULT ((0)) FOR [Salarios]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Servicios públicos]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Servicios públicos]  DEFAULT ((0)) FOR [Servicios públicos]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Publicidad]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Publicidad]  DEFAULT ((0)) FOR [Publicidad]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Papelería]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Papelería]  DEFAULT ((0)) FOR [Papelería]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Imprev]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Imprev]  DEFAULT ((0)) FOR [Imprev]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Depreciacion]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Depreciacion]  DEFAULT ((0)) FOR [Depreciacion]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Materia prima]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Materia prima]  DEFAULT ((0)) FOR [Materia prima]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Mano de obra]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Mano de obra]  DEFAULT ((0)) FOR [Mano de obra]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Costos generales]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Costos generales]  DEFAULT ((0)) FOR [Costos generales]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Period]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Period]  DEFAULT ((0)) FOR [Period]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_BC0]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_BC0]  DEFAULT ((0)) FOR [BC0]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_BC1]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_BC1]  DEFAULT ((0)) FOR [BC1]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Tasa impositiva]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Tasa impositiva]  DEFAULT ((0)) FOR [Tasa impositiva]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Valor residual]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Valor residual]  DEFAULT ((0)) FOR [Valor residual]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Inversion inicial]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Inversion inicial]  DEFAULT ((0)) FOR [Inversion inicial]
GO

-- %% [markdown]
-- # [DF_Proyecventas2_Estado]

-- %%
ALTER TABLE [dbo].[Proyecventas2] ADD  CONSTRAINT [DF_Proyecventas2_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Recaja_Estado]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Recaja_Tipo]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Tipo]  DEFAULT (N'PAGO') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_Recaja_Ciudad]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Ciudad]  DEFAULT (N'Bogotá, D.C.') FOR [Ciudad]
GO

-- %% [markdown]
-- # [DF_Recaja_Fecha]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Recaja_Documento]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Documento]  DEFAULT (N'RC') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Recaja_Document]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Document]  DEFAULT (N'CH') FOR [Document]
GO

-- %% [markdown]
-- # [DF_Recaja_PDesc]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_PDesc]  DEFAULT ((0)) FOR [PDesc]
GO

-- %% [markdown]
-- # [DF_Recaja_Descuento]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_Recaja_PRetencion]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_PRetencion]  DEFAULT ((0)) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_Recaja_Retefuente]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Retefuente]  DEFAULT ((0)) FOR [Retefuente]
GO

-- %% [markdown]
-- # [DF_Recaja_Pagar]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Pagar]  DEFAULT ((0)) FOR [Pagar]
GO

-- %% [markdown]
-- # [DF_Recaja_Netor]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Netor]  DEFAULT ((0)) FOR [Netor]
GO

-- %% [markdown]
-- # [DF_Recaja_Ivar]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Ivar]  DEFAULT ((0)) FOR [Ivar]
GO

-- %% [markdown]
-- # [DF_Recaja_Pivar]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Pivar]  DEFAULT ((0)) FOR [Pivar]
GO

-- %% [markdown]
-- # [DF_Recaja_PReteIca]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_Recaja_ReteIca]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_ReteIca]  DEFAULT ((0)) FOR [ReteIca]
GO

-- %% [markdown]
-- # [DF_Recaja_PReteIva]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_Recaja_ReteIva]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_ReteIva]  DEFAULT ((0)) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_Recaja_Adicion]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Adicion]  DEFAULT ((0)) FOR [Adicion]
GO

-- %% [markdown]
-- # [DF_Recaja_Fproceso]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Recaja_TipoRetencion]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_TipoRetencion]  DEFAULT ((1302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_Recaja_DifCambio]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_DifCambio]  DEFAULT ((0)) FOR [DifCambio]
GO

-- %% [markdown]
-- # [DF_Recaja_Saldo]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Saldo]  DEFAULT ((0)) FOR [Saldo]
GO

-- %% [markdown]
-- # [DF_Recaja_Pcree]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Pcree]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_Recaja_Retecree]

-- %%
ALTER TABLE [dbo].[Recaja] ADD  CONSTRAINT [DF_Recaja_Retecree]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_Reclasificacion_Fecha]

-- %%
ALTER TABLE [dbo].[Reclasificacion] ADD  CONSTRAINT [DF_Reclasificacion_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Reclasificacion_Documento]

-- %%
ALTER TABLE [dbo].[Reclasificacion] ADD  CONSTRAINT [DF_Reclasificacion_Documento]  DEFAULT (N'RCL') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Reclasificacion_Estado]

-- %%
ALTER TABLE [dbo].[Reclasificacion] ADD  CONSTRAINT [DF_Reclasificacion_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Reclasificacionsub_Factura]

-- %%
ALTER TABLE [dbo].[Reclasificacionsub] ADD  CONSTRAINT [DF_Reclasificacionsub_Factura]  DEFAULT (0) FOR [Factura]
GO

-- %% [markdown]
-- # [DF_Reclasificacionsub_Neto]

-- %%
ALTER TABLE [dbo].[Reclasificacionsub] ADD  CONSTRAINT [DF_Reclasificacionsub_Neto]  DEFAULT (0) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Referencias_Stock]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Stock]  DEFAULT ((0)) FOR [Stock]
GO

-- %% [markdown]
-- # [DF_Referencias_Seguridad]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Seguridad]  DEFAULT ((0)) FOR [Seguridad]
GO

-- %% [markdown]
-- # [DF_Referencias_Precioventa]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Precioventa]  DEFAULT ((0)) FOR [Precioventa]
GO

-- %% [markdown]
-- # [DF_Referencias_IVA]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_IVA]  DEFAULT ((0)) FOR [IVA]
GO

-- %% [markdown]
-- # [DF_Referencias_Comiventas]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Comiventas]  DEFAULT ((0)) FOR [Comiventas]
GO

-- %% [markdown]
-- # [DF_Referencias_Caja]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Caja]  DEFAULT ((0)) FOR [Caja]
GO

-- %% [markdown]
-- # [DF_Referencias_Fproceso]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Referencias_Situacion]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Situacion]  DEFAULT (N'ACTIVADO') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Referencias_Costo]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Referencias_Descuen]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Descuen]  DEFAULT ((0)) FOR [Descuen]
GO

-- %% [markdown]
-- # [DF_Referencias_PRetencion]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_PRetencion]  DEFAULT ((0)) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_Referencias_Imputacion]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Imputacion]  DEFAULT (N'DEBITO') FOR [Imputacion]
GO

-- %% [markdown]
-- # [DF_Referencias_ImputacionIva]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_ImputacionIva]  DEFAULT (N'CREDITO') FOR [ImputacionIva]
GO

-- %% [markdown]
-- # [DF_Referencias_TipoRete]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_TipoRete]  DEFAULT ((2302)) FOR [TipoRete]
GO

-- %% [markdown]
-- # [DF_Referencias_VER]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_VER]  DEFAULT (N'SI') FOR [VER]
GO

-- %% [markdown]
-- # [DF_Referencias_ImputacionIngreso]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_ImputacionIngreso]  DEFAULT (N'CREDITO') FOR [ImputacionIngreso]
GO

-- %% [markdown]
-- # [DF_Referencias_Propina]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Propina]  DEFAULT (N'SI') FOR [Propina]
GO

-- %% [markdown]
-- # [DF_Referencias_Tipo]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Tipo]  DEFAULT (N'TERMINADO') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_Referencias_ImputacionRetencion]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_ImputacionRetencion]  DEFAULT (N'CREDITO') FOR [ImputacionRetencion]
GO

-- %% [markdown]
-- # [DF_Referencias_Preciofinal]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Preciofinal]  DEFAULT ((0)) FOR [Preciofinal]
GO

-- %% [markdown]
-- # [DF_Referencias_Estado]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Referencias_ImputacionRRetenida]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_ImputacionRRetenida]  DEFAULT (N'DEBITO') FOR [ImputacionRRetenida]
GO

-- %% [markdown]
-- # [DF_Referencias_TipoReteRetenida]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_TipoReteRetenida]  DEFAULT ((1302)) FOR [TipoReteRetenida]
GO

-- %% [markdown]
-- # [DF_Referencias_ImputacionIvaCompras]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_ImputacionIvaCompras]  DEFAULT (N'DEBITO') FOR [ImputacionIvaCompras]
GO

-- %% [markdown]
-- # [DF_Referencias_ImputacionDescuento]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_ImputacionDescuento]  DEFAULT (N'DEBITO') FOR [ImputacionDescuento]
GO

-- %% [markdown]
-- # [DF_Referencias_ImputacionDevolucion]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_ImputacionDevolucion]  DEFAULT (N'DEBITO') FOR [ImputacionDevolucion]
GO

-- %% [markdown]
-- # [DF_Referencias_ImputacionIvaDevolucion]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_ImputacionIvaDevolucion]  DEFAULT (N'DEBITO') FOR [ImputacionIvaDevolucion]
GO

-- %% [markdown]
-- # [DF_Referencias_ImputacionIvateorico]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_ImputacionIvateorico]  DEFAULT (N'CREDITO') FOR [ImputacionIvateorico]
GO

-- %% [markdown]
-- # [DF_Referencias_Costear]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Costear]  DEFAULT (N'SI') FOR [Costear]
GO

-- %% [markdown]
-- # [DF_Referencias_Existencia]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Existencia]  DEFAULT (N'SI') FOR [Existencia]
GO

-- %% [markdown]
-- # [DF_Referencias_Facturar]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Facturar]  DEFAULT (N'SI') FOR [Facturar]
GO

-- %% [markdown]
-- # [DF_Referencias_Pimpoconsumor]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Pimpoconsumor]  DEFAULT ((0)) FOR [Pimpoconsumor]
GO

-- %% [markdown]
-- # [DF_Referencias_ImputacionImpoconsumo]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_ImputacionImpoconsumo]  DEFAULT (N'CREDITO') FOR [ImputacionImpoconsumo]
GO

-- %% [markdown]
-- # [DF_Referencias_Retecree]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Retecree]  DEFAULT (N'SI') FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_Referencias_ImputacionIngresoTercero]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_ImputacionIngresoTercero]  DEFAULT (N'CREDITO') FOR [ImputacionIngresoTercero]
GO

-- %% [markdown]
-- # [DF_Referencias_Lista2_1]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Lista2_1]  DEFAULT ((0)) FOR [Lista2]
GO

-- %% [markdown]
-- # [DF_Referencias_Lista3_1]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Lista3_1]  DEFAULT ((0)) FOR [Lista3]
GO

-- %% [markdown]
-- # [DF_Referencias_Comision]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Comision]  DEFAULT (N'SI') FOR [Comision]
GO

-- %% [markdown]
-- # [DF_Referencias_Pflete]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Pflete]  DEFAULT ((0)) FOR [Pflete]
GO

-- %% [markdown]
-- # [DF_Referencias_Pcosto]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Pcosto]  DEFAULT ((0)) FOR [Pcosto]
GO

-- %% [markdown]
-- # [DF_Referencias_Minima]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_Minima]  DEFAULT ((0)) FOR [Minima]
GO

-- %% [markdown]
-- # [DF_Referencias_ImputacionReteIca]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_ImputacionReteIca]  DEFAULT (N'DEBITO') FOR [ImputacionReteIca]
GO

-- %% [markdown]
-- # [DF_Referencias_ImputacionCosto]

-- %%
ALTER TABLE [dbo].[Referencias] ADD  CONSTRAINT [DF_Referencias_ImputacionCosto]  DEFAULT (N'DEBITO') FOR [ImputacionCosto]
GO

-- %% [markdown]
-- # [DF_Resoluciones_Estado]

-- %%
ALTER TABLE [dbo].[Resoluciones] ADD  CONSTRAINT [DF_Resoluciones_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Resoluciones_Situacion]

-- %%
ALTER TABLE [dbo].[Resoluciones] ADD  CONSTRAINT [DF_Resoluciones_Situacion]  DEFAULT (N'ACTIVADO') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_RespFiscal_Estado]

-- %%
ALTER TABLE [dbo].[RespFiscal] ADD  CONSTRAINT [DF_RespFiscal_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Resultados_Año]

-- %%
ALTER TABLE [dbo].[Resultados] ADD  CONSTRAINT [DF_Resultados_Año]  DEFAULT (0) FOR [Año]
GO

-- %% [markdown]
-- # [DF_Resultados_Periodo]

-- %%
ALTER TABLE [dbo].[Resultados] ADD  CONSTRAINT [DF_Resultados_Periodo]  DEFAULT (0) FOR [Periodo]
GO

-- %% [markdown]
-- # [DF_Resultados_Fallas]

-- %%
ALTER TABLE [dbo].[Resultados] ADD  CONSTRAINT [DF_Resultados_Fallas]  DEFAULT (0) FOR [Fallas]
GO

-- %% [markdown]
-- # [DF_Resultados_Estado]

-- %%
ALTER TABLE [dbo].[Resultados] ADD  CONSTRAINT [DF_Resultados_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_RetiroCaja_Fecha]

-- %%
ALTER TABLE [dbo].[RetiroCaja] ADD  CONSTRAINT [DF_RetiroCaja_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_RetiroCaja_Documento]

-- %%
ALTER TABLE [dbo].[RetiroCaja] ADD  CONSTRAINT [DF_RetiroCaja_Documento]  DEFAULT (N'RT') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_RetiroCaja_Fproceso]

-- %%
ALTER TABLE [dbo].[RetiroCaja] ADD  CONSTRAINT [DF_RetiroCaja_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_RetiroCaja_Estado]

-- %%
ALTER TABLE [dbo].[RetiroCaja] ADD  CONSTRAINT [DF_RetiroCaja_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Retirosub_NDocumento]

-- %%
ALTER TABLE [dbo].[Retirosub] ADD  CONSTRAINT [DF_Retirosub_NDocumento]  DEFAULT (0) FOR [NDocumento]
GO

-- %% [markdown]
-- # [DF_Retirosub_Neto]

-- %%
ALTER TABLE [dbo].[Retirosub] ADD  CONSTRAINT [DF_Retirosub_Neto]  DEFAULT (0) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Rutas_Estado]

-- %%
ALTER TABLE [dbo].[Rutas] ADD  CONSTRAINT [DF_Rutas_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Salidas_Cantidadsal]

-- %%
ALTER TABLE [dbo].[Salidas] ADD  CONSTRAINT [DF_Salidas_Cantidadsal]  DEFAULT ((1)) FOR [Cantidadsal]
GO

-- %% [markdown]
-- # [DF_Salidas_Precio]

-- %%
ALTER TABLE [dbo].[Salidas] ADD  CONSTRAINT [DF_Salidas_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Salidas_Precio total]

-- %%
ALTER TABLE [dbo].[Salidas] ADD  CONSTRAINT [DF_Salidas_Precio total]  DEFAULT ((0)) FOR [Precio total]
GO

-- %% [markdown]
-- # [DF_Salidas_Descuento]

-- %%
ALTER TABLE [dbo].[Salidas] ADD  CONSTRAINT [DF_Salidas_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_Salidas_Peso]

-- %%
ALTER TABLE [dbo].[Salidas] ADD  CONSTRAINT [DF_Salidas_Peso]  DEFAULT ((0)) FOR [Peso]
GO

-- %% [markdown]
-- # [DF_Salidas_Subtotal]

-- %%
ALTER TABLE [dbo].[Salidas] ADD  CONSTRAINT [DF_Salidas_Subtotal]  DEFAULT ((0)) FOR [Subtotal]
GO

-- %% [markdown]
-- # [DF_Salidasenc_Fecha]

-- %%
ALTER TABLE [dbo].[Salidasenc] ADD  CONSTRAINT [DF_Salidasenc_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Salidasenc_Documento]

-- %%
ALTER TABLE [dbo].[Salidasenc] ADD  CONSTRAINT [DF_Salidasenc_Documento]  DEFAULT (N'SL') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Salidasenc_Fproceso]

-- %%
ALTER TABLE [dbo].[Salidasenc] ADD  CONSTRAINT [DF_Salidasenc_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Salidasenc_Estado]

-- %%
ALTER TABLE [dbo].[Salidasenc] ADD  CONSTRAINT [DF_Salidasenc_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Seguimiento_Estado]

-- %%
ALTER TABLE [dbo].[Seguimiento] ADD  CONSTRAINT [DF_Seguimiento_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Seguimientotrans_Fechaseg]

-- %%
ALTER TABLE [dbo].[Seguimientotrans] ADD  CONSTRAINT [DF_Seguimientotrans_Fechaseg]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fechaseg]
GO

-- %% [markdown]
-- # [DF_Seguimientotrans_Hora]

-- %%
ALTER TABLE [dbo].[Seguimientotrans] ADD  CONSTRAINT [DF_Seguimientotrans_Hora]  DEFAULT (getdate()) FOR [Hora]
GO

-- %% [markdown]
-- # [DF_Seguimientotrans_FProceso]

-- %%
ALTER TABLE [dbo].[Seguimientotrans] ADD  CONSTRAINT [DF_Seguimientotrans_FProceso]  DEFAULT (getdate()) FOR [FProceso]
GO

-- %% [markdown]
-- # [DF_Seguimientotrans_Estado]

-- %%
ALTER TABLE [dbo].[Seguimientotrans] ADD  CONSTRAINT [DF_Seguimientotrans_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Simulador_Fecha]

-- %%
ALTER TABLE [dbo].[Simulador] ADD  CONSTRAINT [DF_Simulador_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Simulador_IngresoNeto]

-- %%
ALTER TABLE [dbo].[Simulador] ADD  CONSTRAINT [DF_Simulador_IngresoNeto]  DEFAULT ((0)) FOR [IngresoNeto]
GO

-- %% [markdown]
-- # [DF_Simulador_PExento]

-- %%
ALTER TABLE [dbo].[Simulador] ADD  CONSTRAINT [DF_Simulador_PExento]  DEFAULT ((25)) FOR [PExento]
GO

-- %% [markdown]
-- # [DF_Simulador_Bgravable]

-- %%
ALTER TABLE [dbo].[Simulador] ADD  CONSTRAINT [DF_Simulador_Bgravable]  DEFAULT ((0)) FOR [Bgravable]
GO

-- %% [markdown]
-- # [DF_Simulador_Meses]

-- %%
ALTER TABLE [dbo].[Simulador] ADD  CONSTRAINT [DF_Simulador_Meses]  DEFAULT ((0)) FOR [Meses]
GO

-- %% [markdown]
-- # [DF_Simulador_Promediomes]

-- %%
ALTER TABLE [dbo].[Simulador] ADD  CONSTRAINT [DF_Simulador_Promediomes]  DEFAULT ((0)) FOR [Promediomes]
GO

-- %% [markdown]
-- # [DF_Simulador_UVT]

-- %%
ALTER TABLE [dbo].[Simulador] ADD  CONSTRAINT [DF_Simulador_UVT]  DEFAULT ((0)) FOR [UVT]
GO

-- %% [markdown]
-- # [DF_Simulador_tuvt]

-- %%
ALTER TABLE [dbo].[Simulador] ADD  CONSTRAINT [DF_Simulador_tuvt]  DEFAULT ((0)) FOR [tuvt]
GO

-- %% [markdown]
-- # [DF_Simulador_Retencion]

-- %%
ALTER TABLE [dbo].[Simulador] ADD  CONSTRAINT [DF_Simulador_Retencion]  DEFAULT ((0)) FOR [Retencion]
GO

-- %% [markdown]
-- # [DF_Simulador_Pretefte]

-- %%
ALTER TABLE [dbo].[Simulador] ADD  CONSTRAINT [DF_Simulador_Pretefte]  DEFAULT ((0)) FOR [Pretefte]
GO

-- %% [markdown]
-- # [DF_Simulador_Estado]

-- %%
ALTER TABLE [dbo].[Simulador] ADD  CONSTRAINT [DF_Simulador_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Simulador_Documento]

-- %%
ALTER TABLE [dbo].[Simulador] ADD  CONSTRAINT [DF_Simulador_Documento]  DEFAULT (N'SM') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_Simuladorsub_Neto]

-- %%
ALTER TABLE [dbo].[Simuladorsub] ADD  CONSTRAINT [DF_Simuladorsub_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_StatusCRM_Estado]

-- %%
ALTER TABLE [dbo].[StatusCRM] ADD  CONSTRAINT [DF_StatusCRM_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Strategy1_Fecha]

-- %%
ALTER TABLE [dbo].[Strategy1] ADD  CONSTRAINT [DF_Strategy1_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Strategy1_Estado]

-- %%
ALTER TABLE [dbo].[Strategy1] ADD  CONSTRAINT [DF_Strategy1_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Strategy18_Pondera]

-- %%
ALTER TABLE [dbo].[Strategy18] ADD  CONSTRAINT [DF_Strategy18_Pondera]  DEFAULT ((0)) FOR [Pondera]
GO

-- %% [markdown]
-- # [DF_Strategy18_Calificacion]

-- %%
ALTER TABLE [dbo].[Strategy18] ADD  CONSTRAINT [DF_Strategy18_Calificacion]  DEFAULT ((0)) FOR [Calificacion]
GO

-- %% [markdown]
-- # [DF_Strategy18_Resultado]

-- %%
ALTER TABLE [dbo].[Strategy18] ADD  CONSTRAINT [DF_Strategy18_Resultado]  DEFAULT ((0)) FOR [Resultado]
GO

-- %% [markdown]
-- # [DF_Strategy181_Inicio]

-- %%
ALTER TABLE [dbo].[Strategy181] ADD  CONSTRAINT [DF_Strategy181_Inicio]  DEFAULT ((0)) FOR [Inicio]
GO

-- %% [markdown]
-- # [DF_Strategy181_Fin]

-- %%
ALTER TABLE [dbo].[Strategy181] ADD  CONSTRAINT [DF_Strategy181_Fin]  DEFAULT ((0)) FOR [Fin]
GO

-- %% [markdown]
-- # [DF_Strategy19_PonderaC0]

-- %%
ALTER TABLE [dbo].[Strategy19] ADD  CONSTRAINT [DF_Strategy19_PonderaC0]  DEFAULT ((0)) FOR [PonderaC0]
GO

-- %% [markdown]
-- # [DF_Strategy19_CalificaC0]

-- %%
ALTER TABLE [dbo].[Strategy19] ADD  CONSTRAINT [DF_Strategy19_CalificaC0]  DEFAULT ((0)) FOR [CalificaC0]
GO

-- %% [markdown]
-- # [DF_Strategy19_ResultadoC0]

-- %%
ALTER TABLE [dbo].[Strategy19] ADD  CONSTRAINT [DF_Strategy19_ResultadoC0]  DEFAULT ((0)) FOR [ResultadoC0]
GO

-- %% [markdown]
-- # [DF_Table_1_PonderaC01]

-- %%
ALTER TABLE [dbo].[Strategy19] ADD  CONSTRAINT [DF_Table_1_PonderaC01]  DEFAULT ((0)) FOR [PonderaC1]
GO

-- %% [markdown]
-- # [DF_Table_1_CalificaC01]

-- %%
ALTER TABLE [dbo].[Strategy19] ADD  CONSTRAINT [DF_Table_1_CalificaC01]  DEFAULT ((0)) FOR [CalificaC1]
GO

-- %% [markdown]
-- # [DF_Table_1_ResultadoC01]

-- %%
ALTER TABLE [dbo].[Strategy19] ADD  CONSTRAINT [DF_Table_1_ResultadoC01]  DEFAULT ((0)) FOR [ResultadoC1]
GO

-- %% [markdown]
-- # [DF_Table_1_PonderaC01_1]

-- %%
ALTER TABLE [dbo].[Strategy19] ADD  CONSTRAINT [DF_Table_1_PonderaC01_1]  DEFAULT ((0)) FOR [PonderaC2]
GO

-- %% [markdown]
-- # [DF_Table_1_CalificaC01_1]

-- %%
ALTER TABLE [dbo].[Strategy19] ADD  CONSTRAINT [DF_Table_1_CalificaC01_1]  DEFAULT ((0)) FOR [CalificaC2]
GO

-- %% [markdown]
-- # [DF_Table_1_ResultadoC01_1]

-- %%
ALTER TABLE [dbo].[Strategy19] ADD  CONSTRAINT [DF_Table_1_ResultadoC01_1]  DEFAULT ((0)) FOR [ResultadoC2]
GO

-- %% [markdown]
-- # [DF_Table_1_PonderaC01_2]

-- %%
ALTER TABLE [dbo].[Strategy19] ADD  CONSTRAINT [DF_Table_1_PonderaC01_2]  DEFAULT ((0)) FOR [PonderaC3]
GO

-- %% [markdown]
-- # [DF_Table_1_CalificaC01_2]

-- %%
ALTER TABLE [dbo].[Strategy19] ADD  CONSTRAINT [DF_Table_1_CalificaC01_2]  DEFAULT ((0)) FOR [CalificaC3]
GO

-- %% [markdown]
-- # [DF_Table_1_ResultadoC01_2]

-- %%
ALTER TABLE [dbo].[Strategy19] ADD  CONSTRAINT [DF_Table_1_ResultadoC01_2]  DEFAULT ((0)) FOR [ResultadoC3]
GO

-- %% [markdown]
-- # [DF_Strategy2_Fecha]

-- %%
ALTER TABLE [dbo].[Strategy2] ADD  CONSTRAINT [DF_Strategy2_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Strategy2_Estado]

-- %%
ALTER TABLE [dbo].[Strategy2] ADD  CONSTRAINT [DF_Strategy2_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Strategy20_Estado]

-- %%
ALTER TABLE [dbo].[Strategy20] ADD  CONSTRAINT [DF_Strategy20_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Strategy21_Meta]

-- %%
ALTER TABLE [dbo].[Strategy21] ADD  CONSTRAINT [DF_Strategy21_Meta]  DEFAULT ((0)) FOR [Meta]
GO

-- %% [markdown]
-- # [DF_Strategy22_Costo]

-- %%
ALTER TABLE [dbo].[Strategy22] ADD  CONSTRAINT [DF_Strategy22_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Strategy3_Fecha]

-- %%
ALTER TABLE [dbo].[Strategy3] ADD  CONSTRAINT [DF_Strategy3_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Strategy3_Estado]

-- %%
ALTER TABLE [dbo].[Strategy3] ADD  CONSTRAINT [DF_Strategy3_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Table_1_Meta]

-- %%
ALTER TABLE [dbo].[Strategy31] ADD  CONSTRAINT [DF_Table_1_Meta]  DEFAULT ((0)) FOR [Resultado]
GO

-- %% [markdown]
-- # [DF_Strategy32_Resultado]

-- %%
ALTER TABLE [dbo].[Strategy32] ADD  CONSTRAINT [DF_Strategy32_Resultado]  DEFAULT ((0)) FOR [Resultado]
GO

-- %% [markdown]
-- # [DF_Strategy5_Fecha]

-- %%
ALTER TABLE [dbo].[Strategy5] ADD  CONSTRAINT [DF_Strategy5_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Strategy5_Estado]

-- %%
ALTER TABLE [dbo].[Strategy5] ADD  CONSTRAINT [DF_Strategy5_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Strategy50_Fecha]

-- %%
ALTER TABLE [dbo].[Strategy50] ADD  CONSTRAINT [DF_Strategy50_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Strategy50_Estado]

-- %%
ALTER TABLE [dbo].[Strategy50] ADD  CONSTRAINT [DF_Strategy50_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Strategy51_Total]

-- %%
ALTER TABLE [dbo].[Strategy51] ADD  CONSTRAINT [DF_Strategy51_Total]  DEFAULT ((0)) FOR [Total]
GO

-- %% [markdown]
-- # [DF_Strategy52_Pondera]

-- %%
ALTER TABLE [dbo].[Strategy52] ADD  CONSTRAINT [DF_Strategy52_Pondera]  DEFAULT ((0)) FOR [Pondera]
GO

-- %% [markdown]
-- # [DF_Strategy52_Qvar]

-- %%
ALTER TABLE [dbo].[Strategy52] ADD  CONSTRAINT [DF_Strategy52_Qvar]  DEFAULT ((0)) FOR [Qvar]
GO

-- %% [markdown]
-- # [DF_Strategy52_Estado]

-- %%
ALTER TABLE [dbo].[Strategy52] ADD  CONSTRAINT [DF_Strategy52_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Strategy6_Fecha]

-- %%
ALTER TABLE [dbo].[Strategy6] ADD  CONSTRAINT [DF_Strategy6_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Strategy6_Estado]

-- %%
ALTER TABLE [dbo].[Strategy6] ADD  CONSTRAINT [DF_Strategy6_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Strategy61_Califica]

-- %%
ALTER TABLE [dbo].[Strategy61] ADD  CONSTRAINT [DF_Strategy61_Califica]  DEFAULT ((0)) FOR [Califica]
GO

-- %% [markdown]
-- # [DF_Strategy62_Estado]

-- %%
ALTER TABLE [dbo].[Strategy62] ADD  CONSTRAINT [DF_Strategy62_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Strategy62_Pondera]

-- %%
ALTER TABLE [dbo].[Strategy62] ADD  CONSTRAINT [DF_Strategy62_Pondera]  DEFAULT ((0)) FOR [Pondera]
GO

-- %% [markdown]
-- # [DF_Sucursales_Centro costos]

-- %%
ALTER TABLE [dbo].[Sucursales] ADD  CONSTRAINT [DF_Sucursales_Centro costos]  DEFAULT (N'.') FOR [Centro costos]
GO

-- %% [markdown]
-- # [DF_Sucursales_Estado]

-- %%
ALTER TABLE [dbo].[Sucursales] ADD  CONSTRAINT [DF_Sucursales_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Tareas_Fecha]

-- %%
ALTER TABLE [dbo].[Tareas] ADD  CONSTRAINT [DF_Tareas_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Tareas_Estado]

-- %%
ALTER TABLE [dbo].[Tareas] ADD  CONSTRAINT [DF_Tareas_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Tareas_Hecho]

-- %%
ALTER TABLE [dbo].[Tareas] ADD  CONSTRAINT [DF_Tareas_Hecho]  DEFAULT (N'NO') FOR [Hecho]
GO

-- %% [markdown]
-- # [DF_Tareas_Estado2]

-- %%
ALTER TABLE [dbo].[Tareas] ADD  CONSTRAINT [DF_Tareas_Estado2]  DEFAULT ((0)) FOR [Estado2]
GO

-- %% [markdown]
-- # [DF_Tarifario_Tarifa]

-- %%
ALTER TABLE [dbo].[Tarifario] ADD  CONSTRAINT [DF_Tarifario_Tarifa]  DEFAULT ((0)) FOR [Tarifa]
GO

-- %% [markdown]
-- # [DF_Tarifario_Estado]

-- %%
ALTER TABLE [dbo].[Tarifario] ADD  CONSTRAINT [DF_Tarifario_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Tasa_Fecha]

-- %%
ALTER TABLE [dbo].[Tasa] ADD  CONSTRAINT [DF_Tasa_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Tasa_Tasa]

-- %%
ALTER TABLE [dbo].[Tasa] ADD  CONSTRAINT [DF_Tasa_Tasa]  DEFAULT (0) FOR [Tasa]
GO

-- %% [markdown]
-- # [DF_Tasa_Estado]

-- %%
ALTER TABLE [dbo].[Tasa] ADD  CONSTRAINT [DF_Tasa_Estado]  DEFAULT (0) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Tasa_Neta_1]

-- %%
ALTER TABLE [dbo].[Tasa] ADD  CONSTRAINT [DF_Tasa_Neta_1]  DEFAULT ((0)) FOR [Neta]
GO

-- %% [markdown]
-- # [DF_Tasa_Adicion_1]

-- %%
ALTER TABLE [dbo].[Tasa] ADD  CONSTRAINT [DF_Tasa_Adicion_1]  DEFAULT ((0)) FOR [Adicion]
GO

-- %% [markdown]
-- # [DF_Terceros_Fproceso]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_Terceros_PReteIca]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_Terceros_PReteIva]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_Terceros_DiasPago]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_DiasPago]  DEFAULT ((0)) FOR [DiasPago]
GO

-- %% [markdown]
-- # [DF_Terceros_PDescuento]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_PDescuento]  DEFAULT ((0)) FOR [PDescuento]
GO

-- %% [markdown]
-- # [DF_Terceros_Situacion]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_Situacion]  DEFAULT (N'ACTIVADO') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Terceros_Estado]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Terceros_Cupo]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_Cupo]  DEFAULT ((0)) FOR [Cupo]
GO

-- %% [markdown]
-- # [DF_Terceros_DiasVencimiento]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_DiasVencimiento]  DEFAULT ((0)) FOR [DiasVencimiento]
GO

-- %% [markdown]
-- # [DF_Terceros_Cuota]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_Cuota]  DEFAULT ((0)) FOR [Cuota]
GO

-- %% [markdown]
-- # [DF_Terceros_Imputacion]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_Imputacion]  DEFAULT (N'CREDITO') FOR [Imputacion]
GO

-- %% [markdown]
-- # [DF_Terceros_Pais]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_Pais]  DEFAULT ((169)) FOR [Pais]
GO

-- %% [markdown]
-- # [DF_Terceros_Cuentacartera]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_Cuentacartera]  DEFAULT ((130505)) FOR [Cuentacartera]
GO

-- %% [markdown]
-- # [DF_Terceros_Imputacioncartera]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_Imputacioncartera]  DEFAULT (N'DEBITO') FOR [Imputacioncartera]
GO

-- %% [markdown]
-- # [DF_Terceros_PRetecree]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_PRetecree]  DEFAULT ((0)) FOR [PRetecree]
GO

-- %% [markdown]
-- # [DF_Terceros_ImputacionRetecree]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_ImputacionRetecree]  DEFAULT (N'CREDITO') FOR [ImputacionRetecree]
GO

-- %% [markdown]
-- # [DF_Terceros_ResFiscal]

-- %%
ALTER TABLE [dbo].[Terceros] ADD  CONSTRAINT [DF_Terceros_ResFiscal]  DEFAULT (N'O-99') FOR [ResFiscal]
GO

-- %% [markdown]
-- # [DF_TercerosConceptos_Dias]

-- %%
ALTER TABLE [dbo].[TercerosConceptos] ADD  CONSTRAINT [DF_TercerosConceptos_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Tercerosref2_Neto]

-- %%
ALTER TABLE [dbo].[Tercerosref2] ADD  CONSTRAINT [DF_Tercerosref2_Neto]  DEFAULT ((0)) FOR [Neto]
GO

-- %% [markdown]
-- # [DF_Tercerosreferencias_Iva]

-- %%
ALTER TABLE [dbo].[Tercerosreferencias] ADD  CONSTRAINT [DF_Tercerosreferencias_Iva]  DEFAULT ((0)) FOR [Ivater]
GO

-- %% [markdown]
-- # [DF_Tercerosreferencias_Precio]

-- %%
ALTER TABLE [dbo].[Tercerosreferencias] ADD  CONSTRAINT [DF_Tercerosreferencias_Precio]  DEFAULT ((0)) FOR [Precioter]
GO

-- %% [markdown]
-- # [DF_Tercerosreferencias_Costo]

-- %%
ALTER TABLE [dbo].[Tercerosreferencias] ADD  CONSTRAINT [DF_Tercerosreferencias_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Tercerosreferencias_Utilidad]

-- %%
ALTER TABLE [dbo].[Tercerosreferencias] ADD  CONSTRAINT [DF_Tercerosreferencias_Utilidad]  DEFAULT ((0)) FOR [Utilidad]
GO

-- %% [markdown]
-- # [DF_Tercerosreferencias_Rendimiento]

-- %%
ALTER TABLE [dbo].[Tercerosreferencias] ADD  CONSTRAINT [DF_Tercerosreferencias_Rendimiento]  DEFAULT ((0)) FOR [Rendimiento]
GO

-- %% [markdown]
-- # [DF_Tercerosreferencias_Estado_1]

-- %%
ALTER TABLE [dbo].[Tercerosreferencias] ADD  CONSTRAINT [DF_Tercerosreferencias_Estado_1]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Textomail_Estado]

-- %%
ALTER TABLE [dbo].[Textomail] ADD  CONSTRAINT [DF_Textomail_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Tiempos_Estado]

-- %%
ALTER TABLE [dbo].[Tiempos] ADD  CONSTRAINT [DF_Tiempos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TiemposPlaneado_Estado]

-- %%
ALTER TABLE [dbo].[TiemposPlaneado] ADD  CONSTRAINT [DF_TiemposPlaneado_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoAnticipo_Estado]

-- %%
ALTER TABLE [dbo].[TipoAnticipo] ADD  CONSTRAINT [DF_TipoAnticipo_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoCoberturas_Estado]

-- %%
ALTER TABLE [dbo].[TipoCoberturas] ADD  CONSTRAINT [DF_TipoCoberturas_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoConcepto_Estado]

-- %%
ALTER TABLE [dbo].[TipoConcepto] ADD  CONSTRAINT [DF_TipoConcepto_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoConceptoNC_Estado]

-- %%
ALTER TABLE [dbo].[TipoConceptoNC] ADD  CONSTRAINT [DF_TipoConceptoNC_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoConceptoND_Estado]

-- %%
ALTER TABLE [dbo].[TipoConceptoND] ADD  CONSTRAINT [DF_TipoConceptoND_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoContrato_Estado]

-- %%
ALTER TABLE [dbo].[TipoContrato] ADD  CONSTRAINT [DF_TipoContrato_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoDocumento_Estado]

-- %%
ALTER TABLE [dbo].[TipoDocumento] ADD  CONSTRAINT [DF_TipoDocumento_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoEstado_Estado]

-- %%
ALTER TABLE [dbo].[TipoEstado] ADD  CONSTRAINT [DF_TipoEstado_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoFactura_Estado]

-- %%
ALTER TABLE [dbo].[TipoFactura] ADD  CONSTRAINT [DF_TipoFactura_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Tipoguia_Estado]

-- %%
ALTER TABLE [dbo].[Tipoguia] ADD  CONSTRAINT [DF_Tipoguia_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoMoneda_Estado]

-- %%
ALTER TABLE [dbo].[TipoMoneda] ADD  CONSTRAINT [DF_TipoMoneda_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoNovedad_Estado]

-- %%
ALTER TABLE [dbo].[TipoNovedad] ADD  CONSTRAINT [DF_TipoNovedad_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoOperacion_Estado]

-- %%
ALTER TABLE [dbo].[TipoOperacion] ADD  CONSTRAINT [DF_TipoOperacion_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoOperacion_Situacion]

-- %%
ALTER TABLE [dbo].[TipoOperacion] ADD  CONSTRAINT [DF_TipoOperacion_Situacion]  DEFAULT (N'ACTIVADO') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_TipoOperfac_Estado]

-- %%
ALTER TABLE [dbo].[TipoOperfac] ADD  CONSTRAINT [DF_TipoOperfac_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoOperNC_Estado]

-- %%
ALTER TABLE [dbo].[TipoOperNC] ADD  CONSTRAINT [DF_TipoOperNC_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoOperND_Estado]

-- %%
ALTER TABLE [dbo].[TipoOperND] ADD  CONSTRAINT [DF_TipoOperND_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoPago_Estado]

-- %%
ALTER TABLE [dbo].[TipoPago] ADD  CONSTRAINT [DF_TipoPago_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoPersona_Estado]

-- %%
ALTER TABLE [dbo].[TipoPersona] ADD  CONSTRAINT [DF_TipoPersona_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoRegimen_Estado]

-- %%
ALTER TABLE [dbo].[TipoRegimen] ADD  CONSTRAINT [DF_TipoRegimen_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoRetePracticada_Estado]

-- %%
ALTER TABLE [dbo].[TipoRetePracticada] ADD  CONSTRAINT [DF_TipoRetePracticada_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoReteRetenida_Estado]

-- %%
ALTER TABLE [dbo].[TipoReteRetenida] ADD  CONSTRAINT [DF_TipoReteRetenida_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoStatus_Estado]

-- %%
ALTER TABLE [dbo].[TipoStatus] ADD  CONSTRAINT [DF_TipoStatus_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoStatusDian_Estado]

-- %%
ALTER TABLE [dbo].[TipoStatusDian] ADD  CONSTRAINT [DF_TipoStatusDian_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoTarjeta_Imputacion]

-- %%
ALTER TABLE [dbo].[TipoTarjeta] ADD  CONSTRAINT [DF_TipoTarjeta_Imputacion]  DEFAULT (N'DEBITO') FOR [Imputacion]
GO

-- %% [markdown]
-- # [DF_TipoTarjeta_Estado]

-- %%
ALTER TABLE [dbo].[TipoTarjeta] ADD  CONSTRAINT [DF_TipoTarjeta_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_TipoVehiculo_Estado]

-- %%
ALTER TABLE [dbo].[TipoVehiculo] ADD  CONSTRAINT [DF_TipoVehiculo_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Transporte_Estado]

-- %%
ALTER TABLE [dbo].[Transporte] ADD  CONSTRAINT [DF_Transporte_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Transporte_Control]

-- %%
ALTER TABLE [dbo].[Transporte] ADD  CONSTRAINT [DF_Transporte_Control]  DEFAULT (N'MANIFIESTO') FOR [Control]
GO

-- %% [markdown]
-- # [DF_Transporte_PorAnticipo]

-- %%
ALTER TABLE [dbo].[Transporte] ADD  CONSTRAINT [DF_Transporte_PorAnticipo]  DEFAULT ((0)) FOR [PorAnticipo]
GO

-- %% [markdown]
-- # [DF_TransporteInformes_Limite]

-- %%
ALTER TABLE [dbo].[TransporteInformes] ADD  CONSTRAINT [DF_TransporteInformes_Limite]  DEFAULT ((0)) FOR [Limite]
GO

-- %% [markdown]
-- # [DF_Trayectos_Estado]

-- %%
ALTER TABLE [dbo].[Trayectos] ADD  CONSTRAINT [DF_Trayectos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Traza_Fecha]

-- %%
ALTER TABLE [dbo].[Traza] ADD  CONSTRAINT [DF_Traza_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_Tributaria_SancionICA]

-- %%
ALTER TABLE [dbo].[Tributaria] ADD  CONSTRAINT [DF_Tributaria_SancionICA]  DEFAULT ((0)) FOR [SancionICA]
GO

-- %% [markdown]
-- # [DF_Tributaria_SancionRetefuente]

-- %%
ALTER TABLE [dbo].[Tributaria] ADD  CONSTRAINT [DF_Tributaria_SancionRetefuente]  DEFAULT ((0)) FOR [SancionRetefuente]
GO

-- %% [markdown]
-- # [DF_Tributaria_SancionRetecree]

-- %%
ALTER TABLE [dbo].[Tributaria] ADD  CONSTRAINT [DF_Tributaria_SancionRetecree]  DEFAULT ((0)) FOR [SancionRetecree]
GO

-- %% [markdown]
-- # [DF_Unidades_Estado]

-- %%
ALTER TABLE [dbo].[Unidades] ADD  CONSTRAINT [DF_Unidades_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Users_Estado]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Users_Datosbasicos]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Datosbasicos]  DEFAULT ((-1)) FOR [Datosbasicos]
GO

-- %% [markdown]
-- # [DF_Users_Inventarios]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Inventarios]  DEFAULT ((0)) FOR [Inventarios]
GO

-- %% [markdown]
-- # [DF_Users_Tesoreria]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Tesoreria]  DEFAULT ((0)) FOR [Tesoreria]
GO

-- %% [markdown]
-- # [DF_Users_Nomina]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Nomina]  DEFAULT ((0)) FOR [Nomina]
GO

-- %% [markdown]
-- # [DF_Users_Contabilidad]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Contabilidad]  DEFAULT ((0)) FOR [Contabilidad]
GO

-- %% [markdown]
-- # [DF_Users_Activos]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Activos]  DEFAULT ((0)) FOR [Activos]
GO

-- %% [markdown]
-- # [DF_Users_Presupuesto]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Presupuesto]  DEFAULT ((0)) FOR [Presupuesto]
GO

-- %% [markdown]
-- # [DF_Users_Comerciales]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Comerciales]  DEFAULT ((0)) FOR [Comerciales]
GO

-- %% [markdown]
-- # [DF_Users_Validador]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Validador]  DEFAULT ((0)) FOR [Validador]
GO

-- %% [markdown]
-- # [DF_Users_Borrado]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Borrado]  DEFAULT ((-1)) FOR [Borrado]
GO

-- %% [markdown]
-- # [DF_Users_Interfaz]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Interfaz]  DEFAULT ((0)) FOR [Interfaz]
GO

-- %% [markdown]
-- # [DF_Users_VER]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_VER]  DEFAULT ((0)) FOR [VER]
GO

-- %% [markdown]
-- # [DF_Users_Creacion]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Creacion]  DEFAULT ((-1)) FOR [Creacion]
GO

-- %% [markdown]
-- # [DF_Users_Terminal]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Terminal]  DEFAULT ((1)) FOR [Terminal]
GO

-- %% [markdown]
-- # [DF_Users_Validaseguridad]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Validaseguridad]  DEFAULT ((0)) FOR [Validaseguridad]
GO

-- %% [markdown]
-- # [DF_Users_Mostrador]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Mostrador]  DEFAULT ((0)) FOR [Mostrador]
GO

-- %% [markdown]
-- # [DF_Users_Credito]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Credito]  DEFAULT ((0)) FOR [Credito]
GO

-- %% [markdown]
-- # [DF_Users_Diario]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Diario]  DEFAULT ((0)) FOR [Diario]
GO

-- %% [markdown]
-- # [DF_Users_Bprecio]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Bprecio]  DEFAULT ((-1)) FOR [Bprecio]
GO

-- %% [markdown]
-- # [DF_Users_Bprecio1]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Bprecio1]  DEFAULT ((-1)) FOR [Bcentro]
GO

-- %% [markdown]
-- # [DF_Users_Salidas]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Salidas]  DEFAULT ((0)) FOR [Salidas]
GO

-- %% [markdown]
-- # [DF_Users_Parametros]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Parametros]  DEFAULT ((-1)) FOR [Parametros]
GO

-- %% [markdown]
-- # [DF_Users_Cotizaciones]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Cotizaciones]  DEFAULT ((0)) FOR [Cotizaciones]
GO

-- %% [markdown]
-- # [DF_Users_Pedidos]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Pedidos]  DEFAULT ((0)) FOR [Pedidos]
GO

-- %% [markdown]
-- # [DF_Users_Remisiones]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Remisiones]  DEFAULT ((0)) FOR [Remisiones]
GO

-- %% [markdown]
-- # [DF_Users_NotasClientes]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_NotasClientes]  DEFAULT ((0)) FOR [NotasClientes]
GO

-- %% [markdown]
-- # [DF_Users_Inforcomerciales]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Inforcomerciales]  DEFAULT ((0)) FOR [Inforcomerciales]
GO

-- %% [markdown]
-- # [DF_Users_Inforinventario]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Inforinventario]  DEFAULT ((0)) FOR [Inforinventario]
GO

-- %% [markdown]
-- # [DF_Users_Compras]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Compras]  DEFAULT ((0)) FOR [Compras]
GO

-- %% [markdown]
-- # [DF_Users_Traslados]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Traslados]  DEFAULT ((0)) FOR [Traslados]
GO

-- %% [markdown]
-- # [DF_Users_NotasProveedores]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_NotasProveedores]  DEFAULT ((0)) FOR [NotasProveedores]
GO

-- %% [markdown]
-- # [DF_Users_Proceinventarios]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Proceinventarios]  DEFAULT ((0)) FOR [Proceinventarios]
GO

-- %% [markdown]
-- # [DF_Users_Costoventas]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Costoventas]  DEFAULT ((0)) FOR [Costoventas]
GO

-- %% [markdown]
-- # [DF_Users_Recaja]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Recaja]  DEFAULT ((0)) FOR [Recaja]
GO

-- %% [markdown]
-- # [DF_Users_Egreso]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Egreso]  DEFAULT ((0)) FOR [Egreso]
GO

-- %% [markdown]
-- # [DF_Users_Recajavirtual]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Recajavirtual]  DEFAULT ((0)) FOR [Recajavirtual]
GO

-- %% [markdown]
-- # [DF_Users_Egresovirtual]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Egresovirtual]  DEFAULT ((0)) FOR [Egresovirtual]
GO

-- %% [markdown]
-- # [DF_Users_Retiros]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Retiros]  DEFAULT ((0)) FOR [Retiros]
GO

-- %% [markdown]
-- # [DF_Users_Chdevueltos]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Chdevueltos]  DEFAULT ((0)) FOR [Chdevueltos]
GO

-- %% [markdown]
-- # [DF_Users_Infortesoreria]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Infortesoreria]  DEFAULT ((0)) FOR [Infortesoreria]
GO

-- %% [markdown]
-- # [DF_Users_Despachos]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Despachos]  DEFAULT ((0)) FOR [Despachos]
GO

-- %% [markdown]
-- # [DF_Users_Interes]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Interes]  DEFAULT ((0)) FOR [Interes]
GO

-- %% [markdown]
-- # [DF_Users_Validacontable]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Validacontable]  DEFAULT ((0)) FOR [Validacontable]
GO

-- %% [markdown]
-- # [DF_Users_Remote]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Remote]  DEFAULT ((0)) FOR [Remote]
GO

-- %% [markdown]
-- # [DF_Users_Comex]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Comex]  DEFAULT ((0)) FOR [Comex]
GO

-- %% [markdown]
-- # [DF_Users_ControlDO]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_ControlDO]  DEFAULT ((0)) FOR [ControlDO]
GO

-- %% [markdown]
-- # [DF_Users_Trans]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Trans]  DEFAULT ((0)) FOR [Trans]
GO

-- %% [markdown]
-- # [DF_Users_Autentica]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Autentica]  DEFAULT ((0)) FOR [Autentica]
GO

-- %% [markdown]
-- # [DF_Users_Admon]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Admon]  DEFAULT ((0)) FOR [Admon]
GO

-- %% [markdown]
-- # [DF_Users_Produccion]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Produccion]  DEFAULT ((0)) FOR [Produccion]
GO

-- %% [markdown]
-- # [DF_Users_Calcenter]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Calcenter]  DEFAULT ((0)) FOR [Calcenter]
GO

-- %% [markdown]
-- # [DF_Users_Consultafac]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Consultafac]  DEFAULT ((0)) FOR [Consultafac]
GO

-- %% [markdown]
-- # [DF_Users_Aduanas]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Aduanas]  DEFAULT ((0)) FOR [Aduanas]
GO

-- %% [markdown]
-- # [DF_Users_DIAN]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_DIAN]  DEFAULT ((0)) FOR [DIAN]
GO

-- %% [markdown]
-- # [DF_Users_Multiresolucion]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Multiresolucion]  DEFAULT ((0)) FOR [Multiresolucion]
GO

-- %% [markdown]
-- # [DF_Users_Conocimiento]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_Conocimiento]  DEFAULT ((-1)) FOR [Conocimiento]
GO

-- %% [markdown]
-- # [DF_Vehiculos_Peso_vacio]

-- %%
ALTER TABLE [dbo].[Vehiculos] ADD  CONSTRAINT [DF_Vehiculos_Peso_vacio]  DEFAULT ((0)) FOR [Peso_vacio]
GO

-- %% [markdown]
-- # [DF_Vehiculos_CAPACIDAD]

-- %%
ALTER TABLE [dbo].[Vehiculos] ADD  CONSTRAINT [DF_Vehiculos_CAPACIDAD]  DEFAULT ((0)) FOR [CAPACIDAD]
GO

-- %% [markdown]
-- # [DF_Vehiculos_Estado]

-- %%
ALTER TABLE [dbo].[Vehiculos] ADD  CONSTRAINT [DF_Vehiculos_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Vehiculos_Situacion]

-- %%
ALTER TABLE [dbo].[Vehiculos] ADD  CONSTRAINT [DF_Vehiculos_Situacion]  DEFAULT (N'ACTIVADO') FOR [Situacion]
GO

-- %% [markdown]
-- # [DF_Vehiculos_Clase]

-- %%
ALTER TABLE [dbo].[Vehiculos] ADD  CONSTRAINT [DF_Vehiculos_Clase]  DEFAULT (N'CB') FOR [Clase]
GO

-- %% [markdown]
-- # [DF_Vehiculos_Consumo]

-- %%
ALTER TABLE [dbo].[Vehiculos] ADD  CONSTRAINT [DF_Vehiculos_Consumo]  DEFAULT ((0)) FOR [Consumo]
GO

-- %% [markdown]
-- # [DF_VehiculosEjecucion_Dias]

-- %%
ALTER TABLE [dbo].[VehiculosEjecucion] ADD  CONSTRAINT [DF_VehiculosEjecucion_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_VehiculosEjecucion_Lectura]

-- %%
ALTER TABLE [dbo].[VehiculosEjecucion] ADD  CONSTRAINT [DF_VehiculosEjecucion_Lectura]  DEFAULT ((0)) FOR [Lectura]
GO

-- %% [markdown]
-- # [DF_VehiculosEjecucion_Cantidad]

-- %%
ALTER TABLE [dbo].[VehiculosEjecucion] ADD  CONSTRAINT [DF_VehiculosEjecucion_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_VehiculosEjecucion_Costo]

-- %%
ALTER TABLE [dbo].[VehiculosEjecucion] ADD  CONSTRAINT [DF_VehiculosEjecucion_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_VehiculosEjecucion_Estado]

-- %%
ALTER TABLE [dbo].[VehiculosEjecucion] ADD  CONSTRAINT [DF_VehiculosEjecucion_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_VehiculosEjecucion_Status]

-- %%
ALTER TABLE [dbo].[VehiculosEjecucion] ADD  CONSTRAINT [DF_VehiculosEjecucion_Status]  DEFAULT (N'EJECUCION') FOR [Status]
GO

-- %% [markdown]
-- # [DF_Vehiculosmanteniento_Dias]

-- %%
ALTER TABLE [dbo].[Vehiculosmanteniento] ADD  CONSTRAINT [DF_Vehiculosmanteniento_Dias]  DEFAULT ((0)) FOR [Dias]
GO

-- %% [markdown]
-- # [DF_Vehiculosmanteniento_Lectura]

-- %%
ALTER TABLE [dbo].[Vehiculosmanteniento] ADD  CONSTRAINT [DF_Vehiculosmanteniento_Lectura]  DEFAULT ((0)) FOR [Lectura]
GO

-- %% [markdown]
-- # [DF_Vehiculosmanteniento_Cantidad]

-- %%
ALTER TABLE [dbo].[Vehiculosmanteniento] ADD  CONSTRAINT [DF_Vehiculosmanteniento_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Vehiculosmanteniento_Costo]

-- %%
ALTER TABLE [dbo].[Vehiculosmanteniento] ADD  CONSTRAINT [DF_Vehiculosmanteniento_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_Vehiculosmanteniento_Estado]

-- %%
ALTER TABLE [dbo].[Vehiculosmanteniento] ADD  CONSTRAINT [DF_Vehiculosmanteniento_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Vehiculosmanteniento_Status]

-- %%
ALTER TABLE [dbo].[Vehiculosmanteniento] ADD  CONSTRAINT [DF_Vehiculosmanteniento_Status]  DEFAULT (N'PLANEACION') FOR [Status]
GO

-- %% [markdown]
-- # [DF_Vehiculosmanteniento_Fplaneacion]

-- %%
ALTER TABLE [dbo].[Vehiculosmanteniento] ADD  CONSTRAINT [DF_Vehiculosmanteniento_Fplaneacion]  DEFAULT (getdate()) FOR [Fplaneacion]
GO

-- %% [markdown]
-- # [DF_VehiculosPendientes_Estado]

-- %%
ALTER TABLE [dbo].[VehiculosPendientes] ADD  CONSTRAINT [DF_VehiculosPendientes_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Verificacion_Estado]

-- %%
ALTER TABLE [dbo].[Verificacion] ADD  CONSTRAINT [DF_Verificacion_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_Verificacionsub_Cantidad]

-- %%
ALTER TABLE [dbo].[Verificacionsub] ADD  CONSTRAINT [DF_Verificacionsub_Cantidad]  DEFAULT ((0)) FOR [Cantidad]
GO

-- %% [markdown]
-- # [DF_Verificacionsub_Us]

-- %%
ALTER TABLE [dbo].[Verificacionsub] ADD  CONSTRAINT [DF_Verificacionsub_Us]  DEFAULT ((0)) FOR [Us]
GO

-- %% [markdown]
-- # [DF_Verificacionsub_Precio]

-- %%
ALTER TABLE [dbo].[Verificacionsub] ADD  CONSTRAINT [DF_Verificacionsub_Precio]  DEFAULT ((0)) FOR [Precio]
GO

-- %% [markdown]
-- # [DF_Verificacionsub_PIva]

-- %%
ALTER TABLE [dbo].[Verificacionsub] ADD  CONSTRAINT [DF_Verificacionsub_PIva]  DEFAULT ((0)) FOR [PIva]
GO

-- %% [markdown]
-- # [DF_Verificacionsub_Costo]

-- %%
ALTER TABLE [dbo].[Verificacionsub] ADD  CONSTRAINT [DF_Verificacionsub_Costo]  DEFAULT ((0)) FOR [Costo]
GO

-- %% [markdown]
-- # [DF_VersionDocumental_Estado]

-- %%
ALTER TABLE [dbo].[VersionDocumental] ADD  CONSTRAINT [DF_VersionDocumental_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Estado]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Tipo]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Tipo]  DEFAULT (N'Pago Virtual') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Fecha]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Ciudad]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Ciudad]  DEFAULT (N'Bogotá, D.C.') FOR [Ciudad]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Document]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Document]  DEFAULT (N'CH') FOR [Document]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Documento]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Documento]  DEFAULT (N'CEV') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_PDesc]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_PDesc]  DEFAULT ((0)) FOR [PDesc]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Descuento]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_PRetencion]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_PRetencion]  DEFAULT ((0)) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Retefuente]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Retefuente]  DEFAULT ((0)) FOR [Retefuente]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Pagar]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Pagar]  DEFAULT ((0)) FOR [Pagar]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Netor]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Netor]  DEFAULT ((0)) FOR [Netor]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Ivar]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Ivar]  DEFAULT ((0)) FOR [Ivar]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Pivar]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Pivar]  DEFAULT ((0)) FOR [Pivar]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_PReteIca]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_ReteIca]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_ReteIca]  DEFAULT ((0)) FOR [ReteIca]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_PReteIva]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_ReteIva]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_ReteIva]  DEFAULT ((0)) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Adicion]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Adicion]  DEFAULT ((0)) FOR [Adicion]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Banco]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Banco]  DEFAULT (N'TRANSFERENCIA') FOR [Banco]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Comprobante]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Comprobante]  DEFAULT ((0)) FOR [Comprobante]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Fproceso]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_TipoRetencion]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_TipoRetencion]  DEFAULT ((2302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_DO]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_DO]  DEFAULT ((0)) FOR [DO]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_DifCambio]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_DifCambio]  DEFAULT ((0)) FOR [DifCambio]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Pcree]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Pcree]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_VirtualCEgreso_Retecree]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso] ADD  CONSTRAINT [DF_VirtualCEgreso_Retecree]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_Estado]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_Tipo]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_Tipo]  DEFAULT (N'Pago Virtual') FOR [Tipo]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_Ciudad]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_Ciudad]  DEFAULT (N'Bogotá, D.C.') FOR [Ciudad]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_Fecha]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_Fecha]  DEFAULT (CONVERT([datetime],CONVERT([varchar],getdate(),(1)),(1))) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_Documento]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_Documento]  DEFAULT (N'RCV') FOR [Documento]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_PDesc]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_PDesc]  DEFAULT ((0)) FOR [PDesc]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_Descuento]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_Descuento]  DEFAULT ((0)) FOR [Descuento]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_PRetencion]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_PRetencion]  DEFAULT ((0)) FOR [PRetencion]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_Retefuente]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_Retefuente]  DEFAULT ((0)) FOR [Retefuente]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_Pagar]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_Pagar]  DEFAULT ((0)) FOR [Pagar]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_Netor]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_Netor]  DEFAULT ((0)) FOR [Netor]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_Ivar]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_Ivar]  DEFAULT ((0)) FOR [Ivar]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_Pivar]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_Pivar]  DEFAULT ((0)) FOR [Pivar]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_PReteIca]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_PReteIca]  DEFAULT ((0)) FOR [PReteIca]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_ReteIca]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_ReteIca]  DEFAULT ((0)) FOR [ReteIca]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_PReteIva]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_PReteIva]  DEFAULT ((0)) FOR [PReteIva]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_ReteIva]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_ReteIva]  DEFAULT ((0)) FOR [ReteIva]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_Adicion]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_Adicion]  DEFAULT ((0)) FOR [Adicion]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_Fproceso]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_Fproceso]  DEFAULT (getdate()) FOR [Fproceso]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_TipoRetencion]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_TipoRetencion]  DEFAULT ((1302)) FOR [TipoRetencion]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_DifCambio]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_DifCambio]  DEFAULT ((0)) FOR [DifCambio]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_Pcree]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_Pcree]  DEFAULT ((0)) FOR [Pcree]
GO

-- %% [markdown]
-- # [DF_VirtualRecaja_Retecree]

-- %%
ALTER TABLE [dbo].[VirtualRecaja] ADD  CONSTRAINT [DF_VirtualRecaja_Retecree]  DEFAULT ((0)) FOR [Retecree]
GO

-- %% [markdown]
-- # [DF_Zonas_Estado]

-- %%
ALTER TABLE [dbo].[Zonas] ADD  CONSTRAINT [DF_Zonas_Estado]  DEFAULT ((0)) FOR [Estado]
GO

-- %% [markdown]
-- # [FK_Activosub_Activos]

-- %%
ALTER TABLE [dbo].[Activosub]  WITH NOCHECK ADD  CONSTRAINT [FK_Activosub_Activos] FOREIGN KEY([IdActivo])
REFERENCES [dbo].[Activos] ([IdActivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Activosub] CHECK CONSTRAINT [FK_Activosub_Activos]
GO

-- %% [markdown]
-- # [FK_Adicionsub_Adicion]

-- %%
ALTER TABLE [dbo].[Adicionsub]  WITH CHECK ADD  CONSTRAINT [FK_Adicionsub_Adicion] FOREIGN KEY([TransferNo])
REFERENCES [dbo].[Adicion] ([TransferNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Adicionsub] CHECK CONSTRAINT [FK_Adicionsub_Adicion]
GO

-- %% [markdown]
-- # [FK_AduanaLiqsub_AduanaLiq]

-- %%
ALTER TABLE [dbo].[AduanaLiqsub]  WITH CHECK ADD  CONSTRAINT [FK_AduanaLiqsub_AduanaLiq] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[AduanaLiq] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[AduanaLiqsub] CHECK CONSTRAINT [FK_AduanaLiqsub_AduanaLiq]
GO

-- %% [markdown]
-- # [FK_Afactura_Recaja]

-- %%
ALTER TABLE [dbo].[Afactura]  WITH CHECK ADD  CONSTRAINT [FK_Afactura_Recaja] FOREIGN KEY([IdCaja])
REFERENCES [dbo].[Recaja] ([Idcaja])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Afactura] CHECK CONSTRAINT [FK_Afactura_Recaja]
GO

-- %% [markdown]
-- # [FK_Afacturaegreso_Comprobanteegreso]

-- %%
ALTER TABLE [dbo].[Afacturaegreso]  WITH CHECK ADD  CONSTRAINT [FK_Afacturaegreso_Comprobanteegreso] FOREIGN KEY([IdEgreso])
REFERENCES [dbo].[Comprobanteegreso] ([Idegreso])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Afacturaegreso] CHECK CONSTRAINT [FK_Afacturaegreso_Comprobanteegreso]
GO

-- %% [markdown]
-- # [FK_AfacturaEgresoVirtual_VirtualCEgreso]

-- %%
ALTER TABLE [dbo].[AfacturaEgresoVirtual]  WITH CHECK ADD  CONSTRAINT [FK_AfacturaEgresoVirtual_VirtualCEgreso] FOREIGN KEY([IdEgreso])
REFERENCES [dbo].[VirtualCEgreso] ([Idegreso])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[AfacturaEgresoVirtual] CHECK CONSTRAINT [FK_AfacturaEgresoVirtual_VirtualCEgreso]
GO

-- %% [markdown]
-- # [FK_AfacturaVirtual_VirtualRecaja]

-- %%
ALTER TABLE [dbo].[AfacturaVirtual]  WITH CHECK ADD  CONSTRAINT [FK_AfacturaVirtual_VirtualRecaja] FOREIGN KEY([IdCaja])
REFERENCES [dbo].[VirtualRecaja] ([Idcaja])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[AfacturaVirtual] CHECK CONSTRAINT [FK_AfacturaVirtual_VirtualRecaja]
GO

-- %% [markdown]
-- # [FK_Aghouseanexos_Aghouse]

-- %%
ALTER TABLE [dbo].[Aghouseanexos]  WITH CHECK ADD  CONSTRAINT [FK_Aghouseanexos_Aghouse] FOREIGN KEY([Norden])
REFERENCES [dbo].[Aghouse] ([Norden])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Aghouseanexos] CHECK CONSTRAINT [FK_Aghouseanexos_Aghouse]
GO

-- %% [markdown]
-- # [FK_Aghousecontenedor_Aghouse]

-- %%
ALTER TABLE [dbo].[Aghousecontenedor]  WITH CHECK ADD  CONSTRAINT [FK_Aghousecontenedor_Aghouse] FOREIGN KEY([Norden])
REFERENCES [dbo].[Aghouse] ([Norden])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Aghousecontenedor] CHECK CONSTRAINT [FK_Aghousecontenedor_Aghouse]
GO

-- %% [markdown]
-- # [FK_Aghousefletes_Aghouse]

-- %%
ALTER TABLE [dbo].[Aghousefletes]  WITH CHECK ADD  CONSTRAINT [FK_Aghousefletes_Aghouse] FOREIGN KEY([Norden])
REFERENCES [dbo].[Aghouse] ([Norden])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Aghousefletes] CHECK CONSTRAINT [FK_Aghousefletes_Aghouse]
GO

-- %% [markdown]
-- # [FK_Aghouseservicios_Aghouse]

-- %%
ALTER TABLE [dbo].[Aghouseservicios]  WITH CHECK ADD  CONSTRAINT [FK_Aghouseservicios_Aghouse] FOREIGN KEY([Norden])
REFERENCES [dbo].[Aghouse] ([Norden])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Aghouseservicios] CHECK CONSTRAINT [FK_Aghouseservicios_Aghouse]
GO

-- %% [markdown]
-- # [FK_Agordenrutaanexos_Agordenruta]

-- %%
ALTER TABLE [dbo].[Agordenrutaanexos]  WITH CHECK ADD  CONSTRAINT [FK_Agordenrutaanexos_Agordenruta] FOREIGN KEY([Norden])
REFERENCES [dbo].[Agordenruta] ([Norden])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Agordenrutaanexos] CHECK CONSTRAINT [FK_Agordenrutaanexos_Agordenruta]
GO

-- %% [markdown]
-- # [FK_Agordenrutacontenedor_Agordenruta]

-- %%
ALTER TABLE [dbo].[Agordenrutacontenedor]  WITH CHECK ADD  CONSTRAINT [FK_Agordenrutacontenedor_Agordenruta] FOREIGN KEY([Norden])
REFERENCES [dbo].[Agordenruta] ([Norden])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Agordenrutacontenedor] CHECK CONSTRAINT [FK_Agordenrutacontenedor_Agordenruta]
GO

-- %% [markdown]
-- # [FK_Agordenrutafletes_Agordenruta]

-- %%
ALTER TABLE [dbo].[Agordenrutafletes]  WITH CHECK ADD  CONSTRAINT [FK_Agordenrutafletes_Agordenruta] FOREIGN KEY([Norden])
REFERENCES [dbo].[Agordenruta] ([Norden])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Agordenrutafletes] CHECK CONSTRAINT [FK_Agordenrutafletes_Agordenruta]
GO

-- %% [markdown]
-- # [FK_Agordenrutaservicios_Agordenruta]

-- %%
ALTER TABLE [dbo].[Agordenrutaservicios]  WITH CHECK ADD  CONSTRAINT [FK_Agordenrutaservicios_Agordenruta] FOREIGN KEY([Norden])
REFERENCES [dbo].[Agordenruta] ([Norden])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Agordenrutaservicios] CHECK CONSTRAINT [FK_Agordenrutaservicios_Agordenruta]
GO

-- %% [markdown]
-- # [FK_Agseguimiento_Agordenruta]

-- %%
ALTER TABLE [dbo].[Agseguimiento]  WITH CHECK ADD  CONSTRAINT [FK_Agseguimiento_Agordenruta] FOREIGN KEY([Norden])
REFERENCES [dbo].[Agordenruta] ([Norden])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Agseguimiento] CHECK CONSTRAINT [FK_Agseguimiento_Agordenruta]
GO

-- %% [markdown]
-- # [FK_Agseguimientohouse_Aghouse]

-- %%
ALTER TABLE [dbo].[Agseguimientohouse]  WITH CHECK ADD  CONSTRAINT [FK_Agseguimientohouse_Aghouse] FOREIGN KEY([Norden])
REFERENCES [dbo].[Aghouse] ([Norden])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Agseguimientohouse] CHECK CONSTRAINT [FK_Agseguimientohouse_Aghouse]
GO

-- %% [markdown]
-- # [FK_Anticipos_Empleado]

-- %%
ALTER TABLE [dbo].[Anticipos]  WITH CHECK ADD  CONSTRAINT [FK_Anticipos_Empleado] FOREIGN KEY([Nombre])
REFERENCES [dbo].[Empleado] ([Cedula])
GO
ALTER TABLE [dbo].[Anticipos] CHECK CONSTRAINT [FK_Anticipos_Empleado]
GO

-- %% [markdown]
-- # [FK_Anticipossub_Anticipos]

-- %%
ALTER TABLE [dbo].[Anticipossub]  WITH CHECK ADD  CONSTRAINT [FK_Anticipossub_Anticipos] FOREIGN KEY([idAnticipos])
REFERENCES [dbo].[Anticipos] ([IdAnticipos])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Anticipossub] CHECK CONSTRAINT [FK_Anticipossub_Anticipos]
GO

-- %% [markdown]
-- # [FK_BaseConductor_Conductores]

-- %%
ALTER TABLE [dbo].[BaseConductor]  WITH NOCHECK ADD  CONSTRAINT [FK_BaseConductor_Conductores] FOREIGN KEY([Cedula])
REFERENCES [dbo].[Conductores] ([Cedula])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[BaseConductor] CHECK CONSTRAINT [FK_BaseConductor_Conductores]
GO

-- %% [markdown]
-- # [FK_BaseContenedor_Cumplido]

-- %%
ALTER TABLE [dbo].[BaseContenedor]  WITH NOCHECK ADD  CONSTRAINT [FK_BaseContenedor_Cumplido] FOREIGN KEY([Remesa])
REFERENCES [dbo].[Cumplido] ([CumplidoNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[BaseContenedor] CHECK CONSTRAINT [FK_BaseContenedor_Cumplido]
GO

-- %% [markdown]
-- # [FK_BaseVehiculos_Vehiculos]

-- %%
ALTER TABLE [dbo].[BaseVehiculos]  WITH NOCHECK ADD  CONSTRAINT [FK_BaseVehiculos_Vehiculos] FOREIGN KEY([Placa2])
REFERENCES [dbo].[Vehiculos] ([Placa])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[BaseVehiculos] CHECK CONSTRAINT [FK_BaseVehiculos_Vehiculos]
GO

-- %% [markdown]
-- # [FK_CajaMenor_AgrupaMenor]

-- %%
ALTER TABLE [dbo].[CajaMenor]  WITH CHECK ADD  CONSTRAINT [FK_CajaMenor_AgrupaMenor] FOREIGN KEY([Grupo])
REFERENCES [dbo].[AgrupaMenor] ([Grupo])
GO
ALTER TABLE [dbo].[CajaMenor] CHECK CONSTRAINT [FK_CajaMenor_AgrupaMenor]
GO

-- %% [markdown]
-- # [FK_CajaMenor_Terceros]

-- %%
ALTER TABLE [dbo].[CajaMenor]  WITH CHECK ADD  CONSTRAINT [FK_CajaMenor_Terceros] FOREIGN KEY([Identificacion])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[CajaMenor] CHECK CONSTRAINT [FK_CajaMenor_Terceros]
GO

-- %% [markdown]
-- # [FK_Certificados_Alumnos]

-- %%
ALTER TABLE [dbo].[Certificados]  WITH CHECK ADD  CONSTRAINT [FK_Certificados_Alumnos] FOREIGN KEY([Codigo])
REFERENCES [dbo].[Alumnos] ([Codigo])
GO
ALTER TABLE [dbo].[Certificados] CHECK CONSTRAINT [FK_Certificados_Alumnos]
GO

-- %% [markdown]
-- # [FK_Chequesrecibidos_Recaja]

-- %%
ALTER TABLE [dbo].[Chequesrecibidos]  WITH CHECK ADD  CONSTRAINT [FK_Chequesrecibidos_Recaja] FOREIGN KEY([IdCaja])
REFERENCES [dbo].[Recaja] ([Idcaja])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Chequesrecibidos] CHECK CONSTRAINT [FK_Chequesrecibidos_Recaja]
GO

-- %% [markdown]
-- # [FK_Cierrecontratosub_Cierrecontrato]

-- %%
ALTER TABLE [dbo].[Cierrecontratosub]  WITH CHECK ADD  CONSTRAINT [FK_Cierrecontratosub_Cierrecontrato] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Cierrecontrato] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Cierrecontratosub] CHECK CONSTRAINT [FK_Cierrecontratosub_Cierrecontrato]
GO

-- %% [markdown]
-- # [FK_Cierredosub_Cierredo]

-- %%
ALTER TABLE [dbo].[Cierredosub]  WITH CHECK ADD  CONSTRAINT [FK_Cierredosub_Cierredo] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Cierredo] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Cierredosub] CHECK CONSTRAINT [FK_Cierredosub_Cierredo]
GO

-- %% [markdown]
-- # [FK_Cierrelineasub_Cierrelinea]

-- %%
ALTER TABLE [dbo].[Cierrelineasub]  WITH CHECK ADD  CONSTRAINT [FK_Cierrelineasub_Cierrelinea] FOREIGN KEY([idcierre])
REFERENCES [dbo].[Cierrelinea] ([idcierre])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Cierrelineasub] CHECK CONSTRAINT [FK_Cierrelineasub_Cierrelinea]
GO

-- %% [markdown]
-- # [FK_Coberturas_TipoCoberturas]

-- %%
ALTER TABLE [dbo].[Coberturas]  WITH CHECK ADD  CONSTRAINT [FK_Coberturas_TipoCoberturas] FOREIGN KEY([Cobertura])
REFERENCES [dbo].[TipoCoberturas] ([Cobertura])
GO
ALTER TABLE [dbo].[Coberturas] CHECK CONSTRAINT [FK_Coberturas_TipoCoberturas]
GO

-- %% [markdown]
-- # [FK_Comprasub_Compras]

-- %%
ALTER TABLE [dbo].[Comprasub]  WITH CHECK ADD  CONSTRAINT [FK_Comprasub_Compras] FOREIGN KEY([Nofacturap], [Proveedor])
REFERENCES [dbo].[Compras] ([Nofacturap], [Proveedor])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Comprasub] CHECK CONSTRAINT [FK_Comprasub_Compras]
GO

-- %% [markdown]
-- # [FK_Comprobanteegreso_Terceros]

-- %%
ALTER TABLE [dbo].[Comprobanteegreso]  WITH NOCHECK ADD  CONSTRAINT [FK_Comprobanteegreso_Terceros] FOREIGN KEY([Pagado a])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Comprobanteegreso] CHECK CONSTRAINT [FK_Comprobanteegreso_Terceros]
GO

-- %% [markdown]
-- # [FK_ConBL_ConRecalada]

-- %%
ALTER TABLE [dbo].[ConBL]  WITH CHECK ADD  CONSTRAINT [FK_ConBL_ConRecalada] FOREIGN KEY([Recalada])
REFERENCES [dbo].[ConRecalada] ([RecaladaNo])
GO
ALTER TABLE [dbo].[ConBL] CHECK CONSTRAINT [FK_ConBL_ConRecalada]
GO

-- %% [markdown]
-- # [FK_ConbokingFte_Conbooking]

-- %%
ALTER TABLE [dbo].[ConbokingFte]  WITH CHECK ADD  CONSTRAINT [FK_ConbokingFte_Conbooking] FOREIGN KEY([Boking])
REFERENCES [dbo].[Conbooking] ([Booking])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[ConbokingFte] CHECK CONSTRAINT [FK_ConbokingFte_Conbooking]
GO

-- %% [markdown]
-- # [FK_Conboocntr_Conbooking]

-- %%
ALTER TABLE [dbo].[Conboocntr]  WITH CHECK ADD  CONSTRAINT [FK_Conboocntr_Conbooking] FOREIGN KEY([Boking])
REFERENCES [dbo].[Conbooking] ([Booking])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Conboocntr] CHECK CONSTRAINT [FK_Conboocntr_Conbooking]
GO

-- %% [markdown]
-- # [FK_ConceptosMedios_Comprobanteegreso]

-- %%
ALTER TABLE [dbo].[ConceptosMedios]  WITH CHECK ADD  CONSTRAINT [FK_ConceptosMedios_Comprobanteegreso] FOREIGN KEY([IdEgreso])
REFERENCES [dbo].[Comprobanteegreso] ([Idegreso])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[ConceptosMedios] CHECK CONSTRAINT [FK_ConceptosMedios_Comprobanteegreso]
GO

-- %% [markdown]
-- # [FK_ConceptosMedios_TipoPago]

-- %%
ALTER TABLE [dbo].[ConceptosMedios]  WITH CHECK ADD  CONSTRAINT [FK_ConceptosMedios_TipoPago] FOREIGN KEY([Concepto])
REFERENCES [dbo].[TipoPago] ([Codigo])
GO
ALTER TABLE [dbo].[ConceptosMedios] CHECK CONSTRAINT [FK_ConceptosMedios_TipoPago]
GO

-- %% [markdown]
-- # [FK_ConceptosMediosVir_TipoPago]

-- %%
ALTER TABLE [dbo].[ConceptosMediosVir]  WITH NOCHECK ADD  CONSTRAINT [FK_ConceptosMediosVir_TipoPago] FOREIGN KEY([Concepto])
REFERENCES [dbo].[TipoPago] ([Codigo])
GO
ALTER TABLE [dbo].[ConceptosMediosVir] CHECK CONSTRAINT [FK_ConceptosMediosVir_TipoPago]
GO

-- %% [markdown]
-- # [FK_ConceptosMediosVir_VirtualCEgreso]

-- %%
ALTER TABLE [dbo].[ConceptosMediosVir]  WITH NOCHECK ADD  CONSTRAINT [FK_ConceptosMediosVir_VirtualCEgreso] FOREIGN KEY([IdEgreso])
REFERENCES [dbo].[VirtualCEgreso] ([Idegreso])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[ConceptosMediosVir] CHECK CONSTRAINT [FK_ConceptosMediosVir_VirtualCEgreso]
GO

-- %% [markdown]
-- # [FK_ConContenedor_ConBL]

-- %%
ALTER TABLE [dbo].[ConContenedor]  WITH CHECK ADD  CONSTRAINT [FK_ConContenedor_ConBL] FOREIGN KEY([BLNo])
REFERENCES [dbo].[ConBL] ([BLNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[ConContenedor] CHECK CONSTRAINT [FK_ConContenedor_ConBL]
GO

-- %% [markdown]
-- # [FK_ConductorPendientes_Conductores]

-- %%
ALTER TABLE [dbo].[ConductorPendientes]  WITH NOCHECK ADD  CONSTRAINT [FK_ConductorPendientes_Conductores] FOREIGN KEY([Cedula])
REFERENCES [dbo].[Conductores] ([Cedula])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[ConductorPendientes] CHECK CONSTRAINT [FK_ConductorPendientes_Conductores]
GO

-- %% [markdown]
-- # [FK_ConFletes_ConBL]

-- %%
ALTER TABLE [dbo].[ConFletes]  WITH CHECK ADD  CONSTRAINT [FK_ConFletes_ConBL] FOREIGN KEY([BLNo])
REFERENCES [dbo].[ConBL] ([BLNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[ConFletes] CHECK CONSTRAINT [FK_ConFletes_ConBL]
GO

-- %% [markdown]
-- # [FK_Conguiasreparsub_Conguiasrepar]

-- %%
ALTER TABLE [dbo].[Conguiasreparsub]  WITH CHECK ADD  CONSTRAINT [FK_Conguiasreparsub_Conguiasrepar] FOREIGN KEY([Contenedor], [FEntrada])
REFERENCES [dbo].[Conguiasrepar] ([Contenedor], [FEntrada])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Conguiasreparsub] CHECK CONSTRAINT [FK_Conguiasreparsub_Conguiasrepar]
GO

-- %% [markdown]
-- # [FK_ConRecalada_ConMotonaves]

-- %%
ALTER TABLE [dbo].[ConRecalada]  WITH CHECK ADD  CONSTRAINT [FK_ConRecalada_ConMotonaves] FOREIGN KEY([Motonave])
REFERENCES [dbo].[ConMotonaves] ([Codigo])
GO
ALTER TABLE [dbo].[ConRecalada] CHECK CONSTRAINT [FK_ConRecalada_ConMotonaves]
GO

-- %% [markdown]
-- # [FK_ConsultaCostos_Referencias]

-- %%
ALTER TABLE [dbo].[ConsultaCostos]  WITH NOCHECK ADD  CONSTRAINT [FK_ConsultaCostos_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[ConsultaCostos] CHECK CONSTRAINT [FK_ConsultaCostos_Referencias]
GO

-- %% [markdown]
-- # [FK_ContenedorPendientes_Cumplido]

-- %%
ALTER TABLE [dbo].[ContenedorPendientes]  WITH NOCHECK ADD  CONSTRAINT [FK_ContenedorPendientes_Cumplido] FOREIGN KEY([Remesa])
REFERENCES [dbo].[Cumplido] ([CumplidoNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[ContenedorPendientes] CHECK CONSTRAINT [FK_ContenedorPendientes_Cumplido]
GO

-- %% [markdown]
-- # [FK_ContenedorPendientes_TipoContenedores]

-- %%
ALTER TABLE [dbo].[ContenedorPendientes]  WITH NOCHECK ADD  CONSTRAINT [FK_ContenedorPendientes_TipoContenedores] FOREIGN KEY([Tipo])
REFERENCES [dbo].[TipoContenedores] ([TipoPendiente])
GO
ALTER TABLE [dbo].[ContenedorPendientes] CHECK CONSTRAINT [FK_ContenedorPendientes_TipoContenedores]
GO

-- %% [markdown]
-- # [FK_Contratos_Terceros]

-- %%
ALTER TABLE [dbo].[Contratos]  WITH NOCHECK ADD  CONSTRAINT [FK_Contratos_Terceros] FOREIGN KEY([Tercero])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Contratos] CHECK CONSTRAINT [FK_Contratos_Terceros]
GO

-- %% [markdown]
-- # [FK_Contratosub_Contratos]

-- %%
ALTER TABLE [dbo].[Contratosub]  WITH CHECK ADD  CONSTRAINT [FK_Contratosub_Contratos] FOREIGN KEY([ContratoNo])
REFERENCES [dbo].[Contratos] ([ContratoNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Contratosub] CHECK CONSTRAINT [FK_Contratosub_Contratos]
GO

-- %% [markdown]
-- # [FK_CostosCIF2_CostosCIF]

-- %%
ALTER TABLE [dbo].[CostosCIF2]  WITH CHECK ADD  CONSTRAINT [FK_CostosCIF2_CostosCIF] FOREIGN KEY([Orden])
REFERENCES [dbo].[CostosCIF] ([Orden])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[CostosCIF2] CHECK CONSTRAINT [FK_CostosCIF2_CostosCIF]
GO

-- %% [markdown]
-- # [FK_CostosCIF2_Referencias]

-- %%
ALTER TABLE [dbo].[CostosCIF2]  WITH NOCHECK ADD  CONSTRAINT [FK_CostosCIF2_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[CostosCIF2] CHECK CONSTRAINT [FK_CostosCIF2_Referencias]
GO

-- %% [markdown]
-- # [FK_Cotizacion_Terceros]

-- %%
ALTER TABLE [dbo].[Cotizacion]  WITH NOCHECK ADD  CONSTRAINT [FK_Cotizacion_Terceros] FOREIGN KEY([Nombre])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Cotizacion] CHECK CONSTRAINT [FK_Cotizacion_Terceros]
GO

-- %% [markdown]
-- # [FK_Cotizacioninsumos_Cotizacion]

-- %%
ALTER TABLE [dbo].[Cotizacioninsumos]  WITH CHECK ADD  CONSTRAINT [FK_Cotizacioninsumos_Cotizacion] FOREIGN KEY([Cotizacion])
REFERENCES [dbo].[Cotizacion] ([NCotizacion])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Cotizacioninsumos] CHECK CONSTRAINT [FK_Cotizacioninsumos_Cotizacion]
GO

-- %% [markdown]
-- # [FK_Cotizacionsub_Cotizacion]

-- %%
ALTER TABLE [dbo].[Cotizacionsub]  WITH NOCHECK ADD  CONSTRAINT [FK_Cotizacionsub_Cotizacion] FOREIGN KEY([NCotizacion])
REFERENCES [dbo].[Cotizacion] ([NCotizacion])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Cotizacionsub] CHECK CONSTRAINT [FK_Cotizacionsub_Cotizacion]
GO

-- %% [markdown]
-- # [FK_Cotizacionsub_Referencias]

-- %%
ALTER TABLE [dbo].[Cotizacionsub]  WITH NOCHECK ADD  CONSTRAINT [FK_Cotizacionsub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Cotizacionsub] CHECK CONSTRAINT [FK_Cotizacionsub_Referencias]
GO

-- %% [markdown]
-- # [FK_CotizaDimensiones_Cotizacion]

-- %%
ALTER TABLE [dbo].[CotizaDimensiones]  WITH CHECK ADD  CONSTRAINT [FK_CotizaDimensiones_Cotizacion] FOREIGN KEY([NCotizacion])
REFERENCES [dbo].[Cotizacion] ([NCotizacion])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[CotizaDimensiones] CHECK CONSTRAINT [FK_CotizaDimensiones_Cotizacion]
GO

-- %% [markdown]
-- # [FK_Crucecuenta_Terceros]

-- %%
ALTER TABLE [dbo].[Crucecuenta]  WITH CHECK ADD  CONSTRAINT [FK_Crucecuenta_Terceros] FOREIGN KEY([Tercero])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Crucecuenta] CHECK CONSTRAINT [FK_Crucecuenta_Terceros]
GO

-- %% [markdown]
-- # [FK_Crucecuentasub_Crucecuenta]

-- %%
ALTER TABLE [dbo].[Crucecuentasub]  WITH CHECK ADD  CONSTRAINT [FK_Crucecuentasub_Crucecuenta] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Crucecuenta] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Crucecuentasub] CHECK CONSTRAINT [FK_Crucecuentasub_Crucecuenta]
GO

-- %% [markdown]
-- # [FK_Ctrafico_CtraficoMatrix]

-- %%
ALTER TABLE [dbo].[Ctrafico]  WITH CHECK ADD  CONSTRAINT [FK_Ctrafico_CtraficoMatrix] FOREIGN KEY([Ruta])
REFERENCES [dbo].[CtraficoMatrix] ([Ruta])
GO
ALTER TABLE [dbo].[Ctrafico] CHECK CONSTRAINT [FK_Ctrafico_CtraficoMatrix]
GO

-- %% [markdown]
-- # [FK_CtraficoMatrixsub_CtraficoMatrix]

-- %%
ALTER TABLE [dbo].[CtraficoMatrixsub]  WITH CHECK ADD  CONSTRAINT [FK_CtraficoMatrixsub_CtraficoMatrix] FOREIGN KEY([Ruta])
REFERENCES [dbo].[CtraficoMatrix] ([Ruta])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[CtraficoMatrixsub] CHECK CONSTRAINT [FK_CtraficoMatrixsub_CtraficoMatrix]
GO

-- %% [markdown]
-- # [FK_Ctraficosub_CPuestos]

-- %%
ALTER TABLE [dbo].[Ctraficosub]  WITH NOCHECK ADD  CONSTRAINT [FK_Ctraficosub_CPuestos] FOREIGN KEY([PuestoControl])
REFERENCES [dbo].[CPuestos] ([Puesto])
GO
ALTER TABLE [dbo].[Ctraficosub] CHECK CONSTRAINT [FK_Ctraficosub_CPuestos]
GO

-- %% [markdown]
-- # [FK_Ctraficosub_Ctrafico]

-- %%
ALTER TABLE [dbo].[Ctraficosub]  WITH NOCHECK ADD  CONSTRAINT [FK_Ctraficosub_Ctrafico] FOREIGN KEY([ControlNo])
REFERENCES [dbo].[Ctrafico] ([ControlNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Ctraficosub] CHECK CONSTRAINT [FK_Ctraficosub_Ctrafico]
GO

-- %% [markdown]
-- # [FK_Cuentas de cobro_Terceros]

-- %%
ALTER TABLE [dbo].[Cuentas de cobro]  WITH NOCHECK ADD  CONSTRAINT [FK_Cuentas de cobro_Terceros] FOREIGN KEY([ACREEDOR])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Cuentas de cobro] CHECK CONSTRAINT [FK_Cuentas de cobro_Terceros]
GO

-- %% [markdown]
-- # [FK_Cuentasub_Cuentas de cobro]

-- %%
ALTER TABLE [dbo].[Cuentasub]  WITH CHECK ADD  CONSTRAINT [FK_Cuentasub_Cuentas de cobro] FOREIGN KEY([IdCuenta])
REFERENCES [dbo].[Cuentas de cobro] ([IdCuenta])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Cuentasub] CHECK CONSTRAINT [FK_Cuentasub_Cuentas de cobro]
GO

-- %% [markdown]
-- # [FK_Cuentasub_Referencias]

-- %%
ALTER TABLE [dbo].[Cuentasub]  WITH NOCHECK ADD  CONSTRAINT [FK_Cuentasub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Cuentasub] CHECK CONSTRAINT [FK_Cuentasub_Referencias]
GO

-- %% [markdown]
-- # [FK_Cuentasubdescuentos_Cuentas de cobro]

-- %%
ALTER TABLE [dbo].[Cuentasubdescuentos]  WITH CHECK ADD  CONSTRAINT [FK_Cuentasubdescuentos_Cuentas de cobro] FOREIGN KEY([IdCuenta])
REFERENCES [dbo].[Cuentas de cobro] ([IdCuenta])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Cuentasubdescuentos] CHECK CONSTRAINT [FK_Cuentasubdescuentos_Cuentas de cobro]
GO

-- %% [markdown]
-- # [FK_Cumplido_Terceros]

-- %%
ALTER TABLE [dbo].[Cumplido]  WITH NOCHECK ADD  CONSTRAINT [FK_Cumplido_Terceros] FOREIGN KEY([Cliente])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Cumplido] CHECK CONSTRAINT [FK_Cumplido_Terceros]
GO

-- %% [markdown]
-- # [FK_Cumplido_Vehiculos]

-- %%
ALTER TABLE [dbo].[Cumplido]  WITH NOCHECK ADD  CONSTRAINT [FK_Cumplido_Vehiculos] FOREIGN KEY([Placa])
REFERENCES [dbo].[Vehiculos] ([Placa])
GO
ALTER TABLE [dbo].[Cumplido] CHECK CONSTRAINT [FK_Cumplido_Vehiculos]
GO

-- %% [markdown]
-- # [FK_Cumplidosub_Cumplido]

-- %%
ALTER TABLE [dbo].[Cumplidosub]  WITH NOCHECK ADD  CONSTRAINT [FK_Cumplidosub_Cumplido] FOREIGN KEY([CumplidoNo])
REFERENCES [dbo].[Cumplido] ([CumplidoNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Cumplidosub] CHECK CONSTRAINT [FK_Cumplidosub_Cumplido]
GO

-- %% [markdown]
-- # [FK_Cumplir_Vehiculos]

-- %%
ALTER TABLE [dbo].[Cumplir]  WITH NOCHECK ADD  CONSTRAINT [FK_Cumplir_Vehiculos] FOREIGN KEY([Placa])
REFERENCES [dbo].[Vehiculos] ([Placa])
GO
ALTER TABLE [dbo].[Cumplir] CHECK CONSTRAINT [FK_Cumplir_Vehiculos]
GO

-- %% [markdown]
-- # [FK_Cumplirsub_Cumplir]

-- %%
ALTER TABLE [dbo].[Cumplirsub]  WITH NOCHECK ADD  CONSTRAINT [FK_Cumplirsub_Cumplir] FOREIGN KEY([CumplidoNo])
REFERENCES [dbo].[Cumplir] ([CumplidoNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Cumplirsub] CHECK CONSTRAINT [FK_Cumplirsub_Cumplir]
GO

-- %% [markdown]
-- # [FK_Datos_Cuentas]

-- %%
ALTER TABLE [dbo].[Datos]  WITH CHECK ADD  CONSTRAINT [FK_Datos_Cuentas] FOREIGN KEY([NúmCuenta])
REFERENCES [dbo].[Cuentas] ([NúmCuenta])
GO
ALTER TABLE [dbo].[Datos] CHECK CONSTRAINT [FK_Datos_Cuentas]
GO

-- %% [markdown]
-- # [FK_Declaracionsub_Declaracion]

-- %%
ALTER TABLE [dbo].[Declaracionsub]  WITH CHECK ADD  CONSTRAINT [FK_Declaracionsub_Declaracion] FOREIGN KEY([Renglon])
REFERENCES [dbo].[Declaracion] ([Renglon])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Declaracionsub] CHECK CONSTRAINT [FK_Declaracionsub_Declaracion]
GO

-- %% [markdown]
-- # [FK_Depreciación_Activos]

-- %%
ALTER TABLE [dbo].[Depreciación]  WITH NOCHECK ADD  CONSTRAINT [FK_Depreciación_Activos] FOREIGN KEY([IdActivo])
REFERENCES [dbo].[Activos] ([IdActivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Depreciación] CHECK CONSTRAINT [FK_Depreciación_Activos]
GO

-- %% [markdown]
-- # [FK_Despachos_Terceros]

-- %%
ALTER TABLE [dbo].[Despachos]  WITH NOCHECK ADD  CONSTRAINT [FK_Despachos_Terceros] FOREIGN KEY([Nombre])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Despachos] CHECK CONSTRAINT [FK_Despachos_Terceros]
GO

-- %% [markdown]
-- # [FK_Despachosub_Despachos]

-- %%
ALTER TABLE [dbo].[Despachosub]  WITH CHECK ADD  CONSTRAINT [FK_Despachosub_Despachos] FOREIGN KEY([NDespacho])
REFERENCES [dbo].[Despachos] ([NDespacho])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Despachosub] CHECK CONSTRAINT [FK_Despachosub_Despachos]
GO

-- %% [markdown]
-- # [FK_Despachosub_Referencias]

-- %%
ALTER TABLE [dbo].[Despachosub]  WITH NOCHECK ADD  CONSTRAINT [FK_Despachosub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Despachosub] CHECK CONSTRAINT [FK_Despachosub_Referencias]
GO

-- %% [markdown]
-- # [FK_Devoluciones_Terceros]

-- %%
ALTER TABLE [dbo].[Devoluciones]  WITH NOCHECK ADD  CONSTRAINT [FK_Devoluciones_Terceros] FOREIGN KEY([Cliente])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Devoluciones] CHECK CONSTRAINT [FK_Devoluciones_Terceros]
GO

-- %% [markdown]
-- # [FK_DiarioA_Diario]

-- %%
ALTER TABLE [dbo].[DiarioA]  WITH CHECK ADD  CONSTRAINT [FK_DiarioA_Diario] FOREIGN KEY([DiarioNo])
REFERENCES [dbo].[Diario] ([PlanillaNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[DiarioA] CHECK CONSTRAINT [FK_DiarioA_Diario]
GO

-- %% [markdown]
-- # [FK_DiarioB_Diario]

-- %%
ALTER TABLE [dbo].[DiarioB]  WITH CHECK ADD  CONSTRAINT [FK_DiarioB_Diario] FOREIGN KEY([DiarioNo])
REFERENCES [dbo].[Diario] ([PlanillaNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[DiarioB] CHECK CONSTRAINT [FK_DiarioB_Diario]
GO

-- %% [markdown]
-- # [FK_DiarioC_Diario]

-- %%
ALTER TABLE [dbo].[DiarioC]  WITH CHECK ADD  CONSTRAINT [FK_DiarioC_Diario] FOREIGN KEY([DiarioNo])
REFERENCES [dbo].[Diario] ([PlanillaNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[DiarioC] CHECK CONSTRAINT [FK_DiarioC_Diario]
GO

-- %% [markdown]
-- # [FK_DiarioD_Diario]

-- %%
ALTER TABLE [dbo].[DiarioD]  WITH CHECK ADD  CONSTRAINT [FK_DiarioD_Diario] FOREIGN KEY([DiarioNo])
REFERENCES [dbo].[Diario] ([PlanillaNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[DiarioD] CHECK CONSTRAINT [FK_DiarioD_Diario]
GO

-- %% [markdown]
-- # [FK_DiarioE_Diario]

-- %%
ALTER TABLE [dbo].[DiarioE]  WITH CHECK ADD  CONSTRAINT [FK_DiarioE_Diario] FOREIGN KEY([DiarioNo])
REFERENCES [dbo].[Diario] ([PlanillaNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[DiarioE] CHECK CONSTRAINT [FK_DiarioE_Diario]
GO

-- %% [markdown]
-- # [FK_DiarioF_Diario]

-- %%
ALTER TABLE [dbo].[DiarioF]  WITH CHECK ADD  CONSTRAINT [FK_DiarioF_Diario] FOREIGN KEY([DiarioNo])
REFERENCES [dbo].[Diario] ([PlanillaNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[DiarioF] CHECK CONSTRAINT [FK_DiarioF_Diario]
GO

-- %% [markdown]
-- # [FK_Documentacion_Empleado]

-- %%
ALTER TABLE [dbo].[Documentacion]  WITH NOCHECK ADD  CONSTRAINT [FK_Documentacion_Empleado] FOREIGN KEY([Cedula])
REFERENCES [dbo].[Empleado] ([Cedula])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Documentacion] CHECK CONSTRAINT [FK_Documentacion_Empleado]
GO

-- %% [markdown]
-- # [FK_DocumentacionDO_OrdenTrabajo]

-- %%
ALTER TABLE [dbo].[DocumentacionDO]  WITH CHECK ADD  CONSTRAINT [FK_DocumentacionDO_OrdenTrabajo] FOREIGN KEY([DO])
REFERENCES [dbo].[OrdenTrabajo] ([OrdTra])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[DocumentacionDO] CHECK CONSTRAINT [FK_DocumentacionDO_OrdenTrabajo]
GO

-- %% [markdown]
-- # [FK_DocumentacionRemesa_Cumplido]

-- %%
ALTER TABLE [dbo].[DocumentacionRemesa]  WITH CHECK ADD  CONSTRAINT [FK_DocumentacionRemesa_Cumplido] FOREIGN KEY([Remesa])
REFERENCES [dbo].[Cumplido] ([CumplidoNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[DocumentacionRemesa] CHECK CONSTRAINT [FK_DocumentacionRemesa_Cumplido]
GO

-- %% [markdown]
-- # [FK_Empleado_Tipoempleado]

-- %%
ALTER TABLE [dbo].[Empleado]  WITH NOCHECK ADD  CONSTRAINT [FK_Empleado_Tipoempleado] FOREIGN KEY([Tipoempleado])
REFERENCES [dbo].[Tipoempleado] ([Tipoempleado])
GO
ALTER TABLE [dbo].[Empleado] CHECK CONSTRAINT [FK_Empleado_Tipoempleado]
GO

-- %% [markdown]
-- # [FK_EmpleadoCompensa_Empleado]

-- %%
ALTER TABLE [dbo].[EmpleadoCompensa]  WITH CHECK ADD  CONSTRAINT [FK_EmpleadoCompensa_Empleado] FOREIGN KEY([Cedula])
REFERENCES [dbo].[Empleado] ([Cedula])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[EmpleadoCompensa] CHECK CONSTRAINT [FK_EmpleadoCompensa_Empleado]
GO

-- %% [markdown]
-- # [FK_Empleadoexenciones_Empleado]

-- %%
ALTER TABLE [dbo].[Empleadoexenciones]  WITH CHECK ADD  CONSTRAINT [FK_Empleadoexenciones_Empleado] FOREIGN KEY([Cedula])
REFERENCES [dbo].[Empleado] ([Cedula])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Empleadoexenciones] CHECK CONSTRAINT [FK_Empleadoexenciones_Empleado]
GO

-- %% [markdown]
-- # [FK_EmpleadoVacaciones_Empleado]

-- %%
ALTER TABLE [dbo].[EmpleadoVacaciones]  WITH CHECK ADD  CONSTRAINT [FK_EmpleadoVacaciones_Empleado] FOREIGN KEY([Cedula])
REFERENCES [dbo].[Empleado] ([Cedula])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[EmpleadoVacaciones] CHECK CONSTRAINT [FK_EmpleadoVacaciones_Empleado]
GO

-- %% [markdown]
-- # [FK_Encuestasub_Encuesta]

-- %%
ALTER TABLE [dbo].[Encuestasub]  WITH CHECK ADD  CONSTRAINT [FK_Encuestasub_Encuesta] FOREIGN KEY([IdEncuesta])
REFERENCES [dbo].[Encuesta] ([IdEncuesta])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Encuestasub] CHECK CONSTRAINT [FK_Encuestasub_Encuesta]
GO

-- %% [markdown]
-- # [FK_Extracontratosub_Extracontrato]

-- %%
ALTER TABLE [dbo].[Extracontratosub]  WITH CHECK ADD  CONSTRAINT [FK_Extracontratosub_Extracontrato] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Extracontrato] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Extracontratosub] CHECK CONSTRAINT [FK_Extracontratosub_Extracontrato]
GO

-- %% [markdown]
-- # [FK_Extractosub_Extracto]

-- %%
ALTER TABLE [dbo].[Extractosub]  WITH CHECK ADD  CONSTRAINT [FK_Extractosub_Extracto] FOREIGN KEY([IdExtracto])
REFERENCES [dbo].[Extracto] ([IdExtracto])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Extractosub] CHECK CONSTRAINT [FK_Extractosub_Extracto]
GO

-- %% [markdown]
-- # [FK_Facturapos_Terceros]

-- %%
ALTER TABLE [dbo].[Facturapos]  WITH CHECK ADD  CONSTRAINT [FK_Facturapos_Terceros] FOREIGN KEY([Cliente])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Facturapos] CHECK CONSTRAINT [FK_Facturapos_Terceros]
GO

-- %% [markdown]
-- # [FK_Facturaposub_Facturapos]

-- %%
ALTER TABLE [dbo].[Facturaposub]  WITH CHECK ADD  CONSTRAINT [FK_Facturaposub_Facturapos] FOREIGN KEY([Resolucion], [Facturanumero])
REFERENCES [dbo].[Facturapos] ([Resolucion], [Facturanumero])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Facturaposub] CHECK CONSTRAINT [FK_Facturaposub_Facturapos]
GO

-- %% [markdown]
-- # [FK_Facturaposub_Referencias]

-- %%
ALTER TABLE [dbo].[Facturaposub]  WITH CHECK ADD  CONSTRAINT [FK_Facturaposub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Facturaposub] CHECK CONSTRAINT [FK_Facturaposub_Referencias]
GO

-- %% [markdown]
-- # [FK_Facturasub_Factura]

-- %%
ALTER TABLE [dbo].[Facturasub]  WITH CHECK ADD  CONSTRAINT [FK_Facturasub_Factura] FOREIGN KEY([Facturanumero])
REFERENCES [dbo].[Factura] ([Facturanumero])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Facturasub] CHECK CONSTRAINT [FK_Facturasub_Factura]
GO

-- %% [markdown]
-- # [FK_Facturasub_Referencias]

-- %%
ALTER TABLE [dbo].[Facturasub]  WITH CHECK ADD  CONSTRAINT [FK_Facturasub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Facturasub] CHECK CONSTRAINT [FK_Facturasub_Referencias]
GO

-- %% [markdown]
-- # [FK_Guiasub_Guia]

-- %%
ALTER TABLE [dbo].[Guiasub]  WITH CHECK ADD  CONSTRAINT [FK_Guiasub_Guia] FOREIGN KEY([Prefijo], [Consecutivo])
REFERENCES [dbo].[Guia] ([Prefijo], [Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Guiasub] CHECK CONSTRAINT [FK_Guiasub_Guia]
GO

-- %% [markdown]
-- # [FK_HistoClinicasub_HistoClinica]

-- %%
ALTER TABLE [dbo].[HistoClinicasub]  WITH CHECK ADD  CONSTRAINT [FK_HistoClinicasub_HistoClinica] FOREIGN KEY([HistoriaNo])
REFERENCES [dbo].[HistoClinica] ([HistoriaNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[HistoClinicasub] CHECK CONSTRAINT [FK_HistoClinicasub_HistoClinica]
GO

-- %% [markdown]
-- # [FK_Indicadoresub1_Indicadores]

-- %%
ALTER TABLE [dbo].[Indicadoresub1]  WITH CHECK ADD  CONSTRAINT [FK_Indicadoresub1_Indicadores] FOREIGN KEY([Idindicador])
REFERENCES [dbo].[Indicadores] ([Idindicador])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Indicadoresub1] CHECK CONSTRAINT [FK_Indicadoresub1_Indicadores]
GO

-- %% [markdown]
-- # [FK_Indicadoresub2_Indicadores]

-- %%
ALTER TABLE [dbo].[Indicadoresub2]  WITH CHECK ADD  CONSTRAINT [FK_Indicadoresub2_Indicadores] FOREIGN KEY([Idindicador])
REFERENCES [dbo].[Indicadores] ([Idindicador])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Indicadoresub2] CHECK CONSTRAINT [FK_Indicadoresub2_Indicadores]
GO

-- %% [markdown]
-- # [FK_Iniciales_InicialescEnc]

-- %%
ALTER TABLE [dbo].[Iniciales]  WITH NOCHECK ADD  CONSTRAINT [FK_Iniciales_InicialescEnc] FOREIGN KEY([IdControl])
REFERENCES [dbo].[InicialescEnc] ([IdControl])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Iniciales] CHECK CONSTRAINT [FK_Iniciales_InicialescEnc]
GO

-- %% [markdown]
-- # [FK_Iniciales_Terceros]

-- %%
ALTER TABLE [dbo].[Iniciales]  WITH NOCHECK ADD  CONSTRAINT [FK_Iniciales_Terceros] FOREIGN KEY([Cliente])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Iniciales] CHECK CONSTRAINT [FK_Iniciales_Terceros]
GO

-- %% [markdown]
-- # [FK_Inicialescontenedoresub_Inicialescontenedores]

-- %%
ALTER TABLE [dbo].[Inicialescontenedoresub]  WITH CHECK ADD  CONSTRAINT [FK_Inicialescontenedoresub_Inicialescontenedores] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Inicialescontenedores] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Inicialescontenedoresub] CHECK CONSTRAINT [FK_Inicialescontenedoresub_Inicialescontenedores]
GO

-- %% [markdown]
-- # [FK_InicialesCXP_InicialesEncCXP]

-- %%
ALTER TABLE [dbo].[InicialesCXP]  WITH NOCHECK ADD  CONSTRAINT [FK_InicialesCXP_InicialesEncCXP] FOREIGN KEY([IdControl])
REFERENCES [dbo].[InicialesEncCXP] ([IdControl])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[InicialesCXP] CHECK CONSTRAINT [FK_InicialesCXP_InicialesEncCXP]
GO

-- %% [markdown]
-- # [FK_InicialesCXP_Terceros]

-- %%
ALTER TABLE [dbo].[InicialesCXP]  WITH NOCHECK ADD  CONSTRAINT [FK_InicialesCXP_Terceros] FOREIGN KEY([Proveedor])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[InicialesCXP] CHECK CONSTRAINT [FK_InicialesCXP_Terceros]
GO

-- %% [markdown]
-- # [FK_InicialesInventariosub_InicialesInventario]

-- %%
ALTER TABLE [dbo].[InicialesInventariosub]  WITH NOCHECK ADD  CONSTRAINT [FK_InicialesInventariosub_InicialesInventario] FOREIGN KEY([IdIniciaIn])
REFERENCES [dbo].[InicialesInventario] ([IdIniciaIn])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[InicialesInventariosub] CHECK CONSTRAINT [FK_InicialesInventariosub_InicialesInventario]
GO

-- %% [markdown]
-- # [FK_InicialesInventariosub_Referencias]

-- %%
ALTER TABLE [dbo].[InicialesInventariosub]  WITH NOCHECK ADD  CONSTRAINT [FK_InicialesInventariosub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[InicialesInventariosub] CHECK CONSTRAINT [FK_InicialesInventariosub_Referencias]
GO

-- %% [markdown]
-- # [FK_InicialesMPrimasub_InicialesMPrima]

-- %%
ALTER TABLE [dbo].[InicialesMPrimasub]  WITH NOCHECK ADD  CONSTRAINT [FK_InicialesMPrimasub_InicialesMPrima] FOREIGN KEY([IdIniciaIn])
REFERENCES [dbo].[InicialesMPrima] ([IdIniciaIn])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[InicialesMPrimasub] CHECK CONSTRAINT [FK_InicialesMPrimasub_InicialesMPrima]
GO

-- %% [markdown]
-- # [FK_InicialesMPrimasub_Referencias]

-- %%
ALTER TABLE [dbo].[InicialesMPrimasub]  WITH NOCHECK ADD  CONSTRAINT [FK_InicialesMPrimasub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[InicialesMPrimasub] CHECK CONSTRAINT [FK_InicialesMPrimasub_Referencias]
GO

-- %% [markdown]
-- # [FK_InicialesMPrimaterminado_InicialesMPrima]

-- %%
ALTER TABLE [dbo].[InicialesMPrimaterminado]  WITH CHECK ADD  CONSTRAINT [FK_InicialesMPrimaterminado_InicialesMPrima] FOREIGN KEY([IdIniciaIn])
REFERENCES [dbo].[InicialesMPrima] ([IdIniciaIn])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[InicialesMPrimaterminado] CHECK CONSTRAINT [FK_InicialesMPrimaterminado_InicialesMPrima]
GO

-- %% [markdown]
-- # [FK_InicialesMPrimaterminado_Referencias]

-- %%
ALTER TABLE [dbo].[InicialesMPrimaterminado]  WITH CHECK ADD  CONSTRAINT [FK_InicialesMPrimaterminado_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[InicialesMPrimaterminado] CHECK CONSTRAINT [FK_InicialesMPrimaterminado_Referencias]
GO

-- %% [markdown]
-- # [FK_InicialesTesoreriasub_InicialesTesoreria]

-- %%
ALTER TABLE [dbo].[InicialesTesoreriasub]  WITH CHECK ADD  CONSTRAINT [FK_InicialesTesoreriasub_InicialesTesoreria] FOREIGN KEY([IdTeso])
REFERENCES [dbo].[InicialesTesoreria] ([IdTeso])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[InicialesTesoreriasub] CHECK CONSTRAINT [FK_InicialesTesoreriasub_InicialesTesoreria]
GO

-- %% [markdown]
-- # [FK_Know1_KnowStatus]

-- %%
ALTER TABLE [dbo].[Know1]  WITH CHECK ADD  CONSTRAINT [FK_Know1_KnowStatus] FOREIGN KEY([Status])
REFERENCES [dbo].[KnowStatus] ([Tipo])
GO
ALTER TABLE [dbo].[Know1] CHECK CONSTRAINT [FK_Know1_KnowStatus]
GO

-- %% [markdown]
-- # [FK_Know1_KnowTipo]

-- %%
ALTER TABLE [dbo].[Know1]  WITH CHECK ADD  CONSTRAINT [FK_Know1_KnowTipo] FOREIGN KEY([Tema])
REFERENCES [dbo].[KnowTipo] ([Tipo])
GO
ALTER TABLE [dbo].[Know1] CHECK CONSTRAINT [FK_Know1_KnowTipo]
GO

-- %% [markdown]
-- # [FK_Legalizacionesub_Legalizaciones]

-- %%
ALTER TABLE [dbo].[Legalizacionesub]  WITH CHECK ADD  CONSTRAINT [FK_Legalizacionesub_Legalizaciones] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Legalizaciones] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Legalizacionesub] CHECK CONSTRAINT [FK_Legalizacionesub_Legalizaciones]
GO

-- %% [markdown]
-- # [FK_Liquidacion final_Empleado]

-- %%
ALTER TABLE [dbo].[Liquidacion final]  WITH NOCHECK ADD  CONSTRAINT [FK_Liquidacion final_Empleado] FOREIGN KEY([Cedula])
REFERENCES [dbo].[Empleado] ([Cedula])
GO
ALTER TABLE [dbo].[Liquidacion final] CHECK CONSTRAINT [FK_Liquidacion final_Empleado]
GO

-- %% [markdown]
-- # [FK_Liquidacion final_Nominapar]

-- %%
ALTER TABLE [dbo].[Liquidacion final]  WITH NOCHECK ADD  CONSTRAINT [FK_Liquidacion final_Nominapar] FOREIGN KEY([Idparnomina])
REFERENCES [dbo].[Nominapar] ([Idparnomina])
GO
ALTER TABLE [dbo].[Liquidacion final] CHECK CONSTRAINT [FK_Liquidacion final_Nominapar]
GO

-- %% [markdown]
-- # [FK_LiquidafleteDO_LiquidaFletes]

-- %%
ALTER TABLE [dbo].[LiquidafleteDO]  WITH CHECK ADD  CONSTRAINT [FK_LiquidafleteDO_LiquidaFletes] FOREIGN KEY([Nliquidacion])
REFERENCES [dbo].[LiquidaFletes] ([Nliquida])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[LiquidafleteDO] CHECK CONSTRAINT [FK_LiquidafleteDO_LiquidaFletes]
GO

-- %% [markdown]
-- # [FK_LiquidaFletes_Terceros]

-- %%
ALTER TABLE [dbo].[LiquidaFletes]  WITH NOCHECK ADD  CONSTRAINT [FK_LiquidaFletes_Terceros] FOREIGN KEY([Nombre])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[LiquidaFletes] CHECK CONSTRAINT [FK_LiquidaFletes_Terceros]
GO

-- %% [markdown]
-- # [FK_Liquidafletessub_LiquidaFletes]

-- %%
ALTER TABLE [dbo].[Liquidafletessub]  WITH NOCHECK ADD  CONSTRAINT [FK_Liquidafletessub_LiquidaFletes] FOREIGN KEY([Nliquida])
REFERENCES [dbo].[LiquidaFletes] ([Nliquida])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Liquidafletessub] CHECK CONSTRAINT [FK_Liquidafletessub_LiquidaFletes]
GO

-- %% [markdown]
-- # [FK_Manifiesto_Conductores]

-- %%
ALTER TABLE [dbo].[Manifiesto]  WITH NOCHECK ADD  CONSTRAINT [FK_Manifiesto_Conductores] FOREIGN KEY([Conductor])
REFERENCES [dbo].[Conductores] ([Cedula])
GO
ALTER TABLE [dbo].[Manifiesto] CHECK CONSTRAINT [FK_Manifiesto_Conductores]
GO

-- %% [markdown]
-- # [FK_Manifiesto_Vehiculos]

-- %%
ALTER TABLE [dbo].[Manifiesto]  WITH NOCHECK ADD  CONSTRAINT [FK_Manifiesto_Vehiculos] FOREIGN KEY([Placa])
REFERENCES [dbo].[Vehiculos] ([Placa])
GO
ALTER TABLE [dbo].[Manifiesto] CHECK CONSTRAINT [FK_Manifiesto_Vehiculos]
GO

-- %% [markdown]
-- # [FK_Manifiestosub_Manifiesto]

-- %%
ALTER TABLE [dbo].[Manifiestosub]  WITH NOCHECK ADD  CONSTRAINT [FK_Manifiestosub_Manifiesto] FOREIGN KEY([ManifiestoNo])
REFERENCES [dbo].[Manifiesto] ([ManifiestoNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Manifiestosub] CHECK CONSTRAINT [FK_Manifiestosub_Manifiesto]
GO

-- %% [markdown]
-- # [FK_Mantenimiento_Activos]

-- %%
ALTER TABLE [dbo].[Mantenimiento]  WITH CHECK ADD  CONSTRAINT [FK_Mantenimiento_Activos] FOREIGN KEY([Maquina])
REFERENCES [dbo].[Activos] ([IdActivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Mantenimiento] CHECK CONSTRAINT [FK_Mantenimiento_Activos]
GO

-- %% [markdown]
-- # [FK_Mantenimientosub_Mantenimiento]

-- %%
ALTER TABLE [dbo].[Mantenimientosub]  WITH CHECK ADD  CONSTRAINT [FK_Mantenimientosub_Mantenimiento] FOREIGN KEY([NoMantenimiento])
REFERENCES [dbo].[Mantenimiento] ([NoMantenimiento])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Mantenimientosub] CHECK CONSTRAINT [FK_Mantenimientosub_Mantenimiento]
GO

-- %% [markdown]
-- # [FK_Matrix_Terceros]

-- %%
ALTER TABLE [dbo].[Matrix]  WITH NOCHECK ADD  CONSTRAINT [FK_Matrix_Terceros] FOREIGN KEY([Cliente])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Matrix] CHECK CONSTRAINT [FK_Matrix_Terceros]
GO

-- %% [markdown]
-- # [FK_MatrixNomina_Empleado]

-- %%
ALTER TABLE [dbo].[MatrixNomina]  WITH NOCHECK ADD  CONSTRAINT [FK_MatrixNomina_Empleado] FOREIGN KEY([Cedula])
REFERENCES [dbo].[Empleado] ([Cedula])
GO
ALTER TABLE [dbo].[MatrixNomina] CHECK CONSTRAINT [FK_MatrixNomina_Empleado]
GO

-- %% [markdown]
-- # [FK_MatrixNomina_Nominapar]

-- %%
ALTER TABLE [dbo].[MatrixNomina]  WITH NOCHECK ADD  CONSTRAINT [FK_MatrixNomina_Nominapar] FOREIGN KEY([Idparnomina])
REFERENCES [dbo].[Nominapar] ([Idparnomina])
GO
ALTER TABLE [dbo].[MatrixNomina] CHECK CONSTRAINT [FK_MatrixNomina_Nominapar]
GO

-- %% [markdown]
-- # [FK_Matrixsub_Matrix]

-- %%
ALTER TABLE [dbo].[Matrixsub]  WITH CHECK ADD  CONSTRAINT [FK_Matrixsub_Matrix] FOREIGN KEY([Factura])
REFERENCES [dbo].[Matrix] ([Factura])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Matrixsub] CHECK CONSTRAINT [FK_Matrixsub_Matrix]
GO

-- %% [markdown]
-- # [FK_Matrixsub_Referencias]

-- %%
ALTER TABLE [dbo].[Matrixsub]  WITH NOCHECK ADD  CONSTRAINT [FK_Matrixsub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Matrixsub] CHECK CONSTRAINT [FK_Matrixsub_Referencias]
GO

-- %% [markdown]
-- # [FK_Mercadeo_Llamadaster]

-- %%
ALTER TABLE [dbo].[Mercadeo]  WITH CHECK ADD  CONSTRAINT [FK_Mercadeo_Llamadaster] FOREIGN KEY([Prospecto])
REFERENCES [dbo].[Llamadaster] ([Identificacion])
GO
ALTER TABLE [dbo].[Mercadeo] CHECK CONSTRAINT [FK_Mercadeo_Llamadaster]
GO

-- %% [markdown]
-- # [FK_Mostrador_Resoluciones]

-- %%
ALTER TABLE [dbo].[Mostrador]  WITH CHECK ADD  CONSTRAINT [FK_Mostrador_Resoluciones] FOREIGN KEY([Resolucion])
REFERENCES [dbo].[Resoluciones] ([Centro])
GO
ALTER TABLE [dbo].[Mostrador] CHECK CONSTRAINT [FK_Mostrador_Resoluciones]
GO

-- %% [markdown]
-- # [FK_Mostrador_Terceros]

-- %%
ALTER TABLE [dbo].[Mostrador]  WITH NOCHECK ADD  CONSTRAINT [FK_Mostrador_Terceros] FOREIGN KEY([Cliente])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Mostrador] CHECK CONSTRAINT [FK_Mostrador_Terceros]
GO

-- %% [markdown]
-- # [FK_Mostradorsub_Mostrador]

-- %%
ALTER TABLE [dbo].[Mostradorsub]  WITH NOCHECK ADD  CONSTRAINT [FK_Mostradorsub_Mostrador] FOREIGN KEY([Resolucion], [Facturanumero])
REFERENCES [dbo].[Mostrador] ([Resolucion], [Facturanumero])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Mostradorsub] CHECK CONSTRAINT [FK_Mostradorsub_Mostrador]
GO

-- %% [markdown]
-- # [FK_Mostradorsub_Referencias]

-- %%
ALTER TABLE [dbo].[Mostradorsub]  WITH NOCHECK ADD  CONSTRAINT [FK_Mostradorsub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Mostradorsub] CHECK CONSTRAINT [FK_Mostradorsub_Referencias]
GO

-- %% [markdown]
-- # [FK_NCredito_Terceros]

-- %%
ALTER TABLE [dbo].[NCredito]  WITH NOCHECK ADD  CONSTRAINT [FK_NCredito_Terceros] FOREIGN KEY([Nombre])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[NCredito] CHECK CONSTRAINT [FK_NCredito_Terceros]
GO

-- %% [markdown]
-- # [FK_NCreditoPos_Terceros]

-- %%
ALTER TABLE [dbo].[NCreditoPos]  WITH NOCHECK ADD  CONSTRAINT [FK_NCreditoPos_Terceros] FOREIGN KEY([Nombre])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[NCreditoPos] CHECK CONSTRAINT [FK_NCreditoPos_Terceros]
GO

-- %% [markdown]
-- # [FK_NCreditoproveedores_Terceros]

-- %%
ALTER TABLE [dbo].[NCreditoproveedores]  WITH CHECK ADD  CONSTRAINT [FK_NCreditoproveedores_Terceros] FOREIGN KEY([Nombre])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[NCreditoproveedores] CHECK CONSTRAINT [FK_NCreditoproveedores_Terceros]
GO

-- %% [markdown]
-- # [FK_NCreditoproveedoresub_NCreditoproveedores]

-- %%
ALTER TABLE [dbo].[NCreditoproveedoresub]  WITH CHECK ADD  CONSTRAINT [FK_NCreditoproveedoresub_NCreditoproveedores] FOREIGN KEY([Idncreditopro])
REFERENCES [dbo].[NCreditoproveedores] ([Idncreditopro])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NCreditoproveedoresub] CHECK CONSTRAINT [FK_NCreditoproveedoresub_NCreditoproveedores]
GO

-- %% [markdown]
-- # [FK_NCreditoproveedoresub_Referencias]

-- %%
ALTER TABLE [dbo].[NCreditoproveedoresub]  WITH CHECK ADD  CONSTRAINT [FK_NCreditoproveedoresub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[NCreditoproveedoresub] CHECK CONSTRAINT [FK_NCreditoproveedoresub_Referencias]
GO

-- %% [markdown]
-- # [FK_NCreditosub_NCredito]

-- %%
ALTER TABLE [dbo].[NCreditosub]  WITH NOCHECK ADD  CONSTRAINT [FK_NCreditosub_NCredito] FOREIGN KEY([Idncredito])
REFERENCES [dbo].[NCredito] ([Idncredito])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NCreditosub] CHECK CONSTRAINT [FK_NCreditosub_NCredito]
GO

-- %% [markdown]
-- # [FK_NCreditosub_Referencias]

-- %%
ALTER TABLE [dbo].[NCreditosub]  WITH NOCHECK ADD  CONSTRAINT [FK_NCreditosub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[NCreditosub] CHECK CONSTRAINT [FK_NCreditosub_Referencias]
GO

-- %% [markdown]
-- # [FK_NCreditosubPos_NCreditoPos]

-- %%
ALTER TABLE [dbo].[NCreditosubPos]  WITH CHECK ADD  CONSTRAINT [FK_NCreditosubPos_NCreditoPos] FOREIGN KEY([Resolucion], [Idncreditopos])
REFERENCES [dbo].[NCreditoPos] ([Resolucion], [Idncreditopos])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NCreditosubPos] CHECK CONSTRAINT [FK_NCreditosubPos_NCreditoPos]
GO

-- %% [markdown]
-- # [FK_NCreditosubPos_Referencias]

-- %%
ALTER TABLE [dbo].[NCreditosubPos]  WITH NOCHECK ADD  CONSTRAINT [FK_NCreditosubPos_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[NCreditosubPos] CHECK CONSTRAINT [FK_NCreditosubPos_Referencias]
GO

-- %% [markdown]
-- # [FK_NDebito_Terceros]

-- %%
ALTER TABLE [dbo].[NDebito]  WITH NOCHECK ADD  CONSTRAINT [FK_NDebito_Terceros] FOREIGN KEY([Nombre])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[NDebito] CHECK CONSTRAINT [FK_NDebito_Terceros]
GO

-- %% [markdown]
-- # [FK_NDebitoClientes_Terceros]

-- %%
ALTER TABLE [dbo].[NDebitoClientes]  WITH NOCHECK ADD  CONSTRAINT [FK_NDebitoClientes_Terceros] FOREIGN KEY([Nombre])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[NDebitoClientes] CHECK CONSTRAINT [FK_NDebitoClientes_Terceros]
GO

-- %% [markdown]
-- # [FK_NDebitoClientesub_NDebitoClientes]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub]  WITH CHECK ADD  CONSTRAINT [FK_NDebitoClientesub_NDebitoClientes] FOREIGN KEY([Idncredito])
REFERENCES [dbo].[NDebitoClientes] ([Idncredito])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NDebitoClientesub] CHECK CONSTRAINT [FK_NDebitoClientesub_NDebitoClientes]
GO

-- %% [markdown]
-- # [FK_NDebitoClientesub_Referencias]

-- %%
ALTER TABLE [dbo].[NDebitoClientesub]  WITH CHECK ADD  CONSTRAINT [FK_NDebitoClientesub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[NDebitoClientesub] CHECK CONSTRAINT [FK_NDebitoClientesub_Referencias]
GO

-- %% [markdown]
-- # [FK_NDebitosub_NDebito]

-- %%
ALTER TABLE [dbo].[NDebitosub]  WITH CHECK ADD  CONSTRAINT [FK_NDebitosub_NDebito] FOREIGN KEY([Idndebito])
REFERENCES [dbo].[NDebito] ([Idndebito])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NDebitosub] CHECK CONSTRAINT [FK_NDebitosub_NDebito]
GO

-- %% [markdown]
-- # [FK_NDebitosub_Referencias]

-- %%
ALTER TABLE [dbo].[NDebitosub]  WITH NOCHECK ADD  CONSTRAINT [FK_NDebitosub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[NDebitosub] CHECK CONSTRAINT [FK_NDebitosub_Referencias]
GO

-- %% [markdown]
-- # [FK_NifDeteriorosub_NifDeterioro]

-- %%
ALTER TABLE [dbo].[NifDeteriorosub]  WITH CHECK ADD  CONSTRAINT [FK_NifDeteriorosub_NifDeterioro] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[NifDeterioro] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NifDeteriorosub] CHECK CONSTRAINT [FK_NifDeteriorosub_NifDeterioro]
GO

-- %% [markdown]
-- # [FK_NifInteresub_NifInteres]

-- %%
ALTER TABLE [dbo].[NifInteresub]  WITH CHECK ADD  CONSTRAINT [FK_NifInteresub_NifInteres] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[NifInteres] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NifInteresub] CHECK CONSTRAINT [FK_NifInteresub_NifInteres]
GO

-- %% [markdown]
-- # [FK_Nifreversionsub_NifReversion]

-- %%
ALTER TABLE [dbo].[Nifreversionsub]  WITH CHECK ADD  CONSTRAINT [FK_Nifreversionsub_NifReversion] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[NifReversion] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Nifreversionsub] CHECK CONSTRAINT [FK_Nifreversionsub_NifReversion]
GO

-- %% [markdown]
-- # [FK_Nomina_Empleado]

-- %%
ALTER TABLE [dbo].[Nomina]  WITH NOCHECK ADD  CONSTRAINT [FK_Nomina_Empleado] FOREIGN KEY([Cedula])
REFERENCES [dbo].[Empleado] ([Cedula])
GO
ALTER TABLE [dbo].[Nomina] CHECK CONSTRAINT [FK_Nomina_Empleado]
GO

-- %% [markdown]
-- # [FK_Nomina_Nominapar]

-- %%
ALTER TABLE [dbo].[Nomina]  WITH CHECK ADD  CONSTRAINT [FK_Nomina_Nominapar] FOREIGN KEY([Idparnomina])
REFERENCES [dbo].[Nominapar] ([Idparnomina])
GO
ALTER TABLE [dbo].[Nomina] CHECK CONSTRAINT [FK_Nomina_Nominapar]
GO

-- %% [markdown]
-- # [FK_NominaCargofun_NominaCargo]

-- %%
ALTER TABLE [dbo].[NominaCargofun]  WITH CHECK ADD  CONSTRAINT [FK_NominaCargofun_NominaCargo] FOREIGN KEY([Cargo])
REFERENCES [dbo].[NominaCargo] ([Cargo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NominaCargofun] CHECK CONSTRAINT [FK_NominaCargofun_NominaCargo]
GO

-- %% [markdown]
-- # [FK_NominaCargosub_NominaCargo]

-- %%
ALTER TABLE [dbo].[NominaCargosub]  WITH CHECK ADD  CONSTRAINT [FK_NominaCargosub_NominaCargo] FOREIGN KEY([Cargo])
REFERENCES [dbo].[NominaCargo] ([Cargo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NominaCargosub] CHECK CONSTRAINT [FK_NominaCargosub_NominaCargo]
GO

-- %% [markdown]
-- # [FK_Nominacompensacion_Nomina]

-- %%
ALTER TABLE [dbo].[Nominacompensacion]  WITH CHECK ADD  CONSTRAINT [FK_Nominacompensacion_Nomina] FOREIGN KEY([IdNomina])
REFERENCES [dbo].[Nomina] ([Idnomina])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Nominacompensacion] CHECK CONSTRAINT [FK_Nominacompensacion_Nomina]
GO

-- %% [markdown]
-- # [FK_Nominadescuentos_Nomina]

-- %%
ALTER TABLE [dbo].[Nominadescuentos]  WITH NOCHECK ADD  CONSTRAINT [FK_Nominadescuentos_Nomina] FOREIGN KEY([IdNomina])
REFERENCES [dbo].[Nomina] ([Idnomina])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Nominadescuentos] CHECK CONSTRAINT [FK_Nominadescuentos_Nomina]
GO

-- %% [markdown]
-- # [FK_Nominadevengos_Nomina]

-- %%
ALTER TABLE [dbo].[Nominadevengos]  WITH CHECK ADD  CONSTRAINT [FK_Nominadevengos_Nomina] FOREIGN KEY([IdNomina])
REFERENCES [dbo].[Nomina] ([Idnomina])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Nominadevengos] CHECK CONSTRAINT [FK_Nominadevengos_Nomina]
GO

-- %% [markdown]
-- # [FK_NominaDO_Nomina]

-- %%
ALTER TABLE [dbo].[NominaDO]  WITH CHECK ADD  CONSTRAINT [FK_NominaDO_Nomina] FOREIGN KEY([IdNomina])
REFERENCES [dbo].[Nomina] ([Idnomina])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NominaDO] CHECK CONSTRAINT [FK_NominaDO_Nomina]
GO

-- %% [markdown]
-- # [FK_NominaNovedades_TipoNovedad]

-- %%
ALTER TABLE [dbo].[NominaNovedades]  WITH CHECK ADD  CONSTRAINT [FK_NominaNovedades_TipoNovedad] FOREIGN KEY([Novedad])
REFERENCES [dbo].[TipoNovedad] ([Tipo])
GO
ALTER TABLE [dbo].[NominaNovedades] CHECK CONSTRAINT [FK_NominaNovedades_TipoNovedad]
GO

-- %% [markdown]
-- # [FK_Nominaprestamos_Nomina]

-- %%
ALTER TABLE [dbo].[Nominaprestamos]  WITH CHECK ADD  CONSTRAINT [FK_Nominaprestamos_Nomina] FOREIGN KEY([NominaNo])
REFERENCES [dbo].[Nomina] ([Idnomina])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Nominaprestamos] CHECK CONSTRAINT [FK_Nominaprestamos_Nomina]
GO

-- %% [markdown]
-- # [FK_NominaPruebasub_NominaPrueba]

-- %%
ALTER TABLE [dbo].[NominaPruebasub]  WITH CHECK ADD  CONSTRAINT [FK_NominaPruebasub_NominaPrueba] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[NominaPrueba] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NominaPruebasub] CHECK CONSTRAINT [FK_NominaPruebasub_NominaPrueba]
GO

-- %% [markdown]
-- # [FK_OCargue_Terceros]

-- %%
ALTER TABLE [dbo].[OCargue]  WITH NOCHECK ADD  CONSTRAINT [FK_OCargue_Terceros] FOREIGN KEY([Cliente])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[OCargue] CHECK CONSTRAINT [FK_OCargue_Terceros]
GO

-- %% [markdown]
-- # [FK_OCargue_Vehiculos]

-- %%
ALTER TABLE [dbo].[OCargue]  WITH NOCHECK ADD  CONSTRAINT [FK_OCargue_Vehiculos] FOREIGN KEY([Placa])
REFERENCES [dbo].[Vehiculos] ([Placa])
GO
ALTER TABLE [dbo].[OCargue] CHECK CONSTRAINT [FK_OCargue_Vehiculos]
GO

-- %% [markdown]
-- # [FK_OCarguesub_OCargue]

-- %%
ALTER TABLE [dbo].[OCarguesub]  WITH CHECK ADD  CONSTRAINT [FK_OCarguesub_OCargue] FOREIGN KEY([OrdenNo])
REFERENCES [dbo].[OCargue] ([OrdenNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[OCarguesub] CHECK CONSTRAINT [FK_OCarguesub_OCargue]
GO

-- %% [markdown]
-- # [FK_Orden_Terceros]

-- %%
ALTER TABLE [dbo].[Orden]  WITH NOCHECK ADD  CONSTRAINT [FK_Orden_Terceros] FOREIGN KEY([Proveedor])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Orden] CHECK CONSTRAINT [FK_Orden_Terceros]
GO

-- %% [markdown]
-- # [FK_Ordencompra_Terceros]

-- %%
ALTER TABLE [dbo].[Ordencompra]  WITH NOCHECK ADD  CONSTRAINT [FK_Ordencompra_Terceros] FOREIGN KEY([Proveedor])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Ordencompra] CHECK CONSTRAINT [FK_Ordencompra_Terceros]
GO

-- %% [markdown]
-- # [FK_Ordencomprasub_Ordencompra]

-- %%
ALTER TABLE [dbo].[Ordencomprasub]  WITH CHECK ADD  CONSTRAINT [FK_Ordencomprasub_Ordencompra] FOREIGN KEY([Ordencompra])
REFERENCES [dbo].[Ordencompra] ([Ordencompra])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Ordencomprasub] CHECK CONSTRAINT [FK_Ordencomprasub_Ordencompra]
GO

-- %% [markdown]
-- # [FK_Ordencomprasub_Referencias]

-- %%
ALTER TABLE [dbo].[Ordencomprasub]  WITH NOCHECK ADD  CONSTRAINT [FK_Ordencomprasub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Ordencomprasub] CHECK CONSTRAINT [FK_Ordencomprasub_Referencias]
GO

-- %% [markdown]
-- # [FK_Ordensub_Orden]

-- %%
ALTER TABLE [dbo].[Ordensub]  WITH CHECK ADD  CONSTRAINT [FK_Ordensub_Orden] FOREIGN KEY([Ordencompra])
REFERENCES [dbo].[Orden] ([Ordencompra])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Ordensub] CHECK CONSTRAINT [FK_Ordensub_Orden]
GO

-- %% [markdown]
-- # [FK_Ordensub_Referencias]

-- %%
ALTER TABLE [dbo].[Ordensub]  WITH NOCHECK ADD  CONSTRAINT [FK_Ordensub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Ordensub] CHECK CONSTRAINT [FK_Ordensub_Referencias]
GO

-- %% [markdown]
-- # [FK_OrdenTrabajo_Terceros]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo]  WITH NOCHECK ADD  CONSTRAINT [FK_OrdenTrabajo_Terceros] FOREIGN KEY([Cliente])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[OrdenTrabajo] CHECK CONSTRAINT [FK_OrdenTrabajo_Terceros]
GO

-- %% [markdown]
-- # [FK_OrdenTrabajo_TipoOperacion]

-- %%
ALTER TABLE [dbo].[OrdenTrabajo]  WITH CHECK ADD  CONSTRAINT [FK_OrdenTrabajo_TipoOperacion] FOREIGN KEY([Resolucion])
REFERENCES [dbo].[TipoOperacion] ([Centro])
GO
ALTER TABLE [dbo].[OrdenTrabajo] CHECK CONSTRAINT [FK_OrdenTrabajo_TipoOperacion]
GO

-- %% [markdown]
-- # [FK_Ordentrabajosub_OrdenTrabajo]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub]  WITH NOCHECK ADD  CONSTRAINT [FK_Ordentrabajosub_OrdenTrabajo] FOREIGN KEY([OrdTra])
REFERENCES [dbo].[OrdenTrabajo] ([OrdTra])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Ordentrabajosub] CHECK CONSTRAINT [FK_Ordentrabajosub_OrdenTrabajo]
GO

-- %% [markdown]
-- # [FK_Ordentrabajosub_Referencias]

-- %%
ALTER TABLE [dbo].[Ordentrabajosub]  WITH NOCHECK ADD  CONSTRAINT [FK_Ordentrabajosub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Ordentrabajosub] CHECK CONSTRAINT [FK_Ordentrabajosub_Referencias]
GO

-- %% [markdown]
-- # [FK_PagoCartera_Recaja]

-- %%
ALTER TABLE [dbo].[PagoCartera]  WITH CHECK ADD  CONSTRAINT [FK_PagoCartera_Recaja] FOREIGN KEY([IdCaja])
REFERENCES [dbo].[Recaja] ([Idcaja])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[PagoCartera] CHECK CONSTRAINT [FK_PagoCartera_Recaja]
GO

-- %% [markdown]
-- # [FK_PagoNomina_Comprobanteegreso]

-- %%
ALTER TABLE [dbo].[PagoNomina]  WITH CHECK ADD  CONSTRAINT [FK_PagoNomina_Comprobanteegreso] FOREIGN KEY([IdEgreso])
REFERENCES [dbo].[Comprobanteegreso] ([Idegreso])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[PagoNomina] CHECK CONSTRAINT [FK_PagoNomina_Comprobanteegreso]
GO

-- %% [markdown]
-- # [FK_PagoProveedores_Comprobanteegreso]

-- %%
ALTER TABLE [dbo].[PagoProveedores]  WITH CHECK ADD  CONSTRAINT [FK_PagoProveedores_Comprobanteegreso] FOREIGN KEY([IdEgreso])
REFERENCES [dbo].[Comprobanteegreso] ([Idegreso])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[PagoProveedores] CHECK CONSTRAINT [FK_PagoProveedores_Comprobanteegreso]
GO

-- %% [markdown]
-- # [FK_ParametrosDepreciacion_Activos]

-- %%
ALTER TABLE [dbo].[ParametrosDepreciacion]  WITH CHECK ADD  CONSTRAINT [FK_ParametrosDepreciacion_Activos] FOREIGN KEY([IdActivo])
REFERENCES [dbo].[Activos] ([IdActivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[ParametrosDepreciacion] CHECK CONSTRAINT [FK_ParametrosDepreciacion_Activos]
GO

-- %% [markdown]
-- # [FK_Pedidos_Empleado]

-- %%
ALTER TABLE [dbo].[Pedidos]  WITH CHECK ADD  CONSTRAINT [FK_Pedidos_Empleado] FOREIGN KEY([Promotor])
REFERENCES [dbo].[Empleado] ([Cedula])
GO
ALTER TABLE [dbo].[Pedidos] CHECK CONSTRAINT [FK_Pedidos_Empleado]
GO

-- %% [markdown]
-- # [FK_Pedidos_Terceros]

-- %%
ALTER TABLE [dbo].[Pedidos]  WITH NOCHECK ADD  CONSTRAINT [FK_Pedidos_Terceros] FOREIGN KEY([Cliente])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Pedidos] CHECK CONSTRAINT [FK_Pedidos_Terceros]
GO

-- %% [markdown]
-- # [FK_Pedisub_Pedidos]

-- %%
ALTER TABLE [dbo].[Pedisub]  WITH CHECK ADD  CONSTRAINT [FK_Pedisub_Pedidos] FOREIGN KEY([Facturanumero])
REFERENCES [dbo].[Pedidos] ([Facturanumero])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Pedisub] CHECK CONSTRAINT [FK_Pedisub_Pedidos]
GO

-- %% [markdown]
-- # [FK_Pedisub_Referencias]

-- %%
ALTER TABLE [dbo].[Pedisub]  WITH NOCHECK ADD  CONSTRAINT [FK_Pedisub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Pedisub] CHECK CONSTRAINT [FK_Pedisub_Referencias]
GO

-- %% [markdown]
-- # [FK_Plandescuentos_Vehiculos]

-- %%
ALTER TABLE [dbo].[Plandescuentos]  WITH CHECK ADD  CONSTRAINT [FK_Plandescuentos_Vehiculos] FOREIGN KEY([Placa])
REFERENCES [dbo].[Vehiculos] ([Placa])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Plandescuentos] CHECK CONSTRAINT [FK_Plandescuentos_Vehiculos]
GO

-- %% [markdown]
-- # [FK_PlanillaMatrix_Matrix]

-- %%
ALTER TABLE [dbo].[PlanillaMatrix]  WITH NOCHECK ADD  CONSTRAINT [FK_PlanillaMatrix_Matrix] FOREIGN KEY([Factura])
REFERENCES [dbo].[Matrix] ([Factura])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[PlanillaMatrix] CHECK CONSTRAINT [FK_PlanillaMatrix_Matrix]
GO

-- %% [markdown]
-- # [FK_Precios_Referencias]

-- %%
ALTER TABLE [dbo].[Precios]  WITH NOCHECK ADD  CONSTRAINT [FK_Precios_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Precios] CHECK CONSTRAINT [FK_Precios_Referencias]
GO

-- %% [markdown]
-- # [FK_Presupuestarsub_Presupuestar]

-- %%
ALTER TABLE [dbo].[Presupuestarsub]  WITH CHECK ADD  CONSTRAINT [FK_Presupuestarsub_Presupuestar] FOREIGN KEY([PresupuestoNo])
REFERENCES [dbo].[Presupuestar] ([PresupuestoNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Presupuestarsub] CHECK CONSTRAINT [FK_Presupuestarsub_Presupuestar]
GO

-- %% [markdown]
-- # [FK_Presupuestosub_Presupuesto]

-- %%
ALTER TABLE [dbo].[Presupuestosub]  WITH CHECK ADD  CONSTRAINT [FK_Presupuestosub_Presupuesto] FOREIGN KEY([Idpresupuesto])
REFERENCES [dbo].[Presupuesto] ([idpresupuesto])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Presupuestosub] CHECK CONSTRAINT [FK_Presupuestosub_Presupuesto]
GO

-- %% [markdown]
-- # [FK_PricingAereo_PricingAereoBase]

-- %%
ALTER TABLE [dbo].[PricingAereo]  WITH CHECK ADD  CONSTRAINT [FK_PricingAereo_PricingAereoBase] FOREIGN KEY([Operacion])
REFERENCES [dbo].[PricingAereoBase] ([Operacion])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[PricingAereo] CHECK CONSTRAINT [FK_PricingAereo_PricingAereoBase]
GO

-- %% [markdown]
-- # [FK_PricingFCL_PricingFCLBase]

-- %%
ALTER TABLE [dbo].[PricingFCL]  WITH CHECK ADD  CONSTRAINT [FK_PricingFCL_PricingFCLBase] FOREIGN KEY([Operacion])
REFERENCES [dbo].[PricingFCLBase] ([Operacion])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[PricingFCL] CHECK CONSTRAINT [FK_PricingFCL_PricingFCLBase]
GO

-- %% [markdown]
-- # [FK_PricingLCL_PricingLCLBase]

-- %%
ALTER TABLE [dbo].[PricingLCL]  WITH CHECK ADD  CONSTRAINT [FK_PricingLCL_PricingLCLBase] FOREIGN KEY([Operacion])
REFERENCES [dbo].[PricingLCLBase] ([Operacion])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[PricingLCL] CHECK CONSTRAINT [FK_PricingLCL_PricingLCLBase]
GO

-- %% [markdown]
-- # [FK_PricingOTM_PricingOTMBase]

-- %%
ALTER TABLE [dbo].[PricingOTM]  WITH CHECK ADD  CONSTRAINT [FK_PricingOTM_PricingOTMBase] FOREIGN KEY([Operacion])
REFERENCES [dbo].[PricingOTMBase] ([Operacion])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[PricingOTM] CHECK CONSTRAINT [FK_PricingOTM_PricingOTMBase]
GO

-- %% [markdown]
-- # [FK_PricingTerrestre_PricingTerrestreBase]

-- %%
ALTER TABLE [dbo].[PricingTerrestre]  WITH CHECK ADD  CONSTRAINT [FK_PricingTerrestre_PricingTerrestreBase] FOREIGN KEY([Operacion])
REFERENCES [dbo].[PricingTerrestreBase] ([Operacion])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[PricingTerrestre] CHECK CONSTRAINT [FK_PricingTerrestre_PricingTerrestreBase]
GO

-- %% [markdown]
-- # [FK_Procesosub_Proceso]

-- %%
ALTER TABLE [dbo].[Procesosub]  WITH CHECK ADD  CONSTRAINT [FK_Procesosub_Proceso] FOREIGN KEY([IdProduccion])
REFERENCES [dbo].[Proceso] ([Idproduccion])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Procesosub] CHECK CONSTRAINT [FK_Procesosub_Proceso]
GO

-- %% [markdown]
-- # [FK_Procesosub_Referencias]

-- %%
ALTER TABLE [dbo].[Procesosub]  WITH NOCHECK ADD  CONSTRAINT [FK_Procesosub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Procesosub] CHECK CONSTRAINT [FK_Procesosub_Referencias]
GO

-- %% [markdown]
-- # [FK_ProduccionOrdenref_ProduccionOrden]

-- %%
ALTER TABLE [dbo].[ProduccionOrdenref]  WITH CHECK ADD  CONSTRAINT [FK_ProduccionOrdenref_ProduccionOrden] FOREIGN KEY([Idproduccion])
REFERENCES [dbo].[ProduccionOrden] ([Idproduccion])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[ProduccionOrdenref] CHECK CONSTRAINT [FK_ProduccionOrdenref_ProduccionOrden]
GO

-- %% [markdown]
-- # [FK_Produccionordensub_ProduccionOrden]

-- %%
ALTER TABLE [dbo].[Produccionordensub]  WITH CHECK ADD  CONSTRAINT [FK_Produccionordensub_ProduccionOrden] FOREIGN KEY([IdProduccion])
REFERENCES [dbo].[ProduccionOrden] ([Idproduccion])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Produccionordensub] CHECK CONSTRAINT [FK_Produccionordensub_ProduccionOrden]
GO

-- %% [markdown]
-- # [FK_Produccionordensub_Referencias]

-- %%
ALTER TABLE [dbo].[Produccionordensub]  WITH CHECK ADD  CONSTRAINT [FK_Produccionordensub_Referencias] FOREIGN KEY([Insumo])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Produccionordensub] CHECK CONSTRAINT [FK_Produccionordensub_Referencias]
GO

-- %% [markdown]
-- # [FK_Produccionsub_Produccion]

-- %%
ALTER TABLE [dbo].[Produccionsub]  WITH CHECK ADD  CONSTRAINT [FK_Produccionsub_Produccion] FOREIGN KEY([IdProduccion])
REFERENCES [dbo].[Produccion] ([Idproduccion])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Produccionsub] CHECK CONSTRAINT [FK_Produccionsub_Produccion]
GO

-- %% [markdown]
-- # [FK_Produccionsub_Referencias]

-- %%
ALTER TABLE [dbo].[Produccionsub]  WITH NOCHECK ADD  CONSTRAINT [FK_Produccionsub_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Produccionsub] CHECK CONSTRAINT [FK_Produccionsub_Referencias]
GO

-- %% [markdown]
-- # [FK_Recaja_Terceros]

-- %%
ALTER TABLE [dbo].[Recaja]  WITH NOCHECK ADD  CONSTRAINT [FK_Recaja_Terceros] FOREIGN KEY([Nombre])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Recaja] CHECK CONSTRAINT [FK_Recaja_Terceros]
GO

-- %% [markdown]
-- # [FK_Reclasificacionsub_Reclasificacion]

-- %%
ALTER TABLE [dbo].[Reclasificacionsub]  WITH NOCHECK ADD  CONSTRAINT [FK_Reclasificacionsub_Reclasificacion] FOREIGN KEY([DocNo])
REFERENCES [dbo].[Reclasificacion] ([DocNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Reclasificacionsub] CHECK CONSTRAINT [FK_Reclasificacionsub_Reclasificacion]
GO

-- %% [markdown]
-- # [FK_Reclasificacionsub_Terceros]

-- %%
ALTER TABLE [dbo].[Reclasificacionsub]  WITH NOCHECK ADD  CONSTRAINT [FK_Reclasificacionsub_Terceros] FOREIGN KEY([Cliente])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Reclasificacionsub] CHECK CONSTRAINT [FK_Reclasificacionsub_Terceros]
GO

-- %% [markdown]
-- # [FK_Resuldebilidades_Debilidades]

-- %%
ALTER TABLE [dbo].[Resuldebilidades]  WITH CHECK ADD  CONSTRAINT [FK_Resuldebilidades_Debilidades] FOREIGN KEY([Codigodeb])
REFERENCES [dbo].[Debilidades] ([IdDebilidades])
GO
ALTER TABLE [dbo].[Resuldebilidades] CHECK CONSTRAINT [FK_Resuldebilidades_Debilidades]
GO

-- %% [markdown]
-- # [FK_Resuldebilidades_Resultados]

-- %%
ALTER TABLE [dbo].[Resuldebilidades]  WITH CHECK ADD  CONSTRAINT [FK_Resuldebilidades_Resultados] FOREIGN KEY([Idcolegios])
REFERENCES [dbo].[Resultados] ([Idcolegios])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Resuldebilidades] CHECK CONSTRAINT [FK_Resuldebilidades_Resultados]
GO

-- %% [markdown]
-- # [FK_Resulfortalezas_Fortalezas]

-- %%
ALTER TABLE [dbo].[Resulfortalezas]  WITH CHECK ADD  CONSTRAINT [FK_Resulfortalezas_Fortalezas] FOREIGN KEY([Codigofor])
REFERENCES [dbo].[Fortalezas] ([Idfortaleza])
GO
ALTER TABLE [dbo].[Resulfortalezas] CHECK CONSTRAINT [FK_Resulfortalezas_Fortalezas]
GO

-- %% [markdown]
-- # [FK_Resulfortalezas_Resultados]

-- %%
ALTER TABLE [dbo].[Resulfortalezas]  WITH CHECK ADD  CONSTRAINT [FK_Resulfortalezas_Resultados] FOREIGN KEY([Idcolegios])
REFERENCES [dbo].[Resultados] ([Idcolegios])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Resulfortalezas] CHECK CONSTRAINT [FK_Resulfortalezas_Resultados]
GO

-- %% [markdown]
-- # [FK_Resulrecomendaciones_Recomendaciones]

-- %%
ALTER TABLE [dbo].[Resulrecomendaciones]  WITH CHECK ADD  CONSTRAINT [FK_Resulrecomendaciones_Recomendaciones] FOREIGN KEY([Codigorec])
REFERENCES [dbo].[Recomendaciones] ([IdRecomendaciones])
GO
ALTER TABLE [dbo].[Resulrecomendaciones] CHECK CONSTRAINT [FK_Resulrecomendaciones_Recomendaciones]
GO

-- %% [markdown]
-- # [FK_Resulrecomendaciones_Resultados]

-- %%
ALTER TABLE [dbo].[Resulrecomendaciones]  WITH CHECK ADD  CONSTRAINT [FK_Resulrecomendaciones_Resultados] FOREIGN KEY([Idcolegios])
REFERENCES [dbo].[Resultados] ([Idcolegios])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Resulrecomendaciones] CHECK CONSTRAINT [FK_Resulrecomendaciones_Resultados]
GO

-- %% [markdown]
-- # [FK_Resultados_Alumnos]

-- %%
ALTER TABLE [dbo].[Resultados]  WITH CHECK ADD  CONSTRAINT [FK_Resultados_Alumnos] FOREIGN KEY([Codigo])
REFERENCES [dbo].[Alumnos] ([Codigo])
GO
ALTER TABLE [dbo].[Resultados] CHECK CONSTRAINT [FK_Resultados_Alumnos]
GO

-- %% [markdown]
-- # [FK_Resultados_Calificaciones]

-- %%
ALTER TABLE [dbo].[Resultados]  WITH CHECK ADD  CONSTRAINT [FK_Resultados_Calificaciones] FOREIGN KEY([Calificacion])
REFERENCES [dbo].[Calificaciones] ([Calificacion])
GO
ALTER TABLE [dbo].[Resultados] CHECK CONSTRAINT [FK_Resultados_Calificaciones]
GO

-- %% [markdown]
-- # [FK_Resultados_Periodos]

-- %%
ALTER TABLE [dbo].[Resultados]  WITH CHECK ADD  CONSTRAINT [FK_Resultados_Periodos] FOREIGN KEY([Periodo])
REFERENCES [dbo].[Periodos] ([Periodo])
GO
ALTER TABLE [dbo].[Resultados] CHECK CONSTRAINT [FK_Resultados_Periodos]
GO

-- %% [markdown]
-- # [FK_Retirosub_RetiroCaja]

-- %%
ALTER TABLE [dbo].[Retirosub]  WITH CHECK ADD  CONSTRAINT [FK_Retirosub_RetiroCaja] FOREIGN KEY([IdRetiro])
REFERENCES [dbo].[RetiroCaja] ([IdRetiro])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Retirosub] CHECK CONSTRAINT [FK_Retirosub_RetiroCaja]
GO

-- %% [markdown]
-- # [FK_Rutasub_Rutas]

-- %%
ALTER TABLE [dbo].[Rutasub]  WITH CHECK ADD  CONSTRAINT [FK_Rutasub_Rutas] FOREIGN KEY([Cobertura])
REFERENCES [dbo].[Rutas] ([OrigenDestino])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Rutasub] CHECK CONSTRAINT [FK_Rutasub_Rutas]
GO

-- %% [markdown]
-- # [FK_Salidas_Referencias]

-- %%
ALTER TABLE [dbo].[Salidas]  WITH NOCHECK ADD  CONSTRAINT [FK_Salidas_Referencias] FOREIGN KEY([Referencia])
REFERENCES [dbo].[Referencias] ([Referencia])
GO
ALTER TABLE [dbo].[Salidas] CHECK CONSTRAINT [FK_Salidas_Referencias]
GO

-- %% [markdown]
-- # [FK_Salidas_Salidasenc]

-- %%
ALTER TABLE [dbo].[Salidas]  WITH CHECK ADD  CONSTRAINT [FK_Salidas_Salidasenc] FOREIGN KEY([Idinventarios])
REFERENCES [dbo].[Salidasenc] ([Idinventarios])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Salidas] CHECK CONSTRAINT [FK_Salidas_Salidasenc]
GO

-- %% [markdown]
-- # [FK_Salidasenc_Terceros]

-- %%
ALTER TABLE [dbo].[Salidasenc]  WITH NOCHECK ADD  CONSTRAINT [FK_Salidasenc_Terceros] FOREIGN KEY([Tercero])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[Salidasenc] CHECK CONSTRAINT [FK_Salidasenc_Terceros]
GO

-- %% [markdown]
-- # [FK_Simuladorsub_Simulador]

-- %%
ALTER TABLE [dbo].[Simuladorsub]  WITH CHECK ADD  CONSTRAINT [FK_Simuladorsub_Simulador] FOREIGN KEY([SimulaNo])
REFERENCES [dbo].[Simulador] ([SimulaNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Simuladorsub] CHECK CONSTRAINT [FK_Simuladorsub_Simulador]
GO

-- %% [markdown]
-- # [FK_Strategy12_Strategy1]

-- %%
ALTER TABLE [dbo].[Strategy12]  WITH CHECK ADD  CONSTRAINT [FK_Strategy12_Strategy1] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Strategy1] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Strategy12] CHECK CONSTRAINT [FK_Strategy12_Strategy1]
GO

-- %% [markdown]
-- # [FK_Strategy13_Strategy1]

-- %%
ALTER TABLE [dbo].[Strategy13]  WITH CHECK ADD  CONSTRAINT [FK_Strategy13_Strategy1] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Strategy1] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Strategy13] CHECK CONSTRAINT [FK_Strategy13_Strategy1]
GO

-- %% [markdown]
-- # [FK_Strategy14_Strategy1]

-- %%
ALTER TABLE [dbo].[Strategy14]  WITH CHECK ADD  CONSTRAINT [FK_Strategy14_Strategy1] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Strategy1] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Strategy14] CHECK CONSTRAINT [FK_Strategy14_Strategy1]
GO

-- %% [markdown]
-- # [FK_Strategy15_Strategy1]

-- %%
ALTER TABLE [dbo].[Strategy15]  WITH CHECK ADD  CONSTRAINT [FK_Strategy15_Strategy1] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Strategy1] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Strategy15] CHECK CONSTRAINT [FK_Strategy15_Strategy1]
GO

-- %% [markdown]
-- # [FK_Strategy16_Strategy1]

-- %%
ALTER TABLE [dbo].[Strategy16]  WITH CHECK ADD  CONSTRAINT [FK_Strategy16_Strategy1] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Strategy1] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Strategy16] CHECK CONSTRAINT [FK_Strategy16_Strategy1]
GO

-- %% [markdown]
-- # [FK_Strategy21_Strategy2]

-- %%
ALTER TABLE [dbo].[Strategy21]  WITH CHECK ADD  CONSTRAINT [FK_Strategy21_Strategy2] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Strategy2] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Strategy21] CHECK CONSTRAINT [FK_Strategy21_Strategy2]
GO

-- %% [markdown]
-- # [FK_Strategy21_Strategy20]

-- %%
ALTER TABLE [dbo].[Strategy21]  WITH CHECK ADD  CONSTRAINT [FK_Strategy21_Strategy20] FOREIGN KEY([Codigo])
REFERENCES [dbo].[Strategy20] ([Codigo])
GO
ALTER TABLE [dbo].[Strategy21] CHECK CONSTRAINT [FK_Strategy21_Strategy20]
GO

-- %% [markdown]
-- # [FK_Strategy22_Strategy2]

-- %%
ALTER TABLE [dbo].[Strategy22]  WITH CHECK ADD  CONSTRAINT [FK_Strategy22_Strategy2] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Strategy2] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Strategy22] CHECK CONSTRAINT [FK_Strategy22_Strategy2]
GO

-- %% [markdown]
-- # [FK_Strategy31_Strategy3]

-- %%
ALTER TABLE [dbo].[Strategy31]  WITH CHECK ADD  CONSTRAINT [FK_Strategy31_Strategy3] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Strategy3] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Strategy31] CHECK CONSTRAINT [FK_Strategy31_Strategy3]
GO

-- %% [markdown]
-- # [FK_Strategy32_Strategy3]

-- %%
ALTER TABLE [dbo].[Strategy32]  WITH CHECK ADD  CONSTRAINT [FK_Strategy32_Strategy3] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Strategy3] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Strategy32] CHECK CONSTRAINT [FK_Strategy32_Strategy3]
GO

-- %% [markdown]
-- # [FK_Strategy51_Strategy5]

-- %%
ALTER TABLE [dbo].[Strategy51]  WITH CHECK ADD  CONSTRAINT [FK_Strategy51_Strategy5] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Strategy5] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Strategy51] CHECK CONSTRAINT [FK_Strategy51_Strategy5]
GO

-- %% [markdown]
-- # [FK_Strategy54_Strategy50]

-- %%
ALTER TABLE [dbo].[Strategy54]  WITH CHECK ADD  CONSTRAINT [FK_Strategy54_Strategy50] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Strategy50] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Strategy54] CHECK CONSTRAINT [FK_Strategy54_Strategy50]
GO

-- %% [markdown]
-- # [FK_Strategy61_Strategy6]

-- %%
ALTER TABLE [dbo].[Strategy61]  WITH CHECK ADD  CONSTRAINT [FK_Strategy61_Strategy6] FOREIGN KEY([Consecutivo])
REFERENCES [dbo].[Strategy6] ([Consecutivo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Strategy61] CHECK CONSTRAINT [FK_Strategy61_Strategy6]
GO

-- %% [markdown]
-- # [FK_Sucursales_Terceros]

-- %%
ALTER TABLE [dbo].[Sucursales]  WITH NOCHECK ADD  CONSTRAINT [FK_Sucursales_Terceros] FOREIGN KEY([Identificacion])
REFERENCES [dbo].[Terceros] ([Identificacion])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Sucursales] CHECK CONSTRAINT [FK_Sucursales_Terceros]
GO

-- %% [markdown]
-- # [FK_Terceros_Clases]

-- %%
ALTER TABLE [dbo].[Terceros]  WITH NOCHECK ADD  CONSTRAINT [FK_Terceros_Clases] FOREIGN KEY([Clase])
REFERENCES [dbo].[Clases] ([Clase])
GO
ALTER TABLE [dbo].[Terceros] CHECK CONSTRAINT [FK_Terceros_Clases]
GO

-- %% [markdown]
-- # [FK_TercerosConceptos_Terceros]

-- %%
ALTER TABLE [dbo].[TercerosConceptos]  WITH CHECK ADD  CONSTRAINT [FK_TercerosConceptos_Terceros] FOREIGN KEY([Tercero])
REFERENCES [dbo].[Terceros] ([Identificacion])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[TercerosConceptos] CHECK CONSTRAINT [FK_TercerosConceptos_Terceros]
GO

-- %% [markdown]
-- # [FK_Tercerosreferencias_Terceros]

-- %%
ALTER TABLE [dbo].[Tercerosreferencias]  WITH CHECK ADD  CONSTRAINT [FK_Tercerosreferencias_Terceros] FOREIGN KEY([Identificacion])
REFERENCES [dbo].[Terceros] ([Identificacion])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Tercerosreferencias] CHECK CONSTRAINT [FK_Tercerosreferencias_Terceros]
GO

-- %% [markdown]
-- # [FK_Tiempos_Cumplir]

-- %%
ALTER TABLE [dbo].[Tiempos]  WITH CHECK ADD  CONSTRAINT [FK_Tiempos_Cumplir] FOREIGN KEY([Cumplido])
REFERENCES [dbo].[Cumplir] ([CumplidoNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Tiempos] CHECK CONSTRAINT [FK_Tiempos_Cumplir]
GO

-- %% [markdown]
-- # [FK_TiemposPlaneado_OCargue]

-- %%
ALTER TABLE [dbo].[TiemposPlaneado]  WITH CHECK ADD  CONSTRAINT [FK_TiemposPlaneado_OCargue] FOREIGN KEY([OCargue])
REFERENCES [dbo].[OCargue] ([OrdenNo])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[TiemposPlaneado] CHECK CONSTRAINT [FK_TiemposPlaneado_OCargue]
GO

-- %% [markdown]
-- # [FK_Transporte_MinMDependencias]

-- %%
ALTER TABLE [dbo].[Transporte]  WITH CHECK ADD  CONSTRAINT [FK_Transporte_MinMDependencias] FOREIGN KEY([CodRegional])
REFERENCES [dbo].[MinMDependencias] ([Codigo])
GO
ALTER TABLE [dbo].[Transporte] CHECK CONSTRAINT [FK_Transporte_MinMDependencias]
GO

-- %% [markdown]
-- # [FK_Vehiculos_Conductores]

-- %%
ALTER TABLE [dbo].[Vehiculos]  WITH NOCHECK ADD  CONSTRAINT [FK_Vehiculos_Conductores] FOREIGN KEY([Conductor])
REFERENCES [dbo].[Conductores] ([Cedula])
GO
ALTER TABLE [dbo].[Vehiculos] CHECK CONSTRAINT [FK_Vehiculos_Conductores]
GO

-- %% [markdown]
-- # [FK_VehiculosPendientes_TipoPendientes]

-- %%
ALTER TABLE [dbo].[VehiculosPendientes]  WITH NOCHECK ADD  CONSTRAINT [FK_VehiculosPendientes_TipoPendientes] FOREIGN KEY([Tipo])
REFERENCES [dbo].[TipoPendientes] ([TipoPendiente])
GO
ALTER TABLE [dbo].[VehiculosPendientes] CHECK CONSTRAINT [FK_VehiculosPendientes_TipoPendientes]
GO

-- %% [markdown]
-- # [FK_VehiculosPendientes_Vehiculos]

-- %%
ALTER TABLE [dbo].[VehiculosPendientes]  WITH NOCHECK ADD  CONSTRAINT [FK_VehiculosPendientes_Vehiculos] FOREIGN KEY([Placa])
REFERENCES [dbo].[Vehiculos] ([Placa])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[VehiculosPendientes] CHECK CONSTRAINT [FK_VehiculosPendientes_Vehiculos]
GO

-- %% [markdown]
-- # [FK_Verificacionsub_Verificacion]

-- %%
ALTER TABLE [dbo].[Verificacionsub]  WITH CHECK ADD  CONSTRAINT [FK_Verificacionsub_Verificacion] FOREIGN KEY([Lista])
REFERENCES [dbo].[Verificacion] ([Lista])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Verificacionsub] CHECK CONSTRAINT [FK_Verificacionsub_Verificacion]
GO

-- %% [markdown]
-- # [FK_VirtualCEgreso_Terceros1]

-- %%
ALTER TABLE [dbo].[VirtualCEgreso]  WITH NOCHECK ADD  CONSTRAINT [FK_VirtualCEgreso_Terceros1] FOREIGN KEY([Pagado a])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[VirtualCEgreso] CHECK CONSTRAINT [FK_VirtualCEgreso_Terceros1]
GO

-- %% [markdown]
-- # [FK_VirtualRecaja_Terceros]

-- %%
ALTER TABLE [dbo].[VirtualRecaja]  WITH NOCHECK ADD  CONSTRAINT [FK_VirtualRecaja_Terceros] FOREIGN KEY([Nombre])
REFERENCES [dbo].[Terceros] ([Identificacion])
GO
ALTER TABLE [dbo].[VirtualRecaja] CHECK CONSTRAINT [FK_VirtualRecaja_Terceros]
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'Comprobanteegreso', @level2type=N'COLUMN',@level2name=N'ReteIca'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'Nomina', @level2type=N'COLUMN',@level2name=N'ProFamiliar'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'Nomina', @level2type=N'COLUMN',@level2name=N'Incapacidad'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'NominaDian', @level2type=N'COLUMN',@level2name=N'ProFamiliar'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'NominaDian', @level2type=N'COLUMN',@level2name=N'Incapacidad'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'Proyecventas2', @level2type=N'COLUMN',@level2name=N'Cantidad10'
GO
